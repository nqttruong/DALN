# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12hdem) - Copy (5)\diengiadung"
os.listdir(path)
# Out:
# ['brand - Copy (2)',
#  'category.ipynb',
#  'dodungnhabep',
#  'thietbigiadinh',
#  'tk_dodungnhabep_all_ed.csv',
#  'tk_thietbigiadinh_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#       Unnamed: 0                                              title    price  \
# 0              0  Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1999000
# 1              1  Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   239000
# 2              2  Nồi chiên không dầu đa chức năng 12 trong 1 Su...  1599000
# 3              3  Máy Xay Sinh Tố Đa Năng Sunhouse HappyTime HTD...   349000
# 4              4  Nồi Cơm Nắp Gài Toshiba RC-10JFM(H)VN (1L) - H...   525000
# ...          ...                                                ...      ...
# 1276        1276                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP   390000
# 1277        1277  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...   450000
# 1278        1278  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1599000
# 1279        1279  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    59000
# 1280        1280  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   600000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=poDyYuobi...     -31%  2300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=kJlLkJ32e...     -55%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=wWIjOg9Qe...     -41%   192.0
# 3     https://tiki.vn/may-xay-sinh-to-da-nang-sunhou...      NaN  5000.0
# 4     https://tiki.vn/noi-com-nap-gai-toshiba-rc-10j...     -40%    80.0
# ...                                                 ...      ...     ...
# 1276  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    26.0
# 1277  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    14.0
# 1278  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    39.0
# 1279  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1280  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   395.0
#
#             category       revenue
# 0       dodungnhabep  4.597700e+09
# 1       dodungnhabep  1.195000e+09
# 2       dodungnhabep  3.070080e+08
# 3       dodungnhabep  1.745000e+09
# 4       dodungnhabep  4.200000e+07
# ...              ...           ...
# 1276  thietbigiadinh  1.014000e+07
# 1277  thietbigiadinh  6.300000e+06
# 1278  thietbigiadinh  6.236100e+07
# 1279  thietbigiadinh  1.475000e+06
# 1280  thietbigiadinh  2.370000e+08
#
# [2587 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "diengiadung")

# %%
df
# Out:
#                                                   title    price  \
# 0     Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1999000
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   239000
# 2     Nồi chiên không dầu đa chức năng 12 trong 1 Su...  1599000
# 3     Máy Xay Sinh Tố Đa Năng Sunhouse HappyTime HTD...   349000
# 4     Nồi Cơm Nắp Gài Toshiba RC-10JFM(H)VN (1L) - H...   525000
# ...                                                 ...      ...
# 1276                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP   390000
# 1277  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...   450000
# 1278  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1599000
# 1279  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    59000
# 1280  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   600000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=poDyYuobi...     -31%  2300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=kJlLkJ32e...     -55%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=wWIjOg9Qe...     -41%   192.0
# 3     https://tiki.vn/may-xay-sinh-to-da-nang-sunhou...      NaN  5000.0
# 4     https://tiki.vn/noi-com-nap-gai-toshiba-rc-10j...     -40%    80.0
# ...                                                 ...      ...     ...
# 1276  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    26.0
# 1277  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    14.0
# 1278  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    39.0
# 1279  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1280  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   395.0
#
#            item_list     category       revenue
# 0       dodungnhabep  diengiadung  4.597700e+09
# 1       dodungnhabep  diengiadung  1.195000e+09
# 2       dodungnhabep  diengiadung  3.070080e+08
# 3       dodungnhabep  diengiadung  1.745000e+09
# 4       dodungnhabep  diengiadung  4.200000e+07
# ...              ...          ...           ...
# 1276  thietbigiadinh  diengiadung  1.014000e+07
# 1277  thietbigiadinh  diengiadung  6.300000e+06
# 1278  thietbigiadinh  diengiadung  6.236100e+07
# 1279  thietbigiadinh  diengiadung  1.475000e+06
# 1280  thietbigiadinh  diengiadung  2.370000e+08
#
# [2587 rows x 8 columns]

# %%
df.to_csv('tk_diengiadung_all_ed.csv', index=False, encoding='utf-8')
