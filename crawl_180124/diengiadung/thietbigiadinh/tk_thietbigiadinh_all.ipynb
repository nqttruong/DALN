# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12hdem) - Copy (5)\diengiadung\thietbigiadinh"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dgd_tbgd.ipynb',
#  'tk_dgd_tbgd_npage.ipynb',
#  'tk_thietbigiadinh_all.ipynb',
#  'tk_thietbigiadinh_t1.csv',
#  'tk_thietbigiadinh_t10.csv',
#  'tk_thietbigiadinh_t11.csv',
#  'tk_thietbigiadinh_t12.csv',
#  'tk_thietbigiadinh_t13.csv',
#  'tk_thietbigiadinh_t14.csv',
#  'tk_thietbigiadinh_t15.csv',
#  'tk_thietbigiadinh_t16.csv',
#  'tk_thietbigiadinh_t17.csv',
#  'tk_thietbigiadinh_t18.csv',
#  'tk_thietbigiadinh_t19.csv',
#  'tk_thietbigiadinh_t2.csv',
#  'tk_thietbigiadinh_t20.csv',
#  'tk_thietbigiadinh_t21.csv',
#  'tk_thietbigiadinh_t22.csv',
#  'tk_thietbigiadinh_t23.csv',
#  'tk_thietbigiadinh_t24.csv',
#  'tk_thietbigiadinh_t25.csv',
#  'tk_thietbigiadinh_t26.csv',
#  'tk_thietbigiadinh_t27.csv',
#  'tk_thietbigiadinh_t28.csv',
#  'tk_thietbigiadinh_t29.csv',
#  'tk_thietbigiadinh_t3.csv',
#  'tk_thietbigiadinh_t30.csv',
#  'tk_thietbigiadinh_t31.csv',
#  'tk_thietbigiadinh_t32.csv',
#  'tk_thietbigiadinh_t33.csv',
#  'tk_thietbigiadinh_t34.csv',
#  'tk_thietbigiadinh_t35.csv',
#  'tk_thietbigiadinh_t36.csv',
#  'tk_thietbigiadinh_t37.csv',
#  'tk_thietbigiadinh_t38.csv',
#  'tk_thietbigiadinh_t39.csv',
#  'tk_thietbigiadinh_t4.csv',
#  'tk_thietbigiadinh_t40.csv',
#  'tk_thietbigiadinh_t41.csv',
#  'tk_thietbigiadinh_t42.csv',
#  'tk_thietbigiadinh_t43.csv',
#  'tk_thietbigiadinh_t44.csv',
#  'tk_thietbigiadinh_t45.csv',
#  'tk_thietbigiadinh_t46.csv',
#  'tk_thietbigiadinh_t47.csv',
#  'tk_thietbigiadinh_t48.csv',
#  'tk_thietbigiadinh_t49.csv',
#  'tk_thietbigiadinh_t5.csv',
#  'tk_thietbigiadinh_t50.csv',
#  'tk_thietbigiadinh_t6.csv',
#  'tk_thietbigiadinh_t7.csv',
#  'tk_thietbigiadinh_t8.csv',
#  'tk_thietbigiadinh_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_thietbigiadinh_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Máy Hút Bụi Lock&Lock ENV336BLK (400W) - Hàng ...  1.499.000₫
# 1   Máy Lọc Nước RO Hydrogen Ion Kiềm Kangaroo KG1...  3.199.000₫
# 2   Máy Lọc Nước RO Kangaroo VTU KG108A 8 Lõi - Hà...  3.379.000₫
# 3   Máy Lọc Nước RO Không Vỏ Tủ Kangaroo KG109A 9 ...   4.970.000
# 4                                                 NaN         NaN
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1.599.000₫
# 37  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...     59.000₫
# 38  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...    600.000₫
# 39  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...   1.600.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=tiAlcjgSB...      1     -54%
# 1   https://tka.tiki.vn/pixel/pixel?data=2Z3lzjjVn...      2     -75%
# 2   https://tka.tiki.vn/pixel/pixel?data=KchBb33So...      3     -55%
# 3   https://tka.tiki.vn/pixel/pixel?data=naYJZ_f0Q...      4      NaN
# 4   https://tka.tiki.vn/pixel/pixel?data=lwWxnKLPD...      5     -48%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...     36      NaN
# 36  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...     37      NaN
# 37  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...     38      NaN
# 38  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...     39      NaN
# 39  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...     40      NaN
#
#           sales        category
# 0   Đã bán 3.7k  thietbigiadinh
# 1     Đã bán 41  thietbigiadinh
# 2    Đã bán 948  thietbigiadinh
# 3           NaN  thietbigiadinh
# 4           NaN  thietbigiadinh
# ..          ...             ...
# 35          NaN  thietbigiadinh
# 36    Đã bán 39  thietbigiadinh
# 37    Đã bán 25  thietbigiadinh
# 38   Đã bán 395  thietbigiadinh
# 39          NaN  thietbigiadinh
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     Máy Hút Bụi Lock&Lock ENV336BLK (400W) - Hàng ...  1.499.000₫
# 1     Máy Lọc Nước RO Hydrogen Ion Kiềm Kangaroo KG1...  3.199.000₫
# 2     Máy Lọc Nước RO Kangaroo VTU KG108A 8 Lõi - Hà...  3.379.000₫
# 3     Máy Hút Bụi Cầm Tay Không Dây Damas XC628 - Ch...    439.000₫
# 4     Máy Hút Bụi Mini Cầm Tay Deerma DX118C Công Su...    479.000₫
# ...                                                 ...         ...
# 1276                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP    390.000₫
# 1277  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...    450.000₫
# 1278  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1.599.000₫
# 1279  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...     59.000₫
# 1280  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...    600.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=tiAlcjgSB...     -54%  Đã bán 3.7k
# 1     https://tka.tiki.vn/pixel/pixel?data=2Z3lzjjVn...     -75%    Đã bán 41
# 2     https://tka.tiki.vn/pixel/pixel?data=KchBb33So...     -55%   Đã bán 948
# 3     https://tiki.vn/may-hut-bui-cam-tay-khong-day-...     -39%   Đã bán 5k+
# 4     https://tiki.vn/may-hut-bui-mini-cam-tay-deerm...     -51%  Đã bán 1.2k
# ...                                                 ...      ...          ...
# 1276  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    Đã bán 26
# 1277  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    Đã bán 14
# 1278  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    Đã bán 39
# 1279  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    Đã bán 25
# 1280  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   Đã bán 395
#
#             category
# 0     thietbigiadinh
# 1     thietbigiadinh
# 2     thietbigiadinh
# 3     thietbigiadinh
# 4     thietbigiadinh
# ...              ...
# 1276  thietbigiadinh
# 1277  thietbigiadinh
# 1278  thietbigiadinh
# 1279  thietbigiadinh
# 1280  thietbigiadinh
#
# [1281 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       1499000
# 1       3199000
# 2       3379000
# 3        439000
# 4        479000
#          ...
# 1276     390000
# 1277     450000
# 1278    1599000
# 1279      59000
# 1280     600000
# Name: price, Length: 1281, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       3700.0
# 1         41.0
# 2        948.0
# 3       5000.0
# 4       1200.0
#          ...
# 1276      26.0
# 1277      14.0
# 1278      39.0
# 1279      25.0
# 1280     395.0
# Name: sales, Length: 1281, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       5.546300e+09
# 1       1.311590e+08
# 2       3.203292e+09
# 3       2.195000e+09
# 4       5.748000e+08
#             ...
# 1276    1.014000e+07
# 1277    6.300000e+06
# 1278    6.236100e+07
# 1279    1.475000e+06
# 1280    2.370000e+08
# Name: revenue, Length: 1281, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số thiet bi gia dinh: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số thiet bi gia dinh:  151188236523.0
# So mat hang da ban:  1281
# So san pham da ban:  202177.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Máy Hút Bụi Lock&Lock ENV336BLK (400W) - Hàng ...  1499000
# 1     Máy Lọc Nước RO Hydrogen Ion Kiềm Kangaroo KG1...  3199000
# 2     Máy Lọc Nước RO Kangaroo VTU KG108A 8 Lõi - Hà...  3379000
# 3     Máy Hút Bụi Cầm Tay Không Dây Damas XC628 - Ch...   439000
# 4     Máy Hút Bụi Mini Cầm Tay Deerma DX118C Công Su...   479000
# ...                                                 ...      ...
# 1276                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP   390000
# 1277  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...   450000
# 1278  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1599000
# 1279  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    59000
# 1280  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   600000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=tiAlcjgSB...     -54%  3700.0
# 1     https://tka.tiki.vn/pixel/pixel?data=2Z3lzjjVn...     -75%    41.0
# 2     https://tka.tiki.vn/pixel/pixel?data=KchBb33So...     -55%   948.0
# 3     https://tiki.vn/may-hut-bui-cam-tay-khong-day-...     -39%  5000.0
# 4     https://tiki.vn/may-hut-bui-mini-cam-tay-deerm...     -51%  1200.0
# ...                                                 ...      ...     ...
# 1276  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    26.0
# 1277  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    14.0
# 1278  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    39.0
# 1279  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1280  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   395.0
#
#             category       revenue
# 0     thietbigiadinh  5.546300e+09
# 1     thietbigiadinh  1.311590e+08
# 2     thietbigiadinh  3.203292e+09
# 3     thietbigiadinh  2.195000e+09
# 4     thietbigiadinh  5.748000e+08
# ...              ...           ...
# 1276  thietbigiadinh  1.014000e+07
# 1277  thietbigiadinh  6.300000e+06
# 1278  thietbigiadinh  6.236100e+07
# 1279  thietbigiadinh  1.475000e+06
# 1280  thietbigiadinh  2.370000e+08
#
# [1281 rows x 7 columns]

# %%
df_all.to_csv("tk_thietbigiadinh_all_ed.csv")
