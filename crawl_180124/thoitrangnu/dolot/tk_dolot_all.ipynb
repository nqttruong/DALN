# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12hdem) - Copy (5)\thoitrangnu\dolot"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dolotnu_t1.csv',
#  'tk_dolotnu_t10.csv',
#  'tk_dolotnu_t11.csv',
#  'tk_dolotnu_t12.csv',
#  'tk_dolotnu_t13.csv',
#  'tk_dolotnu_t14.csv',
#  'tk_dolotnu_t15.csv',
#  'tk_dolotnu_t16.csv',
#  'tk_dolotnu_t17.csv',
#  'tk_dolotnu_t18.csv',
#  'tk_dolotnu_t19.csv',
#  'tk_dolotnu_t2.csv',
#  'tk_dolotnu_t20.csv',
#  'tk_dolotnu_t21.csv',
#  'tk_dolotnu_t22.csv',
#  'tk_dolotnu_t23.csv',
#  'tk_dolotnu_t24.csv',
#  'tk_dolotnu_t25.csv',
#  'tk_dolotnu_t26.csv',
#  'tk_dolotnu_t27.csv',
#  'tk_dolotnu_t28.csv',
#  'tk_dolotnu_t29.csv',
#  'tk_dolotnu_t3.csv',
#  'tk_dolotnu_t30.csv',
#  'tk_dolotnu_t31.csv',
#  'tk_dolotnu_t32.csv',
#  'tk_dolotnu_t33.csv',
#  'tk_dolotnu_t34.csv',
#  'tk_dolotnu_t35.csv',
#  'tk_dolotnu_t36.csv',
#  'tk_dolotnu_t37.csv',
#  'tk_dolotnu_t38.csv',
#  'tk_dolotnu_t39.csv',
#  'tk_dolotnu_t4.csv',
#  'tk_dolotnu_t40.csv',
#  'tk_dolotnu_t41.csv',
#  'tk_dolotnu_t42.csv',
#  'tk_dolotnu_t43.csv',
#  'tk_dolotnu_t44.csv',
#  'tk_dolotnu_t45.csv',
#  'tk_dolotnu_t46.csv',
#  'tk_dolotnu_t47.csv',
#  'tk_dolotnu_t48.csv',
#  'tk_dolotnu_t49.csv',
#  'tk_dolotnu_t5.csv',
#  'tk_dolotnu_t50.csv',
#  'tk_dolotnu_t6.csv',
#  'tk_dolotnu_t7.csv',
#  'tk_dolotnu_t8.csv',
#  'tk_dolotnu_t9.csv',
#  'tk_dolot_all.ipynb',
#  'tk_ttn_dl_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dolot_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Áo Lót Nữ Không Gọng Nâng ngực nhẹ LOIRECHIC B...  139.000₫
# 1   Áo ngực có gọng mút vừa ren cup demi cài trước...  349.000₫
# 2      Áo ngực có gọng mút mỏng trơn iBasic BRAW020-2  199.000₫
# 3   Áo ngực mút mỏng lazer cut không đường may cup...  199.000₫
# 4          Áo ngực có gọng mút dày ren iBasic BRAW073  189.000₫
# ..                                                ...       ...
# 35  Combo 5 - 10 Quần lót nữ viền ren co giãn 4 ch...   45.000₫
# 36  Áo Lót Nữ, Áo Lót Đúc Su Đệm Dày Siêu Nâng Ngự...   97.000₫
# 37     Quần lót lọt khe ren 2 dây chéo mông cách điệu   29.000₫
# 38              Quần lót nữ nâng mông thoáng mát Sexy   37.000₫
# 39  Combo 10 Quần lót nữ cotton trơn cao cấp Vicci...  250.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=Z0uqEtcL2...      1     -26%
# 1   https://tka.tiki.vn/pixel/pixel?data=SxwS81Xcv...      2     -30%
# 2   https://tka.tiki.vn/pixel/pixel?data=fCOwB03Sk...      3     -60%
# 3   https://tka.tiki.vn/pixel/pixel?data=Xt91jOitQ...      4     -50%
# 4   https://tka.tiki.vn/pixel/pixel?data=04iur6Wtc...      5     -37%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/combo-5-10-quan-lot-nu-vien-re...     36      NaN
# 36  https://tiki.vn/ao-lot-nu-ao-lot-duc-su-dem-da...     37      NaN
# 37  https://tiki.vn/quan-lot-lot-khe-ren-2-day-che...     38      NaN
# 38  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...     39      NaN
# 39  https://tiki.vn/combo-10-quan-lot-nu-cotton-tr...     40      NaN
#
#           sales category
# 0   Đã bán 1.2k  dolotnu
# 1     Đã bán 11  dolotnu
# 2     Đã bán 15  dolotnu
# 3     Đã bán 37  dolotnu
# 4    Đã bán 101  dolotnu
# ..          ...      ...
# 35     Đã bán 2  dolotnu
# 36    Đã bán 43  dolotnu
# 37     Đã bán 4  dolotnu
# 38     Đã bán 5  dolotnu
# 39     Đã bán 2  dolotnu
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Áo Lót Nữ Không Gọng Nâng ngực nhẹ LOIRECHIC B...  139.000₫
# 1     Áo ngực có gọng mút vừa ren cup demi cài trước...  349.000₫
# 2        Áo ngực có gọng mút mỏng trơn iBasic BRAW020-2  199.000₫
# 3     Áo ngực mút mỏng lazer cut không đường may cup...  199.000₫
# 4            Áo ngực có gọng mút dày ren iBasic BRAW073  189.000₫
# ...                                                 ...       ...
# 1727  Combo 5 - 10 Quần lót nữ viền ren co giãn 4 ch...   45.000₫
# 1728  Áo Lót Nữ, Áo Lót Đúc Su Đệm Dày Siêu Nâng Ngự...   97.000₫
# 1729     Quần lót lọt khe ren 2 dây chéo mông cách điệu   29.000₫
# 1730              Quần lót nữ nâng mông thoáng mát Sexy   37.000₫
# 1731  Combo 10 Quần lót nữ cotton trơn cao cấp Vicci...  250.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=Z0uqEtcL2...     -26%  Đã bán 1.2k
# 1     https://tka.tiki.vn/pixel/pixel?data=SxwS81Xcv...     -30%    Đã bán 11
# 2     https://tka.tiki.vn/pixel/pixel?data=fCOwB03Sk...     -60%    Đã bán 15
# 3     https://tka.tiki.vn/pixel/pixel?data=Xt91jOitQ...     -50%    Đã bán 37
# 4     https://tka.tiki.vn/pixel/pixel?data=04iur6Wtc...     -37%   Đã bán 101
# ...                                                 ...      ...          ...
# 1727  https://tiki.vn/combo-5-10-quan-lot-nu-vien-re...      NaN     Đã bán 2
# 1728  https://tiki.vn/ao-lot-nu-ao-lot-duc-su-dem-da...      NaN    Đã bán 43
# 1729  https://tiki.vn/quan-lot-lot-khe-ren-2-day-che...      NaN     Đã bán 4
# 1730  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...      NaN     Đã bán 5
# 1731  https://tiki.vn/combo-10-quan-lot-nu-cotton-tr...      NaN     Đã bán 2
#
#      category
# 0     dolotnu
# 1     dolotnu
# 2     dolotnu
# 3     dolotnu
# 4     dolotnu
# ...       ...
# 1727  dolotnu
# 1728  dolotnu
# 1729  dolotnu
# 1730  dolotnu
# 1731  dolotnu
#
# [1732 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       139000
# 1       349000
# 2       199000
# 3       199000
# 4       189000
#          ...
# 1727     45000
# 1728     97000
# 1729     29000
# 1730     37000
# 1731    250000
# Name: price, Length: 1732, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       1200.0
# 1         11.0
# 2         15.0
# 3         37.0
# 4        101.0
#          ...
# 1727       2.0
# 1728      43.0
# 1729       4.0
# 1730       5.0
# 1731       2.0
# Name: sales, Length: 1732, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       166800000.0
# 1         3839000.0
# 2         2985000.0
# 3         7363000.0
# 4        19089000.0
#            ...
# 1727        90000.0
# 1728      4171000.0
# 1729       116000.0
# 1730       185000.0
# 1731       500000.0
# Name: revenue, Length: 1732, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dolot: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dolot:  14011967384.0
# So mat hang da ban:  1732
# So san pham da ban:  112724.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Áo Lót Nữ Không Gọng Nâng ngực nhẹ LOIRECHIC B...  139000
# 1     Áo ngực có gọng mút vừa ren cup demi cài trước...  349000
# 2        Áo ngực có gọng mút mỏng trơn iBasic BRAW020-2  199000
# 3     Áo ngực mút mỏng lazer cut không đường may cup...  199000
# 4            Áo ngực có gọng mút dày ren iBasic BRAW073  189000
# ...                                                 ...     ...
# 1727  Combo 5 - 10 Quần lót nữ viền ren co giãn 4 ch...   45000
# 1728  Áo Lót Nữ, Áo Lót Đúc Su Đệm Dày Siêu Nâng Ngự...   97000
# 1729     Quần lót lọt khe ren 2 dây chéo mông cách điệu   29000
# 1730              Quần lót nữ nâng mông thoáng mát Sexy   37000
# 1731  Combo 10 Quần lót nữ cotton trơn cao cấp Vicci...  250000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=Z0uqEtcL2...     -26%  1200.0
# 1     https://tka.tiki.vn/pixel/pixel?data=SxwS81Xcv...     -30%    11.0
# 2     https://tka.tiki.vn/pixel/pixel?data=fCOwB03Sk...     -60%    15.0
# 3     https://tka.tiki.vn/pixel/pixel?data=Xt91jOitQ...     -50%    37.0
# 4     https://tka.tiki.vn/pixel/pixel?data=04iur6Wtc...     -37%   101.0
# ...                                                 ...      ...     ...
# 1727  https://tiki.vn/combo-5-10-quan-lot-nu-vien-re...      NaN     2.0
# 1728  https://tiki.vn/ao-lot-nu-ao-lot-duc-su-dem-da...      NaN    43.0
# 1729  https://tiki.vn/quan-lot-lot-khe-ren-2-day-che...      NaN     4.0
# 1730  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...      NaN     5.0
# 1731  https://tiki.vn/combo-10-quan-lot-nu-cotton-tr...      NaN     2.0
#
#      category      revenue
# 0     dolotnu  166800000.0
# 1     dolotnu    3839000.0
# 2     dolotnu    2985000.0
# 3     dolotnu    7363000.0
# 4     dolotnu   19089000.0
# ...       ...          ...
# 1727  dolotnu      90000.0
# 1728  dolotnu    4171000.0
# 1729  dolotnu     116000.0
# 1730  dolotnu     185000.0
# 1731  dolotnu     500000.0
#
# [1732 rows x 7 columns]

# %%
df_all.to_csv("tk_dolot_all_ed.csv")
