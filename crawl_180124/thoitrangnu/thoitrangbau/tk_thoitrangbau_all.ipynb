# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12hdem) - Copy (5)\thoitrangnu\thoitrangbau"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_thoitrangbau_all.ipynb',
#  'tk_ttn_ttb.ipynb',
#  'tk_ttn_ttb_npage.ipynb',
#  'tk_ttn_ttb_t1.csv',
#  'tk_ttn_ttb_t10.csv',
#  'tk_ttn_ttb_t11.csv',
#  'tk_ttn_ttb_t12.csv',
#  'tk_ttn_ttb_t13.csv',
#  'tk_ttn_ttb_t14.csv',
#  'tk_ttn_ttb_t15.csv',
#  'tk_ttn_ttb_t16.csv',
#  'tk_ttn_ttb_t17.csv',
#  'tk_ttn_ttb_t18.csv',
#  'tk_ttn_ttb_t19.csv',
#  'tk_ttn_ttb_t2.csv',
#  'tk_ttn_ttb_t20.csv',
#  'tk_ttn_ttb_t21.csv',
#  'tk_ttn_ttb_t22.csv',
#  'tk_ttn_ttb_t23.csv',
#  'tk_ttn_ttb_t24.csv',
#  'tk_ttn_ttb_t25.csv',
#  'tk_ttn_ttb_t26.csv',
#  'tk_ttn_ttb_t27.csv',
#  'tk_ttn_ttb_t28.csv',
#  'tk_ttn_ttb_t29.csv',
#  'tk_ttn_ttb_t3.csv',
#  'tk_ttn_ttb_t30.csv',
#  'tk_ttn_ttb_t31.csv',
#  'tk_ttn_ttb_t32.csv',
#  'tk_ttn_ttb_t33.csv',
#  'tk_ttn_ttb_t34.csv',
#  'tk_ttn_ttb_t4.csv',
#  'tk_ttn_ttb_t5.csv',
#  'tk_ttn_ttb_t6.csv',
#  'tk_ttn_ttb_t7.csv',
#  'tk_ttn_ttb_t8.csv',
#  'tk_ttn_ttb_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_thoitrangbau_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Ngũ cốc bầu siêu dinh dưỡng Lạc Lạc giảm ốm ng...  257.140₫
# 1   COMBO 2 HỘP Ngũ Cốc Bầu Lạc Lạc Plus 30 gói 60...  507.400₫
# 2   Ngũ cốc lợi sữa Lạc Lạc Plus mới cao cấp 39 lo...  515.000₫
# 3   Áo lót bầu- áo lót cho con bú chống chảy xệ mặ...   66.000₫
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36                                       Váy yếm kaki  159.000₫
# 37            Bộ cotton bầu thêu chữ còn 1 bộ màu cam  120.000₫
# 38           quần sooc đùi bầu jean mềm mại thoải mái  120.000₫
# 39                 Váy bầu cổ sen phối nơ( ảnh thật )   250.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=adEk1TCei...      1     -14%
# 1   https://tka.tiki.vn/pixel/pixel?data=ucrNYsEj_...      2     -14%
# 2   https://tka.tiki.vn/pixel/pixel?data=1lAB0CUVM...      3     -14%
# 3   https://tiki.vn/ao-lot-bau-ao-lot-cho-con-bu-c...      4     -14%
# 4   https://tiki.vn/quan-bau-co-dap-bung-quan-legg...      5      -2%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/quan-legging-bau-ni-thu-dong-m...     36      NaN
# 36  https://tiki.vn/vay-yem-kaki-p92319747.html?sp...     37      NaN
# 37  https://tiki.vn/bo-cotton-bau-theu-chu-p923199...     38      NaN
# 38  https://tiki.vn/quan-sooc-dui-bau-jean-mem-mai...     39      NaN
# 39  https://tiki.vn/vay-bau-co-sen-phoi-no-anh-tha...     40      NaN
#
#         sales      category
# 0   Đã bán 30  thoitrangbau
# 1    Đã bán 5  thoitrangbau
# 2    Đã bán 1  thoitrangbau
# 3         NaN  thoitrangbau
# 4         NaN  thoitrangbau
# ..        ...           ...
# 35        NaN  thoitrangbau
# 36        NaN  thoitrangbau
# 37        NaN  thoitrangbau
# 38        NaN  thoitrangbau
# 39        NaN  thoitrangbau
#
# [1360 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Ngũ cốc bầu siêu dinh dưỡng Lạc Lạc giảm ốm ng...  257.140₫
# 1    COMBO 2 HỘP Ngũ Cốc Bầu Lạc Lạc Plus 30 gói 60...  507.400₫
# 2    Ngũ cốc lợi sữa Lạc Lạc Plus mới cao cấp 39 lo...  515.000₫
# 3    Quần bầu dài legging cạp chéo co giãn thoải má...   75.000₫
# 4    Quần mặc váy bầu quần đùi mặc trong váy bầu cạ...   45.000₫
# ..                                                 ...       ...
# 129                           ẢNH THẬT ️Đầm cho con bú  247.000₫
# 130  Chân Váy Bầu Xếp Ly Azuno AZ44 Có Đáp Bụng Và ...   185.000
# 131    Áo bầu công sở mùa hè 2023, áo bà bầu, mleeshop  109.000₫
# 132  Áo bầu xinh hàn quốc, áo babydoll bầu đẹp, MLE...  105.000₫
# 133  Quần bầu Ngố Legging bầu cotton co giãn 4 chiề...  155.000₫
#
#                                              link_item discount      sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=adEk1TCei...     -14%  Đã bán 30
# 1    https://tka.tiki.vn/pixel/pixel?data=ucrNYsEj_...     -14%   Đã bán 5
# 2    https://tka.tiki.vn/pixel/pixel?data=1lAB0CUVM...     -14%   Đã bán 1
# 3    https://tiki.vn/quan-bau-dai-legging-cap-cheo-...      NaN  Đã bán 13
# 4    https://tiki.vn/quan-mac-vay-bau-quan-dui-mac-...      NaN   Đã bán 3
# ..                                                 ...      ...        ...
# 129  https://tiki.vn/anh-that-dam-cho-con-bu-p95173...      NaN   Đã bán 2
# 130  https://tiki.vn/chan-vay-bau-xep-ly-azuno-az44...      NaN   Đã bán 1
# 131  https://tiki.vn/ao-bau-cong-so-mua-he-2023-ao-...      NaN   Đã bán 1
# 132  https://tiki.vn/ao-bau-xinh-han-quoc-ao-babydo...      NaN   Đã bán 1
# 133  https://tiki.vn/quan-bau-ngo-legging-bau-cotto...      NaN   Đã bán 1
#
#          category
# 0    thoitrangbau
# 1    thoitrangbau
# 2    thoitrangbau
# 3    thoitrangbau
# 4    thoitrangbau
# ..            ...
# 129  thoitrangbau
# 130  thoitrangbau
# 131  thoitrangbau
# 132  thoitrangbau
# 133  thoitrangbau
#
# [134 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      257140
# 1      507400
# 2      515000
# 3       75000
# 4       45000
#         ...
# 129    247000
# 130    185000
# 131    109000
# 132    105000
# 133    155000
# Name: price, Length: 134, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      30.0
# 1       5.0
# 2       1.0
# 3      13.0
# 4       3.0
#        ...
# 129     2.0
# 130     1.0
# 131     1.0
# 132     1.0
# 133     1.0
# Name: sales, Length: 134, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      7714200.0
# 1      2537000.0
# 2       515000.0
# 3       975000.0
# 4       135000.0
#          ...
# 129     494000.0
# 130     185000.0
# 131     109000.0
# 132     105000.0
# 133     155000.0
# Name: revenue, Length: 134, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số thoitrangbau: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số thoitrangbau:  85738906.0
# So mat hang da ban:  134
# So san pham da ban:  591.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Ngũ cốc bầu siêu dinh dưỡng Lạc Lạc giảm ốm ng...  257140
# 1    COMBO 2 HỘP Ngũ Cốc Bầu Lạc Lạc Plus 30 gói 60...  507400
# 2    Ngũ cốc lợi sữa Lạc Lạc Plus mới cao cấp 39 lo...  515000
# 3    Quần bầu dài legging cạp chéo co giãn thoải má...   75000
# 4    Quần mặc váy bầu quần đùi mặc trong váy bầu cạ...   45000
# ..                                                 ...     ...
# 129                           ẢNH THẬT ️Đầm cho con bú  247000
# 130  Chân Váy Bầu Xếp Ly Azuno AZ44 Có Đáp Bụng Và ...  185000
# 131    Áo bầu công sở mùa hè 2023, áo bà bầu, mleeshop  109000
# 132  Áo bầu xinh hàn quốc, áo babydoll bầu đẹp, MLE...  105000
# 133  Quần bầu Ngố Legging bầu cotton co giãn 4 chiề...  155000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=adEk1TCei...     -14%   30.0
# 1    https://tka.tiki.vn/pixel/pixel?data=ucrNYsEj_...     -14%    5.0
# 2    https://tka.tiki.vn/pixel/pixel?data=1lAB0CUVM...     -14%    1.0
# 3    https://tiki.vn/quan-bau-dai-legging-cap-cheo-...      NaN   13.0
# 4    https://tiki.vn/quan-mac-vay-bau-quan-dui-mac-...      NaN    3.0
# ..                                                 ...      ...    ...
# 129  https://tiki.vn/anh-that-dam-cho-con-bu-p95173...      NaN    2.0
# 130  https://tiki.vn/chan-vay-bau-xep-ly-azuno-az44...      NaN    1.0
# 131  https://tiki.vn/ao-bau-cong-so-mua-he-2023-ao-...      NaN    1.0
# 132  https://tiki.vn/ao-bau-xinh-han-quoc-ao-babydo...      NaN    1.0
# 133  https://tiki.vn/quan-bau-ngo-legging-bau-cotto...      NaN    1.0
#
#          category    revenue
# 0    thoitrangbau  7714200.0
# 1    thoitrangbau  2537000.0
# 2    thoitrangbau   515000.0
# 3    thoitrangbau   975000.0
# 4    thoitrangbau   135000.0
# ..            ...        ...
# 129  thoitrangbau   494000.0
# 130  thoitrangbau   185000.0
# 131  thoitrangbau   109000.0
# 132  thoitrangbau   105000.0
# 133  thoitrangbau   155000.0
#
# [134 rows x 7 columns]

# %%
df_all.to_csv("tk_thoitrangbau_all_ed.csv")
