# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12hdem) - Copy (5)\thoitrangnu\damnu"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_damnu_all.ipynb',
#  'tk_ttn_dn.ipynb',
#  'tk_ttn_dn_npage.ipynb',
#  'tk_ttn_dn_t1.csv',
#  'tk_ttn_dn_t10.csv',
#  'tk_ttn_dn_t11.csv',
#  'tk_ttn_dn_t12.csv',
#  'tk_ttn_dn_t13.csv',
#  'tk_ttn_dn_t14.csv',
#  'tk_ttn_dn_t15.csv',
#  'tk_ttn_dn_t16.csv',
#  'tk_ttn_dn_t17.csv',
#  'tk_ttn_dn_t18.csv',
#  'tk_ttn_dn_t19.csv',
#  'tk_ttn_dn_t2.csv',
#  'tk_ttn_dn_t20.csv',
#  'tk_ttn_dn_t21.csv',
#  'tk_ttn_dn_t22.csv',
#  'tk_ttn_dn_t23.csv',
#  'tk_ttn_dn_t24.csv',
#  'tk_ttn_dn_t25.csv',
#  'tk_ttn_dn_t26.csv',
#  'tk_ttn_dn_t27.csv',
#  'tk_ttn_dn_t28.csv',
#  'tk_ttn_dn_t29.csv',
#  'tk_ttn_dn_t3.csv',
#  'tk_ttn_dn_t30.csv',
#  'tk_ttn_dn_t31.csv',
#  'tk_ttn_dn_t32.csv',
#  'tk_ttn_dn_t33.csv',
#  'tk_ttn_dn_t34.csv',
#  'tk_ttn_dn_t35.csv',
#  'tk_ttn_dn_t36.csv',
#  'tk_ttn_dn_t37.csv',
#  'tk_ttn_dn_t38.csv',
#  'tk_ttn_dn_t39.csv',
#  'tk_ttn_dn_t4.csv',
#  'tk_ttn_dn_t40.csv',
#  'tk_ttn_dn_t41.csv',
#  'tk_ttn_dn_t42.csv',
#  'tk_ttn_dn_t43.csv',
#  'tk_ttn_dn_t44.csv',
#  'tk_ttn_dn_t45.csv',
#  'tk_ttn_dn_t46.csv',
#  'tk_ttn_dn_t47.csv',
#  'tk_ttn_dn_t48.csv',
#  'tk_ttn_dn_t49.csv',
#  'tk_ttn_dn_t5.csv',
#  'tk_ttn_dn_t50.csv',
#  'tk_ttn_dn_t6.csv',
#  'tk_ttn_dn_t7.csv',
#  'tk_ttn_dn_t8.csv',
#  'tk_ttn_dn_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_damnu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0             LEMME-Đầm sơ mi tay ngắn fom rộng xẻ tà  265.000₫
# 1             Đầm gấm kết hoa xinh sang trọng MS 2597  440.000₫
# 2   MIMI BigSize [45KG-100KG] Đầm Bigsize Cổ Vuông...  199.000₫
# 3   váy len suông dài tay cổ lọ, đầm dáng dài thu ...   105.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Váy, Đầm 2 Lớp Cho Người Trung Niên, Người Lớn...  490.000₫
# 37                Đầm dập li cổ vét sang trọng-MS0025   99.000₫
# 38  Đầm Suông Dự Tiệc Oversize Kiểu Đầm Phối Tay V...  249.000₫
# 39  Viên Uống Phòng Chống, Ngăn Ngừa Đột Quỵ, Tai ...   680.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=WQIwttEDp...      1     -66%
# 1   https://tka.tiki.vn/pixel/pixel?data=JlRPA0O03...      2     -35%
# 2   https://tiki.vn/mimi-bigsize-45kg-100kg-dam-bi
rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      265000
# 1      199000
# 2      300000
# 3      245000
# 4      219000
#         ...
# 793    139000
# 794    170000
# 795    490000
# 796     99000
# 797    249000
# Name: price, Length: 798, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        1.0
# 1        2.0
# 2       39.0
# 3        9.0
# 4        7.0
#        ...
# 793      8.0
# 794      1.0
# 795     84.0
# 796    298.0
# 797      7.0
# Name: sales, Length: 798, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        265000.0
# 1        398000.0
# 2      11700000.0
# 3       2205000.0
# 4       1533000.0
#           ...
# 793     1112000.0
# 794      170000.0
# 795    41160000.0
# 796    29502000.0
# 797     1743000.0
# Name: revenue, Length: 798, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số damnu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số damnu:  3049709850.0
# So mat hang da ban:  798
# So san pham da ban:  14025.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0              LEMME-Đầm sơ mi tay ngắn fom rộng xẻ tà  265000
# 1    MIMI BigSize [45KG-100KG] Đầm Bigsize Cổ Vuông...  199000
# 2      Đầm Cổ V Nút Ngọc Tay Dài màu Kem Thơ Nhẹ Nhàng  300000
# 3                 F367 Đầm ôm cổ tròn form dài qua gối  245000
# 4                      Đầm công sở đắp chéo sang trọng  219000
# ..                                                 ...     ...
# 793  Đầm vintage cổ vest thanh lịch quý phái dài si...  139000
# 794                                      VÁY ĐŨI 2 DÂY  170000
# 795  Váy, Đầm 2 Lớp Cho Người Trung Niên, Người Lớn...  490000
# 796                Đầm dập li cổ vét sang trọng-MS0025   99000
# 797  Đầm Suông Dự Tiệc Oversize Kiểu Đầm Phối Tay V...  249000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=WQIwttEDp...     -66%    1.0
# 1    https://tiki.vn/mimi-bigsize-45kg-100kg-dam-bi...     -12%    2.0
# 2    https://tiki.vn/dam-co-v-nut-ngoc-tay-dai-mau-...     -50%   39.0
# 3    https://tiki.vn/f367-dam-om-co-tron-form-dai-q...      NaN    9.0
# 4    https://tiki.vn/dam-cong-so-p247380733.html?sp...      NaN    7.0
# ..                                                 ...      ...    ...
# 793  https://tiki.vn/dam-vintage-co-vest-thanh-lich...      NaN    8.0
# 794  https://tiki.vn/vay-dui-2-day-p169119219.html?...      NaN    1.0
# 795  https://tiki.vn/vay-dam-2-lop-cho-nguoi-trung-...      NaN   84.0
# 796  https://tiki.vn/dam-dap-li-co-vet-sang-trong-m...      NaN  298.0
# 797  https://tiki.vn/dam-suong-du-tiec-oversize-kie...      NaN    7.0
#
#     category     revenue
# 0      damnu    265000.0
# 1      damnu    398000.0
# 2      damnu  11700000.0
# 3      damnu   2205000.0
# 4      damnu   1533000.0
# ..       ...         ...
# 793    damnu   1112000.0
# 794    damnu    170000.0
# 795    damnu  41160000.0
# 796    damnu  29502000.0
# 797    damnu   1743000.0
#
# [798 rows x 7 columns]

# %%
df_all.to_csv("tk_damnu_all_ed.csv")
