# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12hdem) - Copy (5)\thoitrangnu\chanvay"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_chanvay_all.ipynb',
#  'tk_ttn_cv.ipynb',
#  'tk_ttn_cv_npage.ipynb',
#  'tk_ttn_cv_t1.csv',
#  'tk_ttn_cv_t10.csv',
#  'tk_ttn_cv_t11.csv',
#  'tk_ttn_cv_t12.csv',
#  'tk_ttn_cv_t13.csv',
#  'tk_ttn_cv_t14.csv',
#  'tk_ttn_cv_t15.csv',
#  'tk_ttn_cv_t16.csv',
#  'tk_ttn_cv_t17.csv',
#  'tk_ttn_cv_t18.csv',
#  'tk_ttn_cv_t19.csv',
#  'tk_ttn_cv_t2.csv',
#  'tk_ttn_cv_t20.csv',
#  'tk_ttn_cv_t21.csv',
#  'tk_ttn_cv_t22.csv',
#  'tk_ttn_cv_t23.csv',
#  'tk_ttn_cv_t24.csv',
#  'tk_ttn_cv_t25.csv',
#  'tk_ttn_cv_t26.csv',
#  'tk_ttn_cv_t27.csv',
#  'tk_ttn_cv_t28.csv',
#  'tk_ttn_cv_t29.csv',
#  'tk_ttn_cv_t3.csv',
#  'tk_ttn_cv_t30.csv',
#  'tk_ttn_cv_t31.csv',
#  'tk_ttn_cv_t32.csv',
#  'tk_ttn_cv_t33.csv',
#  'tk_ttn_cv_t34.csv',
#  'tk_ttn_cv_t35.csv',
#  'tk_ttn_cv_t36.csv',
#  'tk_ttn_cv_t37.csv',
#  'tk_ttn_cv_t38.csv',
#  'tk_ttn_cv_t39.csv',
#  'tk_ttn_cv_t4.csv',
#  'tk_ttn_cv_t40.csv',
#  'tk_ttn_cv_t41.csv',
#  'tk_ttn_cv_t42.csv',
#  'tk_ttn_cv_t43.csv',
#  'tk_ttn_cv_t44.csv',
#  'tk_ttn_cv_t45.csv',
#  'tk_ttn_cv_t46.csv',
#  'tk_ttn_cv_t47.csv',
#  'tk_ttn_cv_t48.csv',
#  'tk_ttn_cv_t49.csv',
#  'tk_ttn_cv_t5.csv',
#  'tk_ttn_cv_t50.csv',
#  'tk_ttn_cv_t6.csv',
#  'tk_ttn_cv_t7.csv',
#  'tk_ttn_cv_t8.csv',
#  'tk_ttn_cv_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_chanvay_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Chân váy nữ denim màu đen mới rộng rãi và thon...     39.000₫
# 1   Chân Váy Xòe New Design Dáng Midi Dài Qua Gối ...    329.000₫
# 2   Chân Váy Công Sở New Design Thiết Kế Dáng Váy ...    333.000₫
# 3   Chân váy bút chì - Váy công sở cao cấp có túi ...     299.000
# 4                                                 NaN         NaN
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36  Chân váy thời trang nữ Fila Tennis - FW2SKF106...  1.077.000₫
# 37                OLV - Chân váy Jennifer Cream Skirt    450.000₫
# 38                         Chân váy midi dài phối cúc    195.000₫
# 39     Chân váy ôm xếp pilly – MS0305CV ( có lớp lót)     99.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=MFOWp67LW...      1      NaN
# 1   https://tka.tiki.vn/pixel/pixel?data=W91Z6-Um1...      2     -37%
# 2   https://tka.tiki.vn/pixel/pixel?data=m8qyC1grL...      3     -37%
# 3   https://tka.tiki.vn/pixel/pixel?data=kA2rTkLLI...      4      NaN
# 4   https://tka.tiki.vn/pixel/pixel?data=SQiMJmtpr...      5     -47%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/chan-vay-but-chi-dang-dai-hain...     36      NaN
# 36  https://tiki.vn/chan-vay-thoi-trang-nu-fila-te...     37      NaN
# 37  https://tiki.vn/olv-chan-vay-jennifer-cream-sk...     38      NaN
# 38  https://tiki.vn/chan-vay-midi-dai-phoi-cuc-p86...     39      NaN
# 39  https://tiki.vn/chan-vay-om-xep-pilly-ms0305cv...     40      NaN
#
#         sales category
# 0         NaN  chanvay
# 1   Đã bán 21  chanvay
# 2   Đã bán 80  chanvay
# 3         NaN  chanvay
# 4         NaN  chanvay
# ..        ...      ...
# 35        NaN  chanvay
# 36        NaN  chanvay
# 37        NaN  chanvay
# 38        NaN  chanvay
# 39        NaN  chanvay
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Chân Váy Xòe New Design Dáng Midi Dài Qua Gối ...  329.000₫
# 1    Chân Váy Công Sở New Design Thiết Kế Dáng Váy ...  333.000₫
# 2    Chân Váy Kiểu Cạp Bổ 7 Mảnh Dáng Xòe Chất Tuyt...  290.000₫
# 3             Chân Váy tennis Lưng Cao xếp ly nữ - Đen   49.000₫
# 4        Chân váy lụa dài dáng đuôi cá cạp trễ cao cấp  239.000₫
# ..                                                 ...       ...
# 457        Chân váy cổ tích lưới 3 lớp dễ thương VAY89  120.000₫
# 458  Chân váy bút chì dài qua gối sang trọng - thíc...  146.000₫
# 459                     Chân váy voan xếp ly dễ thương  148.000₫
# 460           Chân váy xòe dài buộc nơ Elly sang trọng  139.000₫
# 461                          CHÂN VÁY XÒE LADY FASHION   75.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=W91Z6-Um1...     -37%   Đã bán 21
# 1    https://tka.tiki.vn/pixel/pixel?data=m8qyC1grL...     -37%   Đã bán 80
# 2    https://tiki.vn/chan-vay-kieu-cap-bo-7-manh-da...     -40%  Đã bán 134
# 3    https://tiki.vn/chan-vay-tennis-lung-cao-xep-l...     -40%   Đã bán 19
# 4    https://tiki.vn/chan-vay-lua-dai-dang-duoi-ca-...     -49%    Đã bán 1
# ..                                                 ...      ...         ...
# 457  https://tiki.vn/chan-vay-co-tich-luoi-3-lop-de...      NaN    Đã bán 1
# 458  https://tiki.vn/chan-vay-but-chi-dai-qua-goi-s...      NaN   Đã bán 95
# 459  https://tiki.vn/chan-vay-voan-xep-ly-de-thuong...      NaN    Đã bán 5
# 460  https://tiki.vn/chan-vay-xoe-dai-buoc-no-elly-...      NaN   Đã bán 22
# 461  https://tiki.vn/chan-vay-xoe-lady-fashion-p213...      NaN    Đã bán 4
#
#     category
# 0    chanvay
# 1    chanvay
# 2    chanvay
# 3    chanvay
# 4    chanvay
# ..       ...
# 457  chanvay
# 458  chanvay
# 459  chanvay
# 460  chanvay
# 461  chanvay
#
# [462 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      329000
# 1      333000
# 2      290000
# 3       49000
# 4      239000
#         ...
# 457    120000
# 458    146000
# 459    148000
# 460    139000
# 461     75000
# Name: price, Length: 462, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       21.0
# 1       80.0
# 2      134.0
# 3       19.0
# 4        1.0
#        ...
# 457      1.0
# 458     95.0
# 459      5.0
# 460     22.0
# 461      4.0
# Name: sales, Length: 462, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       6909000.0
# 1      26640000.0
# 2      38860000.0
# 3        931000.0
# 4        239000.0
#           ...
# 457      120000.0
# 458    13870000.0
# 459      740000.0
# 460     3058000.0
# 461      300000.0
# Name: revenue, Length: 462, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chanvay: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số chanvay:  1182450863.0
# So mat hang da ban:  462
# So san pham da ban:  7155.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Chân Váy Xòe New Design Dáng Midi Dài Qua Gối ...  329000
# 1    Chân Váy Công Sở New Design Thiết Kế Dáng Váy ...  333000
# 2    Chân Váy Kiểu Cạp Bổ 7 Mảnh Dáng Xòe Chất Tuyt...  290000
# 3             Chân Váy tennis Lưng Cao xếp ly nữ - Đen   49000
# 4        Chân váy lụa dài dáng đuôi cá cạp trễ cao cấp  239000
# ..                                                 ...     ...
# 457        Chân váy cổ tích lưới 3 lớp dễ thương VAY89  120000
# 458  Chân váy bút chì dài qua gối sang trọng - thíc...  146000
# 459                     Chân váy voan xếp ly dễ thương  148000
# 460           Chân váy xòe dài buộc nơ Elly sang trọng  139000
# 461                          CHÂN VÁY XÒE LADY FASHION   75000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=W91Z6-Um1...     -37%   21.0
# 1    https://tka.tiki.vn/pixel/pixel?data=m8qyC1grL...     -37%   80.0
# 2    https://tiki.vn/chan-vay-kieu-cap-bo-7-manh-da...     -40%  134.0
# 3    https://tiki.vn/chan-vay-tennis-lung-cao-xep-l...     -40%   19.0
# 4    https://tiki.vn/chan-vay-lua-dai-dang-duoi-ca-...     -49%    1.0
# ..                                                 ...      ...    ...
# 457  https://tiki.vn/chan-vay-co-tich-luoi-3-lop-de...      NaN    1.0
# 458  https://tiki.vn/chan-vay-but-chi-dai-qua-goi-s...      NaN   95.0
# 459  https://tiki.vn/chan-vay-voan-xep-ly-de-thuong...      NaN    5.0
# 460  https://tiki.vn/chan-vay-xoe-dai-buoc-no-elly-...      NaN   22.0
# 461  https://tiki.vn/chan-vay-xoe-lady-fashion-p213...      NaN    4.0
#
#     category     revenue
# 0    chanvay   6909000.0
# 1    chanvay  26640000.0
# 2    chanvay  38860000.0
# 3    chanvay    931000.0
# 4    chanvay    239000.0
# ..       ...         ...
# 457  chanvay    120000.0
# 458  chanvay  13870000.0
# 459  chanvay    740000.0
# 460  chanvay   3058000.0
# 461  chanvay    300000.0
#
# [462 rows x 7 columns]

# %%
df_all.to_csv("tk_chanvay_all_ed.csv")
