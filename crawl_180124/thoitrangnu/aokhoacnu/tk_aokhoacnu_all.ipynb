# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12hdem) - Copy (5)\thoitrangnu\aokhoacnu"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_aokhoacnu_all.ipynb',
#  'tk_ttn_akn.ipynb',
#  'tk_ttn_akn_npage.ipynb',
#  'tk_ttn_akn_t1.csv',
#  'tk_ttn_akn_t10.csv',
#  'tk_ttn_akn_t11.csv',
#  'tk_ttn_akn_t12.csv',
#  'tk_ttn_akn_t13.csv',
#  'tk_ttn_akn_t14.csv',
#  'tk_ttn_akn_t15.csv',
#  'tk_ttn_akn_t16.csv',
#  'tk_ttn_akn_t17.csv',
#  'tk_ttn_akn_t18.csv',
#  'tk_ttn_akn_t19.csv',
#  'tk_ttn_akn_t2.csv',
#  'tk_ttn_akn_t20.csv',
#  'tk_ttn_akn_t21.csv',
#  'tk_ttn_akn_t22.csv',
#  'tk_ttn_akn_t23.csv',
#  'tk_ttn_akn_t24.csv',
#  'tk_ttn_akn_t25.csv',
#  'tk_ttn_akn_t26.csv',
#  'tk_ttn_akn_t27.csv',
#  'tk_ttn_akn_t28.csv',
#  'tk_ttn_akn_t29.csv',
#  'tk_ttn_akn_t3.csv',
#  'tk_ttn_akn_t30.csv',
#  'tk_ttn_akn_t31.csv',
#  'tk_ttn_akn_t32.csv',
#  'tk_ttn_akn_t33.csv',
#  'tk_ttn_akn_t34.csv',
#  'tk_ttn_akn_t35.csv',
#  'tk_ttn_akn_t36.csv',
#  'tk_ttn_akn_t37.csv',
#  'tk_ttn_akn_t38.csv',
#  'tk_ttn_akn_t39.csv',
#  'tk_ttn_akn_t4.csv',
#  'tk_ttn_akn_t40.csv',
#  'tk_ttn_akn_t41.csv',
#  'tk_ttn_akn_t42.csv',
#  'tk_ttn_akn_t43.csv',
#  'tk_ttn_akn_t44.csv',
#  'tk_ttn_akn_t45.csv',
#  'tk_ttn_akn_t46.csv',
#  'tk_ttn_akn_t47.csv',
#  'tk_ttn_akn_t48.csv',
#  'tk_ttn_akn_t49.csv',
#  'tk_ttn_akn_t5.csv',
#  'tk_ttn_akn_t50.csv',
#  'tk_ttn_akn_t6.csv',
#  'tk_ttn_akn_t7.csv',
#  'tk_ttn_akn_t8.csv',
#  'tk_ttn_akn_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_aokhoacnu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235.000₫
# 1   Áo khoác gió cách nhiệt GOKING, form unisex ch...  235.000₫
# 2   Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255.000₫
# 3   Áo Hoodie Trơn Màu Xanh Dương Cao Cấp Dáng Rộn...   120.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  (HÀNG SẴN) Áo Khoác Phao Lông Vũ Dáng Dài Phon...  745.000₫
# 37  Set áo vest blazer nữ ngắn tay 2 túi hàng thiế...  476.000₫
# 38  Áo Khoác Hoodie Chống Nắng Dành cho nam và nữ ...  103.000₫
# 39  Áo khoác nữ thoát nhiệt Nhật Bản GOKING, 100% ...   275.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=C8dOdt2av...      1      NaN
# 1   https://tka.tiki.vn/pixel/pixel?data=cfM8yvDYg...      2     -44%
# 2   https://tka.tiki.vn/pixel/pixel?data=kw9MnCEB-...      3     -12%
# 3   https://tka.tiki.vn/pixel/pixel?data=KOp8gwJSr...      4      NaN
# 4   https://tka.tiki.vn/pixel/pixel?data=7fBtMtvv7...      5      NaN
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ao-khoac-phao-nu-3-lop-chan-bo...     36      NaN
# 36  https://tiki.vn/hang-san-ao-khoac-phao-long-vu...     37      NaN
# 37  https://tiki.vn/set-ao-vest-blazer-nu-ngan-tay...     38      NaN
# 38  https://tiki.vn/ao-khoac-hoodie-chong-nang-dan...     39      NaN
# 39  https://tiki.vn/ao-khoac-nu-thoat-nhiet-nhat-b...     40      NaN
#
#          sales   category
# 0    Đã bán 80  aokhoacnu
# 1    Đã bán 89  aokhoacnu
# 2   Đã bán 102  aokhoacnu
# 3     Đã bán 1  aokhoacnu
# 4          NaN  aokhoacnu
# ..         ...        ...
# 35         NaN  aokhoacnu
# 36         NaN  aokhoacnu
# 37   Đã bán 77  aokhoacnu
# 38   Đã bán 27  aokhoacnu
# 39         NaN  aokhoacnu
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235.000₫
# 1    Áo khoác gió cách nhiệt GOKING, form unisex ch...  235.000₫
# 2    Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255.000₫
# 3    Áo Hoodie Trơn Màu Xanh Dương Cao Cấp Dáng Rộn...   120.000
# 4       Áo Khoác Nữ Cao Cấp Chống Năng Form Lững 2 Sọc  150.000₫
# ..                                                 ...       ...
# 841  Áo gile len nữ có cúc thiết kế phong cách Hàn ...  179.000₫
# 842  áo len nữ tay nỡ cổ và tay phối họa tiết quả trám  104.000₫
# 843  (HÀNG SẴN) Áo Khoác Phao Nữ Ngắn Trẻ Trung Năn...  325.000₫
# 844  Set áo vest blazer nữ ngắn tay 2 túi hàng thiế...  476.000₫
# 845  Áo Khoác Hoodie Chống Nắng Dành cho nam và nữ ...  103.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=C8dOdt2av...      NaN   Đã bán 80
# 1    https://tka.tiki.vn/pixel/pixel?data=cfM8yvDYg...     -44%   Đã bán 89
# 2    https://tka.tiki.vn/pixel/pixel?data=kw9MnCEB-...     -12%  Đã bán 102
# 3    https://tka.tiki.vn/pixel/pixel?data=KOp8gwJSr...      NaN    Đã bán 1
# 4    https://tiki.vn/ao-khoac-nu-cao-cap-chong-nang...      NaN    Đã bán 8
# ..                                                 ...      ...         ...
# 841  https://tiki.vn/ao-gile-len-nu-co-cuc-thiet-ke...      NaN   Đã bán 11
# 842  https://tiki.vn/ao-len-nu-tay-no-co-va-tay-pho...      NaN    Đã bán 6
# 843  https://tiki.vn/hang-san-ao-khoac-phao-nu-ngan...      NaN    Đã bán 8
# 844  https://tiki.vn/set-ao-vest-blazer-nu-ngan-tay...      NaN   Đã bán 77
# 845  https://tiki.vn/ao-khoac-hoodie-chong-nang-dan...      NaN   Đã bán 27
#
#       category
# 0    aokhoacnu
# 1    aokhoacnu
# 2    aokhoacnu
# 3    aokhoacnu
# 4    aokhoacnu
# ..         ...
# 841  aokhoacnu
# 842  aokhoacnu
# 843  aokhoacnu
# 844  aokhoacnu
# 845  aokhoacnu
#
# [846 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      235000
# 1      235000
# 2      255000
# 3      120000
# 4      150000
#         ...
# 841    179000
# 842    104000
# 843    325000
# 844    476000
# 845    103000
# Name: price, Length: 846, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       80.0
# 1       89.0
# 2      102.0
# 3        1.0
# 4        8.0
#        ...
# 841     11.0
# 842      6.0
# 843      8.0
# 844     77.0
# 845     27.0
# Name: sales, Length: 846, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      18800000.0
# 1      20915000.0
# 2      26010000.0
# 3        120000.0
# 4       1200000.0
#           ...
# 841     1969000.0
# 842      624000.0
# 843     2600000.0
# 844    36652000.0
# 845     2781000.0
# Name: revenue, Length: 846, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số aokhoacnu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số aokhoacnu:  3519444699.0
# So mat hang da ban:  846
# So san pham da ban:  15725.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235000
# 1    Áo khoác gió cách nhiệt GOKING, form unisex ch...  235000
# 2    Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255000
# 3    Áo Hoodie Trơn Màu Xanh Dương Cao Cấp Dáng Rộn...  120000
# 4       Áo Khoác Nữ Cao Cấp Chống Năng Form Lững 2 Sọc  150000
# ..                                                 ...     ...
# 841  Áo gile len nữ có cúc thiết kế phong cách Hàn ...  179000
# 842  áo len nữ tay nỡ cổ và tay phối họa tiết quả trám  104000
# 843  (HÀNG SẴN) Áo Khoác Phao Nữ Ngắn Trẻ Trung Năn...  325000
# 844  Set áo vest blazer nữ ngắn tay 2 túi hàng thiế...  476000
# 845  Áo Khoác Hoodie Chống Nắng Dành cho nam và nữ ...  103000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=C8dOdt2av...      NaN   80.0
# 1    https://tka.tiki.vn/pixel/pixel?data=cfM8yvDYg...     -44%   89.0
# 2    https://tka.tiki.vn/pixel/pixel?data=kw9MnCEB-...     -12%  102.0
# 3    https://tka.tiki.vn/pixel/pixel?data=KOp8gwJSr...      NaN    1.0
# 4    https://tiki.vn/ao-khoac-nu-cao-cap-chong-nang...      NaN    8.0
# ..                                                 ...      ...    ...
# 841  https://tiki.vn/ao-gile-len-nu-co-cuc-thiet-ke...      NaN   11.0
# 842  https://tiki.vn/ao-len-nu-tay-no-co-va-tay-pho...      NaN    6.0
# 843  https://tiki.vn/hang-san-ao-khoac-phao-nu-ngan...      NaN    8.0
# 844  https://tiki.vn/set-ao-vest-blazer-nu-ngan-tay...      NaN   77.0
# 845  https://tiki.vn/ao-khoac-hoodie-chong-nang-dan...      NaN   27.0
#
#       category     revenue
# 0    aokhoacnu  18800000.0
# 1    aokhoacnu  20915000.0
# 2    aokhoacnu  26010000.0
# 3    aokhoacnu    120000.0
# 4    aokhoacnu   1200000.0
# ..         ...         ...
# 841  aokhoacnu   1969000.0
# 842  aokhoacnu    624000.0
# 843  aokhoacnu   2600000.0
# 844  aokhoacnu  36652000.0
# 845  aokhoacnu   2781000.0
#
# [846 rows x 7 columns]

# %%
df_all.to_csv("tk_aokhoacnu_all_ed.csv")
