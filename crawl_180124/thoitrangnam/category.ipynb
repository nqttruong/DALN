# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12hdem) - Copy (5)\thoitrangnam"
os.listdir(path)
# Out:
# ['aohoodie',
#  'aoni',
#  'aosomi',
#  'aothunnam',
#  'aovest',
#  'brand',
#  'category.ipynb',
#  'doboi',
#  'dodoi',
#  'dolot',
#  'dongu',
#  'quanaokichcolon',
#  'quanaotrungnien',
#  'quannam',
#  'tk_aohoodie_all_ed.csv',
#  'tk_aoni_all_ed.csv',
#  'tk_aosomi_all_ed.csv',
#  'tk_aothunnam_all_ed.csv',
#  'tk_aovest_all_ed.csv',
#  'tk_doboi_all_ed.csv',
#  'tk_dodoi_all_ed.csv',
#  'tk_dolot_all_ed.csv',
#  'tk_dongu_all_ed.csv',
#  'tk_quanaokichcolon_all_ed.csv',
#  'tk_quanaotrungnien_all_ed.csv',
#  'tk_quannam_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#       Unnamed: 0                                              title   price  \
# 0              0  Áo hoodie nam nữ form rộng Unisex một màu in h...  179000
# 1              1  Áo hoodie nỉ bông unisex Homies liền mũ có túi...  100000
# 2              2  Áo hoodie nam nữ form rộng siêu xinh , Áo khoá...  110000
# 3              3  Áo khoác hoodie nam nữ vải nỉ xịn quảng châu m...  115000
# 4              4  Áo mũ Hoodie Unisex MonsterX Gấu X form rộng 5...  105000
# ...          ...                                                ...     ...
# 1022        1022  Quần ngủ Nam nữ VAZCO Q27 chất liệu vải thun c...   38000
# 1023        1023  Quần kaki dài nam (Tặng 1 dây nịt cao cấp) chấ...  255000
# 1024        1024  Quần body nam Quần short jean nam có giãn shor...  115000
# 1025        1025  Quần jean nam co giãn dáng suông đẹp màu xanh ...  240000
# 1026        1026  QUẦN JEAN NAM TRẮNG CAO CẤP - VẢI TRẮNG TINH C...  150000
#
#                                               link_item discount  sales  \
# 0     https://tiki.vn/ao-hoodie-nam-nu-form-rong-uni...     -10%  925.0
# 1     https://tiki.vn/ao-hoodie-ni-bong-unisex-homie...     -30%  143.0
# 2     https://tiki.vn/ao-hoodie-nam-nu-form-rong-sie...     -30%   23.0
# 3     https://tiki.vn/ao-khoac-hoodie-nam-nu-vai-ni-...     -30%    2.0
# 4     https://tiki.vn/ao-mu-hoodie-unisex-monsterx-g...     -30%    3.0
# ...                                                 ...      ...    ...
# 1022  https://tiki.vn/quan-ngu-nam-nu-vazco-q27-chat...      NaN   10.0
# 1023  https://tiki.vn/quan-kaki-dai-nam-tang-1-day-n...      NaN    1.0
# 1024  https://tiki.vn/quan-body-nam-quan-short-jean-...      NaN    4.0
# 1025  https://tiki.vn/quan-jean-nam-co-gian-dang-suo...      NaN    2.0
# 1026  https://tiki.vn/quan-jean-nam-trang-cao-cap-va...      NaN    1.0
#
#       category      revenue
# 0     aohoodie  165575000.0
# 1     aohoodie   14300000.0
# 2     aohoodie    2530000.0
# 3     aohoodie     230000.0
# 4     aohoodie     315000.0
# ...        ...          ...
# 1022   quannam     380000.0
# 1023   quannam     255000.0
# 1024   quannam     460000.0
# 1025   quannam     480000.0
# 1026   quannam     150000.0
#
# [6343 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "thoitrangnam")

# %%
df
# Out:
#                                                   title   price  \
# 0     Áo hoodie nam nữ form rộng Unisex một màu in h...  179000
# 1     Áo hoodie nỉ bông unisex Homies liền mũ có túi...  100000
# 2     Áo hoodie nam nữ form rộng siêu xinh , Áo khoá...  110000
# 3     Áo khoác hoodie nam nữ vải nỉ xịn quảng châu m...  115000
# 4     Áo mũ Hoodie Unisex MonsterX Gấu X form rộng 5...  105000
# ...                                                 ...     ...
# 1022  Quần ngủ Nam nữ VAZCO Q27 chất liệu vải thun c...   38000
# 1023  Quần kaki dài nam (Tặng 1 dây nịt cao cấp) chấ...  255000
# 1024  Quần body nam Quần short jean nam có giãn shor...  115000
# 1025  Quần jean nam co giãn dáng suông đẹp màu xanh ...  240000
# 1026  QUẦN JEAN NAM TRẮNG CAO CẤP - VẢI TRẮNG TINH C...  150000
#
#                                               link_item discount  sales  \
# 0     https://tiki.vn/ao-hoodie-nam-nu-form-rong-uni...     -10%  925.0
# 1     https://tiki.vn/ao-hoodie-ni-bong-unisex-homie...     -30%  143.0
# 2     https://tiki.vn/ao-hoodie-nam-nu-form-rong-sie...     -30%   23.0
# 3     https://tiki.vn/ao-khoac-hoodie-nam-nu-vai-ni-...     -30%    2.0
# 4     https://tiki.vn/ao-mu-hoodie-unisex-monsterx-g...     -30%    3.0
# ...                                                 ...      ...    ...
# 1022  https://tiki.vn/quan-ngu-nam-nu-vazco-q27-chat...      NaN   10.0
# 1023  https://tiki.vn/quan-kaki-dai-nam-tang-1-day-n...      NaN    1.0
# 1024  https://tiki.vn/quan-body-nam-quan-short-jean-...      NaN    4.0
# 1025  https://tiki.vn/quan-jean-nam-co-gian-dang-suo...      NaN    2.0
# 1026  https://tiki.vn/quan-jean-nam-trang-cao-cap-va...      NaN    1.0
#
#      item_list      category      revenue
# 0     aohoodie  thoitrangnam  165575000.0
# 1     aohoodie  thoitrangnam   14300000.0
# 2     aohoodie  thoitrangnam    2530000.0
# 3     aohoodie  thoitrangnam     230000.0
# 4     aohoodie  thoitrangnam     315000.0
# ...        ...           ...          ...
# 1022   quannam  thoitrangnam     380000.0
# 1023   quannam  thoitrangnam     255000.0
# 1024   quannam  thoitrangnam     460000.0
# 1025   quannam  thoitrangnam     480000.0
# 1026   quannam  thoitrangnam     150000.0
#
# [6343 rows x 8 columns]

# %%
df.to_csv('tk_thoitrangnam_all_ed.csv', index=False, encoding='utf-8')
