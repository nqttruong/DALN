# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12hdem) - Copy (5)\thoitrangnam\aosomi"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_aosomi_all.ipynb',
#  'tk_ttnam_aosomi.ipynb',
#  'tk_ttnam_aosomi_npage.ipynb',
#  'tk_ttnam_aosomi_t1.csv',
#  'tk_ttnam_aosomi_t10.csv',
#  'tk_ttnam_aosomi_t11.csv',
#  'tk_ttnam_aosomi_t12.csv',
#  'tk_ttnam_aosomi_t13.csv',
#  'tk_ttnam_aosomi_t14.csv',
#  'tk_ttnam_aosomi_t15.csv',
#  'tk_ttnam_aosomi_t16.csv',
#  'tk_ttnam_aosomi_t17.csv',
#  'tk_ttnam_aosomi_t18.csv',
#  'tk_ttnam_aosomi_t19.csv',
#  'tk_ttnam_aosomi_t2.csv',
#  'tk_ttnam_aosomi_t20.csv',
#  'tk_ttnam_aosomi_t21.csv',
#  'tk_ttnam_aosomi_t22.csv',
#  'tk_ttnam_aosomi_t23.csv',
#  'tk_ttnam_aosomi_t24.csv',
#  'tk_ttnam_aosomi_t25.csv',
#  'tk_ttnam_aosomi_t26.csv',
#  'tk_ttnam_aosomi_t27.csv',
#  'tk_ttnam_aosomi_t28.csv',
#  'tk_ttnam_aosomi_t29.csv',
#  'tk_ttnam_aosomi_t3.csv',
#  'tk_ttnam_aosomi_t30.csv',
#  'tk_ttnam_aosomi_t31.csv',
#  'tk_ttnam_aosomi_t32.csv',
#  'tk_ttnam_aosomi_t33.csv',
#  'tk_ttnam_aosomi_t34.csv',
#  'tk_ttnam_aosomi_t35.csv',
#  'tk_ttnam_aosomi_t36.csv',
#  'tk_ttnam_aosomi_t37.csv',
#  'tk_ttnam_aosomi_t38.csv',
#  'tk_ttnam_aosomi_t39.csv',
#  'tk_ttnam_aosomi_t4.csv',
#  'tk_ttnam_aosomi_t40.csv',
#  'tk_ttnam_aosomi_t41.csv',
#  'tk_ttnam_aosomi_t42.csv',
#  'tk_ttnam_aosomi_t43.csv',
#  'tk_ttnam_aosomi_t44.csv',
#  'tk_ttnam_aosomi_t45.csv',
#  'tk_ttnam_aosomi_t46.csv',
#  'tk_ttnam_aosomi_t47.csv',
#  'tk_ttnam_aosomi_t48.csv',
#  'tk_ttnam_aosomi_t49.csv',
#  'tk_ttnam_aosomi_t5.csv',
#  'tk_ttnam_aosomi_t50.csv',
#  'tk_ttnam_aosomi_t6.csv',
#  'tk_ttnam_aosomi_t7.csv',
#  'tk_ttnam_aosomi_t8.csv',
#  'tk_ttnam_aosomi_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_aosomi_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0     Áo sơ mi nam vải cotton mềm không nhăn-Quà tặng  108.000₫
# 1   Áo sơ mi nam dài tay màu trắng không túi vải m...  108.000₫
# 2                        Áo sơ mi nam dài tay màu tím  159.000₫
# 3              Áo sơ mi nam dài tay kẻ caro trắng đen   159.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36           ÁO SƠ MI TRẮNG NAM HỌA TIẾT HOA THƯ PHÁP   99.000₫
# 37  Áo Sơ Mi Nam Họa Tiết Vải Lụa Hàn Không Nhăn H...  299.000₫
# 38  Áo Sơ Mi Form Rộng Unisex Nam Nữ Tay Dài Hàn Q...  100.000₫
# 39  Áo sơ mi nam chấm bông, họa tiết nhỏ, tay ngắn...   229.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=hf6CuQj1h...      1     -41%
# 1   https://tka.tiki.vn/pixel/pixel?data=qe3aw5TXu...      2     -35%
# 2   https://tka.tiki.vn/pixel/pixel?data=iWZ0Jdp-X...      3     -31%
# 3   https://tka.tiki.vn/pixel/pixel?data=zUc6VWOhL...      4      NaN
# 4   https://tka.tiki.vn/pixel/pixel?data=RYp2shgJi...      5      NaN
# ..                                                ...    ...      ...
# 35  https://tiki.vn/a-o-so-mi-nam-tay-ngan-ma-u-1-...     36      NaN
# 36  https://tiki.vn/ao-so-mi-trang-nam-hoa-tiet-ho...     37      NaN
# 37  https://tiki.vn/ao-so-mi-nam-hoa-tiet-vai-lua-...     38      NaN
# 38  https://tiki.vn/ao-so-mi-form-rong-unisex-nam-...     39      NaN
# 39  https://tiki.vn/ao-so-mi-nam-cham-bong-hoa-tie...     40      NaN
#
#         sales category
# 0   Đã bán 33   aosomi
# 1   Đã bán 30   aosomi
# 2   Đã bán 23   aosomi
# 3         NaN   aosomi
# 4         NaN   aosomi
# ..        ...      ...
# 35        NaN   aosomi
# 36   Đã bán 9   aosomi
# 37   Đã bán 4   aosomi
# 38  Đã bán 62   aosomi
# 39        NaN   aosomi
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0      Áo sơ mi nam vải cotton mềm không nhăn-Quà tặng  108.000₫
# 1    Áo sơ mi nam dài tay màu trắng không túi vải m...  108.000₫
# 2                         Áo sơ mi nam dài tay màu tím  159.000₫
# 3    Áo sơ mi nam trơn tay dài cao cấp Lados - 779 ...  139.000₫
# 4    Áo sơ mi nam trơn không nhăn LADOS - 523, Chất...  116.000₫
# ..                                                 ...       ...
# 859  Áo Sơ Mi Nam Tay Dài Màu Trơn Thời Trang Poniv...  105.000₫
# 860  Áo sơ mi nam, áo sơ mi cộc tay phối màu trẻ tr...  199.000₫
# 861           ÁO SƠ MI TRẮNG NAM HỌA TIẾT HOA THƯ PHÁP   99.000₫
# 862  Áo Sơ Mi Nam Họa Tiết Vải Lụa Hàn Không Nhăn H...  299.000₫
# 863  Áo Sơ Mi Form Rộng Unisex Nam Nữ Tay Dài Hàn Q...  100.000₫
#
#                                              link_item discount        sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=hf6CuQj1h...     -41%    Đã bán 33
# 1    https://tka.tiki.vn/pixel/pixel?data=qe3aw5TXu...     -35%    Đã bán 30
# 2    https://tka.tiki.vn/pixel/pixel?data=iWZ0Jdp-X...     -31%    Đã bán 23
# 3    https://tiki.vn/ao-so-mi-nam-tron-tay-dai-cao-...     -69%  Đã bán 3.2k
# 4    https://tiki.vn/ao-so-mi-nam-tron-khong-nhan-l...     -51%   Đã bán 542
# ..                                                 ...      ...          ...
# 859  https://tiki.vn/ao-so-mi-nam-tay-dai-mau-tron-...      NaN     Đã bán 4
# 860  https://tiki.vn/ao-so-mi-nam-ao-so-mi-coc-tay-...      NaN     Đã bán 2
# 861  https://tiki.vn/ao-so-mi-trang-nam-hoa-tiet-ho...      NaN     Đã bán 9
# 862  https://tiki.vn/ao-so-mi-nam-hoa-tiet-vai-lua-...      NaN     Đã bán 4
# 863  https://tiki.vn/ao-so-mi-form-rong-unisex-nam-...      NaN    Đã bán 62
#
#     category
# 0     aosomi
# 1     aosomi
# 2     aosomi
# 3     aosomi
# 4     aosomi
# ..       ...
# 859   aosomi
# 860   aosomi
# 861   aosomi
# 862   aosomi
# 863   aosomi
#
# [864 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      108000
# 1      108000
# 2      159000
# 3      139000
# 4      116000
#         ...
# 859    105000
# 860    199000
# 861     99000
# 862    299000
# 863    100000
# Name: price, Length: 864, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        33.0
# 1        30.0
# 2        23.0
# 3      3200.0
# 4       542.0
#         ...
# 859       4.0
# 860       2.0
# 861       9.0
# 862       4.0
# 863      62.0
# Name: sales, Length: 864, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        3564000.0
# 1        3240000.0
# 2        3657000.0
# 3      444800000.0
# 4       62872000.0
#           ...
# 859       420000.0
# 860       398000.0
# 861       891000.0
# 862      1196000.0
# 863      6200000.0
# Name: revenue, Length: 864, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số aosomi: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số aosomi:  3766859470.0
# So mat hang da ban:  864
# So san pham da ban:  21513.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0      Áo sơ mi nam vải cotton mềm không nhăn-Quà tặng  108000
# 1    Áo sơ mi nam dài tay màu trắng không túi vải m...  108000
# 2                         Áo sơ mi nam dài tay màu tím  159000
# 3    Áo sơ mi nam trơn tay dài cao cấp Lados - 779 ...  139000
# 4    Áo sơ mi nam trơn không nhăn LADOS - 523, Chất...  116000
# ..                                                 ...     ...
# 859  Áo Sơ Mi Nam Tay Dài Màu Trơn Thời Trang Poniv...  105000
# 860  Áo sơ mi nam, áo sơ mi cộc tay phối màu trẻ tr...  199000
# 861           ÁO SƠ MI TRẮNG NAM HỌA TIẾT HOA THƯ PHÁP   99000
# 862  Áo Sơ Mi Nam Họa Tiết Vải Lụa Hàn Không Nhăn H...  299000
# 863  Áo Sơ Mi Form Rộng Unisex Nam Nữ Tay Dài Hàn Q...  100000
#
#                                              link_item discount   sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=hf6CuQj1h...     -41%    33.0
# 1    https://tka.tiki.vn/pixel/pixel?data=qe3aw5TXu...     -35%    30.0
# 2    https://tka.tiki.vn/pixel/pixel?data=iWZ0Jdp-X...     -31%    23.0
# 3    https://tiki.vn/ao-so-mi-nam-tron-tay-dai-cao-...     -69%  3200.0
# 4    https://tiki.vn/ao-so-mi-nam-tron-khong-nhan-l...     -51%   542.0
# ..                                                 ...      ...     ...
# 859  https://tiki.vn/ao-so-mi-nam-tay-dai-mau-tron-...      NaN     4.0
# 860  https://tiki.vn/ao-so-mi-nam-ao-so-mi-coc-tay-...      NaN     2.0
# 861  https://tiki.vn/ao-so-mi-trang-nam-hoa-tiet-ho...      NaN     9.0
# 862  https://tiki.vn/ao-so-mi-nam-hoa-tiet-vai-lua-...      NaN     4.0
# 863  https://tiki.vn/ao-so-mi-form-rong-unisex-nam-...      NaN    62.0
#
#     category      revenue
# 0     aosomi    3564000.0
# 1     aosomi    3240000.0
# 2     aosomi    3657000.0
# 3     aosomi  444800000.0
# 4     aosomi   62872000.0
# ..       ...          ...
# 859   aosomi     420000.0
# 860   aosomi     398000.0
# 861   aosomi     891000.0
# 862   aosomi    1196000.0
# 863   aosomi    6200000.0
#
# [864 rows x 7 columns]

# %%
df_all.to_csv("tk_aosomi_all_ed.csv")
