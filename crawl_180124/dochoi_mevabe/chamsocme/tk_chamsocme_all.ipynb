# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12hdem) - Copy (5)\dochoi_mevabe\chamsocme"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_chamsocme_all.ipynb',
#  'tk_chamsocme_t1.csv',
#  'tk_chamsocme_t10.csv',
#  'tk_chamsocme_t11.csv',
#  'tk_chamsocme_t12.csv',
#  'tk_chamsocme_t13.csv',
#  'tk_chamsocme_t14.csv',
#  'tk_chamsocme_t15.csv',
#  'tk_chamsocme_t16.csv',
#  'tk_chamsocme_t17.csv',
#  'tk_chamsocme_t18.csv',
#  'tk_chamsocme_t19.csv',
#  'tk_chamsocme_t2.csv',
#  'tk_chamsocme_t20.csv',
#  'tk_chamsocme_t21.csv',
#  'tk_chamsocme_t22.csv',
#  'tk_chamsocme_t23.csv',
#  'tk_chamsocme_t24.csv',
#  'tk_chamsocme_t25.csv',
#  'tk_chamsocme_t26.csv',
#  'tk_chamsocme_t27.csv',
#  'tk_chamsocme_t28.csv',
#  'tk_chamsocme_t29.csv',
#  'tk_chamsocme_t3.csv',
#  'tk_chamsocme_t30.csv',
#  'tk_chamsocme_t31.csv',
#  'tk_chamsocme_t32.csv',
#  'tk_chamsocme_t33.csv',
#  'tk_chamsocme_t34.csv',
#  'tk_chamsocme_t35.csv',
#  'tk_chamsocme_t36.csv',
#  'tk_chamsocme_t37.csv',
#  'tk_chamsocme_t38.csv',
#  'tk_chamsocme_t39.csv',
#  'tk_chamsocme_t4.csv',
#  'tk_chamsocme_t40.csv',
#  'tk_chamsocme_t41.csv',
#  'tk_chamsocme_t42.csv',
#  'tk_chamsocme_t43.csv',
#  'tk_chamsocme_t44.csv',
#  'tk_chamsocme_t45.csv',
#  'tk_chamsocme_t46.csv',
#  'tk_chamsocme_t47.csv',
#  'tk_chamsocme_t48.csv',
#  'tk_chamsocme_t49.csv',
#  'tk_chamsocme_t5.csv',
#  'tk_chamsocme_t50.csv',
#  'tk_chamsocme_t6.csv',
#  'tk_chamsocme_t7.csv',
#  'tk_chamsocme_t8.csv',
#  'tk_chamsocme_t9.csv',
#  'tk_mvb_chamsocme.ipynb',
#  'tk_mvb_chamsocme_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_chamsocme_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...  185.000₫
# 1   Dầu gừng thảo mộc massage tan mỡ bụng sau sinh...  163.000₫
# 2   Kem nghệ tươi dưỡng da trắng mịn, sạch sạm nám...  242.000₫
# 3   Thảo mộc xông tắm sau sinh Wonmom 50g ( 2 Túi/...   62.100₫
# 4   Combo dưỡng trắng body và săn chắc eo sau sinh...  410.000₫
# ..                                                ...       ...
# 35  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...  165.000₫
# 36  Áo Choàng Cho Bé Bú, Khăn Choàng Che Nắng, Khă...   65.000₫
# 37  Phụ kiện thay thế cho máy hút sữa Fatzbaby Res...   20.000₫
# 38    Bộ phụ kiện đầu đủ dùng cho máy hút sữa Spectra  550.000₫
# 39  Màng hút Máy hút sữa điện đơn và đôi - FatzBab...  100.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=ZQor4f2hY...      1     -16%
# 1   https://tka.tiki.vn/pixel/pixel?data=OlATRTyan...      2     -14%
# 2   https://tka.tiki.vn/pixel/pixel?data=ei-p1-hbI...      3     -12%
# 3   https://tka.tiki.vn/pixel/pixel?data=XIfM1t3oZ...      4     -10%
# 4   https://tka.tiki.vn/pixel/pixel?data=p0HYBiwLN...      5     -18%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...     36      NaN
# 36  https://tiki.vn/ao-choang-cho-be-bu-khan-choan...     37      NaN
# 37  https://tiki.vn/phu-kien-thay-the-cho-may-hut-...     38      NaN
# 38  https://tiki.vn/bo-phu-kien-dau-du-dung-cho-ma...     39      NaN
# 39  https://tiki.vn/mang-hut-may-hut-sua-dien-don-...     40      NaN
#
#          sales   category
# 0   Đã bán 183  chamsocme
# 1   Đã bán 297  chamsocme
# 2   Đã bán 592  chamsocme
# 3   Đã bán 274  chamsocme
# 4     Đã bán 9  chamsocme
# ..         ...        ...
# 35   Đã bán 13  chamsocme
# 36   Đã bán 52  chamsocme
# 37         NaN  chamsocme
# 38   Đã bán 41  chamsocme
# 39         NaN  chamsocme
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...  185.000₫
# 1     Dầu gừng thảo mộc massage tan mỡ bụng sau sinh...  163.000₫
# 2     Kem nghệ tươi dưỡng da trắng mịn, sạch sạm nám...  242.000₫
# 3     Thảo mộc xông tắm sau sinh Wonmom 50g ( 2 Túi/...   62.100₫
# 4     Combo dưỡng trắng body và săn chắc eo sau sinh...  410.000₫
# ...                                                 ...       ...
# 1220  Lá xông, thơm tho cơ thể mẹ sau sinh, lưu thôn...   46.800₫
# 1221  Quần lót bầu và sau sinh cạp chéo chất SU ĐÚC ...   29.000₫
# 1222  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...  165.000₫
# 1223  Áo Choàng Cho Bé Bú, Khăn Choàng Che Nắng, Khă...   65.000₫
# 1224    Bộ phụ kiện đầu đủ dùng cho máy hút sữa Spectra  550.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=ZQor4f2hY...     -16%  Đã bán 183
# 1     https://tka.tiki.vn/pixel/pixel?data=OlATRTyan...     -14%  Đã bán 297
# 2     https://tka.tiki.vn/pixel/pixel?data=ei-p1-hbI...     -12%  Đã bán 592
# 3     https://tka.tiki.vn/pixel/pixel?data=XIfM1t3oZ...     -10%  Đã bán 274
# 4     https://tka.tiki.vn/pixel/pixel?data=p0HYBiwLN...     -18%    Đã bán 9
# ...                                                 ...      ...         ...
# 1220  https://tiki.vn/la-xong-thom-tho-co-the-me-sau...      NaN  Đã bán 224
# 1221  https://tiki.vn/quan-lot-bau-va-sau-sinh-cap-c...      NaN   Đã bán 40
# 1222  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...      NaN   Đã bán 13
# 1223  https://tiki.vn/ao-choang-cho-be-bu-khan-choan...      NaN   Đã bán 52
# 1224  https://tiki.vn/bo-phu-kien-dau-du-dung-cho-ma...      NaN   Đã bán 41
#
#        category
# 0     chamsocme
# 1     chamsocme
# 2     chamsocme
# 3     chamsocme
# 4     chamsocme
# ...         ...
# 1220  chamsocme
# 1221  chamsocme
# 1222  chamsocme
# 1223  chamsocme
# 1224  chamsocme
#
# [1225 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       185000
# 1       163000
# 2       242000
# 3        62100
# 4       410000
#          ...
# 1220     46800
# 1221     29000
# 1222    165000
# 1223     65000
# 1224    550000
# Name: price, Length: 1225, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       183.0
# 1       297.0
# 2       592.0
# 3       274.0
# 4         9.0
#         ...
# 1220    224.0
# 1221     40.0
# 1222     13.0
# 1223     52.0
# 1224     41.0
# Name: sales, Length: 1225, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        33855000.0
# 1        48411000.0
# 2       143264000.0
# 3        17015400.0
# 4         3690000.0
#            ...
# 1220     10483200.0
# 1221      1160000.0
# 1222      2145000.0
# 1223      3380000.0
# 1224     22550000.0
# Name: revenue, Length: 1225, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chamsocme: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số chamsocme:  13048974695.0
# So mat hang da ban:  1225
# So san pham da ban:  50125.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...  185000
# 1     Dầu gừng thảo mộc massage tan mỡ bụng sau sinh...  163000
# 2     Kem nghệ tươi dưỡng da trắng mịn, sạch sạm nám...  242000
# 3     Thảo mộc xông tắm sau sinh Wonmom 50g ( 2 Túi/...   62100
# 4     Combo dưỡng trắng body và săn chắc eo sau sinh...  410000
# ...                                                 ...     ...
# 1220  Lá xông, thơm tho cơ thể mẹ sau sinh, lưu thôn...   46800
# 1221  Quần lót bầu và sau sinh cạp chéo chất SU ĐÚC ...   29000
# 1222  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...  165000
# 1223  Áo Choàng Cho Bé Bú, Khăn Choàng Che Nắng, Khă...   65000
# 1224    Bộ phụ kiện đầu đủ dùng cho máy hút sữa Spectra  550000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=ZQor4f2hY...     -16%  183.0
# 1     https://tka.tiki.vn/pixel/pixel?data=OlATRTyan...     -14%  297.0
# 2     https://tka.tiki.vn/pixel/pixel?data=ei-p1-hbI...     -12%  592.0
# 3     https://tka.tiki.vn/pixel/pixel?data=XIfM1t3oZ...     -10%  274.0
# 4     https://tka.tiki.vn/pixel/pixel?data=p0HYBiwLN...     -18%    9.0
# ...                                                 ...      ...    ...
# 1220  https://tiki.vn/la-xong-thom-tho-co-the-me-sau...      NaN  224.0
# 1221  https://tiki.vn/quan-lot-bau-va-sau-sinh-cap-c...      NaN   40.0
# 1222  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...      NaN   13.0
# 1223  https://tiki.vn/ao-choang-cho-be-bu-khan-choan...      NaN   52.0
# 1224  https://tiki.vn/bo-phu-kien-dau-du-dung-cho-ma...      NaN   41.0
#
#        category      revenue
# 0     chamsocme   33855000.0
# 1     chamsocme   48411000.0
# 2     chamsocme  143264000.0
# 3     chamsocme   17015400.0
# 4     chamsocme    3690000.0
# ...         ...          ...
# 1220  chamsocme   10483200.0
# 1221  chamsocme    1160000.0
# 1222  chamsocme    2145000.0
# 1223  chamsocme    3380000.0
# 1224  chamsocme   22550000.0
#
# [1225 rows x 7 columns]

# %%
df_all.to_csv("tk_chamsocme_all_ed.csv")
