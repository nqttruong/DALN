# %%
import pandas as pd
import os 
import numpy as np
import matplotlib.pyplot as plt

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124"
os.listdir(path)
# Out:
# ['diengiadung',
#  'dienthoai_maytinhbang',
#  'dochoi_mevabe',
#  'thoitrangnam',
#  'thoitrangnu',
#  'tk_180124_all.ipynb',
#  'tk_diengiadung_all_ed.csv',
#  'tk_dienthoai_all_ed.csv',
#  'tk_mevabe_all_ed.csv',
#  'tk_thoitrangnam_all_ed.csv',
#  'tk_thoitrangnu_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_180124_all.csv", index="False")

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1999000
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   239000
# 2     Nồi chiên không dầu đa chức năng 12 trong 1 Su...  1599000
# 3     Máy Xay Sinh Tố Đa Năng Sunhouse HappyTime HTD...   349000
# 4     Nồi Cơm Nắp Gài Toshiba RC-10JFM(H)VN (1L) - H...   525000
# ...                                                 ...      ...
# 7961  Đầm xòe thiết kế trung niên cao cấp sang trọng...   480000
# 7962  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...   235000
# 7963  Váy Đầm cho người trung niên Dáng Dài họa tiết...    99000
# 7964  Bộ đồ trung niên nữ cao cấp hè B58 - Bộ mặc nh...   275000
# 7965  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...   225000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=poDyYuobi...     -31%  2300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=kJlLkJ32e...     -55%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=wWIjOg9Qe...     -41%   192.0
# 3     https://tiki.vn/may-xay-sinh-to-da-nang-sunhou...      NaN  5000.0
# 4     https://tiki.vn/noi-com-nap-gai-toshiba-rc-10j...     -40%    80.0
# ...                                                 ...      ...     ...
# 7961  https://tiki.vn/dam-xoe-thiet-ke-trung-nien-ca...      NaN     1.0
# 7962  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN     1.0
# 7963  https://tiki.vn/vay-dam-cho-nguoi-trung-nien-d...      NaN     1.0
# 7964  https://tiki.vn/bo-do-trung-nien-nu-cao-cap-he...      NaN     4.0
# 7965  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN     3.0
#
#                item_list     category       revenue
# 0           dodungnhabep  diengiadung  4.597700e+09
# 1           dodungnhabep  diengiadung  1.195000e+09
# 2           dodungnhabep  diengiadung  3.070080e+08
# 3           dodungnhabep  diengiadung  1.745000e+09
# 4           dodungnhabep  diengiadung  4.200000e+07
# ...                  ...          ...           ...
# 7961  thoitrangtrungnien  thoitrangnu  4.800000e+05
# 7962  thoitrangtrungnien  thoitrangnu  2.350000e+05
# 7963  thoitrangtrungnien  thoitrangnu  9.900000e+04
# 7964  thoitrangtrungnien  thoitrangnu  1.100000e+06
# 7965  thoitrangtrungnien  thoitrangnu  6.750000e+05
#
# [27428 rows x 8 columns]

# %%
df_all["day"] = "18jan"
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                    title    price  \
# 0      Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1999000
# 1      Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   239000
# 2      Nồi chiên không dầu đa chức năng 12 trong 1 Su...  1599000
# 3      Máy Xay Sinh Tố Đa Năng Sunhouse HappyTime HTD...   349000
# 4      Nồi Cơm Nắp Gài Toshiba RC-10JFM(H)VN (1L) - H...   525000
# ...                                                  ...      ...
# 27423  Đầm xòe thiết kế trung niên cao cấp sang trọng...   480000
# 27424  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...   235000
# 27425  Váy Đầm cho người trung niên Dáng Dài họa tiết...    99000
# 27426  Bộ đồ trung niên nữ cao cấp hè B58 - Bộ mặc nh...   275000
# 27427  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...   225000
#
#                                                link_item discount   sales  \
# 0      https://tka.tiki.vn/pixel/pixel?data=poDyYuobi...     -31%  2300.0
# 1      https://tka.tiki.vn/pixel/pixel?data=kJlLkJ32e...     -55%  5000.0
# 2      https://tka.tiki.vn/pixel/pixel?data=wWIjOg9Qe...     -41%   192.0
# 3      https://tiki.vn/may-xay-sinh-to-da-nang-sunhou...      NaN  5000.0
# 4      https://tiki.vn/noi-com-nap-gai-toshiba-rc-10j...     -40%    80.0
# ...                                                  ...      ...     ...
# 27423  https://tiki.vn/dam-xoe-thiet-ke-trung-nien-ca...      NaN     1.0
# 27424  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN     1.0
# 27425  https://tiki.vn/vay-dam-cho-nguoi-trung-nien-d...      NaN     1.0
# 27426  https://tiki.vn/bo-do-trung-nien-nu-cao-cap-he...      NaN     4.0
# 27427  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN     3.0
#
#                 item_list     category       revenue    day
# 0            dodungnhabep  diengiadung  4.597700e+09  18jan
# 1            dodungnhabep  diengiadung  1.195000e+09  18jan
# 2            dodungnhabep  diengiadung  3.070080e+08  18jan
# 3            dodungnhabep  diengiadung  1.745000e+09  18jan
# 4            dodungnhabep  diengiadung  4.200000e+07  18jan
# ...                   ...          ...           ...    ...
# 27423  thoitrangtrungnien  thoitrangnu  4.800000e+05  18jan
# 27424  thoitrangtrungnien  thoitrangnu  2.350000e+05  18jan
# 27425  thoitrangtrungnien  thoitrangnu  9.900000e+04  18jan
# 27426  thoitrangtrungnien  thoitrangnu  1.100000e+06  18jan
# 27427  thoitrangtrungnien  thoitrangnu  6.750000e+05  18jan
#
# [27428 rows x 9 columns]

# %%
df_all.to_csv("tk_180124_all_ed.csv")
