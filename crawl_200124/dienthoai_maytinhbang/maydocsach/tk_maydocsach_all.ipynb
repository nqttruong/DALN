# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\dienthoai_maytinhbang\maydocsach"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dienthoai_maytinhbang_maydocsach.ipynb',
#  'tk_dienthoai_maytinhbang_maydocsach_t2.ipynb',
#  'tk_maydocsach_all.ipynb',
#  'tk_maydocsach_t1.csv',
#  'tk_maydocsach_t2.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_maydocsach_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Máy đọc sách New Kindle 11th 2022 (16GB) - Hàn...  2.680.000₫
# 1   Máy đọc sách All New Kindle Paperwhite 5 (11th...  3.330.000₫
# 2   Máy đọc sách All New Kindle Oasis 3 - Hàng nhậ...  6.690.000₫
# 3   Máy đọc sách Kindle 2022 (11th) - All new kind...  2.680.000₫
# 4   Máy đọc sách New Kindle 11th 2022 (16GB) - Hàn...  2.680.000₫
# ..                                                ...         ...
# 15  Paperwhite 5 (11th-generation) - 2021 - Hàng N...  3.490.000₫
# 16        Máy Đọc Sách Likebook P10 - Hàng chính hãng  9.090.000₫
# 17  Bút học tiếng Anh i-Tek Venus 2023 (HÀNG CHÍNH...    560.000₫
# 18  Máy đọc sách All new Paperwhite Gen 5 (11th) m...  3.490.000₫
# 19             Máy đọc sách Kobo Nia - Hàng nhập khẩu  2.680.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=o-1rGsNx0...      1      -3%
# 1   https://tka.tiki.vn/pixel/pixel?data=aqpwfHp5O...      2     -30%
# 2   https://tka.tiki.vn/pixel/pixel?data=pSOwBTX_e...      3     -11%
# 3   https://tka.tiki.vn/pixel/pixel?data=WVH4trYor...      4     -21%
# 4   https://tka.tiki.vn/pixel/pixel?data=sLoAU2rDo...      5     -11%
# ..                                                ...    ...      ...
# 15  https://tiki.vn/kindle-paperwhite-5-11th-gener...     16      NaN
# 16  https://tiki.vn/may-doc-sach-likebook-p10-hang...     17      NaN
# 17  https://tiki.vn/but-hoc-tieng-anh-i-tek-chinh-...     18      NaN
# 18  https://tiki.vn/may-doc-sach-all-new-paperwhit...     19      NaN
# 19  https://tiki.vn/may-doc-sach-kobo-nia-p1487018...     20      NaN
#
#         sales    category
# 0    Đã bán 4  maydocsach
# 1    Đã bán 3  maydocsach
# 2   Đã bán 52  maydocsach
# 3    Đã bán 8  maydocsach
# 4    Đã bán 3  maydocsach
# ..        ...         ...
# 15        NaN  maydocsach
# 16   Đã bán 6  maydocsach
# 17   Đã bán 1  maydocsach
# 18        NaN  maydocsach
# 19        NaN  maydocsach
#
# [75 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Máy đọc sách New Kindle 11th 2022 (16GB) - Hàn...  2.680.000₫
# 1   Máy đọc sách All New Kindle Paperwhite 5 (11th...  3.330.000₫
# 2   Máy đọc sách All New Kindle Oasis 3 - Hàng nhậ...  6.690.000₫
# 3   Máy đọc sách Kindle 2022 (11th) - All new kind...  2.680.000₫
# 4   Máy đọc sách New Kindle 11th 2022 (16GB) - Hàn...  2.680.000₫
# ..                                                ...         ...
# 62  Máy đọc sách All New Kindle Oasis 3 - Hàng nhậ...  6.690.000₫
# 63  Combo Máy đọc sách All New Kindle Paperwhite 5...  3.850.000₫
# 64  Combo Máy đọc sách All New Kindle Paperwhite 5...  3.790.000₫
# 65        Máy Đọc Sách Likebook P10 - Hàng chính hãng  9.090.000₫
# 66  Bút học tiếng Anh i-Tek Venus 2023 (HÀNG CHÍNH...    560.000₫
#
#                                             link_item discount      sales  \
# 0   https://tka.tiki.vn/pixel/pixel?data=o-1rGsNx0...      -3%   Đã bán 4
# 1   https://tka.tiki.vn/pixel/pixel?data=aqpwfHp5O...     -30%   Đã bán 3
# 2   https://tka.tiki.vn/pixel/pixel?data=pSOwBTX_e...     -11%  Đã bán 52
# 3   https://tka.tiki.vn/pixel/pixel?data=WVH4trYor...     -21%   Đã bán 8
# 4   https://tka.tiki.vn/pixel/pixel?data=sLoAU2rDo...     -11%   Đã bán 3
# ..                                                ...      ...        ...
# 62  https://tka.tiki.vn/pixel/pixel?data=flkZlZsDm...      NaN  Đã bán 52
# 63  https://tka.tiki.vn/pixel/pixel?data=aYR25-Mff...      NaN   Đã bán 7
# 64  https://tka.tiki.vn/pixel/pixel?data=TkHp7P33V...      NaN   Đã bán 3
# 65  https://tiki.vn/may-doc-sach-likebook-p10-hang...      NaN   Đã bán 6
# 66  https://tiki.vn/but-hoc-tieng-anh-i-tek-chinh-...      NaN   Đã bán 1
#
#       category
# 0   maydocsach
# 1   maydocsach
# 2   maydocsach
# 3   maydocsach
# 4   maydocsach
# ..         ...
# 62  maydocsach
# 63  maydocsach
# 64  maydocsach
# 65  maydocsach
# 66  maydocsach
#
# [67 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0     2680000
# 1     3330000
# 2     6690000
# 3     2680000
# 4     2680000
#        ...
# 62    6690000
# 63    3850000
# 64    3790000
# 65    9090000
# 66     560000
# Name: price, Length: 67, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      4.0
# 1      3.0
# 2     52.0
# 3      8.0
# 4      3.0
#       ...
# 62    52.0
# 63     7.0
# 64     3.0
# 65     6.0
# 66     1.0
# Name: sales, Length: 67, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      10720000.0
# 1       9990000.0
# 2     347880000.0
# 3      21440000.0
# 4       8040000.0
#          ...
# 62    347880000.0
# 63     26950000.0
# 64     11370000.0
# 65     54540000.0
# 66       560000.0
# Name: revenue, Length: 67, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số maydocsach: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số maydocsach:  22811851324.0
# So mat hang da ban:  67
# So san pham da ban:  6098.0

# %%
df_all
# Out:
#                                                 title    price  \
# 0   Máy đọc sách New Kindle 11th 2022 (16GB) - Hàn...  2680000
# 1   Máy đọc sách All New Kindle Paperwhite 5 (11th...  3330000
# 2   Máy đọc sách All New Kindle Oasis 3 - Hàng nhậ...  6690000
# 3   Máy đọc sách Kindle 2022 (11th) - All new kind...  2680000
# 4   Máy đọc sách New Kindle 11th 2022 (16GB) - Hàn...  2680000
# ..                                                ...      ...
# 62  Máy đọc sách All New Kindle Oasis 3 - Hàng nhậ...  6690000
# 63  Combo Máy đọc sách All New Kindle Paperwhite 5...  3850000
# 64  Combo Máy đọc sách All New Kindle Paperwhite 5...  3790000
# 65        Máy Đọc Sách Likebook P10 - Hàng chính hãng  9090000
# 66  Bút học tiếng Anh i-Tek Venus 2023 (HÀNG CHÍNH...   560000
#
#                                             link_item discount  sales  \
# 0   https://tka.tiki.vn/pixel/pixel?data=o-1rGsNx0...      -3%    4.0
# 1   https://tka.tiki.vn/pixel/pixel?data=aqpwfHp5O...     -30%    3.0
# 2   https://tka.tiki.vn/pixel/pixel?data=pSOwBTX_e...     -11%   52.0
# 3   https://tka.tiki.vn/pixel/pixel?data=WVH4trYor...     -21%    8.0
# 4   https://tka.tiki.vn/pixel/pixel?data=sLoAU2rDo...     -11%    3.0
# ..                                                ...      ...    ...
# 62  https://tka.tiki.vn/pixel/pixel?data=flkZlZsDm...      NaN   52.0
# 63  https://tka.tiki.vn/pixel/pixel?data=aYR25-Mff...      NaN    7.0
# 64  https://tka.tiki.vn/pixel/pixel?data=TkHp7P33V...      NaN    3.0
# 65  https://tiki.vn/may-doc-sach-likebook-p10-hang...      NaN    6.0
# 66  https://tiki.vn/but-hoc-tieng-anh-i-tek-chinh-...      NaN    1.0
#
#       category      revenue
# 0   maydocsach   10720000.0
# 1   maydocsach    9990000.0
# 2   maydocsach  347880000.0
# 3   maydocsach   21440000.0
# 4   maydocsach    8040000.0
# ..         ...          ...
# 62  maydocsach  347880000.0
# 63  maydocsach   26950000.0
# 64  maydocsach   11370000.0
# 65  maydocsach   54540000.0
# 66  maydocsach     560000.0
#
# [67 rows x 7 columns]

# %%
df_all.to_csv("tk_maydocsach_all_ed.csv")
