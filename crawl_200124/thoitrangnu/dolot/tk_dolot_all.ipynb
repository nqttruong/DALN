# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\thoitrangnu\dolot"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dolotnu.csv',
#  'tk_dolot_all.ipynb',
#  'tk_ttn_dl.ipynb',
#  'tk_ttn_dln_t10.csv',
#  'tk_ttn_dln_t11.csv',
#  'tk_ttn_dln_t12.csv',
#  'tk_ttn_dln_t13.csv',
#  'tk_ttn_dln_t14.csv',
#  'tk_ttn_dln_t15.csv',
#  'tk_ttn_dln_t16.csv',
#  'tk_ttn_dln_t17.csv',
#  'tk_ttn_dln_t18.csv',
#  'tk_ttn_dln_t19.csv',
#  'tk_ttn_dln_t2.csv',
#  'tk_ttn_dln_t20.csv',
#  'tk_ttn_dln_t21.csv',
#  'tk_ttn_dln_t22.csv',
#  'tk_ttn_dln_t23.csv',
#  'tk_ttn_dln_t24.csv',
#  'tk_ttn_dln_t25.csv',
#  'tk_ttn_dln_t26.csv',
#  'tk_ttn_dln_t27.csv',
#  'tk_ttn_dln_t28.csv',
#  'tk_ttn_dln_t29.csv',
#  'tk_ttn_dln_t3.csv',
#  'tk_ttn_dln_t30.csv',
#  'tk_ttn_dln_t31.csv',
#  'tk_ttn_dln_t32.csv',
#  'tk_ttn_dln_t33.csv',
#  'tk_ttn_dln_t34.csv',
#  'tk_ttn_dln_t35.csv',
#  'tk_ttn_dln_t36.csv',
#  'tk_ttn_dln_t37.csv',
#  'tk_ttn_dln_t38.csv',
#  'tk_ttn_dln_t39.csv',
#  'tk_ttn_dln_t4.csv',
#  'tk_ttn_dln_t40.csv',
#  'tk_ttn_dln_t41.csv',
#  'tk_ttn_dln_t42.csv',
#  'tk_ttn_dln_t43.csv',
#  'tk_ttn_dln_t44.csv',
#  'tk_ttn_dln_t45.csv',
#  'tk_ttn_dln_t46.csv',
#  'tk_ttn_dln_t47.csv',
#  'tk_ttn_dln_t48.csv',
#  'tk_ttn_dln_t49.csv',
#  'tk_ttn_dln_t5.csv',
#  'tk_ttn_dln_t50.csv',
#  'tk_ttn_dln_t6.csv',
#  'tk_ttn_dln_t7.csv',
#  'tk_ttn_dln_t8.csv',
#  'tk_ttn_dln_t9.csv',
#  'tk_ttn_dl_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dolot_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Áo ngực mút mỏng không đường may phối ren T-Sh...  349.000₫
# 1   Áo ngực không gọng mút mỏng ren phối dây Tshir...  199.000₫
# 2   Áo ngực có gọng mút vừa T-Shirt smothie iBasic...  199.000₫
# 3            Áo ngực mút mỏng không gọng iBasic VA029  219.000₫
# 4   Áo ngực có gọng mút mỏng ren T- Shirt iBasic B...  719.200₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36              Quần lót nữ nâng mông thoáng mát Sexy   37.000₫
# 37  Combo 10 Quần lót nữ cotton trơn cao cấp Vicci...  450.000₫
# 38  Bộ 5 Quần Lót Ren phối nơ cực sexy thương hiệu...  294.000₫
# 39  Áo Ngực Su Hình Lá Nâng Ngực Không Gọng Đệm 3c...   88.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=EEGXQGjkm...      1     -42%
# 1   https://tka.tiki.vn/pixel/pixel?data=h7QdUru2L...      2     -75%
# 2   https://tka.tiki.vn/pixel/pixel?data=9lQ_B6szh...      3     -33%
# 3   https://tka.tiki.vn/pixel/pixel?data=JCfT2xudO...      4      -8%
# 4   https://tka.tiki.vn/pixel/pixel?data=fo9ojpOV1...      5     -20%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/quan-lot-lot-khe-ren-2-day-che...     36      NaN
# 36  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...     37      NaN
# 37  https://tiki.vn/combo-10-quan-lot-nu-cotton-tr...     38      NaN
# 38  https://tiki.vn/bo-5-quan-lot-ren-phoi-no-cuc-...     39      NaN
# 39  https://tiki.vn/ao-nguc-su-hinh-la-nang-nguc-k...     40      NaN
#
#          sales category
# 0     Đã bán 5  dolotnu
# 1     Đã bán 5  dolotnu
# 2    Đã bán 86  dolotnu
# 3   Đã bán 281  dolotnu
# 4    Đã bán 11  dolotnu
# ..         ...      ...
# 35         NaN  dolotnu
# 36    Đã bán 5  dolotnu
# 37    Đã bán 2  dolotnu
# 38    Đã bán 1  dolotnu
# 39         NaN  dolotnu
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Áo ngực mút mỏng không đường may phối ren T-Sh...  349.000₫
# 1     Áo ngực không gọng mút mỏng ren phối dây Tshir...  199.000₫
# 2     Áo ngực có gọng mút vừa T-Shirt smothie iBasic...  199.000₫
# 3              Áo ngực mút mỏng không gọng iBasic VA029  219.000₫
# 4     Áo ngực có gọng mút mỏng ren T- Shirt iBasic B...  719.200₫
# ...                                                 ...       ...
# 1176  Áo Lót Mút Dày Siêu Nâng Ngực Màu Trơn Basic D...  579.000₫
# 1177  Combo 5 - 10 Quần lót nữ viền ren co giãn 4 ch...   45.000₫
# 1178              Quần lót nữ nâng mông thoáng mát Sexy   37.000₫
# 1179  Combo 10 Quần lót nữ cotton trơn cao cấp Vicci...  450.000₫
# 1180  Bộ 5 Quần Lót Ren phối nơ cực sexy thương hiệu...  294.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=EEGXQGjkm...     -42%    Đã bán 5
# 1     https://tka.tiki.vn/pixel/pixel?data=h7QdUru2L...     -75%    Đã bán 5
# 2     https://tka.tiki.vn/pixel/pixel?data=9lQ_B6szh...     -33%   Đã bán 86
# 3     https://tka.tiki.vn/pixel/pixel?data=JCfT2xudO...      -8%  Đã bán 281
# 4     https://tka.tiki.vn/pixel/pixel?data=fo9ojpOV1...     -20%   Đã bán 11
# ...                                                 ...      ...         ...
# 1176  https://tiki.vn/ao-lot-mut-day-sieu-nang-nguc-...      NaN  Đã bán 170
# 1177  https://tiki.vn/combo-5-10-quan-lot-nu-vien-re...      NaN    Đã bán 2
# 1178  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...      NaN    Đã bán 5
# 1179  https://tiki.vn/combo-10-quan-lot-nu-cotton-tr...      NaN    Đã bán 2
# 1180  https://tiki.vn/bo-5-quan-lot-ren-phoi-no-cuc-...      NaN    Đã bán 1
#
#      category
# 0     dolotnu
# 1     dolotnu
# 2     dolotnu
# 3     dolotnu
# 4     dolotnu
# ...       ...
# 1176  dolotnu
# 1177  dolotnu
# 1178  dolotnu
# 1179  dolotnu
# 1180  dolotnu
#
# [1181 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       349000
# 1       199000
# 2       199000
# 3       219000
# 4       719200
#          ...
# 1176    579000
# 1177     45000
# 1178     37000
# 1179    450000
# 1180    294000
# Name: price, Length: 1181, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0         5.0
# 1         5.0
# 2        86.0
# 3       281.0
# 4        11.0
#         ...
# 1176    170.0
# 1177      2.0
# 1178      5.0
# 1179      2.0
# 1180      1.0
# Name: sales, Length: 1181, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        1745000.0
# 1         995000.0
# 2       17114000.0
# 3       61539000.0
# 4        7911200.0
#            ...
# 1176    98430000.0
# 1177       90000.0
# 1178      185000.0
# 1179      900000.0
# 1180      294000.0
# Name: revenue, Length: 1181, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dolot: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dolot:  9678110802.0
# So mat hang da ban:  1181
# So san pham da ban:  76566.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Áo ngực mút mỏng không đường may phối ren T-Sh...  349000
# 1     Áo ngực không gọng mút mỏng ren phối dây Tshir...  199000
# 2     Áo ngực có gọng mút vừa T-Shirt smothie iBasic...  199000
# 3              Áo ngực mút mỏng không gọng iBasic VA029  219000
# 4     Áo ngực có gọng mút mỏng ren T- Shirt iBasic B...  719200
# ...                                                 ...     ...
# 1176  Áo Lót Mút Dày Siêu Nâng Ngực Màu Trơn Basic D...  579000
# 1177  Combo 5 - 10 Quần lót nữ viền ren co giãn 4 ch...   45000
# 1178              Quần lót nữ nâng mông thoáng mát Sexy   37000
# 1179  Combo 10 Quần lót nữ cotton trơn cao cấp Vicci...  450000
# 1180  Bộ 5 Quần Lót Ren phối nơ cực sexy thương hiệu...  294000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=EEGXQGjkm...     -42%    5.0
# 1     https://tka.tiki.vn/pixel/pixel?data=h7QdUru2L...     -75%    5.0
# 2     https://tka.tiki.vn/pixel/pixel?data=9lQ_B6szh...     -33%   86.0
# 3     https://tka.tiki.vn/pixel/pixel?data=JCfT2xudO...      -8%  281.0
# 4     https://tka.tiki.vn/pixel/pixel?data=fo9ojpOV1...     -20%   11.0
# ...                                                 ...      ...    ...
# 1176  https://tiki.vn/ao-lot-mut-day-sieu-nang-nguc-...      NaN  170.0
# 1177  https://tiki.vn/combo-5-10-quan-lot-nu-vien-re...      NaN    2.0
# 1178  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...      NaN    5.0
# 1179  https://tiki.vn/combo-10-quan-lot-nu-cotton-tr...      NaN    2.0
# 1180  https://tiki.vn/bo-5-quan-lot-ren-phoi-no-cuc-...      NaN    1.0
#
#      category     revenue
# 0     dolotnu   1745000.0
# 1     dolotnu    995000.0
# 2     dolotnu  17114000.0
# 3     dolotnu  61539000.0
# 4     dolotnu   7911200.0
# ...       ...         ...
# 1176  dolotnu  98430000.0
# 1177  dolotnu     90000.0
# 1178  dolotnu    185000.0
# 1179  dolotnu    900000.0
# 1180  dolotnu    294000.0
#
# [1181 rows x 7 columns]

# %%
df_all.to_csv("tk_dolot_all_ed.csv")
