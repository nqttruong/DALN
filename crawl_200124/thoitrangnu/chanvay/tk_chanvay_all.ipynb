# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\thoitrangnu\chanvay"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_chanvay_all.ipynb',
#  'tk_ttn_cv.csv',
#  'tk_ttn_cv.ipynb',
#  'tk_ttn_cv_npage.ipynb',
#  'tk_ttn_cv_t10.csv',
#  'tk_ttn_cv_t11.csv',
#  'tk_ttn_cv_t12.csv',
#  'tk_ttn_cv_t13.csv',
#  'tk_ttn_cv_t14.csv',
#  'tk_ttn_cv_t15.csv',
#  'tk_ttn_cv_t16.csv',
#  'tk_ttn_cv_t17.csv',
#  'tk_ttn_cv_t18.csv',
#  'tk_ttn_cv_t19.csv',
#  'tk_ttn_cv_t2.csv',
#  'tk_ttn_cv_t20.csv',
#  'tk_ttn_cv_t21.csv',
#  'tk_ttn_cv_t22.csv',
#  'tk_ttn_cv_t23.csv',
#  'tk_ttn_cv_t24.csv',
#  'tk_ttn_cv_t25.csv',
#  'tk_ttn_cv_t26.csv',
#  'tk_ttn_cv_t27.csv',
#  'tk_ttn_cv_t28.csv',
#  'tk_ttn_cv_t29.csv',
#  'tk_ttn_cv_t3.csv',
#  'tk_ttn_cv_t30.csv',
#  'tk_ttn_cv_t31.csv',
#  'tk_ttn_cv_t32.csv',
#  'tk_ttn_cv_t33.csv',
#  'tk_ttn_cv_t34.csv',
#  'tk_ttn_cv_t35.csv',
#  'tk_ttn_cv_t36.csv',
#  'tk_ttn_cv_t37.csv',
#  'tk_ttn_cv_t38.csv',
#  'tk_ttn_cv_t39.csv',
#  'tk_ttn_cv_t4.csv',
#  'tk_ttn_cv_t40.csv',
#  'tk_ttn_cv_t41.csv',
#  'tk_ttn_cv_t42.csv',
#  'tk_ttn_cv_t43.csv',
#  'tk_ttn_cv_t44.csv',
#  'tk_ttn_cv_t45.csv',
#  'tk_ttn_cv_t46.csv',
#  'tk_ttn_cv_t47.csv',
#  'tk_ttn_cv_t48.csv',
#  'tk_ttn_cv_t49.csv',
#  'tk_ttn_cv_t5.csv',
#  'tk_ttn_cv_t50.csv',
#  'tk_ttn_cv_t6.csv',
#  'tk_ttn_cv_t7.csv',
#  'tk_ttn_cv_t8.csv',
#  'tk_ttn_cv_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_chanvay_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Chân Váy Nữ Công Sở New Design Thiết Kế Dáng V...  329.000₫
# 1   Chân Váy Công Sở New Design Thiết Kế Dáng Váy ...  333.000₫
# 2   Chân váy công sở dáng đuôi cá, Lưng cao, Ôm bo...  349.000₫
# 3   Chân váy công sở NEW DESIGN dáng midi dài qua ...  299.000₫
# 4       Chân váy lụa dài dáng đuôi cá cạp trễ cao cấp  239.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36                         Chân váy midi dài phối cúc  195.000₫
# 37     Chân váy ôm xếp pilly – MS0305CV ( có lớp lót)   99.000₫
# 38                                 Váy len QC cao cấp  199.000₫
# 39  Chân váy dáng dài Vintage dễ thương VAY134 fre...   245.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=Fc829pVF_...      1     -37%
# 1   https://tka.tiki.vn/pixel/pixel?data=b1t-fksuC...      2     -31%
# 2   https://tka.tiki.vn/pixel/pixel?data=c3JaIGVm5...      3     -37%
# 3   https://tka.tiki.vn/pixel/pixel?data=hSzhBFnm8...      4     -49%
# 4   https://tka.tiki.vn/pixel/pixel?data=ARx7t6JDN...      5     -47%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/olv-chan-vay-jennifer-cream-sk...     36      NaN
# 36  https://tiki.vn/chan-vay-midi-dai-phoi-cuc-p86...     37      NaN
# 37  https://tiki.vn/chan-vay-om-xep-pilly-ms0305cv...     38      NaN
# 38  https://tiki.vn/vay-len-qc-cao-cap-p201521340....     39      NaN
# 39  https://tiki.vn/chan-vay-dang-dai-vintage-de-t...     40      NaN
#
#         sales category
# 0    Đã bán 9  chanvay
# 1   Đã bán 80  chanvay
# 2    Đã bán 4  chanvay
# 3   Đã bán 15  chanvay
# 4    Đã bán 1  chanvay
# ..        ...      ...
# 35        NaN  chanvay
# 36        NaN  chanvay
# 37  Đã bán 32  chanvay
# 38        NaN  chanvay
# 39        NaN  chanvay
#
# [2028 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Chân Váy Nữ Công Sở New Design Thiết Kế Dáng V...  329.000₫
# 1    Chân Váy Công Sở New Design Thiết Kế Dáng Váy ...  333.000₫
# 2    Chân váy công sở dáng đuôi cá, Lưng cao, Ôm bo...  349.000₫
# 3    Chân váy công sở NEW DESIGN dáng midi dài qua ...  299.000₫
# 4        Chân váy lụa dài dáng đuôi cá cạp trễ cao cấp  239.000₫
# ..                                                 ...       ...
# 471                     Chân váy voan xếp ly dễ thương  148.000₫
# 472  CHÂN VÁY BÒ KIỂUQUẦN VÁY JEAN VẠT LỆCH SANG CHẢNH  297.000₫
# 473      Chân váy bút chì dáng dài Haint Boutique Cv13  131.000₫
# 474                          CHÂN VÁY XÒE LADY FASHION   75.000₫
# 475     Chân váy ôm xếp pilly – MS0305CV ( có lớp lót)   99.000₫
#
#                                              link_item discount      sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=Fc829pVF_...     -37%   Đã bán 9
# 1    https://tka.tiki.vn/pixel/pixel?data=b1t-fksuC...     -31%  Đã bán 80
# 2    https://tka.tiki.vn/pixel/pixel?data=c3JaIGVm5...     -37%   Đã bán 4
# 3    https://tka.tiki.vn/pixel/pixel?data=hSzhBFnm8...     -49%  Đã bán 15
# 4    https://tka.tiki.vn/pixel/pixel?data=ARx7t6JDN...     -47%   Đã bán 1
# ..                                                 ...      ...        ...
# 471  https://tiki.vn/chan-vay-voan-xep-ly-de-thuong...      NaN   Đã bán 5
# 472  https://tiki.vn/chan-vay-bo-kieu-quan-vay-jean...      NaN   Đã bán 5
# 473  https://tiki.vn/chan-vay-but-chi-dang-dai-hain...      NaN   Đã bán 6
# 474  https://tiki.vn/chan-vay-xoe-lady-fashion-p213...      NaN   Đã bán 4
# 475  https://tiki.vn/chan-vay-om-xep-pilly-ms0305cv...      NaN  Đã bán 32
#
#     category
# 0    chanvay
# 1    chanvay
# 2    chanvay
# 3    chanvay
# 4    chanvay
# ..       ...
# 471  chanvay
# 472  chanvay
# 473  chanvay
# 474  chanvay
# 475  chanvay
#
# [476 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      329000
# 1      333000
# 2      349000
# 3      299000
# 4      239000
#         ...
# 471    148000
# 472    297000
# 473    131000
# 474     75000
# 475     99000
# Name: price, Length: 476, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       9.0
# 1      80.0
# 2       4.0
# 3      15.0
# 4       1.0
#        ...
# 471     5.0
# 472     5.0
# 473     6.0
# 474     4.0
# 475    32.0
# Name: sales, Length: 476, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       2961000.0
# 1      26640000.0
# 2       1396000.0
# 3       4485000.0
# 4        239000.0
#           ...
# 471      740000.0
# 472     1485000.0
# 473      786000.0
# 474      300000.0
# 475     3168000.0
# Name: revenue, Length: 476, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chanvay: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số chanvay:  1496715896.0
# So mat hang da ban:  476
# So san pham da ban:  9001.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Chân Váy Nữ Công Sở New Design Thiết Kế Dáng V...  329000
# 1    Chân Váy Công Sở New Design Thiết Kế Dáng Váy ...  333000
# 2    Chân váy công sở dáng đuôi cá, Lưng cao, Ôm bo...  349000
# 3    Chân váy công sở NEW DESIGN dáng midi dài qua ...  299000
# 4        Chân váy lụa dài dáng đuôi cá cạp trễ cao cấp  239000
# ..                                                 ...     ...
# 471                     Chân váy voan xếp ly dễ thương  148000
# 472  CHÂN VÁY BÒ KIỂUQUẦN VÁY JEAN VẠT LỆCH SANG CHẢNH  297000
# 473      Chân váy bút chì dáng dài Haint Boutique Cv13  131000
# 474                          CHÂN VÁY XÒE LADY FASHION   75000
# 475     Chân váy ôm xếp pilly – MS0305CV ( có lớp lót)   99000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=Fc829pVF_...     -37%    9.0
# 1    https://tka.tiki.vn/pixel/pixel?data=b1t-fksuC...     -31%   80.0
# 2    https://tka.tiki.vn/pixel/pixel?data=c3JaIGVm5...     -37%    4.0
# 3    https://tka.tiki.vn/pixel/pixel?data=hSzhBFnm8...     -49%   15.0
# 4    https://tka.tiki.vn/pixel/pixel?data=ARx7t6JDN...     -47%    1.0
# ..                                                 ...      ...    ...
# 471  https://tiki.vn/chan-vay-voan-xep-ly-de-thuong...      NaN    5.0
# 472  https://tiki.vn/chan-vay-bo-kieu-quan-vay-jean...      NaN    5.0
# 473  https://tiki.vn/chan-vay-but-chi-dang-dai-hain...      NaN    6.0
# 474  https://tiki.vn/chan-vay-xoe-lady-fashion-p213...      NaN    4.0
# 475  https://tiki.vn/chan-vay-om-xep-pilly-ms0305cv...      NaN   32.0
#
#     category     revenue
# 0    chanvay   2961000.0
# 1    chanvay  26640000.0
# 2    chanvay   1396000.0
# 3    chanvay   4485000.0
# 4    chanvay    239000.0
# ..       ...         ...
# 471  chanvay    740000.0
# 472  chanvay   1485000.0
# 473  chanvay    786000.0
# 474  chanvay    300000.0
# 475  chanvay   3168000.0
#
# [476 rows x 7 columns]

# %%
df_all.to_csv("tk_chanvay_all_ed.csv")
