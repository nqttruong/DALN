# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\thoitrangnu\quannu"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_quannu.csv',
#  'tk_quannu_all.ipynb',
#  'tk_ttn_qn.ipynb',
#  'tk_ttn_qn_npage.ipynb',
#  'tk_ttn_qn_t10.csv',
#  'tk_ttn_qn_t11.csv',
#  'tk_ttn_qn_t12.csv',
#  'tk_ttn_qn_t13.csv',
#  'tk_ttn_qn_t14.csv',
#  'tk_ttn_qn_t15.csv',
#  'tk_ttn_qn_t16.csv',
#  'tk_ttn_qn_t17.csv',
#  'tk_ttn_qn_t18.csv',
#  'tk_ttn_qn_t19.csv',
#  'tk_ttn_qn_t2.csv',
#  'tk_ttn_qn_t20.csv',
#  'tk_ttn_qn_t21.csv',
#  'tk_ttn_qn_t22.csv',
#  'tk_ttn_qn_t23.csv',
#  'tk_ttn_qn_t24.csv',
#  'tk_ttn_qn_t25.csv',
#  'tk_ttn_qn_t26.csv',
#  'tk_ttn_qn_t27.csv',
#  'tk_ttn_qn_t28.csv',
#  'tk_ttn_qn_t29.csv',
#  'tk_ttn_qn_t3.csv',
#  'tk_ttn_qn_t30.csv',
#  'tk_ttn_qn_t31.csv',
#  'tk_ttn_qn_t32.csv',
#  'tk_ttn_qn_t33.csv',
#  'tk_ttn_qn_t34.csv',
#  'tk_ttn_qn_t35.csv',
#  'tk_ttn_qn_t36.csv',
#  'tk_ttn_qn_t37.csv',
#  'tk_ttn_qn_t38.csv',
#  'tk_ttn_qn_t39.csv',
#  'tk_ttn_qn_t4.csv',
#  'tk_ttn_qn_t40.csv',
#  'tk_ttn_qn_t41.csv',
#  'tk_ttn_qn_t42.csv',
#  'tk_ttn_qn_t43.csv',
#  'tk_ttn_qn_t44.csv',
#  'tk_ttn_qn_t45.csv',
#  'tk_ttn_qn_t46.csv',
#  'tk_ttn_qn_t47.csv',
#  'tk_ttn_qn_t48.csv',
#  'tk_ttn_qn_t49.csv',
#  'tk_ttn_qn_t5.csv',
#  'tk_ttn_qn_t50.csv',
#  'tk_ttn_qn_t6.csv',
#  'tk_ttn_qn_t7.csv',
#  'tk_ttn_qn_t8.csv',
#  'tk_ttn_qn_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_quannu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Quần short kaki nữ GOKING, lưng thun và dây rú...  185.000₫
# 1   Quần Lengging Lửng Nữ Chất Thun Co Dãn 4 Chiều...   45.000₫
# 2   Quần Legging nâng mông gen bụng chất su đúc fu...  180.000₫
# 3   Quần tây nữ Amazing ống đứng, màu xanh và đen,...  225.000₫
# 4   Quần tây nữ màu Xanh đen lưng vừa, dáng suông,...  225.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Quần Jean Nữ, Quần Jean Nữ Lưng Cao, Quần Jean...  159.000₫
# 37  Quần Jeans Nữ, Quần Bò Nữ Ống Rộng Dài...  298.000₫
# 38  Quần nữ legging kiểu dáng lửng, cuận tròn.mầu tím   39.750₫
# 39  Quần đùi jean nữ BIGSIZE có size 26-44. Vải dà...   146.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=rksbSukml...      1     -32%
# 1   https://tka.tiki.vn/pixel/pixel?data=7dYUOVlyZ...      2     -32%
# 2   https://tka.tiki.vn/pixel/pixel?data=WzmDDr_Tp...      3     -50%
# 3   https://tka.tiki.vn/pixel/pixel?data
rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      185000
# 1       45000
# 2      180000
# 3      225000
# 4       39500
#         ...
# 815     58000
# 816    119000
# 817    159000
# 818    298000
# 819    146000
# Name: price, Length: 820, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      266.0
# 1      263.0
# 2        4.0
# 3       21.0
# 4      236.0
#        ...
# 815    111.0
# 816     15.0
# 817     48.0
# 818     41.0
# 819      1.0
# Name: sales, Length: 820, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      49210000.0
# 1      11835000.0
# 2        720000.0
# 3       4725000.0
# 4       9322000.0
#           ...
# 815     6438000.0
# 816     1785000.0
# 817     7632000.0
# 818    12218000.0
# 819      146000.0
# Name: revenue, Length: 820, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số quannu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số quannu:  2907941918.0
# So mat hang da ban:  820
# So san pham da ban:  23660.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Quần short kaki nữ GOKING, lưng thun và dây rú...  185000
# 1    Quần Lengging Lửng Nữ Chất Thun Co Dãn 4 Chiều...   45000
# 2    Quần Legging nâng mông gen bụng chất su đúc fu...  180000
# 3    Quần tây nữ Amazing ống đứng, màu xanh và đen,...  225000
# 4    Quần Đùi Nữ Mặc Nhà Chất vải Lụa Hàn Quốc ,Mịn...   39500
# ..                                                 ...     ...
# 815      Quần ống rộng lửng vải đũi cạp khoá may chuẩn   58000
# 816  Quần nữ ống rộng chất liệu đủi , phôm rộng rủ ...  119000
# 817  Quần Jean Nữ, Quần Jean Nữ Lưng Cao, Quần Jean...  159000
# 818  Quần Jeans Nữ, Quần Bò Nữ Ống Rộng Dài...  298000
# 819  Quần đùi jean nữ BIGSIZE có size 26-44. Vải dà...  146000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=rksbSukml...     -32%  266.0
# 1    https://tka.tiki.vn/pixel/pixel?data=7dYUOVlyZ...     -32%  263.0
# 2    https://tka.tiki.vn/pixel/pixel?data=WzmDDr_Tp...     -50%    4.0
# 3    https://tka.tiki.vn/pixel/pixel?data=EJEAMtGjP...     -21%   21.0
# 4    https://tiki.vn/quan-dui-nu-mac-nha-quan-dui-n...     -44%  236.0
# ..                                                 ...      ...    ...
# 815  https://tiki.vn/quan-ong-rong-lung-vai-dui-cap...      NaN  111.0
# 816  https://tiki.vn/quan-nu-ong-rong-chat-lieu-dui...      NaN   15.0
# 817  https://tiki.vn/quan-jean-nu-quan-jean-nu-lung...      NaN   48.0
# 818  https://tiki.vn/qua-n-jeans-nu-qua-n-bo-nu-o-n...      NaN   41.0
# 819  https://tiki.vn/quan-dui-jean-nu-bigsize-co-si...      NaN    1.0
#
#     category     revenue
# 0     quannu  49210000.0
# 1     quannu  11835000.0
# 2     quannu    720000.0
# 3     quannu   4725000.0
# 4     quannu   9322000.0
# ..       ...         ...
# 815   quannu   6438000.0
# 816   quannu   1785000.0
# 817   quannu   7632000.0
# 818   quannu  12218000.0
# 819   quannu    146000.0
#
# [820 rows x 7 columns]

# %%
df_all.to_csv("tk_quannu_all_ed.csv")
