# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\diengiadung"
os.listdir(path)
# Out:
# ['category.ipynb',
#  'dodungnhabep',
#  'thietbigiadinh',
#  'tk_dodungnhabep_all_ed.csv',
#  'tk_thietbigiadinh_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#       Unnamed: 0.1                                              title  \
# 0              0.0  Máy Hút Bụi Lock&Lock ENV336BLK (400W) - Hàng ...
# 1              1.0  Bàn Ủi Hơi Nước Sunhouse SHD2063P (1600W) – Hà...
# 2              2.0  Máy Sấy Tóc LocknLock - Đen ENA146BLK 2000-230...
# 3              3.0  Máy hút bụi hút bụi giường nệm diệt khuẩn UV t...
# 4              4.0  Máy Hút Bụi Cầm Tay Không Dây Damas XC628 - Ch...
# ...            ...                                                ...
# 1585           NaN  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...
# 1586           NaN  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...
# 1587           NaN  Lõi lọc Karofi số 4 (Màng lọc RO) - Hàng chính...
# 1588           NaN  Máy uốn tóc tự động xoăn VIVID&VOGUE®️ VAV022B...
# 1589           NaN  Lõi lọc nước Toshiba 1686 (1686-PAC - 1686-RO ...
#
#         price                                          link_item discount  \
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df.drop(columns=['Unnamed: 0.1'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "diengiadung")

# %%
df
# Out:
#                                                   title    price  \
# 0     Máy Hút Bụi Lock&Lock ENV336BLK (400W) - Hàng ...  1499000
# 1     Bàn Ủi Hơi Nước Sunhouse SHD2063P (1600W) – Hà...   209000
# 2     Máy Sấy Tóc LocknLock - Đen ENA146BLK 2000-230...   530000
# 3     Máy hút bụi hút bụi giường nệm diệt khuẩn UV t...  1090000
# 4     Máy Hút Bụi Cầm Tay Không Dây Damas XC628 - Ch...   439000
# ...                                                 ...      ...
# 1585  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    69000
# 1586  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1600000
# 1587  Lõi lọc Karofi số 4 (Màng lọc RO) - Hàng chính...   300000
# 1588  Máy uốn tóc tự động xoăn VIVID&VOGUE®️ VAV022B...   500000
# 1589  Lõi lọc nước Toshiba 1686 (1686-PAC - 1686-RO ...   250000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=X8PI5fsMd...     -54%  3700.0
# ...

# %%
df.to_csv('tk_diengiadung_all_ed.csv', index=False, encoding='utf-8')
