# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\diengiadung\thietbigiadinh"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dgd_tbgd.ipynb',
#  'tk_dgd_tbgd_npage.ipynb',
#  'tk_thietbigiadinh.csv',
#  'tk_thietbigiadinh_all.ipynb',
#  'tk_thietbigiadinh_t10.csv',
#  'tk_thietbigiadinh_t11.csv',
#  'tk_thietbigiadinh_t12.csv',
#  'tk_thietbigiadinh_t13.csv',
#  'tk_thietbigiadinh_t14.csv',
#  'tk_thietbigiadinh_t15.csv',
#  'tk_thietbigiadinh_t16.csv',
#  'tk_thietbigiadinh_t17.csv',
#  'tk_thietbigiadinh_t18.csv',
#  'tk_thietbigiadinh_t19.csv',
#  'tk_thietbigiadinh_t2.csv',
#  'tk_thietbigiadinh_t20.csv',
#  'tk_thietbigiadinh_t21.csv',
#  'tk_thietbigiadinh_t22.csv',
#  'tk_thietbigiadinh_t23.csv',
#  'tk_thietbigiadinh_t24.csv',
#  'tk_thietbigiadinh_t25.csv',
#  'tk_thietbigiadinh_t26.csv',
#  'tk_thietbigiadinh_t27.csv',
#  'tk_thietbigiadinh_t28.csv',
#  'tk_thietbigiadinh_t29.csv',
#  'tk_thietbigiadinh_t3.csv',
#  'tk_thietbigiadinh_t30.csv',
#  'tk_thietbigiadinh_t31.csv',
#  'tk_thietbigiadinh_t32.csv',
#  'tk_thietbigiadinh_t33.csv',
#  'tk_thietbigiadinh_t34.csv',
#  'tk_thietbigiadinh_t35.csv',
#  'tk_thietbigiadinh_t36.csv',
#  'tk_thietbigiadinh_t37.csv',
#  'tk_thietbigiadinh_t38.csv',
#  'tk_thietbigiadinh_t39.csv',
#  'tk_thietbigiadinh_t4.csv',
#  'tk_thietbigiadinh_t40.csv',
#  'tk_thietbigiadinh_t41.csv',
#  'tk_thietbigiadinh_t42.csv',
#  'tk_thietbigiadinh_t43.csv',
#  'tk_thietbigiadinh_t44.csv',
#  'tk_thietbigiadinh_t45.csv',
#  'tk_thietbigiadinh_t46.csv',
#  'tk_thietbigiadinh_t47.csv',
#  'tk_thietbigiadinh_t48.csv',
#  'tk_thietbigiadinh_t49.csv',
#  'tk_thietbigiadinh_t5.csv',
#  'tk_thietbigiadinh_t50.csv',
#  'tk_thietbigiadinh_t6.csv',
#  'tk_thietbigiadinh_t7.csv',
#  'tk_thietbigiadinh_t8.csv',
#  'tk_thietbigiadinh_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_thietbigiadinh_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Máy Hút Bụi Lock&Lock ENV336BLK (400W) - Hàng ...  1.499.000₫
# 1   Bàn Ủi Hơi Nước Sunhouse SHD2063P (1600W) – Hà...    209.000₫
# 2   Máy Sấy Tóc LocknLock - Đen ENA146BLK 2000-230...    530.000₫
# 3   Máy hút bụi hút bụi giường nệm diệt khuẩn UV t...  1.090.000₫
# 4   Quạt treo tường AC 50W có remote- AWF01A163-Hà...  1.189.000₫
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1.600.000₫
# 37  Lõi lọc Karofi số 4 (Màng lọc RO) - Hàng chính...    300.000₫
# 38  Máy uốn tóc tự động xoăn VIVID&VOGUE®️ VAV022B...    500.000₫
# 39  Lõi lọc nước Toshiba 1686 (1686-PAC - 1686-RO ...    250.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=X8PI5fsMd...      1     -54%
# 1   https://tka.tiki.vn/pixel/pixel?data=TYN6A1W8l...      2     -37%
# 2   https://tka.tiki.vn/pixel/pixel?data=P-7KgHOyc...      3     -47%
# 3   https://tka.tiki.vn/pixel/pixel?data=72iRp5nfZ...      4     -45%
# 4   https://tka.tiki.vn/pixel/pixel?data=PS0kHJo8W...      5     -18%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...     36      NaN
# 36  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...     37      NaN
# 37  https://tiki.vn/loi-loc-karofi-so-4-mang-loc-r...     38      NaN
# 38  https://tiki.vn/may-uon-toc-tu-dong-xoan-vivid...     39      NaN
# 39  https://tiki.vn/loi-loc-nuoc-toshiba-1686-1686...     40      NaN
#
#           sales        category
# 0   Đã bán 3.7k  thietbigiadinh
# 1   Đã bán 3.2k  thietbigiadinh
# 2   Đã bán 3.7k  thietbigiadinh
# 3      Đã bán 6  thietbigiadinh
# 4           NaN  thietbigiadinh
# ..          ...             ...
# 35          NaN  thietbigiadinh
# 36  Đã bán 1.6k  thietbigiadinh
# 37   Đã bán 175  thietbigiadinh
# 38   Đã bán 273  thietbigiadinh
# 39    Đã bán 25  thietbigiadinh
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_all = df_all.drop('index', axis=1)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     Máy Hút Bụi Lock&Lock ENV336BLK (400W) - Hàng ...  1.499.000₫
# 1     Bàn Ủi Hơi Nước Sunhouse SHD2063P (1600W) – Hà...    209.000₫
# 2     Máy Sấy Tóc LocknLock - Đen ENA146BLK 2000-230...    530.000₫
# 3     Máy hút bụi hút bụi giường nệm diệt khuẩn UV t...  1.090.000₫
# 4     Máy Hút Bụi Cầm Tay Không Dây Damas XC628 - Ch...    439.000₫
# ...                                                 ...         ...
# 1585  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...     69.000₫
# 1586  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1.600.000₫
# 1587  Lõi lọc Karofi số 4 (Màng lọc RO) - Hàng chính...    300.000₫
# 1588  Máy uốn tóc tự động xoăn VIVID&VOGUE®️ VAV022B...    500.000₫
# 1589  Lõi lọc nước Toshiba 1686 (1686-PAC - 1686-RO ...    250.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=X8PI5fsMd...     -54%  Đã bán 3.7k
# 1     https://tka.tiki.vn/pixel/pixel?data=TYN6A1W8l...     -37%  Đã bán 3.2k
# 2     https://tka.tiki.vn/pixel/pixel?data=P-7KgHOyc...     -47%  Đã bán 3.7k
# 3     https://tka.tiki.vn/pixel/pixel?data=72iRp5nfZ...     -45%     Đã bán 6
# 4     https://tiki.vn/may-hut-bui-cam-tay-khong-day-...     -48%   Đã bán 5k+
# ...                                                 ...      ...          ...
# 1585  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    Đã bán 25
# 1586  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...      NaN  Đã bán 1.6k
# 1587  https://tiki.vn/loi-loc-karofi-so-4-mang-loc-r...      NaN   Đã bán 175
# 1588  https://tiki.vn/may-uon-toc-tu-dong-xoan-vivid...      NaN   Đã bán 273
# 1589  https://tiki.vn/loi-loc-nuoc-toshiba-1686-1686...      NaN    Đã bán 25
#
#             category
# 0     thietbigiadinh
# 1     thietbigiadinh
# 2     thietbigiadinh
# 3     thietbigiadinh
# 4     thietbigiadinh
# ...              ...
# 1585  thietbigiadinh
# 1586  thietbigiadinh
# 1587  thietbigiadinh
# 1588  thietbigiadinh
# 1589  thietbigiadinh
#
# [1590 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       1499000
# 1        209000
# 2        530000
# 3       1090000
# 4        439000
#          ...
# 1585      69000
# 1586    1600000
# 1587     300000
# 1588     500000
# 1589     250000
# Name: price, Length: 1590, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       3700.0
# 1       3200.0
# 2       3700.0
# 3          6.0
# 4       5000.0
#          ...
# 1585      25.0
# 1586    1600.0
# 1587     175.0
# 1588     273.0
# 1589      25.0
# Name: sales, Length: 1590, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       5.546300e+09
# 1       6.688000e+08
# 2       1.961000e+09
# 3       6.540000e+06
# 4       2.195000e+09
#             ...
# 1585    1.725000e+06
# 1586    2.560000e+09
# 1587    5.250000e+07
# 1588    1.365000e+08
# 1589    6.250000e+06
# Name: revenue, Length: 1590, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số thiet bi gia dinh: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số thiet bi gia dinh:  174069529246.0
# So mat hang da ban:  1590
# So san pham da ban:  253738.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Máy Hút Bụi Lock&Lock ENV336BLK (400W) - Hàng ...  1499000
# 1     Bàn Ủi Hơi Nước Sunhouse SHD2063P (1600W) – Hà...   209000
# 2     Máy Sấy Tóc LocknLock - Đen ENA146BLK 2000-230...   530000
# 3     Máy hút bụi hút bụi giường nệm diệt khuẩn UV t...  1090000
# 4     Máy Hút Bụi Cầm Tay Không Dây Damas XC628 - Ch...   439000
# ...                                                 ...      ...
# 1585  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    69000
# 1586  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1600000
# 1587  Lõi lọc Karofi số 4 (Màng lọc RO) - Hàng chính...   300000
# 1588  Máy uốn tóc tự động xoăn VIVID&VOGUE®️ VAV022B...   500000
# 1589  Lõi lọc nước Toshiba 1686 (1686-PAC - 1686-RO ...   250000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=X8PI5fsMd...     -54%  3700.0
# 1     https://tka.tiki.vn/pixel/pixel?data=TYN6A1W8l...     -37%  3200.0
# 2     https://tka.tiki.vn/pixel/pixel?data=P-7KgHOyc...     -47%  3700.0
# 3     https://tka.tiki.vn/pixel/pixel?data=72iRp5nfZ...     -45%     6.0
# 4     https://tiki.vn/may-hut-bui-cam-tay-khong-day-...     -48%  5000.0
# ...                                                 ...      ...     ...
# 1585  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1586  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...      NaN  1600.0
# 1587  https://tiki.vn/loi-loc-karofi-so-4-mang-loc-r...      NaN   175.0
# 1588  https://tiki.vn/may-uon-toc-tu-dong-xoan-vivid...      NaN   273.0
# 1589  https://tiki.vn/loi-loc-nuoc-toshiba-1686-1686...      NaN    25.0
#
#             category       revenue
# 0     thietbigiadinh  5.546300e+09
# 1     thietbigiadinh  6.688000e+08
# 2     thietbigiadinh  1.961000e+09
# 3     thietbigiadinh  6.540000e+06
# 4     thietbigiadinh  2.195000e+09
# ...              ...           ...
# 1585  thietbigiadinh  1.725000e+06
# 1586  thietbigiadinh  2.560000e+09
# 1587  thietbigiadinh  5.250000e+07
# 1588  thietbigiadinh  1.365000e+08
# 1589  thietbigiadinh  6.250000e+06
#
# [1590 rows x 7 columns]

# %%
df_all.to_csv("tk_thietbigiadinh_all_ed.csv")
