# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\dochoi_mevabe\dodungchobe"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dodungchobe.csv',
#  'tk_dodungchobe_all.ipynb',
#  'tk_dodungchobe_t10.csv',
#  'tk_dodungchobe_t11.csv',
#  'tk_dodungchobe_t12.csv',
#  'tk_dodungchobe_t13.csv',
#  'tk_dodungchobe_t14.csv',
#  'tk_dodungchobe_t15.csv',
#  'tk_dodungchobe_t16.csv',
#  'tk_dodungchobe_t17.csv',
#  'tk_dodungchobe_t18.csv',
#  'tk_dodungchobe_t19.csv',
#  'tk_dodungchobe_t2.csv',
#  'tk_dodungchobe_t20.csv',
#  'tk_dodungchobe_t21.csv',
#  'tk_dodungchobe_t22.csv',
#  'tk_dodungchobe_t23.csv',
#  'tk_dodungchobe_t24.csv',
#  'tk_dodungchobe_t25.csv',
#  'tk_dodungchobe_t26.csv',
#  'tk_dodungchobe_t27.csv',
#  'tk_dodungchobe_t28.csv',
#  'tk_dodungchobe_t29.csv',
#  'tk_dodungchobe_t3.csv',
#  'tk_dodungchobe_t30.csv',
#  'tk_dodungchobe_t31.csv',
#  'tk_dodungchobe_t32.csv',
#  'tk_dodungchobe_t33.csv',
#  'tk_dodungchobe_t34.csv',
#  'tk_dodungchobe_t35.csv',
#  'tk_dodungchobe_t36.csv',
#  'tk_dodungchobe_t37.csv',
#  'tk_dodungchobe_t38.csv',
#  'tk_dodungchobe_t39.csv',
#  'tk_dodungchobe_t4.csv',
#  'tk_dodungchobe_t40.csv',
#  'tk_dodungchobe_t41.csv',
#  'tk_dodungchobe_t42.csv',
#  'tk_dodungchobe_t43.csv',
#  'tk_dodungchobe_t44.csv',
#  'tk_dodungchobe_t45.csv',
#  'tk_dodungchobe_t46.csv',
#  'tk_dodungchobe_t47.csv',
#  'tk_dodungchobe_t48.csv',
#  'tk_dodungchobe_t49.csv',
#  'tk_dodungchobe_t5.csv',
#  'tk_dodungchobe_t50.csv',
#  'tk_dodungchobe_t6.csv',
#  'tk_dodungchobe_t7.csv',
#  'tk_dodungchobe_t8.csv',
#  'tk_dodungchobe_t9.csv',
#  'tk_mvb_dodungchobe.ipynb',
#  'tk_mvb_dodungchobe_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dodungchobe_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Bộ 2 Chai Sữa Tắm Gội Toàn Thân Cho Bé Johnson...  245.000₫
# 1   Nước Tắm Gội Thảo Dược Dr.Papie Cho Bé Giúp Ng...  135.000₫
# 2   Dung dịch súc rửa bình sữa & phụ kiện Pigeon 5...  102.000₫
# 3   Nước Tắm Bé Bảo Linh,chiết xuất thảo dược,dùng...  225.000₫
# 4    Bình sữa Pigeon PPSU Plus thế hệ III 160ml/240ml  398.000₫
# ..                                                ...       ...
# 35  Tấm lót chống thấm cho bé dùng được 2 mặt. Miế...  139.000₫
# 36  Bệt vệ sinh thu nhỏ có bé từ 18 tháng đến 3 4 ...  169.000₫
# 37  [Made in Thailand] Dung Dịch Giặt Quần Áo Cho ...  199.000₫
# 38                     DẦU TRÀM CUNG ĐÌNH SILVER 30ml   62.000₫
# 39  Bình sữa Pigeon T-Ester Plus Giọt sương 200ml/...  221.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=jGalSy_Oa...      1     -21%
# 1   https://tka.tiki.vn/pixel/pixel?data=z30vTO_FR...      2     -25%
# 2   https://tka.tiki.vn/pixel/pixel?data=QF_SRDL62...      3     -10%
# 3   https://tka.tiki.vn/pixel/pixel?data=ihGeapUwD...      4      -4%
# 4   https://tka.tiki.vn/pixel/pixel?data=bUkv4w1_i...      5     -18%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/tam-lot-chong-tham-cho-be-dung...     36      NaN
# 36  https://tiki.vn/bet-ve-sinh-thu-nho-co-be-tu-1...     37      NaN
# 37  https://tiki.vn/made-in-thailand-dung-dich-gia...     38      NaN
# 38  https://tiki.vn/dau-tram-cung-dinh-silver-30ml...     39      NaN
# 39  https://tiki.vn/binh-sua-pigeon-t-ester-plus-g...     40      NaN
#
#          sales     category
# 0   Đã bán 5k+  dodungchobe
# 1   Đã bán 104  dodungchobe
# 2   Đã bán 173  dodungchobe
# 3     Đã bán 7  dodungchobe
# 4    Đã bán 90  dodungchobe
# ..         ...          ...
# 35  Đã bán 944  dodungchobe
# 36   Đã bán 44  dodungchobe
# 37  Đã bán 5k+  dodungchobe
# 38  Đã bán 151  dodungchobe
# 39   Đã bán 54  dodungchobe
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Bộ 2 Chai Sữa Tắm Gội Toàn Thân Cho Bé Johnson...  245.000₫
# 1     Nước Tắm Gội Thảo Dược Dr.Papie Cho Bé Giúp Ng...  135.000₫
# 2     Dung dịch súc rửa bình sữa & phụ kiện Pigeon 5...  102.000₫
# 3     Nước Tắm Bé Bảo Linh,chiết xuất thảo dược,dùng...  225.000₫
# 4      Bình sữa Pigeon PPSU Plus thế hệ III 160ml/240ml  398.000₫
# ...                                                 ...       ...
# 1804  Tấm lót chống thấm cho bé dùng được 2 mặt. Miế...  139.000₫
# 1805  Bệt vệ sinh thu nhỏ có bé từ 18 tháng đến 3 4 ...  169.000₫
# 1806  [Made in Thailand] Dung Dịch Giặt Quần Áo Cho ...  199.000₫
# 1807                     DẦU TRÀM CUNG ĐÌNH SILVER 30ml   62.000₫
# 1808  Bình sữa Pigeon T-Ester Plus Giọt sương 200ml/...  221.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=jGalSy_Oa...     -21%  Đã bán 5k+
# 1     https://tka.tiki.vn/pixel/pixel?data=z30vTO_FR...     -25%  Đã bán 104
# 2     https://tka.tiki.vn/pixel/pixel?data=QF_SRDL62...     -10%  Đã bán 173
# 3     https://tka.tiki.vn/pixel/pixel?data=ihGeapUwD...      -4%    Đã bán 7
# 4     https://tka.tiki.vn/pixel/pixel?data=bUkv4w1_i...     -18%   Đã bán 90
# ...                                                 ...      ...         ...
# 1804  https://tiki.vn/tam-lot-chong-tham-cho-be-dung...      NaN  Đã bán 944
# 1805  https://tiki.vn/bet-ve-sinh-thu-nho-co-be-tu-1...      NaN   Đã bán 44
# 1806  https://tiki.vn/made-in-thailand-dung-dich-gia...      NaN  Đã bán 5k+
# 1807  https://tiki.vn/dau-tram-cung-dinh-silver-30ml...      NaN  Đã bán 151
# 1808  https://tiki.vn/binh-sua-pigeon-t-ester-plus-g...      NaN   Đã bán 54
#
#          category
# 0     dodungchobe
# 1     dodungchobe
# 2     dodungchobe
# 3     dodungchobe
# 4     dodungchobe
# ...           ...
# 1804  dodungchobe
# 1805  dodungchobe
# 1806  dodungchobe
# 1807  dodungchobe
# 1808  dodungchobe
#
# [1809 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       245000
# 1       135000
# 2       102000
# 3       225000
# 4       398000
#          ...
# 1804    139000
# 1805    169000
# 1806    199000
# 1807     62000
# 1808    221000
# Name: price, Length: 1809, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       5000.0
# 1        104.0
# 2        173.0
# 3          7.0
# 4         90.0
#          ...
# 1804     944.0
# 1805      44.0
# 1806    5000.0
# 1807     151.0
# 1808      54.0
# Name: sales, Length: 1809, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1.225000e+09
# 1       1.404000e+07
# 2       1.764600e+07
# 3       1.575000e+06
# 4       3.582000e+07
#             ...
# 1804    1.312160e+08
# 1805    7.436000e+06
# 1806    9.950000e+08
# 1807    9.362000e+06
# 1808    1.193400e+07
# Name: revenue, Length: 1809, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dodungchobe: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dodungchobe:  47243530432.0
# So mat hang da ban:  1809
# So san pham da ban:  203247.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Bộ 2 Chai Sữa Tắm Gội Toàn Thân Cho Bé Johnson...  245000
# 1     Nước Tắm Gội Thảo Dược Dr.Papie Cho Bé Giúp Ng...  135000
# 2     Dung dịch súc rửa bình sữa & phụ kiện Pigeon 5...  102000
# 3     Nước Tắm Bé Bảo Linh,chiết xuất thảo dược,dùng...  225000
# 4      Bình sữa Pigeon PPSU Plus thế hệ III 160ml/240ml  398000
# ...                                                 ...     ...
# 1804  Tấm lót chống thấm cho bé dùng được 2 mặt. Miế...  139000
# 1805  Bệt vệ sinh thu nhỏ có bé từ 18 tháng đến 3 4 ...  169000
# 1806  [Made in Thailand] Dung Dịch Giặt Quần Áo Cho ...  199000
# 1807                     DẦU TRÀM CUNG ĐÌNH SILVER 30ml   62000
# 1808  Bình sữa Pigeon T-Ester Plus Giọt sương 200ml/...  221000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=jGalSy_Oa...     -21%  5000.0
# 1     https://tka.tiki.vn/pixel/pixel?data=z30vTO_FR...     -25%   104.0
# 2     https://tka.tiki.vn/pixel/pixel?data=QF_SRDL62...     -10%   173.0
# 3     https://tka.tiki.vn/pixel/pixel?data=ihGeapUwD...      -4%     7.0
# 4     https://tka.tiki.vn/pixel/pixel?data=bUkv4w1_i...     -18%    90.0
# ...                                                 ...      ...     ...
# 1804  https://tiki.vn/tam-lot-chong-tham-cho-be-dung...      NaN   944.0
# 1805  https://tiki.vn/bet-ve-sinh-thu-nho-co-be-tu-1...      NaN    44.0
# 1806  https://tiki.vn/made-in-thailand-dung-dich-gia...      NaN  5000.0
# 1807  https://tiki.vn/dau-tram-cung-dinh-silver-30ml...      NaN   151.0
# 1808  https://tiki.vn/binh-sua-pigeon-t-ester-plus-g...      NaN    54.0
#
#          category       revenue
# 0     dodungchobe  1.225000e+09
# 1     dodungchobe  1.404000e+07
# 2     dodungchobe  1.764600e+07
# 3     dodungchobe  1.575000e+06
# 4     dodungchobe  3.582000e+07
# ...           ...           ...
# 1804  dodungchobe  1.312160e+08
# 1805  dodungchobe  7.436000e+06
# 1806  dodungchobe  9.950000e+08
# 1807  dodungchobe  9.362000e+06
# 1808  dodungchobe  1.193400e+07
#
# [1809 rows x 7 columns]

# %%
df_all.to_csv("tk_dodungchobe_all_ed.csv")
