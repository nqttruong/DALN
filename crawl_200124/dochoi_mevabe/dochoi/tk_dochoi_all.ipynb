# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\dochoi_mevabe\dochoi"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dochoi.csv',
#  'tk_dochoi_all.ipynb',
#  'tk_dochoi_t10.csv',
#  'tk_dochoi_t11.csv',
#  'tk_dochoi_t12.csv',
#  'tk_dochoi_t13.csv',
#  'tk_dochoi_t14.csv',
#  'tk_dochoi_t15.csv',
#  'tk_dochoi_t16.csv',
#  'tk_dochoi_t17.csv',
#  'tk_dochoi_t18.csv',
#  'tk_dochoi_t19.csv',
#  'tk_dochoi_t2.csv',
#  'tk_dochoi_t20.csv',
#  'tk_dochoi_t21.csv',
#  'tk_dochoi_t22.csv',
#  'tk_dochoi_t23.csv',
#  'tk_dochoi_t24.csv',
#  'tk_dochoi_t25.csv',
#  'tk_dochoi_t26.csv',
#  'tk_dochoi_t27.csv',
#  'tk_dochoi_t28.csv',
#  'tk_dochoi_t29.csv',
#  'tk_dochoi_t3.csv',
#  'tk_dochoi_t30.csv',
#  'tk_dochoi_t31.csv',
#  'tk_dochoi_t32.csv',
#  'tk_dochoi_t33.csv',
#  'tk_dochoi_t34.csv',
#  'tk_dochoi_t35.csv',
#  'tk_dochoi_t36.csv',
#  'tk_dochoi_t37.csv',
#  'tk_dochoi_t38.csv',
#  'tk_dochoi_t39.csv',
#  'tk_dochoi_t4.csv',
#  'tk_dochoi_t40.csv',
#  'tk_dochoi_t41.csv',
#  'tk_dochoi_t42.csv',
#  'tk_dochoi_t43.csv',
#  'tk_dochoi_t44.csv',
#  'tk_dochoi_t45.csv',
#  'tk_dochoi_t46.csv',
#  'tk_dochoi_t47.csv',
#  'tk_dochoi_t48.csv',
#  'tk_dochoi_t49.csv',
#  'tk_dochoi_t5.csv',
#  'tk_dochoi_t50.csv',
#  'tk_dochoi_t6.csv',
#  'tk_dochoi_t7.csv',
#  'tk_dochoi_t8.csv',
#  'tk_dochoi_t9.csv',
#  'tk_mvb_dochoi.ipynb',
#  'tk_mvb_dochoi_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dochoi_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Xe scooter trẻ em Scoot and Ride Highwaykick 1...  1.805.000₫
# 1   Xe scooter trẻ em Scoot and Ride Highwaykick 1...  2.200.000₫
# 2   Xe scooter trẻ em Scoot and Ride Highwaykick 3...  1.805.000₫
# 3   Xe scooter trẻ em Scoot and Ride Highwaykick 3...  1.805.000₫
# 4   Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...    248.000₫
# ..                                                ...         ...
# 35  Mô hình Gundam Gunpla HG 6601,6602 Wing Zero H...    189.000₫
# 36  04 bộ tranh xếp hình 35 mảnh khổ A4 20x30cm – ...     75.000₫
# 37  ĐỒ CHƠI TÀU HOẢ ÔNG GIÀ NOEL CHẠY TRÊN ĐƯỜNG R...    195.000₫
# 38  Combo 4 Rubik Biến Thể QiYi Gift Box Mastermor...    204.000₫
# 39  Gấu Bông Gối Ôm Thú Bông, Nhồi Bông Hình Ly Tr...    129.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=BYjoHwZ3E...      1     -18%
# 1   https://tka.tiki.vn/pixel/pixel?data=ngpq931BA...      2     -18%
# 2   https://tka.tiki.vn/pixel/pixel?data=DFSxfe9ba...      3     -18%
# 3   https://tka.tiki.vn/pixel/pixel?data=RaFd0C-TP...      4     -10%
# 4   https://tka.tiki.vn/pixel/pixel?data=fCEwGtOt1...      5      -6%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/mo-hinh-gundam-gunpla-hg-6601-...     36      NaN
# 36  https://tiki.vn/04-bo-tranh-xep-hinh-35-manh-k...     37      NaN
# 37  https://tiki.vn/do-choi-tau-hoa-ong-gia-noel-c...     38      NaN
# 38  https://tiki.vn/combo-4-rubik-bien-the-qiyi-gi...     39      NaN
# 39  https://tiki.vn/gau-bong-goi-om-thu-bong-nhoi-...     40      NaN
#
#          sales category
# 0     Đã bán 1   dochoi
# 1          NaN   dochoi
# 2          NaN   dochoi
# 3          NaN   dochoi
# 4   Đã bán 533   dochoi
# ..         ...      ...
# 35    Đã bán 2   dochoi
# 36   Đã bán 46   dochoi
# 37   Đã bán 31   dochoi
# 38    Đã bán 6   dochoi
# 39   Đã bán 46   dochoi
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     Xe scooter trẻ em Scoot and Ride Highwaykick 1...  1.805.000₫
# 1     Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...    248.000₫
# 2                  Xe chòi ô tô cho bé - màu xanh dương    189.000₫
# 3     Xe Chòi Chân Vận Động Kiêm Xe Đạp 3 Bánh Cho B...    189.000₫
# 4     Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...    248.000₫
# ...                                                 ...         ...
# 1978  Mô hình Gundam Gunpla HG 6601,6602 Wing Zero H...    189.000₫
# 1979  04 bộ tranh xếp hình 35 mảnh khổ A4 20x30cm – ...     75.000₫
# 1980  ĐỒ CHƠI TÀU HOẢ ÔNG GIÀ NOEL CHẠY TRÊN ĐƯỜNG R...    195.000₫
# 1981  Combo 4 Rubik Biến Thể QiYi Gift Box Mastermor...    204.000₫
# 1982  Gấu Bông Gối Ôm Thú Bông, Nhồi Bông Hình Ly Tr...    129.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=BYjoHwZ3E...     -18%    Đã bán 1
# 1     https://tka.tiki.vn/pixel/pixel?data=fCEwGtOt1...      -6%  Đã bán 533
# 2     https://tiki.vn/xe-choi-o-to-cho-be-mau-xanh-d...      -5%  Đã bán 353
# 3     https://tiki.vn/xe-choi-chan-van-dong-kiem-xe-...     -10%  Đã bán 304
# 4     https://tiki.vn/xe-lac-cho-be-xe-choi-chan-tre...      -5%  Đã bán 533
# ...                                                 ...      ...         ...
# 1978  https://tiki.vn/mo-hinh-gundam-gunpla-hg-6601-...      NaN    Đã bán 2
# 1979  https://tiki.vn/04-bo-tranh-xep-hinh-35-manh-k...      NaN   Đã bán 46
# 1980  https://tiki.vn/do-choi-tau-hoa-ong-gia-noel-c...      NaN   Đã bán 31
# 1981  https://tiki.vn/combo-4-rubik-bien-the-qiyi-gi...      NaN    Đã bán 6
# 1982  https://tiki.vn/gau-bong-goi-om-thu-bong-nhoi-...      NaN   Đã bán 46
#
#      category
# 0      dochoi
# 1      dochoi
# 2      dochoi
# 3      dochoi
# 4      dochoi
# ...       ...
# 1978   dochoi
# 1979   dochoi
# 1980   dochoi
# 1981   dochoi
# 1982   dochoi
#
# [1983 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       1805000
# 1        248000
# 2        189000
# 3        189000
# 4        248000
#          ...
# 1978     189000
# 1979      75000
# 1980     195000
# 1981     204000
# 1982     129000
# Name: price, Length: 1983, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0         1.0
# 1       533.0
# 2       353.0
# 3       304.0
# 4       533.0
#         ...
# 1978      2.0
# 1979     46.0
# 1980     31.0
# 1981      6.0
# 1982     46.0
# Name: sales, Length: 1983, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0         1805000.0
# 1       132184000.0
# 2        66717000.0
# 3        57456000.0
# 4       132184000.0
#            ...
# 1978       378000.0
# 1979      3450000.0
# 1980      6045000.0
# 1981      1224000.0
# 1982      5934000.0
# Name: revenue, Length: 1983, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dochoi: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dochoi:  25193503869.0
# So mat hang da ban:  1983
# So san pham da ban:  146837.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Xe scooter trẻ em Scoot and Ride Highwaykick 1...  1805000
# 1     Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...   248000
# 2                  Xe chòi ô tô cho bé - màu xanh dương   189000
# 3     Xe Chòi Chân Vận Động Kiêm Xe Đạp 3 Bánh Cho B...   189000
# 4     Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...   248000
# ...                                                 ...      ...
# 1978  Mô hình Gundam Gunpla HG 6601,6602 Wing Zero H...   189000
# 1979  04 bộ tranh xếp hình 35 mảnh khổ A4 20x30cm – ...    75000
# 1980  ĐỒ CHƠI TÀU HOẢ ÔNG GIÀ NOEL CHẠY TRÊN ĐƯỜNG R...   195000
# 1981  Combo 4 Rubik Biến Thể QiYi Gift Box Mastermor...   204000
# 1982  Gấu Bông Gối Ôm Thú Bông, Nhồi Bông Hình Ly Tr...   129000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=BYjoHwZ3E...     -18%    1.0
# 1     https://tka.tiki.vn/pixel/pixel?data=fCEwGtOt1...      -6%  533.0
# 2     https://tiki.vn/xe-choi-o-to-cho-be-mau-xanh-d...      -5%  353.0
# 3     https://tiki.vn/xe-choi-chan-van-dong-kiem-xe-...     -10%  304.0
# 4     https://tiki.vn/xe-lac-cho-be-xe-choi-chan-tre...      -5%  533.0
# ...                                                 ...      ...    ...
# 1978  https://tiki.vn/mo-hinh-gundam-gunpla-hg-6601-...      NaN    2.0
# 1979  https://tiki.vn/04-bo-tranh-xep-hinh-35-manh-k...      NaN   46.0
# 1980  https://tiki.vn/do-choi-tau-hoa-ong-gia-noel-c...      NaN   31.0
# 1981  https://tiki.vn/combo-4-rubik-bien-the-qiyi-gi...      NaN    6.0
# 1982  https://tiki.vn/gau-bong-goi-om-thu-bong-nhoi-...      NaN   46.0
#
#      category      revenue
# 0      dochoi    1805000.0
# 1      dochoi  132184000.0
# 2      dochoi   66717000.0
# 3      dochoi   57456000.0
# 4      dochoi  132184000.0
# ...       ...          ...
# 1978   dochoi     378000.0
# 1979   dochoi    3450000.0
# 1980   dochoi    6045000.0
# 1981   dochoi    1224000.0
# 1982   dochoi    5934000.0
#
# [1983 rows x 7 columns]

# %%
df_all.to_csv("tk_dochoi_all_ed.csv")
