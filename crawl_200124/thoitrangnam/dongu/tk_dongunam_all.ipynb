# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\thoitrangnam\dongu"
os.listdir(path)
# Out:
# ['tk_dongunam.csv',
#  'tk_dongunam.ipynb',
#  'tk_dongunam_all.ipynb',
#  'tk_dongu_all.csv',
#  'tk_ttn_dongunam_t10.csv',
#  'tk_ttn_dongunam_t11.csv',
#  'tk_ttn_dongunam_t12.csv',
#  'tk_ttn_dongunam_t13.csv',
#  'tk_ttn_dongunam_t14.csv',
#  'tk_ttn_dongunam_t15.csv',
#  'tk_ttn_dongunam_t16.csv',
#  'tk_ttn_dongunam_t17.csv',
#  'tk_ttn_dongunam_t18.csv',
#  'tk_ttn_dongunam_t19.csv',
#  'tk_ttn_dongunam_t2.csv',
#  'tk_ttn_dongunam_t20.csv',
#  'tk_ttn_dongunam_t21.csv',
#  'tk_ttn_dongunam_t22.csv',
#  'tk_ttn_dongunam_t23.csv',
#  'tk_ttn_dongunam_t24.csv',
#  'tk_ttn_dongunam_t25.csv',
#  'tk_ttn_dongunam_t26.csv',
#  'tk_ttn_dongunam_t27.csv',
#  'tk_ttn_dongunam_t28.csv',
#  'tk_ttn_dongunam_t29.csv',
#  'tk_ttn_dongunam_t3.csv',
#  'tk_ttn_dongunam_t30.csv',
#  'tk_ttn_dongunam_t31.csv',
#  'tk_ttn_dongunam_t32.csv',
#  'tk_ttn_dongunam_t33.csv',
#  'tk_ttn_dongunam_t4.csv',
#  'tk_ttn_dongunam_t5.csv',
#  'tk_ttn_dongunam_t6.csv',
#  'tk_ttn_dongunam_t7.csv',
#  'tk_ttn_dongunam_t8.csv',
#  'tk_ttn_dongunam_t9.csv',
#  'tk_ttn_tttn_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Bộ Quần Áo Nỉ Nam 5S FASHION, Chất Cotton Mềm ...  718.000₫
# 1   Bộ Quần Áo Nỉ Nam Tay Dài 5S FASHION, Chất Liệ...  419.000₫
# 2   Bộ Quần Áo KaKi Lính Mỹ US ARMY U569 Kiểu Dáng...  836.000₫
# 3   Bộ quần áo thể thao nam FASVIN AB22501.HN chất...  419.000₫
# 4   Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...  299.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36                         Bộ quần áo thể thao nam nữ   95.000₫
# 37  đồ bộ thể thao mặc nhà, đồ bộ dạo phố chất thu...   99.000₫
# 38  Bộ nam hè BỘ ĐỒ BỘ THỂ THAO NAM THUN 4 CHIỀU C...  100.000₫
# 39  Bộ đồ pijama nam quần dài, tay ngắn QSHOP QM71...   290.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=4E7nSkc1d...      1     -42%
# 1   https://tka.tiki.vn/pixel/pixel?data=QDU8EqqZ5...      2     -54%
# 2   https://tka.tiki.vn/pixel/pixel?data=mmzK7X98u...      3     -10%
# 3   https://tka.tiki.vn/pixel/pixel?data=VavZ2MkP7...      4     -36%
# 4   https://tka.tiki.vn/pixel/pixel?data=_vOam1r0z...      5     -44%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/bo-pyjama-huongtam-phi-tay-dai...     36      NaN
# 36  https://tiki.vn/bo-quan-ao-the-thao-nam-nu-p18...     37      NaN
# 37  https://tiki.vn/do-bo-the-thao-mac-nha-do-bo-d...     38      NaN
# 38  https://tiki.vn/product-p91281686.html?spid=10...     39      NaN
# 39  https://tiki.vn/bo-do-pijama-nam-quan-dai-tay-...     40      NaN
#
#         sales  category  Unnamed: 0
# 0   Đã bán 13  dongunam         NaN
# 1    Đã bán 5  dongunam         NaN
# 2   Đã bán 12  dongunam         NaN
# 3    Đã bán 2  dongunam         NaN
# 4    Đã bán 1  dongunam         NaN
# ..        ...       ...         ...
# 35        NaN  dongunam         NaN
# 36        NaN  dongunam         NaN
# 37  Đã bán 39  dongunam         NaN
# 38   Đã bán 4  dongunam         NaN
# 39        NaN  dongunam         NaN
#
# [2638 rows x 8 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)
df_all = df_all.drop('Unnamed: 0', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Bộ Quần Áo Nỉ Nam 5S FASHION, Chất Cotton Mềm ...  718.000₫
# 1    Bộ Quần Áo Nỉ Nam Tay Dài 5S FASHION, Chất Liệ...  419.000₫
# 2    Bộ Quần Áo KaKi Lính Mỹ US ARMY U569 Kiểu Dáng...  836.000₫
# 3    Bộ quần áo thể thao nam FASVIN AB22501.HN chất...  419.000₫
# 4    Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...  299.000₫
# ..                                                 ...       ...
# 831  BỘ PIJAMA NAM | ĐỒ BỘ MẶC NHÀ NAM KHỎE KHOẮN S...  410.000₫
# 832  Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...  299.000₫
# 833  Quần Áo Lính Mỹ US ARMY Giá Rẻ - Quần Túi Hộp ...  480.000₫
# 834  đồ bộ thể thao mặc nhà, đồ bộ dạo phố chất thu...   99.000₫
# 835  Bộ nam hè BỘ ĐỒ BỘ THỂ THAO NAM THUN 4 CHIỀU C...  100.000₫
#
#                                              link_item discount      sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=4E7nSkc1d...     -42%  Đã bán 13
# 1    https://tka.tiki.vn/pixel/pixel?data=QDU8EqqZ5...     -54%   Đã bán 5
# 2    https://tka.tiki.vn/pixel/pixel?data=mmzK7X98u...     -10%  Đã bán 12
# 3    https://tka.tiki.vn/pixel/pixel?data=VavZ2MkP7...     -36%   Đã bán 2
# 4    https://tka.tiki.vn/pixel/pixel?data=_vOam1r0z...     -44%   Đã bán 1
# ..                                                 ...      ...        ...
# 831  https://tiki.vn/bo-pijama-nam-do-bo-mac-nha-na...      NaN   Đã bán 3
# 832  https://tiki.vn/bo-quan-ao-the-thao-nam-fasvin...      NaN   Đã bán 1
# 833  https://tiki.vn/quan-ao-linh-my-us-army-gia-re...      NaN   Đã bán 6
# 834  https://tiki.vn/do-bo-the-thao-mac-nha-do-bo-d...      NaN  Đã bán 39
# 835  https://tiki.vn/product-p91281686.html?spid=10...      NaN   Đã bán 4
#
#      category
# 0    dongunam
# 1    dongunam
# 2    dongunam
# 3    dongunam
# 4    dongunam
# ..        ...
# 831  dongunam
# 832  dongunam
# 833  dongunam
# 834  dongunam
# 835  dongunam
#
# [836 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      718000
# 1      419000
# 2      836000
# 3      419000
# 4      299000
#         ...
# 831    410000
# 832    299000
# 833    480000
# 834     99000
# 835    100000
# Name: price, Length: 836, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      13.0
# 1       5.0
# 2      12.0
# 3       2.0
# 4       1.0
#        ...
# 831     3.0
# 832     1.0
# 833     6.0
# 834    39.0
# 835     4.0
# Name: sales, Length: 836, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       9334000.0
# 1       2095000.0
# 2      10032000.0
# 3        838000.0
# 4        299000.0
#           ...
# 831     1230000.0
# 832      299000.0
# 833     2880000.0
# 834     3861000.0
# 835      400000.0
# Name: revenue, Length: 836, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dongu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dongu:  2741080912.0
# So mat hang da ban:  836
# So san pham da ban:  14332.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Bộ Quần Áo Nỉ Nam 5S FASHION, Chất Cotton Mềm ...  718000
# 1    Bộ Quần Áo Nỉ Nam Tay Dài 5S FASHION, Chất Liệ...  419000
# 2    Bộ Quần Áo KaKi Lính Mỹ US ARMY U569 Kiểu Dáng...  836000
# 3    Bộ quần áo thể thao nam FASVIN AB22501.HN chất...  419000
# 4    Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...  299000
# ..                                                 ...     ...
# 831  BỘ PIJAMA NAM | ĐỒ BỘ MẶC NHÀ NAM KHỎE KHOẮN S...  410000
# 832  Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...  299000
# 833  Quần Áo Lính Mỹ US ARMY Giá Rẻ - Quần Túi Hộp ...  480000
# 834  đồ bộ thể thao mặc nhà, đồ bộ dạo phố chất thu...   99000
# 835  Bộ nam hè BỘ ĐỒ BỘ THỂ THAO NAM THUN 4 CHIỀU C...  100000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=4E7nSkc1d...     -42%   13.0
# 1    https://tka.tiki.vn/pixel/pixel?data=QDU8EqqZ5...     -54%    5.0
# 2    https://tka.tiki.vn/pixel/pixel?data=mmzK7X98u...     -10%   12.0
# 3    https://tka.tiki.vn/pixel/pixel?data=VavZ2MkP7...     -36%    2.0
# 4    https://tka.tiki.vn/pixel/pixel?data=_vOam1r0z...     -44%    1.0
# ..                                                 ...      ...    ...
# 831  https://tiki.vn/bo-pijama-nam-do-bo-mac-nha-na...      NaN    3.0
# 832  https://tiki.vn/bo-quan-ao-the-thao-nam-fasvin...      NaN    1.0
# 833  https://tiki.vn/quan-ao-linh-my-us-army-gia-re...      NaN    6.0
# 834  https://tiki.vn/do-bo-the-thao-mac-nha-do-bo-d...      NaN   39.0
# 835  https://tiki.vn/product-p91281686.html?spid=10...      NaN    4.0
#
#      category     revenue
# 0    dongunam   9334000.0
# 1    dongunam   2095000.0
# 2    dongunam  10032000.0
# 3    dongunam    838000.0
# 4    dongunam    299000.0
# ..        ...         ...
# 831  dongunam   1230000.0
# 832  dongunam    299000.0
# 833  dongunam   2880000.0
# 834  dongunam   3861000.0
# 835  dongunam    400000.0
#
# [836 rows x 7 columns]

# %%
df_all.to_csv("tk_dongunam_all_ed.csv")
