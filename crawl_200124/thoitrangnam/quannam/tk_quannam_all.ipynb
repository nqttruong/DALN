# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\thoitrangnam\quannam"
os.listdir(path)
# Out:
# ['tk_quannam.csv',
#  'tk_quannam_all.csv',
#  'tk_quannam_all.ipynb',
#  'tk_ttn_qn.ipynb',
#  'tk_ttn_qn_npage.ipynb',
#  'tk_ttn_quannam_t10.csv',
#  'tk_ttn_quannam_t11.csv',
#  'tk_ttn_quannam_t12.csv',
#  'tk_ttn_quannam_t13.csv',
#  'tk_ttn_quannam_t14.csv',
#  'tk_ttn_quannam_t15.csv',
#  'tk_ttn_quannam_t16.csv',
#  'tk_ttn_quannam_t17.csv',
#  'tk_ttn_quannam_t18.csv',
#  'tk_ttn_quannam_t19.csv',
#  'tk_ttn_quannam_t2.csv',
#  'tk_ttn_quannam_t20.csv',
#  'tk_ttn_quannam_t21.csv',
#  'tk_ttn_quannam_t22.csv',
#  'tk_ttn_quannam_t23.csv',
#  'tk_ttn_quannam_t24.csv',
#  'tk_ttn_quannam_t25.csv',
#  'tk_ttn_quannam_t26.csv',
#  'tk_ttn_quannam_t27.csv',
#  'tk_ttn_quannam_t28.csv',
#  'tk_ttn_quannam_t29.csv',
#  'tk_ttn_quannam_t3.csv',
#  'tk_ttn_quannam_t30.csv',
#  'tk_ttn_quannam_t31.csv',
#  'tk_ttn_quannam_t32.csv',
#  'tk_ttn_quannam_t33.csv',
#  'tk_ttn_quannam_t34.csv',
#  'tk_ttn_quannam_t35.csv',
#  'tk_ttn_quannam_t36.csv',
#  'tk_ttn_quannam_t37.csv',
#  'tk_ttn_quannam_t38.csv',
#  'tk_ttn_quannam_t39.csv',
#  'tk_ttn_quannam_t4.csv',
#  'tk_ttn_quannam_t40.csv',
#  'tk_ttn_quannam_t41.csv',
#  'tk_ttn_quannam_t42.csv',
#  'tk_ttn_quannam_t43.csv',
#  'tk_ttn_quannam_t44.csv',
#  'tk_ttn_quannam_t45.csv',
#  'tk_ttn_quannam_t46.csv',
#  'tk_ttn_quannam_t47.csv',
#  'tk_ttn_quannam_t48.csv',
#  'tk_ttn_quannam_t49.csv',
#  'tk_ttn_quannam_t5.csv',
#  'tk_ttn_quannam_t50.csv',
#  'tk_ttn_quannam_t6.csv',
#  'tk_ttn_quannam_t7.csv',
#  'tk_ttn_quannam_t8.csv',
#  'tk_ttn_quannam_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Quần tây nam màu xanh đen, ống đứng, không ly,...  209.000₫
# 1   Set 2 quần đùi nam, quần Short Gió nam thê...  245.000₫
# 2   Combo 2 quần đùi nam, quần Short Gió nam t...  259.000₫
# 3   Quần kaki nam ( Tặng 1 dây nịt da hàng hiệu) c...  199.000₫
# 4   Quần Short Nam Kaki Vải Mềm Mịn Lưng Thun Đai ...   82.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Bộ Đồ Nam - Bộ Nỉ Nam Thu Đông Thể Thao Chất N...  300.000₫
# 37  Quần Jean Nam màu xanh thương hiệu Julido Stor...  169.000₫
# 38  Quần Tây Nam Dáng Ôm Chất Liệu Vải Mềm Mịn Khh...   93.000₫
# 39  Viettien - Quần Jeans nam dài Regular fit Màu ...   823.200
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=mlKLHJiDG...      1     -32%
# 1   https://tka.tiki.vn/pixel/pixel?data=5YWlO2RT7...      2     -39%
# 2   https://tka.tiki.vn/pixel/pixel?data=pLprEhgvU...      3     -35%
# 3   https://tka.tiki.vn/pixel/pixel?data=HdYTQP0Cb...      4     -43%
# 4   https://tka.tiki.vn/pixel/pixel?data=JrPVd6MeT...      5     -45%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/quan-short-nam-chat-xop-to-ong...     36      NaN
# 36  https://tiki.vn/bo-do-nam-bo-ni-nam-thu-dong-t...     37      NaN
# 37  https://tiki.vn/quan-jean-nam-mau-xanh-thuong-...     38      NaN
# 38  https://tiki.vn/quan-tay-nam-dang-om-chat-lieu...     39      NaN
# 39  https://tiki.vn/viettien-quan-jeans-nam-dai-re...     40      NaN
#
#           sales category  Unnamed: 0
# 0    Đã bán 144  quannam         NaN
# 1   Đã bán 2.0k  quannam         NaN
# 2    Đã bán 707  quannam         NaN
# 3    Đã bán 102  quannam         NaN
# 4     Đã bán 53  quannam         NaN
# ..          ...      ...         ...
# 35          NaN  quannam         NaN
# 36     Đã bán 3  quannam         NaN
# 37   Đã bán 221  quannam         NaN
# 38   Đã bán 144  quannam         NaN
# 39          NaN  quannam         NaN
#
# [4060 rows x 8 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)
df_all = df_all.drop('Unnamed: 0', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Quần tây nam màu xanh đen, ống đứng, không ly,...  209.000₫
# 1     Set 2 quần đùi nam, quần Short Gió nam thê...  245.000₫
# 2     Combo 2 quần đùi nam, quần Short Gió nam t...  259.000₫
# 3     Quần kaki nam ( Tặng 1 dây nịt da hàng hiệu) c...  199.000₫
# 4     Quần Short Nam Kaki Vải Mềm Mịn Lưng Thun Đai ...   82.000₫
# ...                                                 ...       ...
# 2087  Quần Jean Nam Co Giãn Kiểu Dáng Trẻ Trung Đơn ...  169.000₫
# 2088  QUẦN JEAN NAM TRẮNG CAO CẤP - VẢI TRẮNG TINH C...  150.000₫
# 2089  Bộ Đồ Nam - Bộ Nỉ Nam Thu Đông Thể Thao Chất N...  300.000₫
# 2090  Quần Jean Nam màu xanh thương hiệu Julido Stor...  169.000₫
# 2091  Quần Tây Nam Dáng Ôm Chất Liệu Vải Mềm Mịn Khh...   93.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=mlKLHJiDG...     -32%   Đã bán 144
# 1     https://tka.tiki.vn/pixel/pixel?data=5YWlO2RT7...     -39%  Đã bán 2.0k
# 2     https://tka.tiki.vn/pixel/pixel?data=pLprEhgvU...     -35%   Đã bán 707
# 3     https://tka.tiki.vn/pixel/pixel?data=HdYTQP0Cb...     -43%   Đã bán 102
# 4     https://tka.tiki.vn/pixel/pixel?data=JrPVd6MeT...     -45%    Đã bán 53
# ...                                                 ...      ...          ...
# 2087  https://tiki.vn/quan-jean-nam-co-gian-kieu-dan...      NaN     Đã bán 5
# 2088  https://tiki.vn/quan-jean-nam-trang-cao-cap-va...      NaN     Đã bán 1
# 2089  https://tiki.vn/bo-do-nam-bo-ni-nam-thu-dong-t...      NaN     Đã bán 3
# 2090  https://tiki.vn/quan-jean-nam-mau-xanh-thuong-...      NaN   Đã bán 221
# 2091  https://tiki.vn/quan-tay-nam-dang-om-chat-lieu...      NaN   Đã bán 144
#
#      category
# 0     quannam
# 1     quannam
# 2     quannam
# 3     quannam
# 4     quannam
# ...       ...
# 2087  quannam
# 2088  quannam
# 2089  quannam
# 2090  quannam
# 2091  quannam
#
# [2092 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       209000
# 1       245000
# 2       259000
# 3       199000
# 4        82000
#          ...
# 2087    169000
# 2088    150000
# 2089    300000
# 2090    169000
# 2091     93000
# Name: price, Length: 2092, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        144.0
# 1       2000.0
# 2        707.0
# 3        102.0
# 4         53.0
#          ...
# 2087       5.0
# 2088       1.0
# 2089       3.0
# 2090     221.0
# 2091     144.0
# Name: sales, Length: 2092, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        30096000.0
# 1       490000000.0
# 2       183113000.0
# 3        20298000.0
# 4         4346000.0
#            ...
# 2087       845000.0
# 2088       150000.0
# 2089       900000.0
# 2090     37349000.0
# 2091     13392000.0
# Name: revenue, Length: 2092, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số quannam: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số quannam:  25595492816.0
# So mat hang da ban:  2092
# So san pham da ban:  168944.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Quần tây nam màu xanh đen, ống đứng, không ly,...  209000
# 1     Set 2 quần đùi nam, quần Short Gió nam thê...  245000
# 2     Combo 2 quần đùi nam, quần Short Gió nam t...  259000
# 3     Quần kaki nam ( Tặng 1 dây nịt da hàng hiệu) c...  199000
# 4     Quần Short Nam Kaki Vải Mềm Mịn Lưng Thun Đai ...   82000
# ...                                                 ...     ...
# 2087  Quần Jean Nam Co Giãn Kiểu Dáng Trẻ Trung Đơn ...  169000
# 2088  QUẦN JEAN NAM TRẮNG CAO CẤP - VẢI TRẮNG TINH C...  150000
# 2089  Bộ Đồ Nam - Bộ Nỉ Nam Thu Đông Thể Thao Chất N...  300000
# 2090  Quần Jean Nam màu xanh thương hiệu Julido Stor...  169000
# 2091  Quần Tây Nam Dáng Ôm Chất Liệu Vải Mềm Mịn Khh...   93000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=mlKLHJiDG...     -32%   144.0
# 1     https://tka.tiki.vn/pixel/pixel?data=5YWlO2RT7...     -39%  2000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=pLprEhgvU...     -35%   707.0
# 3     https://tka.tiki.vn/pixel/pixel?data=HdYTQP0Cb...     -43%   102.0
# 4     https://tka.tiki.vn/pixel/pixel?data=JrPVd6MeT...     -45%    53.0
# ...                                                 ...      ...     ...
# 2087  https://tiki.vn/quan-jean-nam-co-gian-kieu-dan...      NaN     5.0
# 2088  https://tiki.vn/quan-jean-nam-trang-cao-cap-va...      NaN     1.0
# 2089  https://tiki.vn/bo-do-nam-bo-ni-nam-thu-dong-t...      NaN     3.0
# 2090  https://tiki.vn/quan-jean-nam-mau-xanh-thuong-...      NaN   221.0
# 2091  https://tiki.vn/quan-tay-nam-dang-om-chat-lieu...      NaN   144.0
#
#      category      revenue
# 0     quannam   30096000.0
# 1     quannam  490000000.0
# 2     quannam  183113000.0
# 3     quannam   20298000.0
# 4     quannam    4346000.0
# ...       ...          ...
# 2087  quannam     845000.0
# 2088  quannam     150000.0
# 2089  quannam     900000.0
# 2090  quannam   37349000.0
# 2091  quannam   13392000.0
#
# [2092 rows x 7 columns]

# %%
df_all.to_csv("tk_quannam_all_ed.csv")
