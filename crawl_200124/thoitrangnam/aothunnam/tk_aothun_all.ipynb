# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\thoitrangnam\aothunnam"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_aothun.csv',
#  'tk_aothun_all.ipynb',
#  'tk_ttnam_aothun.ipynb',
#  'tk_ttnam_aothun_npage.ipynb',
#  'tk_ttnam_aothun_t10.csv',
#  'tk_ttnam_aothun_t11.csv',
#  'tk_ttnam_aothun_t12.csv',
#  'tk_ttnam_aothun_t13.csv',
#  'tk_ttnam_aothun_t14.csv',
#  'tk_ttnam_aothun_t15.csv',
#  'tk_ttnam_aothun_t16.csv',
#  'tk_ttnam_aothun_t17.csv',
#  'tk_ttnam_aothun_t18.csv',
#  'tk_ttnam_aothun_t19.csv',
#  'tk_ttnam_aothun_t2.csv',
#  'tk_ttnam_aothun_t20.csv',
#  'tk_ttnam_aothun_t21.csv',
#  'tk_ttnam_aothun_t22.csv',
#  'tk_ttnam_aothun_t23.csv',
#  'tk_ttnam_aothun_t24.csv',
#  'tk_ttnam_aothun_t25.csv',
#  'tk_ttnam_aothun_t26.csv',
#  'tk_ttnam_aothun_t27.csv',
#  'tk_ttnam_aothun_t28.csv',
#  'tk_ttnam_aothun_t29.csv',
#  'tk_ttnam_aothun_t3.csv',
#  'tk_ttnam_aothun_t30.csv',
#  'tk_ttnam_aothun_t31.csv',
#  'tk_ttnam_aothun_t32.csv',
#  'tk_ttnam_aothun_t33.csv',
#  'tk_ttnam_aothun_t34.csv',
#  'tk_ttnam_aothun_t35.csv',
#  'tk_ttnam_aothun_t36.csv',
#  'tk_ttnam_aothun_t37.csv',
#  'tk_ttnam_aothun_t38.csv',
#  'tk_ttnam_aothun_t39.csv',
#  'tk_ttnam_aothun_t4.csv',
#  'tk_ttnam_aothun_t40.csv',
#  'tk_ttnam_aothun_t41.csv',
#  'tk_ttnam_aothun_t42.csv',
#  'tk_ttnam_aothun_t43.csv',
#  'tk_ttnam_aothun_t44.csv',
#  'tk_ttnam_aothun_t45.csv',
#  'tk_ttnam_aothun_t46.csv',
#  'tk_ttnam_aothun_t47.csv',
#  'tk_ttnam_aothun_t48.csv',
#  'tk_ttnam_aothun_t49.csv',
#  'tk_ttnam_aothun_t5.csv',
#  'tk_ttnam_aothun_t50.csv',
#  'tk_ttnam_aothun_t6.csv',
#  'tk_ttnam_aothun_t7.csv',
#  'tk_ttnam_aothun_t8.csv',
#  'tk_ttnam_aothun_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_aothunnam_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title      price  \
# 0   Áo Polo nam cổ bẻ ngắn tay, chất liệu vải cá s...   179.000₫
# 1   TÔI YÊU VIỆT NAM, mã TV3. Áo phông đẹp cho nam...   168.000₫
# 2   Áo thun Zoro siêu ngầu cho nam nữ teen trẻ em,...   119.000₫
# 3   Áo thun Tanjiro Kimetsu No Yaiba, mã KY2. Áo p...    79.000₫
# 4   Áo thun in hình Urokodaki Kimetsu No Yaiba, mã...   179.000₫
# ..                                                ...        ...
# 35                                                NaN        NaN
# 36  Áo Phông Nam Polo Tay Ngắn Phối Màu Thời Trang...   189.000₫
# 37        Áo Polo Nam Enkoni Basic Trắng Vải Coolmate   389.000₫
# 38  Áo Thun Ba Lỗ Nam Sát Nách Vải Cotton Mềm Form...    39.000₫
# 39  MLB - Áo thun unisex cổ tròn tay ngắn Monotive...  1.790.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=G-bkB6rMr...      1     -28%
# 1   https://tka.tiki.vn/pixel/pixel?data=O8tl6Ldqv...      2     -44%
# 2   https://tka.tiki.vn/pixel/pixel?data=WmH5pIQYS...      3     -12%
# 3   https://tka.tiki.vn/pixel/pixel?data=mOVlt-0s0...      4     -21%
# 4   https://tka.tiki.vn/pixel/pixel?data=J1MZAraXL...      5     -25%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ao-thun-tron-nam-form-rong-vai...     36      NaN
# 36  https://tiki.vn/ao-phong-nam-polo-tay-ngan-pho...     37      NaN
# 37  https://tiki.vn/ao-polo-nam-enkoni-basic-trang...     38      NaN
# 38  https://tiki.vn/ao-thun-ba-lo-nam-sat-nach-vai...     39      NaN
# 39  https://tiki.vn/mlb-ao-thun-unisex-co-tron-tay...     40      NaN
#
#          sales category
# 0   Đã bán 878   aothun
# 1    Đã bán 17   aothun
# 2          NaN   aothun
# 3          NaN   aothun
# 4          NaN   aothun
# ..         ...      ...
# 35         NaN   aothun
# 36  Đã bán 263   aothun
# 37    Đã bán 2   aothun
# 38    Đã bán 3   aothun
# 39         NaN   aothun
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Áo Polo nam cổ bẻ ngắn tay, chất liệu vải cá s...  179.000₫
# 1    TÔI YÊU VIỆT NAM, mã TV3. Áo phông đẹp cho nam...  168.000₫
# 2    Áo thun nam Cotton Compact Premium trẻ trung n...  139.000₫
# 3    Áo Polo Nam cổ bẻ TSIMPLE thun có cổ tay lỡ vả...  149.000₫
# 4    Áo thun tay lỡ form rộng - phông nam nữ oversi...   99.000₫
# ..                                                 ...       ...
# 938  Áo Thun Có Cổ Nam Giordano Luxury Touch Polo 0...  310.000₫
# 939  Combo 2 Áo thun thể thao nam MRM Active Pro th...  219.000₫
# 940  Áo Phông Nam Polo Tay Ngắn Phối Màu Thời Trang...  189.000₫
# 941        Áo Polo Nam Enkoni Basic Trắng Vải Coolmate  389.000₫
# 942  Áo Thun Ba Lỗ Nam Sát Nách Vải Cotton Mềm Form...   39.000₫
#
#                                              link_item discount        sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=G-bkB6rMr...     -28%   Đã bán 878
# 1    https://tka.tiki.vn/pixel/pixel?data=O8tl6Ldqv...     -44%    Đã bán 17
# 2    https://tiki.vn/ao-thun-nam-cotton-compact-pre...     -37%   Đã bán 729
# 3    https://tiki.vn/ao-polo-nam-co-be-tsimple-thun...     -21%  Đã bán 2.1k
# 4    https://tiki.vn/ao-thun-tay-lo-form-rong-phong...     -44%   Đã bán 105
# ..                                                 ...      ...          ...
# 938  https://tiki.vn/ao-thun-co-co-nam-giordano-lux...      NaN    Đã bán 11
# 939  https://tiki.vn/combo-2-ao-thun-the-thao-nam-m...      NaN   Đã bán 125
# 940  https://tiki.vn/ao-phong-nam-polo-tay-ngan-pho...      NaN   Đã bán 263
# 941  https://tiki.vn/ao-polo-nam-enkoni-basic-trang...      NaN     Đã bán 2
# 942  https://tiki.vn/ao-thun-ba-lo-nam-sat-nach-vai...      NaN     Đã bán 3
#
#     category
# 0     aothun
# 1     aothun
# 2     aothun
# 3     aothun
# 4     aothun
# ..       ...
# 938   aothun
# 939   aothun
# 940   aothun
# 941   aothun
# 942   aothun
#
# [943 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      179000
# 1      168000
# 2      139000
# 3      149000
# 4       99000
#         ...
# 938    310000
# 939    219000
# 940    189000
# 941    389000
# 942     39000
# Name: price, Length: 943, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       878.0
# 1        17.0
# 2       729.0
# 3      2100.0
# 4       105.0
#         ...
# 938      11.0
# 939     125.0
# 940     263.0
# 941       2.0
# 942       3.0
# Name: sales, Length: 943, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      157162000.0
# 1        2856000.0
# 2      101331000.0
# 3      312900000.0
# 4       10395000.0
#           ...
# 938      3410000.0
# 939     27375000.0
# 940     49707000.0
# 941       778000.0
# 942       117000.0
# Name: revenue, Length: 943, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số aothunnam: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số aothunnam:  7979804924.0
# So mat hang da ban:  943
# So san pham da ban:  58582.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Áo Polo nam cổ bẻ ngắn tay, chất liệu vải cá s...  179000
# 1    TÔI YÊU VIỆT NAM, mã TV3. Áo phông đẹp cho nam...  168000
# 2    Áo thun nam Cotton Compact Premium trẻ trung n...  139000
# 3    Áo Polo Nam cổ bẻ TSIMPLE thun có cổ tay lỡ vả...  149000
# 4    Áo thun tay lỡ form rộng - phông nam nữ oversi...   99000
# ..                                                 ...     ...
# 938  Áo Thun Có Cổ Nam Giordano Luxury Touch Polo 0...  310000
# 939  Combo 2 Áo thun thể thao nam MRM Active Pro th...  219000
# 940  Áo Phông Nam Polo Tay Ngắn Phối Màu Thời Trang...  189000
# 941        Áo Polo Nam Enkoni Basic Trắng Vải Coolmate  389000
# 942  Áo Thun Ba Lỗ Nam Sát Nách Vải Cotton Mềm Form...   39000
#
#                                              link_item discount   sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=G-bkB6rMr...     -28%   878.0
# 1    https://tka.tiki.vn/pixel/pixel?data=O8tl6Ldqv...     -44%    17.0
# 2    https://tiki.vn/ao-thun-nam-cotton-compact-pre...     -37%   729.0
# 3    https://tiki.vn/ao-polo-nam-co-be-tsimple-thun...     -21%  2100.0
# 4    https://tiki.vn/ao-thun-tay-lo-form-rong-phong...     -44%   105.0
# ..                                                 ...      ...     ...
# 938  https://tiki.vn/ao-thun-co-co-nam-giordano-lux...      NaN    11.0
# 939  https://tiki.vn/combo-2-ao-thun-the-thao-nam-m...      NaN   125.0
# 940  https://tiki.vn/ao-phong-nam-polo-tay-ngan-pho...      NaN   263.0
# 941  https://tiki.vn/ao-polo-nam-enkoni-basic-trang...      NaN     2.0
# 942  https://tiki.vn/ao-thun-ba-lo-nam-sat-nach-vai...      NaN     3.0
#
#     category      revenue
# 0     aothun  157162000.0
# 1     aothun    2856000.0
# 2     aothun  101331000.0
# 3     aothun  312900000.0
# 4     aothun   10395000.0
# ..       ...          ...
# 938   aothun    3410000.0
# 939   aothun   27375000.0
# 940   aothun   49707000.0
# 941   aothun     778000.0
# 942   aothun     117000.0
#
# [943 rows x 7 columns]

# %%
df_all.to_csv("tk_aothunnam_all_ed.csv")
