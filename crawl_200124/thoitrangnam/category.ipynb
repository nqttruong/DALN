# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\thoitrangnam"
os.listdir(path)
# Out:
# ['aohoodie',
#  'aoni',
#  'aosomi',
#  'aothunnam',
#  'aovest',
#  'category.ipynb',
#  'doboi',
#  'dodoi',
#  'dolot',
#  'dongu',
#  'quanaokichcolon',
#  'quanaotrungnien',
#  'quannam',
#  'tk_aohoodie_all_ed.csv',
#  'tk_aoni_all_ed.csv',
#  'tk_aosomi_all_ed.csv',
#  'tk_aothunnam_all_ed.csv',
#  'tk_aovest_all_ed.csv',
#  'tk_doboinam_all_ed.csv',
#  'tk_dodoi_all_ed.csv',
#  'tk_dolotnam_all_ed.csv',
#  'tk_dongunam_all_ed.csv',
#  'tk_quanaokichcolon_all_ed.csv',
#  'tk_quanaotrungnien_all_ed.csv',
#  'tk_quannam_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#       Unnamed: 0                                              title   price  \
# 0              0  Áo hoodie nam nữ form rộng Unisex một màu in h...  179000
# 1              1  Áo hoodie nam nữ form rộng Unisex một màu in h...  127000
# 2              2  Áo hoodie nỉ bông unisex Homies liền mũ có túi...  100000
# 3              3  Áo hoodie, áo sweater thời trang unisex, phong...   88000
# 4              4  Áo hoodie trơn màu đen thời trang trẻ trung, n...  124000
# ...          ...                                                ...     ...
# 2087        2087  Quần Jean Nam Co Giãn Kiểu Dáng Trẻ Trung Đơn ...  169000
# 2088        2088  QUẦN JEAN NAM TRẮNG CAO CẤP - VẢI TRẮNG TINH C...  150000
# 2089        2089  Bộ Đồ Nam - Bộ Nỉ Nam Thu Đông Thể Thao Chất N...  300000
# 2090        2090  Quần Jean Nam màu xanh thương hiệu Julido Stor...  169000
# 2091        2091  Quần Tây Nam Dáng Ôm Chất Liệu Vải Mềm Mịn Khh...   93000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=89qe4o7GK...     -10%  923.0
# 1     https://tiki.vn/ao-hoodie-nam-nu-form-rong-uni...     -54%  923.0
# 2     https://tiki.vn/ao-hoodie-ni-bong-unisex-homie...     -50%  143.0
# 3     https://tiki.vn/ao-hoodie-ao-sweater-thoi-tran...     -30%   10.0
# 4     https://tiki.vn/ao-hoodie-tron-mau-den-thoi-tr...     -30%  463.0
# ...                                                 ...      ...    ...
# 2087  https://tiki.vn/quan-jean-nam-co-gian-kieu-dan...      NaN    5.0
# 2088  https://tiki.vn/quan-jean-nam-trang-cao-cap-va...      NaN    1.0
# 2089  https://tiki.vn/bo-do-nam-bo-ni-nam-thu-dong-t...      NaN    3.0
# 2090  https://tiki.vn/quan-jean-nam-mau-xanh-thuong-...      NaN  221.0
# 2091  https://tiki.vn/quan-tay-nam-dang-om-chat-lieu...      NaN  144.0
#
#       category      revenue
# 0     aohoodie  165217000.0
# 1     aohoodie  117221000.0
# 2     aohoodie   14300000.0
# 3     aohoodie     880000.0
# 4     aohoodie   57412000.0
# ...        ...          ...
# 2087   quannam     845000.0
# 2088   quannam     150000.0
# 2089   quannam     900000.0
# 2090   quannam   37349000.0
# 2091   quannam   13392000.0
#
# [7648 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "thoitrangnam")

# %%
df
# Out:
#                                                   title   price  \
# 0     Áo hoodie nam nữ form rộng Unisex một màu in h...  179000
# 1     Áo hoodie nam nữ form rộng Unisex một màu in h...  127000
# 2     Áo hoodie nỉ bông unisex Homies liền mũ có túi...  100000
# 3     Áo hoodie, áo sweater thời trang unisex, phong...   88000
# 4     Áo hoodie trơn màu đen thời trang trẻ trung, n...  124000
# ...                                                 ...     ...
# 2087  Quần Jean Nam Co Giãn Kiểu Dáng Trẻ Trung Đơn ...  169000
# 2088  QUẦN JEAN NAM TRẮNG CAO CẤP - VẢI TRẮNG TINH C...  150000
# 2089  Bộ Đồ Nam - Bộ Nỉ Nam Thu Đông Thể Thao Chất N...  300000
# 2090  Quần Jean Nam màu xanh thương hiệu Julido Stor...  169000
# 2091  Quần Tây Nam Dáng Ôm Chất Liệu Vải Mềm Mịn Khh...   93000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=89qe4o7GK...     -10%  923.0
# 1     https://tiki.vn/ao-hoodie-nam-nu-form-rong-uni...     -54%  923.0
# 2     https://tiki.vn/ao-hoodie-ni-bong-unisex-homie...     -50%  143.0
# 3     https://tiki.vn/ao-hoodie-ao-sweater-thoi-tran...     -30%   10.0
# 4     https://tiki.vn/ao-hoodie-tron-mau-den-thoi-tr...     -30%  463.0
# ...                                                 ...      ...    ...
# 2087  https://tiki.vn/quan-jean-nam-co-gian-kieu-dan...      NaN    5.0
# 2088  https://tiki.vn/quan-jean-nam-trang-cao-cap-va...      NaN    1.0
# 2089  https://tiki.vn/bo-do-nam-bo-ni-nam-thu-dong-t...      NaN    3.0
# 2090  https://tiki.vn/quan-jean-nam-mau-xanh-thuong-...      NaN  221.0
# 2091  https://tiki.vn/quan-tay-nam-dang-om-chat-lieu...      NaN  144.0
#
#      item_list      category      revenue
# 0     aohoodie  thoitrangnam  165217000.0
# 1     aohoodie  thoitrangnam  117221000.0
# 2     aohoodie  thoitrangnam   14300000.0
# 3     aohoodie  thoitrangnam     880000.0
# 4     aohoodie  thoitrangnam   57412000.0
# ...        ...           ...          ...
# 2087   quannam  thoitrangnam     845000.0
# 2088   quannam  thoitrangnam     150000.0
# 2089   quannam  thoitrangnam     900000.0
# 2090   quannam  thoitrangnam   37349000.0
# 2091   quannam  thoitrangnam   13392000.0
#
# [7648 rows x 8 columns]

# %%
df.to_csv('tk_thoitrangnam_all_ed.csv', index=False, encoding='utf-8')
