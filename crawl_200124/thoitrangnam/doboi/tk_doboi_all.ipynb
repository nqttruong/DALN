# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12htrua)\thoitrangnam\doboi"
os.listdir(path)
# Out:
# ['tk_doboi.csv',
#  'tk_doboi.ipynb',
#  'tk_doboi_all.ipynb',
#  'tk_ttn_doboi_t10.csv',
#  'tk_ttn_doboi_t11.csv',
#  'tk_ttn_doboi_t2.csv',
#  'tk_ttn_doboi_t3.csv',
#  'tk_ttn_doboi_t4.csv',
#  'tk_ttn_doboi_t5.csv',
#  'tk_ttn_doboi_t6.csv',
#  'tk_ttn_doboi_t7.csv',
#  'tk_ttn_doboi_t8.csv',
#  'tk_ttn_doboi_t9.csv',
#  'tk_ttn_tttn_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_doboi_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Quần Bơi Nam Thiết Kế Vảy Cá Mập Cleacco Chống...  111.000₫
# 1   Quần Bơi Nam Boxer Có Túi CLEACCO DEENYT Chất ...  195.000₫
# 2   Quần Bơi Nam Tam Giác Thời Trang Desmiit S324 ...  229.000₫
# 3   Quần Bơi Lửng Nam Brave Person B2240 - Thiết K...  195.000₫
# 4   Quần Bơi Nam Boxers Brave Person B1010 - Thiết...  112.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36                               Quần Tắm Nam Cao Cấp  160.000₫
# 37  Quần bơi nam tam giác in hình ngôi sao, đồ bơi...  190.000₫
# 38                                Quần Bơi Nam Kèm Mũ   99.900₫
# 39       Quần bơi boxer nam hình ngôi sao QSHOP QT495   190.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=BsTVZYcq2...      1     -45%
# 1   https://tka.tiki.vn/pixel/pixel?data=HVRRVxnlH...      2     -40%
# 2   https://tka.tiki.vn/pixel/pixel?data=Itt5m_dNE...      3     -43%
# 3   https://tka.tiki.vn/pixel/pixel?data=tovCHnWAc...      4     -57%
# 4   https://tka.tiki.vn/pixel/pixel?data=uCc3fMbEc...      5     -57%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/bo-2-mon-quan-mu-boi-chat-vai-...     36      NaN
# 36  https://tiki.vn/quan-tam-nam-cao-cap-p6055663....     37      NaN
# 37  https://tiki.vn/quan-boi-nam-tam-giac-in-hinh-...     38      NaN
# 38  https://tiki.vn/quan-boi-nam-kem-mu-p17904013....     39      NaN
# 39  https://tiki.vn/quan-boi-boxer-nam-hinh-ngoi-s...     40      NaN
#
#          sales category
# 0   Đã bán 697    doboi
# 1   Đã bán 395    doboi
# 2     Đã bán 2    doboi
# 3    Đã bán 20    doboi
# 4     Đã bán 3    doboi
# ..         ...      ...
# 35         NaN    doboi
# 36    Đã bán 4    doboi
# 37    Đã bán 5    doboi
# 38         NaN    doboi
# 39         NaN    doboi
#
# [416 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Quần Bơi Nam Thiết Kế Vảy Cá Mập Cleacco Chống...  111.000₫
# 1    Quần Bơi Nam Boxer Có Túi CLEACCO DEENYT Chất ...  195.000₫
# 2    Quần Bơi Nam Tam Giác Thời Trang Desmiit S324 ...  229.000₫
# 3    Quần Bơi Lửng Nam Brave Person B2240 - Thiết K...  195.000₫
# 4    Quần Bơi Nam Boxers Brave Person B1010 - Thiết...  112.000₫
# ..                                                 ...       ...
# 135  Quần bơi cao cấp may 2 lớp chắc chắn chất thun...  119.000₫
# 136             Quần đi biển nam họa tiết mẫu mới 2022   55.000₫
# 137  Quần đi biển nam dáng rộng, chất thun bơi lạnh...  260.000₫
# 138                               Quần Tắm Nam Cao Cấp  160.000₫
# 139  Quần bơi nam tam giác in hình ngôi sao, đồ bơi...  190.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=BsTVZYcq2...     -45%  Đã bán 697
# 1    https://tka.tiki.vn/pixel/pixel?data=HVRRVxnlH...     -40%  Đã bán 395
# 2    https://tka.tiki.vn/pixel/pixel?data=Itt5m_dNE...     -43%    Đã bán 2
# 3    https://tka.tiki.vn/pixel/pixel?data=tovCHnWAc...     -57%   Đã bán 20
# 4    https://tka.tiki.vn/pixel/pixel?data=uCc3fMbEc...     -57%    Đã bán 3
# ..                                                 ...      ...         ...
# 135  https://tiki.vn/quan-boi-cao-cap-may-2-lop-cha...      NaN    Đã bán 1
# 136  https://tiki.vn/quan-di-bien-nam-hoa-tiet-mau-...      NaN    Đã bán 1
# 137  https://tiki.vn/quan-di-bien-nam-dang-rong-cha...      NaN    Đã bán 3
# 138  https://tiki.vn/quan-tam-nam-cao-cap-p6055663....      NaN    Đã bán 4
# 139  https://tiki.vn/quan-boi-nam-tam-giac-in-hinh-...      NaN    Đã bán 5
#
#     category
# 0      doboi
# 1      doboi
# 2      doboi
# 3      doboi
# 4      doboi
# ..       ...
# 135    doboi
# 136    doboi
# 137    doboi
# 138    doboi
# 139    doboi
#
# [140 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      111000
# 1      195000
# 2      229000
# 3      195000
# 4      112000
#         ...
# 135    119000
# 136     55000
# 137    260000
# 138    160000
# 139    190000
# Name: price, Length: 140, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      697.0
# 1      395.0
# 2        2.0
# 3       20.0
# 4        3.0
#        ...
# 135      1.0
# 136      1.0
# 137      3.0
# 138      4.0
# 139      5.0
# Name: sales, Length: 140, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      77367000.0
# 1      77025000.0
# 2        458000.0
# 3       3900000.0
# 4        336000.0
#           ...
# 135      119000.0
# 136       55000.0
# 137      780000.0
# 138      640000.0
# 139      950000.0
# Name: revenue, Length: 140, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số doboi: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số doboi:  944277860.0
# So mat hang da ban:  140
# So san pham da ban:  6069.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Quần Bơi Nam Thiết Kế Vảy Cá Mập Cleacco Chống...  111000
# 1    Quần Bơi Nam Boxer Có Túi CLEACCO DEENYT Chất ...  195000
# 2    Quần Bơi Nam Tam Giác Thời Trang Desmiit S324 ...  229000
# 3    Quần Bơi Lửng Nam Brave Person B2240 - Thiết K...  195000
# 4    Quần Bơi Nam Boxers Brave Person B1010 - Thiết...  112000
# ..                                                 ...     ...
# 135  Quần bơi cao cấp may 2 lớp chắc chắn chất thun...  119000
# 136             Quần đi biển nam họa tiết mẫu mới 2022   55000
# 137  Quần đi biển nam dáng rộng, chất thun bơi lạnh...  260000
# 138                               Quần Tắm Nam Cao Cấp  160000
# 139  Quần bơi nam tam giác in hình ngôi sao, đồ bơi...  190000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=BsTVZYcq2...     -45%  697.0
# 1    https://tka.tiki.vn/pixel/pixel?data=HVRRVxnlH...     -40%  395.0
# 2    https://tka.tiki.vn/pixel/pixel?data=Itt5m_dNE...     -43%    2.0
# 3    https://tka.tiki.vn/pixel/pixel?data=tovCHnWAc...     -57%   20.0
# 4    https://tka.tiki.vn/pixel/pixel?data=uCc3fMbEc...     -57%    3.0
# ..                                                 ...      ...    ...
# 135  https://tiki.vn/quan-boi-cao-cap-may-2-lop-cha...      NaN    1.0
# 136  https://tiki.vn/quan-di-bien-nam-hoa-tiet-mau-...      NaN    1.0
# 137  https://tiki.vn/quan-di-bien-nam-dang-rong-cha...      NaN    3.0
# 138  https://tiki.vn/quan-tam-nam-cao-cap-p6055663....      NaN    4.0
# 139  https://tiki.vn/quan-boi-nam-tam-giac-in-hinh-...      NaN    5.0
#
#     category     revenue
# 0      doboi  77367000.0
# 1      doboi  77025000.0
# 2      doboi    458000.0
# 3      doboi   3900000.0
# 4      doboi    336000.0
# ..       ...         ...
# 135    doboi    119000.0
# 136    doboi     55000.0
# 137    doboi    780000.0
# 138    doboi    640000.0
# 139    doboi    950000.0
#
# [140 rows x 7 columns]

# %%
df_all.to_csv("tk_doboi_all_ed.csv")
