# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\dochoi_mevabe\chamsocme"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_chamsocme.csv',
#  'tk_chamsocme_all.ipynb',
#  'tk_chamsocme_t10.csv',
#  'tk_chamsocme_t11.csv',
#  'tk_chamsocme_t12.csv',
#  'tk_chamsocme_t13.csv',
#  'tk_chamsocme_t14.csv',
#  'tk_chamsocme_t15.csv',
#  'tk_chamsocme_t16.csv',
#  'tk_chamsocme_t17.csv',
#  'tk_chamsocme_t18.csv',
#  'tk_chamsocme_t19.csv',
#  'tk_chamsocme_t2.csv',
#  'tk_chamsocme_t20.csv',
#  'tk_chamsocme_t21.csv',
#  'tk_chamsocme_t22.csv',
#  'tk_chamsocme_t23.csv',
#  'tk_chamsocme_t24.csv',
#  'tk_chamsocme_t25.csv',
#  'tk_chamsocme_t26.csv',
#  'tk_chamsocme_t27.csv',
#  'tk_chamsocme_t28.csv',
#  'tk_chamsocme_t29.csv',
#  'tk_chamsocme_t3.csv',
#  'tk_chamsocme_t30.csv',
#  'tk_chamsocme_t31.csv',
#  'tk_chamsocme_t32.csv',
#  'tk_chamsocme_t33.csv',
#  'tk_chamsocme_t34.csv',
#  'tk_chamsocme_t35.csv',
#  'tk_chamsocme_t36.csv',
#  'tk_chamsocme_t37.csv',
#  'tk_chamsocme_t38.csv',
#  'tk_chamsocme_t39.csv',
#  'tk_chamsocme_t4.csv',
#  'tk_chamsocme_t40.csv',
#  'tk_chamsocme_t41.csv',
#  'tk_chamsocme_t42.csv',
#  'tk_chamsocme_t43.csv',
#  'tk_chamsocme_t44.csv',
#  'tk_chamsocme_t45.csv',
#  'tk_chamsocme_t46.csv',
#  'tk_chamsocme_t47.csv',
#  'tk_chamsocme_t48.csv',
#  'tk_chamsocme_t49.csv',
#  'tk_chamsocme_t5.csv',
#  'tk_chamsocme_t50.csv',
#  'tk_chamsocme_t6.csv',
#  'tk_chamsocme_t7.csv',
#  'tk_chamsocme_t8.csv',
#  'tk_chamsocme_t9.csv',
#  'tk_mvb_chamsocme.ipynb',
#  'tk_mvb_chamsocme_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_chamsocme_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...    185.000₫
# 1   Nước Tắm Thảo Dược Cho Bà Bầu Và Mẹ Sau Sinh B...    243.000₫
# 2   Serum vitamin C trắng da, đánh bay sạm nám Won...    295.000₫
# 3   Kem cấp ẩm, dưỡng trắng da và ngăn ngừa mụn Wo...    231.000₫
# 4   Bộ trắng da, sạch mụn cao cấp Wonmom ( Sữa rửa...  1.199.000₫
# ..                                                ...         ...
# 35  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...    165.000₫
# 36  Áo Choàng Cho Bé Bú, Khăn Choàng Che Nắng, Khă...     65.000₫
# 37  Phụ kiện thay thế cho máy hút sữa Fatzbaby Res...     20.000₫
# 38    Bộ phụ kiện đầu đủ dùng cho máy hút sữa Spectra    550.000₫
# 39  Màng hút Máy hút sữa điện đơn và đôi - FatzBab...    100.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=JwRg7nT3O...      1     -16%
# 1   https://tka.tiki.vn/pixel/pixel?data=cSNk8Jg54...      2     -10%
# 2   https://tka.tiki.vn/pixel/pixel?data=84g5o4zpF...      3     -16%
# 3   https://tka.tiki.vn/pixel/pixel?data=_9c_2kXqm...      4     -16%
# 4   https://tka.tiki.vn/pixel/pixel?data=FksiNVY68...      5     -21%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...     36      NaN
# 36  https://tiki.vn/ao-choang-cho-be-bu-khan-choan...     37      NaN
# 37  https://tiki.vn/phu-kien-thay-the-cho-may-hut-...     38      NaN
# 38  https://tiki.vn/bo-phu-kien-dau-du-dung-cho-ma...     39      NaN
# 39  https://tiki.vn/mang-hut-may-hut-sua-dien-don-...     40      NaN
#
#          sales   category
# 0   Đã bán 183  chamsocme
# 1    Đã bán 11  chamsocme
# 2   Đã bán 125  chamsocme
# 3          NaN  chamsocme
# 4          NaN  chamsocme
# ..         ...        ...
# 35   Đã bán 13  chamsocme
# 36   Đã bán 52  chamsocme
# 37         NaN  chamsocme
# 38   Đã bán 41  chamsocme
# 39         NaN  chamsocme
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...  185.000₫
# 1     Nước Tắm Thảo Dược Cho Bà Bầu Và Mẹ Sau Sinh B...  243.000₫
# 2     Serum vitamin C trắng da, đánh bay sạm nám Won...  295.000₫
# 3             2 Miếng Đá Khô Frozen 1 Fatzbaby FB0020VN   69.000₫
# 4     Băng Vệ Sinh Diana Mama Dùng Cho Mẹ Sau Sinh 1...   26.000₫
# ...                                                 ...       ...
# 1226  Lá xông, thơm tho cơ thể mẹ sau sinh, lưu thôn...   46.800₫
# 1227  Quần lót bầu và sau sinh cạp chéo chất SU ĐÚC ...   29.000₫
# 1228  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...  165.000₫
# 1229  Áo Choàng Cho Bé Bú, Khăn Choàng Che Nắng, Khă...   65.000₫
# 1230    Bộ phụ kiện đầu đủ dùng cho máy hút sữa Spectra  550.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=JwRg7nT3O...     -16%  Đã bán 183
# 1     https://tka.tiki.vn/pixel/pixel?data=cSNk8Jg54...     -10%   Đã bán 11
# 2     https://tka.tiki.vn/pixel/pixel?data=84g5o4zpF...     -16%  Đã bán 125
# 3     https://tiki.vn/2-mieng-da-kho-frozen-1-fatzba...     -24%   Đã bán 11
# 4     https://tiki.vn/bang-ve-sinh-diana-mama-12-mie...     -13%  Đã bán 329
# ...                                                 ...      ...         ...
# 1226  https://tiki.vn/la-xong-thom-tho-co-the-me-sau...      NaN  Đã bán 224
# 1227  https://tiki.vn/quan-lot-bau-va-sau-sinh-cap-c...      NaN   Đã bán 40
# 1228  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...      NaN   Đã bán 13
# 1229  https://tiki.vn/ao-choang-cho-be-bu-khan-choan...      NaN   Đã bán 52
# 1230  https://tiki.vn/bo-phu-kien-dau-du-dung-cho-ma...      NaN   Đã bán 41
#
#        category
# 0     chamsocme
# 1     chamsocme
# 2     chamsocme
# 3     chamsocme
# 4     chamsocme
# ...         ...
# 1226  chamsocme
# 1227  chamsocme
# 1228  chamsocme
# 1229  chamsocme
# 1230  chamsocme
#
# [1231 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       185000
# 1       243000
# 2       295000
# 3        69000
# 4        26000
#          ...
# 1226     46800
# 1227     29000
# 1228    165000
# 1229     65000
# 1230    550000
# Name: price, Length: 1231, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       183.0
# 1        11.0
# 2       125.0
# 3        11.0
# 4       329.0
#         ...
# 1226    224.0
# 1227     40.0
# 1228     13.0
# 1229     52.0
# 1230     41.0
# Name: sales, Length: 1231, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       33855000.0
# 1        2673000.0
# 2       36875000.0
# 3         759000.0
# 4        8554000.0
#            ...
# 1226    10483200.0
# 1227     1160000.0
# 1228     2145000.0
# 1229     3380000.0
# 1230    22550000.0
# Name: revenue, Length: 1231, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chamsocme: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số chamsocme:  13229669755.0
# So mat hang da ban:  1231
# So san pham da ban:  51406.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...  185000
# 1     Nước Tắm Thảo Dược Cho Bà Bầu Và Mẹ Sau Sinh B...  243000
# 2     Serum vitamin C trắng da, đánh bay sạm nám Won...  295000
# 3             2 Miếng Đá Khô Frozen 1 Fatzbaby FB0020VN   69000
# 4     Băng Vệ Sinh Diana Mama Dùng Cho Mẹ Sau Sinh 1...   26000
# ...                                                 ...     ...
# 1226  Lá xông, thơm tho cơ thể mẹ sau sinh, lưu thôn...   46800
# 1227  Quần lót bầu và sau sinh cạp chéo chất SU ĐÚC ...   29000
# 1228  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...  165000
# 1229  Áo Choàng Cho Bé Bú, Khăn Choàng Che Nắng, Khă...   65000
# 1230    Bộ phụ kiện đầu đủ dùng cho máy hút sữa Spectra  550000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=JwRg7nT3O...     -16%  183.0
# 1     https://tka.tiki.vn/pixel/pixel?data=cSNk8Jg54...     -10%   11.0
# 2     https://tka.tiki.vn/pixel/pixel?data=84g5o4zpF...     -16%  125.0
# 3     https://tiki.vn/2-mieng-da-kho-frozen-1-fatzba...     -24%   11.0
# 4     https://tiki.vn/bang-ve-sinh-diana-mama-12-mie...     -13%  329.0
# ...                                                 ...      ...    ...
# 1226  https://tiki.vn/la-xong-thom-tho-co-the-me-sau...      NaN  224.0
# 1227  https://tiki.vn/quan-lot-bau-va-sau-sinh-cap-c...      NaN   40.0
# 1228  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...      NaN   13.0
# 1229  https://tiki.vn/ao-choang-cho-be-bu-khan-choan...      NaN   52.0
# 1230  https://tiki.vn/bo-phu-kien-dau-du-dung-cho-ma...      NaN   41.0
#
#        category     revenue
# 0     chamsocme  33855000.0
# 1     chamsocme   2673000.0
# 2     chamsocme  36875000.0
# 3     chamsocme    759000.0
# 4     chamsocme   8554000.0
# ...         ...         ...
# 1226  chamsocme  10483200.0
# 1227  chamsocme   1160000.0
# 1228  chamsocme   2145000.0
# 1229  chamsocme   3380000.0
# 1230  chamsocme  22550000.0
#
# [1231 rows x 7 columns]

# %%
df_all.to_csv("tk_chamsocme_all_ed.csv")
