# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\dochoi_mevabe\dodungchobe"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dodungchobe_all.ipynb',
#  'tk_dodungchobe_t1.csv',
#  'tk_dodungchobe_t10.csv',
#  'tk_dodungchobe_t11.csv',
#  'tk_dodungchobe_t12.csv',
#  'tk_dodungchobe_t13.csv',
#  'tk_dodungchobe_t14.csv',
#  'tk_dodungchobe_t15.csv',
#  'tk_dodungchobe_t16.csv',
#  'tk_dodungchobe_t17.csv',
#  'tk_dodungchobe_t18.csv',
#  'tk_dodungchobe_t19.csv',
#  'tk_dodungchobe_t2.csv',
#  'tk_dodungchobe_t20.csv',
#  'tk_dodungchobe_t21.csv',
#  'tk_dodungchobe_t22.csv',
#  'tk_dodungchobe_t23.csv',
#  'tk_dodungchobe_t24.csv',
#  'tk_dodungchobe_t25.csv',
#  'tk_dodungchobe_t26.csv',
#  'tk_dodungchobe_t27.csv',
#  'tk_dodungchobe_t28.csv',
#  'tk_dodungchobe_t29.csv',
#  'tk_dodungchobe_t3.csv',
#  'tk_dodungchobe_t30.csv',
#  'tk_dodungchobe_t31.csv',
#  'tk_dodungchobe_t32.csv',
#  'tk_dodungchobe_t33.csv',
#  'tk_dodungchobe_t34.csv',
#  'tk_dodungchobe_t35.csv',
#  'tk_dodungchobe_t36.csv',
#  'tk_dodungchobe_t37.csv',
#  'tk_dodungchobe_t38.csv',
#  'tk_dodungchobe_t39.csv',
#  'tk_dodungchobe_t4.csv',
#  'tk_dodungchobe_t40.csv',
#  'tk_dodungchobe_t41.csv',
#  'tk_dodungchobe_t42.csv',
#  'tk_dodungchobe_t43.csv',
#  'tk_dodungchobe_t44.csv',
#  'tk_dodungchobe_t45.csv',
#  'tk_dodungchobe_t46.csv',
#  'tk_dodungchobe_t47.csv',
#  'tk_dodungchobe_t48.csv',
#  'tk_dodungchobe_t49.csv',
#  'tk_dodungchobe_t5.csv',
#  'tk_dodungchobe_t50.csv',
#  'tk_dodungchobe_t6.csv',
#  'tk_dodungchobe_t7.csv',
#  'tk_dodungchobe_t8.csv',
#  'tk_dodungchobe_t9.csv',
#  'tk_mvb_dodungchobe.ipynb',
#  'tk_mvb_dodungchobe_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dodungchobe_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Bộ 2 Chai Sữa Tắm Gội Toàn Thân Cho Bé Johnson...  245.000₫
# 1   Bình sữa Pigeon PP Plus thế hệ III 160ml/240ml...  196.000₫
# 2   Nước Tắm Gội Thảo Dược Dr.Papie Cho Bé Giúp Ng...  135.000₫
# 3   Dung dịch súc rửa bình sữa & phụ kiện Pigeon 5...   87.000₫
# 4   Nước Tắm Bé Bảo Linh,chiết xuất thảo dược,dùng...  225.000₫
# ..                                                ...       ...
# 35              Nước rửa bình sữa D-nee Organic 600ml   95.000₫
# 36  Chậu tắm gập gọn size lớn cho bé (combo kèm phao)  340.000₫
# 37          Nước rửa bình sữa D-nee Organic túi 550ml   59.000₫
# 38  Set 10 Bịt Ổ Điện Chống Giật, Miếng Chặn Ổ Điệ...   30.000₫
# 39                Miếng Bịt Góc Bàn Ghế Hình Chân Mèo   44.100₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data
rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       245000
# 1       196000
# 2       135000
# 3        87000
# 4       225000
#          ...
# 1805     95000
# 1806    340000
# 1807     59000
# 1808     30000
# 1809     44100
# Name: price, Length: 1810, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       5000.0
# 1         74.0
# 2        104.0
# 3        175.0
# 4          7.0
#          ...
# 1805      93.0
# 1806      35.0
# 1807     101.0
# 1808      91.0
# 1809     444.0
# Name: sales, Length: 1810, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1.225000e+09
# 1       1.450400e+07
# 2       1.404000e+07
# 3       1.522500e+07
# 4       1.575000e+06
#             ...
# 1805    8.835000e+06
# 1806    1.190000e+07
# 1807    5.959000e+06
# 1808    2.730000e+06
# 1809    1.958040e+07
# Name: revenue, Length: 1810, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dodungchobe: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dodungchobe:  46595815968.0
# So mat hang da ban:  1810
# So san pham da ban:  205495.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Bộ 2 Chai Sữa Tắm Gội Toàn Thân Cho Bé Johnson...  245000
# 1     Bình sữa Pigeon PP Plus thế hệ III 160ml/240ml...  196000
# 2     Nước Tắm Gội Thảo Dược Dr.Papie Cho Bé Giúp Ng...  135000
# 3     Dung dịch súc rửa bình sữa & phụ kiện Pigeon 5...   87000
# 4     Nước Tắm Bé Bảo Linh,chiết xuất thảo dược,dùng...  225000
# ...                                                 ...     ...
# 1805              Nước rửa bình sữa D-nee Organic 600ml   95000
# 1806  Chậu tắm gập gọn size lớn cho bé (combo kèm phao)  340000
# 1807          Nước rửa bình sữa D-nee Organic túi 550ml   59000
# 1808  Set 10 Bịt Ổ Điện Chống Giật, Miếng Chặn Ổ Điệ...   30000
# 1809                Miếng Bịt Góc Bàn Ghế Hình Chân Mèo   44100
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=h7X84LQzf...     -21%  5000.0
# 1     https://tka.tiki.vn/pixel/pixel?data=zJ-cXr4Gh...     -20%    74.0
# 2     https://tka.tiki.vn/pixel/pixel?data=AxmACT6mw...     -25%   104.0
# 3     https://tka.tiki.vn/pixel/pixel?data=FCsD3RfjN...     -15%   175.0
# 4     https://tka.tiki.vn/pixel/pixel?data=MIqoFjp6a...     -10%     7.0
# ...                                                 ...      ...     ...
# 1805  https://tiki.vn/nuoc-rua-binh-sua-d-nee-organi...      NaN    93.0
# 1806  https://tiki.vn/chau-tam-gap-gon-size-lon-cho-...      NaN    35.0
# 1807  https://tiki.vn/nuoc-rua-binh-sua-d-nee-organi...      NaN   101.0
# 1808  https://tiki.vn/set-10-bit-o-dien-chong-giat-m...      NaN    91.0
# 1809  https://tiki.vn/mieng-bit-goc-ban-ghe-hinh-cha...      NaN   444.0
#
#          category       revenue
# 0     dodungchobe  1.225000e+09
# 1     dodungchobe  1.450400e+07
# 2     dodungchobe  1.404000e+07
# 3     dodungchobe  1.522500e+07
# 4     dodungchobe  1.575000e+06
# ...           ...           ...
# 1805  dodungchobe  8.835000e+06
# 1806  dodungchobe  1.190000e+07
# 1807  dodungchobe  5.959000e+06
# 1808  dodungchobe  2.730000e+06
# 1809  dodungchobe  1.958040e+07
#
# [1810 rows x 7 columns]

# %%
df_all.to_csv("tk_dodungchobe_all_ed.csv")
