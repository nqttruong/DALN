# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\dochoi_mevabe\dochoi"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dochoi_all.ipynb',
#  'tk_dochoi_t1.csv',
#  'tk_dochoi_t10.csv',
#  'tk_dochoi_t11.csv',
#  'tk_dochoi_t12.csv',
#  'tk_dochoi_t13.csv',
#  'tk_dochoi_t14.csv',
#  'tk_dochoi_t15.csv',
#  'tk_dochoi_t16.csv',
#  'tk_dochoi_t17.csv',
#  'tk_dochoi_t18.csv',
#  'tk_dochoi_t19.csv',
#  'tk_dochoi_t2.csv',
#  'tk_dochoi_t20.csv',
#  'tk_dochoi_t21.csv',
#  'tk_dochoi_t22.csv',
#  'tk_dochoi_t23.csv',
#  'tk_dochoi_t24.csv',
#  'tk_dochoi_t25.csv',
#  'tk_dochoi_t26.csv',
#  'tk_dochoi_t27.csv',
#  'tk_dochoi_t28.csv',
#  'tk_dochoi_t29.csv',
#  'tk_dochoi_t3.csv',
#  'tk_dochoi_t30.csv',
#  'tk_dochoi_t31.csv',
#  'tk_dochoi_t32.csv',
#  'tk_dochoi_t33.csv',
#  'tk_dochoi_t34.csv',
#  'tk_dochoi_t35.csv',
#  'tk_dochoi_t36.csv',
#  'tk_dochoi_t37.csv',
#  'tk_dochoi_t38.csv',
#  'tk_dochoi_t39.csv',
#  'tk_dochoi_t4.csv',
#  'tk_dochoi_t40.csv',
#  'tk_dochoi_t41.csv',
#  'tk_dochoi_t42.csv',
#  'tk_dochoi_t43.csv',
#  'tk_dochoi_t44.csv',
#  'tk_dochoi_t45.csv',
#  'tk_dochoi_t46.csv',
#  'tk_dochoi_t47.csv',
#  'tk_dochoi_t48.csv',
#  'tk_dochoi_t49.csv',
#  'tk_dochoi_t5.csv',
#  'tk_dochoi_t50.csv',
#  'tk_dochoi_t6.csv',
#  'tk_dochoi_t7.csv',
#  'tk_dochoi_t8.csv',
#  'tk_dochoi_t9.csv',
#  'tk_mvb_dochoi.ipynb',
#  'tk_mvb_dochoi_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dochoi_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Máy chơi game Buyfastcart Pop It phiên bản cải...    108.000₫
# 1   Sách Vải Lật Mở Đa Tương Tác Cho Bé 0 - 4 tuổi...    115.000₫
# 2   Xe scooter trẻ em Scoot and Ride Highwaykick 3...  1.870.000₫
# 3   Bàn cờ vua gỗ Cao cấp, dành cho trẻ em giúp ph...  1.504.000₫
# 4   Đồ Chơi Cát Ma Thuật Mideer Magic Sand Play Se...    589.000₫
# ..                                                ...         ...
# 35  ĐỒ CHƠI TÀU HOẢ ÔNG GIÀ NOEL CHẠY TRÊN ĐƯỜNG R...    195.000₫
# 36  Combo 4 Rubik Biến Thể QiYi Gift Box Mastermor...    204.000₫
# 37  Gấu Bông Gối Ôm Thú Bông, Nhồi Bông Hình Ly Tr...    129.000₫
# 38  Côn Trùng Giả Như Thật, Đồ Chơi Gián - Rết - B...      1.000₫
# 39                       Treo nôi cũi bộ thú xinh đẹp    179.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=DayQ1Gwcg...      1     -28%
# 1   https://tka.tiki.vn/pixel/pixel?data=4vMOxbZKl...      2     -15%
# 2   https://tka.tiki.vn/pixel/pixel?data=m4T1qkJdK...      3      -9%
# 3   https://tka.tiki.vn/pixel/pixel?data=fELwCVQMf...      4     -21%
# 4   https://tka.tiki.vn/pixel/pixel?data=7MiFR7Sld...      5     -23%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/do-choi-tau-hoa-ong-gia-noel-c...     36      NaN
# 36  https://tiki.vn/combo-4-rubik-bien-the-qiyi-gi...     37      NaN
# 37  https://tiki.vn/gau-bong-goi-om-thu-bong-nhoi-...     38      NaN
# 38  https://tiki.vn/con-trung-gia-nhu-that-do-choi...     39      NaN
# 39  https://tiki.vn/treo-noi-cui-bo-thu-xinh-dep-p...     40      NaN
#
#          sales category
# 0    Đã bán 68   dochoi
# 1          NaN   dochoi
# 2          NaN   dochoi
# 3          NaN   dochoi
# 4    Đã bán 24   dochoi
# ..         ...      ...
# 35   Đã bán 31   dochoi
# 36    Đã bán 6   dochoi
# 37   Đã bán 46   dochoi
# 38  Đã bán 421   dochoi
# 39    Đã bán 9   dochoi
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Máy chơi game Buyfastcart Pop It phiên bản cải...  108.000₫
# 1     Đồ Chơi Cát Ma Thuật Mideer Magic Sand Play Se...  589.000₫
# 2                  Xe chòi ô tô cho bé - màu xanh dương  200.000₫
# 3     Xe Chòi Chân Vận Động Kiêm Xe Đạp 3 Bánh Cho B...  199.000₫
# 4     Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...  275.000₫
# ...                                                 ...       ...
# 1981  ĐỒ CHƠI TÀU HOẢ ÔNG GIÀ NOEL CHẠY TRÊN ĐƯỜNG R...  195.000₫
# 1982  Combo 4 Rubik Biến Thể QiYi Gift Box Mastermor...  204.000₫
# 1983  Gấu Bông Gối Ôm Thú Bông, Nhồi Bông Hình Ly Tr...  129.000₫
# 1984  Côn Trùng Giả Như Thật, Đồ Chơi Gián - Rết - B...    1.000₫
# 1985                       Treo nôi cũi bộ thú xinh đẹp  179.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=DayQ1Gwcg...     -28%   Đã bán 68
# 1     https://tka.tiki.vn/pixel/pixel?data=7MiFR7Sld...     -23%   Đã bán 24
# 2     https://tiki.vn/xe-choi-o-to-cho-be-mau-xanh-d...     -28%  Đã bán 440
# 3     https://tiki.vn/xe-choi-chan-van-dong-kiem-xe-...     -17%  Đã bán 307
# 4     https://tiki.vn/xe-lac-cho-be-xe-choi-chan-tre...     -37%  Đã bán 534
# ...                                                 ...      ...         ...
# 1981  https://tiki.vn/do-choi-tau-hoa-ong-gia-noel-c...      NaN   Đã bán 31
# 1982  https://tiki.vn/combo-4-rubik-bien-the-qiyi-gi...      NaN    Đã bán 6
# 1983  https://tiki.vn/gau-bong-goi-om-thu-bong-nhoi-...      NaN   Đã bán 46
# 1984  https://tiki.vn/con-trung-gia-nhu-that-do-choi...      NaN  Đã bán 421
# 1985  https://tiki.vn/treo-noi-cui-bo-thu-xinh-dep-p...      NaN    Đã bán 9
#
#      category
# 0      dochoi
# 1      dochoi
# 2      dochoi
# 3      dochoi
# 4      dochoi
# ...       ...
# 1981   dochoi
# 1982   dochoi
# 1983   dochoi
# 1984   dochoi
# 1985   dochoi
#
# [1986 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       108000
# 1       589000
# 2       200000
# 3       199000
# 4       275000
#          ...
# 1981    195000
# 1982    204000
# 1983    129000
# 1984      1000
# 1985    179000
# Name: price, Length: 1986, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        68.0
# 1        24.0
# 2       440.0
# 3       307.0
# 4       534.0
#         ...
# 1981     31.0
# 1982      6.0
# 1983     46.0
# 1984    421.0
# 1985      9.0
# Name: sales, Length: 1986, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0         7344000.0
# 1        14136000.0
# 2        88000000.0
# 3        61093000.0
# 4       146850000.0
#            ...
# 1981      6045000.0
# 1982      1224000.0
# 1983      5934000.0
# 1984       421000.0
# 1985      1611000.0
# Name: revenue, Length: 1986, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dochoi: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dochoi:  24578454451.0
# So mat hang da ban:  1986
# So san pham da ban:  145620.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Máy chơi game Buyfastcart Pop It phiên bản cải...  108000
# 1     Đồ Chơi Cát Ma Thuật Mideer Magic Sand Play Se...  589000
# 2                  Xe chòi ô tô cho bé - màu xanh dương  200000
# 3     Xe Chòi Chân Vận Động Kiêm Xe Đạp 3 Bánh Cho B...  199000
# 4     Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...  275000
# ...                                                 ...     ...
# 1981  ĐỒ CHƠI TÀU HOẢ ÔNG GIÀ NOEL CHẠY TRÊN ĐƯỜNG R...  195000
# 1982  Combo 4 Rubik Biến Thể QiYi Gift Box Mastermor...  204000
# 1983  Gấu Bông Gối Ôm Thú Bông, Nhồi Bông Hình Ly Tr...  129000
# 1984  Côn Trùng Giả Như Thật, Đồ Chơi Gián - Rết - B...    1000
# 1985                       Treo nôi cũi bộ thú xinh đẹp  179000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=DayQ1Gwcg...     -28%   68.0
# 1     https://tka.tiki.vn/pixel/pixel?data=7MiFR7Sld...     -23%   24.0
# 2     https://tiki.vn/xe-choi-o-to-cho-be-mau-xanh-d...     -28%  440.0
# 3     https://tiki.vn/xe-choi-chan-van-dong-kiem-xe-...     -17%  307.0
# 4     https://tiki.vn/xe-lac-cho-be-xe-choi-chan-tre...     -37%  534.0
# ...                                                 ...      ...    ...
# 1981  https://tiki.vn/do-choi-tau-hoa-ong-gia-noel-c...      NaN   31.0
# 1982  https://tiki.vn/combo-4-rubik-bien-the-qiyi-gi...      NaN    6.0
# 1983  https://tiki.vn/gau-bong-goi-om-thu-bong-nhoi-...      NaN   46.0
# 1984  https://tiki.vn/con-trung-gia-nhu-that-do-choi...      NaN  421.0
# 1985  https://tiki.vn/treo-noi-cui-bo-thu-xinh-dep-p...      NaN    9.0
#
#      category      revenue
# 0      dochoi    7344000.0
# 1      dochoi   14136000.0
# 2      dochoi   88000000.0
# 3      dochoi   61093000.0
# 4      dochoi  146850000.0
# ...       ...          ...
# 1981   dochoi    6045000.0
# 1982   dochoi    1224000.0
# 1983   dochoi    5934000.0
# 1984   dochoi     421000.0
# 1985   dochoi    1611000.0
#
# [1986 rows x 7 columns]

# %%
df_all.to_csv("tk_dochoi_all_ed.csv")
