# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\dochoi_mevabe\tabim"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_mvb_tabim.ipynb',
#  'tk_mvb_tabim_npage.ipynb',
#  'tk_tabim_all.ipynb',
#  'tk_tabim_t1.csv',
#  'tk_tabim_t10.csv',
#  'tk_tabim_t11.csv',
#  'tk_tabim_t12.csv',
#  'tk_tabim_t13.csv',
#  'tk_tabim_t14.csv',
#  'tk_tabim_t15.csv',
#  'tk_tabim_t16.csv',
#  'tk_tabim_t17.csv',
#  'tk_tabim_t18.csv',
#  'tk_tabim_t19.csv',
#  'tk_tabim_t2.csv',
#  'tk_tabim_t20.csv',
#  'tk_tabim_t21.csv',
#  'tk_tabim_t22.csv',
#  'tk_tabim_t23.csv',
#  'tk_tabim_t24.csv',
#  'tk_tabim_t25.csv',
#  'tk_tabim_t26.csv',
#  'tk_tabim_t27.csv',
#  'tk_tabim_t28.csv',
#  'tk_tabim_t29.csv',
#  'tk_tabim_t3.csv',
#  'tk_tabim_t30.csv',
#  'tk_tabim_t31.csv',
#  'tk_tabim_t32.csv',
#  'tk_tabim_t33.csv',
#  'tk_tabim_t34.csv',
#  'tk_tabim_t35.csv',
#  'tk_tabim_t36.csv',
#  'tk_tabim_t37.csv',
#  'tk_tabim_t38.csv',
#  'tk_tabim_t39.csv',
#  'tk_tabim_t4.csv',
#  'tk_tabim_t40.csv',
#  'tk_tabim_t41.csv',
#  'tk_tabim_t42.csv',
#  'tk_tabim_t43.csv',
#  'tk_tabim_t44.csv',
#  'tk_tabim_t45.csv',
#  'tk_tabim_t46.csv',
#  'tk_tabim_t47.csv',
#  'tk_tabim_t48.csv',
#  'tk_tabim_t49.csv',
#  'tk_tabim_t5.csv',
#  'tk_tabim_t50.csv',
#  'tk_tabim_t6.csv',
#  'tk_tabim_t7.csv',
#  'tk_tabim_t8.csv',
#  'tk_tabim_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_tabim_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185.000₫
# 1   Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385.000₫
# 2   Combo 3 Tã dán Huggies Skincare Super Jumbo M ...  769.000₫
# 3   Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size M...  385.000₫
# 4   Tã/bỉm quần HUGGIES SKINCARE gói SUPER JUMBO s...  299.000₫
# ..                                                ...       ...
# 35  Combo 3 Gói Khăn Ướt Max Clean 100 Tờ Không Hư...   73.200₫
# 36  Tã dán người lớn Abena Abri Form Premium - Nhậ...  240.000₫
# 37  Bộ 10 Cái Tã Vải Sơ Sinh Cho Bé ( màu ngẫu nhi...   59.800₫
# 38  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273.000₫
# 39  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=1LW9ac77C...      1     -34%
# 1   https://tka.tiki.vn/pixel/pixel?data=cH5yCy8Ny...      2     -40%
# 2   https://tka.tiki.vn/pixel/pixel?data=rDQ4qleCX...      3     -25%
# 3   https://tka.tiki.vn/pixel/pixel?data=oeuvsw1Mh...      4     -40%
# 4   https://tka.tiki.vn/pixel/pixel?data=nm5cSFeoP...      5     -37%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/combo-4-goi-khan-uot-max-clean...     36      NaN
# 36  https://tiki.vn/tham-hut-2500ml-ta-dan-bim-ngu...     37      NaN
# 37  https://tiki.vn/bo-10-cai-ta-vai-so-sinh-nhieu...     38      NaN
# 38  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...     39      NaN
# 39  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...     40      NaN
#
#          sales category
# 0   Đã bán 5k+    tabim
# 1   Đã bán 5k+    tabim
# 2   Đã bán 445    tabim
# 3   Đã bán 884    tabim
# 4   Đã bán 5k+    tabim
# ..         ...      ...
# 35   Đã bán 30    tabim
# 36   Đã bán 35    tabim
# 37   Đã bán 60    tabim
# 38  Đã bán 217    tabim
# 39  Đã bán 189    tabim
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185.000₫
# 1     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385.000₫
# 2     Combo 3 Tã dán Huggies Skincare Super Jumbo M ...  769.000₫
# 3     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size M...  385.000₫
# 4     Tã/bỉm quần HUGGIES SKINCARE gói SUPER JUMBO s...  299.000₫
# ...                                                 ...       ...
# 1427  Combo 3 Gói Khăn Ướt Max Clean 100 Tờ Không Hư...   73.200₫
# 1428  Tã dán người lớn Abena Abri Form Premium - Nhậ...  240.000₫
# 1429  Bộ 10 Cái Tã Vải Sơ Sinh Cho Bé ( màu ngẫu nhi...   59.800₫
# 1430  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273.000₫
# 1431  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=1LW9ac77C...     -34%  Đã bán 5k+
# 1     https://tka.tiki.vn/pixel/pixel?data=cH5yCy8Ny...     -40%  Đã bán 5k+
# 2     https://tka.tiki.vn/pixel/pixel?data=rDQ4qleCX...     -25%  Đã bán 445
# 3     https://tka.tiki.vn/pixel/pixel?data=oeuvsw1Mh...     -40%  Đã bán 884
# 4     https://tka.tiki.vn/pixel/pixel?data=nm5cSFeoP...     -37%  Đã bán 5k+
# ...                                                 ...      ...         ...
# 1427  https://tiki.vn/combo-4-goi-khan-uot-max-clean...      NaN   Đã bán 30
# 1428  https://tiki.vn/tham-hut-2500ml-ta-dan-bim-ngu...      NaN   Đã bán 35
# 1429  https://tiki.vn/bo-10-cai-ta-vai-so-sinh-nhieu...      NaN   Đã bán 60
# 1430  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...      NaN  Đã bán 217
# 1431  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...      NaN  Đã bán 189
#
#      category
# 0       tabim
# 1       tabim
# 2       tabim
# 3       tabim
# 4       tabim
# ...       ...
# 1427    tabim
# 1428    tabim
# 1429    tabim
# 1430    tabim
# 1431    tabim
#
# [1432 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       185000
# 1       385000
# 2       769000
# 3       385000
# 4       299000
#          ...
# 1427     73200
# 1428    240000
# 1429     59800
# 1430    273000
# 1431    275000
# Name: price, Length: 1432, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       5000.0
# 1       5000.0
# 2        445.0
# 3        884.0
# 4       5000.0
#          ...
# 1427      30.0
# 1428      35.0
# 1429      60.0
# 1430     217.0
# 1431     189.0
# Name: sales, Length: 1432, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       9.250000e+08
# 1       1.925000e+09
# 2       3.422050e+08
# 3       3.403400e+08
# 4       1.495000e+09
#             ...
# 1427    2.196000e+06
# 1428    8.400000e+06
# 1429    3.588000e+06
# 1430    5.924100e+07
# 1431    5.197500e+07
# Name: revenue, Length: 1432, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số tabim: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số tabim:  104164577216.0
# So mat hang da ban:  1432
# So san pham da ban:  394646.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185000
# 1     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385000
# 2     Combo 3 Tã dán Huggies Skincare Super Jumbo M ...  769000
# 3     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size M...  385000
# 4     Tã/bỉm quần HUGGIES SKINCARE gói SUPER JUMBO s...  299000
# ...                                                 ...     ...
# 1427  Combo 3 Gói Khăn Ướt Max Clean 100 Tờ Không Hư...   73200
# 1428  Tã dán người lớn Abena Abri Form Premium - Nhậ...  240000
# 1429  Bộ 10 Cái Tã Vải Sơ Sinh Cho Bé ( màu ngẫu nhi...   59800
# 1430  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273000
# 1431  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=1LW9ac77C...     -34%  5000.0
# 1     https://tka.tiki.vn/pixel/pixel?data=cH5yCy8Ny...     -40%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=rDQ4qleCX...     -25%   445.0
# 3     https://tka.tiki.vn/pixel/pixel?data=oeuvsw1Mh...     -40%   884.0
# 4     https://tka.tiki.vn/pixel/pixel?data=nm5cSFeoP...     -37%  5000.0
# ...                                                 ...      ...     ...
# 1427  https://tiki.vn/combo-4-goi-khan-uot-max-clean...      NaN    30.0
# 1428  https://tiki.vn/tham-hut-2500ml-ta-dan-bim-ngu...      NaN    35.0
# 1429  https://tiki.vn/bo-10-cai-ta-vai-so-sinh-nhieu...      NaN    60.0
# 1430  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...      NaN   217.0
# 1431  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...      NaN   189.0
#
#      category       revenue
# 0       tabim  9.250000e+08
# 1       tabim  1.925000e+09
# 2       tabim  3.422050e+08
# 3       tabim  3.403400e+08
# 4       tabim  1.495000e+09
# ...       ...           ...
# 1427    tabim  2.196000e+06
# 1428    tabim  8.400000e+06
# 1429    tabim  3.588000e+06
# 1430    tabim  5.924100e+07
# 1431    tabim  5.197500e+07
#
# [1432 rows x 7 columns]

# %%
df_all.to_csv("tk_tabim_all_ed.csv")
