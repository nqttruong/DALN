# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\diengiadung"
os.listdir(path)
# Out:
# ['brand - Copy (3)',
#  'category.ipynb',
#  'dodungnhabep',
#  'thietbigiadinh',
#  'tk_dodungnhabep_all_ed.csv',
#  'tk_thietbigiadinh_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#       Unnamed: 0                                              title    price  \
# 0              0  Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1999000
# 1              1  Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   229000
# 2              2  Lò Nướng Điện Sunhouse SHD4206 (10L) - Hàng ch...   439000
# 3              3  Nồi Cơm Điện Nắp Gài Sunhouse SHD8217W (1.2L) ...   560000
# 4              4  Nồi Chiên Không Dầu Sunhouse SHD4027 (6 Lít) -...  1399000
# ...          ...                                                ...      ...
# 1279        1279                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP   390000
# 1280        1280  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...   450000
# 1281        1281  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1599000
# 1282        1282  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    59000
# 1283        1283  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   600000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=Yx2a2FGGA...     -31%  2300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=cGSEV7brf...     -46%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=BKgZ-8Uqq...     -44%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=9TjeXzye8...     -46%   992.0
# 4     https://tka.tiki.vn/pixel/pixel?data=bvaCo6q9l...     -41%   488.0
# ...                                                 ...      ...     ...
# 1279  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    26.0
# 1280  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    14.0
# 1281  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    39.0
# 1282  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1283  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   395.0
#
#             category       revenue
# 0       dodungnhabep  4.597700e+09
# 1       dodungnhabep  1.145000e+09
# 2       dodungnhabep  2.195000e+09
# 3       dodungnhabep  5.555200e+08
# 4       dodungnhabep  6.827120e+08
# ...              ...           ...
# 1279  thietbigiadinh  1.014000e+07
# 1280  thietbigiadinh  6.300000e+06
# 1281  thietbigiadinh  6.236100e+07
# 1282  thietbigiadinh  1.475000e+06
# 1283  thietbigiadinh  2.370000e+08
#
# [2612 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "diengiadung")

# %%
df
# Out:
#                                                   title    price  \
# 0     Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1999000
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   229000
# 2     Lò Nướng Điện Sunhouse SHD4206 (10L) - Hàng ch...   439000
# 3     Nồi Cơm Điện Nắp Gài Sunhouse SHD8217W (1.2L) ...   560000
# 4     Nồi Chiên Không Dầu Sunhouse SHD4027 (6 Lít) -...  1399000
# ...                                                 ...      ...
# 1279                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP   390000
# 1280  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...   450000
# 1281  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1599000
# 1282  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    59000
# 1283  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   600000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=Yx2a2FGGA...     -31%  2300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=cGSEV7brf...     -46%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=BKgZ-8Uqq...     -44%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=9TjeXzye8...     -46%   992.0
# 4     https://tka.tiki.vn/pixel/pixel?data=bvaCo6q9l...     -41%   488.0
# ...                                                 ...      ...     ...
# 1279  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    26.0
# 1280  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    14.0
# 1281  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    39.0
# 1282  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1283  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   395.0
#
#            item_list     category       revenue
# 0       dodungnhabep  diengiadung  4.597700e+09
# 1       dodungnhabep  diengiadung  1.145000e+09
# 2       dodungnhabep  diengiadung  2.195000e+09
# 3       dodungnhabep  diengiadung  5.555200e+08
# 4       dodungnhabep  diengiadung  6.827120e+08
# ...              ...          ...           ...
# 1279  thietbigiadinh  diengiadung  1.014000e+07
# 1280  thietbigiadinh  diengiadung  6.300000e+06
# 1281  thietbigiadinh  diengiadung  6.236100e+07
# 1282  thietbigiadinh  diengiadung  1.475000e+06
# 1283  thietbigiadinh  diengiadung  2.370000e+08
#
# [2612 rows x 8 columns]

# %%
df.to_csv('tk_diengiadung_all_ed.csv', index=False, encoding='utf-8')
