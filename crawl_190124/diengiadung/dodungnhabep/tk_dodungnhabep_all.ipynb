# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\diengiadung\dodungnhabep"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dgd_ddnb.ipynb',
#  'tk_dgd_ddnb_npage.ipynb',
#  'tk_dodungnhabep.csv',
#  'tk_dodungnhabep_all.ipynb',
#  'tk_dodungnhabep_t10.csv',
#  'tk_dodungnhabep_t11.csv',
#  'tk_dodungnhabep_t12.csv',
#  'tk_dodungnhabep_t13.csv',
#  'tk_dodungnhabep_t14.csv',
#  'tk_dodungnhabep_t15.csv',
#  'tk_dodungnhabep_t16.csv',
#  'tk_dodungnhabep_t17.csv',
#  'tk_dodungnhabep_t18.csv',
#  'tk_dodungnhabep_t19.csv',
#  'tk_dodungnhabep_t2.csv',
#  'tk_dodungnhabep_t20.csv',
#  'tk_dodungnhabep_t21.csv',
#  'tk_dodungnhabep_t22.csv',
#  'tk_dodungnhabep_t23.csv',
#  'tk_dodungnhabep_t24.csv',
#  'tk_dodungnhabep_t25.csv',
#  'tk_dodungnhabep_t26.csv',
#  'tk_dodungnhabep_t27.csv',
#  'tk_dodungnhabep_t28.csv',
#  'tk_dodungnhabep_t29.csv',
#  'tk_dodungnhabep_t3.csv',
#  'tk_dodungnhabep_t30.csv',
#  'tk_dodungnhabep_t31.csv',
#  'tk_dodungnhabep_t32.csv',
#  'tk_dodungnhabep_t33.csv',
#  'tk_dodungnhabep_t34.csv',
#  'tk_dodungnhabep_t35.csv',
#  'tk_dodungnhabep_t36.csv',
#  'tk_dodungnhabep_t37.csv',
#  'tk_dodungnhabep_t38.csv',
#  'tk_dodungnhabep_t39.csv',
#  'tk_dodungnhabep_t4.csv',
#  'tk_dodungnhabep_t40.csv',
#  'tk_dodungnhabep_t41.csv',
#  'tk_dodungnhabep_t42.csv',
#  'tk_dodungnhabep_t43.csv',
#  'tk_dodungnhabep_t44.csv',
#  'tk_dodungnhabep_t45.csv',
#  'tk_dodungnhabep_t46.csv',
#  'tk_dodungnhabep_t47.csv',
#  'tk_dodungnhabep_t48.csv',
#  'tk_dodungnhabep_t49.csv',
#  'tk_dodungnhabep_t5.csv',
#  'tk_dodungnhabep_t50.csv',
#  'tk_dodungnhabep_t6.csv',
#  'tk_dodungnhabep_t7.csv',
#  'tk_dodungnhabep_t8.csv',
#  'tk_dodungnhabep_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dodungnhabep_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1.999.000₫
# 1   Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...    229.000₫
# 2   Lò Nướng Điện Sunhouse SHD4206 (10L) - Hàng ch...    439.000₫
# 3   Nồi Cơm Điện Nắp Gài Sunhouse SHD8217W (1.2L) ...    560.000₫
# 4   Nồi Chiên Không Dầu Sunhouse SHD4027 (6 Lít) -...  1.399.000₫
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36  Nồi Lẩu Mini, Ca Nấu Mì Nấu Cơm Đa Năng Có Tay...     86.340₫
# 37  Máy Làm Sữa Hạt Đa Năng Locknlock Heating Blen...  1.970.000₫
# 38  Nồi Chiên Không Dầu Elmich AFE-3950 (14Lít) - ...  3.019.000₫
# 39  Bình đun siêu tốc thông minh 1.7L Tefal Smart ...   1.549.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=Yx2a2FGGA...      1     -31%
# 1   https://tka.tiki.vn/pixel/pixel?data=cGSEV7brf...      2     -46%
# 2   https://tka.tiki.vn/pixel/pixel?data=BKgZ-8Uqq...      3     -44%
# 3   https://tka.tiki.vn/pixel/pixel?data=9TjeXzye8...      4     -46%
# 4   https://tka.tiki.vn/pixel/pixel?data=bvaCo6q9l...      5     -41%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/may-nuong-banh-nikai-kep-banh-...     36      NaN
# 36  https://tiki.vn/noi-lau-mini-ca-nau-mi-nau-com...     37      NaN
# 37  https://tiki.vn/may-lam-sua-hat-da-nang-locknl...     38      NaN
# 38  https://tiki.vn/noi-chien-khong-dau-elmich-afe...     39      NaN
# 39  https://tiki.vn/binh-dun-sieu-toc-thong-minh-1...     40      NaN
#
#           sales      category
# 0   Đã bán 2.3k  dodungnhabep
# 1    Đã bán 5k+  dodungnhabep
# 2    Đã bán 5k+  dodungnhabep
# 3    Đã bán 992  dodungnhabep
# 4    Đã bán 488  dodungnhabep
# ..          ...           ...
# 35          NaN  dodungnhabep
# 36     Đã bán 3  dodungnhabep
# 37    Đã bán 46  dodungnhabep
# 38    Đã bán 50  dodungnhabep
# 39          NaN  dodungnhabep
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1.999.000₫
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...    229.000₫
# 2     Lò Nướng Điện Sunhouse SHD4206 (10L) - Hàng ch...    439.000₫
# 3     Nồi Cơm Điện Nắp Gài Sunhouse SHD8217W (1.2L) ...    560.000₫
# 4     Nồi Chiên Không Dầu Sunhouse SHD4027 (6 Lít) -...  1.399.000₫
# ...                                                 ...         ...
# 1323  Máy Xay Sinh Tố Cầm Tay YOICE REKKY (150W - 30...    369.000₫
# 1324  Giấy Lọc Cà Phê Melitta Original 1x2 Hộp 40 tờ...     37.800₫
# 1325  Nồi Lẩu Mini, Ca Nấu Mì Nấu Cơm Đa Năng Có Tay...     86.340₫
# 1326  Máy Làm Sữa Hạt Đa Năng Locknlock Heating Blen...  1.970.000₫
# 1327  Nồi Chiên Không Dầu Elmich AFE-3950 (14Lít) - ...  3.019.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=Yx2a2FGGA...     -31%  Đã bán 2.3k
# 1     https://tka.tiki.vn/pixel/pixel?data=cGSEV7brf...     -46%   Đã bán 5k+
# 2     https://tka.tiki.vn/pixel/pixel?data=BKgZ-8Uqq...     -44%   Đã bán 5k+
# 3     https://tka.tiki.vn/pixel/pixel?data=9TjeXzye8...     -46%   Đã bán 992
# 4     https://tka.tiki.vn/pixel/pixel?data=bvaCo6q9l...     -41%   Đã bán 488
# ...                                                 ...      ...          ...
# 1323  https://tiki.vn/may-xay-sinh-to-cam-tay-yoice-...      NaN   Đã bán 199
# 1324  https://tiki.vn/giay-loc-ca-phe-melitta-duc-1x...      NaN   Đã bán 100
# 1325  https://tiki.vn/noi-lau-mini-ca-nau-mi-nau-com...      NaN     Đã bán 3
# 1326  https://tiki.vn/may-lam-sua-hat-da-nang-locknl...      NaN    Đã bán 46
# 1327  https://tiki.vn/noi-chien-khong-dau-elmich-afe...      NaN    Đã bán 50
#
#           category
# 0     dodungnhabep
# 1     dodungnhabep
# 2     dodungnhabep
# 3     dodungnhabep
# 4     dodungnhabep
# ...            ...
# 1323  dodungnhabep
# 1324  dodungnhabep
# 1325  dodungnhabep
# 1326  dodungnhabep
# 1327  dodungnhabep
#
# [1328 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       1999000
# 1        229000
# 2        439000
# 3        560000
# 4       1399000
#          ...
# 1323     369000
# 1324      37800
# 1325      86340
# 1326    1970000
# 1327    3019000
# Name: price, Length: 1328, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       2300.0
# 1       5000.0
# 2       5000.0
# 3        992.0
# 4        488.0
#          ...
# 1323     199.0
# 1324     100.0
# 1325       3.0
# 1326      46.0
# 1327      50.0
# Name: sales, Length: 1328, dtype: float64

# %%
print(set(df_all["sales"]))
# Out:
# {1.0, 2.0, 3.0, 4100.0, 5.0, 6.0, 7.0, 8.0, 4.0, 9.0, 10.0, 12.0, 13.0, 14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0, 32.0, 33.0, 34.0, 35.0, 36.0, 37.0, 38.0, 39.0, 40.0, 41.0, 42.0, 43.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 2100.0, 52.0, 54.0, 53.0, 56.0, 11.0, 55.0, 59.0, 60.0, 61.0, 57.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 62.0, 70.0, 71.0, 72.0, 73.0, 74.0, 75.0, 76.0, 77.0, 78.0, 79.0, 80.0, 81.0, 82.0, 83.0, 84.0, 85.0, 86.0, 87.0, 88.0, 90.0, 91.0, 92.0, 93.0, 94.0, 95.0, 96.0, 97.0, 100.0, 101.0, 4200.0, 105.0, 104.0, 107.0, 106.0, 109.0, 110.0, 111.0, 112.0, 113.0, 114.0, 115.0, 116.0, 118.0, 119.0, 120.0, 121.0, 122.0, 124.0, 126.0, 128.0, 129.0, 132.0, 134.0, 135.0, 137.0, 138.0, 140.0, 141.0, 142.0, 144.0, 145.0, 147.0, 149.0, 151.0, 152.0, 2200.0, 154.0, 155.0, 156.0, 159.0, 160.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 171.0, 175.0, 179.0, 180.0, 182.0, 183.0, 185.0, 187.0, 188.0, 192.0, 195.0, 199.0, 201.0, 202.0, 4300.0, 206.0, 207.0, 211.0, 212.0, 213.0, 217.0, 219.0, 220.0, 222.0, 223.0, 225.0, 226.0, 227.0, 228.0, 230.0, 231.0, 237.0, 244.0, 247.0, 248.0, 250.0, 251.0, 2300.0, 253.0, 254.0, 256.0, 261.0, 264.0, 266.0, 269.0, 272.0, 275.0, 276.0, 278.0, 280.0, 281.0, 288.0, 291.0, 58.0, 293.0, 297.0, 299.0, 305.0, 306.0, 313.0, 319.0, 321.0, 323.0, 328.0, 329.0, 336.0, 337.0, 342.0, 344.0, 348.0, 2400.0, 356.0, 358.0, 362.0, 370.0, 379.0, 380.0, 383.0, 386.0, 388.0, 391.0, 402.0, 406.0, 414.0, 416.0, 422.0, 423.0, 425.0, 428.0, 430.0, 439.0, 451.0, 2500.0, 457.0, 458.0, 472.0, 483.0, 488.0, 493.0, 502.0, 509.0, 510.0, 511.0, 516.0, 536.0, 544.0, 545.0, 549.0, 2600.0, 559.0, 562.0, 568.0, 572.0, 574.0, 579.0, 581.0, 613.0, 619.0, 642.0, 645.0, 2700.0, 657.0, 660.0, 670.0, 671.0, 688.0, 696.0, 704.0, 706.0, 726.0, 746.0, 747.0, 2800.0, 756.0, 781.0, 792.0, 794.0, 796.0, 805.0, 806.0, 835.0, 843.0, 2900.0, 895.0, 896.0, 5000.0, 905.0, 936.0, 938.0, 3000.0, 987.0, 992.0, 1000.0, 1100.0, 1200.0, 3300.0, 1300.0, 3400.0, 1400.0, 1500.0, 3600.0, 3700.0, 1700.0, 3800.0, 1800.0, 3900.0, 1900.0, 2000.0}

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       4.597700e+09
# 1       1.145000e+09
# 2       2.195000e+09
# 3       5.555200e+08
# 4       6.827120e+08
#             ...
# 1323    7.343100e+07
# 1324    3.780000e+06
# 1325    2.590200e+05
# 1326    9.062000e+07
# 1327    1.509500e+08
# Name: revenue, Length: 1328, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số đồ dùng nhà bếp: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số đồ dùng nhà bếp:  278151358692.0
# So mat hang da ban:  1328
# So san pham da ban:  368093.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1999000
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   229000
# 2     Lò Nướng Điện Sunhouse SHD4206 (10L) - Hàng ch...   439000
# 3     Nồi Cơm Điện Nắp Gài Sunhouse SHD8217W (1.2L) ...   560000
# 4     Nồi Chiên Không Dầu Sunhouse SHD4027 (6 Lít) -...  1399000
# ...                                                 ...      ...
# 1323  Máy Xay Sinh Tố Cầm Tay YOICE REKKY (150W - 30...   369000
# 1324  Giấy Lọc Cà Phê Melitta Original 1x2 Hộp 40 tờ...    37800
# 1325  Nồi Lẩu Mini, Ca Nấu Mì Nấu Cơm Đa Năng Có Tay...    86340
# 1326  Máy Làm Sữa Hạt Đa Năng Locknlock Heating Blen...  1970000
# 1327  Nồi Chiên Không Dầu Elmich AFE-3950 (14Lít) - ...  3019000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=Yx2a2FGGA...     -31%  2300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=cGSEV7brf...     -46%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=BKgZ-8Uqq...     -44%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=9TjeXzye8...     -46%   992.0
# 4     https://tka.tiki.vn/pixel/pixel?data=bvaCo6q9l...     -41%   488.0
# ...                                                 ...      ...     ...
# 1323  https://tiki.vn/may-xay-sinh-to-cam-tay-yoice-...      NaN   199.0
# 1324  https://tiki.vn/giay-loc-ca-phe-melitta-duc-1x...      NaN   100.0
# 1325  https://tiki.vn/noi-lau-mini-ca-nau-mi-nau-com...      NaN     3.0
# 1326  https://tiki.vn/may-lam-sua-hat-da-nang-locknl...      NaN    46.0
# 1327  https://tiki.vn/noi-chien-khong-dau-elmich-afe...      NaN    50.0
#
#           category       revenue
# 0     dodungnhabep  4.597700e+09
# 1     dodungnhabep  1.145000e+09
# 2     dodungnhabep  2.195000e+09
# 3     dodungnhabep  5.555200e+08
# 4     dodungnhabep  6.827120e+08
# ...            ...           ...
# 1323  dodungnhabep  7.343100e+07
# 1324  dodungnhabep  3.780000e+06
# 1325  dodungnhabep  2.590200e+05
# 1326  dodungnhabep  9.062000e+07
# 1327  dodungnhabep  1.509500e+08
#
# [1328 rows x 7 columns]

# %%
df_all.to_csv("tk_dodungnhabep_all_ed.csv")
