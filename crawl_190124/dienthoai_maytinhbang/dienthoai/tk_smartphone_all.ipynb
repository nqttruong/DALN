# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\dienthoai_maytinhbang\dienthoai"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_smartphone.csv',
#  'tk_smartphone.ipynb',
#  'tk_smartphone_all.ipynb',
#  'tk_smartphone_npage.ipynb',
#  'tk_smartphone_t10.csv',
#  'tk_smartphone_t11.csv',
#  'tk_smartphone_t12.csv',
#  'tk_smartphone_t2.csv',
#  'tk_smartphone_t3.csv',
#  'tk_smartphone_t4.csv',
#  'tk_smartphone_t5.csv',
#  'tk_smartphone_t6.csv',
#  'tk_smartphone_t7.csv',
#  'tk_smartphone_t8.csv',
#  'tk_smartphone_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_smartphone_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title        price  \
# 0   Điện thoại Samsung Galaxy S24 Ultra 5G- Hàng c...  44.490.000₫
# 1   Điện thoại Samsung Galaxy S24 5G - Hàng chính ...  22.990.000₫
# 2   Điện thoại Samsung Galaxy S24 Plus 5G - Hàng c...  30.490.000₫
# 3   [MỚI] Điện thoại vivo Y17s - Hàng chính hãng -...   3.790.000₫
# 4   Điện thoại VIVO Y02t - Hàng chính hãng - Pin K...   2.790.000₫
# ..                                                ...          ...
# 35                                                NaN          NaN
# 36  Điện Thoại Realme C51 4GB/128GB - Hàng Chính Hãng   3.085.000₫
# 37  Điện thoại Samsung Galaxy Z Flip4 5G (8 GB/128...  20.250.000₫
# 38  Điện thoại di động Samsung A24 (6G/128G) - Hàn...   5.808.000₫
# 39        Điện thoại OPPO Reno8T 4G - Hàng chính hãng    8.136.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=jeeOfIOjA...      1      -5%
# 1   https://tka.tiki.vn/pixel/pixel?data=mKkaJJaxj...      2     -15%
# 2   https://tka.tiki.vn/pixel/pixel?data=_qjvUHGXl...      3     -27%
# 3   https://tka.tiki.vn/pixel/pixel?data=TqXmxYn9l...      4     -28%
# 4   https://tka.tiki.vn/pixel/pixel?data=GJW8sUiFk...      5      -4%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/dien-thoai-samsung-galaxy-s23-...     36      NaN
# 36  https://tiki.vn/dien-thoai-realme-c51-4gb-128g...     37      NaN
# 37  https://tiki.vn/dien-thoai-samsung-galaxy-z-fl...     38      NaN
# 38  https://tiki.vn/dien-thoai-di-dong-samsung-a24...     39      NaN
# 39  https://tiki.vn/dien-thoai-oppo-reno8t-4g-hang...     40      NaN
#
#        sales    category
# 0        NaN  smartphone
# 1        NaN  smartphone
# 2        NaN  smartphone
# 3   Đã bán 5  smartphone
# 4   Đã bán 3  smartphone
# ..       ...         ...
# 35       NaN  smartphone
# 36       NaN  smartphone
# 37       NaN  smartphone
# 38       NaN  smartphone
# 39       NaN  smartphone
#
# [484 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title        price  \
# 0    [MỚI] Điện thoại vivo Y17s - Hàng chính hãng -...   3.790.000₫
# 1    Điện thoại VIVO Y02t - Hàng chính hãng - Pin K...   2.790.000₫
# 2                      Điện Thoại Oppo A17k (3GB/64GB)   2.390.000₫
# 3                Điện thoại Xiaomi Redmi 9A (2GB/32GB)   1.790.000₫
# 4                                    iPhone 15 Pro Max  31.990.000₫
# ..                                                 ...          ...
# 161   Điện Thoại Realme C51 3GB/64GB - Hàng Chính Hãng    2.699.000
# 162  Điện thoại Xiaomi Redmi 9A 2GB/32GB Xám - Hàng...   2.088.000₫
# 163  Điện Thoại Samsung Galaxy A14 5G (4GB/128GB) -...   5.000.000₫
# 164  Điện thoại TECNO Spark 6 Go (4GB/64GB) - Hàng ...   2.559.000₫
# 165  Điện thoại OPPO A57 4GB/128GB Đen - Hàng chính...   3.850.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=TqXmxYn9l...     -28%    Đã bán 5
# 1    https://tka.tiki.vn/pixel/pixel?data=GJW8sUiFk...      -4%    Đã bán 3
# 2    https://tiki.vn/dien-thoai-oppo-a17k-3gb-64gb-...     -37%  Đã bán 5k+
# 3    https://tiki.vn/dien-thoai-xiaomi-redmi-9a-2gb...      -4%  Đã bán 5k+
# 4    https://tiki.vn/apple-iphone-15-pro-max-p27197...     -17%  Đã bán 727
# ..                                                 ...      ...         ...
# 161  https://tiki.vn/dien-thoai-realme-c51-3gb-64gb...      NaN    Đã bán 1
# 162  https://tiki.vn/dien-thoai-xiaomi-redmi-9a-2gb...      NaN    Đã bán 1
# 163  https://tiki.vn/dien-thoai-samsung-galaxy-a14-...      NaN    Đã bán 1
# 164  https://tiki.vn/dien-thoai-tecno-spark-6-go-4g...      NaN    Đã bán 4
# 165  https://tiki.vn/dien-thoai-oppo-a57-4gb-128gb-...      NaN    Đã bán 1
#
#        category
# 0    smartphone
# 1    smartphone
# 2    smartphone
# 3    smartphone
# 4    smartphone
# ..          ...
# 161  smartphone
# 162  smartphone
# 163  smartphone
# 164  smartphone
# 165  smartphone
#
# [166 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       3790000
# 1       2790000
# 2       2390000
# 3       1790000
# 4      31990000
#          ...
# 161     2699000
# 162     2088000
# 163     5000000
# 164     2559000
# 165     3850000
# Name: price, Length: 166, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0         5.0
# 1         3.0
# 2      5000.0
# 3      5000.0
# 4       727.0
#         ...
# 161       1.0
# 162       1.0
# 163       1.0
# 164       4.0
# 165       1.0
# Name: sales, Length: 166, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      1.895000e+07
# 1      8.370000e+06
# 2      1.195000e+10
# 3      8.950000e+09
# 4      2.325673e+10
#            ...
# 161    2.699000e+06
# 162    2.088000e+06
# 163    5.000000e+06
# 164    1.023600e+07
# 165    3.850000e+06
# Name: revenue, Length: 166, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số smartphone: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số smartphone:  275164608000.0
# So mat hang da ban:  166
# So san pham da ban:  31677.0

# %%
df_all
# Out:
#                                                  title     price  \
# 0    [MỚI] Điện thoại vivo Y17s - Hàng chính hãng -...   3790000
# 1    Điện thoại VIVO Y02t - Hàng chính hãng - Pin K...   2790000
# 2                      Điện Thoại Oppo A17k (3GB/64GB)   2390000
# 3                Điện thoại Xiaomi Redmi 9A (2GB/32GB)   1790000
# 4                                    iPhone 15 Pro Max  31990000
# ..                                                 ...       ...
# 161   Điện Thoại Realme C51 3GB/64GB - Hàng Chính Hãng   2699000
# 162  Điện thoại Xiaomi Redmi 9A 2GB/32GB Xám - Hàng...   2088000
# 163  Điện Thoại Samsung Galaxy A14 5G (4GB/128GB) -...   5000000
# 164  Điện thoại TECNO Spark 6 Go (4GB/64GB) - Hàng ...   2559000
# 165  Điện thoại OPPO A57 4GB/128GB Đen - Hàng chính...   3850000
#
#                                              link_item discount   sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=TqXmxYn9l...     -28%     5.0
# 1    https://tka.tiki.vn/pixel/pixel?data=GJW8sUiFk...      -4%     3.0
# 2    https://tiki.vn/dien-thoai-oppo-a17k-3gb-64gb-...     -37%  5000.0
# 3    https://tiki.vn/dien-thoai-xiaomi-redmi-9a-2gb...      -4%  5000.0
# 4    https://tiki.vn/apple-iphone-15-pro-max-p27197...     -17%   727.0
# ..                                                 ...      ...     ...
# 161  https://tiki.vn/dien-thoai-realme-c51-3gb-64gb...      NaN     1.0
# 162  https://tiki.vn/dien-thoai-xiaomi-redmi-9a-2gb...      NaN     1.0
# 163  https://tiki.vn/dien-thoai-samsung-galaxy-a14-...      NaN     1.0
# 164  https://tiki.vn/dien-thoai-tecno-spark-6-go-4g...      NaN     4.0
# 165  https://tiki.vn/dien-thoai-oppo-a57-4gb-128gb-...      NaN     1.0
#
#        category       revenue
# 0    smartphone  1.895000e+07
# 1    smartphone  8.370000e+06
# 2    smartphone  1.195000e+10
# 3    smartphone  8.950000e+09
# 4    smartphone  2.325673e+10
# ..          ...           ...
# 161  smartphone  2.699000e+06
# 162  smartphone  2.088000e+06
# 163  smartphone  5.000000e+06
# 164  smartphone  1.023600e+07
# 165  smartphone  3.850000e+06
#
# [166 rows x 7 columns]

# %%
df_all.to_csv("tk_smartphone_all_ed.csv")
