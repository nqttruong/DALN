# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\dienthoai_maytinhbang"
os.listdir(path)
# Out:
# ['brand - Copy (3)',
#  'category.ipynb',
#  'dienthoai',
#  'dienthoaiban',
#  'dienthoaiphothong',
#  'maydocsach',
#  'maytinhbang',
#  'tk_dienthoaiban_all_ed.csv',
#  'tk_dienthoaiphothong_all_ed.csv',
#  'tk_dtmaytinhbang_all.ipynb',
#  'tk_maydocsach_all_ed.csv',
#  'tk_maytinhbang_all_ed.csv',
#  'tk_smartphone_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#      Unnamed: 0                                              title    price  \
# 0             0            Điện thoại bàn Ktel 645 hàng chính hãng   398000
# 1             1                    Điện thoại bàn treo tường TC990   250000
# 2             2  Điện thoại bàn Panasonic KX-TS500MX-hàng chính...   300000
# 3             3  Điện thoại bàn Panasonic KX-TSC11 hàng chính hãng   588000
# 4             4  Điện thoại để bàn tân cổ điển phím quay cao cấ...  4200000
# ..          ...                                                ...      ...
# 161         161   Điện Thoại Realme C51 3GB/64GB - Hàng Chính Hãng  2699000
# 162         162  Điện thoại Xiaomi Redmi 9A 2GB/32GB Xám - Hàng...  2088000
# 163         163  Điện Thoại Samsung Galaxy A14 5G (4GB/128GB) -...  5000000
# 164         164  Điện thoại TECNO Spark 6 Go (4GB/64GB) - Hàng ...  2559000
# 165         165  Điện thoại OPPO A57 4GB/128GB Đen - Hàng chính...  3850000
#
#                                              link_item discount  sales  \
# 0    https://tiki.vn/dien-thoai-ban-ktel-645-hang-c...      NaN   54.0
# 1    https://tka.tiki.vn/pixel/pixel?data=DmX_Quf-z...      -2%   21.0
# 2    https://tka.tiki.vn/pixel/pixel?data=89IOpo87G...      NaN  821.0
# 3    https://tka.tiki.vn/pixel/pixel?data=9AP0d6llo...      NaN  143.0
# 4    https://tiki.vn/dien-thoai-de-ban-tan-co-dien-...      NaN    4.0
# ..                                                 ...      ...    ...
# 161  https://tiki.vn/dien-thoai-realme-c51-3gb-64gb...      NaN    1.0
# 162  https://tiki.vn/dien-thoai-xiaomi-redmi-9a-2gb...      NaN    1.0
# 163  https://tiki.vn/dien-thoai-samsung-galaxy-a14-...      NaN    1.0
# 164  https://tiki.vn/dien-thoai-tecno-spark-6-go-4g...      NaN    4.0
# 165  https://tiki.vn/dien-thoai-oppo-a57-4gb-128gb-...      NaN    1.0
#
#          category      revenue
# 0    dienthoaiban   21492000.0
# 1    dienthoaiban    5250000.0
# 2    dienthoaiban  246300000.0
# 3    dienthoaiban   84084000.0
# 4    dienthoaiban   16800000.0
# ..            ...          ...
# 161    smartphone    2699000.0
# 162    smartphone    2088000.0
# 163    smartphone    5000000.0
# 164    smartphone   10236000.0
# 165    smartphone    3850000.0
#
# [309 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "dienthoai")

# %%
df
# Out:
#                                                  title    price  \
# 0              Điện thoại bàn Ktel 645 hàng chính hãng   398000
# 1                      Điện thoại bàn treo tường TC990   250000
# 2    Điện thoại bàn Panasonic KX-TS500MX-hàng chính...   300000
# 3    Điện thoại bàn Panasonic KX-TSC11 hàng chính hãng   588000
# 4    Điện thoại để bàn tân cổ điển phím quay cao cấ...  4200000
# ..                                                 ...      ...
# 161   Điện Thoại Realme C51 3GB/64GB - Hàng Chính Hãng  2699000
# 162  Điện thoại Xiaomi Redmi 9A 2GB/32GB Xám - Hàng...  2088000
# 163  Điện Thoại Samsung Galaxy A14 5G (4GB/128GB) -...  5000000
# 164  Điện thoại TECNO Spark 6 Go (4GB/64GB) - Hàng ...  2559000
# 165  Điện thoại OPPO A57 4GB/128GB Đen - Hàng chính...  3850000
#
#                                              link_item discount  sales  \
# 0    https://tiki.vn/dien-thoai-ban-ktel-645-hang-c...      NaN   54.0
# 1    https://tka.tiki.vn/pixel/pixel?data=DmX_Quf-z...      -2%   21.0
# 2    https://tka.tiki.vn/pixel/pixel?data=89IOpo87G...      NaN  821.0
# 3    https://tka.tiki.vn/pixel/pixel?data=9AP0d6llo...      NaN  143.0
# 4    https://tiki.vn/dien-thoai-de-ban-tan-co-dien-...      NaN    4.0
# ..                                                 ...      ...    ...
# 161  https://tiki.vn/dien-thoai-realme-c51-3gb-64gb...      NaN    1.0
# 162  https://tiki.vn/dien-thoai-xiaomi-redmi-9a-2gb...      NaN    1.0
# 163  https://tiki.vn/dien-thoai-samsung-galaxy-a14-...      NaN    1.0
# 164  https://tiki.vn/dien-thoai-tecno-spark-6-go-4g...      NaN    4.0
# 165  https://tiki.vn/dien-thoai-oppo-a57-4gb-128gb-...      NaN    1.0
#
#         item_list   category      revenue
# 0    dienthoaiban  dienthoai   21492000.0
# 1    dienthoaiban  dienthoai    5250000.0
# 2    dienthoaiban  dienthoai  246300000.0
# 3    dienthoaiban  dienthoai   84084000.0
# 4    dienthoaiban  dienthoai   16800000.0
# ..            ...        ...          ...
# 161    smartphone  dienthoai    2699000.0
# 162    smartphone  dienthoai    2088000.0
# 163    smartphone  dienthoai    5000000.0
# 164    smartphone  dienthoai   10236000.0
# 165    smartphone  dienthoai    3850000.0
#
# [309 rows x 8 columns]

# %%
df.to_csv('tk_dienthoai_all_ed.csv', index=False, encoding='utf-8')
