# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\thoitrangnam\dolot"
os.listdir(path)
# Out:
# ['tk_dolotnam.ipynb',
#  'tk_dolot_all.ipynb',
#  'tk_ttn_dolotnam_npage.ipynb',
#  'tk_ttn_dolotnam_t1.csv',
#  'tk_ttn_dolotnam_t10.csv',
#  'tk_ttn_dolotnam_t11.csv',
#  'tk_ttn_dolotnam_t12.csv',
#  'tk_ttn_dolotnam_t13.csv',
#  'tk_ttn_dolotnam_t14.csv',
#  'tk_ttn_dolotnam_t15.csv',
#  'tk_ttn_dolotnam_t16.csv',
#  'tk_ttn_dolotnam_t17.csv',
#  'tk_ttn_dolotnam_t18.csv',
#  'tk_ttn_dolotnam_t19.csv',
#  'tk_ttn_dolotnam_t2.csv',
#  'tk_ttn_dolotnam_t20.csv',
#  'tk_ttn_dolotnam_t21.csv',
#  'tk_ttn_dolotnam_t22.csv',
#  'tk_ttn_dolotnam_t23.csv',
#  'tk_ttn_dolotnam_t24.csv',
#  'tk_ttn_dolotnam_t25.csv',
#  'tk_ttn_dolotnam_t26.csv',
#  'tk_ttn_dolotnam_t27.csv',
#  'tk_ttn_dolotnam_t28.csv',
#  'tk_ttn_dolotnam_t29.csv',
#  'tk_ttn_dolotnam_t3.csv',
#  'tk_ttn_dolotnam_t30.csv',
#  'tk_ttn_dolotnam_t31.csv',
#  'tk_ttn_dolotnam_t32.csv',
#  'tk_ttn_dolotnam_t33.csv',
#  'tk_ttn_dolotnam_t34.csv',
#  'tk_ttn_dolotnam_t35.csv',
#  'tk_ttn_dolotnam_t36.csv',
#  'tk_ttn_dolotnam_t37.csv',
#  'tk_ttn_dolotnam_t38.csv',
#  'tk_ttn_dolotnam_t39.csv',
#  'tk_ttn_dolotnam_t4.csv',
#  'tk_ttn_dolotnam_t40.csv',
#  'tk_ttn_dolotnam_t41.csv',
#  'tk_ttn_dolotnam_t42.csv',
#  'tk_ttn_dolotnam_t43.csv',
#  'tk_ttn_dolotnam_t44.csv',
#  'tk_ttn_dolotnam_t45.csv',
#  'tk_ttn_dolotnam_t46.csv',
#  'tk_ttn_dolotnam_t47.csv',
#  'tk_ttn_dolotnam_t48.csv',
#  'tk_ttn_dolotnam_t49.csv',
#  'tk_ttn_dolotnam_t5.csv',
#  'tk_ttn_dolotnam_t50.csv',
#  'tk_ttn_dolotnam_t6.csv',
#  'tk_ttn_dolotnam_t7.csv',
#  'tk_ttn_dolotnam_t8.csv',
#  'tk_ttn_dolotnam_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dolot_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Combo 4 quần lót nam tam giác Bamboo Organi...  239.000₫
# 1   Combo 4 quần lót nam Boxer sợi cạp 1cm sợ...  245.000₫
# 2   Quần Lót Nam Không đường may cao cấp BADBIRD, ...   75.000₫
# 3   SET 5 Chiếc Quần Lót Nam Không đường may cao c...   315.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36    Quần lót Nam Cotton thời trang - L ( 59 - 65kg)   99.000₫
# 37   Quần lót nam sexy dây coặc 2 bên mạnh mẽ - 1 cái   45.000₫
# 38                       Quần lót lọt khe dây gợi cảm   23.000₫
# 39               Quần lót nam lọt khe hình bướm chữ G   45.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=258bFB2tt...      1     -30%
# 1   https://tka.tiki.vn/pixel/pixel?data=JKi9XBjq6...      2     -28%
# 2   https://tka.tiki.vn/pixel/pixel?data=4w_eWtLss...      3     -28%
# 3   https://tka.tiki.vn/pixel/pixel?data=y3I0pocxo...      4     -30%
# 4   https://tka.tiki.vn/pixel/pixel?data=lBUZQhsz8...      5     -36%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/quan-lot-nam-dang-luoi-co-gian...     36      NaN
# 36  https://tiki.vn/quan-lot-nam-cotton-thoi-trang...     37      NaN
# 37  https://tiki.vn/quan-lot-nam-sexy-day-coac-2-b...     38      NaN
# 38  https://tiki.vn/quan-lot-lot-khe-day-goi-cam-p...     39      NaN
# 39  https://tiki.vn/quan-lot-nam-lot-khe-hinh-buom...     40      NaN
#
#           sales  category
# 0   Đã bán 3.2k  dolotnam
# 1    Đã bán 5k+  dolotnam
# 2      Đã bán 7  dolotnam
# 3           NaN  dolotnam
# 4           NaN  dolotnam
# ..          ...       ...
# 35          NaN  dolotnam
# 36          NaN  dolotnam
# 37    Đã bán 10  dolotnam
# 38          NaN  dolotnam
# 39          NaN  dolotnam
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Combo 4 quần lót nam tam giác Bamboo Organi...  239.000₫
# 1    Combo 4 quần lót nam Boxer sợi cạp 1cm sợ...  245.000₫
# 2    Quần Lót Nam Không đường may cao cấp BADBIRD, ...   75.000₫
# 3    Combo 4 quần lót nam Boxer sợi cạp 1cm sợ...  245.000₫
# 4    Combo 4 quần lót nam tam giác Bamboo Organi...  239.000₫
# ..                                                 ...       ...
# 702  Quần lót nam lưng thấp dạng dây thiết kế siêu ...   45.000₫
# 703                         Quần Lót Nam, Quần Ngủ Nam   99.000₫
# 704                        Quần lót nam Body thun lạnh   50.000₫
# 705         LÓT NAM-MS:6043(Freeman)cotton lụa 4 chiều   47.610₫
# 706   Quần lót nam sexy dây coặc 2 bên mạnh mẽ - 1 cái   45.000₫
#
#                                              link_item discount        sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=258bFB2tt...     -30%  Đã bán 3.2k
# 1    https://tka.tiki.vn/pixel/pixel?data=JKi9XBjq6...     -28%   Đã bán 5k+
# 2    https://tka.tiki.vn/pixel/pixel?data=4w_eWtLss...     -28%     Đã bán 7
# 3    https://tiki.vn/combo-4-quan-sip-dui-nam-quan-...      NaN   Đã bán 5k+
# 4    https://tiki.vn/combo-4-qua-n-lo-t-nam-tam-gia...      NaN  Đã bán 3.2k
# ..                                                 ...      ...          ...
# 702  https://tiki.vn/quan-lot-nam-lung-thap-dang-da...      NaN    Đã bán 24
# 703  https://tiki.vn/quan-lot-nam-quan-ngu-nam-p162...      NaN    Đã bán 61
# 704  https://tiki.vn/quan-lot-nam-body-thun-lanh-p1...      NaN    Đã bán 11
# 705  https://tiki.vn/lot-nam-ms-6043-freeman-cotton...      NaN     Đã bán 4
# 706  https://tiki.vn/quan-lot-nam-sexy-day-coac-2-b...      NaN    Đã bán 10
#
#      category
# 0    dolotnam
# 1    dolotnam
# 2    dolotnam
# 3    dolotnam
# 4    dolotnam
# ..        ...
# 702  dolotnam
# 703  dolotnam
# 704  dolotnam
# 705  dolotnam
# 706  dolotnam
#
# [707 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      239000
# 1      245000
# 2       75000
# 3      245000
# 4      239000
#         ...
# 702     45000
# 703     99000
# 704     50000
# 705     47610
# 706     45000
# Name: price, Length: 707, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      3200.0
# 1      5000.0
# 2         7.0
# 3      5000.0
# 4      3200.0
#         ...
# 702      24.0
# 703      61.0
# 704      11.0
# 705       4.0
# 706      10.0
# Name: sales, Length: 707, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      7.648000e+08
# 1      1.225000e+09
# 2      5.250000e+05
# 3      1.225000e+09
# 4      7.648000e+08
#            ...
# 702    1.080000e+06
# 703    6.039000e+06
# 704    5.500000e+05
# 705    1.904400e+05
# 706    4.500000e+05
# Name: revenue, Length: 707, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dolot: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dolot:  11179242995.0
# So mat hang da ban:  707
# So san pham da ban:  81096.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Combo 4 quần lót nam tam giác Bamboo Organi...  239000
# 1    Combo 4 quần lót nam Boxer sợi cạp 1cm sợ...  245000
# 2    Quần Lót Nam Không đường may cao cấp BADBIRD, ...   75000
# 3    Combo 4 quần lót nam Boxer sợi cạp 1cm sợ...  245000
# 4    Combo 4 quần lót nam tam giác Bamboo Organi...  239000
# ..                                                 ...     ...
# 702  Quần lót nam lưng thấp dạng dây thiết kế siêu ...   45000
# 703                         Quần Lót Nam, Quần Ngủ Nam   99000
# 704                        Quần lót nam Body thun lạnh   50000
# 705         LÓT NAM-MS:6043(Freeman)cotton lụa 4 chiều   47610
# 706   Quần lót nam sexy dây coặc 2 bên mạnh mẽ - 1 cái   45000
#
#                                              link_item discount   sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=258bFB2tt...     -30%  3200.0
# 1    https://tka.tiki.vn/pixel/pixel?data=JKi9XBjq6...     -28%  5000.0
# 2    https://tka.tiki.vn/pixel/pixel?data=4w_eWtLss...     -28%     7.0
# 3    https://tiki.vn/combo-4-quan-sip-dui-nam-quan-...      NaN  5000.0
# 4    https://tiki.vn/combo-4-qua-n-lo-t-nam-tam-gia...      NaN  3200.0
# ..                                                 ...      ...     ...
# 702  https://tiki.vn/quan-lot-nam-lung-thap-dang-da...      NaN    24.0
# 703  https://tiki.vn/quan-lot-nam-quan-ngu-nam-p162...      NaN    61.0
# 704  https://tiki.vn/quan-lot-nam-body-thun-lanh-p1...      NaN    11.0
# 705  https://tiki.vn/lot-nam-ms-6043-freeman-cotton...      NaN     4.0
# 706  https://tiki.vn/quan-lot-nam-sexy-day-coac-2-b...      NaN    10.0
#
#      category       revenue
# 0    dolotnam  7.648000e+08
# 1    dolotnam  1.225000e+09
# 2    dolotnam  5.250000e+05
# 3    dolotnam  1.225000e+09
# 4    dolotnam  7.648000e+08
# ..        ...           ...
# 702  dolotnam  1.080000e+06
# 703  dolotnam  6.039000e+06
# 704  dolotnam  5.500000e+05
# 705  dolotnam  1.904400e+05
# 706  dolotnam  4.500000e+05
#
# [707 rows x 7 columns]

# %%
df_all.to_csv("tk_dolot_all_ed.csv")
