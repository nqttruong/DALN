# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\thoitrangnam\dongu"
os.listdir(path)
# Out:
# ['tk_dongunam.ipynb',
#  'tk_dongunam_all.ipynb',
#  'tk_ttn_dongunam_npage.ipynb',
#  'tk_ttn_dongunam_t1.csv',
#  'tk_ttn_dongunam_t10.csv',
#  'tk_ttn_dongunam_t11.csv',
#  'tk_ttn_dongunam_t12.csv',
#  'tk_ttn_dongunam_t13.csv',
#  'tk_ttn_dongunam_t14.csv',
#  'tk_ttn_dongunam_t15.csv',
#  'tk_ttn_dongunam_t16.csv',
#  'tk_ttn_dongunam_t17.csv',
#  'tk_ttn_dongunam_t18.csv',
#  'tk_ttn_dongunam_t19.csv',
#  'tk_ttn_dongunam_t2.csv',
#  'tk_ttn_dongunam_t20.csv',
#  'tk_ttn_dongunam_t21.csv',
#  'tk_ttn_dongunam_t22.csv',
#  'tk_ttn_dongunam_t23.csv',
#  'tk_ttn_dongunam_t24.csv',
#  'tk_ttn_dongunam_t25.csv',
#  'tk_ttn_dongunam_t26.csv',
#  'tk_ttn_dongunam_t27.csv',
#  'tk_ttn_dongunam_t28.csv',
#  'tk_ttn_dongunam_t29.csv',
#  'tk_ttn_dongunam_t3.csv',
#  'tk_ttn_dongunam_t30.csv',
#  'tk_ttn_dongunam_t31.csv',
#  'tk_ttn_dongunam_t32.csv',
#  'tk_ttn_dongunam_t33.csv',
#  'tk_ttn_dongunam_t4.csv',
#  'tk_ttn_dongunam_t5.csv',
#  'tk_ttn_dongunam_t6.csv',
#  'tk_ttn_dongunam_t7.csv',
#  'tk_ttn_dongunam_t8.csv',
#  'tk_ttn_dongunam_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dongu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Bộ Quần Áo Nỉ Nam 5S FASHION, Chất Cotton Mềm ...  474.000₫
# 1   Bộ quần áo thể thao nam FASVIN AB23570.HN chất...  429.000₫
# 2   Bộ Quần Áo Nỉ Nam Tay Dài 5S FASHION, Chất Liệ...  419.000₫
# 3   Bộ Quần Áo KaKi Lính Mỹ US ARMY U569 Kiểu Dáng...   877.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Quần Áo Lính Mỹ US ARMY Giá Rẻ - Quần Túi Hộp ...  480.000₫
# 37  Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...  299.000₫
# 38  Đồ bộ nam bonrouttesm" logo Thêu Nổi , Chạy Vi...  115.000₫
# 39  Bộ Pyjama HUONGTAM Phi tay dài nam cao cấp(PDP...   196.710
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=FqUjU3p30...      1     -34%
# 1   https://tka.tiki.vn/pixel/pixel?data=ULPekwVmZ...      2      -8%
# 2   https://tka.tiki.vn/pixel/pixel?data=1ulYdj5JM...      3     -42%
# 3   https://tka.tiki.vn/pixel/pixel?data=zz_bZYxQH...      4      NaN
# 4   https://tka.tiki.vn/pixel/pixel?data=5aCi7B_o9...      5      NaN
# ..                                                ...    ...      ...
# 35  https://tiki.vn/bo-pijama-nam-do-bo-mac-nha-na...     36      NaN
# 36  https://tiki.vn/quan-ao-linh-my-us-army-gia-re...     37      NaN
# 37  https://tiki.vn/bo-quan-ao-the-thao-nam-fasvin...     38      NaN
# 38  https://tiki.vn/do-bo-nam-bonrouttesm-logo-the...     39      NaN
# 39  https://tiki.vn/bo-pyjama-huongtam-phi-tay-dai...     40      NaN
#
#         sales  category
# 0   Đã bán 13  dongunam
# 1    Đã bán 6  dongunam
# 2    Đã bán 7  dongunam
# 3         NaN  dongunam
# 4         NaN  dongunam
# ..        ...       ...
# 35        NaN  dongunam
# 36   Đã bán 6  dongunam
# 37   Đã bán 1  dongunam
# 38        NaN  dongunam
# 39        NaN  dongunam
#
# [1336 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Bộ Quần Áo Nỉ Nam 5S FASHION, Chất Cotton Mềm ...  474.000₫
# 1    Bộ quần áo thể thao nam FASVIN AB23570.HN chất...  429.000₫
# 2    Bộ Quần Áo Nỉ Nam Tay Dài 5S FASHION, Chất Liệ...  419.000₫
# 3    Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...  250.000₫
# 4    Bộ Quần Áo Nỉ Nam 5S FASHION, Chất Cotton Mềm ...  474.000₫
# ..                                                 ...       ...
# 416  BỘ QUẦN ÁO THỂ THAO BỘ ĐỒ NAM NỮ SIZE M L CHẤT...  103.000₫
# 417  BỘ THU ĐÔNG NAM Chất vải Cotton 100% đồ ngủ na...  492.000₫
# 418                                Bộ Quần Áo Nam SE60  282.000₫
# 419  Quần Áo Lính Mỹ US ARMY Giá Rẻ - Quần Túi Hộp ...  480.000₫
# 420  Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...  299.000₫
#
#                                              link_item discount      sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=FqUjU3p30...     -34%  Đã bán 13
# 1    https://tka.tiki.vn/pixel/pixel?data=ULPekwVmZ...      -8%   Đã bán 6
# 2    https://tka.tiki.vn/pixel/pixel?data=1ulYdj5JM...     -42%   Đã bán 7
# 3    https://tiki.vn/bo-do-nam-aviano-4-mau-dai-tay...     -44%  Đã bán 14
# 4    https://tiki.vn/bo-quan-ao-ni-nam-5s-fashion-c...     -34%  Đã bán 13
# ..                                                 ...      ...        ...
# 416  https://tiki.vn/bo-quan-ao-the-thao-bo-do-nam-...      NaN  Đã bán 84
# 417  https://tiki.vn/bo-thu-dong-nam-chat-vai-cotto...      NaN   Đã bán 8
# 418  https://tiki.vn/bo-quan-ao-nam-se60-p22254534....      NaN  Đã bán 27
# 419  https://tiki.vn/quan-ao-linh-my-us-army-gia-re...      NaN   Đã bán 6
# 420  https://tiki.vn/bo-quan-ao-the-thao-nam-fasvin...      NaN   Đã bán 1
#
#      category
# 0    dongunam
# 1    dongunam
# 2    dongunam
# 3    dongunam
# 4    dongunam
# ..        ...
# 416  dongunam
# 417  dongunam
# 418  dongunam
# 419  dongunam
# 420  dongunam
#
# [421 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      474000
# 1      429000
# 2      419000
# 3      250000
# 4      474000
#         ...
# 416    103000
# 417    492000
# 418    282000
# 419    480000
# 420    299000
# Name: price, Length: 421, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      13.0
# 1       6.0
# 2       7.0
# 3      14.0
# 4      13.0
#        ...
# 416    84.0
# 417     8.0
# 418    27.0
# 419     6.0
# 420     1.0
# Name: sales, Length: 421, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      6162000.0
# 1      2574000.0
# 2      2933000.0
# 3      3500000.0
# 4      6162000.0
#          ...
# 416    8652000.0
# 417    3936000.0
# 418    7614000.0
# 419    2880000.0
# 420     299000.0
# Name: revenue, Length: 421, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dongu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dongu:  1359716076.0
# So mat hang da ban:  421
# So san pham da ban:  7302.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Bộ Quần Áo Nỉ Nam 5S FASHION, Chất Cotton Mềm ...  474000
# 1    Bộ quần áo thể thao nam FASVIN AB23570.HN chất...  429000
# 2    Bộ Quần Áo Nỉ Nam Tay Dài 5S FASHION, Chất Liệ...  419000
# 3    Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...  250000
# 4    Bộ Quần Áo Nỉ Nam 5S FASHION, Chất Cotton Mềm ...  474000
# ..                                                 ...     ...
# 416  BỘ QUẦN ÁO THỂ THAO BỘ ĐỒ NAM NỮ SIZE M L CHẤT...  103000
# 417  BỘ THU ĐÔNG NAM Chất vải Cotton 100% đồ ngủ na...  492000
# 418                                Bộ Quần Áo Nam SE60  282000
# 419  Quần Áo Lính Mỹ US ARMY Giá Rẻ - Quần Túi Hộp ...  480000
# 420  Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...  299000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=FqUjU3p30...     -34%   13.0
# 1    https://tka.tiki.vn/pixel/pixel?data=ULPekwVmZ...      -8%    6.0
# 2    https://tka.tiki.vn/pixel/pixel?data=1ulYdj5JM...     -42%    7.0
# 3    https://tiki.vn/bo-do-nam-aviano-4-mau-dai-tay...     -44%   14.0
# 4    https://tiki.vn/bo-quan-ao-ni-nam-5s-fashion-c...     -34%   13.0
# ..                                                 ...      ...    ...
# 416  https://tiki.vn/bo-quan-ao-the-thao-bo-do-nam-...      NaN   84.0
# 417  https://tiki.vn/bo-thu-dong-nam-chat-vai-cotto...      NaN    8.0
# 418  https://tiki.vn/bo-quan-ao-nam-se60-p22254534....      NaN   27.0
# 419  https://tiki.vn/quan-ao-linh-my-us-army-gia-re...      NaN    6.0
# 420  https://tiki.vn/bo-quan-ao-the-thao-nam-fasvin...      NaN    1.0
#
#      category    revenue
# 0    dongunam  6162000.0
# 1    dongunam  2574000.0
# 2    dongunam  2933000.0
# 3    dongunam  3500000.0
# 4    dongunam  6162000.0
# ..        ...        ...
# 416  dongunam  8652000.0
# 417  dongunam  3936000.0
# 418  dongunam  7614000.0
# 419  dongunam  2880000.0
# 420  dongunam   299000.0
#
# [421 rows x 7 columns]

# %%
df_all.to_csv("tk_dongu_all_ed.csv")
