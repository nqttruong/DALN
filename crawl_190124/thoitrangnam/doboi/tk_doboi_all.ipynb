# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\thoitrangnam\doboi"
os.listdir(path)
# Out:
# ['tk_doboi.ipynb',
#  'tk_doboi_all.ipynb',
#  'tk_ttn_doboi_npage.ipynb',
#  'tk_ttn_doboi_t1.csv',
#  'tk_ttn_doboi_t10.csv',
#  'tk_ttn_doboi_t11.csv',
#  'tk_ttn_doboi_t2.csv',
#  'tk_ttn_doboi_t3.csv',
#  'tk_ttn_doboi_t4.csv',
#  'tk_ttn_doboi_t5.csv',
#  'tk_ttn_doboi_t6.csv',
#  'tk_ttn_doboi_t7.csv',
#  'tk_ttn_doboi_t8.csv',
#  'tk_ttn_doboi_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_doboi_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Quần Bơi Nam Thiết Kế Vảy Cá Mập Cleacco Chống...  116.000₫
# 1   Quần Bơi Nam Boxer Có Túi CLEACCO DEENYT Chất ...  219.000₫
# 2   Quần Bơi Lửng Nam Brave Person B2240 - Thiết K...  185.000₫
# 3   Quần Bơi Nam Tam Giác Thời Trang Desmiit S324 ...   218.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Quần đi biển nam Oneill Hyperfreak Heat Stripe...  999.000₫
# 37  Quần đi biển nam dáng rộng, chất thun bơi lạnh...  260.000₫
# 38   Quần Short Đi Biển Nam IZOD Swim Shorts - SIZE M  350.000₫
# 39                               Quần Tắm Nam Cao Cấp   160.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=xMG7K-ezX...      1     -42%
# 1   https://tka.tiki.vn/pixel/pixel?data=bxD2SBSGD...      2     -32%
# 2   https://tka.tiki.vn/pixel/pixel?data=DNRQcd8mH...      3     -59%
# 3   https://tka.tiki.vn/pixel/pixel?data=L5rTLpOFO...      4      NaN
# 4   https://tka.tiki.vn/pixel/pixel?data=P0biMg7Dn...      5      NaN
# ..                                                ...    ...      ...
# 35  https://tiki.vn/quan-di-bien-nam-oneill-hyperf...     36      NaN
# 36  https://tiki.vn/quan-di-bien-nam-oneill-hyperf...     37      NaN
# 37  https://tiki.vn/quan-di-bien-nam-dang-rong-cha...     38      NaN
# 38  https://tiki.vn/quan-short-tap-gym-nam-izod-sw...     39      NaN
# 39  https://tiki.vn/quan-tam-nam-cao-cap-p6055663....     40      NaN
#
#          sales category
# 0   Đã bán 697    doboi
# 1   Đã bán 395    doboi
# 2    Đã bán 20    doboi
# 3          NaN    doboi
# 4          NaN    doboi
# ..         ...      ...
# 35         NaN    doboi
# 36         NaN    doboi
# 37    Đã bán 3    doboi
# 38         NaN    doboi
# 39         NaN    doboi
#
# [423 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Quần Bơi Nam Thiết Kế Vảy Cá Mập Cleacco Chống...  116.000₫
# 1    Quần Bơi Nam Boxer Có Túi CLEACCO DEENYT Chất ...  219.000₫
# 2    Quần Bơi Lửng Nam Brave Person B2240 - Thiết K...  185.000₫
# 3    Quần Bơi Nam Thiết Kế Vảy Cá Mập Cleacco Chống...  110.000₫
# 4    Quần bơi, áo bơi nam dạng dài tay ôm sát body ...  220.000₫
# ..                                                 ...       ...
# 118          Quần short nam vải dù cao cấp QSHOP QS569  350.000₫
# 119                   QUẦN SHORT ĐI BIỂN MẪU MỚI QS396  250.000₫
# 120  Quần bơi cao cấp may 2 lớp chắc chắn chất thun...  119.000₫
# 121             Quần đi biển nam họa tiết mẫu mới 2022   55.000₫
# 122  Quần đi biển nam dáng rộng, chất thun bơi lạnh...  260.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=xMG7K-ezX...     -42%  Đã bán 697
# 1    https://tka.tiki.vn/pixel/pixel?data=bxD2SBSGD...     -32%  Đã bán 395
# 2    https://tka.tiki.vn/pixel/pixel?data=DNRQcd8mH...     -59%   Đã bán 20
# 3    https://tiki.vn/quan-boi-nam-thiet-ke-vay-ca-m...     -45%  Đã bán 697
# 4    https://tiki.vn/quan-boi-ao-boi-nam-dang-dai-t...     -42%    Đã bán 7
# ..                                                 ...      ...         ...
# 118  https://tiki.vn/quan-short-nam-vai-du-cao-cap-...      NaN    Đã bán 1
# 119  https://tiki.vn/quan-short-di-bien-mau-moi-qs3...      NaN    Đã bán 1
# 120  https://tiki.vn/quan-boi-cao-cap-may-2-lop-cha...      NaN    Đã bán 1
# 121  https://tiki.vn/quan-di-bien-nam-hoa-tiet-mau-...      NaN    Đã bán 1
# 122  https://tiki.vn/quan-di-bien-nam-dang-rong-cha...      NaN    Đã bán 3
#
#     category
# 0      doboi
# 1      doboi
# 2      doboi
# 3      doboi
# 4      doboi
# ..       ...
# 118    doboi
# 119    doboi
# 120    doboi
# 121    doboi
# 122    doboi
#
# [123 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      116000
# 1      219000
# 2      185000
# 3      110000
# 4      220000
#         ...
# 118    350000
# 119    250000
# 120    119000
# 121     55000
# 122    260000
# Name: price, Length: 123, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      697.0
# 1      395.0
# 2       20.0
# 3      697.0
# 4        7.0
#        ...
# 118      1.0
# 119      1.0
# 120      1.0
# 121      1.0
# 122      3.0
# Name: sales, Length: 123, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      80852000.0
# 1      86505000.0
# 2       3700000.0
# 3      76670000.0
# 4       1540000.0
#           ...
# 118      350000.0
# 119      250000.0
# 120      119000.0
# 121       55000.0
# 122      780000.0
# Name: revenue, Length: 123, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số doboi: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số doboi:  801556330.0
# So mat hang da ban:  123
# So san pham da ban:  4763.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Quần Bơi Nam Thiết Kế Vảy Cá Mập Cleacco Chống...  116000
# 1    Quần Bơi Nam Boxer Có Túi CLEACCO DEENYT Chất ...  219000
# 2    Quần Bơi Lửng Nam Brave Person B2240 - Thiết K...  185000
# 3    Quần Bơi Nam Thiết Kế Vảy Cá Mập Cleacco Chống...  110000
# 4    Quần bơi, áo bơi nam dạng dài tay ôm sát body ...  220000
# ..                                                 ...     ...
# 118          Quần short nam vải dù cao cấp QSHOP QS569  350000
# 119                   QUẦN SHORT ĐI BIỂN MẪU MỚI QS396  250000
# 120  Quần bơi cao cấp may 2 lớp chắc chắn chất thun...  119000
# 121             Quần đi biển nam họa tiết mẫu mới 2022   55000
# 122  Quần đi biển nam dáng rộng, chất thun bơi lạnh...  260000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=xMG7K-ezX...     -42%  697.0
# 1    https://tka.tiki.vn/pixel/pixel?data=bxD2SBSGD...     -32%  395.0
# 2    https://tka.tiki.vn/pixel/pixel?data=DNRQcd8mH...     -59%   20.0
# 3    https://tiki.vn/quan-boi-nam-thiet-ke-vay-ca-m...     -45%  697.0
# 4    https://tiki.vn/quan-boi-ao-boi-nam-dang-dai-t...     -42%    7.0
# ..                                                 ...      ...    ...
# 118  https://tiki.vn/quan-short-nam-vai-du-cao-cap-...      NaN    1.0
# 119  https://tiki.vn/quan-short-di-bien-mau-moi-qs3...      NaN    1.0
# 120  https://tiki.vn/quan-boi-cao-cap-may-2-lop-cha...      NaN    1.0
# 121  https://tiki.vn/quan-di-bien-nam-hoa-tiet-mau-...      NaN    1.0
# 122  https://tiki.vn/quan-di-bien-nam-dang-rong-cha...      NaN    3.0
#
#     category     revenue
# 0      doboi  80852000.0
# 1      doboi  86505000.0
# 2      doboi   3700000.0
# 3      doboi  76670000.0
# 4      doboi   1540000.0
# ..       ...         ...
# 118    doboi    350000.0
# 119    doboi    250000.0
# 120    doboi    119000.0
# 121    doboi     55000.0
# 122    doboi    780000.0
#
# [123 rows x 7 columns]

# %%
df_all.to_csv("tk_doboi_all_ed.csv")
