# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\thoitrangnam\aothunnam"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_aothun_all.ipynb',
#  'tk_ttnam_aothun.ipynb',
#  'tk_ttnam_aothun_npage.ipynb',
#  'tk_ttnam_aothun_t1.csv',
#  'tk_ttnam_aothun_t10.csv',
#  'tk_ttnam_aothun_t11.csv',
#  'tk_ttnam_aothun_t12.csv',
#  'tk_ttnam_aothun_t13.csv',
#  'tk_ttnam_aothun_t14.csv',
#  'tk_ttnam_aothun_t15.csv',
#  'tk_ttnam_aothun_t16.csv',
#  'tk_ttnam_aothun_t17.csv',
#  'tk_ttnam_aothun_t18.csv',
#  'tk_ttnam_aothun_t19.csv',
#  'tk_ttnam_aothun_t2.csv',
#  'tk_ttnam_aothun_t20.csv',
#  'tk_ttnam_aothun_t21.csv',
#  'tk_ttnam_aothun_t22.csv',
#  'tk_ttnam_aothun_t23.csv',
#  'tk_ttnam_aothun_t24.csv',
#  'tk_ttnam_aothun_t25.csv',
#  'tk_ttnam_aothun_t26.csv',
#  'tk_ttnam_aothun_t27.csv',
#  'tk_ttnam_aothun_t28.csv',
#  'tk_ttnam_aothun_t29.csv',
#  'tk_ttnam_aothun_t3.csv',
#  'tk_ttnam_aothun_t30.csv',
#  'tk_ttnam_aothun_t31.csv',
#  'tk_ttnam_aothun_t32.csv',
#  'tk_ttnam_aothun_t33.csv',
#  'tk_ttnam_aothun_t34.csv',
#  'tk_ttnam_aothun_t35.csv',
#  'tk_ttnam_aothun_t36.csv',
#  'tk_ttnam_aothun_t37.csv',
#  'tk_ttnam_aothun_t38.csv',
#  'tk_ttnam_aothun_t39.csv',
#  'tk_ttnam_aothun_t4.csv',
#  'tk_ttnam_aothun_t40.csv',
#  'tk_ttnam_aothun_t41.csv',
#  'tk_ttnam_aothun_t42.csv',
#  'tk_ttnam_aothun_t43.csv',
#  'tk_ttnam_aothun_t44.csv',
#  'tk_ttnam_aothun_t45.csv',
#  'tk_ttnam_aothun_t46.csv',
#  'tk_ttnam_aothun_t47.csv',
#  'tk_ttnam_aothun_t48.csv',
#  'tk_ttnam_aothun_t49.csv',
#  'tk_ttnam_aothun_t5.csv',
#  'tk_ttnam_aothun_t50.csv',
#  'tk_ttnam_aothun_t6.csv',
#  'tk_ttnam_aothun_t7.csv',
#  'tk_ttnam_aothun_t8.csv',
#  'tk_ttnam_aothun_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_aothunnam_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   áo ba lỗ nam, áo 3 lỗ nam sợi cotton Orga...     79.000₫
# 1   TOKYO, mã G159. Áo thun hàng hiệu GOKING, form...    119.000₫
# 2   Áo Polo nam cổ bẻ ngắn tay, chất liệu vải cá s...    179.000₫
# 3   Áo thun Inosuke Kimetsu No Yaiba, mã KY8. Áo p...     79.000₫
# 4                                                 NaN         NaN
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36        Áo Polo Nam Enkoni Basic Trắng Vải Coolmate    389.000₫
# 37  Áo Thun Ba Lỗ Nam Sát Nách Vải Cotton Mềm Form...     39.000₫
# 38  MLB - Áo thun unisex cổ tròn tay ngắn Monotive...  1.790.000₫
# 39  Áo thun bò sữa nam nữ mặc , áo thun form rộng ...     69.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=ik5_TUr30...      1     -20%
# 1   https://tka.tiki.vn/pixel/pixel?data=SHAnLeY6T...      2     -28%
# 2   https://tka.tiki.vn/pixel/pixel?data=TFM1Wo3W4...      3     -44%
# 3   https://tka.tiki.vn/pixel/pixel?data=_GYO4e44L...      4     -12%
# 4   https://tka.tiki.vn/pixel/pixel?data=GdRciSIP6...      5     -21%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ao-phong-nam-polo-tay-ngan-pho...     36      NaN
# 36  https://tiki.vn/ao-polo-nam-enkoni-basic-trang...     37      NaN
# 37  https://tiki.vn/ao-thun-ba-lo-nam-sat-nach-vai...     38      NaN
# 38  https://tiki.vn/mlb-ao-thun-unisex-co-tron-tay...     39      NaN
# 39  https://tiki.vn/product-p90065069.html?spid=19...     40      NaN
#
#           sales category
# 0   Đã bán 1.1k   aothun
# 1    Đã bán 122   aothun
# 2    Đã bán 879   aothun
# 3           NaN   aothun
# 4           NaN   aothun
# ..          ...      ...
# 35          NaN   aothun
# 36     Đã bán 2   aothun
# 37     Đã bán 3   aothun
# 38          NaN   aothun
# 39     Đã bán 3   aothun
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    áo ba lỗ nam, áo 3 lỗ nam sợi cotton Orga...   79.000₫
# 1    TOKYO, mã G159. Áo thun hàng hiệu GOKING, form...  119.000₫
# 2    Áo Polo nam cổ bẻ ngắn tay, chất liệu vải cá s...  179.000₫
# 3    Áo thun nam Cotton Compact Premium trẻ trung n...  139.000₫
# 4    Áo Polo Nam cổ bẻ TSIMPLE thun có cổ tay lỡ vả...  149.000₫
# ..                                                 ...       ...
# 913  Combo 2 Áo thun thể thao nam MRM Active Pro th...  219.000₫
# 914  UNSTOPABLE, mã G60. Áo thun siêu đẹp cho cả gi...   69.000₫
# 915        Áo Polo Nam Enkoni Basic Trắng Vải Coolmate  389.000₫
# 916  Áo Thun Ba Lỗ Nam Sát Nách Vải Cotton Mềm Form...   39.000₫
# 917  Áo thun bò sữa nam nữ mặc , áo thun form rộng ...   69.000₫
#
#                                              link_item discount        sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=ik5_TUr30...     -20%  Đã bán 1.1k
# 1    https://tka.tiki.vn/pixel/pixel?data=SHAnLeY6T...     -28%   Đã bán 122
# 2    https://tka.tiki.vn/pixel/pixel?data=TFM1Wo3W4...     -44%   Đã bán 879
# 3    https://tiki.vn/ao-thun-nam-cotton-compact-pre...      NaN   Đã bán 733
# 4    https://tiki.vn/ao-polo-nam-co-be-tsimple-thun...      NaN  Đã bán 2.1k
# ..                                                 ...      ...          ...
# 913  https://tiki.vn/combo-2-ao-thun-the-thao-nam-m...      NaN   Đã bán 125
# 914  https://tiki.vn/unstopable-ma-g60-ao-thun-nam-...      NaN     Đã bán 9
# 915  https://tiki.vn/ao-polo-nam-enkoni-basic-trang...      NaN     Đã bán 2
# 916  https://tiki.vn/ao-thun-ba-lo-nam-sat-nach-vai...      NaN     Đã bán 3
# 917  https://tiki.vn/product-p90065069.html?spid=19...      NaN     Đã bán 3
#
#     category
# 0     aothun
# 1     aothun
# 2     aothun
# 3     aothun
# 4     aothun
# ..       ...
# 913   aothun
# 914   aothun
# 915   aothun
# 916   aothun
# 917   aothun
#
# [918 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       79000
# 1      119000
# 2      179000
# 3      139000
# 4      149000
#         ...
# 913    219000
# 914     69000
# 915    389000
# 916     39000
# 917     69000
# Name: price, Length: 918, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      1100.0
# 1       122.0
# 2       879.0
# 3       733.0
# 4      2100.0
#         ...
# 913     125.0
# 914       9.0
# 915       2.0
# 916       3.0
# 917       3.0
# Name: sales, Length: 918, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       86900000.0
# 1       14518000.0
# 2      157341000.0
# 3      101887000.0
# 4      312900000.0
#           ...
# 913     27375000.0
# 914       621000.0
# 915       778000.0
# 916       117000.0
# 917       207000.0
# Name: revenue, Length: 918, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số aothunnam: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số aothunnam:  6643042625.0
# So mat hang da ban:  918
# So san pham da ban:  50230.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    áo ba lỗ nam, áo 3 lỗ nam sợi cotton Orga...   79000
# 1    TOKYO, mã G159. Áo thun hàng hiệu GOKING, form...  119000
# 2    Áo Polo nam cổ bẻ ngắn tay, chất liệu vải cá s...  179000
# 3    Áo thun nam Cotton Compact Premium trẻ trung n...  139000
# 4    Áo Polo Nam cổ bẻ TSIMPLE thun có cổ tay lỡ vả...  149000
# ..                                                 ...     ...
# 913  Combo 2 Áo thun thể thao nam MRM Active Pro th...  219000
# 914  UNSTOPABLE, mã G60. Áo thun siêu đẹp cho cả gi...   69000
# 915        Áo Polo Nam Enkoni Basic Trắng Vải Coolmate  389000
# 916  Áo Thun Ba Lỗ Nam Sát Nách Vải Cotton Mềm Form...   39000
# 917  Áo thun bò sữa nam nữ mặc , áo thun form rộng ...   69000
#
#                                              link_item discount   sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=ik5_TUr30...     -20%  1100.0
# 1    https://tka.tiki.vn/pixel/pixel?data=SHAnLeY6T...     -28%   122.0
# 2    https://tka.tiki.vn/pixel/pixel?data=TFM1Wo3W4...     -44%   879.0
# 3    https://tiki.vn/ao-thun-nam-cotton-compact-pre...      NaN   733.0
# 4    https://tiki.vn/ao-polo-nam-co-be-tsimple-thun...      NaN  2100.0
# ..                                                 ...      ...     ...
# 913  https://tiki.vn/combo-2-ao-thun-the-thao-nam-m...      NaN   125.0
# 914  https://tiki.vn/unstopable-ma-g60-ao-thun-nam-...      NaN     9.0
# 915  https://tiki.vn/ao-polo-nam-enkoni-basic-trang...      NaN     2.0
# 916  https://tiki.vn/ao-thun-ba-lo-nam-sat-nach-vai...      NaN     3.0
# 917  https://tiki.vn/product-p90065069.html?spid=19...      NaN     3.0
#
#     category      revenue
# 0     aothun   86900000.0
# 1     aothun   14518000.0
# 2     aothun  157341000.0
# 3     aothun  101887000.0
# 4     aothun  312900000.0
# ..       ...          ...
# 913   aothun   27375000.0
# 914   aothun     621000.0
# 915   aothun     778000.0
# 916   aothun     117000.0
# 917   aothun     207000.0
#
# [918 rows x 7 columns]

# %%
df_all.to_csv("tk_aothunnam_all_ed.csv")
