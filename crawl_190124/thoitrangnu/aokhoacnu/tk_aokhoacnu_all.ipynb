# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\thoitrangnu\aokhoacnu"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_aokhoacnu_all.ipynb',
#  'tk_ttn_akn.ipynb',
#  'tk_ttn_akn_npage.ipynb',
#  'tk_ttn_akn_t1.csv',
#  'tk_ttn_akn_t10.csv',
#  'tk_ttn_akn_t11.csv',
#  'tk_ttn_akn_t12.csv',
#  'tk_ttn_akn_t13.csv',
#  'tk_ttn_akn_t14.csv',
#  'tk_ttn_akn_t15.csv',
#  'tk_ttn_akn_t16.csv',
#  'tk_ttn_akn_t17.csv',
#  'tk_ttn_akn_t18.csv',
#  'tk_ttn_akn_t19.csv',
#  'tk_ttn_akn_t2.csv',
#  'tk_ttn_akn_t20.csv',
#  'tk_ttn_akn_t21.csv',
#  'tk_ttn_akn_t22.csv',
#  'tk_ttn_akn_t23.csv',
#  'tk_ttn_akn_t24.csv',
#  'tk_ttn_akn_t25.csv',
#  'tk_ttn_akn_t26.csv',
#  'tk_ttn_akn_t27.csv',
#  'tk_ttn_akn_t28.csv',
#  'tk_ttn_akn_t29.csv',
#  'tk_ttn_akn_t3.csv',
#  'tk_ttn_akn_t30.csv',
#  'tk_ttn_akn_t31.csv',
#  'tk_ttn_akn_t32.csv',
#  'tk_ttn_akn_t33.csv',
#  'tk_ttn_akn_t34.csv',
#  'tk_ttn_akn_t35.csv',
#  'tk_ttn_akn_t36.csv',
#  'tk_ttn_akn_t37.csv',
#  'tk_ttn_akn_t38.csv',
#  'tk_ttn_akn_t39.csv',
#  'tk_ttn_akn_t4.csv',
#  'tk_ttn_akn_t40.csv',
#  'tk_ttn_akn_t41.csv',
#  'tk_ttn_akn_t42.csv',
#  'tk_ttn_akn_t43.csv',
#  'tk_ttn_akn_t44.csv',
#  'tk_ttn_akn_t45.csv',
#  'tk_ttn_akn_t46.csv',
#  'tk_ttn_akn_t47.csv',
#  'tk_ttn_akn_t48.csv',
#  'tk_ttn_akn_t49.csv',
#  'tk_ttn_akn_t5.csv',
#  'tk_ttn_akn_t50.csv',
#  'tk_ttn_akn_t6.csv',
#  'tk_ttn_akn_t7.csv',
#  'tk_ttn_akn_t8.csv',
#  'tk_ttn_akn_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_aokhoacnu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235.000₫
# 1   Áo khoác gió cách nhiệt GOKING, form unisex ch...  235.000₫
# 2   Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255.000₫
# 3   Áo Hoodie Trơn Màu Xanh Dương Cao Cấp Dáng Rộn...   120.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Áo Khoác Phao Nữ 3 Lớp Chần Bông Lông Vũ Cực Ấ...  208.000₫
# 37  (HÀNG SẴN) Áo Khoác Phao Lông Vũ Dáng Dài Phon...  745.000₫
# 38  Set áo vest blazer nữ ngắn tay 2 túi hàng thiế...  476.000₫
# 39  Áo Khoác Hoodie Chống Nắng Dành cho nam và nữ ...   103.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=xlY98fkU0...      1      NaN
# 1   https://tka.tiki.vn/pixel/pixel?data=vHcpn6EMV...      2     -44%
# 2   https://tka.tiki.vn/pixel/pixel?data=xR58NASNn...      3     -12%
# 3   https://tka.tiki.vn/pixel/pixel?data=uA1THT8yB...      4      NaN
# 4   https://tka.tiki.vn/pixel/pixel?data=LzBbBKjwN...      5      NaN
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ao-len-nu-ao-len-dai-tay-co-tr...     36      NaN
# 36  https://tiki.vn/ao-khoac-phao-nu-3-lop-chan-bo...     37      NaN
# 37  https://tiki.vn/hang-san-ao-khoac-phao-long-vu...     38      NaN
# 38  https://tiki.vn/set-ao-vest-blazer-nu-ngan-tay...     39      NaN
# 39  https://tiki.vn/ao-khoac-hoodie-chong-nang-dan...     40      NaN
#
#          sales   category
# 0    Đã bán 80  aokhoacnu
# 1    Đã bán 89  aokhoacnu
# 2   Đã bán 102  aokhoacnu
# 3     Đã bán 1  aokhoacnu
# 4          NaN  aokhoacnu
# ..         ...        ...
# 35         NaN  aokhoacnu
# 36    Đã bán 1  aokhoacnu
# 37         NaN  aokhoacnu
# 38   Đã bán 77  aokhoacnu
# 39         NaN  aokhoacnu
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235.000₫
# 1    Áo khoác gió cách nhiệt GOKING, form unisex ch...  235.000₫
# 2    Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255.000₫
# 3    Áo Hoodie Trơn Màu Xanh Dương Cao Cấp Dáng Rộn...   120.000
# 4       Áo Khoác Nữ Cao Cấp Chống Năng Form Lững 2 Sọc  150.000₫
# ..                                                 ...       ...
# 851  Áo khoác Cardigan len nữ họa tiết trẻ trung đủ...  219.000₫
# 852  Áo gile len nữ có cúc thiết kế phong cách Hàn ...  179.000₫
# 853  áo len nữ tay nỡ cổ và tay phối họa tiết quả trám  104.000₫
# 854  Áo Khoác Phao Nữ 3 Lớp Chần Bông Lông Vũ Cực Ấ...  208.000₫
# 855  Set áo vest blazer nữ ngắn tay 2 túi hàng thiế...  476.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=xlY98fkU0...      NaN   Đã bán 80
# 1    https://tka.tiki.vn/pixel/pixel?data=vHcpn6EMV...     -44%   Đã bán 89
# 2    https://tka.tiki.vn/pixel/pixel?data=xR58NASNn...     -12%  Đã bán 102
# 3    https://tka.tiki.vn/pixel/pixel?data=uA1THT8yB...      NaN    Đã bán 1
# 4    https://tiki.vn/ao-khoac-nu-cao-cap-chong-nang...      NaN    Đã bán 8
# ..                                                 ...      ...         ...
# 851  https://tiki.vn/ao-khoac-cardigan-len-nu-hoa-t...      NaN   Đã bán 17
# 852  https://tiki.vn/ao-gile-len-nu-co-cuc-thiet-ke...      NaN   Đã bán 11
# 853  https://tiki.vn/ao-len-nu-tay-no-co-va-tay-pho...      NaN    Đã bán 6
# 854  https://tiki.vn/ao-khoac-phao-nu-3-lop-chan-bo...      NaN    Đã bán 1
# 855  https://tiki.vn/set-ao-vest-blazer-nu-ngan-tay...      NaN   Đã bán 77
#
#       category
# 0    aokhoacnu
# 1    aokhoacnu
# 2    aokhoacnu
# 3    aokhoacnu
# 4    aokhoacnu
# ..         ...
# 851  aokhoacnu
# 852  aokhoacnu
# 853  aokhoacnu
# 854  aokhoacnu
# 855  aokhoacnu
#
# [856 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      235000
# 1      235000
# 2      255000
# 3      120000
# 4      150000
#         ...
# 851    219000
# 852    179000
# 853    104000
# 854    208000
# 855    476000
# Name: price, Length: 856, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       80.0
# 1       89.0
# 2      102.0
# 3        1.0
# 4        8.0
#        ...
# 851     17.0
# 852     11.0
# 853      6.0
# 854      1.0
# 855     77.0
# Name: sales, Length: 856, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      18800000.0
# 1      20915000.0
# 2      26010000.0
# 3        120000.0
# 4       1200000.0
#           ...
# 851     3723000.0
# 852     1969000.0
# 853      624000.0
# 854      208000.0
# 855    36652000.0
# Name: revenue, Length: 856, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số aokhoacnu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số aokhoacnu:  4032491303.0
# So mat hang da ban:  856
# So san pham da ban:  18380.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235000
# 1    Áo khoác gió cách nhiệt GOKING, form unisex ch...  235000
# 2    Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255000
# 3    Áo Hoodie Trơn Màu Xanh Dương Cao Cấp Dáng Rộn...  120000
# 4       Áo Khoác Nữ Cao Cấp Chống Năng Form Lững 2 Sọc  150000
# ..                                                 ...     ...
# 851  Áo khoác Cardigan len nữ họa tiết trẻ trung đủ...  219000
# 852  Áo gile len nữ có cúc thiết kế phong cách Hàn ...  179000
# 853  áo len nữ tay nỡ cổ và tay phối họa tiết quả trám  104000
# 854  Áo Khoác Phao Nữ 3 Lớp Chần Bông Lông Vũ Cực Ấ...  208000
# 855  Set áo vest blazer nữ ngắn tay 2 túi hàng thiế...  476000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=xlY98fkU0...      NaN   80.0
# 1    https://tka.tiki.vn/pixel/pixel?data=vHcpn6EMV...     -44%   89.0
# 2    https://tka.tiki.vn/pixel/pixel?data=xR58NASNn...     -12%  102.0
# 3    https://tka.tiki.vn/pixel/pixel?data=uA1THT8yB...      NaN    1.0
# 4    https://tiki.vn/ao-khoac-nu-cao-cap-chong-nang...      NaN    8.0
# ..                                                 ...      ...    ...
# 851  https://tiki.vn/ao-khoac-cardigan-len-nu-hoa-t...      NaN   17.0
# 852  https://tiki.vn/ao-gile-len-nu-co-cuc-thiet-ke...      NaN   11.0
# 853  https://tiki.vn/ao-len-nu-tay-no-co-va-tay-pho...      NaN    6.0
# 854  https://tiki.vn/ao-khoac-phao-nu-3-lop-chan-bo...      NaN    1.0
# 855  https://tiki.vn/set-ao-vest-blazer-nu-ngan-tay...      NaN   77.0
#
#       category     revenue
# 0    aokhoacnu  18800000.0
# 1    aokhoacnu  20915000.0
# 2    aokhoacnu  26010000.0
# 3    aokhoacnu    120000.0
# 4    aokhoacnu   1200000.0
# ..         ...         ...
# 851  aokhoacnu   3723000.0
# 852  aokhoacnu   1969000.0
# 853  aokhoacnu    624000.0
# 854  aokhoacnu    208000.0
# 855  aokhoacnu  36652000.0
#
# [856 rows x 7 columns]

# %%
df_all.to_csv("tk_aokhoacnu_all_ed.csv")
