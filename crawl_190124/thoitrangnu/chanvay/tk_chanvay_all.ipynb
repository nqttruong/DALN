# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\thoitrangnu\chanvay"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_chanvay_all.ipynb',
#  'tk_ttn_cv.ipynb',
#  'tk_ttn_cv_npage.ipynb',
#  'tk_ttn_cv_t1.csv',
#  'tk_ttn_cv_t10.csv',
#  'tk_ttn_cv_t11.csv',
#  'tk_ttn_cv_t12.csv',
#  'tk_ttn_cv_t13.csv',
#  'tk_ttn_cv_t14.csv',
#  'tk_ttn_cv_t15.csv',
#  'tk_ttn_cv_t16.csv',
#  'tk_ttn_cv_t17.csv',
#  'tk_ttn_cv_t18.csv',
#  'tk_ttn_cv_t19.csv',
#  'tk_ttn_cv_t2.csv',
#  'tk_ttn_cv_t20.csv',
#  'tk_ttn_cv_t21.csv',
#  'tk_ttn_cv_t22.csv',
#  'tk_ttn_cv_t23.csv',
#  'tk_ttn_cv_t24.csv',
#  'tk_ttn_cv_t25.csv',
#  'tk_ttn_cv_t26.csv',
#  'tk_ttn_cv_t27.csv',
#  'tk_ttn_cv_t28.csv',
#  'tk_ttn_cv_t29.csv',
#  'tk_ttn_cv_t3.csv',
#  'tk_ttn_cv_t30.csv',
#  'tk_ttn_cv_t31.csv',
#  'tk_ttn_cv_t32.csv',
#  'tk_ttn_cv_t33.csv',
#  'tk_ttn_cv_t34.csv',
#  'tk_ttn_cv_t35.csv',
#  'tk_ttn_cv_t36.csv',
#  'tk_ttn_cv_t37.csv',
#  'tk_ttn_cv_t38.csv',
#  'tk_ttn_cv_t39.csv',
#  'tk_ttn_cv_t4.csv',
#  'tk_ttn_cv_t40.csv',
#  'tk_ttn_cv_t41.csv',
#  'tk_ttn_cv_t42.csv',
#  'tk_ttn_cv_t43.csv',
#  'tk_ttn_cv_t44.csv',
#  'tk_ttn_cv_t45.csv',
#  'tk_ttn_cv_t46.csv',
#  'tk_ttn_cv_t47.csv',
#  'tk_ttn_cv_t48.csv',
#  'tk_ttn_cv_t49.csv',
#  'tk_ttn_cv_t5.csv',
#  'tk_ttn_cv_t50.csv',
#  'tk_ttn_cv_t6.csv',
#  'tk_ttn_cv_t7.csv',
#  'tk_ttn_cv_t8.csv',
#  'tk_ttn_cv_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_chanvay_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Chân váy nữ denim màu đen mới rộng rãi và thon...     39.000₫
# 1   Chân váy nữ denim màu đen mới rộng rãi và thon...     30.000₫
# 2   Chân váy ngắn công sở xẻ sau dáng chữ a Eva de...    149.000₫
# 3   Chân váy công sở lưng cao, xếp ly siêu tôn dán...     149.000
# 4                                                 NaN         NaN
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36                Vera Chân váy choàng đắp chéo SOBIE    250.000₫
# 37      Chân váy bút chì dáng dài Haint Boutique Cv13    131.000₫
# 38  Chân váy thời trang nữ Fila Tennis - FW2SKF106...  1.077.000₫
# 39                OLV - Chân váy Jennifer Cream Skirt     450.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=suEmDDkB8...      1     -49%
# 1   https://tka.tiki.vn/pixel/pixel?data=BuusAN6Bu...      2      NaN
# 2   https://tka.tiki.vn/pixel/pixel?data=sKie_gven...      3     -37%
# 3   https://tka.tiki.vn/pixel/pixel?data=oTTePa-yo...      4     -40%
# 4   https://tka.tiki.vn/pixel/pixel?data=ixOUlhGpB...      5      NaN
# ..                                                ...    ...      ...
# 35  https://tiki.vn/chan-vay-xoe-lady-fashion-p213...     36      NaN
# 36  https://tiki.vn/vera-chan-vay-choang-dap-cheo-...     37      NaN
# 37  https://tiki.vn/chan-vay-but-chi-dang-dai-hain...     38      NaN
# 38  https://tiki.vn/chan-vay-thoi-trang-nu-fila-te...     39      NaN
# 39  https://tiki.vn/olv-chan-vay-jennifer-cream-sk...     40      NaN
#
#         sales category
# 0         NaN  chanvay
# 1         NaN  chanvay
# 2   Đã bán 63  chanvay
# 3         NaN  chanvay
# 4         NaN  chanvay
# ..        ...      ...
# 35        NaN  chanvay
# 36        NaN  chanvay
# 37   Đã bán 6  chanvay
# 38        NaN  chanvay
# 39        NaN  chanvay
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Chân váy ngắn công sở xẻ sau dáng chữ a Eva de...  149.000₫
# 1    Chân Váy Kiểu Cạp Bổ 7 Mảnh Dáng Xòe Chất Tuyt...  290.000₫
# 2             Chân Váy tennis Lưng Cao xếp ly nữ - Đen   49.000₫
# 3        Chân váy lụa dài dáng đuôi cá cạp trễ cao cấp  239.000₫
# 4    Chân váy Tennis Dáng Ngắn Thiết kế xếp ly đẹp ...   69.000₫
# ..                                                 ...       ...
# 463  Chân váy xếp ly dáng dài (Cun-055 ) siêu đẹp (...  106.000₫
# 464                      CHÂN VÁY CÁCH ĐIỆU THỜI TRANG  135.000₫
# 465        Chân váy cổ tích lưới 3 lớp dễ thương VAY89  120.000₫
# 466           Chân váy xòe dài buộc nơ Elly sang trọng  139.000₫
# 467      Chân váy bút chì dáng dài Haint Boutique Cv13  131.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=sKie_gven...     -37%   Đã bán 63
# 1    https://tiki.vn/chan-vay-kieu-cap-bo-7-manh-da...     -40%  Đã bán 134
# 2    https://tiki.vn/chan-vay-tennis-lung-cao-xep-l...     -37%   Đã bán 19
# 3    https://tiki.vn/chan-vay-lua-dai-dang-duoi-ca-...      NaN    Đã bán 1
# 4    https://tiki.vn/chan-vay-tennis-dang-ngan-thie...      NaN    Đã bán 1
# ..                                                 ...      ...         ...
# 463  https://tiki.vn/chan-vay-xep-ly-dang-dai-cun-0...      NaN    Đã bán 3
# 464  https://tiki.vn/chan-vay-cach-dieu-thoi-trang-...      NaN    Đã bán 1
# 465  https://tiki.vn/chan-vay-co-tich-luoi-3-lop-de...      NaN    Đã bán 1
# 466  https://tiki.vn/chan-vay-xoe-dai-buoc-no-elly-...      NaN   Đã bán 22
# 467  https://tiki.vn/chan-vay-but-chi-dang-dai-hain...      NaN    Đã bán 6
#
#     category
# 0    chanvay
# 1    chanvay
# 2    chanvay
# 3    chanvay
# 4    chanvay
# ..       ...
# 463  chanvay
# 464  chanvay
# 465  chanvay
# 466  chanvay
# 467  chanvay
#
# [468 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      149000
# 1      290000
# 2       49000
# 3      239000
# 4       69000
#         ...
# 463    106000
# 464    135000
# 465    120000
# 466    139000
# 467    131000
# Name: price, Length: 468, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       63.0
# 1      134.0
# 2       19.0
# 3        1.0
# 4        1.0
#        ...
# 463      3.0
# 464      1.0
# 465      1.0
# 466     22.0
# 467      6.0
# Name: sales, Length: 468, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       9387000.0
# 1      38860000.0
# 2        931000.0
# 3        239000.0
# 4         69000.0
#           ...
# 463      318000.0
# 464      135000.0
# 465      120000.0
# 466     3058000.0
# 467      786000.0
# Name: revenue, Length: 468, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chanvay: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số chanvay:  1156820673.0
# So mat hang da ban:  468
# So san pham da ban:  6951.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Chân váy ngắn công sở xẻ sau dáng chữ a Eva de...  149000
# 1    Chân Váy Kiểu Cạp Bổ 7 Mảnh Dáng Xòe Chất Tuyt...  290000
# 2             Chân Váy tennis Lưng Cao xếp ly nữ - Đen   49000
# 3        Chân váy lụa dài dáng đuôi cá cạp trễ cao cấp  239000
# 4    Chân váy Tennis Dáng Ngắn Thiết kế xếp ly đẹp ...   69000
# ..                                                 ...     ...
# 463  Chân váy xếp ly dáng dài (Cun-055 ) siêu đẹp (...  106000
# 464                      CHÂN VÁY CÁCH ĐIỆU THỜI TRANG  135000
# 465        Chân váy cổ tích lưới 3 lớp dễ thương VAY89  120000
# 466           Chân váy xòe dài buộc nơ Elly sang trọng  139000
# 467      Chân váy bút chì dáng dài Haint Boutique Cv13  131000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=sKie_gven...     -37%   63.0
# 1    https://tiki.vn/chan-vay-kieu-cap-bo-7-manh-da...     -40%  134.0
# 2    https://tiki.vn/chan-vay-tennis-lung-cao-xep-l...     -37%   19.0
# 3    https://tiki.vn/chan-vay-lua-dai-dang-duoi-ca-...      NaN    1.0
# 4    https://tiki.vn/chan-vay-tennis-dang-ngan-thie...      NaN    1.0
# ..                                                 ...      ...    ...
# 463  https://tiki.vn/chan-vay-xep-ly-dang-dai-cun-0...      NaN    3.0
# 464  https://tiki.vn/chan-vay-cach-dieu-thoi-trang-...      NaN    1.0
# 465  https://tiki.vn/chan-vay-co-tich-luoi-3-lop-de...      NaN    1.0
# 466  https://tiki.vn/chan-vay-xoe-dai-buoc-no-elly-...      NaN   22.0
# 467  https://tiki.vn/chan-vay-but-chi-dang-dai-hain...      NaN    6.0
#
#     category     revenue
# 0    chanvay   9387000.0
# 1    chanvay  38860000.0
# 2    chanvay    931000.0
# 3    chanvay    239000.0
# 4    chanvay     69000.0
# ..       ...         ...
# 463  chanvay    318000.0
# 464  chanvay    135000.0
# 465  chanvay    120000.0
# 466  chanvay   3058000.0
# 467  chanvay    786000.0
#
# [468 rows x 7 columns]

# %%
df_all.to_csv("tk_chanvay_all_ed.csv")
