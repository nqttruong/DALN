# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\thoitrangnu"
os.listdir(path)
# Out:
# ['aokhoacnu',
#  'aonu',
#  'botrangphuc',
#  'brand',
#  'category.ipynb',
#  'chanvay',
#  'damnu',
#  'doboi',
#  'dodoi',
#  'dolot',
#  'dongu',
#  'quannu',
#  'thoitrangbau',
#  'thoitrangtrungnien',
#  'tk_aokhoacnu_all_ed.csv',
#  'tk_aonu_all_ed.csv',
#  'tk_botrangphuc_all_ed.csv',
#  'tk_chanvay_all_ed.csv',
#  'tk_damnu_all_ed.csv',
#  'tk_doboinu_all_ed.csv',
#  'tk_dodoinu_all_ed.csv',
#  'tk_dolotnu_all_ed.csv',
#  'tk_dongunu_all_ed.csv',
#  'tk_quannu_all_ed.csv',
#  'tk_thoitrangbau_all_ed.csv',
#  'tk_thoitrangtrungnien_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#      Unnamed: 0                                              title   price  \
# 0             0  Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235000
# 1             1  Áo khoác gió cách nhiệt GOKING, form unisex ch...  235000
# 2             2  Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255000
# 3             3  Áo Hoodie Trơn Màu Xanh Dương Cao Cấp Dáng Rộn...  120000
# 4             4     Áo Khoác Nữ Cao Cấp Chống Năng Form Lững 2 Sọc  150000
# ..          ...                                                ...     ...
# 192         192  Đầm xòe thiết kế trung niên cao cấp sang trọng...  480000
# 193         193  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...  235000
# 194         194  Váy Đầm cho người trung niên Dáng Dài họa tiết...   99000
# 195         195  Bộ đồ trung niên nữ cao cấp hè B58 - Bộ mặc nh...  275000
# 196         196  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...  225000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=xlY98fkU0...      NaN   80.0
# 1    https://tka.tiki.vn/pixel/pixel?data=vHcpn6EMV...     -44%   89.0
# 2    https://tka.tiki.vn/pixel/pixel?data=xR58NASNn...     -12%  102.0
# 3    https://tka.tiki.vn/pixel/pixel?data=uA1THT8yB...      NaN    1.0
# 4    https://tiki.vn/ao-khoac-nu-cao-cap-chong-nang...      NaN    8.0
# ..                                                 ...      ...    ...
# 192  https://tiki.vn/dam-xoe-thiet-ke-trung-nien-ca...      NaN    1.0
# 193  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN    1.0
# 194  https://tiki.vn/vay-dam-cho-nguoi-trung-nien-d...      NaN    1.0
# 195  https://tiki.vn/bo-do-trung-nien-nu-cao-cap-he...      NaN    4.0
# 196  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN    3.0
#
#                category     revenue
# 0             aokhoacnu  18800000.0
# 1             aokhoacnu  20915000.0
# 2             aokhoacnu  26010000.0
# 3             aokhoacnu    120000.0
# 4             aokhoacnu   1200000.0
# ..                  ...         ...
# 192  thoitrangtrungnien    480000.0
# 193  thoitrangtrungnien    235000.0
# 194  thoitrangtrungnien     99000.0
# 195  thoitrangtrungnien   1100000.0
# 196  thoitrangtrungnien    675000.0
#
# [7927 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "thoitrangnu")

# %%
df
# Out:
#                                                  title   price  \
# 0    Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235000
# 1    Áo khoác gió cách nhiệt GOKING, form unisex ch...  235000
# 2    Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255000
# 3    Áo Hoodie Trơn Màu Xanh Dương Cao Cấp Dáng Rộn...  120000
# 4       Áo Khoác Nữ Cao Cấp Chống Năng Form Lững 2 Sọc  150000
# ..                                                 ...     ...
# 192  Đầm xòe thiết kế trung niên cao cấp sang trọng...  480000
# 193  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...  235000
# 194  Váy Đầm cho người trung niên Dáng Dài họa tiết...   99000
# 195  Bộ đồ trung niên nữ cao cấp hè B58 - Bộ mặc nh...  275000
# 196  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...  225000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=xlY98fkU0...      NaN   80.0
# 1    https://tka.tiki.vn/pixel/pixel?data=vHcpn6EMV...     -44%   89.0
# 2    https://tka.tiki.vn/pixel/pixel?data=xR58NASNn...     -12%  102.0
# 3    https://tka.tiki.vn/pixel/pixel?data=uA1THT8yB...      NaN    1.0
# 4    https://tiki.vn/ao-khoac-nu-cao-cap-chong-nang...      NaN    8.0
# ..                                                 ...      ...    ...
# 192  https://tiki.vn/dam-xoe-thiet-ke-trung-nien-ca...      NaN    1.0
# 193  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN    1.0
# 194  https://tiki.vn/vay-dam-cho-nguoi-trung-nien-d...      NaN    1.0
# 195  https://tiki.vn/bo-do-trung-nien-nu-cao-cap-he...      NaN    4.0
# 196  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN    3.0
#
#               item_list     category     revenue
# 0             aokhoacnu  thoitrangnu  18800000.0
# 1             aokhoacnu  thoitrangnu  20915000.0
# 2             aokhoacnu  thoitrangnu  26010000.0
# 3             aokhoacnu  thoitrangnu    120000.0
# 4             aokhoacnu  thoitrangnu   1200000.0
# ..                  ...          ...         ...
# 192  thoitrangtrungnien  thoitrangnu    480000.0
# 193  thoitrangtrungnien  thoitrangnu    235000.0
# 194  thoitrangtrungnien  thoitrangnu     99000.0
# 195  thoitrangtrungnien  thoitrangnu   1100000.0
# 196  thoitrangtrungnien  thoitrangnu    675000.0
#
# [7927 rows x 8 columns]

# %%
df.to_csv('tk_thoitrangnu_all_ed.csv', index=False, encoding='utf-8')
