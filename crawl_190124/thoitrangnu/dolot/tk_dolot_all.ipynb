# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\thoitrangnu\dolot"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dolotnu_t1.csv',
#  'tk_dolotnu_t10.csv',
#  'tk_dolotnu_t11.csv',
#  'tk_dolotnu_t12.csv',
#  'tk_dolotnu_t13.csv',
#  'tk_dolotnu_t14.csv',
#  'tk_dolotnu_t15.csv',
#  'tk_dolotnu_t16.csv',
#  'tk_dolotnu_t17.csv',
#  'tk_dolotnu_t18.csv',
#  'tk_dolotnu_t19.csv',
#  'tk_dolotnu_t2.csv',
#  'tk_dolotnu_t20.csv',
#  'tk_dolotnu_t21.csv',
#  'tk_dolotnu_t22.csv',
#  'tk_dolotnu_t23.csv',
#  'tk_dolotnu_t24.csv',
#  'tk_dolotnu_t25.csv',
#  'tk_dolotnu_t26.csv',
#  'tk_dolotnu_t27.csv',
#  'tk_dolotnu_t28.csv',
#  'tk_dolotnu_t29.csv',
#  'tk_dolotnu_t3.csv',
#  'tk_dolotnu_t30.csv',
#  'tk_dolotnu_t31.csv',
#  'tk_dolotnu_t32.csv',
#  'tk_dolotnu_t33.csv',
#  'tk_dolotnu_t34.csv',
#  'tk_dolotnu_t35.csv',
#  'tk_dolotnu_t36.csv',
#  'tk_dolotnu_t37.csv',
#  'tk_dolotnu_t38.csv',
#  'tk_dolotnu_t39.csv',
#  'tk_dolotnu_t4.csv',
#  'tk_dolotnu_t40.csv',
#  'tk_dolotnu_t41.csv',
#  'tk_dolotnu_t42.csv',
#  'tk_dolotnu_t43.csv',
#  'tk_dolotnu_t44.csv',
#  'tk_dolotnu_t45.csv',
#  'tk_dolotnu_t46.csv',
#  'tk_dolotnu_t47.csv',
#  'tk_dolotnu_t48.csv',
#  'tk_dolotnu_t49.csv',
#  'tk_dolotnu_t5.csv',
#  'tk_dolotnu_t50.csv',
#  'tk_dolotnu_t6.csv',
#  'tk_dolotnu_t7.csv',
#  'tk_dolotnu_t8.csv',
#  'tk_dolotnu_t9.csv',
#  'tk_dolot_all.ipynb',
#  'tk_ttn_dl_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dolot_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Áo ngực bralette ren mỏng dây chéo ngực iBasic...   79.000₫
# 1      Áo bralette không gọng mút mỏng iBasic BRAW153  239.000₫
# 2   Áo ngực có gọng mút mỏng ren T- Shirt iBasic B...  719.200₫
# 3   Combo 3 áo lót học sinh ngắn không mút iBasic ...  180.000₫
# 4            Miếng dán ngực silicon 10cm iBasic PK091  159.000₫
# ..                                                ...       ...
# 35  Áo Lót Mút Dày Siêu Nâng Ngực Màu Trơn Basic D...  289.500₫
# 36  Combo 5 - 10 Quần lót nữ viền ren co giãn 4 ch...   45.000₫
# 37  Áo Lót Nữ, Áo Lót Đúc Su Đệm Dày Siêu Nâng Ngự...   97.000₫
# 38     Quần lót lọt khe ren 2 dây chéo mông cách điệu   29.000₫
# 39              Quần lót nữ nâng mông thoáng mát Sexy   37.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=_fEyDwDuj...      1     -80%
# 1   https://tka.tiki.vn/pixel/pixel?data=CZ7jUQ7_H...      2     -40%
# 2   https://tka.tiki.vn/pixel/pixel?data=oHTa5jfKa...      3     -20%
# 3   https://tka.tiki.vn/pixel/pixel?data=VOEpxKb16...      4     -13%
# 4   https://tka.tiki.vn/pixel/pixel?data=ektbyJ3yV...      5     -20%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ao-lot-mut-day-sieu-nang-nguc-...     36      NaN
# 36  https://tiki.vn/combo-5-10-quan-lot-nu-vien-re...     37      NaN
# 37  https://tiki.vn/ao-lot-nu-ao-lot-duc-su-dem-da...     38      NaN
# 38  https://tiki.vn/quan-lot-lot-khe-ren-2-day-che...     39      NaN
# 39  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...     40      NaN
#
#          sales category
# 0    Đã bán 25  dolotnu
# 1          NaN  dolotnu
# 2    Đã bán 12  dolotnu
# 3    Đã bán 37  dolotnu
# 4     Đã bán 3  dolotnu
# ..         ...      ...
# 35  Đã bán 170  dolotnu
# 36    Đã bán 2  dolotnu
# 37   Đã bán 43  dolotnu
# 38    Đã bán 4  dolotnu
# 39    Đã bán 5  dolotnu
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Áo ngực bralette ren mỏng dây chéo ngực iBasic...   79.000₫
# 1     Áo ngực có gọng mút mỏng ren T- Shirt iBasic B...  719.200₫
# 2     Combo 3 áo lót học sinh ngắn không mút iBasic ...  180.000₫
# 3              Miếng dán ngực silicon 10cm iBasic PK091  159.000₫
# 4       Dây áo ngực, áo lót trong suốt- Hàng Chính Hãng   20.240₫
# ...                                                 ...       ...
# 1724  Áo Lót Mút Dày Siêu Nâng Ngực Màu Trơn Basic D...  289.500₫
# 1725  Combo 5 - 10 Quần lót nữ viền ren co giãn 4 ch...   45.000₫
# 1726  Áo Lót Nữ, Áo Lót Đúc Su Đệm Dày Siêu Nâng Ngự...   97.000₫
# 1727     Quần lót lọt khe ren 2 dây chéo mông cách điệu   29.000₫
# 1728              Quần lót nữ nâng mông thoáng mát Sexy   37.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=_fEyDwDuj...     -80%   Đã bán 25
# 1     https://tka.tiki.vn/pixel/pixel?data=oHTa5jfKa...     -20%   Đã bán 12
# 2     https://tka.tiki.vn/pixel/pixel?data=VOEpxKb16...     -13%   Đã bán 37
# 3     https://tka.tiki.vn/pixel/pixel?data=ektbyJ3yV...     -20%    Đã bán 3
# 4     https://tiki.vn/day-ao-nguc-ao-lot-trong-suot-...      -8%  Đã bán 763
# ...                                                 ...      ...         ...
# 1724  https://tiki.vn/ao-lot-mut-day-sieu-nang-nguc-...      NaN  Đã bán 170
# 1725  https://tiki.vn/combo-5-10-quan-lot-nu-vien-re...      NaN    Đã bán 2
# 1726  https://tiki.vn/ao-lot-nu-ao-lot-duc-su-dem-da...      NaN   Đã bán 43
# 1727  https://tiki.vn/quan-lot-lot-khe-ren-2-day-che...      NaN    Đã bán 4
# 1728  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...      NaN    Đã bán 5
#
#      category
# 0     dolotnu
# 1     dolotnu
# 2     dolotnu
# 3     dolotnu
# 4     dolotnu
# ...       ...
# 1724  dolotnu
# 1725  dolotnu
# 1726  dolotnu
# 1727  dolotnu
# 1728  dolotnu
#
# [1729 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        79000
# 1       719200
# 2       180000
# 3       159000
# 4        20240
#          ...
# 1724    289500
# 1725     45000
# 1726     97000
# 1727     29000
# 1728     37000
# Name: price, Length: 1729, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        25.0
# 1        12.0
# 2        37.0
# 3         3.0
# 4       763.0
#         ...
# 1724    170.0
# 1725      2.0
# 1726     43.0
# 1727      4.0
# 1728      5.0
# Name: sales, Length: 1729, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        1975000.0
# 1        8630400.0
# 2        6660000.0
# 3         477000.0
# 4       15443120.0
#            ...
# 1724    49215000.0
# 1725       90000.0
# 1726     4171000.0
# 1727      116000.0
# 1728      185000.0
# Name: revenue, Length: 1729, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dolot: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dolot:  13918042621.0
# So mat hang da ban:  1729
# So san pham da ban:  111801.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Áo ngực bralette ren mỏng dây chéo ngực iBasic...   79000
# 1     Áo ngực có gọng mút mỏng ren T- Shirt iBasic B...  719200
# 2     Combo 3 áo lót học sinh ngắn không mút iBasic ...  180000
# 3              Miếng dán ngực silicon 10cm iBasic PK091  159000
# 4       Dây áo ngực, áo lót trong suốt- Hàng Chính Hãng   20240
# ...                                                 ...     ...
# 1724  Áo Lót Mút Dày Siêu Nâng Ngực Màu Trơn Basic D...  289500
# 1725  Combo 5 - 10 Quần lót nữ viền ren co giãn 4 ch...   45000
# 1726  Áo Lót Nữ, Áo Lót Đúc Su Đệm Dày Siêu Nâng Ngự...   97000
# 1727     Quần lót lọt khe ren 2 dây chéo mông cách điệu   29000
# 1728              Quần lót nữ nâng mông thoáng mát Sexy   37000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=_fEyDwDuj...     -80%   25.0
# 1     https://tka.tiki.vn/pixel/pixel?data=oHTa5jfKa...     -20%   12.0
# 2     https://tka.tiki.vn/pixel/pixel?data=VOEpxKb16...     -13%   37.0
# 3     https://tka.tiki.vn/pixel/pixel?data=ektbyJ3yV...     -20%    3.0
# 4     https://tiki.vn/day-ao-nguc-ao-lot-trong-suot-...      -8%  763.0
# ...                                                 ...      ...    ...
# 1724  https://tiki.vn/ao-lot-mut-day-sieu-nang-nguc-...      NaN  170.0
# 1725  https://tiki.vn/combo-5-10-quan-lot-nu-vien-re...      NaN    2.0
# 1726  https://tiki.vn/ao-lot-nu-ao-lot-duc-su-dem-da...      NaN   43.0
# 1727  https://tiki.vn/quan-lot-lot-khe-ren-2-day-che...      NaN    4.0
# 1728  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...      NaN    5.0
#
#      category     revenue
# 0     dolotnu   1975000.0
# 1     dolotnu   8630400.0
# 2     dolotnu   6660000.0
# 3     dolotnu    477000.0
# 4     dolotnu  15443120.0
# ...       ...         ...
# 1724  dolotnu  49215000.0
# 1725  dolotnu     90000.0
# 1726  dolotnu   4171000.0
# 1727  dolotnu    116000.0
# 1728  dolotnu    185000.0
#
# [1729 rows x 7 columns]

# %%
df_all.to_csv("tk_dolot_all_ed.csv")
