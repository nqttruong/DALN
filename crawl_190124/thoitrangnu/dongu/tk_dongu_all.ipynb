# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_190124(12htrua) - Copy (6)\thoitrangnu\dongu"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dongu_all.ipynb',
#  'tk_ttn_dn.ipynb',
#  'tk_ttn_dn_npage.ipynb',
#  'tk_ttn_dongu_t1.csv',
#  'tk_ttn_dongu_t10.csv',
#  'tk_ttn_dongu_t11.csv',
#  'tk_ttn_dongu_t12.csv',
#  'tk_ttn_dongu_t13.csv',
#  'tk_ttn_dongu_t14.csv',
#  'tk_ttn_dongu_t15.csv',
#  'tk_ttn_dongu_t16.csv',
#  'tk_ttn_dongu_t17.csv',
#  'tk_ttn_dongu_t18.csv',
#  'tk_ttn_dongu_t19.csv',
#  'tk_ttn_dongu_t2.csv',
#  'tk_ttn_dongu_t20.csv',
#  'tk_ttn_dongu_t21.csv',
#  'tk_ttn_dongu_t22.csv',
#  'tk_ttn_dongu_t23.csv',
#  'tk_ttn_dongu_t24.csv',
#  'tk_ttn_dongu_t25.csv',
#  'tk_ttn_dongu_t26.csv',
#  'tk_ttn_dongu_t27.csv',
#  'tk_ttn_dongu_t28.csv',
#  'tk_ttn_dongu_t29.csv',
#  'tk_ttn_dongu_t3.csv',
#  'tk_ttn_dongu_t30.csv',
#  'tk_ttn_dongu_t31.csv',
#  'tk_ttn_dongu_t32.csv',
#  'tk_ttn_dongu_t33.csv',
#  'tk_ttn_dongu_t34.csv',
#  'tk_ttn_dongu_t35.csv',
#  'tk_ttn_dongu_t36.csv',
#  'tk_ttn_dongu_t37.csv',
#  'tk_ttn_dongu_t38.csv',
#  'tk_ttn_dongu_t39.csv',
#  'tk_ttn_dongu_t4.csv',
#  'tk_ttn_dongu_t40.csv',
#  'tk_ttn_dongu_t41.csv',
#  'tk_ttn_dongu_t42.csv',
#  'tk_ttn_dongu_t43.csv',
#  'tk_ttn_dongu_t44.csv',
#  'tk_ttn_dongu_t45.csv',
#  'tk_ttn_dongu_t46.csv',
#  'tk_ttn_dongu_t47.csv',
#  'tk_ttn_dongu_t48.csv',
#  'tk_ttn_dongu_t49.csv',
#  'tk_ttn_dongu_t5.csv',
#  'tk_ttn_dongu_t50.csv',
#  'tk_ttn_dongu_t6.csv',
#  'tk_ttn_dongu_t7.csv',
#  'tk_ttn_dongu_t8.csv',
#  'tk_ttn_dongu_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dongu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Váy ngủ sexy váy ngủ mặc nhà ren mềm cổ sâu th...   94.000₫
# 1   Set Váy Ngủ Cosplay Bikini Sexy Gợi Cảm Độc Lạ...  219.000₫
# 2   Váy ngủ bodysuit ren cổ yếm xẻ đáy sexy gợi cả...  129.000₫
# 3       Set Váy Ngủ Ren Áo Choàng Ngủ Sexy 3 Chi Tiết   199.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36              Đầm Ngủ Lụa Satin Sexy - Váy Ngủ Xinh  280.000₫
# 37  Đồ bộ lửng mặc nhà cao cấp - không nhão - khôn...  109.000₫
# 38  Váy ngủ sexy lụa cổ đổ hở lưng Q151 - Đầm ngủ ...  189.000₫
# 39  Bộ Đồ Ngủ Nữ Lụa Satin Có Mút Ngực Phối Ren Ca
https://tiki.vn/do-bo-lung-mac-nha-cao-cap-kho...      NaN    Đã bán 1
#
#     category
# 0      dongu
# 1      dongu
# 2      dongu
# 3      dongu
# 4      dongu
# ..       ...
# 980    dongu
# 981    dongu
# 982    dongu
# 983    dongu
# 984    dongu
#
# [985 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       94000
# 1      219000
# 2       76000
# 3      111200
# 4      175000
#         ...
# 980     45000
# 981     95000
# 982    399000
# 983    189000
# 984    109000
# Name: price, Length: 985, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        5.0
# 1        2.0
# 2      333.0
# 3       48.0
# 4      105.0
#        ...
# 980     44.0
# 981     82.0
# 982      5.0
# 983      8.0
# 984      1.0
# Name: sales, Length: 985, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        470000.0
# 1        438000.0
# 2      25308000.0
# 3       5337600.0
# 4      18375000.0
#           ...
# 980     1980000.0
# 981     7790000.0
# 982     1995000.0
# 983     1512000.0
# 984      109000.0
# Name: revenue, Length: 985, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dongu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dongu:  3109312620.0
# So mat hang da ban:  985
# So san pham da ban:  21434.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Váy ngủ sexy váy ngủ mặc nhà ren mềm cổ sâu th...   94000
# 1    Set Váy Ngủ Cosplay Bikini Sexy Gợi Cảm Độc Lạ...  219000
# 2    Váy ngủ lưới phối ren xẻ tà trước sexy kèm quầ...   76000
# 3            Váy Ngủ Sexy Gợi Cảm Voan Mỏng Trong Suốt  111200
# 4                   Váy ngủ lụa ren 2 dây sexy gợi cảm  175000
# ..                                                 ...     ...
# 980  Váy ngủ nữ sexy mỏng hồng gợi cảm kèm quần lọt...   45000
# 981  Đầm Ngủ Sexy|Váy Ngủ Ren Hai Dây ️FreeShip - C...   95000
# 982  Bộ đồ ngủ quần dài nữ vải bông Cotton tự nhiên...  399000
# 983  Bộ Mặc Nhà - Đồ Bộ Ngủ Nữ Chất Thun Cotton Dài...  189000
# 984  Đồ bộ lửng mặc nhà cao cấp - không nhão - khôn...  109000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=0QYRLfP89...     -22%    5.0
# 1    https://tka.tiki.vn/pixel/pixel?data=13uAcLJ-L...     -50%    2.0
# 2    https://tiki.vn/vay-ngu-luoi-phoi-ren-xe-ta-tr...     -10%  333.0
# 3    https://tiki.vn/vay-ngu-sexy-goi-cam-voan-mong...      NaN   48.0
# 4    https://tiki.vn/vay-ngu-lua-ren-2-day-sexy-goi...     -50%  105.0
# ..                                                 ...      ...    ...
# 980  https://tiki.vn/vay-ngu-nu-sexy-mong-hong-goi-...      NaN   44.0
# 981  https://tiki.vn/dam-ngu-sexy-vay-ngu-ren-hai-d...      NaN   82.0
# 982  https://tiki.vn/bo-do-ngu-quan-dai-nu-vai-bong...      NaN    5.0
# 983  https://tiki.vn/bo-mac-nha-freeship-do-bo-ngu-...      NaN    8.0
# 984  https://tiki.vn/do-bo-lung-mac-nha-cao-cap-kho...      NaN    1.0
#
#     category     revenue
# 0      dongu    470000.0
# 1      dongu    438000.0
# 2      dongu  25308000.0
# 3      dongu   5337600.0
# 4      dongu  18375000.0
# ..       ...         ...
# 980    dongu   1980000.0
# 981    dongu   7790000.0
# 982    dongu   1995000.0
# 983    dongu   1512000.0
# 984    dongu    109000.0
#
# [985 rows x 7 columns]

# %%
df_all.to_csv("tk_dongu_all_ed.csv")
