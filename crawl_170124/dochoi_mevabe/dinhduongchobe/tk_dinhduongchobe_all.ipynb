# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\dochoi_mevabe\dinhduongchobe"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dinhduongchobe_all.ipynb',
#  'tk_dinhduongchobe_t10.csv',
#  'tk_dinhduongchobe_t11.csv',
#  'tk_dinhduongchobe_t12.csv',
#  'tk_dinhduongchobe_t13.csv',
#  'tk_dinhduongchobe_t14.csv',
#  'tk_dinhduongchobe_t15.csv',
#  'tk_dinhduongchobe_t16.csv',
#  'tk_dinhduongchobe_t17.csv',
#  'tk_dinhduongchobe_t18.csv',
#  'tk_dinhduongchobe_t19.csv',
#  'tk_dinhduongchobe_t2.csv',
#  'tk_dinhduongchobe_t20.csv',
#  'tk_dinhduongchobe_t21.csv',
#  'tk_dinhduongchobe_t22.csv',
#  'tk_dinhduongchobe_t23.csv',
#  'tk_dinhduongchobe_t24.csv',
#  'tk_dinhduongchobe_t25.csv',
#  'tk_dinhduongchobe_t26.csv',
#  'tk_dinhduongchobe_t27.csv',
#  'tk_dinhduongchobe_t28.csv',
#  'tk_dinhduongchobe_t29.csv',
#  'tk_dinhduongchobe_t3.csv',
#  'tk_dinhduongchobe_t30.csv',
#  'tk_dinhduongchobe_t31.csv',
#  'tk_dinhduongchobe_t32.csv',
#  'tk_dinhduongchobe_t33.csv',
#  'tk_dinhduongchobe_t34.csv',
#  'tk_dinhduongchobe_t35.csv',
#  'tk_dinhduongchobe_t36.csv',
#  'tk_dinhduongchobe_t37.csv',
#  'tk_dinhduongchobe_t38.csv',
#  'tk_dinhduongchobe_t39.csv',
#  'tk_dinhduongchobe_t4.csv',
#  'tk_dinhduongchobe_t40.csv',
#  'tk_dinhduongchobe_t41.csv',
#  'tk_dinhduongchobe_t42.csv',
#  'tk_dinhduongchobe_t43.csv',
#  'tk_dinhduongchobe_t44.csv',
#  'tk_dinhduongchobe_t45.csv',
#  'tk_dinhduongchobe_t46.csv',
#  'tk_dinhduongchobe_t47.csv',
#  'tk_dinhduongchobe_t48.csv',
#  'tk_dinhduongchobe_t49.csv',
#  'tk_dinhduongchobe_t5.csv',
#  'tk_dinhduongchobe_t50.csv',
#  'tk_dinhduongchobe_t6.csv',
#  'tk_dinhduongchobe_t7.csv',
#  'tk_dinhduongchobe_t8.csv',
#  'tk_dinhduongchobe_t9.csv',
#  'tk_mvb_dinhduongchobe.ipynb',
#  'tk_mvb_dinhduongchobe_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dinhduongchobe_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Bánh ăn dặm cho bé MBEFOOD Bánh gạo Nhật Hokka...   42.000₫
# 1                   Canxi sữa Bioisland Úc chính hãng  373.000₫
# 2                   Sữa Bột Glico Icreo số 1 lon 820g  479.000₫
# 3   [HSD_T4.2024] Trà cốm hoa quả Burine dinh dưỡn...  143.000₫
# 4   Kẹo Dẻo Healthy Care Kids Gummy Multivitamin 2...  394.250₫
# ..                                                ...       ...
# 35  [Made in Japan] Sữa Morinaga Số 2 - Chilmil (3...  216.000₫
# 36  Sữa bột Bledina Bledilait số 3 – 900g (Từ 12-1...  338.000₫
# 37       Cháo tươi Sài Gòn Food yến mạch hạt sen 240g   19.500₫
# 38  (Hàng nguyên tem) Sữa bột Colos DHA+ số 0+/ số...  399.000₫
# 39  Sữa bột OPTIMUM GOLD Step 4 - Hộp thiếc 1,5kg ...  575.000₫
#
#                                             link_item  index discount  \
# 0   https://tiki.vn/banh-an-dam-cho-be-banh-gao-nh...      1     -22%
# 1   https://tiki.vn/canxi-sua-bioisland-uc-chinh-h...      2      -8%
# 2   https://tiki.vn/sua-bot-glico-icreo-so-1-lon-8...      3      -5%
# 3   https://tiki.vn/tra-com-hoa-qua-burine-hipp-di...      4     -11%
# 4   https://tiki.vn/keo-deo-healthy-care-kids-gumm...      5      -8%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/made-in-japan-sua-morinaga-so-...     36      NaN
# 36  https://tiki.vn/sua-bot-bledina-bledilait-so-3...     37      NaN
# 37  https://tiki.vn/chao-tuoi-sai-gon-food-yen-mac...     38      NaN
# 38  https://tiki.vn/hang-nguyen-tem-sua-bot-colos-...     39      NaN
# 39  https://tiki.vn/sua-bot-optimum-gold-step-4-ho...     40      NaN
#
#          sales        category
# 0    Đã bán 12  dinhduongchobe
# 1   Đã bán 108  dinhduongchobe
# 2    Đã bán 31  dinhduongchobe
# 3    Đã bán 33  dinhduongchobe
# 4    Đã bán 41  dinhduongchobe
# ..         ...             ...
# 35  Đã bán 123  dinhduongchobe
# 36    Đã bán 9  dinhduongchobe
# 37   Đã bán 82  dinhduongchobe
# 38    Đã bán 5  dinhduongchobe
# 39   Đã bán 47  dinhduongchobe
#
# [1975 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Bánh ăn dặm cho bé MBEFOOD Bánh gạo Nhật Hokka...   42.000₫
# 1                     Canxi sữa Bioisland Úc chính hãng  373.000₫
# 2                     Sữa Bột Glico Icreo số 1 lon 820g  479.000₫
# 3     [HSD_T4.2024] Trà cốm hoa quả Burine dinh dưỡn...  143.000₫
# 4     Kẹo Dẻo Healthy Care Kids Gummy Multivitamin 2...  394.250₫
# ...                                                 ...       ...
# 1429  [Made in Japan] Sữa Morinaga Số 2 - Chilmil (3...  216.000₫
# 1430  Sữa bột Bledina Bledilait số 3 – 900g (Từ 12-1...  338.000₫
# 1431       Cháo tươi Sài Gòn Food yến mạch hạt sen 240g   19.500₫
# 1432  (Hàng nguyên tem) Sữa bột Colos DHA+ số 0+/ số...  399.000₫
# 1433  Sữa bột OPTIMUM GOLD Step 4 - Hộp thiếc 1,5kg ...  575.000₫
#
#                                               link_item discount       sales  \
# 0     https://tiki.vn/banh-an-dam-cho-be-banh-gao-nh...     -22%   Đã bán 12
# 1     https://tiki.vn/canxi-sua-bioisland-uc-chinh-h...      -8%  Đã bán 108
# 2     https://tiki.vn/sua-bot-glico-icreo-so-1-lon-8...      -5%   Đã bán 31
# 3     https://tiki.vn/tra-com-hoa-qua-burine-hipp-di...     -11%   Đã bán 33
# 4     https://tiki.vn/keo-deo-healthy-care-kids-gumm...      -8%   Đã bán 41
# ...                                                 ...      ...         ...
# 1429  https://tiki.vn/made-in-japan-sua-morinaga-so-...      NaN  Đã bán 123
# 1430  https://tiki.vn/sua-bot-bledina-bledilait-so-3...      NaN    Đã bán 9
# 1431  https://tiki.vn/chao-tuoi-sai-gon-food-yen-mac...      NaN   Đã bán 82
# 1432  https://tiki.vn/hang-nguyen-tem-sua-bot-colos-...      NaN    Đã bán 5
# 1433  https://tiki.vn/sua-bot-optimum-gold-step-4-ho...      NaN   Đã bán 47
#
#             category
# 0     dinhduongchobe
# 1     dinhduongchobe
# 2     dinhduongchobe
# 3     dinhduongchobe
# 4     dinhduongchobe
# ...              ...
# 1429  dinhduongchobe
# 1430  dinhduongchobe
# 1431  dinhduongchobe
# 1432  dinhduongchobe
# 1433  dinhduongchobe
#
# [1434 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        42000
# 1       373000
# 2       479000
# 3       143000
# 4       394250
#          ...
# 1429    216000
# 1430    338000
# 1431     19500
# 1432    399000
# 1433    575000
# Name: price, Length: 1434, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        12.0
# 1       108.0
# 2        31.0
# 3        33.0
# 4        41.0
#         ...
# 1429    123.0
# 1430      9.0
# 1431     82.0
# 1432      5.0
# 1433     47.0
# Name: sales, Length: 1434, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0         504000.0
# 1       40284000.0
# 2       14849000.0
# 3        4719000.0
# 4       16164250.0
#            ...
# 1429    26568000.0
# 1430     3042000.0
# 1431     1599000.0
# 1432     1995000.0
# 1433    27025000.0
# Name: revenue, Length: 1434, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dinhduongchobe: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dinhduongchobe:  104152233855.0
# So mat hang da ban:  1434
# So san pham da ban:  225075.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Bánh ăn dặm cho bé MBEFOOD Bánh gạo Nhật Hokka...   42000
# 1                     Canxi sữa Bioisland Úc chính hãng  373000
# 2                     Sữa Bột Glico Icreo số 1 lon 820g  479000
# 3     [HSD_T4.2024] Trà cốm hoa quả Burine dinh dưỡn...  143000
# 4     Kẹo Dẻo Healthy Care Kids Gummy Multivitamin 2...  394250
# ...                                                 ...     ...
# 1429  [Made in Japan] Sữa Morinaga Số 2 - Chilmil (3...  216000
# 1430  Sữa bột Bledina Bledilait số 3 – 900g (Từ 12-1...  338000
# 1431       Cháo tươi Sài Gòn Food yến mạch hạt sen 240g   19500
# 1432  (Hàng nguyên tem) Sữa bột Colos DHA+ số 0+/ số...  399000
# 1433  Sữa bột OPTIMUM GOLD Step 4 - Hộp thiếc 1,5kg ...  575000
#
#                                               link_item discount  sales  \
# 0     https://tiki.vn/banh-an-dam-cho-be-banh-gao-nh...     -22%   12.0
# 1     https://tiki.vn/canxi-sua-bioisland-uc-chinh-h...      -8%  108.0
# 2     https://tiki.vn/sua-bot-glico-icreo-so-1-lon-8...      -5%   31.0
# 3     https://tiki.vn/tra-com-hoa-qua-burine-hipp-di...     -11%   33.0
# 4     https://tiki.vn/keo-deo-healthy-care-kids-gumm...      -8%   41.0
# ...                                                 ...      ...    ...
# 1429  https://tiki.vn/made-in-japan-sua-morinaga-so-...      NaN  123.0
# 1430  https://tiki.vn/sua-bot-bledina-bledilait-so-3...      NaN    9.0
# 1431  https://tiki.vn/chao-tuoi-sai-gon-food-yen-mac...      NaN   82.0
# 1432  https://tiki.vn/hang-nguyen-tem-sua-bot-colos-...      NaN    5.0
# 1433  https://tiki.vn/sua-bot-optimum-gold-step-4-ho...      NaN   47.0
#
#             category     revenue
# 0     dinhduongchobe    504000.0
# 1     dinhduongchobe  40284000.0
# 2     dinhduongchobe  14849000.0
# 3     dinhduongchobe   4719000.0
# 4     dinhduongchobe  16164250.0
# ...              ...         ...
# 1429  dinhduongchobe  26568000.0
# 1430  dinhduongchobe   3042000.0
# 1431  dinhduongchobe   1599000.0
# 1432  dinhduongchobe   1995000.0
# 1433  dinhduongchobe  27025000.0
#
# [1434 rows x 7 columns]

# %%
df_all.to_csv("tk_dinhduongchobe_all_ed.csv")
