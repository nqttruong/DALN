# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\dochoi_mevabe\tabim"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_mvb_tabim.ipynb',
#  'tk_mvb_tabim_npage.ipynb',
#  'tk_tabim_all.ipynb',
#  'tk_tabim_t1.csv',
#  'tk_tabim_t10.csv',
#  'tk_tabim_t11.csv',
#  'tk_tabim_t12.csv',
#  'tk_tabim_t13.csv',
#  'tk_tabim_t14.csv',
#  'tk_tabim_t15.csv',
#  'tk_tabim_t16.csv',
#  'tk_tabim_t17.csv',
#  'tk_tabim_t18.csv',
#  'tk_tabim_t19.csv',
#  'tk_tabim_t2.csv',
#  'tk_tabim_t20.csv',
#  'tk_tabim_t21.csv',
#  'tk_tabim_t22.csv',
#  'tk_tabim_t23.csv',
#  'tk_tabim_t24.csv',
#  'tk_tabim_t25.csv',
#  'tk_tabim_t26.csv',
#  'tk_tabim_t27.csv',
#  'tk_tabim_t28.csv',
#  'tk_tabim_t29.csv',
#  'tk_tabim_t3.csv',
#  'tk_tabim_t30.csv',
#  'tk_tabim_t31.csv',
#  'tk_tabim_t32.csv',
#  'tk_tabim_t33.csv',
#  'tk_tabim_t34.csv',
#  'tk_tabim_t35.csv',
#  'tk_tabim_t36.csv',
#  'tk_tabim_t37.csv',
#  'tk_tabim_t38.csv',
#  'tk_tabim_t39.csv',
#  'tk_tabim_t4.csv',
#  'tk_tabim_t40.csv',
#  'tk_tabim_t41.csv',
#  'tk_tabim_t42.csv',
#  'tk_tabim_t43.csv',
#  'tk_tabim_t44.csv',
#  'tk_tabim_t45.csv',
#  'tk_tabim_t46.csv',
#  'tk_tabim_t47.csv',
#  'tk_tabim_t48.csv',
#  'tk_tabim_t49.csv',
#  'tk_tabim_t5.csv',
#  'tk_tabim_t50.csv',
#  'tk_tabim_t6.csv',
#  'tk_tabim_t7.csv',
#  'tk_tabim_t8.csv',
#  'tk_tabim_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_tabim_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Bổ ...  157.000₫
# 1   Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385.000₫
# 2   Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185.000₫
# 3   Tã - Bỉm người lớn Livedo size L (22 cái/ gói)...  730.000₫
# 4    Tã - Bỉm quần người lớn Livedo size M - Nhật bản  515.000₫
# ..                                                ...       ...
# 35  Combo 3 Gói Khăn Ướt Max Clean 100 Tờ Không Hư...   73.200₫
# 36  Tã dán người lớn Abena Abri Form Premium - Nhậ...  228.000₫
# 37  Bộ 10 Cái Tã Vải Sơ Sinh Cho Bé ( màu ngẫu nhi...   55.000₫
# 38  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273.000₫
# 39  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=h-CDpfW0v...      1     -32%
# 1   https://tka.tiki.vn/pixel/pixel?data=qdTJbb4R0...      2     -40%
# 2   https://tka.tiki.vn/pixel/pixel?data=XVWE7yOZc...      3     -34%
# 3   https://tka.tiki.vn/pixel/pixel?data=8KzSf_46R...      4     -40%
# 4   https://tka.tiki.vn/pixel/pixel?data=ht3f8Yvbr...      5     -39%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/combo-4-goi-khan-uot-max-clean...     36      NaN
# 36  https://tiki.vn/tham-hut-2500ml-ta-dan-bim-ngu...     37      NaN
# 37  https://tiki.vn/bo-10-cai-ta-vai-so-sinh-nhieu...     38      NaN
# 38  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...     39      NaN
# 39  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...     40      NaN
#
#          sales category
# 0   Đã bán 5k+    tabim
# 1   Đã bán 5k+    tabim
# 2   Đã bán 5k+    tabim
# 3    Đã bán 12    tabim
# 4    Đã bán 24    tabim
# ..         ...      ...
# 35   Đã bán 30    tabim
# 36   Đã bán 35    tabim
# 37   Đã bán 60    tabim
# 38  Đã bán 217    tabim
# 39  Đã bán 189    tabim
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Bổ ...  157.000₫
# 1     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385.000₫
# 2     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185.000₫
# 3     Tã - Bỉm người lớn Livedo size L (22 cái/ gói)...  730.000₫
# 4      Tã - Bỉm quần người lớn Livedo size M - Nhật bản  515.000₫
# ...                                                 ...       ...
# 1424  Combo 3 Gói Khăn Ướt Max Clean 100 Tờ Không Hư...   73.200₫
# 1425  Tã dán người lớn Abena Abri Form Premium - Nhậ...  228.000₫
# 1426  Bộ 10 Cái Tã Vải Sơ Sinh Cho Bé ( màu ngẫu nhi...   55.000₫
# 1427  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273.000₫
# 1428  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=h-CDpfW0v...     -32%  Đã bán 5k+
# 1     https://tka.tiki.vn/pixel/pixel?data=qdTJbb4R0...     -40%  Đã bán 5k+
# 2     https://tka.tiki.vn/pixel/pixel?data=XVWE7yOZc...     -34%  Đã bán 5k+
# 3     https://tka.tiki.vn/pixel/pixel?data=8KzSf_46R...     -40%   Đã bán 12
# 4     https://tka.tiki.vn/pixel/pixel?data=ht3f8Yvbr...     -39%   Đã bán 24
# ...                                                 ...      ...         ...
# 1424  https://tiki.vn/combo-4-goi-khan-uot-max-clean...      NaN   Đã bán 30
# 1425  https://tiki.vn/tham-hut-2500ml-ta-dan-bim-ngu...      NaN   Đã bán 35
# 1426  https://tiki.vn/bo-10-cai-ta-vai-so-sinh-nhieu...      NaN   Đã bán 60
# 1427  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...      NaN  Đã bán 217
# 1428  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...      NaN  Đã bán 189
#
#      category
# 0       tabim
# 1       tabim
# 2       tabim
# 3       tabim
# 4       tabim
# ...       ...
# 1424    tabim
# 1425    tabim
# 1426    tabim
# 1427    tabim
# 1428    tabim
#
# [1429 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       157000
# 1       385000
# 2       185000
# 3       730000
# 4       515000
#          ...
# 1424     73200
# 1425    228000
# 1426     55000
# 1427    273000
# 1428    275000
# Name: price, Length: 1429, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       5000.0
# 1       5000.0
# 2       5000.0
# 3         12.0
# 4         24.0
#          ...
# 1424      30.0
# 1425      35.0
# 1426      60.0
# 1427     217.0
# 1428     189.0
# Name: sales, Length: 1429, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       7.850000e+08
# 1       1.925000e+09
# 2       9.250000e+08
# 3       8.760000e+06
# 4       1.236000e+07
#             ...
# 1424    2.196000e+06
# 1425    7.980000e+06
# 1426    3.300000e+06
# 1427    5.924100e+07
# 1428    5.197500e+07
# Name: revenue, Length: 1429, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số tabim: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số tabim:  108875175623.0
# So mat hang da ban:  1429
# So san pham da ban:  415559.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Bổ ...  157000
# 1     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385000
# 2     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185000
# 3     Tã - Bỉm người lớn Livedo size L (22 cái/ gói)...  730000
# 4      Tã - Bỉm quần người lớn Livedo size M - Nhật bản  515000
# ...                                                 ...     ...
# 1424  Combo 3 Gói Khăn Ướt Max Clean 100 Tờ Không Hư...   73200
# 1425  Tã dán người lớn Abena Abri Form Premium - Nhậ...  228000
# 1426  Bộ 10 Cái Tã Vải Sơ Sinh Cho Bé ( màu ngẫu nhi...   55000
# 1427  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273000
# 1428  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=h-CDpfW0v...     -32%  5000.0
# 1     https://tka.tiki.vn/pixel/pixel?data=qdTJbb4R0...     -40%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=XVWE7yOZc...     -34%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=8KzSf_46R...     -40%    12.0
# 4     https://tka.tiki.vn/pixel/pixel?data=ht3f8Yvbr...     -39%    24.0
# ...                                                 ...      ...     ...
# 1424  https://tiki.vn/combo-4-goi-khan-uot-max-clean...      NaN    30.0
# 1425  https://tiki.vn/tham-hut-2500ml-ta-dan-bim-ngu...      NaN    35.0
# 1426  https://tiki.vn/bo-10-cai-ta-vai-so-sinh-nhieu...      NaN    60.0
# 1427  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...      NaN   217.0
# 1428  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...      NaN   189.0
#
#      category       revenue
# 0       tabim  7.850000e+08
# 1       tabim  1.925000e+09
# 2       tabim  9.250000e+08
# 3       tabim  8.760000e+06
# 4       tabim  1.236000e+07
# ...       ...           ...
# 1424    tabim  2.196000e+06
# 1425    tabim  7.980000e+06
# 1426    tabim  3.300000e+06
# 1427    tabim  5.924100e+07
# 1428    tabim  5.197500e+07
#
# [1429 rows x 7 columns]

# %%
df_all.to_csv("tk_tabim_all_ed.csv")
