# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\dochoi_mevabe"
os.listdir(path)
# Out:
# ['Brand',
#  'category.ipynb',
#  'chamsocme',
#  'chamsocnhacua',
#  'chuanbimangthai',
#  'dinhduongchobe',
#  'dinhduongchome',
#  'dinhduongnguoilon',
#  'dochoi',
#  'dodungchobe',
#  'tabim',
#  'thoitrangmevabe',
#  'thucphamandam',
#  'tk_chamsocme_all_ed.csv',
#  'tk_chamsocnhacua_all_ed.csv',
#  'tk_dinhduongchobe_all_ed.csv',
#  'tk_dinhduongchome_all_ed.csv',
#  'tk_dinhduongnguoilon_all_ed.csv',
#  'tk_dochoi_all_ed.csv',
#  'tk_dodungchobe_all_ed.csv',
#  'tk_tabim_all_ed.csv',
#  'tk_thoitrangmevabe_all_ed.csv',
#  'tk_thucphamandam_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#     Unnamed: 0                                              title   price  \
# 0            0  Kem nghệ tươi dưỡng da trắng mịn, sạch sạm nám...  242000
# 1            1  Combo dưỡng trắng body và săn chắc eo sau sinh...  410000
# 2            2  [MUA LÀ CÓ QUÀ] Tấm Lót Thấm Sữa Nha Đam Pigeo...   47000
# 3            3  Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...  185000
# 4            4  Cốt gừng hạ thổ săn chắc eo sau sinh Wonmom 200ml  220000
# ..         ...                                                ...     ...
# 75          75   Bánh Gạo Hữu Cơ Hương Dâu Chuối APPLE MONKEY 30G   79000
# 76          76  THỰC PHẨM BỔ SUNG MÌ SOUMEN TÁCH MUỐI BỔ SUNG ...   55000
# 77          77  [Made in Korea] Ngũ cốc socola Pororo(hình sao...  158000
# 78          78  Nui Dinh Dưỡng Hữu Cơ Hình Chứ Cái Alphabet Từ...  233000
# 79          79  Combo 2 Gói Mì ăn dặm cho trẻ trên 1 tuổi Niss...  155000
#
#                                             link_item discount  sales  \
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "mevabe")

# %%
df
# Out:
#                                                 title   price  \
# 0   Kem nghệ tươi dưỡng da trắng mịn, sạch sạm nám...  242000
# 1   Combo dưỡng trắng body và săn chắc eo sau sinh...  410000
# 2   [MUA LÀ CÓ QUÀ] Tấm Lót Thấm Sữa Nha Đam Pigeo...   47000
# 3   Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...  185000
# 4   Cốt gừng hạ thổ săn chắc eo sau sinh Wonmom 200ml  220000
# ..                                                ...     ...
# 75   Bánh Gạo Hữu Cơ Hương Dâu Chuối APPLE MONKEY 30G   79000
# 76  THỰC PHẨM BỔ SUNG MÌ SOUMEN TÁCH MUỐI BỔ SUNG ...   55000
# 77  [Made in Korea] Ngũ cốc socola Pororo(hình sao...  158000
# 78  Nui Dinh Dưỡng Hữu Cơ Hình Chứ Cái Alphabet Từ...  233000
# 79  Combo 2 Gói Mì ăn dặm cho trẻ trên 1 tuổi Niss...  155000
#
#                                             link_item discount  sales  \
# 0   https://tka.tiki.vn/pixel/pixel?data=JqUZEcRgU...     -12%  592.0
# 1   https://tka.tiki.vn/pixel/pixel?data=VLuufrK6n...     -18%    9.0
# ...

# %%
df.to_csv('tk_mevabe_all_ed.csv', index=False, encoding='utf-8')
