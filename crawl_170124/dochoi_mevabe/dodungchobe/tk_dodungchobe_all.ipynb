# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\dochoi_mevabe\dodungchobe"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dodungchobe_all.ipynb',
#  'tk_dodungchobe_t1.csv',
#  'tk_dodungchobe_t10.csv',
#  'tk_dodungchobe_t11.csv',
#  'tk_dodungchobe_t12.csv',
#  'tk_dodungchobe_t13.csv',
#  'tk_dodungchobe_t14.csv',
#  'tk_dodungchobe_t15.csv',
#  'tk_dodungchobe_t16.csv',
#  'tk_dodungchobe_t17.csv',
#  'tk_dodungchobe_t18.csv',
#  'tk_dodungchobe_t19.csv',
#  'tk_dodungchobe_t2.csv',
#  'tk_dodungchobe_t20.csv',
#  'tk_dodungchobe_t21.csv',
#  'tk_dodungchobe_t22.csv',
#  'tk_dodungchobe_t23.csv',
#  'tk_dodungchobe_t24.csv',
#  'tk_dodungchobe_t25.csv',
#  'tk_dodungchobe_t26.csv',
#  'tk_dodungchobe_t27.csv',
#  'tk_dodungchobe_t28.csv',
#  'tk_dodungchobe_t29.csv',
#  'tk_dodungchobe_t3.csv',
#  'tk_dodungchobe_t30.csv',
#  'tk_dodungchobe_t31.csv',
#  'tk_dodungchobe_t32.csv',
#  'tk_dodungchobe_t33.csv',
#  'tk_dodungchobe_t34.csv',
#  'tk_dodungchobe_t35.csv',
#  'tk_dodungchobe_t36.csv',
#  'tk_dodungchobe_t37.csv',
#  'tk_dodungchobe_t38.csv',
#  'tk_dodungchobe_t39.csv',
#  'tk_dodungchobe_t4.csv',
#  'tk_dodungchobe_t40.csv',
#  'tk_dodungchobe_t41.csv',
#  'tk_dodungchobe_t42.csv',
#  'tk_dodungchobe_t43.csv',
#  'tk_dodungchobe_t44.csv',
#  'tk_dodungchobe_t45.csv',
#  'tk_dodungchobe_t46.csv',
#  'tk_dodungchobe_t47.csv',
#  'tk_dodungchobe_t48.csv',
#  'tk_dodungchobe_t49.csv',
#  'tk_dodungchobe_t5.csv',
#  'tk_dodungchobe_t50.csv',
#  'tk_dodungchobe_t6.csv',
#  'tk_dodungchobe_t7.csv',
#  'tk_dodungchobe_t8.csv',
#  'tk_dodungchobe_t9.csv',
#  'tk_mvb_dodungchobe.ipynb',
#  'tk_mvb_dodungchobe_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dodungchobe_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Bộ 2 Chai Sữa Tắm Gội Toàn Thân Cho Bé Johnson...  245.000₫
# 1                  Sữa Tắm Dưỡng Ẩm Arau Baby (450ml)  208.250₫
# 2   Xe đẩy cho bé - Xe đẩy em bé du lịch thông min...  431.000₫
# 3   Xe đẩy cho bé cao cấp XD688 - Xe đẩy kéo du lị...  569.000₫
# 4   Sữa Tắm Gội Chiết Xuất Yến Mạch 0M+ Chicco (20...  250.240₫
# ..                                                ...       ...
# 35  Mũ Bảo Vệ Đầu Cho Bé Tập Bò, Tập Đi Hạn Chế Va...   49.996₫
# 36          Combo 3 nước rửa bình sữa Dnee 620ml/chai  175.000₫
# 37  Ghế Gội Đầu Cho Bé Có Tay Vịn Cho Bé - Giao Mà...  118.000₫
# 38  Tấm lót chống thấm cho bé dùng được 2 mặt. Miế...  139.000₫
# 39  Bệt vệ sinh thu nhỏ có bé từ 18 tháng đến 3 4 ...  169.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=7e1j1ePfw...      1     -21%
# 1   https://tka.tiki.vn/pixel/pixel?data=SeG7XBFIl...      2     -15%
# 2   https://tka.tiki.vn/pixel/pixel?data=pi_HkSNP7...      3     -26%
# 3   https://tka.tiki.vn/pixel/pixel?data=UMyFeM0C4...      4     -26%
# 4   https://tka.tiki.vn/pixel/pixel?data=FjF-cQnf8...      5      -8%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/mu-bao-ve-dau-cho-be-tap-bo-ta...     36      NaN
# 36  https://tiki.vn/combo-3-nuoc-rua-binh-sua-dnee...     37      NaN
# 37  https://tiki.vn/ghe-goi-dau-cho-be-co-tay-vin-...     38      NaN
# 38  https://tiki.vn/tam-lot-chong-tham-cho-be-dung...     39      NaN
# 39  https://tiki.vn/bet-ve-sinh-thu-nho-co-be-tu-1...     40      NaN
#
#          sales     category
# 0   Đã bán 5k+  dodungchobe
# 1    Đã bán 26  dodungchobe
# 2    Đã bán 38  dodungchobe
# 3          NaN  dodungchobe
# 4     Đã bán 9  dodungchobe
# ..         ...          ...
# 35   Đã bán 96  dodungchobe
# 36  Đã bán 212  dodungchobe
# 37  Đã bán 105  dodungchobe
# 38  Đã bán 944  dodungchobe
# 39   Đã bán 44  dodungchobe
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Bộ 2 Chai Sữa Tắm Gội Toàn Thân Cho Bé Johnson...  245.000₫
# 1                    Sữa Tắm Dưỡng Ẩm Arau Baby (450ml)  208.250₫
# 2     Xe đẩy cho bé - Xe đẩy em bé du lịch thông min...  431.000₫
# 3     Sữa Tắm Gội Chiết Xuất Yến Mạch 0M+ Chicco (20...  250.240₫
# 4                  xe tròn tập đi AA1 cho bé- Song Long  212.000₫
# ...                                                 ...       ...
# 1802  Mũ Bảo Vệ Đầu Cho Bé Tập Bò, Tập Đi Hạn Chế Va...   49.996₫
# 1803          Combo 3 nước rửa bình sữa Dnee 620ml/chai  175.000₫
# 1804  Ghế Gội Đầu Cho Bé Có Tay Vịn Cho Bé - Giao Mà...  118.000₫
# 1805  Tấm lót chống thấm cho bé dùng được 2 mặt. Miế...  139.000₫
# 1806  Bệt vệ sinh thu nhỏ có bé từ 18 tháng đến 3 4 ...  169.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=7e1j1ePfw...     -21%  Đã bán 5k+
# 1     https://tka.tiki.vn/pixel/pixel?data=SeG7XBFIl...     -15%   Đã bán 26
# 2     https://tka.tiki.vn/pixel/pixel?data=pi_HkSNP7...     -26%   Đã bán 38
# 3     https://tka.tiki.vn/pixel/pixel?data=FjF-cQnf8...      -8%    Đã bán 9
# 4     https://tiki.vn/xe-tron-tap-di-aa1-cho-be-song...      -4%  Đã bán 333
# ...                                                 ...      ...         ...
# 1802  https://tiki.vn/mu-bao-ve-dau-cho-be-tap-bo-ta...      NaN   Đã bán 96
# 1803  https://tiki.vn/combo-3-nuoc-rua-binh-sua-dnee...      NaN  Đã bán 212
# 1804  https://tiki.vn/ghe-goi-dau-cho-be-co-tay-vin-...      NaN  Đã bán 105
# 1805  https://tiki.vn/tam-lot-chong-tham-cho-be-dung...      NaN  Đã bán 944
# 1806  https://tiki.vn/bet-ve-sinh-thu-nho-co-be-tu-1...      NaN   Đã bán 44
#
#          category
# 0     dodungchobe
# 1     dodungchobe
# 2     dodungchobe
# 3     dodungchobe
# 4     dodungchobe
# ...           ...
# 1802  dodungchobe
# 1803  dodungchobe
# 1804  dodungchobe
# 1805  dodungchobe
# 1806  dodungchobe
#
# [1807 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       245000
# 1       208250
# 2       431000
# 3       250240
# 4       212000
#          ...
# 1802     49996
# 1803    175000
# 1804    118000
# 1805    139000
# 1806    169000
# Name: price, Length: 1807, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       5000.0
# 1         26.0
# 2         38.0
# 3          9.0
# 4        333.0
#          ...
# 1802      96.0
# 1803     212.0
# 1804     105.0
# 1805     944.0
# 1806      44.0
# Name: sales, Length: 1807, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1.225000e+09
# 1       5.414500e+06
# 2       1.637800e+07
# 3       2.252160e+06
# 4       7.059600e+07
#             ...
# 1802    4.799616e+06
# 1803    3.710000e+07
# 1804    1.239000e+07
# 1805    1.312160e+08
# 1806    7.436000e+06
# Name: revenue, Length: 1807, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dodungchobe: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dodungchobe:  47010986014.0
# So mat hang da ban:  1807
# So san pham da ban:  204435.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Bộ 2 Chai Sữa Tắm Gội Toàn Thân Cho Bé Johnson...  245000
# 1                    Sữa Tắm Dưỡng Ẩm Arau Baby (450ml)  208250
# 2     Xe đẩy cho bé - Xe đẩy em bé du lịch thông min...  431000
# 3     Sữa Tắm Gội Chiết Xuất Yến Mạch 0M+ Chicco (20...  250240
# 4                  xe tròn tập đi AA1 cho bé- Song Long  212000
# ...                                                 ...     ...
# 1802  Mũ Bảo Vệ Đầu Cho Bé Tập Bò, Tập Đi Hạn Chế Va...   49996
# 1803          Combo 3 nước rửa bình sữa Dnee 620ml/chai  175000
# 1804  Ghế Gội Đầu Cho Bé Có Tay Vịn Cho Bé - Giao Mà...  118000
# 1805  Tấm lót chống thấm cho bé dùng được 2 mặt. Miế...  139000
# 1806  Bệt vệ sinh thu nhỏ có bé từ 18 tháng đến 3 4 ...  169000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=7e1j1ePfw...     -21%  5000.0
# 1     https://tka.tiki.vn/pixel/pixel?data=SeG7XBFIl...     -15%    26.0
# 2     https://tka.tiki.vn/pixel/pixel?data=pi_HkSNP7...     -26%    38.0
# 3     https://tka.tiki.vn/pixel/pixel?data=FjF-cQnf8...      -8%     9.0
# 4     https://tiki.vn/xe-tron-tap-di-aa1-cho-be-song...      -4%   333.0
# ...                                                 ...      ...     ...
# 1802  https://tiki.vn/mu-bao-ve-dau-cho-be-tap-bo-ta...      NaN    96.0
# 1803  https://tiki.vn/combo-3-nuoc-rua-binh-sua-dnee...      NaN   212.0
# 1804  https://tiki.vn/ghe-goi-dau-cho-be-co-tay-vin-...      NaN   105.0
# 1805  https://tiki.vn/tam-lot-chong-tham-cho-be-dung...      NaN   944.0
# 1806  https://tiki.vn/bet-ve-sinh-thu-nho-co-be-tu-1...      NaN    44.0
#
#          category       revenue
# 0     dodungchobe  1.225000e+09
# 1     dodungchobe  5.414500e+06
# 2     dodungchobe  1.637800e+07
# 3     dodungchobe  2.252160e+06
# 4     dodungchobe  7.059600e+07
# ...           ...           ...
# 1802  dodungchobe  4.799616e+06
# 1803  dodungchobe  3.710000e+07
# 1804  dodungchobe  1.239000e+07
# 1805  dodungchobe  1.312160e+08
# 1806  dodungchobe  7.436000e+06
#
# [1807 rows x 7 columns]

# %%
df_all.to_csv("tk_dodungchobe_all_ed.csv")
