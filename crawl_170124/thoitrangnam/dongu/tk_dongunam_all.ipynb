# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\thoitrangnam\dongu"
os.listdir(path)
# Out:
# ['tk_dongunam.ipynb',
#  'tk_dongunam_all.ipynb',
#  'tk_ttn_dongunam_npage.ipynb',
#  'tk_ttn_dongunam_t10.csv',
#  'tk_ttn_dongunam_t11.csv',
#  'tk_ttn_dongunam_t12.csv',
#  'tk_ttn_dongunam_t13.csv',
#  'tk_ttn_dongunam_t14.csv',
#  'tk_ttn_dongunam_t15.csv',
#  'tk_ttn_dongunam_t16.csv',
#  'tk_ttn_dongunam_t17.csv',
#  'tk_ttn_dongunam_t18.csv',
#  'tk_ttn_dongunam_t19.csv',
#  'tk_ttn_dongunam_t2.csv',
#  'tk_ttn_dongunam_t20.csv',
#  'tk_ttn_dongunam_t21.csv',
#  'tk_ttn_dongunam_t22.csv',
#  'tk_ttn_dongunam_t23.csv',
#  'tk_ttn_dongunam_t24.csv',
#  'tk_ttn_dongunam_t25.csv',
#  'tk_ttn_dongunam_t26.csv',
#  'tk_ttn_dongunam_t27.csv',
#  'tk_ttn_dongunam_t28.csv',
#  'tk_ttn_dongunam_t29.csv',
#  'tk_ttn_dongunam_t3.csv',
#  'tk_ttn_dongunam_t30.csv',
#  'tk_ttn_dongunam_t31.csv',
#  'tk_ttn_dongunam_t32.csv',
#  'tk_ttn_dongunam_t33.csv',
#  'tk_ttn_dongunam_t4.csv',
#  'tk_ttn_dongunam_t5.csv',
#  'tk_ttn_dongunam_t6.csv',
#  'tk_ttn_dongunam_t7.csv',
#  'tk_ttn_dongunam_t8.csv',
#  'tk_ttn_dongunam_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dongu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Đồ bộ nam bonrouttesm" logo Thêu Nổi , Chạy Vi...  115.000₫
# 1   Bộ Pyjama HUONGTAM Phi tay dài nam cao cấp(PDP...  196.710₫
# 2                          Bộ quần áo thể thao nam nữ   95.000₫
# 3   đồ bộ thể thao mặc nhà, đồ bộ dạo phố chất thu...   99.000₫
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Bộ áo bà ba nam xanh lá cây - Có bộ bà ba Bigs...  199.000₫
# 37  BỘ PIJAMA NAM | ĐỒ BỘ MẶC NHÀ NAM KHỎE KHOẮN S...  410.000₫
# 38  Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...  299.000₫
# 39  Quần Áo Lính Mỹ US ARMY Giá Rẻ - Quần Túi Hộp ...   480.000
#
#                                             link_item  index discount  \
# 0   https://tiki.vn/do-bo-nam-bonrouttesm-logo-the...      1     -21%
# 1   https://tiki.vn/bo-pyjama-huongtam-phi-tay-dai...      2     -34%
# 2   https://tiki.vn/bo-quan-ao-the-thao-nam-nu-p18...      3     -18%
# 3   https://tiki.vn/do-bo-the-thao-mac-nha-do-bo-d...      4     -32%
# 4   https://tiki.vn/product-p91281686.html?spid=10...      5     -34%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/bo-do-pijama-nam-quan-dai-tay-...     36      NaN
# 36  https://tiki.vn/bo-ao-ba-ba-nam-ca-te-xanh-la-...     37      NaN
# 37  https://tiki.vn/bo-pijama-nam-do-bo-mac-nha-na...     38      NaN
# 38  https://tiki.vn/bo-quan-ao-the-thao-nam-fasvin...     39      NaN
# 39  https://tiki.vn/quan-ao-linh-my-us-army-gia-re...     40      NaN
#
#        sales  category
# 0        NaN  dongunam
# 1        NaN  dongunam
# 2        NaN  dongunam
# 3        NaN  dongunam
# 4        NaN  dongunam
# ..       ...       ...
# 35       NaN  dongunam
# 36       NaN  dongunam
# 37  Đã bán 3  dongunam
# 38  Đã bán 1  dongunam
# 39       NaN  dongunam
#
# [1295 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title       price  \
# 0               Bộ quần áo nam kaki lính mỹ( xanh rêu)  1.700.000₫
# 1                Bộ đồ ngủ nam thun cotton QSHOP QN130     240.000
# 2    Bộ Mặc Nhà Có Cổ Kiểu Dáng Hiện Đại Phong Cách...    269.000₫
# 3    Bộ quần áo nam cộc tay xốp đồ bộ thể thao nam ...     99.000₫
# 4    Bộ Mặc Nhà Nam Kiểu Dáng Hiện Đại Phối Màu Thờ...    199.000₫
# ..                                                 ...         ...
# 395   Thời trang đồ lam nam đi chùa cổ lãnh tụ , 2 túi    204.000₫
# 396  Quần Áo Thể Thao, Bộ quần áo thể thao nam nữ i...     99.000₫
# 397           Bộ quần áo thể thao nam nữ in Hold Right     73.000₫
# 398  BỘ PIJAMA NAM | ĐỒ BỘ MẶC NHÀ NAM KHỎE KHOẮN S...    410.000₫
# 399  Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...    299.000₫
#
#                                              link_item discount      sales  \
# 0    https://tiki.vn/bo-quan-ao-nam-kaki-linh-my-xa...      NaN   Đã bán 2
# 1    https://tiki.vn/bo-do-ngu-nam-thun-cotton-qsho...      NaN   Đã bán 2
# 2    https://tiki.vn/bo-mac-nha-co-co-kieu-dang-hie...      NaN  Đã bán 27
# 3    https://tiki.vn/bo-quan-ao-nam-coc-tay-dui-xop...      NaN   Đã bán 7
# 4    https://tiki.vn/bo-mac-nha-nam-kieu-dang-hien-...      NaN  Đã bán 20
# ..                                                 ...      ...        ...
# 395  https://tiki.vn/thoi-trang-do-lam-nam-di-chua-...      NaN   Đã bán 4
# 396  https://tiki.vn/quan-ao-the-thao-bo-quan-ao-th...      NaN  Đã bán 48
# 397  https://tiki.vn/bo-quan-ao-the-thao-nam-nu-in-...      NaN   Đã bán 1
# 398  https://tiki.vn/bo-pijama-nam-do-bo-mac-nha-na...      NaN   Đã bán 3
# 399  https://tiki.vn/bo-quan-ao-the-thao-nam-fasvin...      NaN   Đã bán 1
#
#      category
# 0    dongunam
# 1    dongunam
# 2    dongunam
# 3    dongunam
# 4    dongunam
# ..        ...
# 395  dongunam
# 396  dongunam
# 397  dongunam
# 398  dongunam
# 399  dongunam
#
# [400 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      1700000
# 1       240000
# 2       269000
# 3        99000
# 4       199000
#         ...
# 395     204000
# 396      99000
# 397      73000
# 398     410000
# 399     299000
# Name: price, Length: 400, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       2.0
# 1       2.0
# 2      27.0
# 3       7.0
# 4      20.0
#        ...
# 395     4.0
# 396    48.0
# 397     1.0
# 398     3.0
# 399     1.0
# Name: sales, Length: 400, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      3400000.0
# 1       480000.0
# 2      7263000.0
# 3       693000.0
# 4      3980000.0
#          ...
# 395     816000.0
# 396    4752000.0
# 397      73000.0
# 398    1230000.0
# 399     299000.0
# Name: revenue, Length: 400, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dongu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dongu:  1011310523.0
# So mat hang da ban:  400
# So san pham da ban:  5739.0

# %%
df_all
# Out:
#                                                  title    price  \
# 0               Bộ quần áo nam kaki lính mỹ( xanh rêu)  1700000
# 1                Bộ đồ ngủ nam thun cotton QSHOP QN130   240000
# 2    Bộ Mặc Nhà Có Cổ Kiểu Dáng Hiện Đại Phong Cách...   269000
# 3    Bộ quần áo nam cộc tay xốp đồ bộ thể thao nam ...    99000
# 4    Bộ Mặc Nhà Nam Kiểu Dáng Hiện Đại Phối Màu Thờ...   199000
# ..                                                 ...      ...
# 395   Thời trang đồ lam nam đi chùa cổ lãnh tụ , 2 túi   204000
# 396  Quần Áo Thể Thao, Bộ quần áo thể thao nam nữ i...    99000
# 397           Bộ quần áo thể thao nam nữ in Hold Right    73000
# 398  BỘ PIJAMA NAM | ĐỒ BỘ MẶC NHÀ NAM KHỎE KHOẮN S...   410000
# 399  Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...   299000
#
#                                              link_item discount  sales  \
# 0    https://tiki.vn/bo-quan-ao-nam-kaki-linh-my-xa...      NaN    2.0
# 1    https://tiki.vn/bo-do-ngu-nam-thun-cotton-qsho...      NaN    2.0
# 2    https://tiki.vn/bo-mac-nha-co-co-kieu-dang-hie...      NaN   27.0
# 3    https://tiki.vn/bo-quan-ao-nam-coc-tay-dui-xop...      NaN    7.0
# 4    https://tiki.vn/bo-mac-nha-nam-kieu-dang-hien-...      NaN   20.0
# ..                                                 ...      ...    ...
# 395  https://tiki.vn/thoi-trang-do-lam-nam-di-chua-...      NaN    4.0
# 396  https://tiki.vn/quan-ao-the-thao-bo-quan-ao-th...      NaN   48.0
# 397  https://tiki.vn/bo-quan-ao-the-thao-nam-nu-in-...      NaN    1.0
# 398  https://tiki.vn/bo-pijama-nam-do-bo-mac-nha-na...      NaN    3.0
# 399  https://tiki.vn/bo-quan-ao-the-thao-nam-fasvin...      NaN    1.0
#
#      category    revenue
# 0    dongunam  3400000.0
# 1    dongunam   480000.0
# 2    dongunam  7263000.0
# 3    dongunam   693000.0
# 4    dongunam  3980000.0
# ..        ...        ...
# 395  dongunam   816000.0
# 396  dongunam  4752000.0
# 397  dongunam    73000.0
# 398  dongunam  1230000.0
# 399  dongunam   299000.0
#
# [400 rows x 7 columns]

# %%
df_all.to_csv("tk_dongu_all_ed.csv")
