# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\thoitrangnam\aothunnam"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_aothun_all.ipynb',
#  'tk_ttnam_aothun.ipynb',
#  'tk_ttnam_aothun_npage.ipynb',
#  'tk_ttnam_aothun_t1.csv',
#  'tk_ttnam_aothun_t10.csv',
#  'tk_ttnam_aothun_t11.csv',
#  'tk_ttnam_aothun_t12.csv',
#  'tk_ttnam_aothun_t13.csv',
#  'tk_ttnam_aothun_t14.csv',
#  'tk_ttnam_aothun_t15.csv',
#  'tk_ttnam_aothun_t16.csv',
#  'tk_ttnam_aothun_t17.csv',
#  'tk_ttnam_aothun_t18.csv',
#  'tk_ttnam_aothun_t19.csv',
#  'tk_ttnam_aothun_t2.csv',
#  'tk_ttnam_aothun_t20.csv',
#  'tk_ttnam_aothun_t21.csv',
#  'tk_ttnam_aothun_t22.csv',
#  'tk_ttnam_aothun_t23.csv',
#  'tk_ttnam_aothun_t24.csv',
#  'tk_ttnam_aothun_t25.csv',
#  'tk_ttnam_aothun_t26.csv',
#  'tk_ttnam_aothun_t27.csv',
#  'tk_ttnam_aothun_t28.csv',
#  'tk_ttnam_aothun_t29.csv',
#  'tk_ttnam_aothun_t3.csv',
#  'tk_ttnam_aothun_t30.csv',
#  'tk_ttnam_aothun_t31.csv',
#  'tk_ttnam_aothun_t32.csv',
#  'tk_ttnam_aothun_t33.csv',
#  'tk_ttnam_aothun_t34.csv',
#  'tk_ttnam_aothun_t35.csv',
#  'tk_ttnam_aothun_t36.csv',
#  'tk_ttnam_aothun_t37.csv',
#  'tk_ttnam_aothun_t38.csv',
#  'tk_ttnam_aothun_t39.csv',
#  'tk_ttnam_aothun_t4.csv',
#  'tk_ttnam_aothun_t40.csv',
#  'tk_ttnam_aothun_t41.csv',
#  'tk_ttnam_aothun_t42.csv',
#  'tk_ttnam_aothun_t43.csv',
#  'tk_ttnam_aothun_t44.csv',
#  'tk_ttnam_aothun_t45.csv',
#  'tk_ttnam_aothun_t46.csv',
#  'tk_ttnam_aothun_t47.csv',
#  'tk_ttnam_aothun_t48.csv',
#  'tk_ttnam_aothun_t49.csv',
#  'tk_ttnam_aothun_t5.csv',
#  'tk_ttnam_aothun_t50.csv',
#  'tk_ttnam_aothun_t6.csv',
#  'tk_ttnam_aothun_t7.csv',
#  'tk_ttnam_aothun_t8.csv',
#  'tk_ttnam_aothun_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_aothunnam_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Áo thun nam thoát nhiệt Nhật Bản GOKING siêu t...  159.000₫
# 1   NEVER SAY LOSE, mã logo.g43. Áo thun polo cổ b...  148.000₫
# 2   NEVER GIVE UP, mã G174. Áo thun nam nữ in chữ ...   99.000₫
# 3   Áo Polo nam cổ bẻ ngắn tay, chất liệu vải cá s...   179.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Áo thun trơn nam form rộng vải poly cotton cho...   11.000₫
# 37  Áo Phông Nam Polo Tay Ngắn Phối Màu Thời Trang...  189.000₫
# 38        Áo Polo Nam Enkoni Basic Trắng Vải Coolmate  389.000₫
# 39  Áo Thun Ba Lỗ Nam Sát Nách Vải Cotton Mềm Form...   39.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=NFWfL00oC...      1      NaN
# 1   https://tka.tiki.vn/pixel/pixel?data=Xq5YOoyLC...      2     -44%
# 2   https://tka.tiki.vn/pixel/pixel?data=Zo1QOrdgZ...      3     -12%
# 3   https://tka.tiki.vn/pixel/pixel?data=X4Dw4fFrr...      4     -21%
# 4   https://tka.tiki.vn/pixel/pixel?data=v-zi1fOKp...      5      NaN
# ..                                                ...    ...      ...
# 35  https://tiki.vn/unstopable-ma-g60-ao-thun-nam-...     36      NaN
# 36  https://tiki.vn/ao-thun-tron-nam-form-rong-vai...     37      NaN
# 37  https://tiki.vn/ao-phong-nam-polo-tay-ngan-pho...     38      NaN
# 38  https://tiki.vn/ao-polo-nam-enkoni-basic-trang...     39      NaN
# 39  https://tiki.vn/ao-thun-ba-lo-nam-sat-nach-vai...     40      NaN
#
#           sales category
# 0   Đã bán 1.7k   aothun
# 1      Đã bán 9   aothun
# 2     Đã bán 38   aothun
# 3           NaN   aothun
# 4           NaN   aothun
# ..          ...      ...
# 35          NaN   aothun
# 36    Đã bán 15   aothun
# 37   Đã bán 264   aothun
# 38     Đã bán 2   aothun
# 39     Đã bán 3   aothun
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Áo thun nam thoát nhiệt Nhật Bản GOKING siêu t...  159.000₫
# 1    NEVER SAY LOSE, mã logo.g43. Áo thun polo cổ b...  148.000₫
# 2    NEVER GIVE UP, mã G174. Áo thun nam nữ in chữ ...   99.000₫
# 3    Áo thun nam Cotton Compact Premium trẻ trung n...  139.000₫
# 4    Áo Polo Nam cổ bẻ TSIMPLE thun có cổ tay lỡ vả...  149.000₫
# ..                                                 ...       ...
# 906  Áo Thun Có Cổ Nam Giordano Luxury Touch Polo 0...  310.000₫
# 907  Áo thun trơn nam form rộng vải poly cotton cho...   11.000₫
# 908  Áo Phông Nam Polo Tay Ngắn Phối Màu Thời Trang...  189.000₫
# 909        Áo Polo Nam Enkoni Basic Trắng Vải Coolmate  389.000₫
# 910  Áo Thun Ba Lỗ Nam Sát Nách Vải Cotton Mềm Form...   39.000₫
#
#                                              link_item discount        sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=NFWfL00oC...      NaN  Đã bán 1.7k
# 1    https://tka.tiki.vn/pixel/pixel?data=Xq5YOoyLC...     -44%     Đã bán 9
# 2    https://tka.tiki.vn/pixel/pixel?data=Zo1QOrdgZ...     -12%    Đã bán 38
# 3    https://tiki.vn/ao-thun-nam-cotton-compact-pre...      NaN   Đã bán 729
# 4    https://tiki.vn/ao-polo-nam-co-be-tsimple-thun...      NaN  Đã bán 2.1k
# ..                                                 ...      ...          ...
# 906  https://tiki.vn/ao-thun-co-co-nam-giordano-lux...      NaN    Đã bán 11
# 907  https://tiki.vn/ao-thun-tron-nam-form-rong-vai...      NaN    Đã bán 15
# 908  https://tiki.vn/ao-phong-nam-polo-tay-ngan-pho...      NaN   Đã bán 264
# 909  https://tiki.vn/ao-polo-nam-enkoni-basic-trang...      NaN     Đã bán 2
# 910  https://tiki.vn/ao-thun-ba-lo-nam-sat-nach-vai...      NaN     Đã bán 3
#
#     category
# 0     aothun
# 1     aothun
# 2     aothun
# 3     aothun
# 4     aothun
# ..       ...
# 906   aothun
# 907   aothun
# 908   aothun
# 909   aothun
# 910   aothun
#
# [911 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      159000
# 1      148000
# 2       99000
# 3      139000
# 4      149000
#         ...
# 906    310000
# 907     11000
# 908    189000
# 909    389000
# 910     39000
# Name: price, Length: 911, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      1700.0
# 1         9.0
# 2        38.0
# 3       729.0
# 4      2100.0
#         ...
# 906      11.0
# 907      15.0
# 908     264.0
# 909       2.0
# 910       3.0
# Name: sales, Length: 911, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      270300000.0
# 1        1332000.0
# 2        3762000.0
# 3      101331000.0
# 4      312900000.0
#           ...
# 906      3410000.0
# 907       165000.0
# 908     49896000.0
# 909       778000.0
# 910       117000.0
# Name: revenue, Length: 911, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số aothunnam: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số aothunnam:  7632946267.0
# So mat hang da ban:  911
# So san pham da ban:  53767.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Áo thun nam thoát nhiệt Nhật Bản GOKING siêu t...  159000
# 1    NEVER SAY LOSE, mã logo.g43. Áo thun polo cổ b...  148000
# 2    NEVER GIVE UP, mã G174. Áo thun nam nữ in chữ ...   99000
# 3    Áo thun nam Cotton Compact Premium trẻ trung n...  139000
# 4    Áo Polo Nam cổ bẻ TSIMPLE thun có cổ tay lỡ vả...  149000
# ..                                                 ...     ...
# 906  Áo Thun Có Cổ Nam Giordano Luxury Touch Polo 0...  310000
# 907  Áo thun trơn nam form rộng vải poly cotton cho...   11000
# 908  Áo Phông Nam Polo Tay Ngắn Phối Màu Thời Trang...  189000
# 909        Áo Polo Nam Enkoni Basic Trắng Vải Coolmate  389000
# 910  Áo Thun Ba Lỗ Nam Sát Nách Vải Cotton Mềm Form...   39000
#
#                                              link_item discount   sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=NFWfL00oC...      NaN  1700.0
# 1    https://tka.tiki.vn/pixel/pixel?data=Xq5YOoyLC...     -44%     9.0
# 2    https://tka.tiki.vn/pixel/pixel?data=Zo1QOrdgZ...     -12%    38.0
# 3    https://tiki.vn/ao-thun-nam-cotton-compact-pre...      NaN   729.0
# 4    https://tiki.vn/ao-polo-nam-co-be-tsimple-thun...      NaN  2100.0
# ..                                                 ...      ...     ...
# 906  https://tiki.vn/ao-thun-co-co-nam-giordano-lux...      NaN    11.0
# 907  https://tiki.vn/ao-thun-tron-nam-form-rong-vai...      NaN    15.0
# 908  https://tiki.vn/ao-phong-nam-polo-tay-ngan-pho...      NaN   264.0
# 909  https://tiki.vn/ao-polo-nam-enkoni-basic-trang...      NaN     2.0
# 910  https://tiki.vn/ao-thun-ba-lo-nam-sat-nach-vai...      NaN     3.0
#
#     category      revenue
# 0     aothun  270300000.0
# 1     aothun    1332000.0
# 2     aothun    3762000.0
# 3     aothun  101331000.0
# 4     aothun  312900000.0
# ..       ...          ...
# 906   aothun    3410000.0
# 907   aothun     165000.0
# 908   aothun   49896000.0
# 909   aothun     778000.0
# 910   aothun     117000.0
#
# [911 rows x 7 columns]

# %%
df_all.to_csv("tk_aothunnam_all_ed.csv")
