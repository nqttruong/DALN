# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\thoitrangnam\dolot"
os.listdir(path)
# Out:
# ['tk_dolotnam.ipynb',
#  'tk_dolot_all.ipynb',
#  'tk_ttn_dolotnam_npage.ipynb',
#  'tk_ttn_dolotnam_t10.csv',
#  'tk_ttn_dolotnam_t11.csv',
#  'tk_ttn_dolotnam_t12.csv',
#  'tk_ttn_dolotnam_t13.csv',
#  'tk_ttn_dolotnam_t14.csv',
#  'tk_ttn_dolotnam_t15.csv',
#  'tk_ttn_dolotnam_t16.csv',
#  'tk_ttn_dolotnam_t17.csv',
#  'tk_ttn_dolotnam_t18.csv',
#  'tk_ttn_dolotnam_t19.csv',
#  'tk_ttn_dolotnam_t2.csv',
#  'tk_ttn_dolotnam_t20.csv',
#  'tk_ttn_dolotnam_t21.csv',
#  'tk_ttn_dolotnam_t22.csv',
#  'tk_ttn_dolotnam_t23.csv',
#  'tk_ttn_dolotnam_t24.csv',
#  'tk_ttn_dolotnam_t25.csv',
#  'tk_ttn_dolotnam_t26.csv',
#  'tk_ttn_dolotnam_t27.csv',
#  'tk_ttn_dolotnam_t28.csv',
#  'tk_ttn_dolotnam_t29.csv',
#  'tk_ttn_dolotnam_t3.csv',
#  'tk_ttn_dolotnam_t30.csv',
#  'tk_ttn_dolotnam_t31.csv',
#  'tk_ttn_dolotnam_t32.csv',
#  'tk_ttn_dolotnam_t33.csv',
#  'tk_ttn_dolotnam_t34.csv',
#  'tk_ttn_dolotnam_t35.csv',
#  'tk_ttn_dolotnam_t36.csv',
#  'tk_ttn_dolotnam_t37.csv',
#  'tk_ttn_dolotnam_t38.csv',
#  'tk_ttn_dolotnam_t39.csv',
#  'tk_ttn_dolotnam_t4.csv',
#  'tk_ttn_dolotnam_t40.csv',
#  'tk_ttn_dolotnam_t41.csv',
#  'tk_ttn_dolotnam_t42.csv',
#  'tk_ttn_dolotnam_t43.csv',
#  'tk_ttn_dolotnam_t44.csv',
#  'tk_ttn_dolotnam_t45.csv',
#  'tk_ttn_dolotnam_t46.csv',
#  'tk_ttn_dolotnam_t47.csv',
#  'tk_ttn_dolotnam_t48.csv',
#  'tk_ttn_dolotnam_t49.csv',
#  'tk_ttn_dolotnam_t5.csv',
#  'tk_ttn_dolotnam_t50.csv',
#  'tk_ttn_dolotnam_t6.csv',
#  'tk_ttn_dolotnam_t7.csv',
#  'tk_ttn_dolotnam_t8.csv',
#  'tk_ttn_dolotnam_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dolot_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0            Quần lót nam ren lưới thoáng mát - QL06A   95.000₫
# 1   Combo 4 Quần Lót Nam Quần Sịp Nam Sợi Cotton C...  239.000₫
# 2                                    Quần lót nam 274   29.000₫
# 3   Quần lót mềm mại thoáng khí đáy chữ U lưng thấ...   49.000₫
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36    Quần lót Nam Cotton thời trang - L ( 59 - 65kg)   99.000₫
# 37   Quần lót nam sexy dây coặc 2 bên mạnh mẽ - 1 cái   45.000₫
# 38                       Quần lót lọt khe dây gợi cảm   23.000₫
# 39               Quần lót nam lọt khe hình bướm chữ G   45.000₫
#
#                                             link_item  index discount  \
# 0   https://tiki.vn/quan-lot-nam-ren-luoi-thoang-m...      1     -30%
# 1   https://tiki.vn/combo-4-quan-sip-nam-quan-lot-...      2     -53%
# 2   https://tiki.vn/quan-lot-nam-274-p101949478.ht...      3     -44%
# 3   https://tiki.vn/quan-lot-mem-mai-thoang-khi-da...      4      NaN
# 4   https://tiki.vn/quan-lot-boxer-nam-luoi-thun-t...      5     -20%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/quan-lot-nam-dang-luoi-co-gian...     36      NaN
# 36  https://tiki.vn/quan-lot-nam-cotton-thoi-trang...     37      NaN
# 37  https://tiki.vn/quan-lot-nam-sexy-day-coac-2-b...     38      NaN
# 38  https://tiki.vn/quan-lot-lot-khe-day-goi-cam-p...     39      NaN
# 39  https://tiki.vn/quan-lot-nam-lot-khe-hinh-buom...     40      NaN
#
#         sales  category
# 0   Đã bán 15  dolotnam
# 1   Đã bán 20  dolotnam
# 2    Đã bán 2  dolotnam
# 3         NaN  dolotnam
# 4         NaN  dolotnam
# ..        ...       ...
# 35        NaN  dolotnam
# 36        NaN  dolotnam
# 37  Đã bán 10  dolotnam
# 38        NaN  dolotnam
# 39        NaN  dolotnam
#
# [1975 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0             Quần lót nam ren lưới thoáng mát - QL06A   95.000₫
# 1    Combo 4 Quần Lót Nam Quần Sịp Nam Sợi Cotton C...  239.000₫
# 2                                     Quần lót nam 274   29.000₫
# 3    Combo 5 Quần Sịp Đùi Nam Thông Hơi Nhật Bản - ...   78.000₫
# 4    Áo ba lỗ mặc nhà thể thao nam Chất Thun Co Giã...   32.000₫
# ..                                                 ...       ...
# 663  Quần lót nam lưng thấp dạng dây thiết kế siêu ...   45.000₫
# 664                         Quần Lót Nam, Quần Ngủ Nam   99.000₫
# 665                        Quần lót nam Body thun lạnh   50.000₫
# 666         LÓT NAM-MS:6043(Freeman)cotton lụa 4 chiều   47.610₫
# 667   Quần lót nam sexy dây coặc 2 bên mạnh mẽ - 1 cái   45.000₫
#
#                                              link_item discount      sales  \
# 0    https://tiki.vn/quan-lot-nam-ren-luoi-thoang-m...     -30%  Đã bán 15
# 1    https://tiki.vn/combo-4-quan-sip-nam-quan-lot-...     -53%  Đã bán 20
# 2    https://tiki.vn/quan-lot-nam-274-p101949478.ht...     -44%   Đã bán 2
# 3    https://tiki.vn/combo-5-quan-sip-dui-nam-thong...      NaN  Đã bán 39
# 4    https://tiki.vn/ao-ba-lo-mac-nha-the-thao-nam-...      NaN   Đã bán 4
# ..                                                 ...      ...        ...
# 663  https://tiki.vn/quan-lot-nam-lung-thap-dang-da...      NaN  Đã bán 24
# 664  https://tiki.vn/quan-lot-nam-quan-ngu-nam-p162...      NaN  Đã bán 61
# 665  https://tiki.vn/quan-lot-nam-body-thun-lanh-p1...      NaN  Đã bán 11
# 666  https://tiki.vn/lot-nam-ms-6043-freeman-cotton...      NaN   Đã bán 4
# 667  https://tiki.vn/quan-lot-nam-sexy-day-coac-2-b...      NaN  Đã bán 10
#
#      category
# 0    dolotnam
# 1    dolotnam
# 2    dolotnam
# 3    dolotnam
# 4    dolotnam
# ..        ...
# 663  dolotnam
# 664  dolotnam
# 665  dolotnam
# 666  dolotnam
# 667  dolotnam
#
# [668 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       95000
# 1      239000
# 2       29000
# 3       78000
# 4       32000
#         ...
# 663     45000
# 664     99000
# 665     50000
# 666     47610
# 667     45000
# Name: price, Length: 668, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      15.0
# 1      20.0
# 2       2.0
# 3      39.0
# 4       4.0
#        ...
# 663    24.0
# 664    61.0
# 665    11.0
# 666     4.0
# 667    10.0
# Name: sales, Length: 668, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      1425000.0
# 1      4780000.0
# 2        58000.0
# 3      3042000.0
# 4       128000.0
#          ...
# 663    1080000.0
# 664    6039000.0
# 665     550000.0
# 666     190440.0
# 667     450000.0
# Name: revenue, Length: 668, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dolot: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dolot:  7361184481.0
# So mat hang da ban:  668
# So san pham da ban:  60296.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0             Quần lót nam ren lưới thoáng mát - QL06A   95000
# 1    Combo 4 Quần Lót Nam Quần Sịp Nam Sợi Cotton C...  239000
# 2                                     Quần lót nam 274   29000
# 3    Combo 5 Quần Sịp Đùi Nam Thông Hơi Nhật Bản - ...   78000
# 4    Áo ba lỗ mặc nhà thể thao nam Chất Thun Co Giã...   32000
# ..                                                 ...     ...
# 663  Quần lót nam lưng thấp dạng dây thiết kế siêu ...   45000
# 664                         Quần Lót Nam, Quần Ngủ Nam   99000
# 665                        Quần lót nam Body thun lạnh   50000
# 666         LÓT NAM-MS:6043(Freeman)cotton lụa 4 chiều   47610
# 667   Quần lót nam sexy dây coặc 2 bên mạnh mẽ - 1 cái   45000
#
#                                              link_item discount  sales  \
# 0    https://tiki.vn/quan-lot-nam-ren-luoi-thoang-m...     -30%   15.0
# 1    https://tiki.vn/combo-4-quan-sip-nam-quan-lot-...     -53%   20.0
# 2    https://tiki.vn/quan-lot-nam-274-p101949478.ht...     -44%    2.0
# 3    https://tiki.vn/combo-5-quan-sip-dui-nam-thong...      NaN   39.0
# 4    https://tiki.vn/ao-ba-lo-mac-nha-the-thao-nam-...      NaN    4.0
# ..                                                 ...      ...    ...
# 663  https://tiki.vn/quan-lot-nam-lung-thap-dang-da...      NaN   24.0
# 664  https://tiki.vn/quan-lot-nam-quan-ngu-nam-p162...      NaN   61.0
# 665  https://tiki.vn/quan-lot-nam-body-thun-lanh-p1...      NaN   11.0
# 666  https://tiki.vn/lot-nam-ms-6043-freeman-cotton...      NaN    4.0
# 667  https://tiki.vn/quan-lot-nam-sexy-day-coac-2-b...      NaN   10.0
#
#      category    revenue
# 0    dolotnam  1425000.0
# 1    dolotnam  4780000.0
# 2    dolotnam    58000.0
# 3    dolotnam  3042000.0
# 4    dolotnam   128000.0
# ..        ...        ...
# 663  dolotnam  1080000.0
# 664  dolotnam  6039000.0
# 665  dolotnam   550000.0
# 666  dolotnam   190440.0
# 667  dolotnam   450000.0
#
# [668 rows x 7 columns]

# %%
df_all.to_csv("tk_dolot_all_ed.csv")
