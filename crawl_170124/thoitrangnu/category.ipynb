# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\thoitrangnu"
os.listdir(path)
# Out:
# ['aokhoacnu',
#  'aonu',
#  'botrangphuc',
#  'category.ipynb',
#  'chanvay',
#  'damnu',
#  'doboi',
#  'dodoi',
#  'dolot',
#  'dongu',
#  'quannu',
#  'thoitrangbau',
#  'thoitrangtrungnien',
#  'tk_aokhoacnu_all_ed.csv',
#  'tk_aonu_all_ed.csv',
#  'tk_botrangphuc_all_ed.csv',
#  'tk_chanvay_all_ed.csv',
#  'tk_damnu_all_ed.csv',
#  'tk_doboinu_all_ed.csv',
#  'tk_dodoinu_all_ed.csv',
#  'tk_dolotnu_all_ed.csv',
#  'tk_dongunu_all_ed.csv',
#  'tk_quannu_all_ed.csv',
#  'tk_thoitrangbau_all_ed.csv',
#  'tk_thoitrangtrungnien_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19304\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19304\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19304\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19304\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19304\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)

# %%
df
# Out:
#     Unnamed: 0                                              title   price  \
# 0            0  Áo vest nữ blazer hàn quốc [HÀNG CAO CẤP] form...  299000
# 1            1  Áo khoác gió cách nhiệt GOKING, form unisex ch...  235000
# 2            2  Áo Khoác Nữ Đẹp, Áo Khoác Nữ Form Rộng, Áo Kho...  150000
# 3            3     Áo Khoác Nữ Cao Cấp Chống Năng Form Lững 2 Sọc  150000
# 4            4       Áo Len Tăm Cổ 3 Phân Hàng Loại 1 Cao Cấp 344   55500
# ..         ...                                                ...     ...
# 208        208  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...  235000
# 209        209  Bộ quần áo trung niên nữ_ đồ bộ mặc nhà chất v...  149000
# 210        210  Bộ đồ trung niên nữ cao cấp hè B58 - Bộ mặc nh...  275000
# 211        211                                Quần Áo cho mẹ (bộ)   59950
# 212        212  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...  225000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=LjVLhvR7G...     -44%   97.0
# 1    https://tka.tiki.vn/pixel/pixel?data=ODerqHduc...     -48%   89.0
# 2    https://tka.tiki.vn/pixel/pixel?data=_dF9m3RsR...      NaN    2.0
# 3    https://tiki.vn/ao-khoac-nu-cao-cap-chong-nang...     -44%    8.0
# 4    https://tiki.vn/ao-len-tam-co-3-phan-hang-loai...     -11%   26.0
# ..                                                 ...      ...    ...
# 208  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN    1.0
# 209  https://tiki.vn/bo-quan-ao-trung-nien-nu_-do-b...      NaN    3.0
# 210  https://tiki.vn/bo-do-trung-nien-nu-cao-cap-he...      NaN    4.0
# 211  https://tiki.vn/quan-ao-cho-me-bo-p88085979.ht...      NaN    3.0
# 212  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN    3.0
#
#                  category     revenue
# 0               aokhoacnu  29003000.0
# 1               aokhoacnu  20915000.0
# 2               aokhoacnu    300000.0
# 3               aokhoacnu   1200000.0
# 4               aokhoacnu   1443000.0
# ..                    ...         ...
# 208  thoitrangtrungniennu    235000.0
# 209  thoitrangtrungniennu    447000.0
# 210  thoitrangtrungniennu   1100000.0
# 211  thoitrangtrungniennu    179850.0
# 212  thoitrangtrungniennu    675000.0
#
# [6631 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "thoitrangnu")

# %%
df
# Out:
#                                                  title   price  \
# 0    Áo vest nữ blazer hàn quốc [HÀNG CAO CẤP] form...  299000
# 1    Áo khoác gió cách nhiệt GOKING, form unisex ch...  235000
# 2    Áo Khoác Nữ Đẹp, Áo Khoác Nữ Form Rộng, Áo Kho...  150000
# 3       Áo Khoác Nữ Cao Cấp Chống Năng Form Lững 2 Sọc  150000
# 4         Áo Len Tăm Cổ 3 Phân Hàng Loại 1 Cao Cấp 344   55500
# ..                                                 ...     ...
# 208  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...  235000
# 209  Bộ quần áo trung niên nữ_ đồ bộ mặc nhà chất v...  149000
# 210  Bộ đồ trung niên nữ cao cấp hè B58 - Bộ mặc nh...  275000
# 211                                Quần Áo cho mẹ (bộ)   59950
# 212  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...  225000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=LjVLhvR7G...     -44%   97.0
# 1    https://tka.tiki.vn/pixel/pixel?data=ODerqHduc...     -48%   89.0
# 2    https://tka.tiki.vn/pixel/pixel?data=_dF9m3RsR...      NaN    2.0
# 3    https://tiki.vn/ao-khoac-nu-cao-cap-chong-nang...     -44%    8.0
# 4    https://tiki.vn/ao-len-tam-co-3-phan-hang-loai...     -11%   26.0
# ..                                                 ...      ...    ...
# 208  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN    1.0
# 209  https://tiki.vn/bo-quan-ao-trung-nien-nu_-do-b...      NaN    3.0
# 210  https://tiki.vn/bo-do-trung-nien-nu-cao-cap-he...      NaN    4.0
# 211  https://tiki.vn/quan-ao-cho-me-bo-p88085979.ht...      NaN    3.0
# 212  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN    3.0
#
#                 item_list     category     revenue
# 0               aokhoacnu  thoitrangnu  29003000.0
# 1               aokhoacnu  thoitrangnu  20915000.0
# 2               aokhoacnu  thoitrangnu    300000.0
# 3               aokhoacnu  thoitrangnu   1200000.0
# 4               aokhoacnu  thoitrangnu   1443000.0
# ..                    ...          ...         ...
# 208  thoitrangtrungniennu  thoitrangnu    235000.0
# 209  thoitrangtrungniennu  thoitrangnu    447000.0
# 210  thoitrangtrungniennu  thoitrangnu   1100000.0
# 211  thoitrangtrungniennu  thoitrangnu    179850.0
# 212  thoitrangtrungniennu  thoitrangnu    675000.0
#
# [6631 rows x 8 columns]

# %%
df.to_csv('tk_thoitrangnu_all_ed.csv', index=False, encoding='utf-8')
