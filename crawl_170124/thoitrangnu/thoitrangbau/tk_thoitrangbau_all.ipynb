# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\thoitrangnu\thoitrangbau"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_thoitrangbau_all.ipynb',
#  'tk_ttn_ttb.ipynb',
#  'tk_ttn_ttb_npage.ipynb',
#  'tk_ttn_ttb_t1.csv',
#  'tk_ttn_ttb_t10.csv',
#  'tk_ttn_ttb_t11.csv',
#  'tk_ttn_ttb_t12.csv',
#  'tk_ttn_ttb_t13.csv',
#  'tk_ttn_ttb_t14.csv',
#  'tk_ttn_ttb_t15.csv',
#  'tk_ttn_ttb_t16.csv',
#  'tk_ttn_ttb_t17.csv',
#  'tk_ttn_ttb_t18.csv',
#  'tk_ttn_ttb_t19.csv',
#  'tk_ttn_ttb_t2.csv',
#  'tk_ttn_ttb_t20.csv',
#  'tk_ttn_ttb_t21.csv',
#  'tk_ttn_ttb_t22.csv',
#  'tk_ttn_ttb_t23.csv',
#  'tk_ttn_ttb_t24.csv',
#  'tk_ttn_ttb_t25.csv',
#  'tk_ttn_ttb_t26.csv',
#  'tk_ttn_ttb_t27.csv',
#  'tk_ttn_ttb_t28.csv',
#  'tk_ttn_ttb_t29.csv',
#  'tk_ttn_ttb_t3.csv',
#  'tk_ttn_ttb_t30.csv',
#  'tk_ttn_ttb_t31.csv',
#  'tk_ttn_ttb_t32.csv',
#  'tk_ttn_ttb_t33.csv',
#  'tk_ttn_ttb_t34.csv',
#  'tk_ttn_ttb_t4.csv',
#  'tk_ttn_ttb_t5.csv',
#  'tk_ttn_ttb_t6.csv',
#  'tk_ttn_ttb_t7.csv',
#  'tk_ttn_ttb_t8.csv',
#  'tk_ttn_ttb_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_thoitrangbau_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   COMBO 2 HỘP Ngũ Cốc Bầu Lạc Lạc Plus 30 gói 60...  507.400₫
# 1   Ngũ cốc bầu siêu dinh dưỡng Lạc Lạc giảm ốm ng...  257.140₫
# 2   Ngũ cốc lợi sữa Lạc Lạc Plus mới cao cấp 39 lo...  515.000₫
# 3   Áo lót bầu- áo lót cho con bú chống chảy xệ mặ...   66.000₫
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36     Quần bầu jean dáng lỡ cực xinh QBN1345-QBN1369  435.000₫
# 37                     Áo bầu có chỗ cho bé ty AB3134  285.000₫
# 38   Quần bầu THUN cotton form rộng thoải mái QBS1415  195.000₫
# 39             Chia sẻ: Quần jean bầu ống loe QBN1347   425.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=lUas-CV2o...      1     -14%
# 1   https://tka.tiki.vn/pixel/pixel?data=o_V738Ywq...      2     -14%
# 2   https://tka.tiki.vn/pixel/pixel?data=fi16IDHE9...      3     -14%
# 3   https://tiki.vn/ao-lot-bau-ao-lot-cho-con-bu-c...      4     -14%
# 4   https://tiki.vn/quan-bau-co-dap-bung-quan-legg...      5      -2%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/set-quan-ao-bau-mac-di-choi-cu...     36      NaN
# 36  https://tiki.vn/quan-bau-jean-dang-lo-cuc-xinh...     37      NaN
# 37  https://tiki.vn/ao-bau-co-cho-cho-be-ty-ab3134...     38      NaN
# 38  https://tiki.vn/quan-bau-thun-cotton-form-rong...     39      NaN
# 39  https://tiki.vn/chia-se-quan-jean-bau-ong-loe-...     40      NaN
#
#         sales      category
# 0    Đã bán 5  thoitrangbau
# 1   Đã bán 30  thoitrangbau
# 2    Đã bán 1  thoitrangbau
# 3         NaN  thoitrangbau
# 4         NaN  thoitrangbau
# ..        ...           ...
# 35        NaN  thoitrangbau
# 36        NaN  thoitrangbau
# 37        NaN  thoitrangbau
# 38        NaN  thoitrangbau
# 39        NaN  thoitrangbau
#
# [1363 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    COMBO 2 HỘP Ngũ Cốc Bầu Lạc Lạc Plus 30 gói 60...  507.400₫
# 1    Ngũ cốc bầu siêu dinh dưỡng Lạc Lạc giảm ốm ng...  257.140₫
# 2    Ngũ cốc lợi sữa Lạc Lạc Plus mới cao cấp 39 lo...  515.000₫
# 3    Quần bầu dài legging cạp chéo co giãn thoải má...   75.000₫
# 4    Quần mặc váy bầu quần đùi mặc trong váy bầu cạ...   45.000₫
# ..                                                 ...       ...
# 125  Chân Váy Bầu Xếp Ly Azuno AZ44 Có Đáp Bụng Và ...  185.000₫
# 126    Áo bầu công sở mùa hè 2023, áo bà bầu, mleeshop  109.000₫
# 127  Áo bầu xinh hàn quốc, áo babydoll bầu đẹp, MLE...  105.000₫
# 128  Quần bầu Ngố Legging bầu cotton co giãn 4 chiề...   155.000
# 129     Quần legging bầu nỉ thu đông mẫu mới siêu xinh   94.000₫
#
#                                              link_item discount      sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=lUas-CV2o...     -14%   Đã bán 5
# 1    https://tka.tiki.vn/pixel/pixel?data=o_V738Ywq...     -14%  Đã bán 30
# 2    https://tka.tiki.vn/pixel/pixel?data=fi16IDHE9...     -14%   Đã bán 1
# 3    https://tiki.vn/quan-bau-dai-legging-cap-cheo-...      NaN  Đã bán 13
# 4    https://tiki.vn/quan-mac-vay-bau-quan-dui-mac-...      NaN   Đã bán 3
# ..                                                 ...      ...        ...
# 125  https://tiki.vn/chan-vay-bau-xep-ly-azuno-az44...      NaN   Đã bán 1
# 126  https://tiki.vn/ao-bau-cong-so-mua-he-2023-ao-...      NaN   Đã bán 1
# 127  https://tiki.vn/ao-bau-xinh-han-quoc-ao-babydo...      NaN   Đã bán 1
# 128  https://tiki.vn/quan-bau-ngo-legging-bau-cotto...      NaN   Đã bán 1
# 129  https://tiki.vn/quan-legging-bau-ni-thu-dong-m...      NaN   Đã bán 3
#
#          category
# 0    thoitrangbau
# 1    thoitrangbau
# 2    thoitrangbau
# 3    thoitrangbau
# 4    thoitrangbau
# ..            ...
# 125  thoitrangbau
# 126  thoitrangbau
# 127  thoitrangbau
# 128  thoitrangbau
# 129  thoitrangbau
#
# [130 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      507400
# 1      257140
# 2      515000
# 3       75000
# 4       45000
#         ...
# 125    185000
# 126    109000
# 127    105000
# 128    155000
# 129     94000
# Name: price, Length: 130, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       5.0
# 1      30.0
# 2       1.0
# 3      13.0
# 4       3.0
#        ...
# 125     1.0
# 126     1.0
# 127     1.0
# 128     1.0
# 129     3.0
# Name: sales, Length: 130, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      2537000.0
# 1      7714200.0
# 2       515000.0
# 3       975000.0
# 4       135000.0
#          ...
# 125     185000.0
# 126     109000.0
# 127     105000.0
# 128     155000.0
# 129     282000.0
# Name: revenue, Length: 130, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số thoitrangbau: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số thoitrangbau:  71026946.0
# So mat hang da ban:  130
# So san pham da ban:  506.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    COMBO 2 HỘP Ngũ Cốc Bầu Lạc Lạc Plus 30 gói 60...  507400
# 1    Ngũ cốc bầu siêu dinh dưỡng Lạc Lạc giảm ốm ng...  257140
# 2    Ngũ cốc lợi sữa Lạc Lạc Plus mới cao cấp 39 lo...  515000
# 3    Quần bầu dài legging cạp chéo co giãn thoải má...   75000
# 4    Quần mặc váy bầu quần đùi mặc trong váy bầu cạ...   45000
# ..                                                 ...     ...
# 125  Chân Váy Bầu Xếp Ly Azuno AZ44 Có Đáp Bụng Và ...  185000
# 126    Áo bầu công sở mùa hè 2023, áo bà bầu, mleeshop  109000
# 127  Áo bầu xinh hàn quốc, áo babydoll bầu đẹp, MLE...  105000
# 128  Quần bầu Ngố Legging bầu cotton co giãn 4 chiề...  155000
# 129     Quần legging bầu nỉ thu đông mẫu mới siêu xinh   94000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=lUas-CV2o...     -14%    5.0
# 1    https://tka.tiki.vn/pixel/pixel?data=o_V738Ywq...     -14%   30.0
# 2    https://tka.tiki.vn/pixel/pixel?data=fi16IDHE9...     -14%    1.0
# 3    https://tiki.vn/quan-bau-dai-legging-cap-cheo-...      NaN   13.0
# 4    https://tiki.vn/quan-mac-vay-bau-quan-dui-mac-...      NaN    3.0
# ..                                                 ...      ...    ...
# 125  https://tiki.vn/chan-vay-bau-xep-ly-azuno-az44...      NaN    1.0
# 126  https://tiki.vn/ao-bau-cong-so-mua-he-2023-ao-...      NaN    1.0
# 127  https://tiki.vn/ao-bau-xinh-han-quoc-ao-babydo...      NaN    1.0
# 128  https://tiki.vn/quan-bau-ngo-legging-bau-cotto...      NaN    1.0
# 129  https://tiki.vn/quan-legging-bau-ni-thu-dong-m...      NaN    3.0
#
#          category    revenue
# 0    thoitrangbau  2537000.0
# 1    thoitrangbau  7714200.0
# 2    thoitrangbau   515000.0
# 3    thoitrangbau   975000.0
# 4    thoitrangbau   135000.0
# ..            ...        ...
# 125  thoitrangbau   185000.0
# 126  thoitrangbau   109000.0
# 127  thoitrangbau   105000.0
# 128  thoitrangbau   155000.0
# 129  thoitrangbau   282000.0
#
# [130 rows x 7 columns]

# %%
df_all.to_csv("tk_thoitrangbau_all_ed.csv")
