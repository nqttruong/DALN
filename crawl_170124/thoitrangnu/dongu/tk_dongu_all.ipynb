# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\thoitrangnu\dongu"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dongu_all.ipynb',
#  'tk_ttn_dn.ipynb',
#  'tk_ttn_dn_npage.ipynb',
#  'tk_ttn_dongu_t1.csv',
#  'tk_ttn_dongu_t10.csv',
#  'tk_ttn_dongu_t11.csv',
#  'tk_ttn_dongu_t12.csv',
#  'tk_ttn_dongu_t13.csv',
#  'tk_ttn_dongu_t14.csv',
#  'tk_ttn_dongu_t15.csv',
#  'tk_ttn_dongu_t16.csv',
#  'tk_ttn_dongu_t17.csv',
#  'tk_ttn_dongu_t18.csv',
#  'tk_ttn_dongu_t19.csv',
#  'tk_ttn_dongu_t2.csv',
#  'tk_ttn_dongu_t20.csv',
#  'tk_ttn_dongu_t21.csv',
#  'tk_ttn_dongu_t22.csv',
#  'tk_ttn_dongu_t23.csv',
#  'tk_ttn_dongu_t24.csv',
#  'tk_ttn_dongu_t25.csv',
#  'tk_ttn_dongu_t26.csv',
#  'tk_ttn_dongu_t27.csv',
#  'tk_ttn_dongu_t28.csv',
#  'tk_ttn_dongu_t29.csv',
#  'tk_ttn_dongu_t3.csv',
#  'tk_ttn_dongu_t30.csv',
#  'tk_ttn_dongu_t31.csv',
#  'tk_ttn_dongu_t32.csv',
#  'tk_ttn_dongu_t33.csv',
#  'tk_ttn_dongu_t34.csv',
#  'tk_ttn_dongu_t35.csv',
#  'tk_ttn_dongu_t36.csv',
#  'tk_ttn_dongu_t37.csv',
#  'tk_ttn_dongu_t38.csv',
#  'tk_ttn_dongu_t39.csv',
#  'tk_ttn_dongu_t4.csv',
#  'tk_ttn_dongu_t40.csv',
#  'tk_ttn_dongu_t41.csv',
#  'tk_ttn_dongu_t42.csv',
#  'tk_ttn_dongu_t43.csv',
#  'tk_ttn_dongu_t44.csv',
#  'tk_ttn_dongu_t45.csv',
#  'tk_ttn_dongu_t46.csv',
#  'tk_ttn_dongu_t47.csv',
#  'tk_ttn_dongu_t48.csv',
#  'tk_ttn_dongu_t49.csv',
#  'tk_ttn_dongu_t5.csv',
#  'tk_ttn_dongu_t50.csv',
#  'tk_ttn_dongu_t6.csv',
#  'tk_ttn_dongu_t7.csv',
#  'tk_ttn_dongu_t8.csv',
#  'tk_ttn_dongu_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dongu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Set Váy Ngủ Cosplay Bikini Sexy Gợi Cảm Độc Lạ...  219.000₫
# 1   Set Váy Ngủ Lưới Mỏng Ren Áo Choàng Ngủ Sexy 3...  179.000₫
# 2   Set Váy Ngủ Live-action Cosplay Bikini Sexy Gợ...  169.000₫
# 3   Váy ngủ bodysuit ren sexy cao cấp Q426 - Đồ ng...   99.000₫
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Bộ Đồ Ngủ Nữ Lụa Satin Có Mút Ngực Phối Ren Ca...  115.000₫
# 37  Váy ngủ sexy lụa cổ đổ hở lưng Q151 - Đầm ngủ ...  189.000₫
# 38        Bộ đồ pijama nữ quần dài và áo tay dài C093  157.000₫
# 39  Váy ngủ cosplay xuyên thấu hở lưng kèm chip lọ...   179.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=HZdS0IQto...      1     -50%
# 1   https://tka.tiki.vn/pixel/pixel?data=sYonq_n0Z...      2     -50%
# 2   https://tka.tiki.vn/pixel/pixel?data=3k58RSRQn...      3     -50%
# 3   https://tka.tiki.vn/pixel/pixel?data=c-wXcP-wr...      4      NaN
# 4   https://tka.tiki.vn/pixel/pixel?data=MFi0BlErt...      5      NaN
# ..                                                ...    ...      ...
# 35  https://tiki.vn/do-bo-lung-mac-nha-cao-cap-kho...     36      NaN
# 36  https://tiki.vn/bo-do-ngu-nu-lua-satin-co-mut-...     37      NaN
# 37  https://tiki.vn/vay-ngu-sexy-lua-co-do-ho-lung...     38      NaN
# 38  https://tiki.vn/bo-do-pijama-nu-quan-dai-va-ao...     39      NaN
# 39  https://tiki.vn/vay-ngu-cosplay-xuyen-thau-ho-...     40      NaN
#
#          sales category
# 0     Đã bán 2    dongu
# 1    Đã bán 80    dongu
# 2     Đã bán 3    dongu
# 3          NaN    dongu
# 4          NaN    dongu
# ..         ...      ...
# 35         NaN    dongu
# 36   Đã bán 12    dongu
# 37         NaN    dongu
# 38  Đã bán 113    dongu
# 39         NaN    dongu
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Set Váy Ngủ Cosplay Bikini Sexy Gợi Cảm Độc Lạ...  219.000₫
# 1    Set Váy Ngủ Lưới Mỏng Ren Áo Choàng Ngủ Sexy 3...  179.000₫
# 2    Set Váy Ngủ Live-action Cosplay Bikini Sexy Gợ...  169.000₫
# 3    Váy ngủ lưới phối ren xẻ tà trước sexy kèm quầ...   43.000₫
# 4            Váy Ngủ Sexy Gợi Cảm Voan Mỏng Trong Suốt  111.200₫
# ..                                                 ...       ...
# 989  Bộ Mặc Nhà - Đồ Bộ Ngủ Nữ Chất Thun Cotton Dài...  189.000₫
# 990  Đồ Bộ Pijama Nữ , Đồ Bộ Mặc Nhà Nữ Tay Ngắn, Q...  237.000₫
# 991  Váy Ngủ Nữ họa tiết hoạt hình dễ thương xinh x...   99.000₫
# 992  Bộ Đồ Ngủ Nữ Lụa Satin Có Mút Ngực Phối Ren Ca...  115.000₫
# 993        Bộ đồ pijama nữ quần dài và áo tay dài C093  157.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=HZdS0IQto...     -50%    Đã bán 2
# 1    https://tka.tiki.vn/pixel/pixel?data=sYonq_n0Z...     -50%   Đã bán 80
# 2    https://tka.tiki.vn/pixel/pixel?data=3k58RSRQn...     -50%    Đã bán 3
# 3    https://tiki.vn/vay-ngu-luoi-phoi-ren-xe-ta-tr...     -52%  Đã bán 333
# 4    https://tiki.vn/vay-ngu-sexy-goi-cam-voan-mong...     -10%   Đã bán 48
# ..                                                 ...      ...         ...
# 989  https://tiki.vn/bo-mac-nha-freeship-do-bo-ngu-...      NaN    Đã bán 8
# 990  https://tiki.vn/do-bo-pijama-nu-do-bo-mac-nha-...      NaN  Đã bán 305
# 991  https://tiki.vn/vay-ngu-nu-hoa-tiet-hoat-hinh-...      NaN    Đã bán 2
# 992  https://tiki.vn/bo-do-ngu-nu-lua-satin-co-mut-...      NaN   Đã bán 12
# 993  https://tiki.vn/bo-do-pijama-nu-quan-dai-va-ao...      NaN  Đã bán 113
#
#     category
# 0      dongu
# 1      dongu
# 2      dongu
# 3      dongu
# 4      dongu
# ..       ...
# 989    dongu
# 990    dongu
# 991    dongu
# 992    dongu
# 993    dongu
#
# [994 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      219000
# 1      179000
# 2      169000
# 3       43000
# 4      111200
#         ...
# 989    189000
# 990    237000
# 991     99000
# 992    115000
# 993    157000
# Name: price, Length: 994, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        2.0
# 1       80.0
# 2        3.0
# 3      333.0
# 4       48.0
#        ...
# 989      8.0
# 990    305.0
# 991      2.0
# 992     12.0
# 993    113.0
# Name: sales, Length: 994, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        438000.0
# 1      14320000.0
# 2        507000.0
# 3      14319000.0
# 4       5337600.0
#           ...
# 989     1512000.0
# 990    72285000.0
# 991      198000.0
# 992     1380000.0
# 993    17741000.0
# Name: revenue, Length: 994, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dongu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dongu:  3033812800.0
# So mat hang da ban:  994
# So san pham da ban:  20173.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Set Váy Ngủ Cosplay Bikini Sexy Gợi Cảm Độc Lạ...  219000
# 1    Set Váy Ngủ Lưới Mỏng Ren Áo Choàng Ngủ Sexy 3...  179000
# 2    Set Váy Ngủ Live-action Cosplay Bikini Sexy Gợ...  169000
# 3    Váy ngủ lưới phối ren xẻ tà trước sexy kèm quầ...   43000
# 4            Váy Ngủ Sexy Gợi Cảm Voan Mỏng Trong Suốt  111200
# ..                                                 ...     ...
# 989  Bộ Mặc Nhà - Đồ Bộ Ngủ Nữ Chất Thun Cotton Dài...  189000
# 990  Đồ Bộ Pijama Nữ , Đồ Bộ Mặc Nhà Nữ Tay Ngắn, Q...  237000
# 991  Váy Ngủ Nữ họa tiết hoạt hình dễ thương xinh x...   99000
# 992  Bộ Đồ Ngủ Nữ Lụa Satin Có Mút Ngực Phối Ren Ca...  115000
# 993        Bộ đồ pijama nữ quần dài và áo tay dài C093  157000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=HZdS0IQto...     -50%    2.0
# 1    https://tka.tiki.vn/pixel/pixel?data=sYonq_n0Z...     -50%   80.0
# 2    https://tka.tiki.vn/pixel/pixel?data=3k58RSRQn...     -50%    3.0
# 3    https://tiki.vn/vay-ngu-luoi-phoi-ren-xe-ta-tr...     -52%  333.0
# 4    https://tiki.vn/vay-ngu-sexy-goi-cam-voan-mong...     -10%   48.0
# ..                                                 ...      ...    ...
# 989  https://tiki.vn/bo-mac-nha-freeship-do-bo-ngu-...      NaN    8.0
# 990  https://tiki.vn/do-bo-pijama-nu-do-bo-mac-nha-...      NaN  305.0
# 991  https://tiki.vn/vay-ngu-nu-hoa-tiet-hoat-hinh-...      NaN    2.0
# 992  https://tiki.vn/bo-do-ngu-nu-lua-satin-co-mut-...      NaN   12.0
# 993  https://tiki.vn/bo-do-pijama-nu-quan-dai-va-ao...      NaN  113.0
#
#     category     revenue
# 0      dongu    438000.0
# 1      dongu  14320000.0
# 2      dongu    507000.0
# 3      dongu  14319000.0
# 4      dongu   5337600.0
# ..       ...         ...
# 989    dongu   1512000.0
# 990    dongu  72285000.0
# 991    dongu    198000.0
# 992    dongu   1380000.0
# 993    dongu  17741000.0
#
# [994 rows x 7 columns]

# %%
df_all.to_csv("tk_dongu_all_ed.csv")
