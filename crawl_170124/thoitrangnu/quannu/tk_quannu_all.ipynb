# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\thoitrangnu\quannu"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_quannu_all.ipynb',
#  'tk_ttn_qn.ipynb',
#  'tk_ttn_qn_npage.ipynb',
#  'tk_ttn_qn_t1.csv',
#  'tk_ttn_qn_t10.csv',
#  'tk_ttn_qn_t11.csv',
#  'tk_ttn_qn_t12.csv',
#  'tk_ttn_qn_t13.csv',
#  'tk_ttn_qn_t14.csv',
#  'tk_ttn_qn_t15.csv',
#  'tk_ttn_qn_t16.csv',
#  'tk_ttn_qn_t17.csv',
#  'tk_ttn_qn_t18.csv',
#  'tk_ttn_qn_t19.csv',
#  'tk_ttn_qn_t2.csv',
#  'tk_ttn_qn_t20.csv',
#  'tk_ttn_qn_t21.csv',
#  'tk_ttn_qn_t22.csv',
#  'tk_ttn_qn_t23.csv',
#  'tk_ttn_qn_t24.csv',
#  'tk_ttn_qn_t25.csv',
#  'tk_ttn_qn_t26.csv',
#  'tk_ttn_qn_t27.csv',
#  'tk_ttn_qn_t28.csv',
#  'tk_ttn_qn_t29.csv',
#  'tk_ttn_qn_t3.csv',
#  'tk_ttn_qn_t30.csv',
#  'tk_ttn_qn_t31.csv',
#  'tk_ttn_qn_t32.csv',
#  'tk_ttn_qn_t33.csv',
#  'tk_ttn_qn_t34.csv',
#  'tk_ttn_qn_t35.csv',
#  'tk_ttn_qn_t36.csv',
#  'tk_ttn_qn_t37.csv',
#  'tk_ttn_qn_t38.csv',
#  'tk_ttn_qn_t39.csv',
#  'tk_ttn_qn_t4.csv',
#  'tk_ttn_qn_t40.csv',
#  'tk_ttn_qn_t41.csv',
#  'tk_ttn_qn_t42.csv',
#  'tk_ttn_qn_t43.csv',
#  'tk_ttn_qn_t44.csv',
#  'tk_ttn_qn_t45.csv',
#  'tk_ttn_qn_t46.csv',
#  'tk_ttn_qn_t47.csv',
#  'tk_ttn_qn_t48.csv',
#  'tk_ttn_qn_t49.csv',
#  'tk_ttn_qn_t5.csv',
#  'tk_ttn_qn_t50.csv',
#  'tk_ttn_qn_t6.csv',
#  'tk_ttn_qn_t7.csv',
#  'tk_ttn_qn_t8.csv',
#  'tk_ttn_qn_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_quannu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Quần short kaki nữ GOKING, lưng thun và dây rú...  185.000₫
# 1   Quần Lengging Lửng Nữ Chất Thun Co Dãn 4 Chiều...   45.000₫
# 2   Quần Legging nâng mông gen bụng chất su đúc fu...  180.000₫
# 3   Quần short nữ ống rộng lưng cao có túi độc đáo...   139.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36                        Quần ống rộng cạp chun Qt05   87.000₫
# 37  Quần đũi nữ cạp chun Banamo quần baggy đũi lưn...   65.000₫
# 38  Quần ống sớ, quần nữ dáng suông ống rộng khóa ...  140.000₫
# 39   Quần ống rộng gân tăm đai nơ chất cotton co giãn   79.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=qqZFklwrY...      1      NaN
# 1   https://tka.tiki.vn/pixel/pixel?data=alKgRyYf4...      2      NaN
# 2   https://tka.tiki.vn/pixel/pixel?data=ff8tZm3fp...      3     -50%
# 3   https://tka.tiki.vn/pixel/pixel?data=k6rke7EqY...      4     -21%
# 4   https://tka.tiki.vn/pixel/pixel?data=0IUIfa7RJ...      5      NaN
# ..                                                ...    ...      ...
# 35  https://tiki.vn/quan-jean-nu-ong-loe-lung-cao-...     36      NaN
# 36  https://tiki.vn/quan-ong-rong-cap-chun-2-tui-q...     37      NaN
# 37  https://tiki.vn/quan-dui-nu-cap-chun-banamo-qu...     38      NaN
# 38  https://tiki.vn/quan-ong-so-quan-nu-dang-suong...     39      NaN
# 39  https://tiki.vn/quan-ong-rong-gan-tam-dai-no-c...     40      NaN
#
#          sales category
# 0   Đã bán 268   quannu
# 1   Đã bán 263   quannu
# 2     Đã bán 4   quannu
# 3          NaN   quannu
# 4          NaN   quannu
# ..         ...      ...
# 35         NaN   quannu
# 36   Đã bán 47   quannu
# 37   Đã bán 13   quannu
# 38   Đã bán 89   quannu
# 39         NaN   quannu
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Quần short kaki nữ GOKING, lưng thun và dây rú...  185.000₫
# 1    Quần Lengging Lửng Nữ Chất Thun Co Dãn 4 Chiều...   45.000₫
# 2    Quần Legging nâng mông gen bụng chất su đúc fu...  180.000₫
# 3    Quần Đùi Nữ Mặc Nhà Chất vải Lụa Hàn Quốc ,Mịn...   39.500₫
# 4    Quần ống rộng nữ, quần ống suông đũi Gu chun l...   69.000₫
# ..                                                 ...       ...
# 819  Quần Jean nữ Suông mẫu basic QJ280, Thanh lịch...  199.000₫
# 820  Quần nữ thời trang kiểu Hàn Quốc Thu Hà chất l...   149.000
# 821                        Quần ống rộng cạp chun Qt05   87.000₫
# 822  Quần đũi nữ cạp chun Banamo quần baggy đũi lưn...   65.000₫
# 823  Quần ống sớ, quần nữ dáng suông ống rộng khóa ...  140.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=qqZFklwrY...      NaN  Đã bán 268
# 1    https://tka.tiki.vn/pixel/pixel?data=alKgRyYf4...      NaN  Đã bán 263
# 2    https://tka.tiki.vn/pixel/pixel?data=ff8tZm3fp...     -50%    Đã bán 4
# 3    https://tiki.vn/quan-dui-nu-mac-nha-quan-dui-n...     -42%  Đã bán 239
# 4    https://tiki.vn/quan-ong-rong-nu-quan-ong-suon...      NaN  Đã bán 148
# ..                                                 ...      ...         ...
# 819  https://tiki.vn/quan-jean-nu-suong-mau-basic-q...      NaN    Đã bán 1
# 820  https://tiki.vn/quan-nu-thoi-trang-kieu-han-qu...      NaN    Đã bán 3
# 821  https://tiki.vn/quan-ong-rong-cap-chun-2-tui-q...      NaN   Đã bán 47
# 822  https://tiki.vn/quan-dui-nu-cap-chun-banamo-qu...      NaN   Đã bán 13
# 823  https://tiki.vn/quan-ong-so-quan-nu-dang-suong...      NaN   Đã bán 89
#
#     category
# 0     quannu
# 1     quannu
# 2     quannu
# 3     quannu
# 4     quannu
# ..       ...
# 819   quannu
# 820   quannu
# 821   quannu
# 822   quannu
# 823   quannu
#
# [824 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      185000
# 1       45000
# 2      180000
# 3       39500
# 4       69000
#         ...
# 819    199000
# 820    149000
# 821     87000
# 822     65000
# 823    140000
# Name: price, Length: 824, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      268.0
# 1      263.0
# 2        4.0
# 3      239.0
# 4      148.0
#        ...
# 819      1.0
# 820      3.0
# 821     47.0
# 822     13.0
# 823     89.0
# Name: sales, Length: 824, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      49580000.0
# 1      11835000.0
# 2        720000.0
# 3       9440500.0
# 4      10212000.0
#           ...
# 819      199000.0
# 820      447000.0
# 821     4089000.0
# 822      845000.0
# 823    12460000.0
# Name: revenue, Length: 824, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số quannu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số quannu:  2768651280.0
# So mat hang da ban:  824
# So san pham da ban:  22516.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Quần short kaki nữ GOKING, lưng thun và dây rú...  185000
# 1    Quần Lengging Lửng Nữ Chất Thun Co Dãn 4 Chiều...   45000
# 2    Quần Legging nâng mông gen bụng chất su đúc fu...  180000
# 3    Quần Đùi Nữ Mặc Nhà Chất vải Lụa Hàn Quốc ,Mịn...   39500
# 4    Quần ống rộng nữ, quần ống suông đũi Gu chun l...   69000
# ..                                                 ...     ...
# 819  Quần Jean nữ Suông mẫu basic QJ280, Thanh lịch...  199000
# 820  Quần nữ thời trang kiểu Hàn Quốc Thu Hà chất l...  149000
# 821                        Quần ống rộng cạp chun Qt05   87000
# 822  Quần đũi nữ cạp chun Banamo quần baggy đũi lưn...   65000
# 823  Quần ống sớ, quần nữ dáng suông ống rộng khóa ...  140000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=qqZFklwrY...      NaN  268.0
# 1    https://tka.tiki.vn/pixel/pixel?data=alKgRyYf4...      NaN  263.0
# 2    https://tka.tiki.vn/pixel/pixel?data=ff8tZm3fp...     -50%    4.0
# 3    https://tiki.vn/quan-dui-nu-mac-nha-quan-dui-n...     -42%  239.0
# 4    https://tiki.vn/quan-ong-rong-nu-quan-ong-suon...      NaN  148.0
# ..                                                 ...      ...    ...
# 819  https://tiki.vn/quan-jean-nu-suong-mau-basic-q...      NaN    1.0
# 820  https://tiki.vn/quan-nu-thoi-trang-kieu-han-qu...      NaN    3.0
# 821  https://tiki.vn/quan-ong-rong-cap-chun-2-tui-q...      NaN   47.0
# 822  https://tiki.vn/quan-dui-nu-cap-chun-banamo-qu...      NaN   13.0
# 823  https://tiki.vn/quan-ong-so-quan-nu-dang-suong...      NaN   89.0
#
#     category     revenue
# 0     quannu  49580000.0
# 1     quannu  11835000.0
# 2     quannu    720000.0
# 3     quannu   9440500.0
# 4     quannu  10212000.0
# ..       ...         ...
# 819   quannu    199000.0
# 820   quannu    447000.0
# 821   quannu   4089000.0
# 822   quannu    845000.0
# 823   quannu  12460000.0
#
# [824 rows x 7 columns]

# %%
df_all.to_csv("tk_quannu_all_ed.csv")
