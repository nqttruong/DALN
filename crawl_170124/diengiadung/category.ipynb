# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\diengiadung"
os.listdir(path)
# Out:
# ['category.ipynb',
#  'dodungnhabep',
#  'thietbigiadinh',
#  'tk_dodungnhabep_all_ed.csv',
#  'tk_thietbigiadinh_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#       Unnamed: 0                                              title    price  \
# 0              0  Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1249000
# 1              1  Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   239000
# 2              2  Ấm Siêu Tốc Inox SUNHOUSE HAPPY TIME HTD1055 (...   139000
# 3              3  Lò Nướng Đa Năng COMET CM6516 (18 Lít) - Hàng ...   869000
# 4              4  Nồi điện đa năng Locknlock Electric Multipot E...   945000
# ...          ...                                                ...      ...
# 1291        1291     Quạt Bàn Lifan B-106 - Trắng - Hàng chính hãng   180000
# 1292        1292  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...   240000
# 1293        1293  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    69000
# 1294        1294  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   603000
# 1295        1295  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1569000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=7IYS52One...     -20%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=j56Zt1bJH...     -43%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=CvTdcPsLr...     -27%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=Sv35L8T3D...     -20%    49.0
# 4     https://tka.tiki.vn/pixel/pixel?data=0jRGH1VYs...     -50%    33.0
# ...                                                 ...      ...     ...
# 1291  https://tiki.vn/quat-ban-lifan-b-106-trang-han...      NaN    16.0
# 1292  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...      NaN     3.0
# 1293  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1294  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   395.0
# 1295  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...      NaN  1600.0
#
#             category       revenue
# 0       dodungnhabep  1.623700e+09
# 1       dodungnhabep  1.195000e+09
# 2       dodungnhabep  6.950000e+08
# 3       dodungnhabep  4.258100e+07
# 4       dodungnhabep  3.118500e+07
# ...              ...           ...
# 1291  thietbigiadinh  2.880000e+06
# 1292  thietbigiadinh  7.200000e+05
# 1293  thietbigiadinh  1.725000e+06
# 1294  thietbigiadinh  2.381850e+08
# 1295  thietbigiadinh  2.510400e+09
#
# [2627 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "diengiadung")

# %%
df
# Out:
#                                                   title    price  \
# 0     Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1249000
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   239000
# 2     Ấm Siêu Tốc Inox SUNHOUSE HAPPY TIME HTD1055 (...   139000
# 3     Lò Nướng Đa Năng COMET CM6516 (18 Lít) - Hàng ...   869000
# 4     Nồi điện đa năng Locknlock Electric Multipot E...   945000
# ...                                                 ...      ...
# 1291     Quạt Bàn Lifan B-106 - Trắng - Hàng chính hãng   180000
# 1292  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...   240000
# 1293  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    69000
# 1294  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   603000
# 1295  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1569000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=7IYS52One...     -20%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=j56Zt1bJH...     -43%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=CvTdcPsLr...     -27%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=Sv35L8T3D...     -20%    49.0
# 4     https://tka.tiki.vn/pixel/pixel?data=0jRGH1VYs...     -50%    33.0
# ...                                                 ...      ...     ...
# 1291  https://tiki.vn/quat-ban-lifan-b-106-trang-han...      NaN    16.0
# 1292  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...      NaN     3.0
# 1293  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1294  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   395.0
# 1295  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...      NaN  1600.0
#
#            item_list     category       revenue
# 0       dodungnhabep  diengiadung  1.623700e+09
# 1       dodungnhabep  diengiadung  1.195000e+09
# 2       dodungnhabep  diengiadung  6.950000e+08
# 3       dodungnhabep  diengiadung  4.258100e+07
# 4       dodungnhabep  diengiadung  3.118500e+07
# ...              ...          ...           ...
# 1291  thietbigiadinh  diengiadung  2.880000e+06
# 1292  thietbigiadinh  diengiadung  7.200000e+05
# 1293  thietbigiadinh  diengiadung  1.725000e+06
# 1294  thietbigiadinh  diengiadung  2.381850e+08
# 1295  thietbigiadinh  diengiadung  2.510400e+09
#
# [2627 rows x 8 columns]

# %%
df.to_csv('tk_diengiadung_all_ed.csv', index=False, encoding='utf-8')
