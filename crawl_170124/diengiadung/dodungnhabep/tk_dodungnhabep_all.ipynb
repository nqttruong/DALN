# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12htrua) - Copy (2)\diengiadung\dodungnhabep"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dgd_ddnb.ipynb',
#  'tk_dgd_ddnb_npage.ipynb',
#  'tk_dodungnhabep.csv',
#  'tk_dodungnhabep_all.ipynb',
#  'tk_dodungnhabep_t10.csv',
#  'tk_dodungnhabep_t11.csv',
#  'tk_dodungnhabep_t12.csv',
#  'tk_dodungnhabep_t13.csv',
#  'tk_dodungnhabep_t14.csv',
#  'tk_dodungnhabep_t15.csv',
#  'tk_dodungnhabep_t16.csv',
#  'tk_dodungnhabep_t17.csv',
#  'tk_dodungnhabep_t18.csv',
#  'tk_dodungnhabep_t19.csv',
#  'tk_dodungnhabep_t2.csv',
#  'tk_dodungnhabep_t20.csv',
#  'tk_dodungnhabep_t21.csv',
#  'tk_dodungnhabep_t22.csv',
#  'tk_dodungnhabep_t23.csv',
#  'tk_dodungnhabep_t24.csv',
#  'tk_dodungnhabep_t25.csv',
#  'tk_dodungnhabep_t26.csv',
#  'tk_dodungnhabep_t27.csv',
#  'tk_dodungnhabep_t28.csv',
#  'tk_dodungnhabep_t29.csv',
#  'tk_dodungnhabep_t3.csv',
#  'tk_dodungnhabep_t30.csv',
#  'tk_dodungnhabep_t31.csv',
#  'tk_dodungnhabep_t32.csv',
#  'tk_dodungnhabep_t33.csv',
#  'tk_dodungnhabep_t34.csv',
#  'tk_dodungnhabep_t35.csv',
#  'tk_dodungnhabep_t36.csv',
#  'tk_dodungnhabep_t37.csv',
#  'tk_dodungnhabep_t38.csv',
#  'tk_dodungnhabep_t39.csv',
#  'tk_dodungnhabep_t4.csv',
#  'tk_dodungnhabep_t40.csv',
#  'tk_dodungnhabep_t41.csv',
#  'tk_dodungnhabep_t42.csv',
#  'tk_dodungnhabep_t43.csv',
#  'tk_dodungnhabep_t44.csv',
#  'tk_dodungnhabep_t45.csv',
#  'tk_dodungnhabep_t46.csv',
#  'tk_dodungnhabep_t47.csv',
#  'tk_dodungnhabep_t48.csv',
#  'tk_dodungnhabep_t49.csv',
#  'tk_dodungnhabep_t5.csv',
#  'tk_dodungnhabep_t50.csv',
#  'tk_dodungnhabep_t6.csv',
#  'tk_dodungnhabep_t7.csv',
#  'tk_dodungnhabep_t8.csv',
#  'tk_dodungnhabep_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dodungnhabep_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1.249.000₫
# 1   Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...    239.000₫
# 2   Ấm Siêu Tốc Inox SUNHOUSE HAPPY TIME HTD1055 (...    139.000₫
# 3   Lò Nướng Đa Năng COMET CM6516 (18 Lít) - Hàng ...    869.000₫
# 4   Nồi điện đa năng Locknlock Electric Multipot E...    945.000₫
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36                                  Máy xay cafe 600N    699.000₫
# 37  Máy trộn bột GOURMETMAXX 5L 1500W - Thương hiệ...  2.399.000₫
# 38  Nồi Chiên Không Dầu Magic A-802 (4.6 Lít) Đen ...  1.090.000₫
# 39  Máy Đánh Trứng Daewoo DWHM-354 (150W) - Hàng c...     216.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=7IYS52One...      1     -20%
# 1   https://tka.tiki.vn/pixel/pixel?data=j56Zt1bJH...      2     -43%
# 2   https://tka.tiki.vn/pixel/pixel?data=CvTdcPsLr...      3     -27%
# 3   https://tka.tiki.vn/pixel/pixel?data=Sv35L8T3D...      4     -20%
# 4   https://tka.tiki.vn/pixel/pixel?data=0jRGH1VYs...      5     -50%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/noi-com-dien-tu-cuckoo-1-08l-c...     36      NaN
# 36  https://tiki.vn/may-xay-cafe-600n-p23829470.ht...     37      NaN
# 37  https://tiki.vn/may-tron-bot-gourmetmaxx-5l-15...     38      NaN
# 38  https://tiki.vn/noi-chien-khong-dau-magic-a-80...     39      NaN
# 39  https://tiki.vn/may-danh-trung-daewoo-dwhm-354...     40      NaN
#
#           sales      category
# 0   Đã bán 1.3k  dodungnhabep
# 1    Đã bán 5k+  dodungnhabep
# 2    Đã bán 5k+  dodungnhabep
# 3     Đã bán 49  dodungnhabep
# 4     Đã bán 33  dodungnhabep
# ..          ...           ...
# 35          NaN  dodungnhabep
# 36   Đã bán 201  dodungnhabep
# 37    Đã bán 25  dodungnhabep
# 38  Đã bán 1.1k  dodungnhabep
# 39          NaN  dodungnhabep
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1.249.000₫
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...    239.000₫
# 2     Ấm Siêu Tốc Inox SUNHOUSE HAPPY TIME HTD1055 (...    139.000₫
# 3     Lò Nướng Đa Năng COMET CM6516 (18 Lít) - Hàng ...    869.000₫
# 4     Nồi điện đa năng Locknlock Electric Multipot E...    945.000₫
# ...                                                 ...         ...
# 1326  Nồi Cơm Điện Xiaomi Thông Minh Cao Tần 1,6L - ...  1.510.000₫
# 1327  Nồi điện đa năng phủ chống dính cao cấp - Nồi ...    299.000₫
# 1328                                  Máy xay cafe 600N    699.000₫
# 1329  Máy trộn bột GOURMETMAXX 5L 1500W - Thương hiệ...  2.399.000₫
# 1330  Nồi Chiên Không Dầu Magic A-802 (4.6 Lít) Đen ...  1.090.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=7IYS52One...     -20%  Đã bán 1.3k
# 1     https://tka.tiki.vn/pixel/pixel?data=j56Zt1bJH...     -43%   Đã bán 5k+
# 2     https://tka.tiki.vn/pixel/pixel?data=CvTdcPsLr...     -27%   Đã bán 5k+
# 3     https://tka.tiki.vn/pixel/pixel?data=Sv35L8T3D...     -20%    Đã bán 49
# 4     https://tka.tiki.vn/pixel/pixel?data=0jRGH1VYs...     -50%    Đã bán 33
# ...                                                 ...      ...          ...
# 1326  https://tiki.vn/noi-com-dien-xiaomi-thong-minh...     -45%    Đã bán 78
# 1327  https://tiki.vn/noi-dien-da-nang-phu-chong-din...      NaN  Đã bán 1.1k
# 1328  https://tiki.vn/may-xay-cafe-600n-p23829470.ht...      NaN   Đã bán 201
# 1329  https://tiki.vn/may-tron-bot-gourmetmaxx-5l-15...      NaN    Đã bán 25
# 1330  https://tiki.vn/noi-chien-khong-dau-magic-a-80...      NaN  Đã bán 1.1k
#
#           category
# 0     dodungnhabep
# 1     dodungnhabep
# 2     dodungnhabep
# 3     dodungnhabep
# 4     dodungnhabep
# ...            ...
# 1326  dodungnhabep
# 1327  dodungnhabep
# 1328  dodungnhabep
# 1329  dodungnhabep
# 1330  dodungnhabep
#
# [1331 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       1249000
# 1        239000
# 2        139000
# 3        869000
# 4        945000
#          ...
# 1326    1510000
# 1327     299000
# 1328     699000
# 1329    2399000
# 1330    1090000
# Name: price, Length: 1331, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       1300.0
# 1       5000.0
# 2       5000.0
# 3         49.0
# 4         33.0
#          ...
# 1326      78.0
# 1327    1100.0
# 1328     201.0
# 1329      25.0
# 1330    1100.0
# Name: sales, Length: 1331, dtype: float64

# %%
print(set(df_all["sales"]))
# Out:
# {1.0, 2.0, 3.0, 4100.0, 5.0, 6.0, 7.0, 8.0, 9.0, 4.0, 11.0, 10.0, 13.0, 14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0, 32.0, 33.0, 34.0, 35.0, 36.0, 37.0, 38.0, 39.0, 40.0, 41.0, 42.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 2100.0, 52.0, 54.0, 55.0, 56.0, 53.0, 58.0, 57.0, 60.0, 12.0, 59.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 61.0, 70.0, 71.0, 72.0, 73.0, 74.0, 75.0, 76.0, 69.0, 78.0, 79.0, 80.0, 81.0, 82.0, 83.0, 84.0, 85.0, 86.0, 87.0, 88.0, 89.0, 90.0, 92.0, 93.0, 94.0, 95.0, 96.0, 97.0, 98.0, 100.0, 101.0, 103.0, 4200.0, 105.0, 106.0, 109.0, 110.0, 111.0, 112.0, 114.0, 115.0, 116.0, 117.0, 118.0, 119.0, 120.0, 122.0, 124.0, 126.0, 128.0, 129.0, 132.0, 133.0, 134.0, 136.0, 137.0, 139.0, 141.0, 142.0, 144.0, 147.0, 149.0, 151.0, 2200.0, 154.0, 155.0, 158.0, 159.0, 160.0, 162.0, 164.0, 165.0, 166.0, 167.0, 168.0, 171.0, 175.0, 177.0, 179.0, 180.0, 183.0, 185.0, 188.0, 189.0, 192.0, 193.0, 194.0, 196.0, 199.0, 201.0, 202.0, 4300.0, 205.0, 206.0, 207.0, 211.0, 213.0, 215.0, 217.0, 219.0, 222.0, 223.0, 225.0, 229.0, 230.0, 233.0, 235.0, 237.0, 240.0, 244.0, 247.0, 248.0, 249.0, 250.0, 251.0, 252.0, 2300.0, 253.0, 256.0, 261.0, 265.0, 266.0, 274.0, 277.0, 278.0, 280.0, 281.0, 285.0, 288.0, 291.0, 295.0, 297.0, 298.0, 299.0, 303.0, 305.0, 306.0, 62.0, 317.0, 321.0, 328.0, 329.0, 336.0, 337.0, 344.0, 345.0, 352.0, 355.0, 356.0, 358.0, 362.0, 374.0, 378.0, 386.0, 388.0, 391.0, 398.0, 400.0, 402.0, 406.0, 411.0, 414.0, 420.0, 422.0, 423.0, 428.0, 439.0, 451.0, 458.0, 464.0, 468.0, 475.0, 477.0, 482.0, 492.0, 494.0, 497.0, 509.0, 510.0, 511.0, 523.0, 526.0, 536.0, 544.0, 549.0, 2600.0, 559.0, 568.0, 572.0, 577.0, 581.0, 595.0, 601.0, 602.0, 636.0, 643.0, 657.0, 669.0, 671.0, 692.0, 694.0, 695.0, 706.0, 722.0, 744.0, 746.0, 2800.0, 779.0, 792.0, 794.0, 796.0, 800.0, 805.0, 816.0, 835.0, 837.0, 841.0, 2900.0, 895.0, 899.0, 5000.0, 938.0, 940.0, 3000.0, 958.0, 963.0, 981.0, 988.0, 991.0, 1000.0, 1100.0, 1200.0, 3300.0, 1300.0, 3400.0, 1400.0, 1500.0, 3600.0, 1700.0, 3800.0, 1800.0, 3900.0, 1900.0, 2000.0}

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1.623700e+09
# 1       1.195000e+09
# 2       6.950000e+08
# 3       4.258100e+07
# 4       3.118500e+07
#             ...
# 1326    1.177800e+08
# 1327    3.289000e+08
# 1328    1.404990e+08
# 1329    5.997500e+07
# 1330    1.199000e+09
# Name: revenue, Length: 1331, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số đồ dùng nhà bếp: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số đồ dùng nhà bếp:  270470144122.0
# So mat hang da ban:  1331
# So san pham da ban:  364878.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1249000
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   239000
# 2     Ấm Siêu Tốc Inox SUNHOUSE HAPPY TIME HTD1055 (...   139000
# 3     Lò Nướng Đa Năng COMET CM6516 (18 Lít) - Hàng ...   869000
# 4     Nồi điện đa năng Locknlock Electric Multipot E...   945000
# ...                                                 ...      ...
# 1326  Nồi Cơm Điện Xiaomi Thông Minh Cao Tần 1,6L - ...  1510000
# 1327  Nồi điện đa năng phủ chống dính cao cấp - Nồi ...   299000
# 1328                                  Máy xay cafe 600N   699000
# 1329  Máy trộn bột GOURMETMAXX 5L 1500W - Thương hiệ...  2399000
# 1330  Nồi Chiên Không Dầu Magic A-802 (4.6 Lít) Đen ...  1090000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=7IYS52One...     -20%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=j56Zt1bJH...     -43%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=CvTdcPsLr...     -27%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=Sv35L8T3D...     -20%    49.0
# 4     https://tka.tiki.vn/pixel/pixel?data=0jRGH1VYs...     -50%    33.0
# ...                                                 ...      ...     ...
# 1326  https://tiki.vn/noi-com-dien-xiaomi-thong-minh...     -45%    78.0
# 1327  https://tiki.vn/noi-dien-da-nang-phu-chong-din...      NaN  1100.0
# 1328  https://tiki.vn/may-xay-cafe-600n-p23829470.ht...      NaN   201.0
# 1329  https://tiki.vn/may-tron-bot-gourmetmaxx-5l-15...      NaN    25.0
# 1330  https://tiki.vn/noi-chien-khong-dau-magic-a-80...      NaN  1100.0
#
#           category       revenue
# 0     dodungnhabep  1.623700e+09
# 1     dodungnhabep  1.195000e+09
# 2     dodungnhabep  6.950000e+08
# 3     dodungnhabep  4.258100e+07
# 4     dodungnhabep  3.118500e+07
# ...            ...           ...
# 1326  dodungnhabep  1.177800e+08
# 1327  dodungnhabep  3.289000e+08
# 1328  dodungnhabep  1.404990e+08
# 1329  dodungnhabep  5.997500e+07
# 1330  dodungnhabep  1.199000e+09
#
# [1331 rows x 7 columns]

# %%
df_all.to_csv("tk_dodungnhabep_all_ed.csv")
