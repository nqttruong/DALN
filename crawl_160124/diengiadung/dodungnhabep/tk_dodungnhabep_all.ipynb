# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\diengiadung\dodungnhabep"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dgd_ddnb.ipynb',
#  'tk_dgd_ddnb_npage.ipynb',
#  'tk_dodungnhabep.csv',
#  'tk_dodungnhabep_all.ipynb',
#  'tk_dodungnhabep_t10.csv',
#  'tk_dodungnhabep_t11.csv',
#  'tk_dodungnhabep_t12.csv',
#  'tk_dodungnhabep_t13.csv',
#  'tk_dodungnhabep_t14.csv',
#  'tk_dodungnhabep_t15.csv',
#  'tk_dodungnhabep_t16.csv',
#  'tk_dodungnhabep_t17.csv',
#  'tk_dodungnhabep_t18.csv',
#  'tk_dodungnhabep_t19.csv',
#  'tk_dodungnhabep_t2.csv',
#  'tk_dodungnhabep_t20.csv',
#  'tk_dodungnhabep_t21.csv',
#  'tk_dodungnhabep_t22.csv',
#  'tk_dodungnhabep_t23.csv',
#  'tk_dodungnhabep_t24.csv',
#  'tk_dodungnhabep_t25.csv',
#  'tk_dodungnhabep_t26.csv',
#  'tk_dodungnhabep_t27.csv',
#  'tk_dodungnhabep_t28.csv',
#  'tk_dodungnhabep_t29.csv',
#  'tk_dodungnhabep_t3.csv',
#  'tk_dodungnhabep_t30.csv',
#  'tk_dodungnhabep_t31.csv',
#  'tk_dodungnhabep_t32.csv',
#  'tk_dodungnhabep_t33.csv',
#  'tk_dodungnhabep_t34.csv',
#  'tk_dodungnhabep_t35.csv',
#  'tk_dodungnhabep_t36.csv',
#  'tk_dodungnhabep_t37.csv',
#  'tk_dodungnhabep_t38.csv',
#  'tk_dodungnhabep_t39.csv',
#  'tk_dodungnhabep_t4.csv',
#  'tk_dodungnhabep_t40.csv',
#  'tk_dodungnhabep_t41.csv',
#  'tk_dodungnhabep_t42.csv',
#  'tk_dodungnhabep_t43.csv',
#  'tk_dodungnhabep_t44.csv',
#  'tk_dodungnhabep_t45.csv',
#  'tk_dodungnhabep_t46.csv',
#  'tk_dodungnhabep_t47.csv',
#  'tk_dodungnhabep_t48.csv',
#  'tk_dodungnhabep_t49.csv',
#  'tk_dodungnhabep_t5.csv',
#  'tk_dodungnhabep_t50.csv',
#  'tk_dodungnhabep_t6.csv',
#  'tk_dodungnhabep_t7.csv',
#  'tk_dodungnhabep_t8.csv',
#  'tk_dodungnhabep_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dodungnhabep_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1.999.000₫
# 1   Nồi Lẩu Điện Sunhouse SHD4521 (3L) - Hàng chín...    451.000₫
# 2   Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...    239.000₫
# 3   Nồi chiên không dầu 9 lít Sunhouse SHD4036 - H...  1.930.000₫
# 4   Nồi Chiên Không Dầu Điện Tử Cảm Ứng 9L Sunhous...  2.220.000₫
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36  Nồi nấu chậm Panasonic NF-N31AWRA - Hàng Chính...  1.299.000₫
# 37  Nồi cơm điện tử Cuckoo 1.08L CR-0675F - Tùy ch...  1.690.000₫
# 38                                  Máy xay cafe 600N    699.000₫
# 39  Máy trộn bột GOURMETMAXX 5L 1500W - Thương hiệ...   2.399.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=myx7HoBXl...      1     -31%
# 1   https://tka.tiki.vn/pixel/pixel?data=jMvaE0B2Y...      2     -42%
# 2   https://tka.tiki.vn/pixel/pixel?data=CC7lEEv10...      3     -43%
# 3   https://tka.tiki.vn/pixel/pixel?data=uw4hnDq7o...      4     -32%
# 4   https://tka.tiki.vn/pixel/pixel?data=Nc3dTcAwC...      5     -30%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/noi-dien-da-nang-phu-chong-din...     36      NaN
# 36  https://tiki.vn/noi-nau-cham-panasonic-nf-n31a...     37      NaN
# 37  https://tiki.vn/noi-com-dien-tu-cuckoo-1-08l-c...     38      NaN
# 38  https://tiki.vn/may-xay-cafe-600n-p23829470.ht...     39      NaN
# 39  https://tiki.vn/may-tron-bot-gourmetmaxx-5l-15...     40      NaN
#
#           sales      category
# 0   Đã bán 2.3k  dodungnhabep
# 1    Đã bán 5k+  dodungnhabep
# 2    Đã bán 5k+  dodungnhabep
# 3      Đã bán 2  dodungnhabep
# 4      Đã bán 5  dodungnhabep
# ..          ...           ...
# 35          NaN  dodungnhabep
# 36    Đã bán 74  dodungnhabep
# 37   Đã bán 659  dodungnhabep
# 38   Đã bán 200  dodungnhabep
# 39          NaN  dodungnhabep
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1.999.000₫
# 1     Nồi Lẩu Điện Sunhouse SHD4521 (3L) - Hàng chín...    451.000₫
# 2     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...    239.000₫
# 3     Nồi chiên không dầu 9 lít Sunhouse SHD4036 - H...  1.930.000₫
# 4     Nồi Chiên Không Dầu Điện Tử Cảm Ứng 9L Sunhous...  2.220.000₫
# ...                                                 ...         ...
# 1322  Bếp Điện Từ Đôi Kangaroo KG498N (3100W) - Hàng...  2.210.000₫
# 1323  Lò Vi Sóng Tráng Men Samsung Dòng Vi Sóng MS23...  1.790.000₫
# 1324  Nồi nấu chậm Panasonic NF-N31AWRA - Hàng Chính...  1.299.000₫
# 1325  Nồi cơm điện tử Cuckoo 1.08L CR-0675F - Tùy ch...  1.690.000₫
# 1326                                  Máy xay cafe 600N    699.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=myx7HoBXl...     -31%  Đã bán 2.3k
# 1     https://tka.tiki.vn/pixel/pixel?data=jMvaE0B2Y...     -42%   Đã bán 5k+
# 2     https://tka.tiki.vn/pixel/pixel?data=CC7lEEv10...     -43%   Đã bán 5k+
# 3     https://tka.tiki.vn/pixel/pixel?data=uw4hnDq7o...     -32%     Đã bán 2
# 4     https://tka.tiki.vn/pixel/pixel?data=Nc3dTcAwC...     -30%     Đã bán 5
# ...                                                 ...      ...          ...
# 1322  https://tiki.vn/bep-dien-tu-doi-kangaroo-kg498...     -23%   Đã bán 577
# 1323  https://tiki.vn/lo-vi-song-trang-men-samsung-d...      NaN   Đã bán 224
# 1324  https://tiki.vn/noi-nau-cham-panasonic-nf-n31a...      NaN    Đã bán 74
# 1325  https://tiki.vn/noi-com-dien-tu-cuckoo-1-08l-c...      NaN   Đã bán 659
# 1326  https://tiki.vn/may-xay-cafe-600n-p23829470.ht...      NaN   Đã bán 200
#
#           category
# 0     dodungnhabep
# 1     dodungnhabep
# 2     dodungnhabep
# 3     dodungnhabep
# 4     dodungnhabep
# ...            ...
# 1322  dodungnhabep
# 1323  dodungnhabep
# 1324  dodungnhabep
# 1325  dodungnhabep
# 1326  dodungnhabep
#
# [1327 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       1999000
# 1        451000
# 2        239000
# 3       1930000
# 4       2220000
#          ...
# 1322    2210000
# 1323    1790000
# 1324    1299000
# 1325    1690000
# 1326     699000
# Name: price, Length: 1327, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       2300.0
# 1       5000.0
# 2       5000.0
# 3          2.0
# 4          5.0
#          ...
# 1322     577.0
# 1323     224.0
# 1324      74.0
# 1325     659.0
# 1326     200.0
# Name: sales, Length: 1327, dtype: float64

# %%
print(set(df_all["sales"]))
# Out:
# {1.0, 2.0, 3.0, 4100.0, 5.0, 6.0, 7.0, 4.0, 9.0, 8.0, 11.0, 10.0, 13.0, 14.0, 15.0, 12.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0, 32.0, 33.0, 34.0, 35.0, 36.0, 37.0, 38.0, 39.0, 40.0, 41.0, 42.0, 43.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 2100.0, 53.0, 54.0, 55.0, 52.0, 57.0, 56.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 69.0, 70.0, 71.0, 72.0, 73.0, 74.0, 75.0, 76.0, 77.0, 79.0, 80.0, 16.0, 82.0, 83.0, 81.0, 84.0, 86.0, 87.0, 88.0, 89.0, 90.0, 91.0, 92.0, 93.0, 94.0, 95.0, 96.0, 97.0, 99.0, 100.0, 101.0, 102.0, 103.0, 4200.0, 104.0, 105.0, 107.0, 108.0, 106.0, 110.0, 111.0, 112.0, 113.0, 114.0, 115.0, 116.0, 118.0, 119.0, 122.0, 124.0, 126.0, 127.0, 128.0, 129.0, 131.0, 134.0, 135.0, 136.0, 137.0, 139.0, 141.0, 142.0, 143.0, 144.0, 147.0, 149.0, 150.0, 151.0, 2200.0, 154.0, 155.0, 158.0, 159.0, 163.0, 164.0, 165.0, 167.0, 168.0, 170.0, 171.0, 172.0, 175.0, 176.0, 177.0, 179.0, 180.0, 182.0, 184.0, 185.0, 188.0, 189.0, 193.0, 194.0, 195.0, 196.0, 199.0, 200.0, 201.0, 4300.0, 206.0, 207.0, 210.0, 211.0, 213.0, 215.0, 217.0, 219.0, 222.0, 223.0, 224.0, 225.0, 226.0, 227.0, 230.0, 232.0, 235.0, 236.0, 237.0, 240.0, 244.0, 246.0, 247.0, 248.0, 249.0, 250.0, 251.0, 2300.0, 252.0, 253.0, 256.0, 258.0, 261.0, 270.0, 272.0, 274.0, 276.0, 278.0, 279.0, 281.0, 285.0, 288.0, 291.0, 292.0, 58.0, 297.0, 299.0, 305.0, 306.0, 321.0, 327.0, 336.0, 344.0, 346.0, 351.0, 2400.0, 352.0, 354.0, 356.0, 370.0, 373.0, 378.0, 379.0, 386.0, 388.0, 391.0, 401.0, 406.0, 411.0, 413.0, 414.0, 420.0, 421.0, 422.0, 423.0, 439.0, 443.0, 451.0, 468.0, 472.0, 475.0, 489.0, 492.0, 510.0, 515.0, 523.0, 536.0, 541.0, 544.0, 549.0, 2600.0, 554.0, 559.0, 564.0, 567.0, 572.0, 577.0, 594.0, 595.0, 632.0, 642.0, 659.0, 667.0, 669.0, 692.0, 693.0, 695.0, 714.0, 720.0, 730.0, 746.0, 2800.0, 792.0, 799.0, 805.0, 814.0, 835.0, 836.0, 841.0, 2900.0, 896.0, 899.0, 5000.0, 921.0, 936.0, 3000.0, 963.0, 979.0, 988.0, 990.0, 999.0, 1000.0, 1100.0, 1200.0, 3300.0, 1300.0, 3400.0, 1400.0, 1500.0, 3600.0, 1700.0, 3800.0, 1800.0, 3900.0, 1900.0, 2000.0}

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       4.597700e+09
# 1       2.255000e+09
# 2       1.195000e+09
# 3       3.860000e+06
# 4       1.110000e+07
#             ...
# 1322    1.275170e+09
# 1323    4.009600e+08
# 1324    9.612600e+07
# 1325    1.113710e+09
# 1326    1.398000e+08
# Name: revenue, Length: 1327, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số đồ dùng nhà bếp: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số đồ dùng nhà bếp:  276968311811.0
# So mat hang da ban:  1327
# So san pham da ban:  364463.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1999000
# 1     Nồi Lẩu Điện Sunhouse SHD4521 (3L) - Hàng chín...   451000
# 2     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   239000
# 3     Nồi chiên không dầu 9 lít Sunhouse SHD4036 - H...  1930000
# 4     Nồi Chiên Không Dầu Điện Tử Cảm Ứng 9L Sunhous...  2220000
# ...                                                 ...      ...
# 1322  Bếp Điện Từ Đôi Kangaroo KG498N (3100W) - Hàng...  2210000
# 1323  Lò Vi Sóng Tráng Men Samsung Dòng Vi Sóng MS23...  1790000
# 1324  Nồi nấu chậm Panasonic NF-N31AWRA - Hàng Chính...  1299000
# 1325  Nồi cơm điện tử Cuckoo 1.08L CR-0675F - Tùy ch...  1690000
# 1326                                  Máy xay cafe 600N   699000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=myx7HoBXl...     -31%  2300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=jMvaE0B2Y...     -42%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=CC7lEEv10...     -43%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=uw4hnDq7o...     -32%     2.0
# 4     https://tka.tiki.vn/pixel/pixel?data=Nc3dTcAwC...     -30%     5.0
# ...                                                 ...      ...     ...
# 1322  https://tiki.vn/bep-dien-tu-doi-kangaroo-kg498...     -23%   577.0
# 1323  https://tiki.vn/lo-vi-song-trang-men-samsung-d...      NaN   224.0
# 1324  https://tiki.vn/noi-nau-cham-panasonic-nf-n31a...      NaN    74.0
# 1325  https://tiki.vn/noi-com-dien-tu-cuckoo-1-08l-c...      NaN   659.0
# 1326  https://tiki.vn/may-xay-cafe-600n-p23829470.ht...      NaN   200.0
#
#           category       revenue
# 0     dodungnhabep  4.597700e+09
# 1     dodungnhabep  2.255000e+09
# 2     dodungnhabep  1.195000e+09
# 3     dodungnhabep  3.860000e+06
# 4     dodungnhabep  1.110000e+07
# ...            ...           ...
# 1322  dodungnhabep  1.275170e+09
# 1323  dodungnhabep  4.009600e+08
# 1324  dodungnhabep  9.612600e+07
# 1325  dodungnhabep  1.113710e+09
# 1326  dodungnhabep  1.398000e+08
#
# [1327 rows x 7 columns]

# %%
df_all.to_csv("tk_dodungnhabep_all_ed.csv")
