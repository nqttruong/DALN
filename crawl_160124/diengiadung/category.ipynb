# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\diengiadung"
os.listdir(path)
# Out:
# ['Brand',
#  'category.ipynb',
#  'dodungnhabep',
#  'thietbigiadinh',
#  'tk_dodungnhabep_all_ed.csv',
#  'tk_thietbigiadinh_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#       Unnamed: 0                                              title    price  \
# 0              0  Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1999000
# 1              1  Nồi Lẩu Điện Sunhouse SHD4521 (3L) - Hàng chín...   451000
# 2              2  Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   239000
# 3              3  Nồi chiên không dầu 9 lít Sunhouse SHD4036 - H...  1930000
# 4              4  Nồi Chiên Không Dầu Điện Tử Cảm Ứng 9L Sunhous...  2220000
# ...          ...                                                ...      ...
# 1281        1281     Quạt Bàn Lifan B-106 - Trắng - Hàng chính hãng   180000
# 1282        1282  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...   240000
# 1283        1283  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    69000
# 1284        1284  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   603000
# 1285        1285  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1600000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=myx7HoBXl...     -31%  2300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=jMvaE0B2Y...     -42%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=CC7lEEv10...     -43%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=uw4hnDq7o...     -32%     2.0
# 4     https://tka.tiki.vn/pixel/pixel?data=Nc3dTcAwC...     -30%     5.0
# ...                                                 ...      ...     ...
# 1281  https://tiki.vn/quat-ban-lifan-b-106-trang-han...      NaN    16.0
# 1282  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...      NaN     3.0
# 1283  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1284  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   394.0
# 1285  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...      NaN  1600.0
#
#             category       revenue
# 0       dodungnhabep  4.597700e+09
# 1       dodungnhabep  2.255000e+09
# 2       dodungnhabep  1.195000e+09
# 3       dodungnhabep  3.860000e+06
# 4       dodungnhabep  1.110000e+07
# ...              ...           ...
# 1281  thietbigiadinh  2.880000e+06
# 1282  thietbigiadinh  7.200000e+05
# 1283  thietbigiadinh  1.725000e+06
# 1284  thietbigiadinh  2.375820e+08
# 1285  thietbigiadinh  2.560000e+09
#
# [2613 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "diengiadung")

# %%
df
# Out:
#                                                   title    price  \
# 0     Nồi cơm điện tử Toshiba RC-18NTFV(W) (1.8 Lít)...  1999000
# 1     Nồi Lẩu Điện Sunhouse SHD4521 (3L) - Hàng chín...   451000
# 2     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   239000
# 3     Nồi chiên không dầu 9 lít Sunhouse SHD4036 - H...  1930000
# 4     Nồi Chiên Không Dầu Điện Tử Cảm Ứng 9L Sunhous...  2220000
# ...                                                 ...      ...
# 1281     Quạt Bàn Lifan B-106 - Trắng - Hàng chính hãng   180000
# 1282  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...   240000
# 1283  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    69000
# 1284  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   603000
# 1285  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1600000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=myx7HoBXl...     -31%  2300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=jMvaE0B2Y...     -42%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=CC7lEEv10...     -43%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=uw4hnDq7o...     -32%     2.0
# 4     https://tka.tiki.vn/pixel/pixel?data=Nc3dTcAwC...     -30%     5.0
# ...                                                 ...      ...     ...
# 1281  https://tiki.vn/quat-ban-lifan-b-106-trang-han...      NaN    16.0
# 1282  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...      NaN     3.0
# 1283  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1284  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   394.0
# 1285  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...      NaN  1600.0
#
#            item_list     category       revenue
# 0       dodungnhabep  diengiadung  4.597700e+09
# 1       dodungnhabep  diengiadung  2.255000e+09
# 2       dodungnhabep  diengiadung  1.195000e+09
# 3       dodungnhabep  diengiadung  3.860000e+06
# 4       dodungnhabep  diengiadung  1.110000e+07
# ...              ...          ...           ...
# 1281  thietbigiadinh  diengiadung  2.880000e+06
# 1282  thietbigiadinh  diengiadung  7.200000e+05
# 1283  thietbigiadinh  diengiadung  1.725000e+06
# 1284  thietbigiadinh  diengiadung  2.375820e+08
# 1285  thietbigiadinh  diengiadung  2.560000e+09
#
# [2613 rows x 8 columns]

# %%
df.to_csv('tk_diengiadung_all_ed.csv', index=False, encoding='utf-8')
