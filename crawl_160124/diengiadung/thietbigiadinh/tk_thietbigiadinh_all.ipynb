# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\diengiadung\thietbigiadinh"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dgd_tbgd.ipynb',
#  'tk_dgd_tbgd_npage.ipynb',
#  'tk_thietbigiadinh.csv',
#  'tk_thietbigiadinh_all.ipynb',
#  'tk_thietbigiadinh_t10.csv',
#  'tk_thietbigiadinh_t11.csv',
#  'tk_thietbigiadinh_t12.csv',
#  'tk_thietbigiadinh_t13.csv',
#  'tk_thietbigiadinh_t14.csv',
#  'tk_thietbigiadinh_t15.csv',
#  'tk_thietbigiadinh_t16.csv',
#  'tk_thietbigiadinh_t17.csv',
#  'tk_thietbigiadinh_t18.csv',
#  'tk_thietbigiadinh_t19.csv',
#  'tk_thietbigiadinh_t2.csv',
#  'tk_thietbigiadinh_t20.csv',
#  'tk_thietbigiadinh_t21.csv',
#  'tk_thietbigiadinh_t22.csv',
#  'tk_thietbigiadinh_t23.csv',
#  'tk_thietbigiadinh_t24.csv',
#  'tk_thietbigiadinh_t25.csv',
#  'tk_thietbigiadinh_t26.csv',
#  'tk_thietbigiadinh_t27.csv',
#  'tk_thietbigiadinh_t28.csv',
#  'tk_thietbigiadinh_t29.csv',
#  'tk_thietbigiadinh_t3.csv',
#  'tk_thietbigiadinh_t30.csv',
#  'tk_thietbigiadinh_t31.csv',
#  'tk_thietbigiadinh_t32.csv',
#  'tk_thietbigiadinh_t33.csv',
#  'tk_thietbigiadinh_t34.csv',
#  'tk_thietbigiadinh_t35.csv',
#  'tk_thietbigiadinh_t36.csv',
#  'tk_thietbigiadinh_t37.csv',
#  'tk_thietbigiadinh_t38.csv',
#  'tk_thietbigiadinh_t39.csv',
#  'tk_thietbigiadinh_t4.csv',
#  'tk_thietbigiadinh_t40.csv',
#  'tk_thietbigiadinh_t41.csv',
#  'tk_thietbigiadinh_t42.csv',
#  'tk_thietbigiadinh_t43.csv',
#  'tk_thietbigiadinh_t44.csv',
#  'tk_thietbigiadinh_t45.csv',
#  'tk_thietbigiadinh_t46.csv',
#  'tk_thietbigiadinh_t47.csv',
#  'tk_thietbigiadinh_t48.csv',
#  'tk_thietbigiadinh_t49.csv',
#  'tk_thietbigiadinh_t5.csv',
#  'tk_thietbigiadinh_t50.csv',
#  'tk_thietbigiadinh_t6.csv',
#  'tk_thietbigiadinh_t7.csv',
#  'tk_thietbigiadinh_t8.csv',
#  'tk_thietbigiadinh_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_thietbigiadinh_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0     Máy sấy tóc Philips BHC010/10 - Hàng Chính Hãng    289.000₫
# 1   Máy Lọc Nước RO Hydrogen Ion Kiềm Kangaroo KG1...  3.199.000₫
# 2   Máy Lọc Nước RO Kangaroo VTU KG108A 8 Lõi - Hà...  3.379.000₫
# 3   Máy Lọc Nước RO Không Vỏ Tủ Kangaroo KG109A 9 ...  4.970.000₫
# 4   Máy Sấy Tóc LocknLock - Đen ENA146BLK 2000-230...    530.000₫
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...     69.000₫
# 37  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...    603.000₫
# 38  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1.600.000₫
# 39  Lõi lọc Karofi số 4 (Màng lọc RO) - Hàng chính...     300.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=dD7TAc7z1...      1     -27%
# 1   https://tka.tiki.vn/pixel/pixel?data=3rpjwFmT9...      2     -75%
# 2   https://tka.tiki.vn/pixel/pixel?data=HmX_znbav...      3     -55%
# 3   https://tka.tiki.vn/pixel/pixel?data=23J5xSsxO...      4     -31%
# 4   https://tka.tiki.vn/pixel/pixel?data=abLJmq9MK...      5     -47%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...     36      NaN
# 36  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...     37      NaN
# 37  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...     38      NaN
# 38  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...     39      NaN
# 39  https://tiki.vn/loi-loc-karofi-so-4-mang-loc-r...     40      NaN
#
#           sales        category
# 0   Đã bán 1.3k  thietbigiadinh
# 1     Đã bán 41  thietbigiadinh
# 2    Đã bán 948  thietbigiadinh
# 3     Đã bán 92  thietbigiadinh
# 4   Đã bán 3.7k  thietbigiadinh
# ..          ...             ...
# 35          NaN  thietbigiadinh
# 36    Đã bán 25  thietbigiadinh
# 37   Đã bán 394  thietbigiadinh
# 38  Đã bán 1.6k  thietbigiadinh
# 39          NaN  thietbigiadinh
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0       Máy sấy tóc Philips BHC010/10 - Hàng Chính Hãng    289.000₫
# 1     Máy Lọc Nước RO Hydrogen Ion Kiềm Kangaroo KG1...  3.199.000₫
# 2     Máy Lọc Nước RO Kangaroo VTU KG108A 8 Lõi - Hà...  3.379.000₫
# 3     Máy Lọc Nước RO Không Vỏ Tủ Kangaroo KG109A 9 ...  4.970.000₫
# 4     Máy Sấy Tóc LocknLock - Đen ENA146BLK 2000-230...    530.000₫
# ...                                                 ...         ...
# 1281     Quạt Bàn Lifan B-106 - Trắng - Hàng chính hãng    180.000₫
# 1282  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...     240.000
# 1283  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...     69.000₫
# 1284  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...    603.000₫
# 1285  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1.600.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=dD7TAc7z1...     -27%  Đã bán 1.3k
# 1     https://tka.tiki.vn/pixel/pixel?data=3rpjwFmT9...     -75%    Đã bán 41
# 2     https://tka.tiki.vn/pixel/pixel?data=HmX_znbav...     -55%   Đã bán 948
# 3     https://tka.tiki.vn/pixel/pixel?data=23J5xSsxO...     -31%    Đã bán 92
# 4     https://tka.tiki.vn/pixel/pixel?data=abLJmq9MK...     -47%  Đã bán 3.7k
# ...                                                 ...      ...          ...
# 1281  https://tiki.vn/quat-ban-lifan-b-106-trang-han...      NaN    Đã bán 16
# 1282  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...      NaN     Đã bán 3
# 1283  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    Đã bán 25
# 1284  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   Đã bán 394
# 1285  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...      NaN  Đã bán 1.6k
#
#             category
# 0     thietbigiadinh
# 1     thietbigiadinh
# 2     thietbigiadinh
# 3     thietbigiadinh
# 4     thietbigiadinh
# ...              ...
# 1281  thietbigiadinh
# 1282  thietbigiadinh
# 1283  thietbigiadinh
# 1284  thietbigiadinh
# 1285  thietbigiadinh
#
# [1286 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        289000
# 1       3199000
# 2       3379000
# 3       4970000
# 4        530000
#          ...
# 1281     180000
# 1282     240000
# 1283      69000
# 1284     603000
# 1285    1600000
# Name: price, Length: 1286, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       1300.0
# 1         41.0
# 2        948.0
# 3         92.0
# 4       3700.0
#          ...
# 1281      16.0
# 1282       3.0
# 1283      25.0
# 1284     394.0
# 1285    1600.0
# Name: sales, Length: 1286, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       3.757000e+08
# 1       1.311590e+08
# 2       3.203292e+09
# 3       4.572400e+08
# 4       1.961000e+09
#             ...
# 1281    2.880000e+06
# 1282    7.200000e+05
# 1283    1.725000e+06
# 1284    2.375820e+08
# 1285    2.560000e+09
# Name: revenue, Length: 1286, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số thiet bi gia dinh: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số thiet bi gia dinh:  140592474385.0
# So mat hang da ban:  1286
# So san pham da ban:  215565.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0       Máy sấy tóc Philips BHC010/10 - Hàng Chính Hãng   289000
# 1     Máy Lọc Nước RO Hydrogen Ion Kiềm Kangaroo KG1...  3199000
# 2     Máy Lọc Nước RO Kangaroo VTU KG108A 8 Lõi - Hà...  3379000
# 3     Máy Lọc Nước RO Không Vỏ Tủ Kangaroo KG109A 9 ...  4970000
# 4     Máy Sấy Tóc LocknLock - Đen ENA146BLK 2000-230...   530000
# ...                                                 ...      ...
# 1281     Quạt Bàn Lifan B-106 - Trắng - Hàng chính hãng   180000
# 1282  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...   240000
# 1283  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    69000
# 1284  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   603000
# 1285  Cây Nước Nóng Lạnh Sunhouse SHD9602 - Hàng chí...  1600000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=dD7TAc7z1...     -27%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=3rpjwFmT9...     -75%    41.0
# 2     https://tka.tiki.vn/pixel/pixel?data=HmX_znbav...     -55%   948.0
# 3     https://tka.tiki.vn/pixel/pixel?data=23J5xSsxO...     -31%    92.0
# 4     https://tka.tiki.vn/pixel/pixel?data=abLJmq9MK...     -47%  3700.0
# ...                                                 ...      ...     ...
# 1281  https://tiki.vn/quat-ban-lifan-b-106-trang-han...      NaN    16.0
# 1282  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...      NaN     3.0
# 1283  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1284  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   394.0
# 1285  https://tiki.vn/cay-nuoc-nong-lanh-sunhouse-sh...      NaN  1600.0
#
#             category       revenue
# 0     thietbigiadinh  3.757000e+08
# 1     thietbigiadinh  1.311590e+08
# 2     thietbigiadinh  3.203292e+09
# 3     thietbigiadinh  4.572400e+08
# 4     thietbigiadinh  1.961000e+09
# ...              ...           ...
# 1281  thietbigiadinh  2.880000e+06
# 1282  thietbigiadinh  7.200000e+05
# 1283  thietbigiadinh  1.725000e+06
# 1284  thietbigiadinh  2.375820e+08
# 1285  thietbigiadinh  2.560000e+09
#
# [1286 rows x 7 columns]

# %%
df_all.to_csv("tk_thietbigiadinh_all_ed.csv")
