# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\dochoi_mevabe\dinhduongchobe"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dinhduongchobe.csv',
#  'tk_dinhduongchobe_all.ipynb',
#  'tk_dinhduongchobe_t10.csv',
#  'tk_dinhduongchobe_t11.csv',
#  'tk_dinhduongchobe_t12.csv',
#  'tk_dinhduongchobe_t13.csv',
#  'tk_dinhduongchobe_t14.csv',
#  'tk_dinhduongchobe_t15.csv',
#  'tk_dinhduongchobe_t16.csv',
#  'tk_dinhduongchobe_t17.csv',
#  'tk_dinhduongchobe_t18.csv',
#  'tk_dinhduongchobe_t19.csv',
#  'tk_dinhduongchobe_t2.csv',
#  'tk_dinhduongchobe_t20.csv',
#  'tk_dinhduongchobe_t21.csv',
#  'tk_dinhduongchobe_t22.csv',
#  'tk_dinhduongchobe_t23.csv',
#  'tk_dinhduongchobe_t24.csv',
#  'tk_dinhduongchobe_t25.csv',
#  'tk_dinhduongchobe_t26.csv',
#  'tk_dinhduongchobe_t27.csv',
#  'tk_dinhduongchobe_t28.csv',
#  'tk_dinhduongchobe_t29.csv',
#  'tk_dinhduongchobe_t3.csv',
#  'tk_dinhduongchobe_t30.csv',
#  'tk_dinhduongchobe_t31.csv',
#  'tk_dinhduongchobe_t32.csv',
#  'tk_dinhduongchobe_t33.csv',
#  'tk_dinhduongchobe_t34.csv',
#  'tk_dinhduongchobe_t35.csv',
#  'tk_dinhduongchobe_t36.csv',
#  'tk_dinhduongchobe_t37.csv',
#  'tk_dinhduongchobe_t38.csv',
#  'tk_dinhduongchobe_t39.csv',
#  'tk_dinhduongchobe_t4.csv',
#  'tk_dinhduongchobe_t40.csv',
#  'tk_dinhduongchobe_t41.csv',
#  'tk_dinhduongchobe_t42.csv',
#  'tk_dinhduongchobe_t43.csv',
#  'tk_dinhduongchobe_t44.csv',
#  'tk_dinhduongchobe_t45.csv',
#  'tk_dinhduongchobe_t46.csv',
#  'tk_dinhduongchobe_t47.csv',
#  'tk_dinhduongchobe_t48.csv',
#  'tk_dinhduongchobe_t49.csv',
#  'tk_dinhduongchobe_t5.csv',
#  'tk_dinhduongchobe_t50.csv',
#  'tk_dinhduongchobe_t6.csv',
#  'tk_dinhduongchobe_t7.csv',
#  'tk_dinhduongchobe_t8.csv',
#  'tk_dinhduongchobe_t9.csv',
#  'tk_mvb_dinhduongchobe.ipynb',
#  'tk_mvb_dinhduongchobe_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dinhduongchobe_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   [Combo 3 lon còn 1tr450] Sữa Bột Nutifood Grow...    584.000₫
# 1   Bộ 2 lon Sữa bột Nestlé NAN OPTIPRO PLUS 4 150...  1.449.000₫
# 2   Thùng sữa bột pha sẵn Thực phẩm bổ sung Nestlé...    289.000₫
# 3   Sữa bột Nestlé NAN OPTIPRO PLUS 4 850g/lon với...    435.000₫
# 4   Sữa bột Nestlé NAN OPTIPRO PLUS 4 1500g/lon vớ...    725.000₫
# ..                                                ...         ...
# 35  [Made in Japan] Sữa Morinaga Số 2 - Chilmil (3...    194.000₫
# 36       Cháo tươi Sài Gòn Food yến mạch hạt sen 240g     19.500₫
# 37  (Hàng nguyên tem) Sữa bột Colos DHA+ số 0+/ số...    399.000₫
# 38  Sữa bột OPTIMUM GOLD Step 4 - Hộp thiếc 1,5kg ...    575.000₫
# 39  Bánh ăn dặm cho bé MBEFOOD Bánh gạo Nhật Hokka...     42.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=jepgSdVhr...      1     -34%
# 1   https://tka.tiki.vn/pixel/pixel?data=UVZrfLBt7...      2     -10%
# 2   https://tka.tiki.vn/pixel/pixel?data=MO8noEMSI...      3     -37%
# 3   https://tka.tiki.vn/pixel/pixel?data=WnS_B2fik...      4     -12%
# 4   https://tka.tiki.vn/pixel/pixel?data=XK3onA7sR...      5     -11%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/made-in-japan-sua-morinaga-so-...     36      NaN
# 36  https://tiki.vn/chao-tuoi-sai-gon-food-yen-mac...     37      NaN
# 37  https://tiki.vn/hang-nguyen-tem-sua-bot-colos-...     38      NaN
# 38  https://tiki.vn/sua-bot-optimum-gold-step-4-ho...     39      NaN
# 39  https://tiki.vn/banh-an-dam-cho-be-banh-gao-nh...     40      NaN
#
#           sales        category
# 0   Đã bán 1.8k  dinhduongchobe
# 1    Đã bán 176  dinhduongchobe
# 2     Đã bán 77  dinhduongchobe
# 3    Đã bán 614  dinhduongchobe
# 4    Đã bán 402  dinhduongchobe
# ..          ...             ...
# 35   Đã bán 123  dinhduongchobe
# 36    Đã bán 82  dinhduongchobe
# 37     Đã bán 5  dinhduongchobe
# 38    Đã bán 47  dinhduongchobe
# 39    Đã bán 12  dinhduongchobe
#
# [2026 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     [Combo 3 lon còn 1tr450] Sữa Bột Nutifood Grow...    584.000₫
# 1     Bộ 2 lon Sữa bột Nestlé NAN OPTIPRO PLUS 4 150...  1.449.000₫
# 2     Thùng sữa bột pha sẵn Thực phẩm bổ sung Nestlé...    289.000₫
# 3     Sữa bột Nestlé NAN OPTIPRO PLUS 4 850g/lon với...    435.000₫
# 4     Sữa bột Nestlé NAN OPTIPRO PLUS 4 1500g/lon vớ...    725.000₫
# ...                                                 ...         ...
# 1475  [Made in Japan] Sữa Morinaga Số 2 - Chilmil (3...    194.000₫
# 1476       Cháo tươi Sài Gòn Food yến mạch hạt sen 240g     19.500₫
# 1477  (Hàng nguyên tem) Sữa bột Colos DHA+ số 0+/ số...    399.000₫
# 1478  Sữa bột OPTIMUM GOLD Step 4 - Hộp thiếc 1,5kg ...    575.000₫
# 1479  Bánh ăn dặm cho bé MBEFOOD Bánh gạo Nhật Hokka...     42.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=jepgSdVhr...     -34%  Đã bán 1.8k
# 1     https://tka.tiki.vn/pixel/pixel?data=UVZrfLBt7...     -10%   Đã bán 176
# 2     https://tka.tiki.vn/pixel/pixel?data=MO8noEMSI...     -37%    Đã bán 77
# 3     https://tka.tiki.vn/pixel/pixel?data=WnS_B2fik...     -12%   Đã bán 614
# 4     https://tka.tiki.vn/pixel/pixel?data=XK3onA7sR...     -11%   Đã bán 402
# ...                                                 ...      ...          ...
# 1475  https://tiki.vn/made-in-japan-sua-morinaga-so-...      NaN   Đã bán 123
# 1476  https://tiki.vn/chao-tuoi-sai-gon-food-yen-mac...      NaN    Đã bán 82
# 1477  https://tiki.vn/hang-nguyen-tem-sua-bot-colos-...      NaN     Đã bán 5
# 1478  https://tiki.vn/sua-bot-optimum-gold-step-4-ho...      NaN    Đã bán 47
# 1479  https://tiki.vn/banh-an-dam-cho-be-banh-gao-nh...      NaN    Đã bán 12
#
#             category
# 0     dinhduongchobe
# 1     dinhduongchobe
# 2     dinhduongchobe
# 3     dinhduongchobe
# 4     dinhduongchobe
# ...              ...
# 1475  dinhduongchobe
# 1476  dinhduongchobe
# 1477  dinhduongchobe
# 1478  dinhduongchobe
# 1479  dinhduongchobe
#
# [1480 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        584000
# 1       1449000
# 2        289000
# 3        435000
# 4        725000
#          ...
# 1475     194000
# 1476      19500
# 1477     399000
# 1478     575000
# 1479      42000
# Name: price, Length: 1480, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       1800.0
# 1        176.0
# 2         77.0
# 3        614.0
# 4        402.0
#          ...
# 1475     123.0
# 1476      82.0
# 1477       5.0
# 1478      47.0
# 1479      12.0
# Name: sales, Length: 1480, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1.051200e+09
# 1       2.550240e+08
# 2       2.225300e+07
# 3       2.670900e+08
# 4       2.914500e+08
#             ...
# 1475    2.386200e+07
# 1476    1.599000e+06
# 1477    1.995000e+06
# 1478    2.702500e+07
# 1479    5.040000e+05
# Name: revenue, Length: 1480, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dinhduongchobe: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dinhduongchobe:  180518699962.0
# So mat hang da ban:  1480
# So san pham da ban:  357044.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     [Combo 3 lon còn 1tr450] Sữa Bột Nutifood Grow...   584000
# 1     Bộ 2 lon Sữa bột Nestlé NAN OPTIPRO PLUS 4 150...  1449000
# 2     Thùng sữa bột pha sẵn Thực phẩm bổ sung Nestlé...   289000
# 3     Sữa bột Nestlé NAN OPTIPRO PLUS 4 850g/lon với...   435000
# 4     Sữa bột Nestlé NAN OPTIPRO PLUS 4 1500g/lon vớ...   725000
# ...                                                 ...      ...
# 1475  [Made in Japan] Sữa Morinaga Số 2 - Chilmil (3...   194000
# 1476       Cháo tươi Sài Gòn Food yến mạch hạt sen 240g    19500
# 1477  (Hàng nguyên tem) Sữa bột Colos DHA+ số 0+/ số...   399000
# 1478  Sữa bột OPTIMUM GOLD Step 4 - Hộp thiếc 1,5kg ...   575000
# 1479  Bánh ăn dặm cho bé MBEFOOD Bánh gạo Nhật Hokka...    42000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=jepgSdVhr...     -34%  1800.0
# 1     https://tka.tiki.vn/pixel/pixel?data=UVZrfLBt7...     -10%   176.0
# 2     https://tka.tiki.vn/pixel/pixel?data=MO8noEMSI...     -37%    77.0
# 3     https://tka.tiki.vn/pixel/pixel?data=WnS_B2fik...     -12%   614.0
# 4     https://tka.tiki.vn/pixel/pixel?data=XK3onA7sR...     -11%   402.0
# ...                                                 ...      ...     ...
# 1475  https://tiki.vn/made-in-japan-sua-morinaga-so-...      NaN   123.0
# 1476  https://tiki.vn/chao-tuoi-sai-gon-food-yen-mac...      NaN    82.0
# 1477  https://tiki.vn/hang-nguyen-tem-sua-bot-colos-...      NaN     5.0
# 1478  https://tiki.vn/sua-bot-optimum-gold-step-4-ho...      NaN    47.0
# 1479  https://tiki.vn/banh-an-dam-cho-be-banh-gao-nh...      NaN    12.0
#
#             category       revenue
# 0     dinhduongchobe  1.051200e+09
# 1     dinhduongchobe  2.550240e+08
# 2     dinhduongchobe  2.225300e+07
# 3     dinhduongchobe  2.670900e+08
# 4     dinhduongchobe  2.914500e+08
# ...              ...           ...
# 1475  dinhduongchobe  2.386200e+07
# 1476  dinhduongchobe  1.599000e+06
# 1477  dinhduongchobe  1.995000e+06
# 1478  dinhduongchobe  2.702500e+07
# 1479  dinhduongchobe  5.040000e+05
#
# [1480 rows x 7 columns]

# %%
df_all.to_csv("tk_dinhduongchobe_all_ed.csv")
