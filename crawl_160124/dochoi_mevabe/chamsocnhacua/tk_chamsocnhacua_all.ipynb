# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\dochoi_mevabe\chamsocme"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_chamsocme.csv',
#  'tk_chamsocme_all.csv',
#  'tk_chamsocme_all.ipynb',
#  'tk_chamsocme_t10.csv',
#  'tk_chamsocme_t11.csv',
#  'tk_chamsocme_t12.csv',
#  'tk_chamsocme_t13.csv',
#  'tk_chamsocme_t14.csv',
#  'tk_chamsocme_t15.csv',
#  'tk_chamsocme_t16.csv',
#  'tk_chamsocme_t17.csv',
#  'tk_chamsocme_t18.csv',
#  'tk_chamsocme_t19.csv',
#  'tk_chamsocme_t2.csv',
#  'tk_chamsocme_t20.csv',
#  'tk_chamsocme_t21.csv',
#  'tk_chamsocme_t22.csv',
#  'tk_chamsocme_t23.csv',
#  'tk_chamsocme_t24.csv',
#  'tk_chamsocme_t25.csv',
#  'tk_chamsocme_t26.csv',
#  'tk_chamsocme_t27.csv',
#  'tk_chamsocme_t28.csv',
#  'tk_chamsocme_t29.csv',
#  'tk_chamsocme_t3.csv',
#  'tk_chamsocme_t30.csv',
#  'tk_chamsocme_t31.csv',
#  'tk_chamsocme_t32.csv',
#  'tk_chamsocme_t33.csv',
#  'tk_chamsocme_t34.csv',
#  'tk_chamsocme_t35.csv',
#  'tk_chamsocme_t36.csv',
#  'tk_chamsocme_t37.csv',
#  'tk_chamsocme_t38.csv',
#  'tk_chamsocme_t39.csv',
#  'tk_chamsocme_t4.csv',
#  'tk_chamsocme_t40.csv',
#  'tk_chamsocme_t41.csv',
#  'tk_chamsocme_t42.csv',
#  'tk_chamsocme_t43.csv',
#  'tk_chamsocme_t44.csv',
#  'tk_chamsocme_t45.csv',
#  'tk_chamsocme_t46.csv',
#  'tk_chamsocme_t47.csv',
#  'tk_chamsocme_t48.csv',
#  'tk_chamsocme_t49.csv',
#  'tk_chamsocme_t5.csv',
#  'tk_chamsocme_t50.csv',
#  'tk_chamsocme_t6.csv',
#  'tk_chamsocme_t7.csv',
#  'tk_chamsocme_t8.csv',
#  'tk_chamsocme_t9.csv',
#  'tk_mvb_chamsocme.ipynb',
#  'tk_mvb_chamsocme_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_chamsocnhacua_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Nước Tắm Thảo Dược Cho Bà Bầu Và Mẹ Sau Sinh B...    243.000₫
# 1   Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...    185.000₫
# 2   Combo 2 hộp lá xông giúp khử mùi, giải cảm, lư...     90.480₫
# 3   Kem Dưỡng Da Mắt, Ngăn Ngừa Nếp Nhăn, Quầng Th...    280.500₫
# 4   Bộ trắng da, sạch nám cao cấp Wonmom ( Sữa rửa...  1.211.200₫
# ..                                                ...         ...
# 35  Dầu gội cốt bồ kết đánh bay gàu, mọc tóc, dưỡn...    168.000₫
# 36  Lá xông, thơm tho cơ thể mẹ sau sinh, lưu thôn...     45.240₫
# 37  Quần lót bầu và sau sinh cạp chéo chất SU ĐÚC ...     29.000₫
# 38  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...    165.000₫
# 39  Áo Choàng Cho Bé Bú, Khăn Choàng Che Nắng, Khă...     65.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=e_riaufiw...      1     -10%
# 1   https://tka.tiki.vn/pixel/pixel?data=eOpGcPjMA...      2     -16%
# 2   https://tka.tiki.vn/pixel/pixel?data=16ncby6ov...      3     -13%
# 3   https://tka.tiki.vn/pixel/pixel?data=K9nnWtHGu...      4     -15%
# 4   https://tka.tiki.vn/pixel/pixel?data=9OJUFvyHX...      5     -20%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/dau-goi-cot-bo-ket-danh-bay-ga...     36      NaN
# 36  https://tiki.vn/la-xong-thom-tho-co-the-me-sau...     37      NaN
# 37  https://tiki.vn/quan-lot-bau-va-sau-sinh-cap-c...     38      NaN
# 38  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...     39      NaN
# 39  https://tiki.vn/ao-choang-cho-be-bu-khan-choan...     40      NaN
#
#          sales   category  Unnamed: 0
# 0    Đã bán 11  chamsocme         NaN
# 1   Đã bán 183  chamsocme         NaN
# 2   Đã bán 115  chamsocme         NaN
# 3          NaN  chamsocme         NaN
# 4     Đã bán 1  chamsocme         NaN
# ..         ...        ...         ...
# 35  Đã bán 433  chamsocme         NaN
# 36  Đã bán 224  chamsocme         NaN
# 37   Đã bán 40  chamsocme         NaN
# 38   Đã bán 13  chamsocme         NaN
# 39   Đã bán 52  chamsocme         NaN
#
# [4060 rows x 8 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     Nước Tắm Thảo Dược Cho Bà Bầu Và Mẹ Sau Sinh B...    243.000₫
# 1     Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...    185.000₫
# 2     Combo 2 hộp lá xông giúp khử mùi, giải cảm, lư...     90.480₫
# 3     Bộ trắng da, sạch nám cao cấp Wonmom ( Sữa rửa...  1.211.200₫
# 4             2 Miếng Đá Khô Frozen 1 Fatzbaby FB0020VN     72.000₫
# ...                                                 ...         ...
# 2473  Dầu gội cốt bồ kết đánh bay gàu, mọc tóc, dưỡn...    168.000₫
# 2474  Lá xông, thơm tho cơ thể mẹ sau sinh, lưu thôn...     45.240₫
# 2475  Quần lót bầu và sau sinh cạp chéo chất SU ĐÚC ...     29.000₫
# 2476  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...    165.000₫
# 2477  Áo Choàng Cho Bé Bú, Khăn Choàng Che Nắng, Khă...     65.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=e_riaufiw...     -10%   Đã bán 11
# 1     https://tka.tiki.vn/pixel/pixel?data=eOpGcPjMA...     -16%  Đã bán 183
# 2     https://tka.tiki.vn/pixel/pixel?data=16ncby6ov...     -13%  Đã bán 115
# 3     https://tka.tiki.vn/pixel/pixel?data=9OJUFvyHX...     -20%    Đã bán 1
# 4     https://tiki.vn/2-mieng-da-kho-frozen-1-fatzba...      -9%  Đã bán 181
# ...                                                 ...      ...         ...
# 2473  https://tiki.vn/dau-goi-cot-bo-ket-danh-bay-ga...      NaN  Đã bán 433
# 2474  https://tiki.vn/la-xong-thom-tho-co-the-me-sau...      NaN  Đã bán 224
# 2475  https://tiki.vn/quan-lot-bau-va-sau-sinh-cap-c...      NaN   Đã bán 40
# 2476  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...      NaN   Đã bán 13
# 2477  https://tiki.vn/ao-choang-cho-be-bu-khan-choan...      NaN   Đã bán 52
#
#        category  Unnamed: 0
# 0     chamsocme         NaN
# 1     chamsocme         NaN
# 2     chamsocme         NaN
# 3     chamsocme         NaN
# 4     chamsocme         NaN
# ...         ...         ...
# 2473  chamsocme         NaN
# 2474  chamsocme         NaN
# 2475  chamsocme         NaN
# 2476  chamsocme         NaN
# 2477  chamsocme         NaN
#
# [2478 rows x 7 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        243000
# 1        185000
# 2         90480
# 3       1211200
# 4         72000
#          ...
# 2473     168000
# 2474      45240
# 2475      29000
# 2476     165000
# 2477      65000
# Name: price, Length: 2478, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        11.0
# 1       183.0
# 2       115.0
# 3         1.0
# 4       181.0
#         ...
# 2473    433.0
# 2474    224.0
# 2475     40.0
# 2476     13.0
# 2477     52.0
# Name: sales, Length: 2478, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        2673000.0
# 1       33855000.0
# 2       10405200.0
# 3        1211200.0
# 4       13032000.0
#            ...
# 2473    72744000.0
# 2474    10133760.0
# 2475     1160000.0
# 2476     2145000.0
# 2477     3380000.0
# Name: revenue, Length: 2478, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chăm sóc nhà cửa: ", total)
print("Số mặt hàng đã bán: ", len(df_all["title"])) # san pham da ban
print("Số sản phẩm đã bán: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số chăm sóc nhà cửa:  27973788648.0
# Số mặt hàng đã bán:  2478
# Số sản phẩm đã bán:  111522.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Nước Tắm Thảo Dược Cho Bà Bầu Và Mẹ Sau Sinh B...   243000
# 1     Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...   185000
# 2     Combo 2 hộp lá xông giúp khử mùi, giải cảm, lư...    90480
# 3     Bộ trắng da, sạch nám cao cấp Wonmom ( Sữa rửa...  1211200
# 4             2 Miếng Đá Khô Frozen 1 Fatzbaby FB0020VN    72000
# ...                                                 ...      ...
# 2473  Dầu gội cốt bồ kết đánh bay gàu, mọc tóc, dưỡn...   168000
# 2474  Lá xông, thơm tho cơ thể mẹ sau sinh, lưu thôn...    45240
# 2475  Quần lót bầu và sau sinh cạp chéo chất SU ĐÚC ...    29000
# 2476  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...   165000
# 2477  Áo Choàng Cho Bé Bú, Khăn Choàng Che Nắng, Khă...    65000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=e_riaufiw...     -10%   11.0
# 1     https://tka.tiki.vn/pixel/pixel?data=eOpGcPjMA...     -16%  183.0
# 2     https://tka.tiki.vn/pixel/pixel?data=16ncby6ov...     -13%  115.0
# 3     https://tka.tiki.vn/pixel/pixel?data=9OJUFvyHX...     -20%    1.0
# 4     https://tiki.vn/2-mieng-da-kho-frozen-1-fatzba...      -9%  181.0
# ...                                                 ...      ...    ...
# 2473  https://tiki.vn/dau-goi-cot-bo-ket-danh-bay-ga...      NaN  433.0
# 2474  https://tiki.vn/la-xong-thom-tho-co-the-me-sau...      NaN  224.0
# 2475  https://tiki.vn/quan-lot-bau-va-sau-sinh-cap-c...      NaN   40.0
# 2476  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...      NaN   13.0
# 2477  https://tiki.vn/ao-choang-cho-be-bu-khan-choan...      NaN   52.0
#
#        category  Unnamed: 0     revenue
# 0     chamsocme         NaN   2673000.0
# 1     chamsocme         NaN  33855000.0
# 2     chamsocme         NaN  10405200.0
# 3     chamsocme         NaN   1211200.0
# 4     chamsocme         NaN  13032000.0
# ...         ...         ...         ...
# 2473  chamsocme         NaN  72744000.0
# 2474  chamsocme         NaN  10133760.0
# 2475  chamsocme         NaN   1160000.0
# 2476  chamsocme         NaN   2145000.0
# 2477  chamsocme         NaN   3380000.0
#
# [2478 rows x 8 columns]

# %%
df_all = df_all.drop('Unnamed: 0', axis=1)

# %%
df_all.to_csv("tk_chamsocnhacua_all_ed.csv")
