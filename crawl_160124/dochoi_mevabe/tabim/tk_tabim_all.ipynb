# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\dochoi_mevabe\tabim"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_mvb_tabim.ipynb',
#  'tk_mvb_tabim_npage.ipynb',
#  'tk_tabim.csv',
#  'tk_tabim_all.ipynb',
#  'tk_tabim_t10.csv',
#  'tk_tabim_t11.csv',
#  'tk_tabim_t12.csv',
#  'tk_tabim_t13.csv',
#  'tk_tabim_t14.csv',
#  'tk_tabim_t15.csv',
#  'tk_tabim_t16.csv',
#  'tk_tabim_t17.csv',
#  'tk_tabim_t18.csv',
#  'tk_tabim_t19.csv',
#  'tk_tabim_t2.csv',
#  'tk_tabim_t20.csv',
#  'tk_tabim_t21.csv',
#  'tk_tabim_t22.csv',
#  'tk_tabim_t23.csv',
#  'tk_tabim_t24.csv',
#  'tk_tabim_t25.csv',
#  'tk_tabim_t26.csv',
#  'tk_tabim_t27.csv',
#  'tk_tabim_t28.csv',
#  'tk_tabim_t29.csv',
#  'tk_tabim_t3.csv',
#  'tk_tabim_t30.csv',
#  'tk_tabim_t31.csv',
#  'tk_tabim_t32.csv',
#  'tk_tabim_t33.csv',
#  'tk_tabim_t34.csv',
#  'tk_tabim_t35.csv',
#  'tk_tabim_t36.csv',
#  'tk_tabim_t37.csv',
#  'tk_tabim_t38.csv',
#  'tk_tabim_t39.csv',
#  'tk_tabim_t4.csv',
#  'tk_tabim_t40.csv',
#  'tk_tabim_t41.csv',
#  'tk_tabim_t42.csv',
#  'tk_tabim_t43.csv',
#  'tk_tabim_t44.csv',
#  'tk_tabim_t45.csv',
#  'tk_tabim_t46.csv',
#  'tk_tabim_t47.csv',
#  'tk_tabim_t48.csv',
#  'tk_tabim_t49.csv',
#  'tk_tabim_t5.csv',
#  'tk_tabim_t50.csv',
#  'tk_tabim_t6.csv',
#  'tk_tabim_t7.csv',
#  'tk_tabim_t8.csv',
#  'tk_tabim_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_tabim_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Bổ ...  157.000₫
# 1   Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  335.000₫
# 2    Tã - Bỉm quần người lớn Livedo size L - Nhật Bản  730.000₫
# 3   Tã - Bỉm người lớn Livedo size L (22 cái/ gói)...   730.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275.000₫
# 36  Khăn giấy ướt vịt vàng 10 gói kèm thùng nhựa t...   84.781₫
# 37       Tã Dán Cao Cấp Moony Nhật Bản S84 (84 Miếng)  287.500₫
# 38  Combo 10 tả vải, tả dán sơ sinh cotton Thái Hà...  135.000₫
# 39  Bỉm Dùng Thử KITIN NATURAL Size NB56/S50/M44/L...    3.500₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=BLEuG72DB...      1     -32%
# 1   https://tka.tiki.vn/pixel/pixel?data=VqdTa58SX...      2     -48%
# 2   https://tka.tiki.vn/pixel/pixel?data=PmY78UjL6...      3      NaN
# 3   https://tka.tiki.vn/pixel/pixel?data=zyb6ZgkKb...      4     -48%
# 4   https://tka.tiki.vn/pixel/pixel?data=Idu8i1DDW...      5     -39%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...     36      NaN
# 36  https://tiki.vn/khan-giay-uot-vit-vang-10-goi-...     37      NaN
# 37  https://tiki.vn/ta-dan-cao-cap-moony-nhat-ban-...     38      NaN
# 38  https://tiki.vn/combo-10-ta-vai-ta-dan-so-sinh...     39      NaN
# 39  https://tiki.vn/bim-dung-thu-kitin-natural-siz...     40      NaN
#
#          sales category
# 0   Đã bán 5k+    tabim
# 1   Đã bán 5k+    tabim
# 2    Đã bán 55    tabim
# 3    Đã bán 12    tabim
# 4          NaN    tabim
# ..         ...      ...
# 35  Đã bán 189    tabim
# 36   Đã bán 11    tabim
# 37  Đã bán 238    tabim
# 38   Đã bán 88    tabim
# 39  Đã bán 145    tabim
#
# [2021 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Bổ ...  157.000₫
# 1     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  335.000₫
# 2      Tã - Bỉm quần người lớn Livedo size L - Nhật Bản  730.000₫
# 3     Tã - Bỉm người lớn Livedo size L (22 cái/ gói)...   730.000
# 4     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  335.000₫
# ...                                                 ...       ...
# 1389  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275.000₫
# 1390  Khăn giấy ướt vịt vàng 10 gói kèm thùng nhựa t...   84.781₫
# 1391       Tã Dán Cao Cấp Moony Nhật Bản S84 (84 Miếng)  287.500₫
# 1392  Combo 10 tả vải, tả dán sơ sinh cotton Thái Hà...  135.000₫
# 1393  Bỉm Dùng Thử KITIN NATURAL Size NB56/S50/M44/L...    3.500₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=BLEuG72DB...     -32%  Đã bán 5k+
# 1     https://tka.tiki.vn/pixel/pixel?data=VqdTa58SX...     -48%  Đã bán 5k+
# 2     https://tka.tiki.vn/pixel/pixel?data=PmY78UjL6...      NaN   Đã bán 55
# 3     https://tka.tiki.vn/pixel/pixel?data=zyb6ZgkKb...     -48%   Đã bán 12
# 4     https://tiki.vn/thung-ta-bim-quan-huggies-skin...     -40%  Đã bán 5k+
# ...                                                 ...      ...         ...
# 1389  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...      NaN  Đã bán 189
# 1390  https://tiki.vn/khan-giay-uot-vit-vang-10-goi-...      NaN   Đã bán 11
# 1391  https://tiki.vn/ta-dan-cao-cap-moony-nhat-ban-...      NaN  Đã bán 238
# 1392  https://tiki.vn/combo-10-ta-vai-ta-dan-so-sinh...      NaN   Đã bán 88
# 1393  https://tiki.vn/bim-dung-thu-kitin-natural-siz...      NaN  Đã bán 145
#
#      category
# 0       tabim
# 1       tabim
# 2       tabim
# 3       tabim
# 4       tabim
# ...       ...
# 1389    tabim
# 1390    tabim
# 1391    tabim
# 1392    tabim
# 1393    tabim
#
# [1394 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       157000
# 1       335000
# 2       730000
# 3       730000
# 4       335000
#          ...
# 1389    275000
# 1390     84781
# 1391    287500
# 1392    135000
# 1393      3500
# Name: price, Length: 1394, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       5000.0
# 1       5000.0
# 2         55.0
# 3         12.0
# 4       5000.0
#          ...
# 1389     189.0
# 1390      11.0
# 1391     238.0
# 1392      88.0
# 1393     145.0
# Name: sales, Length: 1394, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       7.850000e+08
# 1       1.675000e+09
# 2       4.015000e+07
# 3       8.760000e+06
# 4       1.675000e+09
#             ...
# 1389    5.197500e+07
# 1390    9.325910e+05
# 1391    6.842500e+07
# 1392    1.188000e+07
# 1393    5.075000e+05
# Name: revenue, Length: 1394, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số tabim: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số tabim:  83551004853.0
# So mat hang da ban:  1394
# So san pham da ban:  317804.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Bổ ...  157000
# 1     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  335000
# 2      Tã - Bỉm quần người lớn Livedo size L - Nhật Bản  730000
# 3     Tã - Bỉm người lớn Livedo size L (22 cái/ gói)...  730000
# 4     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  335000
# ...                                                 ...     ...
# 1389  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275000
# 1390  Khăn giấy ướt vịt vàng 10 gói kèm thùng nhựa t...   84781
# 1391       Tã Dán Cao Cấp Moony Nhật Bản S84 (84 Miếng)  287500
# 1392  Combo 10 tả vải, tả dán sơ sinh cotton Thái Hà...  135000
# 1393  Bỉm Dùng Thử KITIN NATURAL Size NB56/S50/M44/L...    3500
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=BLEuG72DB...     -32%  5000.0
# 1     https://tka.tiki.vn/pixel/pixel?data=VqdTa58SX...     -48%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=PmY78UjL6...      NaN    55.0
# 3     https://tka.tiki.vn/pixel/pixel?data=zyb6ZgkKb...     -48%    12.0
# 4     https://tiki.vn/thung-ta-bim-quan-huggies-skin...     -40%  5000.0
# ...                                                 ...      ...     ...
# 1389  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...      NaN   189.0
# 1390  https://tiki.vn/khan-giay-uot-vit-vang-10-goi-...      NaN    11.0
# 1391  https://tiki.vn/ta-dan-cao-cap-moony-nhat-ban-...      NaN   238.0
# 1392  https://tiki.vn/combo-10-ta-vai-ta-dan-so-sinh...      NaN    88.0
# 1393  https://tiki.vn/bim-dung-thu-kitin-natural-siz...      NaN   145.0
#
#      category       revenue
# 0       tabim  7.850000e+08
# 1       tabim  1.675000e+09
# 2       tabim  4.015000e+07
# 3       tabim  8.760000e+06
# 4       tabim  1.675000e+09
# ...       ...           ...
# 1389    tabim  5.197500e+07
# 1390    tabim  9.325910e+05
# 1391    tabim  6.842500e+07
# 1392    tabim  1.188000e+07
# 1393    tabim  5.075000e+05
#
# [1394 rows x 7 columns]

# %%
df_all.to_csv("tk_tabim_all_ed.csv")
