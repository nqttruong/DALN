# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\dochoi_mevabe\dochoi"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dochoi.csv',
#  'tk_dochoi_all.ipynb',
#  'tk_dochoi_t23.csv',
#  'tk_dochoi_t24.csv',
#  'tk_dochoi_t25.csv',
#  'tk_dochoi_t26.csv',
#  'tk_dochoi_t27.csv',
#  'tk_dochoi_t28.csv',
#  'tk_dochoi_t29.csv',
#  'tk_dochoi_t30.csv',
#  'tk_dochoi_t31.csv',
#  'tk_dochoi_t32.csv',
#  'tk_dochoi_t33.csv',
#  'tk_dochoi_t34.csv',
#  'tk_dochoi_t35.csv',
#  'tk_dochoi_t36.csv',
#  'tk_dochoi_t37.csv',
#  'tk_dochoi_t38.csv',
#  'tk_dochoi_t39.csv',
#  'tk_dochoi_t40.csv',
#  'tk_dochoi_t41.csv',
#  'tk_dochoi_t42.csv',
#  'tk_dochoi_t43.csv',
#  'tk_dochoi_t44.csv',
#  'tk_dochoi_t45.csv',
#  'tk_dochoi_t46.csv',
#  'tk_dochoi_t47.csv',
#  'tk_dochoi_t48.csv',
#  'tk_dochoi_t49.csv',
#  'tk_dochoi_t50.csv',
#  'tk_mvb_dochoi.ipynb',
#  'tk_mvb_dochoi_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dochoi_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Máy Đọc Viết Từ Vựng Phát Nhạc Song Ngữ LalaTa...  359.000₫
# 1                Xe chòi ô tô cho bé - màu xanh dương  189.000₫
# 2   Xe Chòi Chân Vận Động Kiêm Xe Đạp 3 Bánh Cho B...  189.000₫
# 3   Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...  248.000₫
# 4   Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...  155.000₫
# ..                                                ...       ...
# 35     Đồ Chơi Khoa Học Bóng Đèn Sinh Thái – 4M 03426  279.000₫
# 36                  Bộ luồn hạt mini đồ chơi giáo dục   24.000₫
# 37  Khăn Nhung Vải Dệt Mềm Trải Bài Tarot Cao Cấp ...   39.000₫
# 38  Gấu bông Sóc Shiba Cosplay ngộ nghĩnh đáng yêu...   59.000₫
# 39                  Bộ Bài Light Seer’s Tarot New Đẹp   99.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=9h8-IN7s0...      1     -36%
# 1   https://tiki.vn/xe-choi-o-to-cho-be-mau-xanh-d...      2      -6%
# 2   https://tiki.vn/xe-choi-chan-van-dong-kiem-xe-...      3      -5%
# 3   https://tiki.vn/xe-lac-cho-be-xe-choi-chan-tre...      4     -10%
# 4   https://tiki.vn/xe-lac-cho-be-xe-choi-chan-tre...      5     -29%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/do-choi-khoa-hoc-bong-den-sinh...     36      NaN
# 36  https://tiki.vn/bo-luon-hat-mini-do-choi-giao-...     37      NaN
# 37  https://tiki.vn/khan-nhung-vai-det-mem-trai-ba...     38      NaN
# 38  https://tiki.vn/gau-bong-soc-shiba-cosplay-ngo...     39      NaN
# 39  https://tiki.vn/bo-bai-light-seer-s-tarot-new-...     40      NaN
#
#          sales category
# 0    Đã bán 42   dochoi
# 1   Đã bán 353   dochoi
# 2   Đã bán 304   dochoi
# 3   Đã bán 533   dochoi
# 4    Đã bán 55   dochoi
# ..         ...      ...
# 35    Đã bán 2   dochoi
# 36    Đã bán 2   dochoi
# 37         NaN   dochoi
# 38   Đã bán 25   dochoi
# 39         NaN   dochoi
#
# [1161 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Máy Đọc Viết Từ Vựng Phát Nhạc Song Ngữ LalaTa...  359.000₫
# 1                  Xe chòi ô tô cho bé - màu xanh dương  189.000₫
# 2     Xe Chòi Chân Vận Động Kiêm Xe Đạp 3 Bánh Cho B...  189.000₫
# 3     Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...  248.000₫
# 4     Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...  155.000₫
# ...                                                 ...       ...
# 1126  Đồ chơi trẻ em cua bò tinh nghịch đáng yêu - Q...  120.000₫
# 1127  Rubik biến thể QiYi Fisher Cube stickerless hi...  140.000₫
# 1128     Đồ Chơi Khoa Học Bóng Đèn Sinh Thái – 4M 03426  279.000₫
# 1129                  Bộ luồn hạt mini đồ chơi giáo dục   24.000₫
# 1130  Gấu bông Sóc Shiba Cosplay ngộ nghĩnh đáng yêu...   59.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=9h8-IN7s0...     -36%   Đã bán 42
# 1     https://tiki.vn/xe-choi-o-to-cho-be-mau-xanh-d...      -6%  Đã bán 353
# 2     https://tiki.vn/xe-choi-chan-van-dong-kiem-xe-...      -5%  Đã bán 304
# 3     https://tiki.vn/xe-lac-cho-be-xe-choi-chan-tre...     -10%  Đã bán 533
# 4     https://tiki.vn/xe-lac-cho-be-xe-choi-chan-tre...     -29%   Đã bán 55
# ...                                                 ...      ...         ...
# 1126  https://tiki.vn/do-choi-tre-em-cua-biet-bo-tin...      NaN    Đã bán 3
# 1127  https://tiki.vn/rubik-bien-the-qiyi-fisher-cub...      NaN   Đã bán 25
# 1128  https://tiki.vn/do-choi-khoa-hoc-bong-den-sinh...      NaN    Đã bán 2
# 1129  https://tiki.vn/bo-luon-hat-mini-do-choi-giao-...      NaN    Đã bán 2
# 1130  https://tiki.vn/gau-bong-soc-shiba-cosplay-ngo...      NaN   Đã bán 25
#
#      category
# 0      dochoi
# 1      dochoi
# 2      dochoi
# 3      dochoi
# 4      dochoi
# ...       ...
# 1126   dochoi
# 1127   dochoi
# 1128   dochoi
# 1129   dochoi
# 1130   dochoi
#
# [1131 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       359000
# 1       189000
# 2       189000
# 3       248000
# 4       155000
#          ...
# 1126    120000
# 1127    140000
# 1128    279000
# 1129     24000
# 1130     59000
# Name: price, Length: 1131, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        42.0
# 1       353.0
# 2       304.0
# 3       533.0
# 4        55.0
#         ...
# 1126      3.0
# 1127     25.0
# 1128      2.0
# 1129      2.0
# 1130     25.0
# Name: sales, Length: 1131, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        15078000.0
# 1        66717000.0
# 2        57456000.0
# 3       132184000.0
# 4         8525000.0
#            ...
# 1126       360000.0
# 1127      3500000.0
# 1128       558000.0
# 1129        48000.0
# 1130      1475000.0
# Name: revenue, Length: 1131, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dochoi: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dochoi:  8884377327.0
# So mat hang da ban:  1131
# So san pham da ban:  48437.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Máy Đọc Viết Từ Vựng Phát Nhạc Song Ngữ LalaTa...  359000
# 1                  Xe chòi ô tô cho bé - màu xanh dương  189000
# 2     Xe Chòi Chân Vận Động Kiêm Xe Đạp 3 Bánh Cho B...  189000
# 3     Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...  248000
# 4     Xe lắc cho bé, Xe chòi chân trẻ em hình ô tô p...  155000
# ...                                                 ...     ...
# 1126  Đồ chơi trẻ em cua bò tinh nghịch đáng yêu - Q...  120000
# 1127  Rubik biến thể QiYi Fisher Cube stickerless hi...  140000
# 1128     Đồ Chơi Khoa Học Bóng Đèn Sinh Thái – 4M 03426  279000
# 1129                  Bộ luồn hạt mini đồ chơi giáo dục   24000
# 1130  Gấu bông Sóc Shiba Cosplay ngộ nghĩnh đáng yêu...   59000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=9h8-IN7s0...     -36%   42.0
# 1     https://tiki.vn/xe-choi-o-to-cho-be-mau-xanh-d...      -6%  353.0
# 2     https://tiki.vn/xe-choi-chan-van-dong-kiem-xe-...      -5%  304.0
# 3     https://tiki.vn/xe-lac-cho-be-xe-choi-chan-tre...     -10%  533.0
# 4     https://tiki.vn/xe-lac-cho-be-xe-choi-chan-tre...     -29%   55.0
# ...                                                 ...      ...    ...
# 1126  https://tiki.vn/do-choi-tre-em-cua-biet-bo-tin...      NaN    3.0
# 1127  https://tiki.vn/rubik-bien-the-qiyi-fisher-cub...      NaN   25.0
# 1128  https://tiki.vn/do-choi-khoa-hoc-bong-den-sinh...      NaN    2.0
# 1129  https://tiki.vn/bo-luon-hat-mini-do-choi-giao-...      NaN    2.0
# 1130  https://tiki.vn/gau-bong-soc-shiba-cosplay-ngo...      NaN   25.0
#
#      category      revenue
# 0      dochoi   15078000.0
# 1      dochoi   66717000.0
# 2      dochoi   57456000.0
# 3      dochoi  132184000.0
# 4      dochoi    8525000.0
# ...       ...          ...
# 1126   dochoi     360000.0
# 1127   dochoi    3500000.0
# 1128   dochoi     558000.0
# 1129   dochoi      48000.0
# 1130   dochoi    1475000.0
#
# [1131 rows x 7 columns]

# %%
df_all.to_csv("tk_dochoi_all_ed.csv")
