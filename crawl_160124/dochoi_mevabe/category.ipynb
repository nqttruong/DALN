# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\dochoi_mevabe"
os.listdir(path)
# Out:
# ['Brand',
#  'category.ipynb',
#  'chamsocme',
#  'chamsocnhacua',
#  'chuanbimangthai',
#  'dinhduongchobe',
#  'dinhduongchome',
#  'dinhduongnguoilon',
#  'dochoi',
#  'dodungchobe',
#  'tabim',
#  'thoitrangmevabe',
#  'thucphamandam',
#  'tk_chamsocme_all_ed.csv',
#  'tk_chamsocnhacua_all_ed.csv',
#  'tk_chuanbimangthai_all_ed.csv',
#  'tk_dinhduongchobe_all_ed.csv',
#  'tk_dinhduongchome_all_ed.csv',
#  'tk_dinhduongnguoilon_all_ed.csv',
#  'tk_dochoi_all_ed.csv',
#  'tk_dodungchobe_all_ed.csv',
#  'tk_tabim_all_ed.csv',
#  'tk_thoitrangmevabe_all_ed.csv',
#  'tk_thucphamandam_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_26148\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_26148\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_26148\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_26148\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_26148\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_26148\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_26148\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_26148\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_26148\1754220595.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat(frames)

# %%
df
# Out:
#    Unnamed: 0                                              title    price  \
# 0           0  Nước Tắm Thảo Dược Cho Bà Bầu Và Mẹ Sau Sinh B...   243000
# 1           1  Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...   185000
# 2           2  Combo 2 hộp lá xông giúp khử mùi, giải cảm, lư...    90480
# 3           3  Bộ trắng da, sạch nám cao cấp Wonmom ( Sữa rửa...  1211200
# 4           4          2 Miếng Đá Khô Frozen 1 Fatzbaby FB0020VN    72000
# ..        ...                                                ...      ...
# 70         70   Bánh Gạo Hữu Cơ Hương Dâu Chuối APPLE MONKEY 30G    79000
# 71         71  THỰC PHẨM BỔ SUNG MÌ SOUMEN TÁCH MUỐI BỔ SUNG ...    55000
# 72         72  [Made in Korea] Ngũ cốc socola Pororo(hình sao...   158000
# 73         73  Nui Dinh Dưỡng Hữu Cơ Hình Chứ Cái Alphabet Từ...   233000
# 74         74  Combo 2 Gói Mì ăn dặm cho trẻ trên 1 tuổi Niss...   155000
#
#                                             link_item discount  sales  \
# 0   https://tka.tiki.vn/pixel/pixel?data=e_riaufiw...     -10%   11.0
# 1   https://tka.tiki.vn/pixel/pixel?data=eOpGcPjMA...     -16%  183.0
# 2   https://tka.tiki.vn/pixel/pixel?data=16ncby6ov...     -13%  115.0
# 3   https://tka.tiki.vn/pixel/pixel?data=9OJUFvyHX...     -20%    1.0
# 4   https://tiki.vn/2-mieng-da-kho-frozen-1-fatzba...      -9%  181.0
# ..                                                ...      ...    ...
# 70  https://tiki.vn/banh-gao-huu-co-huong-dau-chuo...      NaN    2.0
# 71  https://tiki.vn/thuc-pham-bo-sung-mi-soumen-ta...      NaN    2.0
# 72  https://tiki.vn/made-in-korea-ngu-coc-socola-p...      NaN    2.0
# 73  https://tiki.vn/nui-dinh-duong-huu-co-hinh-chu...      NaN    1.0
# 74  https://tiki.vn/combo-2-goi-mi-an-dam-cho-tre-...      NaN    4.0
#
#          category     revenue
# 0       chamsocme   2673000.0
# 1       chamsocme  33855000.0
# 2       chamsocme  10405200.0
# 3       chamsocme   1211200.0
# 4       chamsocme  13032000.0
# ..            ...         ...
# 70  thucphamandam    158000.0
# 71  thucphamandam    110000.0
# 72  thucphamandam    316000.0
# 73  thucphamandam    233000.0
# 74  thucphamandam    620000.0
#
# [11511 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "mevabe")

# %%
df
# Out:
#                                                 title    price  \
# 0   Nước Tắm Thảo Dược Cho Bà Bầu Và Mẹ Sau Sinh B...   243000
# 1   Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...   185000
# 2   Combo 2 hộp lá xông giúp khử mùi, giải cảm, lư...    90480
# 3   Bộ trắng da, sạch nám cao cấp Wonmom ( Sữa rửa...  1211200
# 4           2 Miếng Đá Khô Frozen 1 Fatzbaby FB0020VN    72000
# ..                                                ...      ...
# 70   Bánh Gạo Hữu Cơ Hương Dâu Chuối APPLE MONKEY 30G    79000
# 71  THỰC PHẨM BỔ SUNG MÌ SOUMEN TÁCH MUỐI BỔ SUNG ...    55000
# 72  [Made in Korea] Ngũ cốc socola Pororo(hình sao...   158000
# 73  Nui Dinh Dưỡng Hữu Cơ Hình Chứ Cái Alphabet Từ...   233000
# 74  Combo 2 Gói Mì ăn dặm cho trẻ trên 1 tuổi Niss...   155000
#
#                                             link_item discount  sales  \
# 0   https://tka.tiki.vn/pixel/pixel?data=e_riaufiw...     -10%   11.0
# 1   https://tka.tiki.vn/pixel/pixel?data=eOpGcPjMA...     -16%  183.0
# 2   https://tka.tiki.vn/pixel/pixel?data=16ncby6ov...     -13%  115.0
# 3   https://tka.tiki.vn/pixel/pixel?data=9OJUFvyHX...     -20%    1.0
# 4   https://tiki.vn/2-mieng-da-kho-frozen-1-fatzba...      -9%  181.0
# ..                                                ...      ...    ...
# 70  https://tiki.vn/banh-gao-huu-co-huong-dau-chuo...      NaN    2.0
# 71  https://tiki.vn/thuc-pham-bo-sung-mi-soumen-ta...      NaN    2.0
# 72  https://tiki.vn/made-in-korea-ngu-coc-socola-p...      NaN    2.0
# 73  https://tiki.vn/nui-dinh-duong-huu-co-hinh-chu...      NaN    1.0
# 74  https://tiki.vn/combo-2-goi-mi-an-dam-cho-tre-...      NaN    4.0
#
#         item_list category     revenue
# 0       chamsocme   mevabe   2673000.0
# 1       chamsocme   mevabe  33855000.0
# 2       chamsocme   mevabe  10405200.0
# 3       chamsocme   mevabe   1211200.0
# 4       chamsocme   mevabe  13032000.0
# ..            ...      ...         ...
# 70  thucphamandam   mevabe    158000.0
# 71  thucphamandam   mevabe    110000.0
# 72  thucphamandam   mevabe    316000.0
# 73  thucphamandam   mevabe    233000.0
# 74  thucphamandam   mevabe    620000.0
#
# [11511 rows x 8 columns]

# %%
df.to_csv('tk_mevabe_all_ed.csv', index=False, encoding='utf-8')
