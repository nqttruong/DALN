# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\dienthoai_maytinhbang"
os.listdir(path)
# Out:
# ['Brand',
#  'category.ipynb',
#  'dienthoai',
#  'dienthoaiban',
#  'dienthoaiphothong',
#  'maydocsach',
#  'maytinhbang',
#  'tk_dienthoaiban_all_ed.csv',
#  'tk_dienthoaiphothong_all_ed.csv',
#  'tk_maydocsach_all_ed.csv',
#  'tk_maytinhbang_all_ed.csv',
#  'tk_smartphone_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#      Unnamed: 0                                              title    price  \
# 0             0            Điện thoại bàn Ktel 645 hàng chính hãng   398000
# 1             1  Điện thoại bàn Panasonic KX-TGF310 hàng chính ...  2250000
# 2             2  Điện thoại bàn Panasonic KX-TS500MX-hàng chính...   300000
# 3             3  Điện Thoại Bàn Panasonic KX-TSC11 - Hàng Chính...   588000
# 4             4  Điện thoại bàn không dây Panasonic KX-TGD310 -...  1280000
# ..          ...                                                ...      ...
# 143         143   Điện Thoại Realme C51 3GB/64GB - Hàng Chính Hãng  2699000
# 144         144  Điện thoại Xiaomi Redmi 9A 2GB/32GB Xám - Hàng...  2088000
# 145         145  Điện Thoại Samsung Galaxy A14 5G (4GB/128GB) -...  5000000
# 146         146  Điện thoại TECNO Spark 6 Go (4GB/64GB) - Hàng ...  2559000
# 147         147  Điện thoại OPPO A57 4GB/128GB Đen - Hàng chính...  3850000
#
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "dienthoai")

# %%
df
# Out:
#                                                  title    price  \
# 0              Điện thoại bàn Ktel 645 hàng chính hãng   398000
# 1    Điện thoại bàn Panasonic KX-TGF310 hàng chính ...  2250000
# 2    Điện thoại bàn Panasonic KX-TS500MX-hàng chính...   300000
# 3    Điện Thoại Bàn Panasonic KX-TSC11 - Hàng Chính...   588000
# 4    Điện thoại bàn không dây Panasonic KX-TGD310 -...  1280000
# ..                                                 ...      ...
# 143   Điện Thoại Realme C51 3GB/64GB - Hàng Chính Hãng  2699000
# 144  Điện thoại Xiaomi Redmi 9A 2GB/32GB Xám - Hàng...  2088000
# 145  Điện Thoại Samsung Galaxy A14 5G (4GB/128GB) -...  5000000
# 146  Điện thoại TECNO Spark 6 Go (4GB/64GB) - Hàng ...  2559000
# 147  Điện thoại OPPO A57 4GB/128GB Đen - Hàng chính...  3850000
#
#                                              link_item discount  sales  \
# 0    https://tiki.vn/dien-thoai-ban-ktel-645-hang-c...      NaN   54.0
# ...

# %%
df.to_csv('tk_dienthoai_all_ed.csv', index=False, encoding='utf-8')
