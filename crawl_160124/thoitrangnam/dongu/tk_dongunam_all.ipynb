# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\thoitrangnam\dongu"
os.listdir(path)
# Out:
# ['tk_dongunam.csv',
#  'tk_dongunam.ipynb',
#  'tk_dongunam_all.ipynb',
#  'tk_ttn_dongunam_npage.ipynb',
#  'tk_ttn_dongunam_t10.csv',
#  'tk_ttn_dongunam_t11.csv',
#  'tk_ttn_dongunam_t12.csv',
#  'tk_ttn_dongunam_t13.csv',
#  'tk_ttn_dongunam_t14.csv',
#  'tk_ttn_dongunam_t15.csv',
#  'tk_ttn_dongunam_t16.csv',
#  'tk_ttn_dongunam_t17.csv',
#  'tk_ttn_dongunam_t18.csv',
#  'tk_ttn_dongunam_t19.csv',
#  'tk_ttn_dongunam_t2.csv',
#  'tk_ttn_dongunam_t20.csv',
#  'tk_ttn_dongunam_t21.csv',
#  'tk_ttn_dongunam_t22.csv',
#  'tk_ttn_dongunam_t23.csv',
#  'tk_ttn_dongunam_t24.csv',
#  'tk_ttn_dongunam_t25.csv',
#  'tk_ttn_dongunam_t26.csv',
#  'tk_ttn_dongunam_t27.csv',
#  'tk_ttn_dongunam_t28.csv',
#  'tk_ttn_dongunam_t29.csv',
#  'tk_ttn_dongunam_t3.csv',
#  'tk_ttn_dongunam_t30.csv',
#  'tk_ttn_dongunam_t31.csv',
#  'tk_ttn_dongunam_t32.csv',
#  'tk_ttn_dongunam_t33.csv',
#  'tk_ttn_dongunam_t4.csv',
#  'tk_ttn_dongunam_t5.csv',
#  'tk_ttn_dongunam_t6.csv',
#  'tk_ttn_dongunam_t7.csv',
#  'tk_ttn_dongunam_t8.csv',
#  'tk_ttn_dongunam_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dongu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Bộ Quần Áo Nỉ Nam 5S FASHION, Chất Cotton Mềm ...  718.000₫
# 1   Bộ Quần Áo Nỉ Nam Tay Dài 5S FASHION, Chất Liệ...  419.000₫
# 2   Bộ Quần Áo KaKi Lính Mỹ US ARMY U569 Kiểu Dáng...  836.000₫
# 3   Bộ quần áo thể thao nam Fasvin AB20274.HN cộc ...  229.000₫
# 4   Bộ thể thao nam Fasvin AB21452.HN chất vải mềm...  309.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  đồ bộ thể thao mặc nhà, đồ bộ dạo phố chất thu...   99.000₫
# 37  Bộ nam hè BỘ ĐỒ BỘ THỂ THAO NAM THUN 4 CHIỀU C...  100.000₫
# 38  Bộ đồ ngủ pijama nam tay ngắn sang trọng QSHOP...  300.000₫
# 39  Bộ đồ pijama nam quần dài, tay ngắn QSHOP QM71...   290.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=vl-SWDL-l...      1     -42%
# 1   https://tka.tiki.vn/pixel/pixel?data=smAD93Wvp...      2     -54%
# 2   https://tka.tiki.vn/pixel/pixel?data=7IBQBlwks...      3     -50%
# 3   https://tka.tiki.vn/pixel/pixel?data=caI8S_BNG...      4     -34%
# 4   https://tka.tiki.vn/pixel/pixel?data=Z6leD9fF4...      5     -44%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/bo-quan-ao-the-thao-nam-nu-p18...     36      NaN
# 36  https://tiki.vn/do-bo-the-thao-mac-nha-do-bo-d...     37      NaN
# 37  https://tiki.vn/product-p91281686.html?spid=10...     38      NaN
# 38  https://tiki.vn/bo-do-ngu-pijama-nam-tay-ngan-...     39      NaN
# 39  https://tiki.vn/bo-do-pijama-nam-quan-dai-tay-...     40      NaN
#
#         sales  category
# 0   Đã bán 13  dongunam
# 1    Đã bán 5  dongunam
# 2   Đã bán 12  dongunam
# 3   Đã bán 10  dongunam
# 4         NaN  dongunam
# ..        ...       ...
# 35        NaN  dongunam
# 36  Đã bán 39  dongunam
# 37   Đã bán 4  dongunam
# 38        NaN  dongunam
# 39        NaN  dongunam
#
# [1318 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Bộ Quần Áo Nỉ Nam 5S FASHION, Chất Cotton Mềm ...  718.000₫
# 1    Bộ Quần Áo Nỉ Nam Tay Dài 5S FASHION, Chất Liệ...  419.000₫
# 2    Bộ Quần Áo KaKi Lính Mỹ US ARMY U569 Kiểu Dáng...  836.000₫
# 3    Bộ quần áo thể thao nam Fasvin AB20274.HN cộc ...  229.000₫
# 4    Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...  250.000₫
# ..                                                 ...       ...
# 422           Bộ quần áo thể thao nam nữ in Hold Right   73.000₫
# 423  Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...  299.000₫
# 424  Quần Áo Lính Mỹ US ARMY Giá Rẻ - Quần Túi Hộp ...  480.000₫
# 425  đồ bộ thể thao mặc nhà, đồ bộ dạo phố chất thu...   99.000₫
# 426  Bộ nam hè BỘ ĐỒ BỘ THỂ THAO NAM THUN 4 CHIỀU C...  100.000₫
#
#                                              link_item discount      sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=vl-SWDL-l...     -42%  Đã bán 13
# 1    https://tka.tiki.vn/pixel/pixel?data=smAD93Wvp...     -54%   Đã bán 5
# 2    https://tka.tiki.vn/pixel/pixel?data=7IBQBlwks...     -50%  Đã bán 12
# 3    https://tka.tiki.vn/pixel/pixel?data=caI8S_BNG...     -34%  Đã bán 10
# 4    https://tiki.vn/bo-do-nam-aviano-4-mau-dai-tay...     -34%  Đã bán 14
# ..                                                 ...      ...        ...
# 422  https://tiki.vn/bo-quan-ao-the-thao-nam-nu-in-...      NaN   Đã bán 1
# 423  https://tiki.vn/bo-quan-ao-the-thao-nam-fasvin...      NaN   Đã bán 1
# 424  https://tiki.vn/quan-ao-linh-my-us-army-gia-re...      NaN   Đã bán 6
# 425  https://tiki.vn/do-bo-the-thao-mac-nha-do-bo-d...      NaN  Đã bán 39
# 426  https://tiki.vn/product-p91281686.html?spid=10...      NaN   Đã bán 4
#
#      category
# 0    dongunam
# 1    dongunam
# 2    dongunam
# 3    dongunam
# 4    dongunam
# ..        ...
# 422  dongunam
# 423  dongunam
# 424  dongunam
# 425  dongunam
# 426  dongunam
#
# [427 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      718000
# 1      419000
# 2      836000
# 3      229000
# 4      250000
#         ...
# 422     73000
# 423    299000
# 424    480000
# 425     99000
# 426    100000
# Name: price, Length: 427, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      13.0
# 1       5.0
# 2      12.0
# 3      10.0
# 4      14.0
#        ...
# 422     1.0
# 423     1.0
# 424     6.0
# 425    39.0
# 426     4.0
# Name: sales, Length: 427, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       9334000.0
# 1       2095000.0
# 2      10032000.0
# 3       2290000.0
# 4       3500000.0
#           ...
# 422       73000.0
# 423      299000.0
# 424     2880000.0
# 425     3861000.0
# 426      400000.0
# Name: revenue, Length: 427, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dongu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dongu:  1414326466.0
# So mat hang da ban:  427
# So san pham da ban:  7388.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Bộ Quần Áo Nỉ Nam 5S FASHION, Chất Cotton Mềm ...  718000
# 1    Bộ Quần Áo Nỉ Nam Tay Dài 5S FASHION, Chất Liệ...  419000
# 2    Bộ Quần Áo KaKi Lính Mỹ US ARMY U569 Kiểu Dáng...  836000
# 3    Bộ quần áo thể thao nam Fasvin AB20274.HN cộc ...  229000
# 4    Bộ Đồ Nam AVIANO 4 Màu Dài Tay, Bộ Thể Thao Na...  250000
# ..                                                 ...     ...
# 422           Bộ quần áo thể thao nam nữ in Hold Right   73000
# 423  Bộ quần áo thể thao nam Fasvin AB22494.HN mềm ...  299000
# 424  Quần Áo Lính Mỹ US ARMY Giá Rẻ - Quần Túi Hộp ...  480000
# 425  đồ bộ thể thao mặc nhà, đồ bộ dạo phố chất thu...   99000
# 426  Bộ nam hè BỘ ĐỒ BỘ THỂ THAO NAM THUN 4 CHIỀU C...  100000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=vl-SWDL-l...     -42%   13.0
# 1    https://tka.tiki.vn/pixel/pixel?data=smAD93Wvp...     -54%    5.0
# 2    https://tka.tiki.vn/pixel/pixel?data=7IBQBlwks...     -50%   12.0
# 3    https://tka.tiki.vn/pixel/pixel?data=caI8S_BNG...     -34%   10.0
# 4    https://tiki.vn/bo-do-nam-aviano-4-mau-dai-tay...     -34%   14.0
# ..                                                 ...      ...    ...
# 422  https://tiki.vn/bo-quan-ao-the-thao-nam-nu-in-...      NaN    1.0
# 423  https://tiki.vn/bo-quan-ao-the-thao-nam-fasvin...      NaN    1.0
# 424  https://tiki.vn/quan-ao-linh-my-us-army-gia-re...      NaN    6.0
# 425  https://tiki.vn/do-bo-the-thao-mac-nha-do-bo-d...      NaN   39.0
# 426  https://tiki.vn/product-p91281686.html?spid=10...      NaN    4.0
#
#      category     revenue
# 0    dongunam   9334000.0
# 1    dongunam   2095000.0
# 2    dongunam  10032000.0
# 3    dongunam   2290000.0
# 4    dongunam   3500000.0
# ..        ...         ...
# 422  dongunam     73000.0
# 423  dongunam    299000.0
# 424  dongunam   2880000.0
# 425  dongunam   3861000.0
# 426  dongunam    400000.0
#
# [427 rows x 7 columns]

# %%
df_all.to_csv("tk_dongu_all_ed.csv")
