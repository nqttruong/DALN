# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\thoitrangnu\dongu"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dongunu.csv',
#  'tk_dongu_all.ipynb',
#  'tk_ttn_dn.ipynb',
#  'tk_ttn_dn_npage.ipynb',
#  'tk_ttn_dongunu_t10.csv',
#  'tk_ttn_dongunu_t11.csv',
#  'tk_ttn_dongunu_t12.csv',
#  'tk_ttn_dongunu_t13.csv',
#  'tk_ttn_dongunu_t14.csv',
#  'tk_ttn_dongunu_t15.csv',
#  'tk_ttn_dongunu_t16.csv',
#  'tk_ttn_dongunu_t17.csv',
#  'tk_ttn_dongunu_t18.csv',
#  'tk_ttn_dongunu_t19.csv',
#  'tk_ttn_dongunu_t2.csv',
#  'tk_ttn_dongunu_t20.csv',
#  'tk_ttn_dongunu_t21.csv',
#  'tk_ttn_dongunu_t22.csv',
#  'tk_ttn_dongunu_t23.csv',
#  'tk_ttn_dongunu_t24.csv',
#  'tk_ttn_dongunu_t25.csv',
#  'tk_ttn_dongunu_t26.csv',
#  'tk_ttn_dongunu_t27.csv',
#  'tk_ttn_dongunu_t28.csv',
#  'tk_ttn_dongunu_t29.csv',
#  'tk_ttn_dongunu_t3.csv',
#  'tk_ttn_dongunu_t30.csv',
#  'tk_ttn_dongunu_t31.csv',
#  'tk_ttn_dongunu_t32.csv',
#  'tk_ttn_dongunu_t33.csv',
#  'tk_ttn_dongunu_t34.csv',
#  'tk_ttn_dongunu_t35.csv',
#  'tk_ttn_dongunu_t36.csv',
#  'tk_ttn_dongunu_t37.csv',
#  'tk_ttn_dongunu_t38.csv',
#  'tk_ttn_dongunu_t39.csv',
#  'tk_ttn_dongunu_t4.csv',
#  'tk_ttn_dongunu_t40.csv',
#  'tk_ttn_dongunu_t41.csv',
#  'tk_ttn_dongunu_t42.csv',
#  'tk_ttn_dongunu_t43.csv',
#  'tk_ttn_dongunu_t44.csv',
#  'tk_ttn_dongunu_t45.csv',
#  'tk_ttn_dongunu_t46.csv',
#  'tk_ttn_dongunu_t47.csv',
#  'tk_ttn_dongunu_t48.csv',
#  'tk_ttn_dongunu_t49.csv',
#  'tk_ttn_dongunu_t5.csv',
#  'tk_ttn_dongunu_t50.csv',
#  'tk_ttn_dongunu_t6.csv',
#  'tk_ttn_dongunu_t7.csv',
#  'tk_ttn_dongunu_t8.csv',
#  'tk_ttn_dongunu_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dongu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Set Váy Ngủ Cosplay Bikini Sexy Gợi Cảm Độc Lạ...  219.000₫
# 1   Set Váy Ngủ Lưới Mỏng Ren Áo Choàng Ngủ Sexy 3...  179.000₫
# 2   Set Váy Ngủ Live-action Cosplay Bikini Sexy Gợ...  169.000₫
# 3   Váy ngủ nữ lụa hở lưng sexy Q60 - Đầm ngủ nữ q...  149.000₫
# 4   Váy ngủ bodysuit ren sexy cao cấp Q426 - Đồ ng...  190.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Bộ Đồ Ngủ Nữ Lụa Satin Có Mút Ngực Phối Ren Ca...  115.000₫
# 37  Váy ngủ sexy lụa cổ đổ hở lưng Q151 - Đầm ngủ ...  189.000₫
# 38        Bộ đồ pijama nữ quần dài và áo tay dài C093  157.000₫
# 39  Váy ngủ cosplay xuyên thấu hở lưng kèm chip lọ...   179.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=P31CzifTg...      1     -50%
# 1   https://tka.tiki.vn/pixel/pixel?data=pH3-FUMUr...      2     -50%
# 2   https://tka.tiki.vn/pixel/pixel?data=4QEqNcTPE...      3     -50%
# 3   https://tka.tiki.vn/pixel/pixel?data=-ppUX-t08...      4     -35%
# 4   https://tka.tiki.vn/pixel/pixel?data=kqt4GCYQS...      5     -52%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/do-bo-lung-mac-nha-cao-cap-kho...     36      NaN
# 36  https://tiki.vn/bo-do-ngu-nu-lua-satin-co-mut-...     37      NaN
# 37  https://tiki.vn/vay-ngu-sexy-lua-co-do-ho-lung...     38      NaN
# 38  https://tiki.vn/bo-do-pijama-nu-quan-dai-va-ao...     39      NaN
# 39  https://tiki.vn/vay-ngu-cosplay-xuyen-thau-ho-...     40      NaN
#
#          sales category
# 0     Đã bán 2  dongunu
# 1    Đã bán 80  dongunu
# 2     Đã bán 3  dongunu
# 3    Đã bán 40  dongunu
# 4    Đã bán 48  dongunu
# ..         ...      ...
# 35         NaN  dongunu
# 36   Đã bán 12  dongunu
# 37         NaN  dongunu
# 38  Đã bán 113  dongunu
# 39         NaN  dongunu
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Set Váy Ngủ Cosplay Bikini Sexy Gợi Cảm Độc Lạ...  219.000₫
# 1     Set Váy Ngủ Lưới Mỏng Ren Áo Choàng Ngủ Sexy 3...  179.000₫
# 2     Set Váy Ngủ Live-action Cosplay Bikini Sexy Gợ...  169.000₫
# 3     Váy ngủ nữ lụa hở lưng sexy Q60 - Đầm ngủ nữ q...  149.000₫
# 4     Váy ngủ bodysuit ren sexy cao cấp Q426 - Đồ ng...  190.000₫
# ...                                                 ...       ...
# 997   Bộ Mặc Nhà - Đồ Bộ Ngủ Nữ Chất Thun Cotton Dài...  189.000₫
# 998   Đồ Bộ Pijama Nữ , Đồ Bộ Mặc Nhà Nữ Tay Ngắn, Q...  237.000₫
# 999   Váy Ngủ Nữ họa tiết hoạt hình dễ thương xinh x...   99.000₫
# 1000  Bộ Đồ Ngủ Nữ Lụa Satin Có Mút Ngực Phối Ren Ca...  115.000₫
# 1001        Bộ đồ pijama nữ quần dài và áo tay dài C093  157.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=P31CzifTg...     -50%    Đã bán 2
# 1     https://tka.tiki.vn/pixel/pixel?data=pH3-FUMUr...     -50%   Đã bán 80
# 2     https://tka.tiki.vn/pixel/pixel?data=4QEqNcTPE...     -50%    Đã bán 3
# 3     https://tka.tiki.vn/pixel/pixel?data=-ppUX-t08...     -35%   Đã bán 40
# 4     https://tka.tiki.vn/pixel/pixel?data=kqt4GCYQS...     -52%   Đã bán 48
# ...                                                 ...      ...         ...
# 997   https://tiki.vn/bo-mac-nha-freeship-do-bo-ngu-...      NaN    Đã bán 8
# 998   https://tiki.vn/do-bo-pijama-nu-do-bo-mac-nha-...      NaN  Đã bán 305
# 999   https://tiki.vn/vay-ngu-nu-hoa-tiet-hoat-hinh-...      NaN    Đã bán 2
# 1000  https://tiki.vn/bo-do-ngu-nu-lua-satin-co-mut-...      NaN   Đã bán 12
# 1001  https://tiki.vn/bo-do-pijama-nu-quan-dai-va-ao...      NaN  Đã bán 113
#
#      category
# 0     dongunu
# 1     dongunu
# 2     dongunu
# 3     dongunu
# 4     dongunu
# ...       ...
# 997   dongunu
# 998   dongunu
# 999   dongunu
# 1000  dongunu
# 1001  dongunu
#
# [1002 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       219000
# 1       179000
# 2       169000
# 3       149000
# 4       190000
#          ...
# 997     189000
# 998     237000
# 999      99000
# 1000    115000
# 1001    157000
# Name: price, Length: 1002, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0         2.0
# 1        80.0
# 2         3.0
# 3        40.0
# 4        48.0
#         ...
# 997       8.0
# 998     305.0
# 999       2.0
# 1000     12.0
# 1001    113.0
# Name: sales, Length: 1002, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0         438000.0
# 1       14320000.0
# 2         507000.0
# 3        5960000.0
# 4        9120000.0
#            ...
# 997      1512000.0
# 998     72285000.0
# 999       198000.0
# 1000     1380000.0
# 1001    17741000.0
# Name: revenue, Length: 1002, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dongu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dongu:  3128852270.0
# So mat hang da ban:  1002
# So san pham da ban:  20996.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Set Váy Ngủ Cosplay Bikini Sexy Gợi Cảm Độc Lạ...  219000
# 1     Set Váy Ngủ Lưới Mỏng Ren Áo Choàng Ngủ Sexy 3...  179000
# 2     Set Váy Ngủ Live-action Cosplay Bikini Sexy Gợ...  169000
# 3     Váy ngủ nữ lụa hở lưng sexy Q60 - Đầm ngủ nữ q...  149000
# 4     Váy ngủ bodysuit ren sexy cao cấp Q426 - Đồ ng...  190000
# ...                                                 ...     ...
# 997   Bộ Mặc Nhà - Đồ Bộ Ngủ Nữ Chất Thun Cotton Dài...  189000
# 998   Đồ Bộ Pijama Nữ , Đồ Bộ Mặc Nhà Nữ Tay Ngắn, Q...  237000
# 999   Váy Ngủ Nữ họa tiết hoạt hình dễ thương xinh x...   99000
# 1000  Bộ Đồ Ngủ Nữ Lụa Satin Có Mút Ngực Phối Ren Ca...  115000
# 1001        Bộ đồ pijama nữ quần dài và áo tay dài C093  157000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=P31CzifTg...     -50%    2.0
# 1     https://tka.tiki.vn/pixel/pixel?data=pH3-FUMUr...     -50%   80.0
# 2     https://tka.tiki.vn/pixel/pixel?data=4QEqNcTPE...     -50%    3.0
# 3     https://tka.tiki.vn/pixel/pixel?data=-ppUX-t08...     -35%   40.0
# 4     https://tka.tiki.vn/pixel/pixel?data=kqt4GCYQS...     -52%   48.0
# ...                                                 ...      ...    ...
# 997   https://tiki.vn/bo-mac-nha-freeship-do-bo-ngu-...      NaN    8.0
# 998   https://tiki.vn/do-bo-pijama-nu-do-bo-mac-nha-...      NaN  305.0
# 999   https://tiki.vn/vay-ngu-nu-hoa-tiet-hoat-hinh-...      NaN    2.0
# 1000  https://tiki.vn/bo-do-ngu-nu-lua-satin-co-mut-...      NaN   12.0
# 1001  https://tiki.vn/bo-do-pijama-nu-quan-dai-va-ao...      NaN  113.0
#
#      category     revenue
# 0     dongunu    438000.0
# 1     dongunu  14320000.0
# 2     dongunu    507000.0
# 3     dongunu   5960000.0
# 4     dongunu   9120000.0
# ...       ...         ...
# 997   dongunu   1512000.0
# 998   dongunu  72285000.0
# 999   dongunu    198000.0
# 1000  dongunu   1380000.0
# 1001  dongunu  17741000.0
#
# [1002 rows x 7 columns]

# %%
df_all.to_csv("tk_dongu_all_ed.csv")
