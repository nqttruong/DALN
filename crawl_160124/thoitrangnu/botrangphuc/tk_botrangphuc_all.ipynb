# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\thoitrangnu\botrangphuc"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_botrangphuc.csv',
#  'tk_botrangphuc_all.ipynb',
#  'tk_ttn_botrangphuc_t10.csv',
#  'tk_ttn_botrangphuc_t11.csv',
#  'tk_ttn_botrangphuc_t12.csv',
#  'tk_ttn_botrangphuc_t13.csv',
#  'tk_ttn_botrangphuc_t14.csv',
#  'tk_ttn_botrangphuc_t15.csv',
#  'tk_ttn_botrangphuc_t16.csv',
#  'tk_ttn_botrangphuc_t17.csv',
#  'tk_ttn_botrangphuc_t18.csv',
#  'tk_ttn_botrangphuc_t19.csv',
#  'tk_ttn_botrangphuc_t2.csv',
#  'tk_ttn_botrangphuc_t20.csv',
#  'tk_ttn_botrangphuc_t21.csv',
#  'tk_ttn_botrangphuc_t22.csv',
#  'tk_ttn_botrangphuc_t23.csv',
#  'tk_ttn_botrangphuc_t24.csv',
#  'tk_ttn_botrangphuc_t25.csv',
#  'tk_ttn_botrangphuc_t26.csv',
#  'tk_ttn_botrangphuc_t27.csv',
#  'tk_ttn_botrangphuc_t28.csv',
#  'tk_ttn_botrangphuc_t29.csv',
#  'tk_ttn_botrangphuc_t3.csv',
#  'tk_ttn_botrangphuc_t30.csv',
#  'tk_ttn_botrangphuc_t31.csv',
#  'tk_ttn_botrangphuc_t32.csv',
#  'tk_ttn_botrangphuc_t33.csv',
#  'tk_ttn_botrangphuc_t34.csv',
#  'tk_ttn_botrangphuc_t35.csv',
#  'tk_ttn_botrangphuc_t36.csv',
#  'tk_ttn_botrangphuc_t37.csv',
#  'tk_ttn_botrangphuc_t38.csv',
#  'tk_ttn_botrangphuc_t39.csv',
#  'tk_ttn_botrangphuc_t4.csv',
#  'tk_ttn_botrangphuc_t40.csv',
#  'tk_ttn_botrangphuc_t41.csv',
#  'tk_ttn_botrangphuc_t42.csv',
#  'tk_ttn_botrangphuc_t43.csv',
#  'tk_ttn_botrangphuc_t44.csv',
#  'tk_ttn_botrangphuc_t45.csv',
#  'tk_ttn_botrangphuc_t46.csv',
#  'tk_ttn_botrangphuc_t47.csv',
#  'tk_ttn_botrangphuc_t48.csv',
#  'tk_ttn_botrangphuc_t49.csv',
#  'tk_ttn_botrangphuc_t5.csv',
#  'tk_ttn_botrangphuc_t50.csv',
#  'tk_ttn_botrangphuc_t6.csv',
#  'tk_ttn_botrangphuc_t7.csv',
#  'tk_ttn_botrangphuc_t8.csv',
#  'tk_ttn_botrangphuc_t9.csv',
#  'tk_ttn_btp.ipynb',
#  'tk_ttn_btp_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_botrangphuc_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   [MẪU MỚI] Set Đồ Nữ Đi Chơi QuDu Vải Không Nhă...  499.000₫
# 1   Bộ mặc nhà cho người già, quần áo phụ nữ trung...  107.000₫
# 2                              TÚI NHÍ 2 ĐI CHÙA # Bị   25.000₫
# 3         ĐỒ LAM CHO BÉ IU # Mẫu Bé Vạt Hò In Hoa Sen   
rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      107000
# 1       25000
# 2       80000
# 3       73000
# 4      155000
#         ...
# 575    170000
# 576    524000
# 577    450000
# 578    300000
# 579    104500
# Name: price, Length: 580, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      11.0
# 1      72.0
# 2       3.0
# 3       3.0
# 4       4.0
#        ...
# 575     1.0
# 576     1.0
# 577     1.0
# 578     2.0
# 579     1.0
# Name: sales, Length: 580, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      1177000.0
# 1      1800000.0
# 2       240000.0
# 3       219000.0
# 4       620000.0
#          ...
# 575     170000.0
# 576     524000.0
# 577     450000.0
# 578     600000.0
# 579     104500.0
# Name: revenue, Length: 580, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số botrangphuc: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số botrangphuc:  1160783338.0
# So mat hang da ban:  580
# So san pham da ban:  5165.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Bộ mặc nhà cho người già, quần áo phụ nữ trung...  107000
# 1                               TÚI NHÍ 2 ĐI CHÙA # Bị   25000
# 2          ĐỒ LAM CHO BÉ IU # Mẫu Bé Vạt Hò In Hoa Sen   80000
# 3    Mẫu Cho Bé iu # La Hán Cho Bé# Quần Áo Bé # Đồ...   73000
# 4                 Đồ Lam Đi Chùa # Cổ Tàu Viền # Đồ Bộ  155000
# ..                                                 ...     ...
# 575                                 Jumpsuit F21(2121)  170000
# 576  Áo Dài Thêu Truyền Thống Lụa Tô Châu Cao Cấp -...  524000
# 577           ÁO DÀI MAY SẴN VẢI GẤM ĐỎ ĐẬM - ẢNH THẬT  450000
# 578      Cosplay trang phục cô gái cổ trang Trung Quốc  300000
# 579  Đồ Bộ Thun Lửng Cho Mẹ Cho Bà Đồ Thun Lửng Bà ...  104500
#
#                                              link_item discount  sales  \
# 0    https://tiki.vn/bo-mac-nha-cho-nguoi-gia-quan-...      -5%   11.0
# 1    https://tiki.vn/tui-nhi-2-di-chua-bi-p25410894...     -67%   72.0
# 2    https://tiki.vn/do-lam-cho-be-iu-mau-be-vat-ho...     -50%    3.0
# 3    https://tiki.vn/mau-cho-be-iu-la-han-cho-be-qu...     -46%    3.0
# 4    https://tiki.vn/do-lam-di-chua-co-tau-vien-do-...     -36%    4.0
# ..                                                 ...      ...    ...
# 575  https://tiki.vn/jumpsuit-f21-2121-p105925176.h...      NaN    1.0
# 576  https://tiki.vn/ao-dai-theu-truyen-thong-lua-t...      NaN    1.0
# 577  https://tiki.vn/ao-dai-may-san-vai-gam-do-dam-...      NaN    1.0
# 578  https://tiki.vn/cosplay-trang-phuc-co-gai-co-t...      NaN    2.0
# 579  https://tiki.vn/do-bo-thun-lung-cho-me-cho-ba-...      NaN    1.0
#
#         category    revenue
# 0    botrangphuc  1177000.0
# 1    botrangphuc  1800000.0
# 2    botrangphuc   240000.0
# 3    botrangphuc   219000.0
# 4    botrangphuc   620000.0
# ..           ...        ...
# 575  botrangphuc   170000.0
# 576  botrangphuc   524000.0
# 577  botrangphuc   450000.0
# 578  botrangphuc   600000.0
# 579  botrangphuc   104500.0
#
# [580 rows x 7 columns]

# %%
df_all.to_csv("tk_botrangphuc_all_ed.csv")
