# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_160124(12hdem)\thoitrangnu"
os.listdir(path)
# Out:
# ['aokhoacnu',
#  'aonu',
#  'botrangphuc',
#  'brand',
#  'category.ipynb',
#  'chanvay',
#  'damnu',
#  'doboi',
#  'dodoi',
#  'dolot',
#  'dongu',
#  'quannu',
#  'thoitrangbau',
#  'thoitrangtrungnien',
#  'tk_aokhoacnu_all_ed.csv',
#  'tk_aonu_all_ed.csv',
#  'tk_botrangphuc_all_ed.csv',
#  'tk_chanvay_all_ed.csv',
#  'tk_damnu_all_ed.csv',
#  'tk_doboinu_all_ed.csv',
#  'tk_dodoinu_all_ed.csv',
#  'tk_dolotnu_all_ed.csv',
#  'tk_dongunu_all_ed.csv',
#  'tk_quannu_all_ed.csv',
#  'tk_thoitrangbau_all_ed.csv',
#  'tk_thoitrangtrungnien_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#      Unnamed: 0                                              title   price  \
# 0             0  Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235000
# 1             1  Áo khoác gió cách nhiệt GOKING, form unisex ch...  235000
# 2             2  Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255000
# 3             3  Áo Hoodie Trơn Màu Xanh Dương Cao Cấp Dáng Rộn...  120000
# 4             4  Áo Sweater Trơn Chất Nỉ Lót Bông - Sweater Uni...  109000
# ..          ...                                                ...     ...
# 208         208  ÁO VOAN NỮ TRUNG NIÊN CHO BÀ CHO ME-ÁO NỮ TRUN...  218900
# 209         209             BỘ MẶC NHÀ TRUNG NIÊN NỮ CHO BÀ CHO MẸ  108900
# 210         210     ÁO NỮ TRUNG NIÊN_ÁO KIỂU TRUNG NIÊN SANG TRỌNG  199000
# 211         211  Đầm xòe thiết kế trung niên cao cấp sang trọng...  480000
# 212         212  Đầm xòe thiết kế trung niên sang trọng quý phá...  485000
#
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "thoitrangnu")

# %%
df
# Out:
#                                                  title   price  \
# 0    Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235000
# 1    Áo khoác gió cách nhiệt GOKING, form unisex ch...  235000
# 2    Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255000
# 3    Áo Hoodie Trơn Màu Xanh Dương Cao Cấp Dáng Rộn...  120000
# 4    Áo Sweater Trơn Chất Nỉ Lót Bông - Sweater Uni...  109000
# ..                                                 ...     ...
# 208  ÁO VOAN NỮ TRUNG NIÊN CHO BÀ CHO ME-ÁO NỮ TRUN...  218900
# 209             BỘ MẶC NHÀ TRUNG NIÊN NỮ CHO BÀ CHO MẸ  108900
# 210     ÁO NỮ TRUNG NIÊN_ÁO KIỂU TRUNG NIÊN SANG TRỌNG  199000
# 211  Đầm xòe thiết kế trung niên cao cấp sang trọng...  480000
# 212  Đầm xòe thiết kế trung niên sang trọng quý phá...  485000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=t57dKt_8l...     -44%   80.0
# ...

# %%
df.to_csv('tk_thoitrangnu_all_ed.csv', index=False, encoding='utf-8')
