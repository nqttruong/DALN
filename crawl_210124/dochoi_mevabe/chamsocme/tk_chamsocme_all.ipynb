# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12hdem) - Copy\dochoi_mevabe\chamsocme"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_chamsocme.csv',
#  'tk_chamsocme_all.ipynb',
#  'tk_chamsocme_t10.csv',
#  'tk_chamsocme_t11.csv',
#  'tk_chamsocme_t12.csv',
#  'tk_chamsocme_t13.csv',
#  'tk_chamsocme_t14.csv',
#  'tk_chamsocme_t15.csv',
#  'tk_chamsocme_t16.csv',
#  'tk_chamsocme_t17.csv',
#  'tk_chamsocme_t18.csv',
#  'tk_chamsocme_t19.csv',
#  'tk_chamsocme_t2.csv',
#  'tk_chamsocme_t20.csv',
#  'tk_chamsocme_t21.csv',
#  'tk_chamsocme_t22.csv',
#  'tk_chamsocme_t23.csv',
#  'tk_chamsocme_t24.csv',
#  'tk_chamsocme_t25.csv',
#  'tk_chamsocme_t26.csv',
#  'tk_chamsocme_t27.csv',
#  'tk_chamsocme_t28.csv',
#  'tk_chamsocme_t29.csv',
#  'tk_chamsocme_t3.csv',
#  'tk_chamsocme_t30.csv',
#  'tk_chamsocme_t31.csv',
#  'tk_chamsocme_t32.csv',
#  'tk_chamsocme_t33.csv',
#  'tk_chamsocme_t34.csv',
#  'tk_chamsocme_t35.csv',
#  'tk_chamsocme_t36.csv',
#  'tk_chamsocme_t37.csv',
#  'tk_chamsocme_t38.csv',
#  'tk_chamsocme_t39.csv',
#  'tk_chamsocme_t4.csv',
#  'tk_chamsocme_t40.csv',
#  'tk_chamsocme_t41.csv',
#  'tk_chamsocme_t42.csv',
#  'tk_chamsocme_t43.csv',
#  'tk_chamsocme_t44.csv',
#  'tk_chamsocme_t45.csv',
#  'tk_chamsocme_t46.csv',
#  'tk_chamsocme_t47.csv',
#  'tk_chamsocme_t48.csv',
#  'tk_chamsocme_t49.csv',
#  'tk_chamsocme_t5.csv',
#  'tk_chamsocme_t50.csv',
#  'tk_chamsocme_t6.csv',
#  'tk_chamsocme_t7.csv',
#  'tk_chamsocme_t8.csv',
#  'tk_chamsocme_t9.csv',
#  'tk_mvb_chamsocme.ipynb',
#  'tk_mvb_chamsocme_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_chamsocme_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Kem nghệ tươi dưỡng da trắng mịn, sạch sạm nám...  242.000₫
# 1   Combo dưỡng trắng body và săn chắc eo sau sinh...  410.000₫
# 2   Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...  182.000₫
# 3   Muối ngâm chân thảo mộc giảm đau nhức, chống s...   85.500₫
# 4   Cốt gừng hạ thổ săn chắc eo sau sinh Wonmom 200ml  220.000₫
# ..                                                ...       ...
# 35  Máy Hút Sữa Điện Đôi ICHIKO Nhật Bản M5 (Massa...  600.000₫
# 36  Dầu gội cốt bồ kết đánh bay gàu, mọc tóc, dưỡn...  132.000₫
# 37  Lá xông, thơm tho cơ thể mẹ sau sinh, lưu thôn...   45.240₫
# 38  Quần lót bầu và sau sinh cạp chéo chất SU ĐÚC ...   29.000₫
# 39  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...  165.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=1AVqMj9z8...      1     -12%
# 1   https://tka.tiki.vn/pixel/pixel?data=pUBwivPtl...      2     -18%
# 2   https://tka.tiki.vn/pixel/pixel?data=8xOkKVkQE...      3     -17%
# 3   https://tka.tiki.vn/pixel/pixel?data=wzpVSd1vS...      4     -10%
# 4   https://tka.tiki.vn/pixel/pixel?data=VFW8E9dQe...      5     -12%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/may-hut-sua-dien-doi-ichiko-nh...     36      NaN
# 36  https://tiki.vn/dau-goi-cot-bo-ket-danh-bay-ga...     37      NaN
# 37  https://tiki.vn/la-xong-thom-tho-co-the-me-sau...     38      NaN
# 38  https://tiki.vn/quan-lot-bau-va-sau-sinh-cap-c...     39      NaN
# 39  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...     40      NaN
#
#          sales   category
# 0   Đã bán 592  chamsocme
# 1     Đã bán 9  chamsocme
# 2   Đã bán 183  chamsocme
# 3   Đã bán 677  chamsocme
# 4    Đã bán 55  chamsocme
# ..         ...        ...
# 35   Đã bán 93  chamsocme
# 36   Đã bán 65  chamsocme
# 37  Đã bán 224  chamsocme
# 38   Đã bán 40  chamsocme
# 39   Đã bán 13  chamsocme
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Kem nghệ tươi dưỡng da trắng mịn, sạch sạm nám...  242.000₫
# 1     Combo dưỡng trắng body và săn chắc eo sau sinh...  410.000₫
# 2     Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...  182.000₫
# 3     Muối ngâm chân thảo mộc giảm đau nhức, chống s...   85.500₫
# 4     Cốt gừng hạ thổ săn chắc eo sau sinh Wonmom 200ml  220.000₫
# ...                                                 ...       ...
# 1224  Máy Hút Sữa Điện Đôi ICHIKO Nhật Bản M5 (Massa...  600.000₫
# 1225  Dầu gội cốt bồ kết đánh bay gàu, mọc tóc, dưỡn...  132.000₫
# 1226  Lá xông, thơm tho cơ thể mẹ sau sinh, lưu thôn...   45.240₫
# 1227  Quần lót bầu và sau sinh cạp chéo chất SU ĐÚC ...   29.000₫
# 1228  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...  165.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=1AVqMj9z8...     -12%  Đã bán 592
# 1     https://tka.tiki.vn/pixel/pixel?data=pUBwivPtl...     -18%    Đã bán 9
# 2     https://tka.tiki.vn/pixel/pixel?data=8xOkKVkQE...     -17%  Đã bán 183
# 3     https://tka.tiki.vn/pixel/pixel?data=wzpVSd1vS...     -10%  Đã bán 677
# 4     https://tka.tiki.vn/pixel/pixel?data=VFW8E9dQe...     -12%   Đã bán 55
# ...                                                 ...      ...         ...
# 1224  https://tiki.vn/may-hut-sua-dien-doi-ichiko-nh...      NaN   Đã bán 93
# 1225  https://tiki.vn/dau-goi-cot-bo-ket-danh-bay-ga...      NaN   Đã bán 65
# 1226  https://tiki.vn/la-xong-thom-tho-co-the-me-sau...      NaN  Đã bán 224
# 1227  https://tiki.vn/quan-lot-bau-va-sau-sinh-cap-c...      NaN   Đã bán 40
# 1228  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...      NaN   Đã bán 13
#
#        category
# 0     chamsocme
# 1     chamsocme
# 2     chamsocme
# 3     chamsocme
# 4     chamsocme
# ...         ...
# 1224  chamsocme
# 1225  chamsocme
# 1226  chamsocme
# 1227  chamsocme
# 1228  chamsocme
#
# [1229 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       242000
# 1       410000
# 2       182000
# 3        85500
# 4       220000
#          ...
# 1224    600000
# 1225    132000
# 1226     45240
# 1227     29000
# 1228    165000
# Name: price, Length: 1229, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       592.0
# 1         9.0
# 2       183.0
# 3       677.0
# 4        55.0
#         ...
# 1224     93.0
# 1225     65.0
# 1226    224.0
# 1227     40.0
# 1228     13.0
# Name: sales, Length: 1229, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       143264000.0
# 1         3690000.0
# 2        33306000.0
# 3        57883500.0
# 4        12100000.0
#            ...
# 1224     55800000.0
# 1225      8580000.0
# 1226     10133760.0
# 1227      1160000.0
# 1228      2145000.0
# Name: revenue, Length: 1229, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chamsocme: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số chamsocme:  13650119138.0
# So mat hang da ban:  1229
# So san pham da ban:  53557.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Kem nghệ tươi dưỡng da trắng mịn, sạch sạm nám...  242000
# 1     Combo dưỡng trắng body và săn chắc eo sau sinh...  410000
# 2     Gừng toàn thân hạ thổ giữ ấm cơ thể, lưu thông...  182000
# 3     Muối ngâm chân thảo mộc giảm đau nhức, chống s...   85500
# 4     Cốt gừng hạ thổ săn chắc eo sau sinh Wonmom 200ml  220000
# ...                                                 ...     ...
# 1224  Máy Hút Sữa Điện Đôi ICHIKO Nhật Bản M5 (Massa...  600000
# 1225  Dầu gội cốt bồ kết đánh bay gàu, mọc tóc, dưỡn...  132000
# 1226  Lá xông, thơm tho cơ thể mẹ sau sinh, lưu thôn...   45240
# 1227  Quần lót bầu và sau sinh cạp chéo chất SU ĐÚC ...   29000
# 1228  Balo bỉm sữa ĐA NĂNG có túi đựng đồ giữ nhiệt ...  165000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=1AVqMj9z8...     -12%  592.0
# 1     https://tka.tiki.vn/pixel/pixel?data=pUBwivPtl...     -18%    9.0
# 2     https://tka.tiki.vn/pixel/pixel?data=8xOkKVkQE...     -17%  183.0
# 3     https://tka.tiki.vn/pixel/pixel?data=wzpVSd1vS...     -10%  677.0
# 4     https://tka.tiki.vn/pixel/pixel?data=VFW8E9dQe...     -12%   55.0
# ...                                                 ...      ...    ...
# 1224  https://tiki.vn/may-hut-sua-dien-doi-ichiko-nh...      NaN   93.0
# 1225  https://tiki.vn/dau-goi-cot-bo-ket-danh-bay-ga...      NaN   65.0
# 1226  https://tiki.vn/la-xong-thom-tho-co-the-me-sau...      NaN  224.0
# 1227  https://tiki.vn/quan-lot-bau-va-sau-sinh-cap-c...      NaN   40.0
# 1228  https://tiki.vn/balo-bim-sua-da-nang-co-tui-du...      NaN   13.0
#
#        category      revenue
# 0     chamsocme  143264000.0
# 1     chamsocme    3690000.0
# 2     chamsocme   33306000.0
# 3     chamsocme   57883500.0
# 4     chamsocme   12100000.0
# ...         ...          ...
# 1224  chamsocme   55800000.0
# 1225  chamsocme    8580000.0
# 1226  chamsocme   10133760.0
# 1227  chamsocme    1160000.0
# 1228  chamsocme    2145000.0
#
# [1229 rows x 7 columns]

# %%
df_all.to_csv("tk_chamsocme_all_ed.csv")
