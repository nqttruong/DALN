# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12hdem) - Copy\dochoi_mevabe\tabim"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_mvb_tabim.ipynb',
#  'tk_mvb_tabim_npage.ipynb',
#  'tk_tabim_all.ipynb',
#  'tk_tabim_t1.csv',
#  'tk_tabim_t10.csv',
#  'tk_tabim_t11.csv',
#  'tk_tabim_t12.csv',
#  'tk_tabim_t13.csv',
#  'tk_tabim_t14.csv',
#  'tk_tabim_t15.csv',
#  'tk_tabim_t16.csv',
#  'tk_tabim_t17.csv',
#  'tk_tabim_t18.csv',
#  'tk_tabim_t19.csv',
#  'tk_tabim_t2.csv',
#  'tk_tabim_t20.csv',
#  'tk_tabim_t21.csv',
#  'tk_tabim_t22.csv',
#  'tk_tabim_t23.csv',
#  'tk_tabim_t24.csv',
#  'tk_tabim_t25.csv',
#  'tk_tabim_t26.csv',
#  'tk_tabim_t27.csv',
#  'tk_tabim_t28.csv',
#  'tk_tabim_t29.csv',
#  'tk_tabim_t3.csv',
#  'tk_tabim_t30.csv',
#  'tk_tabim_t31.csv',
#  'tk_tabim_t32.csv',
#  'tk_tabim_t33.csv',
#  'tk_tabim_t34.csv',
#  'tk_tabim_t35.csv',
#  'tk_tabim_t36.csv',
#  'tk_tabim_t37.csv',
#  'tk_tabim_t38.csv',
#  'tk_tabim_t39.csv',
#  'tk_tabim_t4.csv',
#  'tk_tabim_t40.csv',
#  'tk_tabim_t41.csv',
#  'tk_tabim_t42.csv',
#  'tk_tabim_t43.csv',
#  'tk_tabim_t44.csv',
#  'tk_tabim_t45.csv',
#  'tk_tabim_t46.csv',
#  'tk_tabim_t47.csv',
#  'tk_tabim_t48.csv',
#  'tk_tabim_t49.csv',
#  'tk_tabim_t5.csv',
#  'tk_tabim_t50.csv',
#  'tk_tabim_t6.csv',
#  'tk_tabim_t7.csv',
#  'tk_tabim_t8.csv',
#  'tk_tabim_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_tabim_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Tã - Bỉm người lớn Livedo size L (22 cái/ gói)...  730.000₫
# 1   Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185.000₫
# 2   Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385.000₫
# 3    Tã - Bỉm quần người lớn Livedo size L - Nhật Bản  730.000₫
# 4   Tã/bỉm quần HUGGIES SKINCARE gói SUPER JUMBO s...  309.000₫
# ..                                                ...       ...
# 35  Bộ 10 Cái Tã Vải Sơ Sinh Cho Bé ( màu ngẫu nhi...   59.800₫
# 36  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273.000₫
# 37  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275.000₫
# 38  Khăn giấy ướt vịt vàng 10 gói kèm thùng nhựa t...   84.781₫
# 39       Tã Dán Cao Cấp Moony Nhật Bản S84 (84 Miếng)  287.500₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=90ZuoL0r3...      1     -34%
# 1   https://tka.tiki.vn/pixel/pixel?data=v1rrh9qa0...      2     -40%
# 2   https://tka.tiki.vn/pixel/pixel?data=8PuFXIg9A...      3     -35%
# 3   https://tka.tiki.vn/pixel/pixel?data=ixK8UNSqg...      4     -40%
# 4   https://tka.tiki.vn/pixel/pixel?data=wV75I5RBc...      5     -38%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/bo-10-cai-ta-vai-so-sinh-nhieu...     36      NaN
# 36  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...     37      NaN
# 37  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...     38      NaN
# 38  https://tiki.vn/khan-giay-uot-vit-vang-10-goi-...     39      NaN
# 39  https://tiki.vn/ta-dan-cao-cap-moony-nhat-ban-...     40      NaN
#
#           sales category
# 0     Đã bán 12    tabim
# 1    Đã bán 5k+    tabim
# 2    Đã bán 5k+    tabim
# 3     Đã bán 55    tabim
# 4   Đã bán 2.5k    tabim
# ..          ...      ...
# 35    Đã bán 60    tabim
# 36   Đã bán 217    tabim
# 37   Đã bán 189    tabim
# 38    Đã bán 11    tabim
# 39   Đã bán 238    tabim
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Tã - Bỉm người lớn Livedo size L (22 cái/ gói)...  730.000₫
# 1     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185.000₫
# 2     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385.000₫
# 3      Tã - Bỉm quần người lớn Livedo size L - Nhật Bản  730.000₫
# 4     Tã/bỉm quần HUGGIES SKINCARE gói SUPER JUMBO s...  309.000₫
# ...                                                 ...       ...
# 1422  Bộ 10 Cái Tã Vải Sơ Sinh Cho Bé ( màu ngẫu nhi...   59.800₫
# 1423  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273.000₫
# 1424  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275.000₫
# 1425  Khăn giấy ướt vịt vàng 10 gói kèm thùng nhựa t...   84.781₫
# 1426       Tã Dán Cao Cấp Moony Nhật Bản S84 (84 Miếng)  287.500₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=90ZuoL0r3...     -34%    Đã bán 12
# 1     https://tka.tiki.vn/pixel/pixel?data=v1rrh9qa0...     -40%   Đã bán 5k+
# 2     https://tka.tiki.vn/pixel/pixel?data=8PuFXIg9A...     -35%   Đã bán 5k+
# 3     https://tka.tiki.vn/pixel/pixel?data=ixK8UNSqg...     -40%    Đã bán 55
# 4     https://tka.tiki.vn/pixel/pixel?data=wV75I5RBc...     -38%  Đã bán 2.5k
# ...                                                 ...      ...          ...
# 1422  https://tiki.vn/bo-10-cai-ta-vai-so-sinh-nhieu...      NaN    Đã bán 60
# 1423  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...      NaN   Đã bán 217
# 1424  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...      NaN   Đã bán 189
# 1425  https://tiki.vn/khan-giay-uot-vit-vang-10-goi-...      NaN    Đã bán 11
# 1426  https://tiki.vn/ta-dan-cao-cap-moony-nhat-ban-...      NaN   Đã bán 238
#
#      category
# 0       tabim
# 1       tabim
# 2       tabim
# 3       tabim
# 4       tabim
# ...       ...
# 1422    tabim
# 1423    tabim
# 1424    tabim
# 1425    tabim
# 1426    tabim
#
# [1427 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       730000
# 1       185000
# 2       385000
# 3       730000
# 4       309000
#          ...
# 1422     59800
# 1423    273000
# 1424    275000
# 1425     84781
# 1426    287500
# Name: price, Length: 1427, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0         12.0
# 1       5000.0
# 2       5000.0
# 3         55.0
# 4       2500.0
#          ...
# 1422      60.0
# 1423     217.0
# 1424     189.0
# 1425      11.0
# 1426     238.0
# Name: sales, Length: 1427, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       8.760000e+06
# 1       9.250000e+08
# 2       1.925000e+09
# 3       4.015000e+07
# 4       7.725000e+08
#             ...
# 1422    3.588000e+06
# 1423    5.924100e+07
# 1424    5.197500e+07
# 1425    9.325910e+05
# 1426    6.842500e+07
# Name: revenue, Length: 1427, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số tabim: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số tabim:  108958197449.0
# So mat hang da ban:  1427
# So san pham da ban:  407464.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Tã - Bỉm người lớn Livedo size L (22 cái/ gói)...  730000
# 1     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185000
# 2     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385000
# 3      Tã - Bỉm quần người lớn Livedo size L - Nhật Bản  730000
# 4     Tã/bỉm quần HUGGIES SKINCARE gói SUPER JUMBO s...  309000
# ...                                                 ...     ...
# 1422  Bộ 10 Cái Tã Vải Sơ Sinh Cho Bé ( màu ngẫu nhi...   59800
# 1423  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273000
# 1424  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275000
# 1425  Khăn giấy ướt vịt vàng 10 gói kèm thùng nhựa t...   84781
# 1426       Tã Dán Cao Cấp Moony Nhật Bản S84 (84 Miếng)  287500
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=90ZuoL0r3...     -34%    12.0
# 1     https://tka.tiki.vn/pixel/pixel?data=v1rrh9qa0...     -40%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=8PuFXIg9A...     -35%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=ixK8UNSqg...     -40%    55.0
# 4     https://tka.tiki.vn/pixel/pixel?data=wV75I5RBc...     -38%  2500.0
# ...                                                 ...      ...     ...
# 1422  https://tiki.vn/bo-10-cai-ta-vai-so-sinh-nhieu...      NaN    60.0
# 1423  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...      NaN   217.0
# 1424  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...      NaN   189.0
# 1425  https://tiki.vn/khan-giay-uot-vit-vang-10-goi-...      NaN    11.0
# 1426  https://tiki.vn/ta-dan-cao-cap-moony-nhat-ban-...      NaN   238.0
#
#      category       revenue
# 0       tabim  8.760000e+06
# 1       tabim  9.250000e+08
# 2       tabim  1.925000e+09
# 3       tabim  4.015000e+07
# 4       tabim  7.725000e+08
# ...       ...           ...
# 1422    tabim  3.588000e+06
# 1423    tabim  5.924100e+07
# 1424    tabim  5.197500e+07
# 1425    tabim  9.325910e+05
# 1426    tabim  6.842500e+07
#
# [1427 rows x 7 columns]

# %%
df_all.to_csv("tk_tabim_all_ed.csv")
