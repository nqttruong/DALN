# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12hdem) - Copy\dienthoai_maytinhbang\maydocsach"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dienthoai_maytinhbang_maydocsach.ipynb',
#  'tk_dienthoai_maytinhbang_maydocsach_t2.ipynb',
#  'tk_maydocsach_all.ipynb',
#  'tk_maydocsach_t1.csv',
#  'tk_maydocsach_t2.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_maydocsach_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Máy đọc sách New Kindle 11th 2022 (16GB) - Hàn...  2.680.000₫
# 1   Máy đọc sách Kindle 2022 (11th) - All new kind...  2.680.000₫
# 2   Máy đọc sách All New Kindle Oasis 3 - Hàng nhậ...  6.690.000₫
# 3   Máy đọc sách Kindle Oasis 3 (2019) - Amazon - ...  5.790.000₫
# 4   Máy Đọc Sách Kindle Oasis (10th Gen) 2019- 8GB...  5.831.008₫
# ..                                                ...         ...
# 13  Combo Máy đọc sách All New Kindle Paperwhite 5...  3.830.000₫
# 14  Máy đọc sách Kindle Oasis 3 (2019) - Amazon - ...  5.790.000₫
# 15  Bút học tiếng Anh i-Tek Venus 2023 (HÀNG CHÍNH...    560.000₫
# 16  Máy đọc sách All new Paperwhite Gen 5 (11th) m...  3.490.000₫
# 17             Máy đọc sách Kobo Nia - Hàng nhập khẩu  2.680.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=1Hp8fS6vu...      1     -14%
# 1   https://tka.tiki.vn/pixel/pixel?data=qM9urDJFL...      2      -4%
# 2   https://tka.tiki.vn/pixel/pixel?data=dsEBUVJYP...      3     -11%
# 3   https://tka.tiki.vn/pixel/pixel?data=I8H2sLxGi...      4     -21%
# 4   https://tka.tiki.vn/pixel/pixel?data=QNAB6U2ll...      5      -4%
# ..                                                ...    ...      ...
# 13  https://tka.tiki.vn/pixel/pixel?data=VXkgDuiMO...     14      NaN
# 14  https://tka.tiki.vn/pixel/pixel?data=eiEnO_gPD...     15      NaN
# 15  https://tiki.vn/but-hoc-tieng-anh-i-tek-chinh-...     16      NaN
# 16  https://tiki.vn/may-doc-sach-all-new-paperwhit...     17      NaN
# 17  https://tiki.vn/may-doc-sach-kobo-nia-p1487018...     18      NaN
#
#         sales    category
# 0    Đã bán 3  maydocsach
# 1    Đã bán 8  maydocsach
# 2   Đã bán 52  maydocsach
# 3   Đã bán 35  maydocsach
# 4    Đã bán 3  maydocsach
# ..        ...         ...
# 13   Đã bán 7  maydocsach
# 14  Đã bán 35  maydocsach
# 15   Đã bán 1  maydocsach
# 16        NaN  maydocsach
# 17        NaN  maydocsach
#
# [73 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Máy đọc sách New Kindle 11th 2022 (16GB) - Hàn...  2.680.000₫
# 1   Máy đọc sách Kindle 2022 (11th) - All new kind...  2.680.000₫
# 2   Máy đọc sách All New Kindle Oasis 3 - Hàng nhậ...  6.690.000₫
# 3   Máy đọc sách Kindle Oasis 3 (2019) - Amazon - ...  5.790.000₫
# 4   Máy Đọc Sách Kindle Oasis (10th Gen) 2019- 8GB...  5.831.008₫
# ..                                                ...         ...
# 60  Combo Máy đọc sách All New Kindle Paperwhite 5...  3.790.000₫
# 61  Combo Máy đọc sách All New Kindle Paperwhite 5...  3.360.000₫
# 62  Combo Máy đọc sách All New Kindle Paperwhite 5...  3.830.000₫
# 63  Máy đọc sách Kindle Oasis 3 (2019) - Amazon - ...  5.790.000₫
# 64  Bút học tiếng Anh i-Tek Venus 2023 (HÀNG CHÍNH...    560.000₫
#
#                                             link_item discount       sales  \
# 0   https://tka.tiki.vn/pixel/pixel?data=1Hp8fS6vu...     -14%    Đã bán 3
# 1   https://tka.tiki.vn/pixel/pixel?data=qM9urDJFL...      -4%    Đã bán 8
# 2   https://tka.tiki.vn/pixel/pixel?data=dsEBUVJYP...     -11%   Đã bán 52
# 3   https://tka.tiki.vn/pixel/pixel?data=I8H2sLxGi...     -21%   Đã bán 35
# 4   https://tka.tiki.vn/pixel/pixel?data=QNAB6U2ll...      -4%    Đã bán 3
# ..                                                ...      ...         ...
# 60  https://tka.tiki.vn/pixel/pixel?data=zpCVgwVO0...      NaN    Đã bán 3
# 61  https://tka.tiki.vn/pixel/pixel?data=Tdd4VkMiq...      NaN  Đã bán 454
# 62  https://tka.tiki.vn/pixel/pixel?data=VXkgDuiMO...      NaN    Đã bán 7
# 63  https://tka.tiki.vn/pixel/pixel?data=eiEnO_gPD...      NaN   Đã bán 35
# 64  https://tiki.vn/but-hoc-tieng-anh-i-tek-chinh-...      NaN    Đã bán 1
#
#       category
# 0   maydocsach
# 1   maydocsach
# 2   maydocsach
# 3   maydocsach
# 4   maydocsach
# ..         ...
# 60  maydocsach
# 61  maydocsach
# 62  maydocsach
# 63  maydocsach
# 64  maydocsach
#
# [65 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0     2680000
# 1     2680000
# 2     6690000
# 3     5790000
# 4     5831008
#        ...
# 60    3790000
# 61    3360000
# 62    3830000
# 63    5790000
# 64     560000
# Name: price, Length: 65, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       3.0
# 1       8.0
# 2      52.0
# 3      35.0
# 4       3.0
#       ...
# 60      3.0
# 61    454.0
# 62      7.0
# 63     35.0
# 64      1.0
# Name: sales, Length: 65, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0     8.040000e+06
# 1     2.144000e+07
# 2     3.478800e+08
# 3     2.026500e+08
# 4     1.749302e+07
#           ...
# 60    1.137000e+07
# 61    1.525440e+09
# 62    2.681000e+07
# 63    2.026500e+08
# 64    5.600000e+05
# Name: revenue, Length: 65, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số maydocsach: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số maydocsach:  29173131924.0
# So mat hang da ban:  65
# So san pham da ban:  8138.0

# %%
df_all
# Out:
#                                                 title    price  \
# 0   Máy đọc sách New Kindle 11th 2022 (16GB) - Hàn...  2680000
# 1   Máy đọc sách Kindle 2022 (11th) - All new kind...  2680000
# 2   Máy đọc sách All New Kindle Oasis 3 - Hàng nhậ...  6690000
# 3   Máy đọc sách Kindle Oasis 3 (2019) - Amazon - ...  5790000
# 4   Máy Đọc Sách Kindle Oasis (10th Gen) 2019- 8GB...  5831008
# ..                                                ...      ...
# 60  Combo Máy đọc sách All New Kindle Paperwhite 5...  3790000
# 61  Combo Máy đọc sách All New Kindle Paperwhite 5...  3360000
# 62  Combo Máy đọc sách All New Kindle Paperwhite 5...  3830000
# 63  Máy đọc sách Kindle Oasis 3 (2019) - Amazon - ...  5790000
# 64  Bút học tiếng Anh i-Tek Venus 2023 (HÀNG CHÍNH...   560000
#
#                                             link_item discount  sales  \
# 0   https://tka.tiki.vn/pixel/pixel?data=1Hp8fS6vu...     -14%    3.0
# 1   https://tka.tiki.vn/pixel/pixel?data=qM9urDJFL...      -4%    8.0
# 2   https://tka.tiki.vn/pixel/pixel?data=dsEBUVJYP...     -11%   52.0
# 3   https://tka.tiki.vn/pixel/pixel?data=I8H2sLxGi...     -21%   35.0
# 4   https://tka.tiki.vn/pixel/pixel?data=QNAB6U2ll...      -4%    3.0
# ..                                                ...      ...    ...
# 60  https://tka.tiki.vn/pixel/pixel?data=zpCVgwVO0...      NaN    3.0
# 61  https://tka.tiki.vn/pixel/pixel?data=Tdd4VkMiq...      NaN  454.0
# 62  https://tka.tiki.vn/pixel/pixel?data=VXkgDuiMO...      NaN    7.0
# 63  https://tka.tiki.vn/pixel/pixel?data=eiEnO_gPD...      NaN   35.0
# 64  https://tiki.vn/but-hoc-tieng-anh-i-tek-chinh-...      NaN    1.0
#
#       category       revenue
# 0   maydocsach  8.040000e+06
# 1   maydocsach  2.144000e+07
# 2   maydocsach  3.478800e+08
# 3   maydocsach  2.026500e+08
# 4   maydocsach  1.749302e+07
# ..         ...           ...
# 60  maydocsach  1.137000e+07
# 61  maydocsach  1.525440e+09
# 62  maydocsach  2.681000e+07
# 63  maydocsach  2.026500e+08
# 64  maydocsach  5.600000e+05
#
# [65 rows x 7 columns]

# %%
df_all.to_csv("tk_maydocsach_all_ed.csv")
