# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12hdem) - Copy\thoitrangnu\damnu"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_damnu_all.ipynb',
#  'tk_ttn_dn.csv',
#  'tk_ttn_dn.ipynb',
#  'tk_ttn_dn_npage.ipynb',
#  'tk_ttn_dn_t10.csv',
#  'tk_ttn_dn_t11.csv',
#  'tk_ttn_dn_t12.csv',
#  'tk_ttn_dn_t13.csv',
#  'tk_ttn_dn_t14.csv',
#  'tk_ttn_dn_t15.csv',
#  'tk_ttn_dn_t16.csv',
#  'tk_ttn_dn_t17.csv',
#  'tk_ttn_dn_t18.csv',
#  'tk_ttn_dn_t19.csv',
#  'tk_ttn_dn_t2.csv',
#  'tk_ttn_dn_t20.csv',
#  'tk_ttn_dn_t21.csv',
#  'tk_ttn_dn_t22.csv',
#  'tk_ttn_dn_t23.csv',
#  'tk_ttn_dn_t24.csv',
#  'tk_ttn_dn_t25.csv',
#  'tk_ttn_dn_t26.csv',
#  'tk_ttn_dn_t27.csv',
#  'tk_ttn_dn_t28.csv',
#  'tk_ttn_dn_t29.csv',
#  'tk_ttn_dn_t3.csv',
#  'tk_ttn_dn_t30.csv',
#  'tk_ttn_dn_t31.csv',
#  'tk_ttn_dn_t32.csv',
#  'tk_ttn_dn_t33.csv',
#  'tk_ttn_dn_t34.csv',
#  'tk_ttn_dn_t35.csv',
#  'tk_ttn_dn_t36.csv',
#  'tk_ttn_dn_t37.csv',
#  'tk_ttn_dn_t38.csv',
#  'tk_ttn_dn_t39.csv',
#  'tk_ttn_dn_t4.csv',
#  'tk_ttn_dn_t40.csv',
#  'tk_ttn_dn_t41.csv',
#  'tk_ttn_dn_t42.csv',
#  'tk_ttn_dn_t43.csv',
#  'tk_ttn_dn_t44.csv',
#  'tk_ttn_dn_t45.csv',
#  'tk_ttn_dn_t46.csv',
#  'tk_ttn_dn_t47.csv',
#  'tk_ttn_dn_t48.csv',
#  'tk_ttn_dn_t49.csv',
#  'tk_ttn_dn_t5.csv',
#  'tk_ttn_dn_t50.csv',
#  'tk_ttn_dn_t6.csv',
#  'tk_ttn_dn_t7.csv',
#  'tk_ttn_dn_t8.csv',
#  'tk_ttn_dn_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_damnu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0             LEMME-Đầm sơ mi tay ngắn fom rộng xẻ tà  265.000₫
# 1             Đầm gấm kết hoa xinh sang trọng MS 2597  440.000₫
# 2   MIMI BigSize [45KG-100KG] Đầm Bigsize Cổ Vuông...  199.000₫
# 3   váy len suông dài tay cổ lọ, đầm dáng dài thu ...  105.000₫
# 4   F342 Đầm ôm body cổ tròn tay ngắn xẻ tà một bê...  245.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36    Váy tiểu thư trễ vai tay chun nhẹ nhàng nữ tính  135.000₫
# 37                                      VÁY ĐŨI 2 DÂY  170.000₫
# 38               Đầm maxi 2 lớp nhún ngực vai - DS228  219.000₫
# 39  Đầm xòe voan hoa dạo phố Hàn Quốc, họa tiết ho...   139.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=HWU0FuoBL...      1     -66%
# 1   https://tka.tiki.vn/pixel/pixel?data=sq_yIt7-i...      2     -35%
# 2   https://tiki.vn/mimi-bigsize-45kg-100kg-dam-bi
rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      265000
# 1      199000
# 2      105000
# 3      245000
# 4      169000
#         ...
# 806    145000
# 807    118999
# 808    235000
# 809    170000
# 810    219000
# Name: price, Length: 811, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       1.0
# 1       2.0
# 2      52.0
# 3       6.0
# 4       9.0
#        ...
# 806     3.0
# 807     6.0
# 808     1.0
# 809     1.0
# 810     4.0
# Name: sales, Length: 811, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       265000.0
# 1       398000.0
# 2      5460000.0
# 3      1470000.0
# 4      1521000.0
#          ...
# 806     435000.0
# 807     713994.0
# 808     235000.0
# 809     170000.0
# 810     876000.0
# Name: revenue, Length: 811, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số damnu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số damnu:  2814475714.0
# So mat hang da ban:  811
# So san pham da ban:  13043.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0              LEMME-Đầm sơ mi tay ngắn fom rộng xẻ tà  265000
# 1    MIMI BigSize [45KG-100KG] Đầm Bigsize Cổ Vuông...  199000
# 2    váy len suông dài tay cổ lọ, đầm dáng dài thu ...  105000
# 3    F342 Đầm ôm body cổ tròn tay ngắn xẻ tà một bê...  245000
# 4    Váy đầm thun nữ ngắn tay vải Modal (gỗ Sồi) mề...  169000
# ..                                                 ...     ...
# 806  Đầm nữ dáng dài cổ bẻ, váy polo body dáng dài ...  145000
# 807  Đầm Váy Nữ Tay Lỡ Cổ Tròn, Xếp Tầng Công Chúa ...  118999
# 808  Đầm Xòe Họa Tiết Đi Tiệc phong cách thời trang...  235000
# 809                                      VÁY ĐŨI 2 DÂY  170000
# 810               Đầm maxi 2 lớp nhún ngực vai - DS228  219000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=HWU0FuoBL...     -66%    1.0
# 1    https://tiki.vn/mimi-bigsize-45kg-100kg-dam-bi...     -12%    2.0
# 2    https://tiki.vn/vay-len-suong-dai-tay-co-lo-da...     -78%   52.0
# 3    https://tiki.vn/f342-dam-om-body-co-tron-tay-n...     -54%    6.0
# 4    https://tiki.vn/vay-dam-thun-nu-ngan-tay-vai-m...      NaN    9.0
# ..                                                 ...      ...    ...
# 806  https://tiki.vn/dam-nu-dang-dai-co-be-vay-polo...      NaN    3.0
# 807  https://tiki.vn/vay-nu-hoa-tiet-hoa-xep-tang-t...      NaN    6.0
# 808  https://tiki.vn/dam-xoe-hoa-tiet-di-tiec-phong...      NaN    1.0
# 809  https://tiki.vn/vay-dui-2-day-p169119219.html?...      NaN    1.0
# 810  https://tiki.vn/dam-maxi-2-lop-nhun-nguc-vai-d...      NaN    4.0
#
#     category    revenue
# 0      damnu   265000.0
# 1      damnu   398000.0
# 2      damnu  5460000.0
# 3      damnu  1470000.0
# 4      damnu  1521000.0
# ..       ...        ...
# 806    damnu   435000.0
# 807    damnu   713994.0
# 808    damnu   235000.0
# 809    damnu   170000.0
# 810    damnu   876000.0
#
# [811 rows x 7 columns]

# %%
df_all.to_csv("tk_damnu_all_ed.csv")
