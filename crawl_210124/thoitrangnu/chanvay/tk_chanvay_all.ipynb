# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12hdem) - Copy\thoitrangnu\chanvay"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_chanvay_all.ipynb',
#  'tk_ttn_cv.csv',
#  'tk_ttn_cv.ipynb',
#  'tk_ttn_cv_npage.ipynb',
#  'tk_ttn_cv_t10.csv',
#  'tk_ttn_cv_t11.csv',
#  'tk_ttn_cv_t12.csv',
#  'tk_ttn_cv_t13.csv',
#  'tk_ttn_cv_t14.csv',
#  'tk_ttn_cv_t15.csv',
#  'tk_ttn_cv_t16.csv',
#  'tk_ttn_cv_t17.csv',
#  'tk_ttn_cv_t18.csv',
#  'tk_ttn_cv_t19.csv',
#  'tk_ttn_cv_t2.csv',
#  'tk_ttn_cv_t20.csv',
#  'tk_ttn_cv_t21.csv',
#  'tk_ttn_cv_t22.csv',
#  'tk_ttn_cv_t23.csv',
#  'tk_ttn_cv_t24.csv',
#  'tk_ttn_cv_t25.csv',
#  'tk_ttn_cv_t26.csv',
#  'tk_ttn_cv_t27.csv',
#  'tk_ttn_cv_t28.csv',
#  'tk_ttn_cv_t29.csv',
#  'tk_ttn_cv_t3.csv',
#  'tk_ttn_cv_t30.csv',
#  'tk_ttn_cv_t31.csv',
#  'tk_ttn_cv_t32.csv',
#  'tk_ttn_cv_t33.csv',
#  'tk_ttn_cv_t34.csv',
#  'tk_ttn_cv_t35.csv',
#  'tk_ttn_cv_t36.csv',
#  'tk_ttn_cv_t37.csv',
#  'tk_ttn_cv_t38.csv',
#  'tk_ttn_cv_t39.csv',
#  'tk_ttn_cv_t4.csv',
#  'tk_ttn_cv_t40.csv',
#  'tk_ttn_cv_t41.csv',
#  'tk_ttn_cv_t42.csv',
#  'tk_ttn_cv_t43.csv',
#  'tk_ttn_cv_t44.csv',
#  'tk_ttn_cv_t45.csv',
#  'tk_ttn_cv_t46.csv',
#  'tk_ttn_cv_t47.csv',
#  'tk_ttn_cv_t48.csv',
#  'tk_ttn_cv_t49.csv',
#  'tk_ttn_cv_t5.csv',
#  'tk_ttn_cv_t50.csv',
#  'tk_ttn_cv_t6.csv',
#  'tk_ttn_cv_t7.csv',
#  'tk_ttn_cv_t8.csv',
#  'tk_ttn_cv_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_chanvay_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Chân Váy Dài Lưng Cao New Design ,Thiết Kế Dài...    179.000₫
# 1   Chân Váy Công Sở New Design Thiết Kế Dáng Váy ...    333.000₫
# 2   Chân váy công sở lưng cao, xếp ly siêu tôn dán...    149.000₫
# 3       Chân váy lụa dài dáng đuôi cá cạp trễ cao cấp    239.000₫
# 4   Chân váy nữ bigsize quần váy dancer hai lớp dá...    169.000₫
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36                          CHÂN VÁY XÒE LADY FASHION     75.000₫
# 37                Vera Chân váy choàng đắp chéo SOBIE    250.000₫
# 38  Chân váy thời trang nữ Fila Tennis - FW2SKF106...  1.077.000₫
# 39                OLV - Chân váy Jennifer Cream Skirt     450.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=NacN_Ql9H...      1     -49%
# 1   https://tka.tiki.vn/pixel/pixel?data=LqdO8289_...      2     -40%
# 2   https://tka.tiki.vn/pixel/pixel?data=tC0zG5P6Z...      3     -37%
# 3   https://tka.tiki.vn/pixel/pixel?data=VkTAjzx75...      4     -40%
# 4   https://tka.tiki.vn/pixel/pixel?data=YIGergXXZ...      5     -31%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/chan-vay-but-chi-dang-dai-hain...     36      NaN
# 36  https://tiki.vn/chan-vay-xoe-lady-fashion-p213...     37      NaN
# 37  https://tiki.vn/vera-chan-vay-choang-dap-cheo-...     38      NaN
# 38  https://tiki.vn/chan-vay-thoi-trang-nu-fila-te...     39      NaN
# 39  https://tiki.vn/olv-chan-vay-jennifer-cream-sk...     40      NaN
#
#          sales category
# 0    Đã bán 64  chanvay
# 1    Đã bán 80  chanvay
# 2   Đã bán 171  chanvay
# 3     Đã bán 1  chanvay
# 4    Đã bán 40  chanvay
# ..         ...      ...
# 35         NaN  chanvay
# 36    Đã bán 4  chanvay
# 37         NaN  chanvay
# 38         NaN  chanvay
# 39         NaN  chanvay
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Chân Váy Dài Lưng Cao New Design ,Thiết Kế Dài...  179.000₫
# 1    Chân Váy Công Sở New Design Thiết Kế Dáng Váy ...  333.000₫
# 2    Chân váy công sở lưng cao, xếp ly siêu tôn dán...  149.000₫
# 3        Chân váy lụa dài dáng đuôi cá cạp trễ cao cấp  239.000₫
# 4    Chân váy nữ bigsize quần váy dancer hai lớp dá...  169.000₫
# ..                                                 ...       ...
# 459  Chân Váy Xếp Ly Dài Kèm Đai, Kiểu Dáng Sang Tr...  139.000₫
# 460        Chân váy cổ tích lưới 3 lớp dễ thương VAY89  120.000₫
# 461  CHÂN VÁY BÒ KIỂUQUẦN VÁY JEAN VẠT LỆCH SANG CHẢNH  297.000₫
# 462           Chân váy xòe dài buộc nơ Elly sang trọng  139.000₫
# 463                          CHÂN VÁY XÒE LADY FASHION   75.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=NacN_Ql9H...     -49%   Đã bán 64
# 1    https://tka.tiki.vn/pixel/pixel?data=LqdO8289_...     -40%   Đã bán 80
# 2    https://tka.tiki.vn/pixel/pixel?data=tC0zG5P6Z...     -37%  Đã bán 171
# 3    https://tka.tiki.vn/pixel/pixel?data=VkTAjzx75...     -40%    Đã bán 1
# 4    https://tka.tiki.vn/pixel/pixel?data=YIGergXXZ...     -31%   Đã bán 40
# ..                                                 ...      ...         ...
# 459  https://tiki.vn/chan-vay-xep-ly-dai-kem-dai-ki...      NaN    Đã bán 1
# 460  https://tiki.vn/chan-vay-co-tich-luoi-3-lop-de...      NaN    Đã bán 1
# 461  https://tiki.vn/chan-vay-bo-kieu-quan-vay-jean...      NaN    Đã bán 5
# 462  https://tiki.vn/chan-vay-xoe-dai-buoc-no-elly-...      NaN   Đã bán 22
# 463  https://tiki.vn/chan-vay-xoe-lady-fashion-p213...      NaN    Đã bán 4
#
#     category
# 0    chanvay
# 1    chanvay
# 2    chanvay
# 3    chanvay
# 4    chanvay
# ..       ...
# 459  chanvay
# 460  chanvay
# 461  chanvay
# 462  chanvay
# 463  chanvay
#
# [464 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      179000
# 1      333000
# 2      149000
# 3      239000
# 4      169000
#         ...
# 459    139000
# 460    120000
# 461    297000
# 462    139000
# 463     75000
# Name: price, Length: 464, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       64.0
# 1       80.0
# 2      171.0
# 3        1.0
# 4       40.0
#        ...
# 459      1.0
# 460      1.0
# 461      5.0
# 462     22.0
# 463      4.0
# Name: sales, Length: 464, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      11456000.0
# 1      26640000.0
# 2      25479000.0
# 3        239000.0
# 4       6760000.0
#           ...
# 459      139000.0
# 460      120000.0
# 461     1485000.0
# 462     3058000.0
# 463      300000.0
# Name: revenue, Length: 464, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số chanvay: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số chanvay:  1306871503.0
# So mat hang da ban:  464
# So san pham da ban:  7740.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Chân Váy Dài Lưng Cao New Design ,Thiết Kế Dài...  179000
# 1    Chân Váy Công Sở New Design Thiết Kế Dáng Váy ...  333000
# 2    Chân váy công sở lưng cao, xếp ly siêu tôn dán...  149000
# 3        Chân váy lụa dài dáng đuôi cá cạp trễ cao cấp  239000
# 4    Chân váy nữ bigsize quần váy dancer hai lớp dá...  169000
# ..                                                 ...     ...
# 459  Chân Váy Xếp Ly Dài Kèm Đai, Kiểu Dáng Sang Tr...  139000
# 460        Chân váy cổ tích lưới 3 lớp dễ thương VAY89  120000
# 461  CHÂN VÁY BÒ KIỂUQUẦN VÁY JEAN VẠT LỆCH SANG CHẢNH  297000
# 462           Chân váy xòe dài buộc nơ Elly sang trọng  139000
# 463                          CHÂN VÁY XÒE LADY FASHION   75000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=NacN_Ql9H...     -49%   64.0
# 1    https://tka.tiki.vn/pixel/pixel?data=LqdO8289_...     -40%   80.0
# 2    https://tka.tiki.vn/pixel/pixel?data=tC0zG5P6Z...     -37%  171.0
# 3    https://tka.tiki.vn/pixel/pixel?data=VkTAjzx75...     -40%    1.0
# 4    https://tka.tiki.vn/pixel/pixel?data=YIGergXXZ...     -31%   40.0
# ..                                                 ...      ...    ...
# 459  https://tiki.vn/chan-vay-xep-ly-dai-kem-dai-ki...      NaN    1.0
# 460  https://tiki.vn/chan-vay-co-tich-luoi-3-lop-de...      NaN    1.0
# 461  https://tiki.vn/chan-vay-bo-kieu-quan-vay-jean...      NaN    5.0
# 462  https://tiki.vn/chan-vay-xoe-dai-buoc-no-elly-...      NaN   22.0
# 463  https://tiki.vn/chan-vay-xoe-lady-fashion-p213...      NaN    4.0
#
#     category     revenue
# 0    chanvay  11456000.0
# 1    chanvay  26640000.0
# 2    chanvay  25479000.0
# 3    chanvay    239000.0
# 4    chanvay   6760000.0
# ..       ...         ...
# 459  chanvay    139000.0
# 460  chanvay    120000.0
# 461  chanvay   1485000.0
# 462  chanvay   3058000.0
# 463  chanvay    300000.0
#
# [464 rows x 7 columns]

# %%
df_all.to_csv("tk_chanvay_all_ed.csv")
