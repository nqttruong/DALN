# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12hdem) - Copy\thoitrangnu\dolot"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dolotnu_t1.csv',
#  'tk_dolotnu_t10.csv',
#  'tk_dolotnu_t11.csv',
#  'tk_dolotnu_t12.csv',
#  'tk_dolotnu_t13.csv',
#  'tk_dolotnu_t14.csv',
#  'tk_dolotnu_t15.csv',
#  'tk_dolotnu_t16.csv',
#  'tk_dolotnu_t17.csv',
#  'tk_dolotnu_t18.csv',
#  'tk_dolotnu_t19.csv',
#  'tk_dolotnu_t2.csv',
#  'tk_dolotnu_t20.csv',
#  'tk_dolotnu_t21.csv',
#  'tk_dolotnu_t22.csv',
#  'tk_dolotnu_t23.csv',
#  'tk_dolotnu_t24.csv',
#  'tk_dolotnu_t25.csv',
#  'tk_dolotnu_t26.csv',
#  'tk_dolotnu_t27.csv',
#  'tk_dolotnu_t28.csv',
#  'tk_dolotnu_t29.csv',
#  'tk_dolotnu_t3.csv',
#  'tk_dolotnu_t30.csv',
#  'tk_dolotnu_t31.csv',
#  'tk_dolotnu_t32.csv',
#  'tk_dolotnu_t33.csv',
#  'tk_dolotnu_t34.csv',
#  'tk_dolotnu_t35.csv',
#  'tk_dolotnu_t36.csv',
#  'tk_dolotnu_t37.csv',
#  'tk_dolotnu_t38.csv',
#  'tk_dolotnu_t39.csv',
#  'tk_dolotnu_t4.csv',
#  'tk_dolotnu_t40.csv',
#  'tk_dolotnu_t41.csv',
#  'tk_dolotnu_t5.csv',
#  'tk_dolotnu_t6.csv',
#  'tk_dolotnu_t7.csv',
#  'tk_dolotnu_t8.csv',
#  'tk_dolotnu_t9.csv',
#  'tk_dolot_all.ipynb',
#  'tk_ttn_dl.ipynb',
#  'tk_ttn_dl_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dolot_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0             Quần lót nữ không đường may iBasic V188   75.000₫
# 1   [MUA 2 TẶNG 1] Pack 3 quần lót nữ không đường ...  178.000₫
# 2             Quần lót nữ không đường may iBasic V189   75.000₫
# 3     Combo 5 quần lót nữ không đường may iBasic V188  345.000₫
# 4             Quần lót nữ không đường may iBasic V109  119.000₫
# ..                                                ...       ...
# 50  Bộ 5 Quần Lót Nữ Damses đai siêu đẹp, chất su ...  280.000₫
# 51  Áo Bra nữ thun GOMTAT gân tăm 2 dây mảnh nâng ...   19.000₫
# 52  Áo Lót Nữ, Áo Ngực Đúc Su Không Gọng Xuất Nhật...  129.000₫
# 53  Áo ngực trơn mút mỏng không đường may iBasic B...  349.000₫
# 54           Áo ngực mút mỏng không gọng iBasic VA029  219.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=W8fad81OV...      1     -16%
# 1   https://tka.tiki.vn/pixel/pixel?data=BEMUMx400...      2     -33%
# 2   https://tka.tiki.vn/pixel/pixel?data=OAL4zh_X1...      3     -16%
# 3   https://tka.tiki.vn/pixel/pixel?data=Nh9xfKaxD...      4     -22%
# 4   https://tka.tiki.vn/pixel/pixel?data=HKhxFZR8T...      5     -25%
rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        75000
# 1       178000
# 2        75000
# 3       345000
# 4       119000
#          ...
# 2209    280000
# 2210     19000
# 2211    129000
# 2212    349000
# 2213    219000
# Name: price, Length: 2214, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       385.0
# 1        18.0
# 2       650.0
# 3       241.0
# 4        62.0
#         ...
# 2209     10.0
# 2210     22.0
# 2211    259.0
# 2212     16.0
# 2213    281.0
# Name: sales, Length: 2214, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       28875000.0
# 1        3204000.0
# 2       48750000.0
# 3       83145000.0
# 4        7378000.0
#            ...
# 2209     2800000.0
# 2210      418000.0
# 2211    33411000.0
# 2212     5584000.0
# 2213    61539000.0
# Name: revenue, Length: 2214, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dolot: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dolot:  122931264840.0
# So mat hang da ban:  2214
# So san pham da ban:  989119.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0               Quần lót nữ không đường may iBasic V188   75000
# 1     [MUA 2 TẶNG 1] Pack 3 quần lót nữ không đường ...  178000
# 2               Quần lót nữ không đường may iBasic V189   75000
# 3       Combo 5 quần lót nữ không đường may iBasic V188  345000
# 4               Quần lót nữ không đường may iBasic V109  119000
# ...                                                 ...     ...
# 2209  Bộ 5 Quần Lót Nữ Damses đai siêu đẹp, chất su ...  280000
# 2210  Áo Bra nữ thun GOMTAT gân tăm 2 dây mảnh nâng ...   19000
# 2211  Áo Lót Nữ, Áo Ngực Đúc Su Không Gọng Xuất Nhật...  129000
# 2212  Áo ngực trơn mút mỏng không đường may iBasic B...  349000
# 2213           Áo ngực mút mỏng không gọng iBasic VA029  219000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=W8fad81OV...     -16%  385.0
# 1     https://tka.tiki.vn/pixel/pixel?data=BEMUMx400...     -33%   18.0
# 2     https://tka.tiki.vn/pixel/pixel?data=OAL4zh_X1...     -16%  650.0
# 3     https://tka.tiki.vn/pixel/pixel?data=Nh9xfKaxD...     -22%  241.0
# 4     https://tka.tiki.vn/pixel/pixel?data=HKhxFZR8T...     -25%   62.0
# ...                                                 ...      ...    ...
# 2209  https://tiki.vn/bo-5-quan-lot-nu-damses-dai-si...      NaN   10.0
# 2210  https://tiki.vn/ao-bra-nu-thun-gomtat-gan-tam-...      NaN   22.0
# 2211  https://tiki.vn/ao-lot-nu-ao-nguc-duc-su-khong...      NaN  259.0
# 2212  https://tiki.vn/ao-nguc-tron-mut-mong-khong-du...      NaN   16.0
# 2213  https://tiki.vn/ao-nguc-mut-mong-khong-gong-ib...      NaN  281.0
#
#      category     revenue
# 0     dolotnu  28875000.0
# 1     dolotnu   3204000.0
# 2     dolotnu  48750000.0
# 3     dolotnu  83145000.0
# 4     dolotnu   7378000.0
# ...       ...         ...
# 2209  dolotnu   2800000.0
# 2210  dolotnu    418000.0
# 2211  dolotnu  33411000.0
# 2212  dolotnu   5584000.0
# 2213  dolotnu  61539000.0
#
# [2214 rows x 7 columns]

# %%
df_all.to_csv("tk_dolot_all_ed.csv")
