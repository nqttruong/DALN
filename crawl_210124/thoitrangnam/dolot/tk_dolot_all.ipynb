# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12hdem) - Copy\thoitrangnam\dolot"
os.listdir(path)
# Out:
# ['tk_dolotnam.csv',
#  'tk_dolotnam.ipynb',
#  'tk_dolot_all.ipynb',
#  'tk_ttn_dolotnam_npage.ipynb',
#  'tk_ttn_dolotnam_t10.csv',
#  'tk_ttn_dolotnam_t11.csv',
#  'tk_ttn_dolotnam_t12.csv',
#  'tk_ttn_dolotnam_t13.csv',
#  'tk_ttn_dolotnam_t14.csv',
#  'tk_ttn_dolotnam_t15.csv',
#  'tk_ttn_dolotnam_t16.csv',
#  'tk_ttn_dolotnam_t17.csv',
#  'tk_ttn_dolotnam_t18.csv',
#  'tk_ttn_dolotnam_t19.csv',
#  'tk_ttn_dolotnam_t2.csv',
#  'tk_ttn_dolotnam_t20.csv',
#  'tk_ttn_dolotnam_t21.csv',
#  'tk_ttn_dolotnam_t22.csv',
#  'tk_ttn_dolotnam_t23.csv',
#  'tk_ttn_dolotnam_t24.csv',
#  'tk_ttn_dolotnam_t25.csv',
#  'tk_ttn_dolotnam_t26.csv',
#  'tk_ttn_dolotnam_t27.csv',
#  'tk_ttn_dolotnam_t28.csv',
#  'tk_ttn_dolotnam_t29.csv',
#  'tk_ttn_dolotnam_t3.csv',
#  'tk_ttn_dolotnam_t30.csv',
#  'tk_ttn_dolotnam_t31.csv',
#  'tk_ttn_dolotnam_t32.csv',
#  'tk_ttn_dolotnam_t33.csv',
#  'tk_ttn_dolotnam_t34.csv',
#  'tk_ttn_dolotnam_t35.csv',
#  'tk_ttn_dolotnam_t36.csv',
#  'tk_ttn_dolotnam_t37.csv',
#  'tk_ttn_dolotnam_t38.csv',
#  'tk_ttn_dolotnam_t39.csv',
#  'tk_ttn_dolotnam_t4.csv',
#  'tk_ttn_dolotnam_t40.csv',
#  'tk_ttn_dolotnam_t41.csv',
#  'tk_ttn_dolotnam_t42.csv',
#  'tk_ttn_dolotnam_t43.csv',
#  'tk_ttn_dolotnam_t44.csv',
#  'tk_ttn_dolotnam_t45.csv',
#  'tk_ttn_dolotnam_t46.csv',
#  'tk_ttn_dolotnam_t47.csv',
#  'tk_ttn_dolotnam_t48.csv',
#  'tk_ttn_dolotnam_t49.csv',
#  'tk_ttn_dolotnam_t5.csv',
#  'tk_ttn_dolotnam_t50.csv',
#  'tk_ttn_dolotnam_t6.csv',
#  'tk_ttn_dolotnam_t7.csv',
#  'tk_ttn_dolotnam_t8.csv',
#  'tk_ttn_dolotnam_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dolot_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Quần Lót Nam Không đường may cao cấp BADBIRD, ...   75.000₫
# 1   Combo 4 quần lót nam Boxer sợi cạp 1cm sợ...  244.000₫
# 2   Combo 3 quần lót nam thun brief Espresso iBasi...  209.000₫
# 3   Combo 3 quần lót nam không đường may bonding t...  405.000₫
# 4   Combo 7 Quần lót nam tam giác cotton xịn nhiều...   68.700₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36    Quần lót Nam Cotton thời trang - L ( 59 - 65kg)   99.000₫
# 37   Quần lót nam sexy dây coặc 2 bên mạnh mẽ - 1 cái   45.000₫
# 38                       Quần lót lọt khe dây gợi cảm   23.000₫
# 39               Quần lót nam lọt khe hình bướm chữ G   45.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=VCchONoeP...      1     -28%
# 1   https://tka.tiki.vn/pixel/pixel?data=JBW89Hun1...      2     -30%
# 2   https://tka.tiki.vn/pixel/pixel?data=CYhTCpOHG...      3     -32%
# 3   https://tka.tiki.vn/pixel/pixel?data=_Hb2vj9aP...      4     -49%
# 4   https://tka.tiki.vn/pixel/pixel?data=iwK3PZbjP...      5     -28%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/quan-lot-nam-dang-luoi-co-gian...     36      NaN
# 36  https://tiki.vn/quan-lot-nam-cotton-thoi-trang...     37      NaN
# 37  https://tiki.vn/quan-lot-nam-sexy-day-coac-2-b...     38      NaN
# 38  https://tiki.vn/quan-lot-lot-khe-day-goi-cam-p...     39      NaN
# 39  https://tiki.vn/quan-lot-nam-lot-khe-hinh-buom...     40      NaN
#
#          sales  category
# 0     Đã bán 7  dolotnam
# 1   Đã bán 5k+  dolotnam
# 2    Đã bán 36  dolotnam
# 3    Đã bán 41  dolotnam
# 4   Đã bán 670  dolotnam
# ..         ...       ...
# 35         NaN  dolotnam
# 36         NaN  dolotnam
# 37   Đã bán 10  dolotnam
# 38         NaN  dolotnam
# 39         NaN  dolotnam
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Quần Lót Nam Không đường may cao cấp BADBIRD, ...   75.000₫
# 1    Combo 4 quần lót nam Boxer sợi cạp 1cm sợ...  244.000₫
# 2    Combo 3 quần lót nam thun brief Espresso iBasi...  209.000₫
# 3    Combo 3 quần lót nam không đường may bonding t...  405.000₫
# 4    Combo 7 Quần lót nam tam giác cotton xịn nhiều...   68.700₫
# ..                                                 ...       ...
# 714  Quần lót nam lưng thấp dạng dây thiết kế siêu ...   45.000₫
# 715                         Quần Lót Nam, Quần Ngủ Nam   99.000₫
# 716                        Quần lót nam Body thun lạnh   50.000₫
# 717         LÓT NAM-MS:6043(Freeman)cotton lụa 4 chiều   47.610₫
# 718   Quần lót nam sexy dây coặc 2 bên mạnh mẽ - 1 cái   45.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=VCchONoeP...     -28%    Đã bán 7
# 1    https://tka.tiki.vn/pixel/pixel?data=JBW89Hun1...     -30%  Đã bán 5k+
# 2    https://tka.tiki.vn/pixel/pixel?data=CYhTCpOHG...     -32%   Đã bán 36
# 3    https://tka.tiki.vn/pixel/pixel?data=_Hb2vj9aP...     -49%   Đã bán 41
# 4    https://tka.tiki.vn/pixel/pixel?data=iwK3PZbjP...     -28%  Đã bán 670
# ..                                                 ...      ...         ...
# 714  https://tiki.vn/quan-lot-nam-lung-thap-dang-da...      NaN   Đã bán 24
# 715  https://tiki.vn/quan-lot-nam-quan-ngu-nam-p162...      NaN   Đã bán 61
# 716  https://tiki.vn/quan-lot-nam-body-thun-lanh-p1...      NaN   Đã bán 11
# 717  https://tiki.vn/lot-nam-ms-6043-freeman-cotton...      NaN    Đã bán 4
# 718  https://tiki.vn/quan-lot-nam-sexy-day-coac-2-b...      NaN   Đã bán 10
#
#      category
# 0    dolotnam
# 1    dolotnam
# 2    dolotnam
# 3    dolotnam
# 4    dolotnam
# ..        ...
# 714  dolotnam
# 715  dolotnam
# 716  dolotnam
# 717  dolotnam
# 718  dolotnam
#
# [719 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       75000
# 1      244000
# 2      209000
# 3      405000
# 4       68700
#         ...
# 714     45000
# 715     99000
# 716     50000
# 717     47610
# 718     45000
# Name: price, Length: 719, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0         7.0
# 1      5000.0
# 2        36.0
# 3        41.0
# 4       670.0
#         ...
# 714      24.0
# 715      61.0
# 716      11.0
# 717       4.0
# 718      10.0
# Name: sales, Length: 719, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      5.250000e+05
# 1      1.220000e+09
# 2      7.524000e+06
# 3      1.660500e+07
# 4      4.602900e+07
#            ...
# 714    1.080000e+06
# 715    6.039000e+06
# 716    5.500000e+05
# 717    1.904400e+05
# 718    4.500000e+05
# Name: revenue, Length: 719, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dolot: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dolot:  14943693939.0
# So mat hang da ban:  719
# So san pham da ban:  105748.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Quần Lót Nam Không đường may cao cấp BADBIRD, ...   75000
# 1    Combo 4 quần lót nam Boxer sợi cạp 1cm sợ...  244000
# 2    Combo 3 quần lót nam thun brief Espresso iBasi...  209000
# 3    Combo 3 quần lót nam không đường may bonding t...  405000
# 4    Combo 7 Quần lót nam tam giác cotton xịn nhiều...   68700
# ..                                                 ...     ...
# 714  Quần lót nam lưng thấp dạng dây thiết kế siêu ...   45000
# 715                         Quần Lót Nam, Quần Ngủ Nam   99000
# 716                        Quần lót nam Body thun lạnh   50000
# 717         LÓT NAM-MS:6043(Freeman)cotton lụa 4 chiều   47610
# 718   Quần lót nam sexy dây coặc 2 bên mạnh mẽ - 1 cái   45000
#
#                                              link_item discount   sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=VCchONoeP...     -28%     7.0
# 1    https://tka.tiki.vn/pixel/pixel?data=JBW89Hun1...     -30%  5000.0
# 2    https://tka.tiki.vn/pixel/pixel?data=CYhTCpOHG...     -32%    36.0
# 3    https://tka.tiki.vn/pixel/pixel?data=_Hb2vj9aP...     -49%    41.0
# 4    https://tka.tiki.vn/pixel/pixel?data=iwK3PZbjP...     -28%   670.0
# ..                                                 ...      ...     ...
# 714  https://tiki.vn/quan-lot-nam-lung-thap-dang-da...      NaN    24.0
# 715  https://tiki.vn/quan-lot-nam-quan-ngu-nam-p162...      NaN    61.0
# 716  https://tiki.vn/quan-lot-nam-body-thun-lanh-p1...      NaN    11.0
# 717  https://tiki.vn/lot-nam-ms-6043-freeman-cotton...      NaN     4.0
# 718  https://tiki.vn/quan-lot-nam-sexy-day-coac-2-b...      NaN    10.0
#
#      category       revenue
# 0    dolotnam  5.250000e+05
# 1    dolotnam  1.220000e+09
# 2    dolotnam  7.524000e+06
# 3    dolotnam  1.660500e+07
# 4    dolotnam  4.602900e+07
# ..        ...           ...
# 714  dolotnam  1.080000e+06
# 715  dolotnam  6.039000e+06
# 716  dolotnam  5.500000e+05
# 717  dolotnam  1.904400e+05
# 718  dolotnam  4.500000e+05
#
# [719 rows x 7 columns]

# %%
df_all.to_csv("tk_dolot_all_ed.csv")
