# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12hdem) - Copy\diengiadung"
os.listdir(path)
# Out:
# ['brand - Copy (4)',
#  'category.ipynb',
#  'dodungnhabep',
#  'thietbigiadinh',
#  'tk_dodungnhabep_all_ed.csv',
#  'tk_thietbigiadinh_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#       Unnamed: 0                                              title    price  \
# 0              0  Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1299000
# 1              1  Ấm Siêu Tốc Inox SUNHOUSE HAPPY TIME HTD1055 (...   139000
# 2              2  Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   249000
# 3              3  Lò vi sóng để bàn Electrolux 20L - EMM20K22B...  1780000
# 4              4  Lò vi sóng để bàn Electrolux UltimateTaste 300...  1990000
# ...          ...                                                ...      ...
# 1283        1283                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP   390000
# 1284        1284  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...   450000
# 1285        1285  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...   240000
# 1286        1286  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1589000
# 1287        1287  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    58000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=oOpBPJlmY...     -17%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=mxlgMc6hj...     -27%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=Ixd_I_lUt...     -41%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=la1w4mrW2...     -11%    40.0
# 4     https://tka.tiki.vn/pixel/pixel?data=rzrSYXXz1...     -46%    70.0
# ...                                                 ...      ...     ...
# 1283  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    26.0
# 1284  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    14.0
# 1285  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...      NaN     3.0
# 1286  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    39.0
# 1287  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
#
#             category       revenue
# 0       dodungnhabep  1.688700e+09
# 1       dodungnhabep  6.950000e+08
# 2       dodungnhabep  1.245000e+09
# 3       dodungnhabep  7.120000e+07
# 4       dodungnhabep  1.393000e+08
# ...              ...           ...
# 1283  thietbigiadinh  1.014000e+07
# 1284  thietbigiadinh  6.300000e+06
# 1285  thietbigiadinh  7.200000e+05
# 1286  thietbigiadinh  6.197100e+07
# 1287  thietbigiadinh  1.450000e+06
#
# [2619 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "diengiadung")

# %%
df
# Out:
#                                                   title    price  \
# 0     Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1299000
# 1     Ấm Siêu Tốc Inox SUNHOUSE HAPPY TIME HTD1055 (...   139000
# 2     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   249000
# 3     Lò vi sóng để bàn Electrolux 20L - EMM20K22B...  1780000
# 4     Lò vi sóng để bàn Electrolux UltimateTaste 300...  1990000
# ...                                                 ...      ...
# 1283                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP   390000
# 1284  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...   450000
# 1285  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...   240000
# 1286  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1589000
# 1287  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    58000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=oOpBPJlmY...     -17%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=mxlgMc6hj...     -27%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=Ixd_I_lUt...     -41%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=la1w4mrW2...     -11%    40.0
# 4     https://tka.tiki.vn/pixel/pixel?data=rzrSYXXz1...     -46%    70.0
# ...                                                 ...      ...     ...
# 1283  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    26.0
# 1284  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    14.0
# 1285  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...      NaN     3.0
# 1286  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    39.0
# 1287  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
#
#            item_list     category       revenue
# 0       dodungnhabep  diengiadung  1.688700e+09
# 1       dodungnhabep  diengiadung  6.950000e+08
# 2       dodungnhabep  diengiadung  1.245000e+09
# 3       dodungnhabep  diengiadung  7.120000e+07
# 4       dodungnhabep  diengiadung  1.393000e+08
# ...              ...          ...           ...
# 1283  thietbigiadinh  diengiadung  1.014000e+07
# 1284  thietbigiadinh  diengiadung  6.300000e+06
# 1285  thietbigiadinh  diengiadung  7.200000e+05
# 1286  thietbigiadinh  diengiadung  6.197100e+07
# 1287  thietbigiadinh  diengiadung  1.450000e+06
#
# [2619 rows x 8 columns]

# %%
df.to_csv('tk_diengiadung_all_ed.csv', index=False, encoding='utf-8')
