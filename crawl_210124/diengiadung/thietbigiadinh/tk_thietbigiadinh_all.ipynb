# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12hdem) - Copy\diengiadung\thietbigiadinh"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dgd_tbgd.ipynb',
#  'tk_dgd_tbgd_npage.ipynb',
#  'tk_thietbigiadinh.csv',
#  'tk_thietbigiadinh_all.ipynb',
#  'tk_thietbigiadinh_t10.csv',
#  'tk_thietbigiadinh_t11.csv',
#  'tk_thietbigiadinh_t12.csv',
#  'tk_thietbigiadinh_t13.csv',
#  'tk_thietbigiadinh_t14.csv',
#  'tk_thietbigiadinh_t15.csv',
#  'tk_thietbigiadinh_t16.csv',
#  'tk_thietbigiadinh_t17.csv',
#  'tk_thietbigiadinh_t18.csv',
#  'tk_thietbigiadinh_t19.csv',
#  'tk_thietbigiadinh_t2.csv',
#  'tk_thietbigiadinh_t20.csv',
#  'tk_thietbigiadinh_t21.csv',
#  'tk_thietbigiadinh_t22.csv',
#  'tk_thietbigiadinh_t23.csv',
#  'tk_thietbigiadinh_t24.csv',
#  'tk_thietbigiadinh_t25.csv',
#  'tk_thietbigiadinh_t26.csv',
#  'tk_thietbigiadinh_t27.csv',
#  'tk_thietbigiadinh_t28.csv',
#  'tk_thietbigiadinh_t29.csv',
#  'tk_thietbigiadinh_t3.csv',
#  'tk_thietbigiadinh_t30.csv',
#  'tk_thietbigiadinh_t31.csv',
#  'tk_thietbigiadinh_t32.csv',
#  'tk_thietbigiadinh_t33.csv',
#  'tk_thietbigiadinh_t34.csv',
#  'tk_thietbigiadinh_t35.csv',
#  'tk_thietbigiadinh_t36.csv',
#  'tk_thietbigiadinh_t37.csv',
#  'tk_thietbigiadinh_t38.csv',
#  'tk_thietbigiadinh_t39.csv',
#  'tk_thietbigiadinh_t4.csv',
#  'tk_thietbigiadinh_t40.csv',
#  'tk_thietbigiadinh_t41.csv',
#  'tk_thietbigiadinh_t42.csv',
#  'tk_thietbigiadinh_t43.csv',
#  'tk_thietbigiadinh_t44.csv',
#  'tk_thietbigiadinh_t45.csv',
#  'tk_thietbigiadinh_t46.csv',
#  'tk_thietbigiadinh_t47.csv',
#  'tk_thietbigiadinh_t48.csv',
#  'tk_thietbigiadinh_t49.csv',
#  'tk_thietbigiadinh_t5.csv',
#  'tk_thietbigiadinh_t50.csv',
#  'tk_thietbigiadinh_t6.csv',
#  'tk_thietbigiadinh_t7.csv',
#  'tk_thietbigiadinh_t8.csv',
#  'tk_thietbigiadinh_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_thietbigiadinh_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0     Máy sấy tóc Philips BHC010/10 - Hàng Chính Hãng    279.000₫
# 1   Máy Sấy Tóc LocknLock - Đen ENA146BLK 2000-230...    519.000₫
# 2   Quạt Làm Mát Và Sưởi Ấm ULTTY SKJ-CR018H, Chất...  4.750.000₫
# 3   Cây nước nóng lạnh để bàn Nagakawa NAG1107 (50...  1.340.000₫
# 4   [TẶNG THÊM 6 THÁNG BẢO HÀNH - COMBO TIẾT KIỆM]...  1.793.500₫
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...    240.000₫
# 37  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1.589.000₫
# 38  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...     58.000₫
# 39  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...     629.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=uYS7jpRqK...      1     -29%
# 1   https://tka.tiki.vn/pixel/pixel?data=cTQKKlJzP...      2     -48%
# 2   https://tka.tiki.vn/pixel/pixel?data=ZKh3KMOh-...      3     -11%
# 3   https://tka.tiki.vn/pixel/pixel?data=LbhxhlZWs...      4     -38%
# 4   https://tka.tiki.vn/pixel/pixel?data=GiW0hGsqP...      5     -48%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/quat-ban-lifan-b-106-trang-han...     36      NaN
# 36  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...     37      NaN
# 37  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...     38      NaN
# 38  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...     39      NaN
# 39  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...     40      NaN
#
#           sales        category
# 0   Đã bán 1.3k  thietbigiadinh
# 1   Đã bán 3.7k  thietbigiadinh
# 2     Đã bán 65  thietbigiadinh
# 3     Đã bán 10  thietbigiadinh
# 4      Đã bán 7  thietbigiadinh
# ..          ...             ...
# 35          NaN  thietbigiadinh
# 36     Đã bán 3  thietbigiadinh
# 37    Đã bán 39  thietbigiadinh
# 38    Đã bán 25  thietbigiadinh
# 39          NaN  thietbigiadinh
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0       Máy sấy tóc Philips BHC010/10 - Hàng Chính Hãng    279.000₫
# 1     Máy Sấy Tóc LocknLock - Đen ENA146BLK 2000-230...    519.000₫
# 2     Quạt Làm Mát Và Sưởi Ấm ULTTY SKJ-CR018H, Chất...  4.750.000₫
# 3     Cây nước nóng lạnh để bàn Nagakawa NAG1107 (50...  1.340.000₫
# 4     [TẶNG THÊM 6 THÁNG BẢO HÀNH - COMBO TIẾT KIỆM]...  1.793.500₫
# ...                                                 ...         ...
# 1283                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP    390.000₫
# 1284  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...     450.000
# 1285  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...    240.000₫
# 1286  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1.589.000₫
# 1287  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...     58.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=uYS7jpRqK...     -29%  Đã bán 1.3k
# 1     https://tka.tiki.vn/pixel/pixel?data=cTQKKlJzP...     -48%  Đã bán 3.7k
# 2     https://tka.tiki.vn/pixel/pixel?data=ZKh3KMOh-...     -11%    Đã bán 65
# 3     https://tka.tiki.vn/pixel/pixel?data=LbhxhlZWs...     -38%    Đã bán 10
# 4     https://tka.tiki.vn/pixel/pixel?data=GiW0hGsqP...     -48%     Đã bán 7
# ...                                                 ...      ...          ...
# 1283  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    Đã bán 26
# 1284  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    Đã bán 14
# 1285  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...      NaN     Đã bán 3
# 1286  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    Đã bán 39
# 1287  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    Đã bán 25
#
#             category
# 0     thietbigiadinh
# 1     thietbigiadinh
# 2     thietbigiadinh
# 3     thietbigiadinh
# 4     thietbigiadinh
# ...              ...
# 1283  thietbigiadinh
# 1284  thietbigiadinh
# 1285  thietbigiadinh
# 1286  thietbigiadinh
# 1287  thietbigiadinh
#
# [1288 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        279000
# 1        519000
# 2       4750000
# 3       1340000
# 4       1793500
#          ...
# 1283     390000
# 1284     450000
# 1285     240000
# 1286    1589000
# 1287      58000
# Name: price, Length: 1288, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# %%
# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       1300.0
# 1       3700.0
# 2         65.0
# 3         10.0
# 4          7.0
#          ...
# 1283      26.0
# 1284      14.0
# 1285       3.0
# 1286      39.0
# 1287      25.0
# Name: sales, Length: 1288, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       3.627000e+08
# 1       1.920300e+09
# 2       3.087500e+08
# 3       1.340000e+07
# 4       1.255450e+07
#             ...
# 1283    1.014000e+07
# 1284    6.300000e+06
# 1285    7.200000e+05
# 1286    6.197100e+07
# 1287    1.450000e+06
# Name: revenue, Length: 1288, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số thiet bi gia dinh: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số thiet bi gia dinh:  136562443817.0
# So mat hang da ban:  1288
# So san pham da ban:  210222.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0       Máy sấy tóc Philips BHC010/10 - Hàng Chính Hãng   279000
# 1     Máy Sấy Tóc LocknLock - Đen ENA146BLK 2000-230...   519000
# 2     Quạt Làm Mát Và Sưởi Ấm ULTTY SKJ-CR018H, Chất...  4750000
# 3     Cây nước nóng lạnh để bàn Nagakawa NAG1107 (50...  1340000
# 4     [TẶNG THÊM 6 THÁNG BẢO HÀNH - COMBO TIẾT KIỆM]...  1793500
# ...                                                 ...      ...
# 1283                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP   390000
# 1284  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...   450000
# 1285  Quạt Treo Tường Lồng Nhựa Lifan T-109 - Xanh D...   240000
# 1286  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1589000
# 1287  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    58000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=uYS7jpRqK...     -29%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=cTQKKlJzP...     -48%  3700.0
# 2     https://tka.tiki.vn/pixel/pixel?data=ZKh3KMOh-...     -11%    65.0
# 3     https://tka.tiki.vn/pixel/pixel?data=LbhxhlZWs...     -38%    10.0
# 4     https://tka.tiki.vn/pixel/pixel?data=GiW0hGsqP...     -48%     7.0
# ...                                                 ...      ...     ...
# 1283  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    26.0
# 1284  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    14.0
# 1285  https://tiki.vn/quat-treo-tuong-long-nhua-lifa...      NaN     3.0
# 1286  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    39.0
# 1287  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
#
#             category       revenue
# 0     thietbigiadinh  3.627000e+08
# 1     thietbigiadinh  1.920300e+09
# 2     thietbigiadinh  3.087500e+08
# 3     thietbigiadinh  1.340000e+07
# 4     thietbigiadinh  1.255450e+07
# ...              ...           ...
# 1283  thietbigiadinh  1.014000e+07
# 1284  thietbigiadinh  6.300000e+06
# 1285  thietbigiadinh  7.200000e+05
# 1286  thietbigiadinh  6.197100e+07
# 1287  thietbigiadinh  1.450000e+06
#
# [1288 rows x 7 columns]

# %%
df_all.to_csv("tk_thietbigiadinh_all_ed.csv")
