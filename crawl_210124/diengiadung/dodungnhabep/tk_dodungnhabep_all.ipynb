# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_170124(12hdem) - Copy\diengiadung\dodungnhabep"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dgd_ddnb.ipynb',
#  'tk_dgd_ddnb_npage.ipynb',
#  'tk_dodungnhabep.csv',
#  'tk_dodungnhabep_all.ipynb',
#  'tk_dodungnhabep_t10.csv',
#  'tk_dodungnhabep_t11.csv',
#  'tk_dodungnhabep_t12.csv',
#  'tk_dodungnhabep_t13.csv',
#  'tk_dodungnhabep_t14.csv',
#  'tk_dodungnhabep_t15.csv',
#  'tk_dodungnhabep_t16.csv',
#  'tk_dodungnhabep_t17.csv',
#  'tk_dodungnhabep_t18.csv',
#  'tk_dodungnhabep_t19.csv',
#  'tk_dodungnhabep_t2.csv',
#  'tk_dodungnhabep_t20.csv',
#  'tk_dodungnhabep_t21.csv',
#  'tk_dodungnhabep_t22.csv',
#  'tk_dodungnhabep_t23.csv',
#  'tk_dodungnhabep_t24.csv',
#  'tk_dodungnhabep_t25.csv',
#  'tk_dodungnhabep_t26.csv',
#  'tk_dodungnhabep_t27.csv',
#  'tk_dodungnhabep_t28.csv',
#  'tk_dodungnhabep_t29.csv',
#  'tk_dodungnhabep_t3.csv',
#  'tk_dodungnhabep_t30.csv',
#  'tk_dodungnhabep_t31.csv',
#  'tk_dodungnhabep_t32.csv',
#  'tk_dodungnhabep_t33.csv',
#  'tk_dodungnhabep_t34.csv',
#  'tk_dodungnhabep_t35.csv',
#  'tk_dodungnhabep_t36.csv',
#  'tk_dodungnhabep_t37.csv',
#  'tk_dodungnhabep_t38.csv',
#  'tk_dodungnhabep_t39.csv',
#  'tk_dodungnhabep_t4.csv',
#  'tk_dodungnhabep_t40.csv',
#  'tk_dodungnhabep_t41.csv',
#  'tk_dodungnhabep_t42.csv',
#  'tk_dodungnhabep_t43.csv',
#  'tk_dodungnhabep_t44.csv',
#  'tk_dodungnhabep_t45.csv',
#  'tk_dodungnhabep_t46.csv',
#  'tk_dodungnhabep_t47.csv',
#  'tk_dodungnhabep_t48.csv',
#  'tk_dodungnhabep_t49.csv',
#  'tk_dodungnhabep_t5.csv',
#  'tk_dodungnhabep_t50.csv',
#  'tk_dodungnhabep_t6.csv',
#  'tk_dodungnhabep_t7.csv',
#  'tk_dodungnhabep_t8.csv',
#  'tk_dodungnhabep_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dodungnhabep_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1.299.000₫
# 1   Ấm Siêu Tốc Inox SUNHOUSE HAPPY TIME HTD1055 (...    139.000₫
# 2   Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...    249.000₫
# 3   Lò vi sóng để bàn Electrolux 20L - EMM20K22B...  1.780.000₫
# 4   Lò vi sóng để bàn Electrolux UltimateTaste 300...  1.990.000₫
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36  Bếp Điện Từ Đôi Kangaroo KG498N (3100W) - Hàng...  2.159.000₫
# 37  Lò Vi Sóng Tráng Men Samsung Dòng Vi Sóng MS23...  1.790.000₫
# 38  Nồi Cơm Điện Xiaomi Thông Minh Cao Tần 1,6L - ...  1.510.000₫
# 39  Nồi điện đa năng phủ chống dính cao cấp - Nồi ...     270.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=oOpBPJlmY...      1     -17%
# 1   https://tka.tiki.vn/pixel/pixel?data=mxlgMc6hj...      2     -27%
# 2   https://tka.tiki.vn/pixel/pixel?data=Ixd_I_lUt...      3     -41%
# 3   https://tka.tiki.vn/pixel/pixel?data=la1w4mrW2...      4     -11%
# 4   https://tka.tiki.vn/pixel/pixel?data=rzrSYXXz1...      5     -46%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/binh-dun-sieu-toc-thong-minh-1...     36      NaN
# 36  https://tiki.vn/bep-dien-tu-doi-kangaroo-kg498...     37      NaN
# 37  https://tiki.vn/lo-vi-song-trang-men-samsung-d...     38      NaN
# 38  https://tiki.vn/noi-com-dien-xiaomi-thong-minh...     39      NaN
# 39  https://tiki.vn/noi-dien-da-nang-phu-chong-din...     40      NaN
#
#           sales      category
# 0   Đã bán 1.3k  dodungnhabep
# 1    Đã bán 5k+  dodungnhabep
# 2    Đã bán 5k+  dodungnhabep
# 3     Đã bán 40  dodungnhabep
# 4     Đã bán 70  dodungnhabep
# ..          ...           ...
# 35          NaN  dodungnhabep
# 36   Đã bán 578  dodungnhabep
# 37   Đã bán 226  dodungnhabep
# 38    Đã bán 78  dodungnhabep
# 39          NaN  dodungnhabep
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1.299.000₫
# 1     Ấm Siêu Tốc Inox SUNHOUSE HAPPY TIME HTD1055 (...    139.000₫
# 2     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...    249.000₫
# 3     Lò vi sóng để bàn Electrolux 20L - EMM20K22B...  1.780.000₫
# 4     Lò vi sóng để bàn Electrolux UltimateTaste 300...  1.990.000₫
# ...                                                 ...         ...
# 1326                   Máy Nướng Bánh Nikai Kẹp Bánh Mỳ    217.651₫
# 1327  Nồi Lẩu Mini, Ca Nấu Mì Nấu Cơm Đa Năng Có Tay...     86.340₫
# 1328  Bếp Điện Từ Đôi Kangaroo KG498N (3100W) - Hàng...  2.159.000₫
# 1329  Lò Vi Sóng Tráng Men Samsung Dòng Vi Sóng MS23...  1.790.000₫
# 1330  Nồi Cơm Điện Xiaomi Thông Minh Cao Tần 1,6L - ...  1.510.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=oOpBPJlmY...     -17%  Đã bán 1.3k
# 1     https://tka.tiki.vn/pixel/pixel?data=mxlgMc6hj...     -27%   Đã bán 5k+
# 2     https://tka.tiki.vn/pixel/pixel?data=Ixd_I_lUt...     -41%   Đã bán 5k+
# 3     https://tka.tiki.vn/pixel/pixel?data=la1w4mrW2...     -11%    Đã bán 40
# 4     https://tka.tiki.vn/pixel/pixel?data=rzrSYXXz1...     -46%    Đã bán 70
# ...                                                 ...      ...          ...
# 1326  https://tiki.vn/may-nuong-banh-nikai-kep-banh-...      NaN    Đã bán 21
# 1327  https://tiki.vn/noi-lau-mini-ca-nau-mi-nau-com...      NaN     Đã bán 3
# 1328  https://tiki.vn/bep-dien-tu-doi-kangaroo-kg498...      NaN   Đã bán 578
# 1329  https://tiki.vn/lo-vi-song-trang-men-samsung-d...      NaN   Đã bán 226
# 1330  https://tiki.vn/noi-com-dien-xiaomi-thong-minh...      NaN    Đã bán 78
#
#           category
# 0     dodungnhabep
# 1     dodungnhabep
# 2     dodungnhabep
# 3     dodungnhabep
# 4     dodungnhabep
# ...            ...
# 1326  dodungnhabep
# 1327  dodungnhabep
# 1328  dodungnhabep
# 1329  dodungnhabep
# 1330  dodungnhabep
#
# [1331 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       1299000
# 1        139000
# 2        249000
# 3       1780000
# 4       1990000
#          ...
# 1326     217651
# 1327      86340
# 1328    2159000
# 1329    1790000
# 1330    1510000
# Name: price, Length: 1331, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       1300.0
# 1       5000.0
# 2       5000.0
# 3         40.0
# 4         70.0
#          ...
# 1326      21.0
# 1327       3.0
# 1328     578.0
# 1329     226.0
# 1330      78.0
# Name: sales, Length: 1331, dtype: float64

# %%
print(set(df_all["sales"]))
# Out:
# {1.0, 2.0, 3.0, 4100.0, 4.0, 6.0, 7.0, 5.0, 9.0, 8.0, 10.0, 11.0, 13.0, 14.0, 15.0, 16.0, 17.0, 12.0, 19.0, 18.0, 21.0, 20.0, 23.0, 24.0, 25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0, 32.0, 33.0, 34.0, 35.0, 36.0, 37.0, 38.0, 39.0, 40.0, 41.0, 42.0, 43.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 2100.0, 52.0, 54.0, 55.0, 56.0, 53.0, 57.0, 59.0, 60.0, 58.0, 61.0, 63.0, 62.0, 64.0, 66.0, 67.0, 68.0, 69.0, 70.0, 71.0, 72.0, 73.0, 74.0, 75.0, 76.0, 77.0, 78.0, 79.0, 80.0, 81.0, 82.0, 83.0, 84.0, 85.0, 86.0, 87.0, 88.0, 89.0, 90.0, 92.0, 93.0, 94.0, 95.0, 96.0, 97.0, 99.0, 100.0, 103.0, 4200.0, 105.0, 104.0, 106.0, 109.0, 110.0, 22.0, 111.0, 112.0, 114.0, 115.0, 116.0, 117.0, 118.0, 119.0, 120.0, 121.0, 122.0, 124.0, 126.0, 128.0, 129.0, 132.0, 133.0, 135.0, 136.0, 137.0, 139.0, 141.0, 142.0, 144.0, 147.0, 150.0, 151.0, 2200.0, 154.0, 155.0, 159.0, 162.0, 164.0, 165.0, 167.0, 168.0, 169.0, 170.0, 171.0, 172.0, 173.0, 175.0, 176.0, 177.0, 180.0, 182.0, 183.0, 185.0, 186.0, 188.0, 189.0, 190.0, 192.0, 193.0, 194.0, 195.0, 196.0, 201.0, 202.0, 4300.0, 205.0, 206.0, 207.0, 213.0, 215.0, 217.0, 219.0, 220.0, 222.0, 226.0, 227.0, 228.0, 229.0, 230.0, 231.0, 235.0, 236.0, 240.0, 247.0, 248.0, 250.0, 251.0, 2300.0, 255.0, 256.0, 258.0, 261.0, 264.0, 266.0, 270.0, 274.0, 276.0, 278.0, 280.0, 281.0, 285.0, 287.0, 288.0, 291.0, 293.0, 295.0, 297.0, 299.0, 305.0, 306.0, 317.0, 321.0, 323.0, 328.0, 329.0, 336.0, 345.0, 2400.0, 352.0, 355.0, 358.0, 362.0, 370.0, 374.0, 379.0, 380.0, 383.0, 386.0, 388.0, 391.0, 402.0, 406.0, 411.0, 414.0, 420.0, 423.0, 429.0, 440.0, 447.0, 2500.0, 457.0, 458.0, 477.0, 493.0, 496.0, 497.0, 509.0, 510.0, 511.0, 514.0, 516.0, 523.0, 526.0, 536.0, 544.0, 545.0, 549.0, 2600.0, 554.0, 568.0, 578.0, 581.0, 596.0, 601.0, 602.0, 606.0, 638.0, 645.0, 2700.0, 657.0, 660.0, 688.0, 714.0, 746.0, 747.0, 751.0, 2800.0, 794.0, 796.0, 800.0, 802.0, 4900.0, 835.0, 837.0, 842.0, 2900.0, 869.0, 899.0, 5000.0, 922.0, 938.0, 940.0, 3000.0, 958.0, 965.0, 981.0, 988.0, 991.0, 996.0, 1000.0, 1100.0, 1200.0, 3300.0, 1300.0, 1400.0, 1500.0, 1600.0, 3700.0, 1700.0, 3800.0, 1800.0, 2000.0}

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1.688700e+09
# 1       6.950000e+08
# 2       1.245000e+09
# 3       7.120000e+07
# 4       1.393000e+08
#             ...
# 1326    4.570671e+06
# 1327    2.590200e+05
# 1328    1.247902e+09
# 1329    4.045400e+08
# 1330    1.177800e+08
# Name: revenue, Length: 1331, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số đồ dùng nhà bếp: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số đồ dùng nhà bếp:  284821060257.0
# So mat hang da ban:  1331
# So san pham da ban:  364874.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1299000
# 1     Ấm Siêu Tốc Inox SUNHOUSE HAPPY TIME HTD1055 (...   139000
# 2     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   249000
# 3     Lò vi sóng để bàn Electrolux 20L - EMM20K22B...  1780000
# 4     Lò vi sóng để bàn Electrolux UltimateTaste 300...  1990000
# ...                                                 ...      ...
# 1326                   Máy Nướng Bánh Nikai Kẹp Bánh Mỳ   217651
# 1327  Nồi Lẩu Mini, Ca Nấu Mì Nấu Cơm Đa Năng Có Tay...    86340
# 1328  Bếp Điện Từ Đôi Kangaroo KG498N (3100W) - Hàng...  2159000
# 1329  Lò Vi Sóng Tráng Men Samsung Dòng Vi Sóng MS23...  1790000
# 1330  Nồi Cơm Điện Xiaomi Thông Minh Cao Tần 1,6L - ...  1510000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=oOpBPJlmY...     -17%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=mxlgMc6hj...     -27%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=Ixd_I_lUt...     -41%  5000.0
# 3     https://tka.tiki.vn/pixel/pixel?data=la1w4mrW2...     -11%    40.0
# 4     https://tka.tiki.vn/pixel/pixel?data=rzrSYXXz1...     -46%    70.0
# ...                                                 ...      ...     ...
# 1326  https://tiki.vn/may-nuong-banh-nikai-kep-banh-...      NaN    21.0
# 1327  https://tiki.vn/noi-lau-mini-ca-nau-mi-nau-com...      NaN     3.0
# 1328  https://tiki.vn/bep-dien-tu-doi-kangaroo-kg498...      NaN   578.0
# 1329  https://tiki.vn/lo-vi-song-trang-men-samsung-d...      NaN   226.0
# 1330  https://tiki.vn/noi-com-dien-xiaomi-thong-minh...      NaN    78.0
#
#           category       revenue
# 0     dodungnhabep  1.688700e+09
# 1     dodungnhabep  6.950000e+08
# 2     dodungnhabep  1.245000e+09
# 3     dodungnhabep  7.120000e+07
# 4     dodungnhabep  1.393000e+08
# ...            ...           ...
# 1326  dodungnhabep  4.570671e+06
# 1327  dodungnhabep  2.590200e+05
# 1328  dodungnhabep  1.247902e+09
# 1329  dodungnhabep  4.045400e+08
# 1330  dodungnhabep  1.177800e+08
#
# [1331 rows x 7 columns]

# %%
df_all.to_csv("tk_dodungnhabep_all_ed.csv")
