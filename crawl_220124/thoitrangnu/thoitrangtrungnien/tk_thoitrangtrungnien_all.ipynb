# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\thoitrangnu\thoitrangtrungnien"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_thoitrangtrungnien.csv',
#  'tk_thoitrangtrungnien_all.ipynb',
#  'tk_ttn_tttn.ipynb',
#  'tk_ttn_tttn_npage.ipynb',
#  'tk_ttn_tttn_t10.csv',
#  'tk_ttn_tttn_t11.csv',
#  'tk_ttn_tttn_t12.csv',
#  'tk_ttn_tttn_t13.csv',
#  'tk_ttn_tttn_t14.csv',
#  'tk_ttn_tttn_t15.csv',
#  'tk_ttn_tttn_t16.csv',
#  'tk_ttn_tttn_t17.csv',
#  'tk_ttn_tttn_t18.csv',
#  'tk_ttn_tttn_t19.csv',
#  'tk_ttn_tttn_t2.csv',
#  'tk_ttn_tttn_t20.csv',
#  'tk_ttn_tttn_t21.csv',
#  'tk_ttn_tttn_t22.csv',
#  'tk_ttn_tttn_t3.csv',
#  'tk_ttn_tttn_t4.csv',
#  'tk_ttn_tttn_t5.csv',
#  'tk_ttn_tttn_t6.csv',
#  'tk_ttn_tttn_t7.csv',
#  'tk_ttn_tttn_t8.csv',
#  'tk_ttn_tttn_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_thoitrangtrungnien_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Bộ đồ trung niên nữ đẹp B91 dài tay, quần áo n...  150.000₫
# 1   Đồ Bộ Mặc Nhà Trung Niên Chất Liệu Lanh Cao Cấ...  162.000₫
# 2        SET ĐỒ BỘ TRUNG NIÊN CHO MẸ VÀ BÀ SANG TRỌNG  390.000₫
# 3   Đồ bộ trung niên lụa pháp mát mịn tặng người l...  243.000₫
# 4   Váy trung niên nữ họa tiết dáng suông V18 - Áo...  169.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36                                Quần Áo cho mẹ (bộ)   59.950₫
# 37  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...  225.000₫
# 38  ( HÀNG SẴN) Bộ Đồ Lụa Mặc Nhà Phối Ren Trung N...  285.000₫
# 39  Áo khoác len trung niên nữ áo len thu đông cho...   199.000
#
#                                             link_item  index discount  \
# 0   https://tiki.vn/bo-do-trung-nien-nu-dep-b91-da...      1     -10%
# 1   https://tiki.vn/do-bo-mac-nha-trung-nien-chat-...      2      -4%
# 2   https://tiki.vn/set-do-bo-trung-nien-cho-me-va...      3     -26%
# 3   https://tiki.vn/do-bo-trung-nien-lua-phap-mat-...      4     -12%
# 4   https://tiki.vn/vay-trung-nien-nu-hoa-tiet-dan...      5     -13%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ao-kieu-trung-nien-tay-coc-cha...     36      NaN
# 36  https://tiki.vn/quan-ao-cho-me-bo-p88085979.ht...     37      NaN
# 37  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...     38      NaN
# 38  https://tiki.vn/hang-san-bo-do-lua-mac-nha-pho...     39      NaN
# 39  https://tiki.vn/ao-khoac-len-trung-nien-nu-ao-...     40      NaN
#
#          sales              category
# 0    Đã bán 11  thoitrangtrungniennu
# 1     Đã bán 7  thoitrangtrungniennu
# 2   Đã bán 127  thoitrangtrungniennu
# 3     Đã bán 5  thoitrangtrungniennu
# 4     Đã bán 9  thoitrangtrungniennu
# ..         ...                   ...
# 35         NaN    thoitrangtrungnien
# 36    Đã bán 3    thoitrangtrungnien
# 37    Đã bán 3    thoitrangtrungnien
# 38         NaN    thoitrangtrungnien
# 39         NaN    thoitrangtrungnien
#
# [880 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Bộ đồ trung niên nữ đẹp B91 dài tay, quần áo n...  150.000₫
# 1    Đồ Bộ Mặc Nhà Trung Niên Chất Liệu Lanh Cao Cấ...  162.000₫
# 2         SET ĐỒ BỘ TRUNG NIÊN CHO MẸ VÀ BÀ SANG TRỌNG  390.000₫
# 3    Đồ bộ trung niên lụa pháp mát mịn tặng người l...  243.000₫
# 4    Váy trung niên nữ họa tiết dáng suông V18 - Áo...  169.000₫
# ..                                                 ...       ...
# 209  Đầm xòe thiết kế trung niên cao cấp sang trọng...  480.000₫
# 210  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...   235.000
# 211  Bộ quần áo trung niên nữ_ đồ bộ mặc nhà chất v...  149.000₫
# 212                                Quần Áo cho mẹ (bộ)   59.950₫
# 213  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...  225.000₫
#
#                                              link_item discount       sales  \
# 0    https://tiki.vn/bo-do-trung-nien-nu-dep-b91-da...     -10%   Đã bán 11
# 1    https://tiki.vn/do-bo-mac-nha-trung-nien-chat-...      -4%    Đã bán 7
# 2    https://tiki.vn/set-do-bo-trung-nien-cho-me-va...     -26%  Đã bán 127
# 3    https://tiki.vn/do-bo-trung-nien-lua-phap-mat-...     -12%    Đã bán 5
# 4    https://tiki.vn/vay-trung-nien-nu-hoa-tiet-dan...     -13%    Đã bán 9
# ..                                                 ...      ...         ...
# 209  https://tiki.vn/dam-xoe-thiet-ke-trung-nien-ca...      NaN    Đã bán 1
# 210  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN    Đã bán 1
# 211  https://tiki.vn/bo-quan-ao-trung-nien-nu_-do-b...      NaN    Đã bán 3
# 212  https://tiki.vn/quan-ao-cho-me-bo-p88085979.ht...      NaN    Đã bán 3
# 213  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN    Đã bán 3
#
#                  category
# 0    thoitrangtrungniennu
# 1    thoitrangtrungniennu
# 2    thoitrangtrungniennu
# 3    thoitrangtrungniennu
# 4    thoitrangtrungniennu
# ..                    ...
# 209    thoitrangtrungnien
# 210    thoitrangtrungnien
# 211    thoitrangtrungnien
# 212    thoitrangtrungnien
# 213    thoitrangtrungnien
#
# [214 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      150000
# 1      162000
# 2      390000
# 3      243000
# 4      169000
#         ...
# 209    480000
# 210    235000
# 211    149000
# 212     59950
# 213    225000
# Name: price, Length: 214, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       11.0
# 1        7.0
# 2      127.0
# 3        5.0
# 4        9.0
#        ...
# 209      1.0
# 210      1.0
# 211      3.0
# 212      3.0
# 213      3.0
# Name: sales, Length: 214, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1650000.0
# 1       1134000.0
# 2      49530000.0
# 3       1215000.0
# 4       1521000.0
#           ...
# 209      480000.0
# 210      235000.0
# 211      447000.0
# 212      179850.0
# 213      675000.0
# Name: revenue, Length: 214, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số thoitrangtrungnien: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số thoitrangtrungnien:  322237132.0
# So mat hang da ban:  214
# So san pham da ban:  1313.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Bộ đồ trung niên nữ đẹp B91 dài tay, quần áo n...  150000
# 1    Đồ Bộ Mặc Nhà Trung Niên Chất Liệu Lanh Cao Cấ...  162000
# 2         SET ĐỒ BỘ TRUNG NIÊN CHO MẸ VÀ BÀ SANG TRỌNG  390000
# 3    Đồ bộ trung niên lụa pháp mát mịn tặng người l...  243000
# 4    Váy trung niên nữ họa tiết dáng suông V18 - Áo...  169000
# ..                                                 ...     ...
# 209  Đầm xòe thiết kế trung niên cao cấp sang trọng...  480000
# 210  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...  235000
# 211  Bộ quần áo trung niên nữ_ đồ bộ mặc nhà chất v...  149000
# 212                                Quần Áo cho mẹ (bộ)   59950
# 213  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...  225000
#
#                                              link_item discount  sales  \
# 0    https://tiki.vn/bo-do-trung-nien-nu-dep-b91-da...     -10%   11.0
# 1    https://tiki.vn/do-bo-mac-nha-trung-nien-chat-...      -4%    7.0
# 2    https://tiki.vn/set-do-bo-trung-nien-cho-me-va...     -26%  127.0
# 3    https://tiki.vn/do-bo-trung-nien-lua-phap-mat-...     -12%    5.0
# 4    https://tiki.vn/vay-trung-nien-nu-hoa-tiet-dan...     -13%    9.0
# ..                                                 ...      ...    ...
# 209  https://tiki.vn/dam-xoe-thiet-ke-trung-nien-ca...      NaN    1.0
# 210  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN    1.0
# 211  https://tiki.vn/bo-quan-ao-trung-nien-nu_-do-b...      NaN    3.0
# 212  https://tiki.vn/quan-ao-cho-me-bo-p88085979.ht...      NaN    3.0
# 213  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN    3.0
#
#                  category     revenue
# 0    thoitrangtrungniennu   1650000.0
# 1    thoitrangtrungniennu   1134000.0
# 2    thoitrangtrungniennu  49530000.0
# 3    thoitrangtrungniennu   1215000.0
# 4    thoitrangtrungniennu   1521000.0
# ..                    ...         ...
# 209    thoitrangtrungnien    480000.0
# 210    thoitrangtrungnien    235000.0
# 211    thoitrangtrungnien    447000.0
# 212    thoitrangtrungnien    179850.0
# 213    thoitrangtrungnien    675000.0
#
# [214 rows x 7 columns]

# %%
df_all.to_csv("tk_thoitrangtrungnien_all_ed.csv")
