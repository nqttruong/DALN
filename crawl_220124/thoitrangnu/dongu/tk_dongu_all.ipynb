# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\thoitrangnu\dongu"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dongunu.csv',
#  'tk_dongu_all.ipynb',
#  'tk_ttn_dn.ipynb',
#  'tk_ttn_dn_npage.ipynb',
#  'tk_ttn_dongu_t10.csv',
#  'tk_ttn_dongu_t11.csv',
#  'tk_ttn_dongu_t12.csv',
#  'tk_ttn_dongu_t13.csv',
#  'tk_ttn_dongu_t14.csv',
#  'tk_ttn_dongu_t15.csv',
#  'tk_ttn_dongu_t16.csv',
#  'tk_ttn_dongu_t17.csv',
#  'tk_ttn_dongu_t18.csv',
#  'tk_ttn_dongu_t19.csv',
#  'tk_ttn_dongu_t2.csv',
#  'tk_ttn_dongu_t20.csv',
#  'tk_ttn_dongu_t21.csv',
#  'tk_ttn_dongu_t22.csv',
#  'tk_ttn_dongu_t23.csv',
#  'tk_ttn_dongu_t24.csv',
#  'tk_ttn_dongu_t25.csv',
#  'tk_ttn_dongu_t26.csv',
#  'tk_ttn_dongu_t27.csv',
#  'tk_ttn_dongu_t28.csv',
#  'tk_ttn_dongu_t29.csv',
#  'tk_ttn_dongu_t3.csv',
#  'tk_ttn_dongu_t30.csv',
#  'tk_ttn_dongu_t31.csv',
#  'tk_ttn_dongu_t32.csv',
#  'tk_ttn_dongu_t33.csv',
#  'tk_ttn_dongu_t34.csv',
#  'tk_ttn_dongu_t35.csv',
#  'tk_ttn_dongu_t36.csv',
#  'tk_ttn_dongu_t37.csv',
#  'tk_ttn_dongu_t38.csv',
#  'tk_ttn_dongu_t39.csv',
#  'tk_ttn_dongu_t4.csv',
#  'tk_ttn_dongu_t40.csv',
#  'tk_ttn_dongu_t41.csv',
#  'tk_ttn_dongu_t42.csv',
#  'tk_ttn_dongu_t43.csv',
#  'tk_ttn_dongu_t44.csv',
#  'tk_ttn_dongu_t45.csv',
#  'tk_ttn_dongu_t46.csv',
#  'tk_ttn_dongu_t47.csv',
#  'tk_ttn_dongu_t48.csv',
#  'tk_ttn_dongu_t49.csv',
#  'tk_ttn_dongu_t5.csv',
#  'tk_ttn_dongu_t50.csv',
#  'tk_ttn_dongu_t6.csv',
#  'tk_ttn_dongu_t7.csv',
#  'tk_ttn_dongu_t8.csv',
#  'tk_ttn_dongu_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dongu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Váy ngủ cosplay sườn xám thêu hoa sexy Q63 - Đ...  149.000₫
# 1   Váy ngủ nữ lụa hở lưng sexy Q60 - Đầm ngủ nữ q...  149.000₫
# 2   Váy ngủ ren hai dây nút cài xẻ trước kèm chip ...  139.000₫
# 3   Váy ngủ bodysuit ren sexy cao cấp Q426 - Đồ ng...   99.000₫
# 4   Váy ngủ bodysuit ren sexy cao cấp Q426 - Đồ ng...   99.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Váy ngủ sexy lụa cổ đổ hở lưng Q151 - Đầm ngủ ...  189.000₫
# 37  Bộ Đồ Ngủ Nữ Lụa Satin Có Mút Ngực Phối Ren Ca...  114.000₫
# 38        Bộ đồ pijama nữ quần dài và áo tay dài C093  151.000₫
# 39  Váy ngủ cosplay xuyên thấu hở lưng kèm chip lọ...   179.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=Fa6v3eexW...      1     -40%
# 1   https://tka.tiki.vn/pixel/pixel?data=0OIVCeCYo...      2     -35%
# 2   https://tka.tiki.vn/pixel/pixel?data=WlXMtCve9...      3     -34%
# 3   https://tka.tiki.vn/pixel/pixel?data=GFJK4ATJN...      4     -48%
# 4   https://tka.tiki.vn/pixel/pixel?data=WuFatCJW0...      5     -48%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/do-bo-lung-mac-nha-cao-cap-kho...     36      NaN
# 36  https://tiki.vn/vay-ngu-sexy-lua-co-do-ho-lung...     37      NaN
# 37  https://tiki.vn/bo-do-ngu-nu-lua-satin-co-mut-...     38      NaN
# 38  https://tiki.vn/bo-do-pijama-nu-quan-dai-va-ao...     39      NaN
# 39  https://tiki.vn/vay-ngu-cosplay-xuyen-thau-ho-...     40      NaN
#
#          sales category
# 0    Đã bán 14  dongunu
# 1    Đã bán 40  dongunu
# 2    Đã bán 39  dongunu
# 3    Đã bán 36  dongunu
# 4    Đã bán 48  dongunu
# ..         ...      ...
# 35         NaN    dongu
# 36         NaN    dongu
# 37   Đã bán 12    dongu
# 38  Đã bán 113    dongu
# 39         NaN    dongu
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Váy ngủ cosplay sườn xám thêu hoa sexy Q63 - Đ...  149.000₫
# 1    Váy ngủ nữ lụa hở lưng sexy Q60 - Đầm ngủ nữ q...  149.000₫
# 2    Váy ngủ ren hai dây nút cài xẻ trước kèm chip ...  139.000₫
# 3    Váy ngủ bodysuit ren sexy cao cấp Q426 - Đồ ng...   99.000₫
# 4    Váy ngủ bodysuit ren sexy cao cấp Q426 - Đồ ng...   99.000₫
# ..                                                 ...       ...
# 992  Bộ Mặc Nhà - Đồ Bộ Ngủ Nữ Chất Thun Cotton Dài...  189.000₫
# 993  Đồ Bộ Pijama Nữ , Đồ Bộ Mặc Nhà Nữ Tay Ngắn, Q...  235.000₫
# 994  Váy Ngủ Nữ họa tiết hoạt hình dễ thương xinh x...   99.000₫
# 995  Bộ Đồ Ngủ Nữ Lụa Satin Có Mút Ngực Phối Ren Ca...  114.000₫
# 996        Bộ đồ pijama nữ quần dài và áo tay dài C093  151.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=Fa6v3eexW...     -40%   Đã bán 14
# 1    https://tka.tiki.vn/pixel/pixel?data=0OIVCeCYo...     -35%   Đã bán 40
# 2    https://tka.tiki.vn/pixel/pixel?data=WlXMtCve9...     -34%   Đã bán 39
# 3    https://tka.tiki.vn/pixel/pixel?data=GFJK4ATJN...     -48%   Đã bán 36
# 4    https://tka.tiki.vn/pixel/pixel?data=WuFatCJW0...     -48%   Đã bán 48
# ..                                                 ...      ...         ...
# 992  https://tiki.vn/bo-mac-nha-freeship-do-bo-ngu-...      NaN    Đã bán 8
# 993  https://tiki.vn/do-bo-pijama-nu-do-bo-mac-nha-...      NaN  Đã bán 305
# 994  https://tiki.vn/vay-ngu-nu-hoa-tiet-hoat-hinh-...      NaN    Đã bán 2
# 995  https://tiki.vn/bo-do-ngu-nu-lua-satin-co-mut-...      NaN   Đã bán 12
# 996  https://tiki.vn/bo-do-pijama-nu-quan-dai-va-ao...      NaN  Đã bán 113
#
#     category
# 0    dongunu
# 1    dongunu
# 2    dongunu
# 3    dongunu
# 4    dongunu
# ..       ...
# 992    dongu
# 993    dongu
# 994    dongu
# 995    dongu
# 996    dongu
#
# [997 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      149000
# 1      149000
# 2      139000
# 3       99000
# 4       99000
#         ...
# 992    189000
# 993    235000
# 994     99000
# 995    114000
# 996    151000
# Name: price, Length: 997, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       14.0
# 1       40.0
# 2       39.0
# 3       36.0
# 4       48.0
#        ...
# 992      8.0
# 993    305.0
# 994      2.0
# 995     12.0
# 996    113.0
# Name: sales, Length: 997, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       2086000.0
# 1       5960000.0
# 2       5421000.0
# 3       3564000.0
# 4       4752000.0
#           ...
# 992     1512000.0
# 993    71675000.0
# 994      198000.0
# 995     1368000.0
# 996    17063000.0
# Name: revenue, Length: 997, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dongu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dongu:  2936337070.0
# So mat hang da ban:  997
# So san pham da ban:  20758.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Váy ngủ cosplay sườn xám thêu hoa sexy Q63 - Đ...  149000
# 1    Váy ngủ nữ lụa hở lưng sexy Q60 - Đầm ngủ nữ q...  149000
# 2    Váy ngủ ren hai dây nút cài xẻ trước kèm chip ...  139000
# 3    Váy ngủ bodysuit ren sexy cao cấp Q426 - Đồ ng...   99000
# 4    Váy ngủ bodysuit ren sexy cao cấp Q426 - Đồ ng...   99000
# ..                                                 ...     ...
# 992  Bộ Mặc Nhà - Đồ Bộ Ngủ Nữ Chất Thun Cotton Dài...  189000
# 993  Đồ Bộ Pijama Nữ , Đồ Bộ Mặc Nhà Nữ Tay Ngắn, Q...  235000
# 994  Váy Ngủ Nữ họa tiết hoạt hình dễ thương xinh x...   99000
# 995  Bộ Đồ Ngủ Nữ Lụa Satin Có Mút Ngực Phối Ren Ca...  114000
# 996        Bộ đồ pijama nữ quần dài và áo tay dài C093  151000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=Fa6v3eexW...     -40%   14.0
# 1    https://tka.tiki.vn/pixel/pixel?data=0OIVCeCYo...     -35%   40.0
# 2    https://tka.tiki.vn/pixel/pixel?data=WlXMtCve9...     -34%   39.0
# 3    https://tka.tiki.vn/pixel/pixel?data=GFJK4ATJN...     -48%   36.0
# 4    https://tka.tiki.vn/pixel/pixel?data=WuFatCJW0...     -48%   48.0
# ..                                                 ...      ...    ...
# 992  https://tiki.vn/bo-mac-nha-freeship-do-bo-ngu-...      NaN    8.0
# 993  https://tiki.vn/do-bo-pijama-nu-do-bo-mac-nha-...      NaN  305.0
# 994  https://tiki.vn/vay-ngu-nu-hoa-tiet-hoat-hinh-...      NaN    2.0
# 995  https://tiki.vn/bo-do-ngu-nu-lua-satin-co-mut-...      NaN   12.0
# 996  https://tiki.vn/bo-do-pijama-nu-quan-dai-va-ao...      NaN  113.0
#
#     category     revenue
# 0    dongunu   2086000.0
# 1    dongunu   5960000.0
# 2    dongunu   5421000.0
# 3    dongunu   3564000.0
# 4    dongunu   4752000.0
# ..       ...         ...
# 992    dongu   1512000.0
# 993    dongu  71675000.0
# 994    dongu    198000.0
# 995    dongu   1368000.0
# 996    dongu  17063000.0
#
# [997 rows x 7 columns]

# %%
df_all.to_csv("tk_dongu_all_ed.csv")
