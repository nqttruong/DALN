# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\thoitrangnu\aokhoacnu"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_akn.csv',
#  'tk_aokhoacnu_all.ipynb',
#  'tk_ttn_akn.ipynb',
#  'tk_ttn_akn_npage.ipynb',
#  'tk_ttn_akn_t10.csv',
#  'tk_ttn_akn_t11.csv',
#  'tk_ttn_akn_t12.csv',
#  'tk_ttn_akn_t13.csv',
#  'tk_ttn_akn_t14.csv',
#  'tk_ttn_akn_t15.csv',
#  'tk_ttn_akn_t16.csv',
#  'tk_ttn_akn_t17.csv',
#  'tk_ttn_akn_t18.csv',
#  'tk_ttn_akn_t19.csv',
#  'tk_ttn_akn_t2.csv',
#  'tk_ttn_akn_t20.csv',
#  'tk_ttn_akn_t21.csv',
#  'tk_ttn_akn_t22.csv',
#  'tk_ttn_akn_t23.csv',
#  'tk_ttn_akn_t24.csv',
#  'tk_ttn_akn_t25.csv',
#  'tk_ttn_akn_t26.csv',
#  'tk_ttn_akn_t27.csv',
#  'tk_ttn_akn_t28.csv',
#  'tk_ttn_akn_t29.csv',
#  'tk_ttn_akn_t3.csv',
#  'tk_ttn_akn_t30.csv',
#  'tk_ttn_akn_t31.csv',
#  'tk_ttn_akn_t32.csv',
#  'tk_ttn_akn_t33.csv',
#  'tk_ttn_akn_t34.csv',
#  'tk_ttn_akn_t35.csv',
#  'tk_ttn_akn_t36.csv',
#  'tk_ttn_akn_t37.csv',
#  'tk_ttn_akn_t38.csv',
#  'tk_ttn_akn_t39.csv',
#  'tk_ttn_akn_t4.csv',
#  'tk_ttn_akn_t40.csv',
#  'tk_ttn_akn_t41.csv',
#  'tk_ttn_akn_t42.csv',
#  'tk_ttn_akn_t43.csv',
#  'tk_ttn_akn_t44.csv',
#  'tk_ttn_akn_t45.csv',
#  'tk_ttn_akn_t46.csv',
#  'tk_ttn_akn_t47.csv',
#  'tk_ttn_akn_t48.csv',
#  'tk_ttn_akn_t49.csv',
#  'tk_ttn_akn_t5.csv',
#  'tk_ttn_akn_t50.csv',
#  'tk_ttn_akn_t6.csv',
#  'tk_ttn_akn_t7.csv',
#  'tk_ttn_akn_t8.csv',
#  'tk_ttn_akn_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_aokhoacnu_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Áo vest nữ blazer hàn quốc [HÀNG CAO CẤP] form...  299.000₫
# 1   Áo khoác gió cách nhiệt GOKING, form unisex ch...  235.000₫
# 2   Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235.000₫
# 3   Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255.000₫
# 4                              Áo Khoác Nữ Măng Tô Dạ  550.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Áo Khoác Hoodie Chống Nắng Dành cho nam và nữ ...  103.000₫
# 37  Áo khoác nữ thoát nhiệt Nhật Bản GOKING, 100% ...  275.000₫
# 38                               Áo khoác len nữ KN32  199.000₫
# 39  Áo Khoác Hoodie Nỉ Bông Dây Kéo Zip Baby FACE ...   100.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=HwQiHXzX9...      1     -44%
# 1   https://tka.tiki.vn/pixel/pixel?data=m0VcnyBMy...      2     -44%
# 2   https://tka.tiki.vn/pixel/pixel?data
dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       97.0
# 1       89.0
# 2       80.0
# 3      102.0
# 4       88.0
#        ...
# 855      8.0
# 856      1.0
# 857     27.0
# 858    525.0
# 859      5.0
# Name: sales, Length: 860, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       29003000.0
# 1       20915000.0
# 2       18800000.0
# 3       26010000.0
# 4       48400000.0
#           ...
# 855      2600000.0
# 856       208000.0
# 857      2781000.0
# 858    144375000.0
# 859       995000.0
# Name: revenue, Length: 860, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số aokhoacnu: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số aokhoacnu:  4291337267.0
# So mat hang da ban:  860
# So san pham da ban:  18737.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Áo vest nữ blazer hàn quốc [HÀNG CAO CẤP] form...  299000
# 1    Áo khoác gió cách nhiệt GOKING, form unisex ch...  235000
# 2    Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235000
# 3    Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255000
# 4                               Áo Khoác Nữ Măng Tô Dạ  550000
# ..                                                 ...     ...
# 855  (HÀNG SẴN) Áo Khoác Phao Nữ Ngắn Trẻ Trung Năn...  325000
# 856  Áo Khoác Phao Nữ 3 Lớp Chần Bông Lông Vũ Cực Ấ...  208000
# 857  Áo Khoác Hoodie Chống Nắng Dành cho nam và nữ ...  103000
# 858  Áo khoác nữ thoát nhiệt Nhật Bản GOKING, 100% ...  275000
# 859                               Áo khoác len nữ KN32  199000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=HwQiHXzX9...     -44%   97.0
# 1    https://tka.tiki.vn/pixel/pixel?data=m0VcnyBMy...     -44%   89.0
# 2    https://tka.tiki.vn/pixel/pixel?data=NwRuAUBJA...     -44%   80.0
# 3    https://tka.tiki.vn/pixel/pixel?data=nf9JSzvTz...     -12%  102.0
# 4    https://tka.tiki.vn/pixel/pixel?data=rovoCPF_Z...      NaN   88.0
# ..                                                 ...      ...    ...
# 855  https://tiki.vn/hang-san-ao-khoac-phao-nu-ngan...      NaN    8.0
# 856  https://tiki.vn/ao-khoac-phao-nu-3-lop-chan-bo...      NaN    1.0
# 857  https://tiki.vn/ao-khoac-hoodie-chong-nang-dan...      NaN   27.0
# 858  https://tiki.vn/ao-khoac-nu-thoat-nhiet-nhat-b...      NaN  525.0
# 859  https://tiki.vn/ao-khoac-len-nu-kn31-p20620638...      NaN    5.0
#
#       category      revenue
# 0    aokhoacnu   29003000.0
# 1    aokhoacnu   20915000.0
# 2    aokhoacnu   18800000.0
# 3    aokhoacnu   26010000.0
# 4    aokhoacnu   48400000.0
# ..         ...          ...
# 855  aokhoacnu    2600000.0
# 856  aokhoacnu     208000.0
# 857  aokhoacnu    2781000.0
# 858  aokhoacnu  144375000.0
# 859  aokhoacnu     995000.0
#
# [860 rows x 7 columns]

# %%
df_all.to_csv("tk_aokhoacnu_all_ed.csv")
