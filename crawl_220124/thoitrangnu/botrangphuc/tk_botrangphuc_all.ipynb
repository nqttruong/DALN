# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\thoitrangnu\botrangphuc"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_botrangphuc.csv',
#  'tk_botrangphuc_all.ipynb',
#  'tk_ttn_btp.ipynb',
#  'tk_ttn_btp_npage.ipynb',
#  'tk_ttn_dodoi_t10.csv',
#  'tk_ttn_dodoi_t11.csv',
#  'tk_ttn_dodoi_t12.csv',
#  'tk_ttn_dodoi_t13.csv',
#  'tk_ttn_dodoi_t14.csv',
#  'tk_ttn_dodoi_t15.csv',
#  'tk_ttn_dodoi_t16.csv',
#  'tk_ttn_dodoi_t17.csv',
#  'tk_ttn_dodoi_t18.csv',
#  'tk_ttn_dodoi_t19.csv',
#  'tk_ttn_dodoi_t2.csv',
#  'tk_ttn_dodoi_t20.csv',
#  'tk_ttn_dodoi_t21.csv',
#  'tk_ttn_dodoi_t22.csv',
#  'tk_ttn_dodoi_t23.csv',
#  'tk_ttn_dodoi_t24.csv',
#  'tk_ttn_dodoi_t25.csv',
#  'tk_ttn_dodoi_t26.csv',
#  'tk_ttn_dodoi_t27.csv',
#  'tk_ttn_dodoi_t28.csv',
#  'tk_ttn_dodoi_t29.csv',
#  'tk_ttn_dodoi_t3.csv',
#  'tk_ttn_dodoi_t30.csv',
#  'tk_ttn_dodoi_t31.csv',
#  'tk_ttn_dodoi_t32.csv',
#  'tk_ttn_dodoi_t33.csv',
#  'tk_ttn_dodoi_t34.csv',
#  'tk_ttn_dodoi_t35.csv',
#  'tk_ttn_dodoi_t36.csv',
#  'tk_ttn_dodoi_t37.csv',
#  'tk_ttn_dodoi_t38.csv',
#  'tk_ttn_dodoi_t39.csv',
#  'tk_ttn_dodoi_t4.csv',
#  'tk_ttn_dodoi_t40.csv',
#  'tk_ttn_dodoi_t41.csv',
#  'tk_ttn_dodoi_t42.csv',
#  'tk_ttn_dodoi_t43.csv',
#  'tk_ttn_dodoi_t44.csv',
#  'tk_ttn_dodoi_t45.csv',
#  'tk_ttn_dodoi_t46.csv',
#  'tk_ttn_dodoi_t47.csv',
#  'tk_ttn_dodoi_t48.csv',
#  'tk_ttn_dodoi_t49.csv',
#  'tk_ttn_dodoi_t5.csv',
#  'tk_ttn_dodoi_t50.csv',
#  'tk_ttn_dodoi_t6.csv',
#  'tk_ttn_dodoi_t7.csv',
#  'tk_ttn_dodoi_t8.csv',
#  'tk_ttn_dodoi_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_botrangphuc_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   [MẪU MỚI] Set Đồ Nữ Đi Chơi QuDu Vải Không Nhă...  499.000₫
# 1   Bộ mặc nhà cho người già, quần áo phụ nữ trung...  107.000₫
# 2                              TÚI NHÍ 2 ĐI CHÙA # Bị   25.000₫
# 3         ĐỒ LAM CHO BÉ IU # Mẫu Bé Vạt Hò In Hoa Sen   80.000₫
# 4   Mẫu Cho Bé iu # La Hán Cho Bé# Quần Áo Bé # Đồ...   73.000₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36  Cặp quần đôi đi biển mẫu mới xinh yêu (giá com...  149.000₫
# 37  Quần đôi đi biển mẫu mới đẹp xinh combo 2 quần...   99.000₫
# 38                    TẠP DỀ YẾM NHỰA CHỐNG THẤM NƯỚC   30.000₫
# 39  Áo Gia Đình Local Brand NOMYC Mẫu GĐ8 Chất Liệ...   180.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=2r91ZSASR...      1     -47%
# 1   https://tiki.vn/bo-mac-nha-cho-nguoi-gia-quan-...      2      -5%
# 2   https://tiki.vn/tui-nhi-2-di-chua-bi-p25410894...      3     -67%
# 3   https://tiki.vn/do-lam-cho-be-iu-mau-be-vat-ho...      4     -52%
# 4   https://tiki.vn/mau-cho-be-iu-la-han-cho-be-qu...      5     -46%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/combo-2-quan-di-bien-mau-moi-x...     36      NaN
# 36  https://tiki.vn/cap-quan-doi-di-bien-mau-moi-x...     37      NaN
# 37  https://tiki.vn/quan-doi-di-bien-mau-moi-dep-x...     38      NaN
# 38  https://tiki.vn/tap-de-yem-nhua-chong-tham-nuo...     39      NaN
# 39  https://tiki.vn/ao-gia-dinh-local-brand-nomyc-...     40      NaN
#
#         sales     category
# 0         NaN  botrangphuc
# 1   Đã bán 11  botrangphuc
# 2   Đã bán 72  botrangphuc
# 3    Đã bán 3  botrangphuc
# 4    Đã bán 3  botrangphuc
# ..        ...          ...
# 35        NaN        dodoi
# 36        NaN        dodoi
# 37        NaN        dodoi
# 38   Đã bán 1        dodoi
# 39        NaN        dodoi
#
# [2001 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Bộ mặc nhà cho người già, quần áo phụ nữ trung...  107.000₫
# 1                               TÚI NHÍ 2 ĐI CHÙA # Bị   25.000₫
# 2          ĐỒ LAM CHO BÉ IU # Mẫu Bé Vạt Hò In Hoa Sen   80.000₫
# 3    Mẫu Cho Bé iu # La Hán Cho Bé# Quần Áo Bé # Đồ...   73.000₫
# 4                 Đồ Lam Đi Chùa # Cổ Tàu Viền # Đồ Bộ  155.000₫
# ..                                                 ...       ...
# 176  Áo thun gia đình mẫu màu cam GD340 dễ thương đ...   25.000₫
# 177                                áo đôi chuột mickey   45.000₫
# 178  áo gia đình con là tất cả , hàng đẹp,nhóm, thu...   50.000₫
# 179      Áo Thun Đôi In Logo LÁ CỜ YEEZY FOR FRESIDENT   49.000₫
# 180                    TẠP DỀ YẾM NHỰA CHỐNG THẤM NƯỚC   30.000₫
#
#                                              link_item discount      sales  \
# 0    https://tiki.vn/bo-mac-nha-cho-nguoi-gia-quan-...      -5%  Đã bán 11
# 1    https://tiki.vn/tui-nhi-2-di-chua-bi-p25410894...     -67%  Đã bán 72
# 2    https://tiki.vn/do-lam-cho-be-iu-mau-be-vat-ho...     -52%   Đã bán 3
# 3    https://tiki.vn/mau-cho-be-iu-la-han-cho-be-qu...     -46%   Đã bán 3
# 4    https://tiki.vn/do-lam-di-chua-co-tau-vien-do-...     -36%   Đã bán 4
# ..                                                 ...      ...        ...
# 176  https://tiki.vn/ao-thun-gia-dinh-happy-family-...      NaN   Đã bán 7
# 177  https://tiki.vn/ao-doi-chuot-mickey-p126186945...      NaN   Đã bán 3
# 178  https://tiki.vn/ao-gia-dinh-con-la-tat-ca-hang...      NaN   Đã bán 3
# 179  https://tiki.vn/ao-thun-doi-in-logo-la-co-yeez...      NaN   Đã bán 1
# 180  https://tiki.vn/tap-de-yem-nhua-chong-tham-nuo...      NaN   Đã bán 1
#
#         category
# 0    botrangphuc
# 1    botrangphuc
# 2    botrangphuc
# 3    botrangphuc
# 4    botrangphuc
# ..           ...
# 176        dodoi
# 177        dodoi
# 178        dodoi
# 179        dodoi
# 180        dodoi
#
# [181 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      107000
# 1       25000
# 2       80000
# 3       73000
# 4      155000
#         ...
# 176     25000
# 177     45000
# 178     50000
# 179     49000
# 180     30000
# Name: price, Length: 181, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      11.0
# 1      72.0
# 2       3.0
# 3       3.0
# 4       4.0
#        ...
# 176     7.0
# 177     3.0
# 178     3.0
# 179     1.0
# 180     1.0
# Name: sales, Length: 181, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      1177000.0
# 1      1800000.0
# 2       240000.0
# 3       219000.0
# 4       620000.0
#          ...
# 176     175000.0
# 177     135000.0
# 178     150000.0
# 179      49000.0
# 180      30000.0
# Name: revenue, Length: 181, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số botrangphuc: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số botrangphuc:  207244729.0
# So mat hang da ban:  181
# So san pham da ban:  1429.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Bộ mặc nhà cho người già, quần áo phụ nữ trung...  107000
# 1                               TÚI NHÍ 2 ĐI CHÙA # Bị   25000
# 2          ĐỒ LAM CHO BÉ IU # Mẫu Bé Vạt Hò In Hoa Sen   80000
# 3    Mẫu Cho Bé iu # La Hán Cho Bé# Quần Áo Bé # Đồ...   73000
# 4                 Đồ Lam Đi Chùa # Cổ Tàu Viền # Đồ Bộ  155000
# ..                                                 ...     ...
# 176  Áo thun gia đình mẫu màu cam GD340 dễ thương đ...   25000
# 177                                áo đôi chuột mickey   45000
# 178  áo gia đình con là tất cả , hàng đẹp,nhóm, thu...   50000
# 179      Áo Thun Đôi In Logo LÁ CỜ YEEZY FOR FRESIDENT   49000
# 180                    TẠP DỀ YẾM NHỰA CHỐNG THẤM NƯỚC   30000
#
#                                              link_item discount  sales  \
# 0    https://tiki.vn/bo-mac-nha-cho-nguoi-gia-quan-...      -5%   11.0
# 1    https://tiki.vn/tui-nhi-2-di-chua-bi-p25410894...     -67%   72.0
# 2    https://tiki.vn/do-lam-cho-be-iu-mau-be-vat-ho...     -52%    3.0
# 3    https://tiki.vn/mau-cho-be-iu-la-han-cho-be-qu...     -46%    3.0
# 4    https://tiki.vn/do-lam-di-chua-co-tau-vien-do-...     -36%    4.0
# ..                                                 ...      ...    ...
# 176  https://tiki.vn/ao-thun-gia-dinh-happy-family-...      NaN    7.0
# 177  https://tiki.vn/ao-doi-chuot-mickey-p126186945...      NaN    3.0
# 178  https://tiki.vn/ao-gia-dinh-con-la-tat-ca-hang...      NaN    3.0
# 179  https://tiki.vn/ao-thun-doi-in-logo-la-co-yeez...      NaN    1.0
# 180  https://tiki.vn/tap-de-yem-nhua-chong-tham-nuo...      NaN    1.0
#
#         category    revenue
# 0    botrangphuc  1177000.0
# 1    botrangphuc  1800000.0
# 2    botrangphuc   240000.0
# 3    botrangphuc   219000.0
# 4    botrangphuc   620000.0
# ..           ...        ...
# 176        dodoi   175000.0
# 177        dodoi   135000.0
# 178        dodoi   150000.0
# 179        dodoi    49000.0
# 180        dodoi    30000.0
#
# [181 rows x 7 columns]

# %%
df_all.to_csv("tk_botrangphuc_all_ed.csv")
