# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\thoitrangnu\dolot"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dolotnu.csv',
#  'tk_dolotnu_t10.csv',
#  'tk_dolotnu_t11.csv',
#  'tk_dolotnu_t12.csv',
#  'tk_dolotnu_t13.csv',
#  'tk_dolotnu_t14.csv',
#  'tk_dolotnu_t15.csv',
#  'tk_dolotnu_t16.csv',
#  'tk_dolotnu_t17.csv',
#  'tk_dolotnu_t18.csv',
#  'tk_dolotnu_t19.csv',
#  'tk_dolotnu_t2.csv',
#  'tk_dolotnu_t20.csv',
#  'tk_dolotnu_t21.csv',
#  'tk_dolotnu_t22.csv',
#  'tk_dolotnu_t23.csv',
#  'tk_dolotnu_t24.csv',
#  'tk_dolotnu_t25.csv',
#  'tk_dolotnu_t26.csv',
#  'tk_dolotnu_t27.csv',
#  'tk_dolotnu_t28.csv',
#  'tk_dolotnu_t29.csv',
#  'tk_dolotnu_t3.csv',
#  'tk_dolotnu_t30.csv',
#  'tk_dolotnu_t31.csv',
#  'tk_dolotnu_t32.csv',
#  'tk_dolotnu_t33.csv',
#  'tk_dolotnu_t34.csv',
#  'tk_dolotnu_t35.csv',
#  'tk_dolotnu_t36.csv',
#  'tk_dolotnu_t37.csv',
#  'tk_dolotnu_t38.csv',
#  'tk_dolotnu_t39.csv',
#  'tk_dolotnu_t4.csv',
#  'tk_dolotnu_t40.csv',
#  'tk_dolotnu_t41.csv',
#  'tk_dolotnu_t42.csv',
#  'tk_dolotnu_t43.csv',
#  'tk_dolotnu_t44.csv',
#  'tk_dolotnu_t45.csv',
#  'tk_dolotnu_t46.csv',
#  'tk_dolotnu_t47.csv',
#  'tk_dolotnu_t48.csv',
#  'tk_dolotnu_t49.csv',
#  'tk_dolotnu_t5.csv',
#  'tk_dolotnu_t50.csv',
#  'tk_dolotnu_t6.csv',
#  'tk_dolotnu_t7.csv',
#  'tk_dolotnu_t8.csv',
#  'tk_dolotnu_t9.csv',
#  'tk_dolot_all.ipynb',
#  'tk_ttn_dl.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dolot_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0             Quần lót nữ không đường may iBasic V188   75.000₫
# 1   [MUA 2 TẶNG 1] Pack 3 quần lót nữ không đường ...  178.000₫
# 2             Quần lót nữ không đường may iBasic V189   75.000₫
# 3              Quần lót nữ cotton mặc váy iBasic V107   59.000₫
# 4             Quần lót nữ không đường may iBasic V109  119.000₫
# ..                                                ...       ...
# 35  Áo Lót Mút Dày Siêu Nâng Ngực Màu Trơn Basic D...  289.500₫
# 36  Combo 5 - 10 Quần lót nữ viền ren co giãn 4 ch...   45.000₫
# 37  Áo Lót Nữ, Áo Lót Đúc Su Đệm Dày Siêu Nâng Ngự...   96.000₫
# 38     Quần lót lọt khe ren 2 dây chéo mông cách điệu   29.000₫
# 39              Quần lót nữ nâng mông thoáng mát Sexy   37.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=SQgHQ2Iug...      1     -16%
# 1   https://tka.tiki.vn/pixel/pixel?data=63FvNXYts...      2     -33%
# 2   https://tka.tiki.vn/pixel/pixel?data=KjyISf13d...      3     -16%
# 3   https://tka.tiki.vn/pixel/pixel?data=mfyW3CQ_P...      4     -14%
# 4   https://tka.tiki.vn/pixel/pixel?data=Q-_4AwSst...      5     -25%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ao-lot-mut-day-sieu-nang-nguc-...     36      NaN
# 36  https://tiki.vn/combo-5-10-quan-lot-nu-vien-re...     37      NaN
# 37  https://tiki.vn/ao-lot-nu-ao-lot-duc-su-dem-da...     38      NaN
# 38  https://tiki.vn/quan-lot-lot-khe-ren-2-day-che...     39      NaN
# 39  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...     40      NaN
#
#          sales category
# 0   Đã bán 385  dolotnu
# 1    Đã bán 18  dolotnu
# 2   Đã bán 650  dolotnu
# 3   Đã bán 197  dolotnu
# 4    Đã bán 62  dolotnu
# ..         ...      ...
# 35  Đã bán 170  dolotnu
# 36    Đã bán 2  dolotnu
# 37   Đã bán 43  dolotnu
# 38    Đã bán 4  dolotnu
# 39    Đã bán 5  dolotnu
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0               Quần lót nữ không đường may iBasic V188   75.000₫
# 1     [MUA 2 TẶNG 1] Pack 3 quần lót nữ không đường ...  178.000₫
# 2               Quần lót nữ không đường may iBasic V189   75.000₫
# 3                Quần lót nữ cotton mặc váy iBasic V107   59.000₫
# 4               Quần lót nữ không đường may iBasic V109  119.000₫
# ...                                                 ...       ...
# 1719  Áo Lót Mút Dày Siêu Nâng Ngực Màu Trơn Basic D...  289.500₫
# 1720  Combo 5 - 10 Quần lót nữ viền ren co giãn 4 ch...   45.000₫
# 1721  Áo Lót Nữ, Áo Lót Đúc Su Đệm Dày Siêu Nâng Ngự...   96.000₫
# 1722     Quần lót lọt khe ren 2 dây chéo mông cách điệu   29.000₫
# 1723              Quần lót nữ nâng mông thoáng mát Sexy   37.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=SQgHQ2Iug...     -16%  Đã bán 385
# 1     https://tka.tiki.vn/pixel/pixel?data=63FvNXYts...     -33%   Đã bán 18
# 2     https://tka.tiki.vn/pixel/pixel?data=KjyISf13d...     -16%  Đã bán 650
# 3     https://tka.tiki.vn/pixel/pixel?data=mfyW3CQ_P...     -14%  Đã bán 197
# 4     https://tka.tiki.vn/pixel/pixel?data=Q-_4AwSst...     -25%   Đã bán 62
# ...                                                 ...      ...         ...
# 1719  https://tiki.vn/ao-lot-mut-day-sieu-nang-nguc-...      NaN  Đã bán 170
# 1720  https://tiki.vn/combo-5-10-quan-lot-nu-vien-re...      NaN    Đã bán 2
# 1721  https://tiki.vn/ao-lot-nu-ao-lot-duc-su-dem-da...      NaN   Đã bán 43
# 1722  https://tiki.vn/quan-lot-lot-khe-ren-2-day-che...      NaN    Đã bán 4
# 1723  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...      NaN    Đã bán 5
#
#      category
# 0     dolotnu
# 1     dolotnu
# 2     dolotnu
# 3     dolotnu
# 4     dolotnu
# ...       ...
# 1719  dolotnu
# 1720  dolotnu
# 1721  dolotnu
# 1722  dolotnu
# 1723  dolotnu
#
# [1724 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        75000
# 1       178000
# 2        75000
# 3        59000
# 4       119000
#          ...
# 1719    289500
# 1720     45000
# 1721     96000
# 1722     29000
# 1723     37000
# Name: price, Length: 1724, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       385.0
# 1        18.0
# 2       650.0
# 3       197.0
# 4        62.0
#         ...
# 1719    170.0
# 1720      2.0
# 1721     43.0
# 1722      4.0
# 1723      5.0
# Name: sales, Length: 1724, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       28875000.0
# 1        3204000.0
# 2       48750000.0
# 3       11623000.0
# 4        7378000.0
#            ...
# 1719    49215000.0
# 1720       90000.0
# 1721     4128000.0
# 1722      116000.0
# 1723      185000.0
# Name: revenue, Length: 1724, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dolot: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dolot:  14424157432.0
# So mat hang da ban:  1724
# So san pham da ban:  115373.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0               Quần lót nữ không đường may iBasic V188   75000
# 1     [MUA 2 TẶNG 1] Pack 3 quần lót nữ không đường ...  178000
# 2               Quần lót nữ không đường may iBasic V189   75000
# 3                Quần lót nữ cotton mặc váy iBasic V107   59000
# 4               Quần lót nữ không đường may iBasic V109  119000
# ...                                                 ...     ...
# 1719  Áo Lót Mút Dày Siêu Nâng Ngực Màu Trơn Basic D...  289500
# 1720  Combo 5 - 10 Quần lót nữ viền ren co giãn 4 ch...   45000
# 1721  Áo Lót Nữ, Áo Lót Đúc Su Đệm Dày Siêu Nâng Ngự...   96000
# 1722     Quần lót lọt khe ren 2 dây chéo mông cách điệu   29000
# 1723              Quần lót nữ nâng mông thoáng mát Sexy   37000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=SQgHQ2Iug...     -16%  385.0
# 1     https://tka.tiki.vn/pixel/pixel?data=63FvNXYts...     -33%   18.0
# 2     https://tka.tiki.vn/pixel/pixel?data=KjyISf13d...     -16%  650.0
# 3     https://tka.tiki.vn/pixel/pixel?data=mfyW3CQ_P...     -14%  197.0
# 4     https://tka.tiki.vn/pixel/pixel?data=Q-_4AwSst...     -25%   62.0
# ...                                                 ...      ...    ...
# 1719  https://tiki.vn/ao-lot-mut-day-sieu-nang-nguc-...      NaN  170.0
# 1720  https://tiki.vn/combo-5-10-quan-lot-nu-vien-re...      NaN    2.0
# 1721  https://tiki.vn/ao-lot-nu-ao-lot-duc-su-dem-da...      NaN   43.0
# 1722  https://tiki.vn/quan-lot-lot-khe-ren-2-day-che...      NaN    4.0
# 1723  https://tiki.vn/quan-lot-nu-nang-mong-thoang-m...      NaN    5.0
#
#      category     revenue
# 0     dolotnu  28875000.0
# 1     dolotnu   3204000.0
# 2     dolotnu  48750000.0
# 3     dolotnu  11623000.0
# 4     dolotnu   7378000.0
# ...       ...         ...
# 1719  dolotnu  49215000.0
# 1720  dolotnu     90000.0
# 1721  dolotnu   4128000.0
# 1722  dolotnu    116000.0
# 1723  dolotnu    185000.0
#
# [1724 rows x 7 columns]

# %%
df_all.to_csv("tk_dolot_all_ed.csv")
