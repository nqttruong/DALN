# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\thoitrangnu"
os.listdir(path)
# Out:
# ['aokhoacnu',
#  'aonu',
#  'botrangphuc',
#  'brand',
#  'category.ipynb',
#  'chanvay',
#  'damnu',
#  'doboi',
#  'dodoi',
#  'dolot',
#  'dongu',
#  'quannu',
#  'thoitrangbau',
#  'thoitrangtrungnien',
#  'tk_aokhoacnu_all_ed.csv',
#  'tk_aonu_all_ed.csv',
#  'tk_botrangphuc_all_ed.csv',
#  'tk_chanvay_all_ed.csv',
#  'tk_damnu_all_ed.csv',
#  'tk_doboinu_all_ed.csv',
#  'tk_dodoinu_all_ed.csv',
#  'tk_dolotnu_all_ed.csv',
#  'tk_dongunu_all_ed.csv',
#  'tk_quannu_all_ed.csv',
#  'tk_thoitrangbau_all_ed.csv',
#  'tk_thoitrangtrungnien_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#      Unnamed: 0                                              title   price  \
# 0             0  Áo vest nữ blazer hàn quốc [HÀNG CAO CẤP] form...  299000
# 1             1  Áo khoác gió cách nhiệt GOKING, form unisex ch...  235000
# 2             2  Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235000
# 3             3  Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255000
# 4             4                             Áo Khoác Nữ Măng Tô Dạ  550000
# ..          ...                                                ...     ...
# 209         209  Đầm xòe thiết kế trung niên cao cấp sang trọng...  480000
# 210         210  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...  235000
# 211         211  Bộ quần áo trung niên nữ_ đồ bộ mặc nhà chất v...  149000
# 212         212                                Quần Áo cho mẹ (bộ)   59950
# 213         213  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...  225000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=HwQiHXzX9...     -44%   97.0
# 1    https://tka.tiki.vn/pixel/pixel?data=m0VcnyBMy...     -44%   89.0
# 2    https://tka.tiki.vn/pixel/pixel?data=NwRuAUBJA...     -44%   80.0
# 3    https://tka.tiki.vn/pixel/pixel?data=nf9JSzvTz...     -12%  102.0
# 4    https://tka.tiki.vn/pixel/pixel?data=rovoCPF_Z...      NaN   88.0
# ..                                                 ...      ...    ...
# 209  https://tiki.vn/dam-xoe-thiet-ke-trung-nien-ca...      NaN    1.0
# 210  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN    1.0
# 211  https://tiki.vn/bo-quan-ao-trung-nien-nu_-do-b...      NaN    3.0
# 212  https://tiki.vn/quan-ao-cho-me-bo-p88085979.ht...      NaN    3.0
# 213  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN    3.0
#
#                category     revenue
# 0             aokhoacnu  29003000.0
# 1             aokhoacnu  20915000.0
# 2             aokhoacnu  18800000.0
# 3             aokhoacnu  26010000.0
# 4             aokhoacnu  48400000.0
# ..                  ...         ...
# 209  thoitrangtrungnien    480000.0
# 210  thoitrangtrungnien    235000.0
# 211  thoitrangtrungnien    447000.0
# 212  thoitrangtrungnien    179850.0
# 213  thoitrangtrungnien    675000.0
#
# [8103 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "thoitrangnu")

# %%
df
# Out:
#                                                  title   price  \
# 0    Áo vest nữ blazer hàn quốc [HÀNG CAO CẤP] form...  299000
# 1    Áo khoác gió cách nhiệt GOKING, form unisex ch...  235000
# 2    Áo khoác gió GOKING 2 lớp, form unisex cho nam...  235000
# 3    Áo khoác gió cách nhiệt GOKING phối viền, mũ d...  255000
# 4                               Áo Khoác Nữ Măng Tô Dạ  550000
# ..                                                 ...     ...
# 209  Đầm xòe thiết kế trung niên cao cấp sang trọng...  480000
# 210  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...  235000
# 211  Bộ quần áo trung niên nữ_ đồ bộ mặc nhà chất v...  149000
# 212                                Quần Áo cho mẹ (bộ)   59950
# 213  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...  225000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=HwQiHXzX9...     -44%   97.0
# 1    https://tka.tiki.vn/pixel/pixel?data=m0VcnyBMy...     -44%   89.0
# 2    https://tka.tiki.vn/pixel/pixel?data=NwRuAUBJA...     -44%   80.0
# 3    https://tka.tiki.vn/pixel/pixel?data=nf9JSzvTz...     -12%  102.0
# 4    https://tka.tiki.vn/pixel/pixel?data=rovoCPF_Z...      NaN   88.0
# ..                                                 ...      ...    ...
# 209  https://tiki.vn/dam-xoe-thiet-ke-trung-nien-ca...      NaN    1.0
# 210  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN    1.0
# 211  https://tiki.vn/bo-quan-ao-trung-nien-nu_-do-b...      NaN    3.0
# 212  https://tiki.vn/quan-ao-cho-me-bo-p88085979.ht...      NaN    3.0
# 213  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN    3.0
#
#               item_list     category     revenue
# 0             aokhoacnu  thoitrangnu  29003000.0
# 1             aokhoacnu  thoitrangnu  20915000.0
# 2             aokhoacnu  thoitrangnu  18800000.0
# 3             aokhoacnu  thoitrangnu  26010000.0
# 4             aokhoacnu  thoitrangnu  48400000.0
# ..                  ...          ...         ...
# 209  thoitrangtrungnien  thoitrangnu    480000.0
# 210  thoitrangtrungnien  thoitrangnu    235000.0
# 211  thoitrangtrungnien  thoitrangnu    447000.0
# 212  thoitrangtrungnien  thoitrangnu    179850.0
# 213  thoitrangtrungnien  thoitrangnu    675000.0
#
# [8103 rows x 8 columns]

# %%
df.to_csv('tk_thoitrangnu_all_ed.csv', index=False, encoding='utf-8')
