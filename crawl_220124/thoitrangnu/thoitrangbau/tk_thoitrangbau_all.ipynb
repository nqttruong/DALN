# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\thoitrangnu\thoitrangbau"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_thoitrangbau.csv',
#  'tk_thoitrangbau_all.ipynb',
#  'tk_ttn_ttb.ipynb',
#  'tk_ttn_ttb_npage.ipynb',
#  'tk_ttn_ttb_t10.csv',
#  'tk_ttn_ttb_t11.csv',
#  'tk_ttn_ttb_t12.csv',
#  'tk_ttn_ttb_t13.csv',
#  'tk_ttn_ttb_t14.csv',
#  'tk_ttn_ttb_t15.csv',
#  'tk_ttn_ttb_t16.csv',
#  'tk_ttn_ttb_t17.csv',
#  'tk_ttn_ttb_t18.csv',
#  'tk_ttn_ttb_t19.csv',
#  'tk_ttn_ttb_t2.csv',
#  'tk_ttn_ttb_t20.csv',
#  'tk_ttn_ttb_t21.csv',
#  'tk_ttn_ttb_t22.csv',
#  'tk_ttn_ttb_t23.csv',
#  'tk_ttn_ttb_t24.csv',
#  'tk_ttn_ttb_t25.csv',
#  'tk_ttn_ttb_t26.csv',
#  'tk_ttn_ttb_t27.csv',
#  'tk_ttn_ttb_t28.csv',
#  'tk_ttn_ttb_t29.csv',
#  'tk_ttn_ttb_t3.csv',
#  'tk_ttn_ttb_t30.csv',
#  'tk_ttn_ttb_t31.csv',
#  'tk_ttn_ttb_t32.csv',
#  'tk_ttn_ttb_t33.csv',
#  'tk_ttn_ttb_t34.csv',
#  'tk_ttn_ttb_t4.csv',
#  'tk_ttn_ttb_t5.csv',
#  'tk_ttn_ttb_t6.csv',
#  'tk_ttn_ttb_t7.csv',
#  'tk_ttn_ttb_t8.csv',
#  'tk_ttn_ttb_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_thoitrangbau_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Ngũ cốc bầu siêu dinh dưỡng Lạc Lạc giảm ốm ng...  257.140₫
# 1   COMBO 2 HỘP Ngũ Cốc Bầu Lạc Lạc Plus 30 gói 60...  507.400₫
# 2   Ngũ cốc lợi sữa Lạc Lạc Plus mới cao cấp 39 lo...  515.000₫
# 3   Áo lót bầu- áo lót cho con bú chống chảy xệ mặ...   66.000₫
# 4   QUẦN BẦU CÓ ĐÁP BỤNG - QUẦN LEGGING BẦU CÓ ĐÁP...   74.340₫
# ..                                                ...       ...
# 35                                                NaN       NaN
# 36      SÉT QUẦN ÁO BẦU MẶC ĐI CHƠI CỰC XINH pjmb3125  455.000₫
# 37     Quần bầu jean dáng lỡ cực xinh QBN1345-QBN1369  435.000₫
# 38                     Áo bầu có chỗ cho bé ty AB3134  285.000₫
# 39   Quần bầu THUN cotton form rộng thoải mái QBS1415   195.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=7RQh7yn9j...      1     -14%
# 1   https://tka.tiki.vn/pixel/pixel?data=pH4N1sXJ1...      2     -14%
# 2   https://tka.tiki.vn/pixel/pixel?data=nJTD8mT9H...      3     -14%
# 3   https://tiki.vn/ao-lot-bau-ao-lot-cho-con-bu-c...      4     -13%
# 4   https://tiki.vn/quan-bau-co-dap-bung-quan-legg...      5     -14%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/quan-legging-bau-ni-thu-dong-m...     36      NaN
# 36  https://tiki.vn/set-quan-ao-bau-mac-di-choi-cu...     37      NaN
# 37  https://tiki.vn/quan-bau-jean-dang-lo-cuc-xinh...     38      NaN
# 38  https://tiki.vn/ao-bau-co-cho-cho-be-ty-ab3134...     39      NaN
# 39  https://tiki.vn/quan-bau-thun-cotton-form-rong...     40      NaN
#
#         sales      category
# 0   Đã bán 30  thoitrangbau
# 1    Đã bán 5  thoitrangbau
# 2    Đã bán 1  thoitrangbau
# 3   Đã bán 48  thoitrangbau
# 4    Đã bán 9  thoitrangbau
# ..        ...           ...
# 35        NaN  thoitrangbau
# 36        NaN  thoitrangbau
# 37        NaN  thoitrangbau
# 38        NaN  thoitrangbau
# 39        NaN  thoitrangbau
#
# [1360 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title     price  \
# 0    Ngũ cốc bầu siêu dinh dưỡng Lạc Lạc giảm ốm ng...  257.140₫
# 1    COMBO 2 HỘP Ngũ Cốc Bầu Lạc Lạc Plus 30 gói 60...  507.400₫
# 2    Ngũ cốc lợi sữa Lạc Lạc Plus mới cao cấp 39 lo...  515.000₫
# 3    Áo lót bầu- áo lót cho con bú chống chảy xệ mặ...   66.000₫
# 4    QUẦN BẦU CÓ ĐÁP BỤNG - QUẦN LEGGING BẦU CÓ ĐÁP...   74.340₫
# ..                                                 ...       ...
# 138                           ẢNH THẬT ️Đầm cho con bú  247.000₫
# 139                 ️ẢNH THẬT️ Áo giữ nhiệt cho con bú   299.000
# 140  Chân Váy Bầu Xếp Ly Azuno AZ44 Có Đáp Bụng Và ...   185.000
# 141    Áo bầu công sở mùa hè 2023, áo bà bầu, mleeshop  109.000₫
# 142  Áo bầu xinh hàn quốc, áo babydoll bầu đẹp, MLE...  105.000₫
#
#                                              link_item discount      sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=7RQh7yn9j...     -14%  Đã bán 30
# 1    https://tka.tiki.vn/pixel/pixel?data=pH4N1sXJ1...     -14%   Đã bán 5
# 2    https://tka.tiki.vn/pixel/pixel?data=nJTD8mT9H...     -14%   Đã bán 1
# 3    https://tiki.vn/ao-lot-bau-ao-lot-cho-con-bu-c...     -13%  Đã bán 48
# 4    https://tiki.vn/quan-bau-co-dap-bung-quan-legg...     -14%   Đã bán 9
# ..                                                 ...      ...        ...
# 138  https://tiki.vn/anh-that-dam-cho-con-bu-p95173...      NaN   Đã bán 2
# 139  https://tiki.vn/anh-that-ao-giu-nhiet-cho-con-...      NaN   Đã bán 2
# 140  https://tiki.vn/chan-vay-bau-xep-ly-azuno-az44...      NaN   Đã bán 1
# 141  https://tiki.vn/ao-bau-cong-so-mua-he-2023-ao-...      NaN   Đã bán 1
# 142  https://tiki.vn/ao-bau-xinh-han-quoc-ao-babydo...      NaN   Đã bán 1
#
#          category
# 0    thoitrangbau
# 1    thoitrangbau
# 2    thoitrangbau
# 3    thoitrangbau
# 4    thoitrangbau
# ..            ...
# 138  thoitrangbau
# 139  thoitrangbau
# 140  thoitrangbau
# 141  thoitrangbau
# 142  thoitrangbau
#
# [143 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      257140
# 1      507400
# 2      515000
# 3       66000
# 4       74340
#         ...
# 138    247000
# 139    299000
# 140    185000
# 141    109000
# 142    105000
# Name: price, Length: 143, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      30.0
# 1       5.0
# 2       1.0
# 3      48.0
# 4       9.0
#        ...
# 138     2.0
# 139     2.0
# 140     1.0
# 141     1.0
# 142     1.0
# Name: sales, Length: 143, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      7714200.0
# 1      2537000.0
# 2       515000.0
# 3      3168000.0
# 4       669060.0
#          ...
# 138     494000.0
# 139     598000.0
# 140     185000.0
# 141     109000.0
# 142     105000.0
# Name: revenue, Length: 143, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số thoitrangbau: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số thoitrangbau:  89845356.0
# So mat hang da ban:  143
# So san pham da ban:  730.0

# %%
df_all
# Out:
#                                                  title   price  \
# 0    Ngũ cốc bầu siêu dinh dưỡng Lạc Lạc giảm ốm ng...  257140
# 1    COMBO 2 HỘP Ngũ Cốc Bầu Lạc Lạc Plus 30 gói 60...  507400
# 2    Ngũ cốc lợi sữa Lạc Lạc Plus mới cao cấp 39 lo...  515000
# 3    Áo lót bầu- áo lót cho con bú chống chảy xệ mặ...   66000
# 4    QUẦN BẦU CÓ ĐÁP BỤNG - QUẦN LEGGING BẦU CÓ ĐÁP...   74340
# ..                                                 ...     ...
# 138                           ẢNH THẬT ️Đầm cho con bú  247000
# 139                 ️ẢNH THẬT️ Áo giữ nhiệt cho con bú  299000
# 140  Chân Váy Bầu Xếp Ly Azuno AZ44 Có Đáp Bụng Và ...  185000
# 141    Áo bầu công sở mùa hè 2023, áo bà bầu, mleeshop  109000
# 142  Áo bầu xinh hàn quốc, áo babydoll bầu đẹp, MLE...  105000
#
#                                              link_item discount  sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=7RQh7yn9j...     -14%   30.0
# 1    https://tka.tiki.vn/pixel/pixel?data=pH4N1sXJ1...     -14%    5.0
# 2    https://tka.tiki.vn/pixel/pixel?data=nJTD8mT9H...     -14%    1.0
# 3    https://tiki.vn/ao-lot-bau-ao-lot-cho-con-bu-c...     -13%   48.0
# 4    https://tiki.vn/quan-bau-co-dap-bung-quan-legg...     -14%    9.0
# ..                                                 ...      ...    ...
# 138  https://tiki.vn/anh-that-dam-cho-con-bu-p95173...      NaN    2.0
# 139  https://tiki.vn/anh-that-ao-giu-nhiet-cho-con-...      NaN    2.0
# 140  https://tiki.vn/chan-vay-bau-xep-ly-azuno-az44...      NaN    1.0
# 141  https://tiki.vn/ao-bau-cong-so-mua-he-2023-ao-...      NaN    1.0
# 142  https://tiki.vn/ao-bau-xinh-han-quoc-ao-babydo...      NaN    1.0
#
#          category    revenue
# 0    thoitrangbau  7714200.0
# 1    thoitrangbau  2537000.0
# 2    thoitrangbau   515000.0
# 3    thoitrangbau  3168000.0
# 4    thoitrangbau   669060.0
# ..            ...        ...
# 138  thoitrangbau   494000.0
# 139  thoitrangbau   598000.0
# 140  thoitrangbau   185000.0
# 141  thoitrangbau   109000.0
# 142  thoitrangbau   105000.0
#
# [143 rows x 7 columns]

# %%
df_all.to_csv("tk_thoitrangbau_all_ed.csv")
