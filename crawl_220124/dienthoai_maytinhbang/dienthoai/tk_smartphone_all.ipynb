# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\dienthoai_maytinhbang\dienthoai"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_smartphone.csv',
#  'tk_smartphone.ipynb',
#  'tk_smartphone_all.ipynb',
#  'tk_smartphone_npage.ipynb',
#  'tk_smartphone_t10.csv',
#  'tk_smartphone_t11.csv',
#  'tk_smartphone_t12.csv',
#  'tk_smartphone_t2.csv',
#  'tk_smartphone_t3.csv',
#  'tk_smartphone_t4.csv',
#  'tk_smartphone_t5.csv',
#  'tk_smartphone_t6.csv',
#  'tk_smartphone_t7.csv',
#  'tk_smartphone_t8.csv',
#  'tk_smartphone_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_smartphone_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title        price  \
# 0                     Điện Thoại Oppo A17k (3GB/64GB)   2.370.000₫
# 1   Điện thoại Vivo Y36 (8GB/128GB) - Hàng Chính H...   5.490.000₫
# 2   Điện thoại VIVO Y02t - Hàng chính hãng - Pin K...   2.790.000₫
# 3   [MỚI] Điện thoại vivo Y17s - Hàng chính hãng -...   3.790.000₫
# 4   [Mới] Điện thoại vivo V29e 5G (8GB/256GB) - Hà...   8.690.000₫
# ..                                                ...          ...
# 35                                                NaN          NaN
# 36  Điện thoại Samsung Galaxy A04s (4GB/64BG) - Hà...   3.990.000₫
# 37   Điện Thoại Samsung Galaxy A04e - Hàng Chính Hãng   2.340.000₫
# 38  Điện thoại Samsung Galaxy Z Fold 4 5G 512GB Ke...  42.000.000₫
# 39  Điện thoại Samsung Galaxy A04 32GB - Hàng chín...    2.400.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=XmWrLv7ER...      1     -28%
# 1   https://tka.tiki.vn/pixel/pixel?data=l4Cn3ojzL...      2     -13%
# 2   https://tka.tiki.vn/pixel/pixel?data=LDJ9YepT1...      3     -15%
# 3   https://tka.tiki.vn/pixel/pixel?data=TCIzI1hKu...      4      -5%
# 4   https://tka.tiki.vn/pixel/pixel?data=cr3CUdrS1...      5      -3%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/dien-thoai-oppo-a76-6gb-128gb-...     36      NaN
# 36  https://tiki.vn/dien-thoai-samsung-galaxy-a04s...     37      NaN
# 37  https://tiki.vn/dien-thoai-samsung-galaxy-a04e...     38      NaN
# 38  https://tiki.vn/dien-thoai-samsung-galaxy-z-fo...     39      NaN
# 39  https://tiki.vn/dien-thoai-samsung-galaxy-a04-...     40      NaN
#
#          sales    category
# 0   Đã bán 5k+  smartphone
# 1     Đã bán 2  smartphone
# 2     Đã bán 3  smartphone
# 3     Đã bán 5  smartphone
# 4     Đã bán 2  smartphone
# ..         ...         ...
# 35         NaN  smartphone
# 36         NaN  smartphone
# 37         NaN  smartphone
# 38         NaN  smartphone
# 39         NaN  smartphone
#
# [492 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                  title       price  \
# 0                      Điện Thoại Oppo A17k (3GB/64GB)  2.370.000₫
# 1    Điện thoại Vivo Y36 (8GB/128GB) - Hàng Chính H...  5.490.000₫
# 2    Điện thoại VIVO Y02t - Hàng chính hãng - Pin K...  2.790.000₫
# 3    [MỚI] Điện thoại vivo Y17s - Hàng chính hãng -...  3.790.000₫
# 4    [Mới] Điện thoại vivo V29e 5G (8GB/256GB) - Hà...  8.690.000₫
# ..                                                 ...         ...
# 153   Điện Thoại Realme C51 3GB/64GB - Hàng Chính Hãng  2.699.000₫
# 154  Điện thoại Xiaomi Redmi 9A 2GB/32GB Xám - Hàng...  2.088.000₫
# 155  Điện Thoại Samsung Galaxy A14 5G (4GB/128GB) -...  5.000.000₫
# 156  Điện thoại TECNO Spark 6 Go (4GB/64GB) - Hàng ...  2.559.000₫
# 157  Điện thoại OPPO A57 4GB/128GB Đen - Hàng chính...  3.850.000₫
#
#                                              link_item discount       sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=XmWrLv7ER...     -28%  Đã bán 5k+
# 1    https://tka.tiki.vn/pixel/pixel?data=l4Cn3ojzL...     -13%    Đã bán 2
# 2    https://tka.tiki.vn/pixel/pixel?data=LDJ9YepT1...     -15%    Đã bán 3
# 3    https://tka.tiki.vn/pixel/pixel?data=TCIzI1hKu...      -5%    Đã bán 5
# 4    https://tka.tiki.vn/pixel/pixel?data=cr3CUdrS1...      -3%    Đã bán 2
# ..                                                 ...      ...         ...
# 153  https://tiki.vn/dien-thoai-realme-c51-3gb-64gb...      NaN    Đã bán 1
# 154  https://tiki.vn/dien-thoai-xiaomi-redmi-9a-2gb...      NaN    Đã bán 1
# 155  https://tiki.vn/dien-thoai-samsung-galaxy-a14-...      NaN    Đã bán 1
# 156  https://tiki.vn/dien-thoai-tecno-spark-6-go-4g...      NaN    Đã bán 4
# 157  https://tiki.vn/dien-thoai-oppo-a57-4gb-128gb-...      NaN    Đã bán 1
#
#        category
# 0    smartphone
# 1    smartphone
# 2    smartphone
# 3    smartphone
# 4    smartphone
# ..          ...
# 153  smartphone
# 154  smartphone
# 155  smartphone
# 156  smartphone
# 157  smartphone
#
# [158 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0      2370000
# 1      5490000
# 2      2790000
# 3      3790000
# 4      8690000
#         ...
# 153    2699000
# 154    2088000
# 155    5000000
# 156    2559000
# 157    3850000
# Name: price, Length: 158, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0      5000.0
# 1         2.0
# 2         3.0
# 3         5.0
# 4         2.0
#         ...
# 153       1.0
# 154       1.0
# 155       1.0
# 156       4.0
# 157       1.0
# Name: sales, Length: 158, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0      1.185000e+10
# 1      1.098000e+07
# 2      8.370000e+06
# 3      1.895000e+07
# 4      1.738000e+07
#            ...
# 153    2.699000e+06
# 154    2.088000e+06
# 155    5.000000e+06
# 156    1.023600e+07
# 157    3.850000e+06
# Name: revenue, Length: 158, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số smartphone: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số smartphone:  290737454000.0
# So mat hang da ban:  158
# So san pham da ban:  41114.0

# %%
df_all
# Out:
#                                                  title    price  \
# 0                      Điện Thoại Oppo A17k (3GB/64GB)  2370000
# 1    Điện thoại Vivo Y36 (8GB/128GB) - Hàng Chính H...  5490000
# 2    Điện thoại VIVO Y02t - Hàng chính hãng - Pin K...  2790000
# 3    [MỚI] Điện thoại vivo Y17s - Hàng chính hãng -...  3790000
# 4    [Mới] Điện thoại vivo V29e 5G (8GB/256GB) - Hà...  8690000
# ..                                                 ...      ...
# 153   Điện Thoại Realme C51 3GB/64GB - Hàng Chính Hãng  2699000
# 154  Điện thoại Xiaomi Redmi 9A 2GB/32GB Xám - Hàng...  2088000
# 155  Điện Thoại Samsung Galaxy A14 5G (4GB/128GB) -...  5000000
# 156  Điện thoại TECNO Spark 6 Go (4GB/64GB) - Hàng ...  2559000
# 157  Điện thoại OPPO A57 4GB/128GB Đen - Hàng chính...  3850000
#
#                                              link_item discount   sales  \
# 0    https://tka.tiki.vn/pixel/pixel?data=XmWrLv7ER...     -28%  5000.0
# 1    https://tka.tiki.vn/pixel/pixel?data=l4Cn3ojzL...     -13%     2.0
# 2    https://tka.tiki.vn/pixel/pixel?data=LDJ9YepT1...     -15%     3.0
# 3    https://tka.tiki.vn/pixel/pixel?data=TCIzI1hKu...      -5%     5.0
# 4    https://tka.tiki.vn/pixel/pixel?data=cr3CUdrS1...      -3%     2.0
# ..                                                 ...      ...     ...
# 153  https://tiki.vn/dien-thoai-realme-c51-3gb-64gb...      NaN     1.0
# 154  https://tiki.vn/dien-thoai-xiaomi-redmi-9a-2gb...      NaN     1.0
# 155  https://tiki.vn/dien-thoai-samsung-galaxy-a14-...      NaN     1.0
# 156  https://tiki.vn/dien-thoai-tecno-spark-6-go-4g...      NaN     4.0
# 157  https://tiki.vn/dien-thoai-oppo-a57-4gb-128gb-...      NaN     1.0
#
#        category       revenue
# 0    smartphone  1.185000e+10
# 1    smartphone  1.098000e+07
# 2    smartphone  8.370000e+06
# 3    smartphone  1.895000e+07
# 4    smartphone  1.738000e+07
# ..          ...           ...
# 153  smartphone  2.699000e+06
# 154  smartphone  2.088000e+06
# 155  smartphone  5.000000e+06
# 156  smartphone  1.023600e+07
# 157  smartphone  3.850000e+06
#
# [158 rows x 7 columns]

# %%
df_all.to_csv("tk_smartphone_all_ed.csv")
