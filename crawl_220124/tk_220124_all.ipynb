# %%
import pandas as pd
import os 
import numpy as np
import matplotlib.pyplot as plt

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_220124"
os.listdir(path)
# Out:
# ['diengiadung',
#  'dienthoai_maytinhbang',
#  'dochoi_mevabe',
#  'thoitrangnam',
#  'thoitrangnu',
#  'tk_220124_all.ipynb',
#  'tk_diengiadung_all_ed.csv',
#  'tk_dienthoai_all_ed.csv',
#  'tk_mevabe_all_ed.csv',
#  'tk_thoitrangnam_all_ed.csv',
#  'tk_thoitrangnu_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_220124_all.csv", index="False")

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1249000
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   229000
# 2     Máy ép chậm Elmich JEE - 1855OL - Hàng chính h...  1849000
# 3     Lẩu điện Sunhouse SHD4528, Công suất 1200W, Du...   547000
# 4     Ấm Siêu Tốc Sunhouse SHD1306 (1.7 Lít) - Hàn...   359000
# ...                                                 ...      ...
# 8098  Đầm xòe thiết kế trung niên cao cấp sang trọng...   480000
# 8099  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...   235000
# 8100  Bộ quần áo trung niên nữ_ đồ bộ mặc nhà chất v...   149000
# 8101                                Quần Áo cho mẹ (bộ)    59950
# 8102  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...   225000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=07ctn9JP6...     -20%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=0iVHEp30s...     -46%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=6xX2mPSyZ...     -52%   329.0
# 3     https://tka.tiki.vn/pixel/pixel?data=OZ06fuKoN...     -39%     7.0
# 4     https://tka.tiki.vn/pixel/pixel?data=jJGFGzTp7...     -46%   572.0
# ...                                                 ...      ...     ...
# 8098  https://tiki.vn/dam-xoe-thiet-ke-trung-nien-ca...      NaN     1.0
# 8099  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN     1.0
# 8100  https://tiki.vn/bo-quan-ao-trung-nien-nu_-do-b...      NaN     3.0
# 8101  https://tiki.vn/quan-ao-cho-me-bo-p88085979.ht...      NaN     3.0
# 8102  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN     3.0
#
#                item_list     category       revenue  index
# 0           dodungnhabep  diengiadung  1.623700e+09    NaN
# 1           dodungnhabep  diengiadung  1.145000e+09    NaN
# 2           dodungnhabep  diengiadung  6.083210e+08    NaN
# 3           dodungnhabep  diengiadung  3.829000e+06    NaN
# 4           dodungnhabep  diengiadung  2.053480e+08    NaN
# ...                  ...          ...           ...    ...
# 8098  thoitrangtrungnien  thoitrangnu  4.800000e+05    NaN
# 8099  thoitrangtrungnien  thoitrangnu  2.350000e+05    NaN
# 8100  thoitrangtrungnien  thoitrangnu  4.470000e+05    NaN
# 8101  thoitrangtrungnien  thoitrangnu  1.798500e+05    NaN
# 8102  thoitrangtrungnien  thoitrangnu  6.750000e+05    NaN
#
# [28157 rows x 9 columns]

# %%
df_all = df_all.drop('index', axis=1)
df_all["day"] = "22jan"
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                    title    price  \
# 0      Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1249000
# 1      Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   229000
# 2      Máy ép chậm Elmich JEE - 1855OL - Hàng chính h...  1849000
# 3      Lẩu điện Sunhouse SHD4528, Công suất 1200W, Du...   547000
# 4      Ấm Siêu Tốc Sunhouse SHD1306 (1.7 Lít) - Hàn...   359000
# ...                                                  ...      ...
# 28152  Đầm xòe thiết kế trung niên cao cấp sang trọng...   480000
# 28153  Bộ Đũi Trung Niên Hoa Thêu Cực Đẹp Vải Mát Đườ...   235000
# 28154  Bộ quần áo trung niên nữ_ đồ bộ mặc nhà chất v...   149000
# 28155                                Quần Áo cho mẹ (bộ)    59950
# 28156  ( HÀNG SẴN) Áo Voan Trung Niên Tay Lỡ Đẹp SM54...   225000
#
#                                                link_item discount   sales  \
# 0      https://tka.tiki.vn/pixel/pixel?data=07ctn9JP6...     -20%  1300.0
# 1      https://tka.tiki.vn/pixel/pixel?data=0iVHEp30s...     -46%  5000.0
# 2      https://tka.tiki.vn/pixel/pixel?data=6xX2mPSyZ...     -52%   329.0
# 3      https://tka.tiki.vn/pixel/pixel?data=OZ06fuKoN...     -39%     7.0
# 4      https://tka.tiki.vn/pixel/pixel?data=jJGFGzTp7...     -46%   572.0
# ...                                                  ...      ...     ...
# 28152  https://tiki.vn/dam-xoe-thiet-ke-trung-nien-ca...      NaN     1.0
# 28153  https://tiki.vn/bo-dui-trung-nien-hoa-theu-cuc...      NaN     1.0
# 28154  https://tiki.vn/bo-quan-ao-trung-nien-nu_-do-b...      NaN     3.0
# 28155  https://tiki.vn/quan-ao-cho-me-bo-p88085979.ht...      NaN     3.0
# 28156  https://tiki.vn/hang-san-ao-voan-trung-nien-ta...      NaN     3.0
#
#                 item_list     category       revenue    day
# 0            dodungnhabep  diengiadung  1.623700e+09  22jan
# 1            dodungnhabep  diengiadung  1.145000e+09  22jan
# 2            dodungnhabep  diengiadung  6.083210e+08  22jan
# 3            dodungnhabep  diengiadung  3.829000e+06  22jan
# 4            dodungnhabep  diengiadung  2.053480e+08  22jan
# ...                   ...          ...           ...    ...
# 28152  thoitrangtrungnien  thoitrangnu  4.800000e+05  22jan
# 28153  thoitrangtrungnien  thoitrangnu  2.350000e+05  22jan
# 28154  thoitrangtrungnien  thoitrangnu  4.470000e+05  22jan
# 28155  thoitrangtrungnien  thoitrangnu  1.798500e+05  22jan
# 28156  thoitrangtrungnien  thoitrangnu  6.750000e+05  22jan
#
# [28157 rows x 9 columns]

# %%
df_all.to_csv("tk_220124_all_ed.csv")
