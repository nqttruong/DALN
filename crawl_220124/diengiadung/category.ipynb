# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\diengiadung"
os.listdir(path)
# Out:
# ['brand - Copy',
#  'category.ipynb',
#  'dodungnhabep',
#  'thietbigiadinh',
#  'tk_dodungnhabep_all_ed.csv',
#  'tk_thietbigiadinh_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#       Unnamed: 0                                              title    price  \
# 0              0  Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1249000
# 1              1  Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   229000
# 2              2  Máy ép chậm Elmich JEE - 1855OL - Hàng chính h...  1849000
# 3              3  Lẩu điện Sunhouse SHD4528, Công suất 1200W, Du...   547000
# 4              4  Ấm Siêu Tốc Sunhouse SHD1306 (1.7 Lít) - Hàn...   359000
# ...          ...                                                ...      ...
# 1288        1288                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP   390000
# 1289        1289  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...   450000
# 1290        1290  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1589000
# 1291        1291  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    58000
# 1292        1292  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   629000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=07ctn9JP6...     -20%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=0iVHEp30s...     -46%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=6xX2mPSyZ...     -52%   329.0
# 3     https://tka.tiki.vn/pixel/pixel?data=OZ06fuKoN...     -39%     7.0
# 4     https://tka.tiki.vn/pixel/pixel?data=jJGFGzTp7...     -46%   572.0
# ...                                                 ...      ...     ...
# 1288  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    26.0
# 1289  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    14.0
# 1290  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    39.0
# 1291  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1292  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   395.0
#
#             category       revenue
# 0       dodungnhabep  1.623700e+09
# 1       dodungnhabep  1.145000e+09
# 2       dodungnhabep  6.083210e+08
# 3       dodungnhabep  3.829000e+06
# 4       dodungnhabep  2.053480e+08
# ...              ...           ...
# 1288  thietbigiadinh  1.014000e+07
# 1289  thietbigiadinh  6.300000e+06
# 1290  thietbigiadinh  6.197100e+07
# 1291  thietbigiadinh  1.450000e+06
# 1292  thietbigiadinh  2.484550e+08
#
# [2631 rows x 8 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "diengiadung")

# %%
df
# Out:
#                                                   title    price  \
# 0     Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1249000
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   229000
# 2     Máy ép chậm Elmich JEE - 1855OL - Hàng chính h...  1849000
# 3     Lẩu điện Sunhouse SHD4528, Công suất 1200W, Du...   547000
# 4     Ấm Siêu Tốc Sunhouse SHD1306 (1.7 Lít) - Hàn...   359000
# ...                                                 ...      ...
# 1288                    MÁY DUỖI TÓC TOKYO 100% CAO CẤP   390000
# 1289  Máy phun sương tạo ẩm dùng cho ô tô, xe hơi nh...   450000
# 1290  Bàn Ủi Điện Panasonic NI-U600CARA (2300W) - Hà...  1589000
# 1291  Máy Hút Bụi Cầm Tay Mini Không Dây 6000Mpa Siê...    58000
# 1292  Bàn là hơi nước cầm tay LEBENLANG LBD528S nhập...   629000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=07ctn9JP6...     -20%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=0iVHEp30s...     -46%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=6xX2mPSyZ...     -52%   329.0
# 3     https://tka.tiki.vn/pixel/pixel?data=OZ06fuKoN...     -39%     7.0
# 4     https://tka.tiki.vn/pixel/pixel?data=jJGFGzTp7...     -46%   572.0
# ...                                                 ...      ...     ...
# 1288  https://tiki.vn/may-duoi-toc-tokyo-100-cao-cap...      NaN    26.0
# 1289  https://tiki.vn/may-phun-suong-tao-am-dung-cho...      NaN    14.0
# 1290  https://tiki.vn/ban-ui-dien-panasonic-ni-u600c...      NaN    39.0
# 1291  https://tiki.vn/hla-may-hut-bui-cam-tay-mini-k...      NaN    25.0
# 1292  https://tiki.vn/ban-la-hoi-nuoc-cam-tay-lebenl...      NaN   395.0
#
#            item_list     category       revenue
# 0       dodungnhabep  diengiadung  1.623700e+09
# 1       dodungnhabep  diengiadung  1.145000e+09
# 2       dodungnhabep  diengiadung  6.083210e+08
# 3       dodungnhabep  diengiadung  3.829000e+06
# 4       dodungnhabep  diengiadung  2.053480e+08
# ...              ...          ...           ...
# 1288  thietbigiadinh  diengiadung  1.014000e+07
# 1289  thietbigiadinh  diengiadung  6.300000e+06
# 1290  thietbigiadinh  diengiadung  6.197100e+07
# 1291  thietbigiadinh  diengiadung  1.450000e+06
# 1292  thietbigiadinh  diengiadung  2.484550e+08
#
# [2631 rows x 8 columns]

# %%
df.to_csv('tk_diengiadung_all_ed.csv', index=False, encoding='utf-8')
