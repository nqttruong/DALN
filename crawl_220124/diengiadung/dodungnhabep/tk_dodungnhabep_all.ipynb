# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\diengiadung\dodungnhabep"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dgd_ddnb.ipynb',
#  'tk_dgd_ddnb_npage.ipynb',
#  'tk_dodungnhabep.csv',
#  'tk_dodungnhabep_all.ipynb',
#  'tk_dodungnhabep_t10.csv',
#  'tk_dodungnhabep_t11.csv',
#  'tk_dodungnhabep_t12.csv',
#  'tk_dodungnhabep_t13.csv',
#  'tk_dodungnhabep_t14.csv',
#  'tk_dodungnhabep_t15.csv',
#  'tk_dodungnhabep_t16.csv',
#  'tk_dodungnhabep_t17.csv',
#  'tk_dodungnhabep_t18.csv',
#  'tk_dodungnhabep_t19.csv',
#  'tk_dodungnhabep_t2.csv',
#  'tk_dodungnhabep_t20.csv',
#  'tk_dodungnhabep_t21.csv',
#  'tk_dodungnhabep_t22.csv',
#  'tk_dodungnhabep_t23.csv',
#  'tk_dodungnhabep_t24.csv',
#  'tk_dodungnhabep_t25.csv',
#  'tk_dodungnhabep_t26.csv',
#  'tk_dodungnhabep_t27.csv',
#  'tk_dodungnhabep_t28.csv',
#  'tk_dodungnhabep_t29.csv',
#  'tk_dodungnhabep_t3.csv',
#  'tk_dodungnhabep_t30.csv',
#  'tk_dodungnhabep_t31.csv',
#  'tk_dodungnhabep_t32.csv',
#  'tk_dodungnhabep_t33.csv',
#  'tk_dodungnhabep_t34.csv',
#  'tk_dodungnhabep_t35.csv',
#  'tk_dodungnhabep_t36.csv',
#  'tk_dodungnhabep_t37.csv',
#  'tk_dodungnhabep_t38.csv',
#  'tk_dodungnhabep_t39.csv',
#  'tk_dodungnhabep_t4.csv',
#  'tk_dodungnhabep_t40.csv',
#  'tk_dodungnhabep_t41.csv',
#  'tk_dodungnhabep_t42.csv',
#  'tk_dodungnhabep_t43.csv',
#  'tk_dodungnhabep_t44.csv',
#  'tk_dodungnhabep_t45.csv',
#  'tk_dodungnhabep_t46.csv',
#  'tk_dodungnhabep_t47.csv',
#  'tk_dodungnhabep_t48.csv',
#  'tk_dodungnhabep_t49.csv',
#  'tk_dodungnhabep_t5.csv',
#  'tk_dodungnhabep_t50.csv',
#  'tk_dodungnhabep_t6.csv',
#  'tk_dodungnhabep_t7.csv',
#  'tk_dodungnhabep_t8.csv',
#  'tk_dodungnhabep_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dodungnhabep_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1.249.000₫
# 1   Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...    229.000₫
# 2   Máy ép chậm Elmich JEE - 1855OL - Hàng chính h...  1.849.000₫
# 3   Lẩu điện Sunhouse SHD4528, Công suất 1200W, Du...    547.000₫
# 4   Ấm Siêu Tốc Sunhouse SHD1306 (1.7 Lít) - Hàn...    359.000₫
# ..                                                ...         ...
# 35                                                NaN         NaN
# 36  Nồi Chiên Không Dầu Elmich AFE-3950 (14Lít) - ...  2.989.000₫
# 37  Bình đun siêu tốc thông minh 1.7L Tefal Smart ...  1.549.000₫
# 38  Bếp Điện Từ Đôi Kangaroo KG498N (3100W) - Hàng...  2.159.000₫
# 39  Lò Vi Sóng Tráng Men Samsung Dòng Vi Sóng MS23...   1.785.000
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=07ctn9JP6...      1     -20%
# 1   https://tka.tiki.vn/pixel/pixel?data=0iVHEp30s...      2     -46%
# 2   https://tka.tiki.vn/pixel/pixel?data=6xX2mPSyZ...      3     -52%
# 3   https://tka.tiki.vn/pixel/pixel?data=OZ06fuKoN...      4     -39%
# 4   https://tka.tiki.vn/pixel/pixel?data=jJGFGzTp7...      5     -46%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/may-lam-sua-hat-da-nang-locknl...     36      NaN
# 36  https://tiki.vn/noi-chien-khong-dau-elmich-afe...     37      NaN
# 37  https://tiki.vn/binh-dun-sieu-toc-thong-minh-1...     38      NaN
# 38  https://tiki.vn/bep-dien-tu-doi-kangaroo-kg498...     39      NaN
# 39  https://tiki.vn/lo-vi-song-trang-men-samsung-d...     40      NaN
#
#           sales      category
# 0   Đã bán 1.3k  dodungnhabep
# 1    Đã bán 5k+  dodungnhabep
# 2    Đã bán 329  dodungnhabep
# 3      Đã bán 7  dodungnhabep
# 4    Đã bán 572  dodungnhabep
# ..          ...           ...
# 35          NaN  dodungnhabep
# 36    Đã bán 50  dodungnhabep
# 37   Đã bán 444  dodungnhabep
# 38   Đã bán 578  dodungnhabep
# 39          NaN  dodungnhabep
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1.249.000₫
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...    229.000₫
# 2     Máy ép chậm Elmich JEE - 1855OL - Hàng chính h...  1.849.000₫
# 3     Lẩu điện Sunhouse SHD4528, Công suất 1200W, Du...    547.000₫
# 4     Ấm Siêu Tốc Sunhouse SHD1306 (1.7 Lít) - Hàn...    359.000₫
# ...                                                 ...         ...
# 1333  Bình Đun Siêu Tốc 2 Lớp Damas DK-6018 1.8L - T...    395.000₫
# 1334                   Máy Nướng Bánh Nikai Kẹp Bánh Mỳ    217.651₫
# 1335  Nồi Chiên Không Dầu Elmich AFE-3950 (14Lít) - ...  2.989.000₫
# 1336  Bình đun siêu tốc thông minh 1.7L Tefal Smart ...  1.549.000₫
# 1337  Bếp Điện Từ Đôi Kangaroo KG498N (3100W) - Hàng...  2.159.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=07ctn9JP6...     -20%  Đã bán 1.3k
# 1     https://tka.tiki.vn/pixel/pixel?data=0iVHEp30s...     -46%   Đã bán 5k+
# 2     https://tka.tiki.vn/pixel/pixel?data=6xX2mPSyZ...     -52%   Đã bán 329
# 3     https://tka.tiki.vn/pixel/pixel?data=OZ06fuKoN...     -39%     Đã bán 7
# 4     https://tka.tiki.vn/pixel/pixel?data=jJGFGzTp7...     -46%   Đã bán 572
# ...                                                 ...      ...          ...
# 1333  https://tiki.vn/binh-dun-sieu-toc-2-lop-damas-...      NaN    Đã bán 35
# 1334  https://tiki.vn/may-nuong-banh-nikai-kep-banh-...      NaN    Đã bán 21
# 1335  https://tiki.vn/noi-chien-khong-dau-elmich-afe...      NaN    Đã bán 50
# 1336  https://tiki.vn/binh-dun-sieu-toc-thong-minh-1...      NaN   Đã bán 444
# 1337  https://tiki.vn/bep-dien-tu-doi-kangaroo-kg498...      NaN   Đã bán 578
#
#           category
# 0     dodungnhabep
# 1     dodungnhabep
# 2     dodungnhabep
# 3     dodungnhabep
# 4     dodungnhabep
# ...            ...
# 1333  dodungnhabep
# 1334  dodungnhabep
# 1335  dodungnhabep
# 1336  dodungnhabep
# 1337  dodungnhabep
#
# [1338 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       1249000
# 1        229000
# 2       1849000
# 3        547000
# 4        359000
#          ...
# 1333     395000
# 1334     217651
# 1335    2989000
# 1336    1549000
# 1337    2159000
# Name: price, Length: 1338, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       1300.0
# 1       5000.0
# 2        329.0
# 3          7.0
# 4        572.0
#          ...
# 1333      35.0
# 1334      21.0
# 1335      50.0
# 1336     444.0
# 1337     578.0
# Name: sales, Length: 1338, dtype: float64

# %%
print(set(df_all["sales"]))
# Out:
# {1.0, 2.0, 3.0, 4100.0, 5.0, 6.0, 7.0, 8.0, 9.0, 4.0, 11.0, 10.0, 13.0, 14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0, 32.0, 33.0, 35.0, 36.0, 37.0, 38.0, 39.0, 40.0, 41.0, 42.0, 43.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 2100.0, 52.0, 53.0, 54.0, 56.0, 55.0, 58.0, 59.0, 57.0, 12.0, 61.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 62.0, 70.0, 71.0, 72.0, 73.0, 74.0, 75.0, 76.0, 77.0, 78.0, 79.0, 80.0, 81.0, 82.0, 83.0, 85.0, 86.0, 87.0, 88.0, 89.0, 90.0, 91.0, 92.0, 93.0, 94.0, 95.0, 96.0, 97.0, 99.0, 100.0, 101.0, 103.0, 4200.0, 105.0, 106.0, 107.0, 104.0, 109.0, 110.0, 111.0, 112.0, 113.0, 114.0, 115.0, 116.0, 117.0, 118.0, 119.0, 120.0, 122.0, 124.0, 126.0, 128.0, 129.0, 132.0, 133.0, 134.0, 135.0, 138.0, 139.0, 141.0, 144.0, 147.0, 149.0, 150.0, 151.0, 2200.0, 154.0, 155.0, 159.0, 160.0, 163.0, 164.0, 165.0, 166.0, 168.0, 169.0, 170.0, 171.0, 172.0, 173.0, 175.0, 177.0, 179.0, 180.0, 183.0, 185.0, 186.0, 188.0, 189.0, 190.0, 192.0, 194.0, 195.0, 197.0, 202.0, 4300.0, 205.0, 206.0, 207.0, 211.0, 212.0, 213.0, 217.0, 219.0, 220.0, 222.0, 223.0, 225.0, 227.0, 229.0, 230.0, 236.0, 237.0, 240.0, 244.0, 247.0, 248.0, 249.0, 250.0, 251.0, 2300.0, 253.0, 254.0, 258.0, 261.0, 264.0, 265.0, 266.0, 272.0, 276.0, 278.0, 279.0, 285.0, 288.0, 297.0, 299.0, 303.0, 305.0, 310.0, 313.0, 321.0, 323.0, 328.0, 329.0, 336.0, 337.0, 345.0, 348.0, 69.0, 2400.0, 362.0, 370.0, 374.0, 378.0, 379.0, 380.0, 386.0, 388.0, 391.0, 398.0, 406.0, 411.0, 414.0, 422.0, 423.0, 429.0, 439.0, 440.0, 444.0, 451.0, 2500.0, 458.0, 464.0, 472.0, 476.0, 477.0, 482.0, 488.0, 493.0, 496.0, 497.0, 509.0, 510.0, 513.0, 514.0, 536.0, 544.0, 2600.0, 559.0, 568.0, 572.0, 578.0, 581.0, 596.0, 602.0, 606.0, 613.0, 619.0, 638.0, 645.0, 2700.0, 667.0, 669.0, 688.0, 706.0, 714.0, 726.0, 747.0, 751.0, 2800.0, 779.0, 794.0, 796.0, 800.0, 816.0, 842.0, 2900.0, 5000.0, 905.0, 936.0, 938.0, 940.0, 3000.0, 958.0, 965.0, 983.0, 988.0, 992.0, 996.0, 1000.0, 1100.0, 1200.0, 3300.0, 1300.0, 3400.0, 1400.0, 1500.0, 3600.0, 3700.0, 1700.0, 3800.0, 3900.0, 1900.0, 2000.0}

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1.623700e+09
# 1       1.145000e+09
# 2       6.083210e+08
# 3       3.829000e+06
# 4       2.053480e+08
#             ...
# 1333    1.382500e+07
# 1334    4.570671e+06
# 1335    1.494500e+08
# 1336    6.877560e+08
# 1337    1.247902e+09
# Name: revenue, Length: 1338, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số đồ dùng nhà bếp: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số đồ dùng nhà bếp:  283509708401.0
# So mat hang da ban:  1338
# So san pham da ban:  384615.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Lò Vi Sóng Sharp R-208VN-WS (20L) - Hàng Chính...  1249000
# 1     Ấm Đun Siêu Tốc Inox 2 Lớp Sunhouse SHD1351 (1...   229000
# 2     Máy ép chậm Elmich JEE - 1855OL - Hàng chính h...  1849000
# 3     Lẩu điện Sunhouse SHD4528, Công suất 1200W, Du...   547000
# 4     Ấm Siêu Tốc Sunhouse SHD1306 (1.7 Lít) - Hàn...   359000
# ...                                                 ...      ...
# 1333  Bình Đun Siêu Tốc 2 Lớp Damas DK-6018 1.8L - T...   395000
# 1334                   Máy Nướng Bánh Nikai Kẹp Bánh Mỳ   217651
# 1335  Nồi Chiên Không Dầu Elmich AFE-3950 (14Lít) - ...  2989000
# 1336  Bình đun siêu tốc thông minh 1.7L Tefal Smart ...  1549000
# 1337  Bếp Điện Từ Đôi Kangaroo KG498N (3100W) - Hàng...  2159000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=07ctn9JP6...     -20%  1300.0
# 1     https://tka.tiki.vn/pixel/pixel?data=0iVHEp30s...     -46%  5000.0
# 2     https://tka.tiki.vn/pixel/pixel?data=6xX2mPSyZ...     -52%   329.0
# 3     https://tka.tiki.vn/pixel/pixel?data=OZ06fuKoN...     -39%     7.0
# 4     https://tka.tiki.vn/pixel/pixel?data=jJGFGzTp7...     -46%   572.0
# ...                                                 ...      ...     ...
# 1333  https://tiki.vn/binh-dun-sieu-toc-2-lop-damas-...      NaN    35.0
# 1334  https://tiki.vn/may-nuong-banh-nikai-kep-banh-...      NaN    21.0
# 1335  https://tiki.vn/noi-chien-khong-dau-elmich-afe...      NaN    50.0
# 1336  https://tiki.vn/binh-dun-sieu-toc-thong-minh-1...      NaN   444.0
# 1337  https://tiki.vn/bep-dien-tu-doi-kangaroo-kg498...      NaN   578.0
#
#           category       revenue
# 0     dodungnhabep  1.623700e+09
# 1     dodungnhabep  1.145000e+09
# 2     dodungnhabep  6.083210e+08
# 3     dodungnhabep  3.829000e+06
# 4     dodungnhabep  2.053480e+08
# ...            ...           ...
# 1333  dodungnhabep  1.382500e+07
# 1334  dodungnhabep  4.570671e+06
# 1335  dodungnhabep  1.494500e+08
# 1336  dodungnhabep  6.877560e+08
# 1337  dodungnhabep  1.247902e+09
#
# [1338 rows x 7 columns]

# %%
df_all.to_csv("tk_dodungnhabep_all_ed.csv")
