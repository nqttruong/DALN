# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\thoitrangnam\aovest"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_aovest.csv',
#  'tk_aovest_all.ipynb',
#  'tk_ttnam_aovest.ipynb',
#  'tk_ttnam_aovest_npage.ipynb',
#  'tk_ttnam_aovest_t10.csv',
#  'tk_ttnam_aovest_t11.csv',
#  'tk_ttnam_aovest_t12.csv',
#  'tk_ttnam_aovest_t13.csv',
#  'tk_ttnam_aovest_t14.csv',
#  'tk_ttnam_aovest_t15.csv',
#  'tk_ttnam_aovest_t16.csv',
#  'tk_ttnam_aovest_t17.csv',
#  'tk_ttnam_aovest_t18.csv',
#  'tk_ttnam_aovest_t19.csv',
#  'tk_ttnam_aovest_t2.csv',
#  'tk_ttnam_aovest_t20.csv',
#  'tk_ttnam_aovest_t21.csv',
#  'tk_ttnam_aovest_t22.csv',
#  'tk_ttnam_aovest_t23.csv',
#  'tk_ttnam_aovest_t24.csv',
#  'tk_ttnam_aovest_t25.csv',
#  'tk_ttnam_aovest_t26.csv',
#  'tk_ttnam_aovest_t27.csv',
#  'tk_ttnam_aovest_t28.csv',
#  'tk_ttnam_aovest_t29.csv',
#  'tk_ttnam_aovest_t3.csv',
#  'tk_ttnam_aovest_t30.csv',
#  'tk_ttnam_aovest_t31.csv',
#  'tk_ttnam_aovest_t32.csv',
#  'tk_ttnam_aovest_t33.csv',
#  'tk_ttnam_aovest_t34.csv',
#  'tk_ttnam_aovest_t35.csv',
#  'tk_ttnam_aovest_t36.csv',
#  'tk_ttnam_aovest_t37.csv',
#  'tk_ttnam_aovest_t38.csv',
#  'tk_ttnam_aovest_t39.csv',
#  'tk_ttnam_aovest_t4.csv',
#  'tk_ttnam_aovest_t40.csv',
#  'tk_ttnam_aovest_t41.csv',
#  'tk_ttnam_aovest_t42.csv',
#  'tk_ttnam_aovest_t43.csv',
#  'tk_ttnam_aovest_t44.csv',
#  'tk_ttnam_aovest_t45.csv',
#  'tk_ttnam_aovest_t46.csv',
#  'tk_ttnam_aovest_t47.csv',
#  'tk_ttnam_aovest_t48.csv',
#  'tk_ttnam_aovest_t49.csv',
#  'tk_ttnam_aovest_t5.csv',
#  'tk_ttnam_aovest_t50.csv',
#  'tk_ttnam_aovest_t6.csv',
#  'tk_ttnam_aovest_t7.csv',
#  'tk_ttnam_aovest_t8.csv',
#  'tk_ttnam_aovest_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_aovest_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   áo vest nam phong cách Hàn quốc siêu ngầu, trư...  357.500₫
# 1   Áo khoác nam chống nắng gió thu đông Doka (DBL...  139.000₫
# 2   Áo Phao Chần Bông Nam 5S FASHION PREMIUM, Chất...  519.000₫
# 3   Áo vest,áo vest nam với chất POLY chéo hàn cao...  352.080₫
# 4   Áo len Nam Áo Cardigan nam chất liệu Len dệt c...  358.000₫
# ..                                                ...       ...
# 35  Áo Khoác Nam 2 Lớp Lót Lông Thời Trang Cao Cấp...  300.000₫
# 36  Bộ vest nam 1 cúc màu ghi sáng cực sang DKA013...  687.000₫
# 37  Áo khoác dù , áo khoác gió nam nữ mặc , áo kho...   97.000₫
# 38                             Áo Khoác Da Bomber Nam  175.000₫
# 39                       Áo khoác dù nam 2 lớp thêu N   49.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=t3oEAa6Lu...      1     -35%
# 1   https://tka.tiki.vn/pixel/pixel?data=lvfBA9yFC...      2     -39%
# 2   https://tka.tiki.vn/pixel/pixel?data=Tqbt3l_1F...      3     -48%
# 3   https://tka.tiki.vn/pixel/pixel?data=cPpYzTTO-...      4     -28%
# 4   https://tka.tiki.vn/pixel/pixel?data=Mh88FPF78...      5     -31%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ao-khoac-nam-2-lop-lot-long-th...     36      NaN
# 36  https://tiki.vn/bo-vest-nam-1-cuc-mau-ghi-sang...     37      NaN
# 37  https://tiki.vn/ao-khoac-du-ao-khoac-gio-nam-n...     38      NaN
# 38  https://tiki.vn/ao-khoac-da-bomber-nam-p466887...     39      NaN
# 39  https://tiki.vn/ao-khoac-du-nam-2-lop-theu-n-p...     40      NaN
#
#          sales category
# 0    Đã bán 12   aovest
# 1   Đã bán 911   aovest
# 2    Đã bán 25   aovest
# 3    Đã bán 19   aovest
# 4     Đã bán 3   aovest
# ..         ...      ...
# 35   Đã bán 22   aovest
# 36         NaN   aovest
# 37  Đã bán 142   aovest
# 38   Đã bán 41   aovest
# 39   Đã bán 29   aovest
#
# [2030 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     áo vest nam phong cách Hàn quốc siêu ngầu, trư...  357.500₫
# 1     Áo khoác nam chống nắng gió thu đông Doka (DBL...  139.000₫
# 2     Áo Phao Chần Bông Nam 5S FASHION PREMIUM, Chất...  519.000₫
# 3     Áo vest,áo vest nam với chất POLY chéo hàn cao...  352.080₫
# 4     Áo len Nam Áo Cardigan nam chất liệu Len dệt c...  358.000₫
# ...                                                 ...       ...
# 1254  Áo măng tô nam form rộng Sans22 khoác dạ blaze...  699.999₫
# 1255  Áo Khoác Nam 2 Lớp Lót Lông Thời Trang Cao Cấp...  300.000₫
# 1256  Áo khoác dù , áo khoác gió nam nữ mặc , áo kho...   97.000₫
# 1257                             Áo Khoác Da Bomber Nam  175.000₫
# 1258                       Áo khoác dù nam 2 lớp thêu N   49.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=t3oEAa6Lu...     -35%   Đã bán 12
# 1     https://tka.tiki.vn/pixel/pixel?data=lvfBA9yFC...     -39%  Đã bán 911
# 2     https://tka.tiki.vn/pixel/pixel?data=Tqbt3l_1F...     -48%   Đã bán 25
# 3     https://tka.tiki.vn/pixel/pixel?data=cPpYzTTO-...     -28%   Đã bán 19
# 4     https://tka.tiki.vn/pixel/pixel?data=Mh88FPF78...     -31%    Đã bán 3
# ...                                                 ...      ...         ...
# 1254  https://tiki.vn/ao-mang-to-nam-form-rong-sans2...      NaN    Đã bán 2
# 1255  https://tiki.vn/ao-khoac-nam-2-lop-lot-long-th...      NaN   Đã bán 22
# 1256  https://tiki.vn/ao-khoac-du-ao-khoac-gio-nam-n...      NaN  Đã bán 142
# 1257  https://tiki.vn/ao-khoac-da-bomber-nam-p466887...      NaN   Đã bán 41
# 1258  https://tiki.vn/ao-khoac-du-nam-2-lop-theu-n-p...      NaN   Đã bán 29
#
#      category
# 0      aovest
# 1      aovest
# 2      aovest
# 3      aovest
# 4      aovest
# ...       ...
# 1254   aovest
# 1255   aovest
# 1256   aovest
# 1257   aovest
# 1258   aovest
#
# [1259 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       357500
# 1       139000
# 2       519000
# 3       352080
# 4       358000
#          ...
# 1254    699999
# 1255    300000
# 1256     97000
# 1257    175000
# 1258     49000
# Name: price, Length: 1259, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        12.0
# 1       911.0
# 2        25.0
# 3        19.0
# 4         3.0
#         ...
# 1254      2.0
# 1255     22.0
# 1256    142.0
# 1257     41.0
# 1258     29.0
# Name: sales, Length: 1259, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0         4290000.0
# 1       126629000.0
# 2        12975000.0
# 3         6689520.0
# 4         1074000.0
#            ...
# 1254      1399998.0
# 1255      6600000.0
# 1256     13774000.0
# 1257      7175000.0
# 1258      1421000.0
# Name: revenue, Length: 1259, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số aovest: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số aovest:  11718133824.0
# So mat hang da ban:  1259
# So san pham da ban:  55173.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     áo vest nam phong cách Hàn quốc siêu ngầu, trư...  357500
# 1     Áo khoác nam chống nắng gió thu đông Doka (DBL...  139000
# 2     Áo Phao Chần Bông Nam 5S FASHION PREMIUM, Chất...  519000
# 3     Áo vest,áo vest nam với chất POLY chéo hàn cao...  352080
# 4     Áo len Nam Áo Cardigan nam chất liệu Len dệt c...  358000
# ...                                                 ...     ...
# 1254  Áo măng tô nam form rộng Sans22 khoác dạ blaze...  699999
# 1255  Áo Khoác Nam 2 Lớp Lót Lông Thời Trang Cao Cấp...  300000
# 1256  Áo khoác dù , áo khoác gió nam nữ mặc , áo kho...   97000
# 1257                             Áo Khoác Da Bomber Nam  175000
# 1258                       Áo khoác dù nam 2 lớp thêu N   49000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=t3oEAa6Lu...     -35%   12.0
# 1     https://tka.tiki.vn/pixel/pixel?data=lvfBA9yFC...     -39%  911.0
# 2     https://tka.tiki.vn/pixel/pixel?data=Tqbt3l_1F...     -48%   25.0
# 3     https://tka.tiki.vn/pixel/pixel?data=cPpYzTTO-...     -28%   19.0
# 4     https://tka.tiki.vn/pixel/pixel?data=Mh88FPF78...     -31%    3.0
# ...                                                 ...      ...    ...
# 1254  https://tiki.vn/ao-mang-to-nam-form-rong-sans2...      NaN    2.0
# 1255  https://tiki.vn/ao-khoac-nam-2-lop-lot-long-th...      NaN   22.0
# 1256  https://tiki.vn/ao-khoac-du-ao-khoac-gio-nam-n...      NaN  142.0
# 1257  https://tiki.vn/ao-khoac-da-bomber-nam-p466887...      NaN   41.0
# 1258  https://tiki.vn/ao-khoac-du-nam-2-lop-theu-n-p...      NaN   29.0
#
#      category      revenue
# 0      aovest    4290000.0
# 1      aovest  126629000.0
# 2      aovest   12975000.0
# 3      aovest    6689520.0
# 4      aovest    1074000.0
# ...       ...          ...
# 1254   aovest    1399998.0
# 1255   aovest    6600000.0
# 1256   aovest   13774000.0
# 1257   aovest    7175000.0
# 1258   aovest    1421000.0
#
# [1259 rows x 7 columns]

# %%
df_all.to_csv("tk_aovest_all_ed.csv")
