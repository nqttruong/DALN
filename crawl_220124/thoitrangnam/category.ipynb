# %%
import pandas as pd
import os

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\thoitrangnam"
os.listdir(path)
# Out:
# ['aohoodie',
#  'aoni',
#  'aosomi',
#  'aothunnam',
#  'aovest',
#  'brand',
#  'category.ipynb',
#  'doboi',
#  'dodoi',
#  'dolot',
#  'dongu',
#  'quanaokichcolon',
#  'quanaotrungnien',
#  'quannam',
#  'tk_aohoodie_all_ed.csv',
#  'tk_aoni_all_ed.csv',
#  'tk_aosomi_all_ed.csv',
#  'tk_aothunnam_all_ed.csv',
#  'tk_aovest_all_ed.csv',
#  'tk_doboi_all_ed.csv',
#  'tk_dodoi_all_ed.csv',
#  'tk_dolot_all_ed.csv',
#  'tk_dongu_all_ed.csv',
#  'tk_quanaokichcolon_all_ed.csv',
#  'tk_quanaotrungnien_all_ed.csv',
#  'tk_quannam_all_ed.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df = result

# %%
df
# Out:
#       Unnamed: 0                                              title   price  \
# 0              0  Áo hoodie nam nữ form rộng Unisex một màu in h...   99000
# 1              1  Áo hoodie nam nữ form rộng Unisex một màu in h...   99000
# 2              2  Áo hoodie nỉ bông unisex Homies liền mũ có túi...  100000
# 3              3  Áo hoodie nam nữ form rộng siêu xinh , Áo khoá...  110000
# 4              4  Áo khoác hoodie nam nữ vải nỉ xịn quảng châu m...  115000
# ...          ...                                                ...     ...
# 1058        1058  Quần Jean nam Leman xanh bạc rách JD18 - Slim ...  384000
# 1059        1059  Bộ Đồ Nam - Bộ Nỉ Nam Thu Đông Thể Thao Chất N...  300000
# 1060        1060  Quần Tây Nam Dáng Ôm Chất Liệu Vải Mềm Mịn Khh...   93000
# 1061        1061  Viettien - Quần Jeans nam dài Regular fit Màu ...  823200
# 1062        1062  Quần Jean Nam Trắng Trơn cao cấp thương hiệu C...  169000
#
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.rename(columns={'category': 'item_list'}, inplace=True)

# %%
df.insert(6, "category", "thoitrangnam")

# %%
df
# Out:
#                                                   title   price  \
# 0     Áo hoodie nam nữ form rộng Unisex một màu in h...   99000
# 1     Áo hoodie nam nữ form rộng Unisex một màu in h...   99000
# 2     Áo hoodie nỉ bông unisex Homies liền mũ có túi...  100000
# 3     Áo hoodie nam nữ form rộng siêu xinh , Áo khoá...  110000
# 4     Áo khoác hoodie nam nữ vải nỉ xịn quảng châu m...  115000
# ...                                                 ...     ...
# 1058  Quần Jean nam Leman xanh bạc rách JD18 - Slim ...  384000
# 1059  Bộ Đồ Nam - Bộ Nỉ Nam Thu Đông Thể Thao Chất N...  300000
# 1060  Quần Tây Nam Dáng Ôm Chất Liệu Vải Mềm Mịn Khh...   93000
# 1061  Viettien - Quần Jeans nam dài Regular fit Màu ...  823200
# 1062  Quần Jean Nam Trắng Trơn cao cấp thương hiệu C...  169000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=8ERGJXeHy...     -50%  924.0
# ...

# %%
df.to_csv('tk_thoitrangnam_all_ed.csv', index=False, encoding='utf-8')
