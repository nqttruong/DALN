# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\dochoi_mevabe\dochoi"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dochoi.csv',
#  'tk_dochoi_all.ipynb',
#  'tk_dochoi_t1.csv',
#  'tk_dochoi_t10.csv',
#  'tk_dochoi_t11.csv',
#  'tk_dochoi_t12.csv',
#  'tk_dochoi_t13.csv',
#  'tk_dochoi_t14.csv',
#  'tk_dochoi_t15.csv',
#  'tk_dochoi_t16.csv',
#  'tk_dochoi_t17.csv',
#  'tk_dochoi_t18.csv',
#  'tk_dochoi_t19.csv',
#  'tk_dochoi_t2.csv',
#  'tk_dochoi_t20.csv',
#  'tk_dochoi_t21.csv',
#  'tk_dochoi_t22.csv',
#  'tk_dochoi_t23.csv',
#  'tk_dochoi_t24.csv',
#  'tk_dochoi_t25.csv',
#  'tk_dochoi_t26.csv',
#  'tk_dochoi_t27.csv',
#  'tk_dochoi_t28.csv',
#  'tk_dochoi_t29.csv',
#  'tk_dochoi_t3.csv',
#  'tk_dochoi_t30.csv',
#  'tk_dochoi_t31.csv',
#  'tk_dochoi_t32.csv',
#  'tk_dochoi_t33.csv',
#  'tk_dochoi_t34.csv',
#  'tk_dochoi_t35.csv',
#  'tk_dochoi_t36.csv',
#  'tk_dochoi_t37.csv',
#  'tk_dochoi_t38.csv',
#  'tk_dochoi_t39.csv',
#  'tk_dochoi_t4.csv',
#  'tk_dochoi_t40.csv',
#  'tk_dochoi_t41.csv',
#  'tk_dochoi_t42.csv',
#  'tk_dochoi_t43.csv',
#  'tk_dochoi_t44.csv',
#  'tk_dochoi_t45.csv',
#  'tk_dochoi_t46.csv',
#  'tk_dochoi_t47.csv',
#  'tk_dochoi_t48.csv',
#  'tk_dochoi_t49.csv',
#  'tk_dochoi_t5.csv',
#  'tk_dochoi_t50.csv',
#  'tk_dochoi_t6.csv',
#  'tk_dochoi_t7.csv',
#  'tk_dochoi_t8.csv',
#  'tk_dochoi_t9.csv',
#  'tk_mvb_dochoi.ipynb',
#  'tk_mvb_dochoi_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dochoi_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title       price  \
# 0   Máy chơi game Buyfastcart Pop It phiên bản cải...    108.000₫
# 1   Xe scooter trẻ em Scoot and Ride Highwaykick 3...  1.805.000₫
# 2   Đồ Chơi Cát Ma Thuật Mideer Magic Sand Play Se...    583.000₫
# 3   Đồ chơi Sổ Tay Trang Điểm và Tô Màu Nước - Mid...    179.000₫
# 4   Đồ chơi âm nhạc cho bé - Đàn piano cổ điển kèm...  1.716.000₫
# ..                                                ...         ...
# 35  04 bộ tranh xếp hình 35 mảnh khổ A4 20x30cm – ...     72.000₫
# 36  ĐỒ CHƠI TÀU HOẢ ÔNG GIÀ NOEL CHẠY TRÊN ĐƯỜNG R...    195.000₫
# 37  Combo 4 Rubik Biến Thể QiYi Gift Box Mastermor...    204.000₫
# 38  Gấu Bông Gối Ôm Thú Bông, Nhồi Bông Hình Ly Tr...    129.000₫
# 39  Côn Trùng Giả Như Thật, Đồ Chơi Gián - Rết - B...      1.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=qJXJgTfmq...      1     -18%
# 1   https://tka.tiki.vn/pixel/pixel?data=nPaO1JHkK...      2     -22%
# 2   https://tka.tiki.vn/pixel/pixel?data=f7o8ztHRV...      3     -28%
# 3   https://tka.tiki.vn/pixel/pixel?data=--XnvSroF...      4      -6%
# 4   https://tka.tiki.vn/pixel/pixel?data=9bMj5WcqL...      5      -5%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/04-bo-tranh-xep-hinh-35-manh-k...     36      NaN
# 36  https://tiki.vn/do-choi-tau-hoa-ong-gia-noel-c...     37      NaN
# 37  https://tiki.vn/combo-4-rubik-bien-the-qiyi-gi...     38      NaN
# 38  https://tiki.vn/gau-bong-goi-om-thu-bong-nhoi-...     39      NaN
# 39  https://tiki.vn/con-trung-gia-nhu-that-do-choi...     40      NaN
#
#          sales category
# 0    Đã bán 68   dochoi
# 1          NaN   dochoi
# 2    Đã bán 24   dochoi
# 3    Đã bán 24   dochoi
# 4     Đã bán 5   dochoi
# ..         ...      ...
# 35   Đã bán 46   dochoi
# 36   Đã bán 31   dochoi
# 37    Đã bán 6   dochoi
# 38   Đã bán 46   dochoi
# 39  Đã bán 421   dochoi
#
# [2085 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title       price  \
# 0     Máy chơi game Buyfastcart Pop It phiên bản cải...    108.000₫
# 1     Đồ Chơi Cát Ma Thuật Mideer Magic Sand Play Se...    583.000₫
# 2     Đồ chơi Sổ Tay Trang Điểm và Tô Màu Nước - Mid...    179.000₫
# 3     Đồ chơi âm nhạc cho bé - Đàn piano cổ điển kèm...  1.716.000₫
# 4                  Xe chòi ô tô cho bé - màu xanh dương    189.000₫
# ...                                                 ...         ...
# 2032  04 bộ tranh xếp hình 35 mảnh khổ A4 20x30cm – ...     72.000₫
# 2033  ĐỒ CHƠI TÀU HOẢ ÔNG GIÀ NOEL CHẠY TRÊN ĐƯỜNG R...    195.000₫
# 2034  Combo 4 Rubik Biến Thể QiYi Gift Box Mastermor...    204.000₫
# 2035  Gấu Bông Gối Ôm Thú Bông, Nhồi Bông Hình Ly Tr...    129.000₫
# 2036  Côn Trùng Giả Như Thật, Đồ Chơi Gián - Rết - B...      1.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=qJXJgTfmq...     -18%   Đã bán 68
# 1     https://tka.tiki.vn/pixel/pixel?data=f7o8ztHRV...     -28%   Đã bán 24
# 2     https://tka.tiki.vn/pixel/pixel?data=--XnvSroF...      -6%   Đã bán 24
# 3     https://tka.tiki.vn/pixel/pixel?data=9bMj5WcqL...      -5%    Đã bán 5
# 4     https://tiki.vn/xe-choi-o-to-cho-be-mau-xanh-d...     -10%  Đã bán 357
# ...                                                 ...      ...         ...
# 2032  https://tiki.vn/04-bo-tranh-xep-hinh-35-manh-k...      NaN   Đã bán 46
# 2033  https://tiki.vn/do-choi-tau-hoa-ong-gia-noel-c...      NaN   Đã bán 31
# 2034  https://tiki.vn/combo-4-rubik-bien-the-qiyi-gi...      NaN    Đã bán 6
# 2035  https://tiki.vn/gau-bong-goi-om-thu-bong-nhoi-...      NaN   Đã bán 46
# 2036  https://tiki.vn/con-trung-gia-nhu-that-do-choi...      NaN  Đã bán 421
#
#      category
# 0      dochoi
# 1      dochoi
# 2      dochoi
# 3      dochoi
# 4      dochoi
# ...       ...
# 2032   dochoi
# 2033   dochoi
# 2034   dochoi
# 2035   dochoi
# 2036   dochoi
#
# [2037 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0        108000
# 1        583000
# 2        179000
# 3       1716000
# 4        189000
#          ...
# 2032      72000
# 2033     195000
# 2034     204000
# 2035     129000
# 2036       1000
# Name: price, Length: 2037, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0        68.0
# 1        24.0
# 2        24.0
# 3         5.0
# 4       357.0
#         ...
# 2032     46.0
# 2033     31.0
# 2034      6.0
# 2035     46.0
# 2036    421.0
# Name: sales, Length: 2037, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0        7344000.0
# 1       13992000.0
# 2        4296000.0
# 3        8580000.0
# 4       67473000.0
#            ...
# 2032     3312000.0
# 2033     6045000.0
# 2034     1224000.0
# 2035     5934000.0
# 2036      421000.0
# Name: revenue, Length: 2037, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dochoi: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dochoi:  26864766521.0
# So mat hang da ban:  2037
# So san pham da ban:  156197.0

# %%
df_all
# Out:
#                                                   title    price  \
# 0     Máy chơi game Buyfastcart Pop It phiên bản cải...   108000
# 1     Đồ Chơi Cát Ma Thuật Mideer Magic Sand Play Se...   583000
# 2     Đồ chơi Sổ Tay Trang Điểm và Tô Màu Nước - Mid...   179000
# 3     Đồ chơi âm nhạc cho bé - Đàn piano cổ điển kèm...  1716000
# 4                  Xe chòi ô tô cho bé - màu xanh dương   189000
# ...                                                 ...      ...
# 2032  04 bộ tranh xếp hình 35 mảnh khổ A4 20x30cm – ...    72000
# 2033  ĐỒ CHƠI TÀU HOẢ ÔNG GIÀ NOEL CHẠY TRÊN ĐƯỜNG R...   195000
# 2034  Combo 4 Rubik Biến Thể QiYi Gift Box Mastermor...   204000
# 2035  Gấu Bông Gối Ôm Thú Bông, Nhồi Bông Hình Ly Tr...   129000
# 2036  Côn Trùng Giả Như Thật, Đồ Chơi Gián - Rết - B...     1000
#
#                                               link_item discount  sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=qJXJgTfmq...     -18%   68.0
# 1     https://tka.tiki.vn/pixel/pixel?data=f7o8ztHRV...     -28%   24.0
# 2     https://tka.tiki.vn/pixel/pixel?data=--XnvSroF...      -6%   24.0
# 3     https://tka.tiki.vn/pixel/pixel?data=9bMj5WcqL...      -5%    5.0
# 4     https://tiki.vn/xe-choi-o-to-cho-be-mau-xanh-d...     -10%  357.0
# ...                                                 ...      ...    ...
# 2032  https://tiki.vn/04-bo-tranh-xep-hinh-35-manh-k...      NaN   46.0
# 2033  https://tiki.vn/do-choi-tau-hoa-ong-gia-noel-c...      NaN   31.0
# 2034  https://tiki.vn/combo-4-rubik-bien-the-qiyi-gi...      NaN    6.0
# 2035  https://tiki.vn/gau-bong-goi-om-thu-bong-nhoi-...      NaN   46.0
# 2036  https://tiki.vn/con-trung-gia-nhu-that-do-choi...      NaN  421.0
#
#      category     revenue
# 0      dochoi   7344000.0
# 1      dochoi  13992000.0
# 2      dochoi   4296000.0
# 3      dochoi   8580000.0
# 4      dochoi  67473000.0
# ...       ...         ...
# 2032   dochoi   3312000.0
# 2033   dochoi   6045000.0
# 2034   dochoi   1224000.0
# 2035   dochoi   5934000.0
# 2036   dochoi    421000.0
#
# [2037 rows x 7 columns]

# %%
df_all.to_csv("tk_dochoi_all_ed.csv")
