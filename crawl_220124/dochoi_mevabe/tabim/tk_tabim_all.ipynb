# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\dochoi_mevabe\tabim"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_mvb_tabim.ipynb',
#  'tk_mvb_tabim_npage.ipynb',
#  'tk_tabim.csv',
#  'tk_tabim_all.ipynb',
#  'tk_tabim_t1.csv',
#  'tk_tabim_t10.csv',
#  'tk_tabim_t11.csv',
#  'tk_tabim_t12.csv',
#  'tk_tabim_t13.csv',
#  'tk_tabim_t14.csv',
#  'tk_tabim_t15.csv',
#  'tk_tabim_t16.csv',
#  'tk_tabim_t17.csv',
#  'tk_tabim_t18.csv',
#  'tk_tabim_t19.csv',
#  'tk_tabim_t2.csv',
#  'tk_tabim_t20.csv',
#  'tk_tabim_t21.csv',
#  'tk_tabim_t22.csv',
#  'tk_tabim_t23.csv',
#  'tk_tabim_t24.csv',
#  'tk_tabim_t25.csv',
#  'tk_tabim_t26.csv',
#  'tk_tabim_t27.csv',
#  'tk_tabim_t28.csv',
#  'tk_tabim_t29.csv',
#  'tk_tabim_t3.csv',
#  'tk_tabim_t30.csv',
#  'tk_tabim_t31.csv',
#  'tk_tabim_t32.csv',
#  'tk_tabim_t33.csv',
#  'tk_tabim_t34.csv',
#  'tk_tabim_t35.csv',
#  'tk_tabim_t36.csv',
#  'tk_tabim_t37.csv',
#  'tk_tabim_t38.csv',
#  'tk_tabim_t39.csv',
#  'tk_tabim_t4.csv',
#  'tk_tabim_t40.csv',
#  'tk_tabim_t41.csv',
#  'tk_tabim_t42.csv',
#  'tk_tabim_t43.csv',
#  'tk_tabim_t44.csv',
#  'tk_tabim_t45.csv',
#  'tk_tabim_t46.csv',
#  'tk_tabim_t47.csv',
#  'tk_tabim_t48.csv',
#  'tk_tabim_t49.csv',
#  'tk_tabim_t5.csv',
#  'tk_tabim_t50.csv',
#  'tk_tabim_t6.csv',
#  'tk_tabim_t7.csv',
#  'tk_tabim_t8.csv',
#  'tk_tabim_t9.csv']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_tabim_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385.000₫
# 1   Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385.000₫
# 2   Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185.000₫
# 3   Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size M...   385.000
# 4                                                 NaN       NaN
# ..                                                ...       ...
# 35  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273.000₫
# 36  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275.000₫
# 37  Khăn giấy ướt vịt vàng 10 gói kèm thùng nhựa t...   84.781₫
# 38       Tã Dán Cao Cấp Moony Nhật Bản S84 (84 Miếng)  287.500₫
# 39  Combo 10 tả vải, tả dán sơ sinh cotton Thái Hà...  135.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=qp3TEDsxf...      1     -40%
# 1   https://tka.tiki.vn/pixel/pixel?data=MFIR0Z3B4...      2     -40%
# 2   https://tka.tiki.vn/pixel/pixel?data=RT5eTnIrK...      3     -34%
# 3   https://tka.tiki.vn/pixel/pixel?data=ssKion1iI...      4      NaN
# 4   https://tka.tiki.vn/pixel/pixel?data=RXTryxS19...      5      NaN
# ..                                                ...    ...      ...
# 35  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...     36      NaN
# 36  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...     37      NaN
# 37  https://tiki.vn/khan-giay-uot-vit-vang-10-goi-...     38      NaN
# 38  https://tiki.vn/ta-dan-cao-cap-moony-nhat-ban-...     39      NaN
# 39  https://tiki.vn/combo-10-ta-vai-ta-dan-so-sinh...     40      NaN
#
#           sales category
# 0    Đã bán 5k+    tabim
# 1   Đã bán 3.8k    tabim
# 2    Đã bán 5k+    tabim
# 3           NaN    tabim
# 4           NaN    tabim
# ..          ...      ...
# 35   Đã bán 217    tabim
# 36   Đã bán 189    tabim
# 37    Đã bán 11    tabim
# 38   Đã bán 238    tabim
# 39    Đã bán 88    tabim
#
# [2081 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385.000₫
# 1     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385.000₫
# 2     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185.000₫
# 3     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385.000₫
# 4     Tã/bỉm quần HUGGIES SKINCARE gói SUPER JUMBO s...  295.000₫
# ...                                                 ...       ...
# 1453  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273.000₫
# 1454  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275.000₫
# 1455  Khăn giấy ướt vịt vàng 10 gói kèm thùng nhựa t...   84.781₫
# 1456       Tã Dán Cao Cấp Moony Nhật Bản S84 (84 Miếng)  287.500₫
# 1457  Combo 10 tả vải, tả dán sơ sinh cotton Thái Hà...  135.000₫
#
#                                               link_item discount        sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=qp3TEDsxf...     -40%   Đã bán 5k+
# 1     https://tka.tiki.vn/pixel/pixel?data=MFIR0Z3B4...     -40%  Đã bán 3.8k
# 2     https://tka.tiki.vn/pixel/pixel?data=RT5eTnIrK...     -34%   Đã bán 5k+
# 3     https://tiki.vn/thung-ta-bim-quan-huggies-skin...     -40%   Đã bán 5k+
# 4     https://tiki.vn/ta-bim-quan-huggies-skincare-g...     -38%   Đã bán 5k+
# ...                                                 ...      ...          ...
# 1453  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...      NaN   Đã bán 217
# 1454  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...      NaN   Đã bán 189
# 1455  https://tiki.vn/khan-giay-uot-vit-vang-10-goi-...      NaN    Đã bán 11
# 1456  https://tiki.vn/ta-dan-cao-cap-moony-nhat-ban-...      NaN   Đã bán 238
# 1457  https://tiki.vn/combo-10-ta-vai-ta-dan-so-sinh...      NaN    Đã bán 88
#
#      category
# 0       tabim
# 1       tabim
# 2       tabim
# 3       tabim
# 4       tabim
# ...       ...
# 1453    tabim
# 1454    tabim
# 1455    tabim
# 1456    tabim
# 1457    tabim
#
# [1458 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       385000
# 1       385000
# 2       185000
# 3       385000
# 4       295000
#          ...
# 1453    273000
# 1454    275000
# 1455     84781
# 1456    287500
# 1457    135000
# Name: price, Length: 1458, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       5000.0
# 1       3800.0
# 2       5000.0
# 3       5000.0
# 4       5000.0
#          ...
# 1453     217.0
# 1454     189.0
# 1455      11.0
# 1456     238.0
# 1457      88.0
# Name: sales, Length: 1458, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1.925000e+09
# 1       1.463000e+09
# 2       9.250000e+08
# 3       1.925000e+09
# 4       1.475000e+09
#             ...
# 1453    5.924100e+07
# 1454    5.197500e+07
# 1455    9.325910e+05
# 1456    6.842500e+07
# 1457    1.188000e+07
# Name: revenue, Length: 1458, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số tabim: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số tabim:  135112556372.0
# So mat hang da ban:  1458
# So san pham da ban:  505235.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385000
# 1     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385000
# 2     Combo Tiết Kiệm: 6 Gói Khăn Ướt Bobby Care Khô...  185000
# 3     Tã/bỉm quần HUGGIES SKINCARE MEGA JUMBO size X...  385000
# 4     Tã/bỉm quần HUGGIES SKINCARE gói SUPER JUMBO s...  295000
# ...                                                 ...     ...
# 1453  Tã quần cao cấp Bobby Extra Soft Dry thun c...  273000
# 1454  Miếng lót đêm dùng cho tã - bỉm người lớn Live...  275000
# 1455  Khăn giấy ướt vịt vàng 10 gói kèm thùng nhựa t...   84781
# 1456       Tã Dán Cao Cấp Moony Nhật Bản S84 (84 Miếng)  287500
# 1457  Combo 10 tả vải, tả dán sơ sinh cotton Thái Hà...  135000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=qp3TEDsxf...     -40%  5000.0
# 1     https://tka.tiki.vn/pixel/pixel?data=MFIR0Z3B4...     -40%  3800.0
# 2     https://tka.tiki.vn/pixel/pixel?data=RT5eTnIrK...     -34%  5000.0
# 3     https://tiki.vn/thung-ta-bim-quan-huggies-skin...     -40%  5000.0
# 4     https://tiki.vn/ta-bim-quan-huggies-skincare-g...     -38%  5000.0
# ...                                                 ...      ...     ...
# 1453  https://tiki.vn/ta-qua-n-cao-ca-p-bobby-extra-...      NaN   217.0
# 1454  https://tiki.vn/mieng-lot-dem-dung-cho-ta-bim-...      NaN   189.0
# 1455  https://tiki.vn/khan-giay-uot-vit-vang-10-goi-...      NaN    11.0
# 1456  https://tiki.vn/ta-dan-cao-cap-moony-nhat-ban-...      NaN   238.0
# 1457  https://tiki.vn/combo-10-ta-vai-ta-dan-so-sinh...      NaN    88.0
#
#      category       revenue
# 0       tabim  1.925000e+09
# 1       tabim  1.463000e+09
# 2       tabim  9.250000e+08
# 3       tabim  1.925000e+09
# 4       tabim  1.475000e+09
# ...       ...           ...
# 1453    tabim  5.924100e+07
# 1454    tabim  5.197500e+07
# 1455    tabim  9.325910e+05
# 1456    tabim  6.842500e+07
# 1457    tabim  1.188000e+07
#
# [1458 rows x 7 columns]

# %%
df_all.to_csv("tk_tabim_all_ed.csv")
