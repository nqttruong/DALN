# %%
import pandas as pd
import os 
import numpy as np

# %%
path = r"D:\CNTT\py_for_da\crawl_data_analyst\tiki\crawl_180124(12htrua) - Copy (4)\dochoi_mevabe\dodungchobe"
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'tk_dodungchobe.csv',
#  'tk_dodungchobe_all.ipynb',
#  'tk_dodungchobe_t1.csv',
#  'tk_dodungchobe_t10.csv',
#  'tk_dodungchobe_t11.csv',
#  'tk_dodungchobe_t12.csv',
#  'tk_dodungchobe_t13.csv',
#  'tk_dodungchobe_t14.csv',
#  'tk_dodungchobe_t15.csv',
#  'tk_dodungchobe_t16.csv',
#  'tk_dodungchobe_t17.csv',
#  'tk_dodungchobe_t18.csv',
#  'tk_dodungchobe_t19.csv',
#  'tk_dodungchobe_t2.csv',
#  'tk_dodungchobe_t20.csv',
#  'tk_dodungchobe_t21.csv',
#  'tk_dodungchobe_t22.csv',
#  'tk_dodungchobe_t23.csv',
#  'tk_dodungchobe_t24.csv',
#  'tk_dodungchobe_t25.csv',
#  'tk_dodungchobe_t26.csv',
#  'tk_dodungchobe_t27.csv',
#  'tk_dodungchobe_t28.csv',
#  'tk_dodungchobe_t29.csv',
#  'tk_dodungchobe_t3.csv',
#  'tk_dodungchobe_t30.csv',
#  'tk_dodungchobe_t31.csv',
#  'tk_dodungchobe_t32.csv',
#  'tk_dodungchobe_t33.csv',
#  'tk_dodungchobe_t34.csv',
#  'tk_dodungchobe_t35.csv',
#  'tk_dodungchobe_t36.csv',
#  'tk_dodungchobe_t37.csv',
#  'tk_dodungchobe_t38.csv',
#  'tk_dodungchobe_t39.csv',
#  'tk_dodungchobe_t4.csv',
#  'tk_dodungchobe_t40.csv',
#  'tk_dodungchobe_t41.csv',
#  'tk_dodungchobe_t42.csv',
#  'tk_dodungchobe_t43.csv',
#  'tk_dodungchobe_t44.csv',
#  'tk_dodungchobe_t45.csv',
#  'tk_dodungchobe_t46.csv',
#  'tk_dodungchobe_t47.csv',
#  'tk_dodungchobe_t48.csv',
#  'tk_dodungchobe_t49.csv',
#  'tk_dodungchobe_t5.csv',
#  'tk_dodungchobe_t50.csv',
#  'tk_dodungchobe_t6.csv',
#  'tk_dodungchobe_t7.csv',
#  'tk_dodungchobe_t8.csv',
#  'tk_dodungchobe_t9.csv',
#  'tk_mvb_dodungchobe.ipynb',
#  'tk_mvb_dodungchobe_npage.ipynb']

# %%
frames = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + '\\' + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)

df_all = result
df_all.to_csv("tk_dodungchobe_all.csv", index="False")

# %%
df_all
# Out:
#                                                 title     price  \
# 0   Bộ 2 Chai Sữa Tắm Gội Toàn Thân Cho Bé Johnson...  227.000₫
# 1   Xe tròn tập đi cao cấp cho bé, khung xe kim lo...  306.000₫
# 2   Dung dịch súc rửa bình sữa & phụ kiện Pigeon 5...   82.000₫
# 3   Xe đẩy cho bé - Xe đẩy em bé du lịch thông min...  431.000₫
# 4     Đai đi xe máy cho bé cao cấp Chính Hãng Vinanoi  120.000₫
# ..                                                ...       ...
# 35          Combo 3 nước rửa bình sữa Dnee 620ml/chai  175.000₫
# 36  Ghế Gội Đầu Cho Bé Có Tay Vịn Cho Bé - Giao Mà...  118.000₫
# 37  Tấm lót chống thấm cho bé dùng được 2 mặt. Miế...  139.000₫
# 38  Bệt vệ sinh thu nhỏ có bé từ 18 tháng đến 3 4 ...  169.000₫
# 39  [Made in Thailand] Dung Dịch Giặt Quần Áo Cho ...  199.000₫
#
#                                             link_item  index discount  \
# 0   https://tka.tiki.vn/pixel/pixel?data=e8eHa9KIr...      1     -27%
# 1   https://tka.tiki.vn/pixel/pixel?data=KRnnA1nwp...      2     -41%
# 2   https://tka.tiki.vn/pixel/pixel?data=xmWX_qsCI...      3     -20%
# 3   https://tka.tiki.vn/pixel/pixel?data=yK6Fjsluy...      4     -26%
# 4   https://tka.tiki.vn/pixel/pixel?data=mNm5AFErN...      5      -4%
# ..                                                ...    ...      ...
# 35  https://tiki.vn/combo-3-nuoc-rua-binh-sua-dnee...     36      NaN
# 36  https://tiki.vn/ghe-goi-dau-cho-be-co-tay-vin-...     37      NaN
# 37  https://tiki.vn/tam-lot-chong-tham-cho-be-dung...     38      NaN
# 38  https://tiki.vn/bet-ve-sinh-thu-nho-co-be-tu-1...     39      NaN
# 39  https://tiki.vn/made-in-thailand-dung-dich-gia...     40      NaN
#
#          sales     category
# 0   Đã bán 5k+  dodungchobe
# 1    Đã bán 31  dodungchobe
# 2   Đã bán 174  dodungchobe
# 3    Đã bán 38  dodungchobe
# 4    Đã bán 24  dodungchobe
# ..         ...          ...
# 35  Đã bán 213  dodungchobe
# 36  Đã bán 105  dodungchobe
# 37  Đã bán 944  dodungchobe
# 38   Đã bán 44  dodungchobe
# 39  Đã bán 5k+  dodungchobe
#
# [2085 rows x 7 columns]

# %% [markdown]
# 1. Xử lý dữ liệu

# %%
df_all = df_all.drop('index', axis=1)

# %%
df_all.dropna(subset=['sales'], inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                                                   title     price  \
# 0     Bộ 2 Chai Sữa Tắm Gội Toàn Thân Cho Bé Johnson...  227.000₫
# 1     Xe tròn tập đi cao cấp cho bé, khung xe kim lo...  306.000₫
# 2     Dung dịch súc rửa bình sữa & phụ kiện Pigeon 5...   82.000₫
# 3     Xe đẩy cho bé - Xe đẩy em bé du lịch thông min...  431.000₫
# 4       Đai đi xe máy cho bé cao cấp Chính Hãng Vinanoi  120.000₫
# ...                                                 ...       ...
# 1857          Combo 3 nước rửa bình sữa Dnee 620ml/chai  175.000₫
# 1858  Ghế Gội Đầu Cho Bé Có Tay Vịn Cho Bé - Giao Mà...  118.000₫
# 1859  Tấm lót chống thấm cho bé dùng được 2 mặt. Miế...  139.000₫
# 1860  Bệt vệ sinh thu nhỏ có bé từ 18 tháng đến 3 4 ...  169.000₫
# 1861  [Made in Thailand] Dung Dịch Giặt Quần Áo Cho ...  199.000₫
#
#                                               link_item discount       sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=e8eHa9KIr...     -27%  Đã bán 5k+
# 1     https://tka.tiki.vn/pixel/pixel?data=KRnnA1nwp...     -41%   Đã bán 31
# 2     https://tka.tiki.vn/pixel/pixel?data=xmWX_qsCI...     -20%  Đã bán 174
# 3     https://tka.tiki.vn/pixel/pixel?data=yK6Fjsluy...     -26%   Đã bán 38
# 4     https://tka.tiki.vn/pixel/pixel?data=mNm5AFErN...      -4%   Đã bán 24
# ...                                                 ...      ...         ...
# 1857  https://tiki.vn/combo-3-nuoc-rua-binh-sua-dnee...      NaN  Đã bán 213
# 1858  https://tiki.vn/ghe-goi-dau-cho-be-co-tay-vin-...      NaN  Đã bán 105
# 1859  https://tiki.vn/tam-lot-chong-tham-cho-be-dung...      NaN  Đã bán 944
# 1860  https://tiki.vn/bet-ve-sinh-thu-nho-co-be-tu-1...      NaN   Đã bán 44
# 1861  https://tiki.vn/made-in-thailand-dung-dich-gia...      NaN  Đã bán 5k+
#
#          category
# 0     dodungchobe
# 1     dodungchobe
# 2     dodungchobe
# 3     dodungchobe
# 4     dodungchobe
# ...           ...
# 1857  dodungchobe
# 1858  dodungchobe
# 1859  dodungchobe
# 1860  dodungchobe
# 1861  dodungchobe
#
# [1862 rows x 6 columns]

# %%
df_all["price"] = df_all["price"].replace('[\₫,]', '', regex=True).replace('\.', '', regex=True).astype(int)
print(df_all["price"])
# Out:
# 0       227000
# 1       306000
# 2        82000
# 3       431000
# 4       120000
#          ...
# 1857    175000
# 1858    118000
# 1859    139000
# 1860    169000
# 1861    199000
# Name: price, Length: 1862, dtype: int32

# %%
def convert_to_number(value):
    if isinstance(value, str):
        if 'k+' in value:
            return float(value.replace('k+', '')) * 1000
        elif 'k' in value:
            return float(value.replace('k', '')) * 1000
        else:
            return float(value) if value else None
    else:
        return value

# Áp dụng hàm convert_to_number cho cột 'Gia'
df_all["sales"] = df_all["sales"].apply(lambda x: np.nan if pd.isna(x) else x.split('Đã bán')[1].strip())
df_all["sales"] = df_all["sales"].apply(convert_to_number)
df_all["sales"]
# Out:
# 0       5000.0
# 1         31.0
# 2        174.0
# 3         38.0
# 4         24.0
#          ...
# 1857     213.0
# 1858     105.0
# 1859     944.0
# 1860      44.0
# 1861    5000.0
# Name: sales, Length: 1862, dtype: float64

# %%
df_all["revenue"] = df_all["price"] * df_all["sales"]
df_all["revenue"]
# Out:
# 0       1.135000e+09
# 1       9.486000e+06
# 2       1.426800e+07
# 3       1.637800e+07
# 4       2.880000e+06
#             ...
# 1857    3.727500e+07
# 1858    1.239000e+07
# 1859    1.312160e+08
# 1860    7.436000e+06
# 1861    9.950000e+08
# Name: revenue, Length: 1862, dtype: float64

# %%
total = df_all["revenue"].sum()

# %%
print("Tổng doanh số dodungchobe: ", total)
print("So mat hang da ban: ", len(df_all["title"])) # san pham da ban
print("So san pham da ban: ", df_all["sales"].sum()) # san pham co luot ban
# Out:
# Tổng doanh số dodungchobe:  50878206807.0
# So mat hang da ban:  1862
# So san pham da ban:  235423.0

# %%
df_all
# Out:
#                                                   title   price  \
# 0     Bộ 2 Chai Sữa Tắm Gội Toàn Thân Cho Bé Johnson...  227000
# 1     Xe tròn tập đi cao cấp cho bé, khung xe kim lo...  306000
# 2     Dung dịch súc rửa bình sữa & phụ kiện Pigeon 5...   82000
# 3     Xe đẩy cho bé - Xe đẩy em bé du lịch thông min...  431000
# 4       Đai đi xe máy cho bé cao cấp Chính Hãng Vinanoi  120000
# ...                                                 ...     ...
# 1857          Combo 3 nước rửa bình sữa Dnee 620ml/chai  175000
# 1858  Ghế Gội Đầu Cho Bé Có Tay Vịn Cho Bé - Giao Mà...  118000
# 1859  Tấm lót chống thấm cho bé dùng được 2 mặt. Miế...  139000
# 1860  Bệt vệ sinh thu nhỏ có bé từ 18 tháng đến 3 4 ...  169000
# 1861  [Made in Thailand] Dung Dịch Giặt Quần Áo Cho ...  199000
#
#                                               link_item discount   sales  \
# 0     https://tka.tiki.vn/pixel/pixel?data=e8eHa9KIr...     -27%  5000.0
# 1     https://tka.tiki.vn/pixel/pixel?data=KRnnA1nwp...     -41%    31.0
# 2     https://tka.tiki.vn/pixel/pixel?data=xmWX_qsCI...     -20%   174.0
# 3     https://tka.tiki.vn/pixel/pixel?data=yK6Fjsluy...     -26%    38.0
# 4     https://tka.tiki.vn/pixel/pixel?data=mNm5AFErN...      -4%    24.0
# ...                                                 ...      ...     ...
# 1857  https://tiki.vn/combo-3-nuoc-rua-binh-sua-dnee...      NaN   213.0
# 1858  https://tiki.vn/ghe-goi-dau-cho-be-co-tay-vin-...      NaN   105.0
# 1859  https://tiki.vn/tam-lot-chong-tham-cho-be-dung...      NaN   944.0
# 1860  https://tiki.vn/bet-ve-sinh-thu-nho-co-be-tu-1...      NaN    44.0
# 1861  https://tiki.vn/made-in-thailand-dung-dich-gia...      NaN  5000.0
#
#          category       revenue
# 0     dodungchobe  1.135000e+09
# 1     dodungchobe  9.486000e+06
# 2     dodungchobe  1.426800e+07
# 3     dodungchobe  1.637800e+07
# 4     dodungchobe  2.880000e+06
# ...           ...           ...
# 1857  dodungchobe  3.727500e+07
# 1858  dodungchobe  1.239000e+07
# 1859  dodungchobe  1.312160e+08
# 1860  dodungchobe  7.436000e+06
# 1861  dodungchobe  9.950000e+08
#
# [1862 rows x 7 columns]

# %%
df_all.to_csv("tk_dodungchobe_all_ed.csv")
